# %%
import numpy as np
from scipy.stats import multivariate_normal
from ManifoldHMCAlgorithms.mixture_manifoldhmc import MHMC_AdaptiveKernel
from utils import quick_MVN_marginals, quick_MVN_scatter
import matplotlib.pyplot as plt

# %%
mu = np.zeros(2)
Sigma = np.array([[1.0, 0.99], [0.99, 2.0]])
target = multivariate_normal(mu, Sigma)
x = target.rvs()
z = target.pdf(x)

alpha = 0.2
N = 100000
n = 1
m = 200
T = 5.0
epsilon = 0.1
M = np.eye(2)
s = 0.5
trainevery=100

# %%
samples, func, n_zappa = MHMC_AdaptiveKernel(x, alpha, N, n, m, Sigma, mu, T, 
                                             epsilon, M, s, trainevery=trainevery)

# %%
quick_MVN_scatter(samples, target)

# %%
quick_MVN_marginals(samples, target)

# %%
xs = np.linspace(0.001, target.pdf(mu), 200)
plt.plot(xs, np.array([func(xx) for xx in xs]))
plt.show()
