# %%
import numpy as np
from scipy.stats import norm
import matplotlib.pyplot as plt

# %%
samples = norm.rvs(size=1000000)
_ = plt.hist(samples, bins=50, density=True)

# %%
_ = plt.hist(norm.pdf(samples), bins=50, density=True)
