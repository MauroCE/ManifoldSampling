# %%
import numpy as np
from numpy import zeros, eye, array, diag, exp, ones
from numpy.linalg import solve, norm
from numpy.random import choice, default_rng, randint, randn
from scipy.stats import multivariate_normal as MVN
from scipy.special import logsumexp
from scipy.stats import uniform as udist
import math
import time
from copy import deepcopy

import matplotlib.pyplot as plt
from matplotlib import rc
from ipywidgets.widgets import IntSlider
from ipywidgets.widgets import interact
from warnings import resetwarnings

from Manifolds.GKManifoldNew import GKManifold, data_generator, find_point_on_manifold, find_point_on_manifold_from_θ
from markov_snippets import MSAdaptive, SMCAdaptive
from tangential_hug_functions import TangentialHugSampler
from RWM import RWM

# %%
seed = randint(low=1000, high=9999)
print("Using random seed: ", seed)
# Out:
# Using random seed:  5464

# %%
def generate_settings(
    d=10, 
    N=5000,
    B=20,
    δ=0.1,
    δmin=1e-3,
    δmax=100.0,
    εmin=1e-16,
    min_pm=1e-4,
    maxiter=500,
    verbose=True,
    εs_fixed=None,
    adaptiveε=True,
    adaptiveδ=True,
    z0_manual=None,
    pm_target=0.23,
    pm_switch=0.05,
    prior_seed=seed,
    low_memory=True,
    integrator='rwm',
    εprop_switch=0.01,
    ε0_manual=None,
    quantile_value=0.5,
    initialization='prior',
    switch_strategy='pm',
    prior='uniform',
    kernel='uniform',
    prior_scale=7,
    thinning=10,
    burnin=100
    use_autograd=False):
    # here d represents m+4
    # Generate the manifold
    θ0        = array([3.0, 1.0, 2.0, 0.5])       # True parameter value on U(0, 10) scale.
    #d         = 4 + m                            # Dimensionality of ξ=(θ, z)
    ystar     = data_generator(θ0, m, seed=1234)  # Observed data
    q         = MVN(zeros(d), eye(d))             # Proposal distribution for THUG
    resetwarnings()
    manifold  = GKManifold(ystar, kernel_type=kernel, use_autograd=use_autograd)
    # grab arguments
    arguments = locals()
    return arguments

# %%
m = 50     # number of latent variables
d = m + 4  # dimensionality of x-component

# %%
SETTINGS_RWM = generate_settings(d=d, integrator='rwm')
SETTINGS_RT  = generate_settings(d=d, integrator='rwm_then_thug')

# %% [markdown]
# ### Manual Initialization

# %%
ξ0 = SETTINGS_RWM['manifold'].sample()               # Initial point on manifold  
ε0 = 10.0                                            # Starting epsilon
logηε0 = SETTINGS_RWM['manifold'].generate_logηε(ε0)  # Target filamentary distribution

# %%
# Sample using RWM
s_rwm, a_rwm = RWM(x0=ξ0, s=0.001, N=SETTINGS_RWM['N'], logpi=logηε0)

# %%
# create random velocities
v0_manual = randn(*s_rwm.shape)
z0_manual = np.hstack((s_rwm, v0_manual))

# %%
SETTING_MANUAL_RWM = generate_settings(
    δ=0.001,
    d=d, 
    integrator='rwm', 
    initialization='manual', 
    z0_manual=z0_manual, 
    ε0_manual=ε0
)

SETTING_MANUAL_RT = generate_settings(
    δ=0.001,
    d=d, 
    integrator='rwm_then_thug', 
    initialization='manual', 
    z0_manual=z0_manual, 
    ε0_manual=ε0
)

# %%
SMC_RWM_MAN = SMCAdaptive(SETTING_MANUAL_RWM)
_ = SMC_RWM_MAN.sample()
# Out:
# Stochastic Kernel: RWM.
# Iteration:  1
# 	Particles resampled.
# 	Epsilon: 9.7047254957788525
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0366000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  2
# 	Particles resampled.
# 	Epsilon: 9.4959656852404546
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0354000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  3
# 	Particles resampled.
# 	Epsilon: 9.3130213541161293
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0352000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  4
# 	Particles resampled.
# 	Epsilon: 9.1293049384503746
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0280000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  5
# 	Particles resampled.
# 	Epsilon: 8.9324860374137547
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0210000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  6
# 	Particles resampled.
# 	Epsilon: 8.6935449916760721
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0185999999999999
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  7
# 	Particles resampled.
# 	Epsilon: 8.4019182110290380
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0178000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  8
# 	Particles resampled.
# 	Epsilon: 8.1920202092816368
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0124000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  9
# 	Particles resampled.
# 	Epsilon: 7.9175616738066612
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0064000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  10
# 	Particles resampled.
# 	Epsilon: 7.7193330978923047
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0036000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  11
# 	Particles resampled.
# 	Epsilon: 7.4920409195934079
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0024000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  12
# 	Particles resampled.
# 	Epsilon: 7.2897981624841046
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0000000000000000
# 	Step-size adapted to: 0.0010000000000000

# %%
MS_RWM_MAN = MSAdaptive(SETTING_MANUAL_RWM)
_ = MS_RWM_MAN.sample()
# Out:
# Integrator: RWM.
# Iteration:  1
# 	Trajectories constructed.
# 	Epsilon: 9.6902592282570676
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9564000000000000
# 	Step-size adapted to: 0.0014379234151677
# Iteration:  2
# 	Trajectories constructed.
# 	Epsilon: 9.4961297402494722
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9470000000000000
# 	Step-size adapted to: 0.0020579287174409
# Iteration:  3
# 	Trajectories constructed.
# 	Epsilon: 9.3140089648127002
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9460000000000000
# 	Step-size adapted to: 0.0029437962796975
# Iteration:  4
# 	Trajectories constructed.
# 	Epsilon: 9.1430032254103342
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9332000000000000
# 	Step-size adapted to: 0.0041841350334042
# Iteration:  5
# 	Trajectories constructed.
# 	Epsilon: 8.9707328411109479
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9210000000000000
# 	Step-size adapted to: 0.0059109112065575
# Iteration:  6
# 	Trajectories constructed.
# 	Epsilon: 8.8110508130436429
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9062000000000000
# 	Step-size adapted to: 0.0082887568489892
# Iteration:  7
# 	Trajectories constructed.
# 	Epsilon: 8.6448488281877349
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8804000000000000
# 	Step-size adapted to: 0.0114741881042362
# Iteration:  8
# 	Trajectories constructed.
# 	Epsilon: 8.4552988125609936
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8424000000000000
# 	Step-size adapted to: 0.0155848610880963
# Iteration:  9
# 	Trajectories constructed.
# 	Epsilon: 8.2491300226193331
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7874000000000000
# 	Step-size adapted to: 0.0205940047111960
# Iteration:  10
# 	Trajectories constructed.
# 	Epsilon: 8.0559725977792738
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7136000000000000
# 	Step-size adapted to: 0.0262272776278448
# Iteration:  11
# 	Trajectories constructed.
# 	Epsilon: 7.8565247991637897
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.6644000000000000
# 	Step-size adapted to: 0.0325898209885274
# Iteration:  12
# 	Trajectories constructed.
# 	Epsilon: 7.6513048146773670
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.5914000000000000
# 	Step-size adapted to: 0.0390444210796008
# Iteration:  13
# 	Trajectories constructed.
# 	Epsilon: 7.4635299264121038
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.5175999999999999
# 	Step-size adapted to: 0.0450827639768754
# Iteration:  14
# 	Trajectories constructed.
# 	Epsilon: 7.2930227530049381
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.4692000000000000
# 	Step-size adapted to: 0.0508103462405571
# Iteration:  15
# 	Trajectories constructed.
# 	Epsilon: 7.1235955193641898
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.4088000000000000
# 	Step-size adapted to: 0.0555620269832200
# Iteration:  16
# 	Trajectories constructed.
# 	Epsilon: 6.9421665184383015
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.3476000000000000
# 	Step-size adapted to: 0.0589270359633245
# Iteration:  17
# 	Trajectories constructed.
# 	Epsilon: 6.7734031312696352
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.3396000000000000
# 	Step-size adapted to: 0.0622463562814294
# Iteration:  18
# 	Trajectories constructed.
# 	Epsilon: 6.6137888673435237
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.3206000000000000
# 	Step-size adapted to: 0.0651309592053406
# Iteration:  19
# 	Trajectories constructed.
# 	Epsilon: 6.4575449286648077
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2732000000000000
# 	Step-size adapted to: 0.0665530916626347
# Iteration:  20
# 	Trajectories constructed.
# 	Epsilon: 6.3196747783322289
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2626000000000000
# 	Step-size adapted to: 0.0676467965360237
# Iteration:  21
# 	Trajectories constructed.
# 	Epsilon: 6.2016553647198469
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2216000000000000
# 	Step-size adapted to: 0.0673632758008916
# Iteration:  22
# 	Trajectories constructed.
# 	Epsilon: 6.0954380357741886
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2108000000000000
# 	Step-size adapted to: 0.0667196825436265
# Iteration:  23
# 	Trajectories constructed.
# 	Epsilon: 5.9952594453122527
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2118000000000000
# 	Step-size adapted to: 0.0661152876002947
# Iteration:  24
# 	Trajectories constructed.
# 	Epsilon: 5.8979680133751771
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1862000000000000
# 	Step-size adapted to: 0.0646831024694328
# Iteration:  25
# 	Trajectories constructed.
# 	Epsilon: 5.7966253602864848
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2012000000000000
# 	Step-size adapted to: 0.0637583400630382
# Iteration:  26
# 	Trajectories constructed.
# 	Epsilon: 5.7040337140451616
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1834000000000000
# 	Step-size adapted to: 0.0622899439847427
# Iteration:  27
# 	Trajectories constructed.
# 	Epsilon: 5.6104501986424253
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2206000000000000
# 	Step-size adapted to: 0.0619978681638562
# Iteration:  28
# 	Trajectories constructed.
# 	Epsilon: 5.5110768470085727
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2224000000000000
# 	Step-size adapted to: 0.0617627233229888
# Iteration:  29
# 	Trajectories constructed.
# 	Epsilon: 5.4186670000788686
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2330000000000000
# 	Step-size adapted to: 0.0618554369257916
# Iteration:  30
# 	Trajectories constructed.
# 	Epsilon: 5.3211471129187657
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2134000000000000
# 	Step-size adapted to: 0.0613441615273545
# Iteration:  31
# 	Trajectories constructed.
# 	Epsilon: 5.2337872954819025
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1932000000000000
# 	Step-size adapted to: 0.0602257498961999
# Iteration:  32
# 	Trajectories constructed.
# 	Epsilon: 5.1568079106151421
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1758000000000000
# 	Step-size adapted to: 0.0586155488427275
# Iteration:  33
# 	Trajectories constructed.
# 	Epsilon: 5.0888972787514373
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1362000000000000
# 	Step-size adapted to: 0.0559299491689657
# Iteration:  34
# 	Trajectories constructed.
# 	Epsilon: 5.0288613285737647
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1828000000000000
# 	Step-size adapted to: 0.0546254559340672
# Iteration:  35
# 	Trajectories constructed.
# 	Epsilon: 4.9712811482145405
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1480000000000000
# 	Step-size adapted to: 0.0524311038421975
# Iteration:  36
# 	Trajectories constructed.
# 	Epsilon: 4.9240995530379346
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1924000000000000
# 	Step-size adapted to: 0.0514546069219346
# Iteration:  37
# 	Trajectories constructed.
# 	Epsilon: 4.8708923032796445
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1854000000000000
# 	Step-size adapted to: 0.0503198685445970
# Iteration:  38
# 	Trajectories constructed.
# 	Epsilon: 4.8099375446870285
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1708000000000000
# 	Step-size adapted to: 0.0488522286616596
# Iteration:  39
# 	Trajectories constructed.
# 	Epsilon: 4.7539779901629924
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1888000000000000
# 	Step-size adapted to: 0.0478561674059602
# Iteration:  40
# 	Trajectories constructed.
# 	Epsilon: 4.7026716874203380
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1834000000000000
# 	Step-size adapted to: 0.0467540087162628
# Iteration:  41
# 	Trajectories constructed.
# 	Epsilon: 4.6496777689485125
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1448000000000000
# 	Step-size adapted to: 0.0448041155429671
# Iteration:  42
# 	Trajectories constructed.
# 	Epsilon: 4.6039878258885309
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2092000000000000
# 	Step-size adapted to: 0.0443405673699267
# Iteration:  43
# 	Trajectories constructed.
# 	Epsilon: 4.5534020177839700
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1788000000000000
# 	Step-size adapted to: 0.0432198551666196
# Iteration:  44
# 	Trajectories constructed.
# 	Epsilon: 4.4950048688344557
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1824000000000000
# 	Step-size adapted to: 0.0422033668063274
# Iteration:  45
# 	Trajectories constructed.
# 	Epsilon: 4.4272283133443739
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1948000000000000
# 	Step-size adapted to: 0.0414670858289055
# Iteration:  46
# 	Trajectories constructed.
# 	Epsilon: 4.3464213155545366
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1934000000000000
# 	Step-size adapted to: 0.0407151394524079
# Iteration:  47
# 	Trajectories constructed.
# 	Epsilon: 4.2645691027789390
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1826000000000000
# 	Step-size adapted to: 0.0397615354897431
# Iteration:  48
# 	Trajectories constructed.
# 	Epsilon: 4.1826548589282897
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1636000000000000
# 	Step-size adapted to: 0.0384631253804043
# Iteration:  49
# 	Trajectories constructed.
# 	Epsilon: 4.1087556393529114
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1598000000000000
# 	Step-size adapted to: 0.0371364883589877
# Iteration:  50
# 	Trajectories constructed.
# 	Epsilon: 4.0491663120364052
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1500000000000000
# 	Step-size adapted to: 0.0356803458225186
# Iteration:  51
# 	Trajectories constructed.
# 	Epsilon: 3.9821268958627245
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1338000000000000
# 	Step-size adapted to: 0.0340047424937734
# Iteration:  52
# 	Trajectories constructed.
# 	Epsilon: 3.9292834167673307
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1512000000000000
# 	Step-size adapted to: 0.0326910061896211
# Iteration:  53
# 	Trajectories constructed.
# 	Epsilon: 3.8785510496608859
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1488000000000000
# 	Step-size adapted to: 0.0313903336506705
# Iteration:  54
# 	Trajectories constructed.
# 	Epsilon: 3.8244174684657155
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1604000000000000
# 	Step-size adapted to: 0.0303167389327118
# Iteration:  55
# 	Trajectories constructed.
# 	Epsilon: 3.7776448333453150
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1418000000000000
# 	Step-size adapted to: 0.0290088222720596
# Iteration:  56
# 	Trajectories constructed.
# 	Epsilon: 3.7314780271926566
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1652000000000000
# 	Step-size adapted to: 0.0280839994620509
# Iteration:  57
# 	Trajectories constructed.
# 	Epsilon: 3.6913074873343423
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1954000000000000
# 	Step-size adapted to: 0.0276023247707455
# Iteration:  58
# 	Trajectories constructed.
# 	Epsilon: 3.6491846173685563
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1900000000000000
# 	Step-size adapted to: 0.0270557621204670
# Iteration:  59
# 	Trajectories constructed.
# 	Epsilon: 3.6011533021246347
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1792000000000000
# 	Step-size adapted to: 0.0263771999831215
# Iteration:  60
# 	Trajectories constructed.
# 	Epsilon: 3.5524123604474060
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2280000000000000
# 	Step-size adapted to: 0.0263508359673433
# Iteration:  61
# 	Trajectories constructed.
# 	Epsilon: 3.5085521036740532
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2078000000000000
# 	Step-size adapted to: 0.0260599590416162
# Iteration:  62
# 	Trajectories constructed.
# 	Epsilon: 3.4606527384031347
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2204000000000000
# 	Step-size adapted to: 0.0259351709691833
# Iteration:  63
# 	Trajectories constructed.
# 	Epsilon: 3.4122863675261614
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2104000000000000
# 	Step-size adapted to: 0.0256822476422139
# Iteration:  64
# 	Trajectories constructed.
# 	Epsilon: 3.3634691523846736
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2248000000000000
# 	Step-size adapted to: 0.0256155605291582
# Iteration:  65
# 	Trajectories constructed.
# 	Epsilon: 3.3131519055032426
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2072000000000000
# 	Step-size adapted to: 0.0253252013311378
# Iteration:  66
# 	Trajectories constructed.
# 	Epsilon: 3.2626445925239884
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2110000000000000
# 	Step-size adapted to: 0.0250857511079149
# Iteration:  67
# 	Trajectories constructed.
# 	Epsilon: 3.2108394140204615
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2076000000000000
# 	Step-size adapted to: 0.0248063582162803
# Iteration:  68
# 	Trajectories constructed.
# 	Epsilon: 3.1581078312483877
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2246000000000000
# 	Step-size adapted to: 0.0247394713869497
# Iteration:  69
# 	Trajectories constructed.
# 	Epsilon: 3.1023981487436565
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1916000000000000
# 	Step-size adapted to: 0.0242690044713647
# Iteration:  70
# 	Trajectories constructed.
# 	Epsilon: 3.0543205713076116
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2030000000000000
# 	Step-size adapted to: 0.0239435745057219
# Iteration:  71
# 	Trajectories constructed.
# 	Epsilon: 3.0045275534780105
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1812000000000000
# 	Step-size adapted to: 0.0233664211924202
# Iteration:  72
# 	Trajectories constructed.
# 	Epsilon: 2.9580906205850876
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1950000000000000
# 	Step-size adapted to: 0.0229610660242235
# Iteration:  73
# 	Trajectories constructed.
# 	Epsilon: 2.9149237671359565
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2148000000000000
# 	Step-size adapted to: 0.0227872233613203
# Iteration:  74
# 	Trajectories constructed.
# 	Epsilon: 2.8651462114425601
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1910000000000000
# 	Step-size adapted to: 0.0223471769026305
# Iteration:  75
# 	Trajectories constructed.
# 	Epsilon: 2.8173679507850191
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2128000000000000
# 	Step-size adapted to: 0.0221558152159451
# Iteration:  76
# 	Trajectories constructed.
# 	Epsilon: 2.7732737022070997
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2094000000000000
# 	Step-size adapted to: 0.0219287815497649
# Iteration:  77
# 	Trajectories constructed.
# 	Epsilon: 2.7268326421530418
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1686000000000000
# 	Step-size adapted to: 0.0212657968420048
# Iteration:  78
# 	Trajectories constructed.
# 	Epsilon: 2.6888337700035447
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1684000000000000
# 	Step-size adapted to: 0.0206207943267979
# Iteration:  79
# 	Trajectories constructed.
# 	Epsilon: 2.6517005823760913
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1706000000000000
# 	Step-size adapted to: 0.0200173620605904
# Iteration:  80
# 	Trajectories constructed.
# 	Epsilon: 2.6157641318134655
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1602000000000000
# 	Step-size adapted to: 0.0193308062088649
# Iteration:  81
# 	Trajectories constructed.
# 	Epsilon: 2.5807082672173354
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1514000000000000
# 	Step-size adapted to: 0.0185858399913029
# Iteration:  82
# 	Trajectories constructed.
# 	Epsilon: 2.5498791325424803
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1582000000000000
# 	Step-size adapted to: 0.0179304430985015
# Iteration:  83
# 	Trajectories constructed.
# 	Epsilon: 2.5221496572617674
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1300000000000000
# 	Step-size adapted to: 0.0170559650696303
# Iteration:  84
# 	Trajectories constructed.
# 	Epsilon: 2.4981083683774492
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1266000000000000
# 	Step-size adapted to: 0.0161965782371621
# Iteration:  85
# 	Trajectories constructed.
# 	Epsilon: 2.4766727933610024
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0986000000000000
# 	Step-size adapted to: 0.0151666661011200
# Iteration:  86
# 	Trajectories constructed.
# 	Epsilon: 2.4505097687199240
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2062000000000000
# 	Step-size adapted to: 0.0149872524032452
# Iteration:  87
# 	Trajectories constructed.
# 	Epsilon: 2.4254058909631526
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1758000000000000
# 	Step-size adapted to: 0.0145865518781383
# Iteration:  88
# 	Trajectories constructed.
# 	Epsilon: 2.4009453762392639
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2582000000000000
# 	Step-size adapted to: 0.0147936790747880
# Iteration:  89
# 	Trajectories constructed.
# 	Epsilon: 2.3740873913222424
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2544000000000000
# 	Step-size adapted to: 0.0149752673959647
# Iteration:  90
# 	Trajectories constructed.
# 	Epsilon: 2.3484570084026513
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2310000000000000
# 	Step-size adapted to: 0.0149827569018831
# Iteration:  91
# 	Trajectories constructed.
# 	Epsilon: 2.3211900250190700
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2340000000000000
# 	Step-size adapted to: 0.0150127524011877
# Iteration:  92
# 	Trajectories constructed.
# 	Epsilon: 2.2946681755846385
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2180000000000000
# 	Step-size adapted to: 0.0149229455766744
# Iteration:  93
# 	Trajectories constructed.
# 	Epsilon: 2.2704827314176796
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1968000000000000
# 	Step-size adapted to: 0.0146772694336063
# Iteration:  94
# 	Trajectories constructed.
# 	Epsilon: 2.2468225068334013
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2060000000000000
# 	Step-size adapted to: 0.0145021947493994
# Iteration:  95
# 	Trajectories constructed.
# 	Epsilon: 2.2218262197851986
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1876000000000000
# 	Step-size adapted to: 0.0141979842456638
# Iteration:  96
# 	Trajectories constructed.
# 	Epsilon: 2.1978215262145007
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2398000000000000
# 	Step-size adapted to: 0.0142677250940063
# Iteration:  97
# 	Trajectories constructed.
# 	Epsilon: 2.1726567113453212
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2436000000000000
# 	Step-size adapted to: 0.0143650762434274
# Iteration:  98
# 	Trajectories constructed.
# 	Epsilon: 2.1466154960792041
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2148000000000000
# 	Step-size adapted to: 0.0142563154783858
# Iteration:  99
# 	Trajectories constructed.
# 	Epsilon: 2.1217654280600899
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2318000000000000
# 	Step-size adapted to: 0.0142691519378567
# Iteration:  100
# 	Trajectories constructed.
# 	Epsilon: 2.0954231493077544
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1806000000000000
# 	Step-size adapted to: 0.0139210210011469
# Iteration:  101
# 	Trajectories constructed.
# 	Epsilon: 2.0710544839972642
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2058000000000000
# 	Step-size adapted to: 0.0137535916374562
# Iteration:  102
# 	Trajectories constructed.
# 	Epsilon: 2.0492597211208530
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1868000000000000
# 	Step-size adapted to: 0.0134596995193988
# Iteration:  103
# 	Trajectories constructed.
# 	Epsilon: 2.0253979184773443
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2100000000000000
# 	Step-size adapted to: 0.0133257732714946
# Iteration:  104
# 	Trajectories constructed.
# 	Epsilon: 2.0033130649286814
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2058000000000000
# 	Step-size adapted to: 0.0131655030054451
# Iteration:  105
# 	Trajectories constructed.
# 	Epsilon: 1.9822341470935003
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1868000000000000
# 	Step-size adapted to: 0.0128841773949752
# Iteration:  106
# 	Trajectories constructed.
# 	Epsilon: 1.9623402430980046
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1680000000000000
# 	Step-size adapted to: 0.0124908952636068
# Iteration:  107
# 	Trajectories constructed.
# 	Epsilon: 1.9433930014810981
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1994000000000000
# 	Step-size adapted to: 0.0123012391351587
# Iteration:  108
# 	Trajectories constructed.
# 	Epsilon: 1.9237559631519496
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2312000000000000
# 	Step-size adapted to: 0.0123086220933058
# Iteration:  109
# 	Trajectories constructed.
# 	Epsilon: 1.9036587400206673
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2290000000000000
# 	Step-size adapted to: 0.0123024693205805
# Iteration:  110
# 	Trajectories constructed.
# 	Epsilon: 1.8811313330329495
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2430000000000000
# 	Step-size adapted to: 0.0123826958248392
# Iteration:  111
# 	Trajectories constructed.
# 	Epsilon: 1.8579394850157276
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2442000000000000
# 	Step-size adapted to: 0.0124709258110073
# Iteration:  112
# 	Trajectories constructed.
# 	Epsilon: 1.8327423157128324
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2562000000000000
# 	Step-size adapted to: 0.0126353696948931
# Iteration:  113
# 	Trajectories constructed.
# 	Epsilon: 1.8064986288861755
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2360000000000000
# 	Step-size adapted to: 0.0126733327200432
# Iteration:  114
# 	Trajectories constructed.
# 	Epsilon: 1.7765944154326523
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2370000000000000
# 	Step-size adapted to: 0.0127177670993671
# Iteration:  115
# 	Trajectories constructed.
# 	Epsilon: 1.7508158585819813
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2128000000000000
# 	Step-size adapted to: 0.0126088632600315
# Iteration:  116
# 	Trajectories constructed.
# 	Epsilon: 1.7261752093713980
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1920000000000000
# 	Step-size adapted to: 0.0123715564120845
# Iteration:  117
# 	Trajectories constructed.
# 	Epsilon: 1.7025153194647795
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2174000000000000
# 	Step-size adapted to: 0.0122938606054579
# Iteration:  118
# 	Trajectories constructed.
# 	Epsilon: 1.6800940948579390
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1878000000000000
# 	Step-size adapted to: 0.0120371776746824
# Iteration:  119
# 	Trajectories constructed.
# 	Epsilon: 1.6581056523035018
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2176000000000000
# 	Step-size adapted to: 0.0119627780502617
# Iteration:  120
# 	Trajectories constructed.
# 	Epsilon: 1.6374957176654454
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2100000000000000
# 	Step-size adapted to: 0.0118437464198398
# Iteration:  121
# 	Trajectories constructed.
# 	Epsilon: 1.6158032428031650
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1682000000000000
# 	Step-size adapted to: 0.0114833711274391
# Iteration:  122
# 	Trajectories constructed.
# 	Epsilon: 1.5940151232811732
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2086000000000000
# 	Step-size adapted to: 0.0113611540836102
# Iteration:  123
# 	Trajectories constructed.
# 	Epsilon: 1.5737385531468180
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2186000000000000
# 	Step-size adapted to: 0.0112965797171132
# Iteration:  124
# 	Trajectories constructed.
# 	Epsilon: 1.5507430724388191
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2074000000000000
# 	Step-size adapted to: 0.0111696468874655
# Iteration:  125
# 	Trajectories constructed.
# 	Epsilon: 1.5311064956289004
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2024000000000000
# 	Step-size adapted to: 0.0110165644585882
# Iteration:  126
# 	Trajectories constructed.
# 	Epsilon: 1.5110772056641948
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2188000000000000
# 	Step-size adapted to: 0.0109550441153542
# Iteration:  127
# 	Trajectories constructed.
# 	Epsilon: 1.4908183024182891
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1844000000000000
# 	Step-size adapted to: 0.0107080950268746
# Iteration:  128
# 	Trajectories constructed.
# 	Epsilon: 1.4719212497011405
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1934000000000000
# 	Step-size adapted to: 0.0105139190173071
# Iteration:  129
# 	Trajectories constructed.
# 	Epsilon: 1.4536195397325995
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2066000000000000
# 	Step-size adapted to: 0.0103916229916435
# Iteration:  130
# 	Trajectories constructed.
# 	Epsilon: 1.4352295423978354
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1938000000000000
# 	Step-size adapted to: 0.0102052265916638
# Iteration:  131
# 	Trajectories constructed.
# 	Epsilon: 1.4182005663998825
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1804000000000000
# 	Step-size adapted to: 0.0099552495001532
# Iteration:  132
# 	Trajectories constructed.
# 	Epsilon: 1.4018353880240333
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2006000000000000
# 	Step-size adapted to: 0.0098099776962323
# Iteration:  133
# 	Trajectories constructed.
# 	Epsilon: 1.3838727817986243
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1742000000000000
# 	Step-size adapted to: 0.0095400621489122
# Iteration:  134
# 	Trajectories constructed.
# 	Epsilon: 1.3687632290604319
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1538000000000000
# 	Step-size adapted to: 0.0091834228994555
# Iteration:  135
# 	Trajectories constructed.
# 	Epsilon: 1.3538516720629228
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2052000000000000
# 	Step-size adapted to: 0.0090702515678564
# Iteration:  136
# 	Trajectories constructed.
# 	Epsilon: 1.3393158123376123
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2006000000000000
# 	Step-size adapted to: 0.0089378940807579
# Iteration:  137
# 	Trajectories constructed.
# 	Epsilon: 1.3248547596804909
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1986000000000000
# 	Step-size adapted to: 0.0087986649522196
# Iteration:  138
# 	Trajectories constructed.
# 	Epsilon: 1.3108757651724974
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2138000000000000
# 	Step-size adapted to: 0.0087276836285575
# Iteration:  139
# 	Trajectories constructed.
# 	Epsilon: 1.2966330749803381
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1892000000000000
# 	Step-size adapted to: 0.0085514426524855
# Iteration:  140
# 	Trajectories constructed.
# 	Epsilon: 1.2847627374529893
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2268000000000000
# 	Step-size adapted to: 0.0085377712842526
# Iteration:  141
# 	Trajectories constructed.
# 	Epsilon: 1.2695308751507584
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1698000000000000
# 	Step-size adapted to: 0.0082846135064866
# Iteration:  142
# 	Trajectories constructed.
# 	Epsilon: 1.2560989365097004
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2038000000000000
# 	Step-size adapted to: 0.0081767928368587
# Iteration:  143
# 	Trajectories constructed.
# 	Epsilon: 1.2425985465845613
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1994000000000000
# 	Step-size adapted to: 0.0080526400968162
# Iteration:  144
# 	Trajectories constructed.
# 	Epsilon: 1.2294862053599098
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1904000000000000
# 	Step-size adapted to: 0.0078947659348182
# Iteration:  145
# 	Trajectories constructed.
# 	Epsilon: 1.2159201775330406
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2192000000000000
# 	Step-size adapted to: 0.0078522490975467
# Iteration:  146
# 	Trajectories constructed.
# 	Epsilon: 1.2033345584404147
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2058000000000000
# 	Step-size adapted to: 0.0077578093959016
# Iteration:  147
# 	Trajectories constructed.
# 	Epsilon: 1.1901942698428369
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2090000000000000
# 	Step-size adapted to: 0.0076767785536360
# Iteration:  148
# 	Trajectories constructed.
# 	Epsilon: 1.1772534914629493
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1930000000000000
# 	Step-size adapted to: 0.0075360637753725
# Iteration:  149
# 	Trajectories constructed.
# 	Epsilon: 1.1632802511938614
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1988000000000000
# 	Step-size adapted to: 0.0074194134189167
# Iteration:  150
# 	Trajectories constructed.
# 	Epsilon: 1.1505585035119423
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2044000000000000
# 	Step-size adapted to: 0.0073250501405062
# Iteration:  151
# 	Trajectories constructed.
# 	Epsilon: 1.1382991051663218
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2130000000000000
# 	Step-size adapted to: 0.0072630510835893
# Iteration:  152
# 	Trajectories constructed.
# 	Epsilon: 1.1253213898018255
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2146000000000000
# 	Step-size adapted to: 0.0072073403518201
# Iteration:  153
# 	Trajectories constructed.
# 	Epsilon: 1.1131402343665746
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2140000000000000
# 	Step-size adapted to: 0.0071499116500985
# Iteration:  154
# 	Trajectories constructed.
# 	Epsilon: 1.0995148084838058
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2380000000000000
# 	Step-size adapted to: 0.0071785685723342
# Iteration:  155
# 	Trajectories constructed.
# 	Epsilon: 1.0870563783957168
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2452000000000000
# 	Step-size adapted to: 0.0072333335367469
# Iteration:  156
# 	Trajectories constructed.
# 	Epsilon: 1.0740501237587707
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2108000000000000
# 	Step-size adapted to: 0.0071642257827600
# Iteration:  157
# 	Trajectories constructed.
# 	Epsilon: 1.0616430363857947
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2054000000000000
# 	Step-size adapted to: 0.0070766455283619
# Iteration:  158
# 	Trajectories constructed.
# 	Epsilon: 1.0493300888349220
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2012000000000000
# 	Step-size adapted to: 0.0069754720302122
# Iteration:  159
# 	Trajectories constructed.
# 	Epsilon: 1.0365358273335936
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2082000000000000
# 	Step-size adapted to: 0.0068998522615195
# Iteration:  160
# 	Trajectories constructed.
# 	Epsilon: 1.0241488347757439
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1752000000000000
# 	Step-size adapted to: 0.0067133628813139
# Iteration:  161
# 	Trajectories constructed.
# 	Epsilon: 1.0133188170774974
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1856000000000000
# 	Step-size adapted to: 0.0065659683580009
# Iteration:  162
# 	Trajectories constructed.
# 	Epsilon: 1.0024750624682912
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1974000000000000
# 	Step-size adapted to: 0.0064598106098237
# Iteration:  163
# 	Trajectories constructed.
# 	Epsilon: 0.9916747644084185
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2054000000000000
# 	Step-size adapted to: 0.0063808415943673
# Iteration:  164
# 	Trajectories constructed.
# 	Epsilon: 0.9819023485276640
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2012000000000000
# 	Step-size adapted to: 0.0062896158769488
# Iteration:  165
# 	Trajectories constructed.
# 	Epsilon: 0.9725161876271402
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2086000000000000
# 	Step-size adapted to: 0.0062226757553791
# Iteration:  166
# 	Trajectories constructed.
# 	Epsilon: 0.9628382080995719
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1810000000000000
# 	Step-size adapted to: 0.0060720726209876
# Iteration:  167
# 	Trajectories constructed.
# 	Epsilon: 0.9536392657867594
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1966000000000000
# 	Step-size adapted to: 0.0059715110345877
# Iteration:  168
# 	Trajectories constructed.
# 	Epsilon: 0.9447173096621564
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2042000000000000
# 	Step-size adapted to: 0.0058949732721935
# Iteration:  169
# 	Trajectories constructed.
# 	Epsilon: 0.9355080669400343
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1930000000000000
# 	Step-size adapted to: 0.0057869188518308
# Iteration:  170
# 	Trajectories constructed.
# 	Epsilon: 0.9267865140725451
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1714000000000000
# 	Step-size adapted to: 0.0056198220516678
# Iteration:  171
# 	Trajectories constructed.
# 	Epsilon: 0.9179471853459418
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1960000000000000
# 	Step-size adapted to: 0.0055250925588692
# Iteration:  172
# 	Trajectories constructed.
# 	Epsilon: 0.9107768766089798
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1654000000000000
# 	Step-size adapted to: 0.0053494834240836
# Iteration:  173
# 	Trajectories constructed.
# 	Epsilon: 0.9023122163232432
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2204000000000000
# 	Step-size adapted to: 0.0053238674312135
# Iteration:  174
# 	Trajectories constructed.
# 	Epsilon: 0.8945424400828215
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2256000000000000
# 	Step-size adapted to: 0.0053121677971811
# Iteration:  175
# 	Trajectories constructed.
# 	Epsilon: 0.8859274558470703
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1992000000000000
# 	Step-size adapted to: 0.0052309871087998
# Iteration:  176
# 	Trajectories constructed.
# 	Epsilon: 0.8782172778489712
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2178000000000000
# 	Step-size adapted to: 0.0051991752123635
# Iteration:  177
# 	Trajectories constructed.
# 	Epsilon: 0.8699932950600867
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2056000000000000
# 	Step-size adapted to: 0.0051361306286941
# Iteration:  178
# 	Trajectories constructed.
# 	Epsilon: 0.8617753357302016
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2256000000000000
# 	Step-size adapted to: 0.0051248435616372
# Iteration:  179
# 	Trajectories constructed.
# 	Epsilon: 0.8524742255844417
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2234000000000000
# 	Step-size adapted to: 0.0051079594519871
# Iteration:  180
# 	Trajectories constructed.
# 	Epsilon: 0.8443499847504639
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2084000000000000
# 	Step-size adapted to: 0.0050530903165638
# Iteration:  181
# 	Trajectories constructed.
# 	Epsilon: 0.8359640741284688
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2076000000000000
# 	Step-size adapted to: 0.0049968114549439
# Iteration:  182
# 	Trajectories constructed.
# 	Epsilon: 0.8288759377099921
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1728000000000000
# 	Step-size adapted to: 0.0048559268995053
# Iteration:  183
# 	Trajectories constructed.
# 	Epsilon: 0.8210456220004405
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2262000000000000
# 	Step-size adapted to: 0.0048467093977957
# Iteration:  184
# 	Trajectories constructed.
# 	Epsilon: 0.8142589289214137
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1954000000000000
# 	Step-size adapted to: 0.0047635824465869
# Iteration:  185
# 	Trajectories constructed.
# 	Epsilon: 0.8075615081884631
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2000000000000000
# 	Step-size adapted to: 0.0046926619434164
# Iteration:  186
# 	Trajectories constructed.
# 	Epsilon: 0.8005499727031715
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1942000000000000
# 	Step-size adapted to: 0.0046094106168697
# Iteration:  187
# 	Trajectories constructed.
# 	Epsilon: 0.7933857707209899
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1998000000000000
# 	Step-size adapted to: 0.0045403313773713
# Iteration:  188
# 	Trajectories constructed.
# 	Epsilon: 0.7864438989293492
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2070000000000000
# 	Step-size adapted to: 0.0044884166483657
# Iteration:  189
# 	Trajectories constructed.
# 	Epsilon: 0.7802346021002284
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2274000000000000
# 	Step-size adapted to: 0.0044825854977919
# Iteration:  190
# 	Trajectories constructed.
# 	Epsilon: 0.7739953057801315
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2110000000000000
# 	Step-size adapted to: 0.0044402025732091
# Iteration:  191
# 	Trajectories constructed.
# 	Epsilon: 0.7676019996470724
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2068000000000000
# 	Step-size adapted to: 0.0043889938084153
# Iteration:  192
# 	Trajectories constructed.
# 	Epsilon: 0.7607452175832013
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2206000000000000
# 	Step-size adapted to: 0.0043684139380951
# Iteration:  193
# 	Trajectories constructed.
# 	Epsilon: 0.7537026259184760
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1986000000000000
# 	Step-size adapted to: 0.0043003654179180
# Iteration:  194
# 	Trajectories constructed.
# 	Epsilon: 0.7471350979918387
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2094000000000000
# 	Step-size adapted to: 0.0042562989858220
# Iteration:  195
# 	Trajectories constructed.
# 	Epsilon: 0.7408139305945323
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1976000000000000
# 	Step-size adapted to: 0.0041879024500174
# Iteration:  196
# 	Trajectories constructed.
# 	Epsilon: 0.7349044888588038
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2166000000000000
# 	Step-size adapted to: 0.0041599372914962
# Iteration:  197
# 	Trajectories constructed.
# 	Epsilon: 0.7294429374873939
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2064000000000000
# 	Step-size adapted to: 0.0041111385104917
# Iteration:  198
# 	Trajectories constructed.
# 	Epsilon: 0.7239711042776783
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2006000000000000
# 	Step-size adapted to: 0.0040511467938021
# Iteration:  199
# 	Trajectories constructed.
# 	Epsilon: 0.7178406192597911
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2320000000000000
# 	Step-size adapted to: 0.0040551999668447
# Iteration:  200
# 	Trajectories constructed.
# 	Epsilon: 0.7109639231612667
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2322000000000000
# 	Step-size adapted to: 0.0040596631411040
# Iteration:  201
# 	Trajectories constructed.
# 	Epsilon: 0.7032336676854096
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2380000000000000
# 	Step-size adapted to: 0.0040759343143200
# Iteration:  202
# 	Trajectories constructed.
# 	Epsilon: 0.6960270127746930
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2158000000000000
# 	Step-size adapted to: 0.0040470976719067
# Iteration:  203
# 	Trajectories constructed.
# 	Epsilon: 0.6901670725483814
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2236000000000000
# 	Step-size adapted to: 0.0040341676584118
# Iteration:  204
# 	Trajectories constructed.
# 	Epsilon: 0.6838381944520906
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1968000000000000
# 	Step-size adapted to: 0.0039677532400440
# Iteration:  205
# 	Trajectories constructed.
# 	Epsilon: 0.6784271803365101
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2020000000000000
# 	Step-size adapted to: 0.0039125917262484
# Iteration:  206
# 	Trajectories constructed.
# 	Epsilon: 0.6725700241410928
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2204000000000000
# 	Step-size adapted to: 0.0038938562869887
# Iteration:  207
# 	Trajectories constructed.
# 	Epsilon: 0.6663714021175996
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2142000000000000
# 	Step-size adapted to: 0.0038632160107673
# Iteration:  208
# 	Trajectories constructed.
# 	Epsilon: 0.6603639671779206
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2028000000000000
# 	Step-size adapted to: 0.0038110319291044
# Iteration:  209
# 	Trajectories constructed.
# 	Epsilon: 0.6539568500498951
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2118000000000000
# 	Step-size adapted to: 0.0037765088567663
# Iteration:  210
# 	Trajectories constructed.
# 	Epsilon: 0.6475109846308668
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2298000000000000
# 	Step-size adapted to: 0.0037761312247625
# Iteration:  211
# 	Trajectories constructed.
# 	Epsilon: 0.6415160506303557
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1972000000000000
# 	Step-size adapted to: 0.0037147077220976
# Iteration:  212
# 	Trajectories constructed.
# 	Epsilon: 0.6362078019938996
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2152000000000000
# 	Step-size adapted to: 0.0036873203432335
# Iteration:  213
# 	Trajectories constructed.
# 	Epsilon: 0.6310813966423430
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2092000000000000
# 	Step-size adapted to: 0.0036491709324526
# Iteration:  214
# 	Trajectories constructed.
# 	Epsilon: 0.6255528286263792
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# ...
# Iteration:  415
# 	Trajectories constructed.
# 	Epsilon: 0.1167611220925776
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0708000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  416
# 	Trajectories constructed.
# 	Epsilon: 0.1157607521644063
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1156000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  417
# 	Trajectories constructed.
# 	Epsilon: 0.1147005298304497
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0708000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  418
# 	Trajectories constructed.
# 	Epsilon: 0.1137136577526223
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0934000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  419
# 	Trajectories constructed.
# 	Epsilon: 0.1126438900518666
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0694000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  420
# 	Trajectories constructed.
# 	Epsilon: 0.1117872339857927
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0756000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  421
# 	Trajectories constructed.
# 	Epsilon: 0.1106724889926937
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0478000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  422
# 	Trajectories constructed.
# 	Epsilon: 0.1096824375560265
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0450000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  423
# 	Trajectories constructed.
# 	Epsilon: 0.1088484327038540
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0432000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  424
# 	Trajectories constructed.
# 	Epsilon: 0.1080104895923001
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0856000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  425
# 	Trajectories constructed.
# 	Epsilon: 0.1071828767956507
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0532000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  426
# 	Trajectories constructed.
# 	Epsilon: 0.1060967051733576
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1134000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  427
# 	Trajectories constructed.
# 	Epsilon: 0.1050902288867065
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0604000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  428
# 	Trajectories constructed.
# 	Epsilon: 0.1038450037227801
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0388000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  429
# 	Trajectories constructed.
# 	Epsilon: 0.1028816597536649
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0652000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  430
# 	Trajectories constructed.
# 	Epsilon: 0.1019829981691584
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0510000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  431
# 	Trajectories constructed.
# 	Epsilon: 0.1007784542496234
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0524000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  432
# 	Trajectories constructed.
# 	Epsilon: 0.0998278618849704
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0602000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  433
# 	Trajectories constructed.
# 	Epsilon: 0.0987957989131272
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0282000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  434
# 	Trajectories constructed.
# 	Epsilon: 0.0976936854818258
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0672000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  435
# 	Trajectories constructed.
# 	Epsilon: 0.0968329658514377
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0688000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  436
# 	Trajectories constructed.
# 	Epsilon: 0.0956965052443821
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0616000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  437
# 	Trajectories constructed.
# 	Epsilon: 0.0946396446787597
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0390000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  438
# 	Trajectories constructed.
# 	Epsilon: 0.0934959500435136
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0704000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  439
# 	Trajectories constructed.
# 	Epsilon: 0.0925824725899948
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0448000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  440
# 	Trajectories constructed.
# 	Epsilon: 0.0916980828359455
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0280000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  441
# 	Trajectories constructed.
# 	Epsilon: 0.0907474087273652
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0390000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  442
# 	Trajectories constructed.
# 	Epsilon: 0.0896041154049324
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0468000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  443
# 	Trajectories constructed.
# 	Epsilon: 0.0888833515265198
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0216000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  444
# 	Trajectories constructed.
# 	Epsilon: 0.0880342964640958
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0548000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  445
# 	Trajectories constructed.
# 	Epsilon: 0.0872504439718392
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0376000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  446
# 	Trajectories constructed.
# 	Epsilon: 0.0862368567169852
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0270000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  447
# 	Trajectories constructed.
# 	Epsilon: 0.0853697256287046
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0484000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  448
# 	Trajectories constructed.
# 	Epsilon: 0.0838938348744620
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0302000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  449
# 	Trajectories constructed.
# 	Epsilon: 0.0830593111773525
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0716000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  450
# 	Trajectories constructed.
# 	Epsilon: 0.0820808596339668
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0184000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  451
# 	Trajectories constructed.
# 	Epsilon: 0.0811775708850398
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0264000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  452
# 	Trajectories constructed.
# 	Epsilon: 0.0802506061595108
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0178000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  453
# 	Trajectories constructed.
# 	Epsilon: 0.0795986126594262
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0140000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  454
# 	Trajectories constructed.
# 	Epsilon: 0.0788518583187028
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0132000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  455
# 	Trajectories constructed.
# 	Epsilon: 0.0779294786964452
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0394000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  456
# 	Trajectories constructed.
# 	Epsilon: 0.0771159858007045
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0230000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  457
# 	Trajectories constructed.
# 	Epsilon: 0.0763466739755753
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0216000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  458
# 	Trajectories constructed.
# 	Epsilon: 0.0753968501335447
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0390000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  459
# 	Trajectories constructed.
# 	Epsilon: 0.0741645076662477
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0262000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  460
# 	Trajectories constructed.
# 	Epsilon: 0.0731786126341447
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0188000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  461
# 	Trajectories constructed.
# 	Epsilon: 0.0718898574518101
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1158000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  462
# 	Trajectories constructed.
# 	Epsilon: 0.0711020704444271
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0196000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  463
# 	Trajectories constructed.
# 	Epsilon: 0.0702973160470240
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0202000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  464
# 	Trajectories constructed.
# 	Epsilon: 0.0694884560756110
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0090000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  465
# 	Trajectories constructed.
# 	Epsilon: 0.0684905107838115
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0036000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  466
# 	Trajectories constructed.
# 	Epsilon: 0.0677064991187955
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0124000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  467
# 	Trajectories constructed.
# 	Epsilon: 0.0667570715385890
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0102000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  468
# 	Trajectories constructed.
# 	Epsilon: 0.0659719527324309
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0022000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  469
# 	Trajectories constructed.
# 	Epsilon: 0.0653770671281089
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0268000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  470
# 	Trajectories constructed.
# 	Epsilon: 0.0644223907767481
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0102000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  471
# 	Trajectories constructed.
# 	Epsilon: 0.0639990930064121
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0026000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  472
# 	Trajectories constructed.
# 	Epsilon: 0.0634969992318934
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0072000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  473
# 	Trajectories constructed.
# 	Epsilon: 0.0629764809027522
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0040000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  474
# 	Trajectories constructed.
# 	Epsilon: 0.0622069447047148
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0030000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  475
# 	Trajectories constructed.
# 	Epsilon: 0.0609093674345509
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0350000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  476
# 	Trajectories constructed.
# 	Epsilon: 0.0603171167042332
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0086000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  477
# 	Trajectories constructed.
# 	Epsilon: 0.0596634844505373
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0026000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  478
# 	Trajectories constructed.
# 	Epsilon: 0.0588303407747858
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0010000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  479
# 	Trajectories constructed.
# 	Epsilon: 0.0584210278209457
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0010000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  480
# 	Trajectories constructed.
# 	Epsilon: 0.0576902950387942
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0528000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  481
# 	Trajectories constructed.
# 	Epsilon: 0.0572907799217241
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0126000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  482
# 	Trajectories constructed.
# 	Epsilon: 0.0565422816100553
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0028000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  483
# 	Trajectories constructed.
# 	Epsilon: 0.0557776516413386
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0190000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  484
# 	Trajectories constructed.
# 	Epsilon: 0.0548482683662201
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0010000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  485
# 	Trajectories constructed.
# 	Epsilon: 0.0540901387507972
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0000000000000000
# 	Step-size adapted to: 0.0010000000000000

# %%
SMC_RT_MAN = SMCAdaptive(SETTING_MANUAL_RT)
_ = SMC_RT_MAN.sample()
# Out:
# Stochastic Kernel: RWM.
# Iteration:  1
# 	Particles resampled.
# 	Epsilon: 9.7079374936302525
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0390000000000000
# 	Step-size adapted to: 0.0010000000000000
#
#
# ####################################
# ### SWITCHING TO THUG KERNEL ###
# ####################################
#
#
# Iteration:  2
# 	Particles resampled.
# 	Epsilon: 9.5011376707167550
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4664000000000000
# 	Step-size adapted to: 0.0011254691826960
# Iteration:  3
# 	Particles resampled.
# 	Epsilon: 9.3331017746231879
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4874000000000001
# 	Step-size adapted to: 0.0012800511012677
# Iteration:  4
# 	Particles resampled.
# 	Epsilon: 9.1955215786319311
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4946000000000000
# 	Step-size adapted to: 0.0014611152295690
# Iteration:  5
# 	Particles resampled.
# 	Epsilon: 9.0230448626778923
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.5087999999999999
# 	Step-size adapted to: 0.0016796744586074
# Iteration:  6
# 	Particles resampled.
# 	Epsilon: 8.8797403396535426
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4908000000000000
# 	Step-size adapted to: 0.0019136262456361
# Iteration:  7
# 	Particles resampled.
# 	Epsilon: 8.6951602871257574
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4878000000000000
# 	Step-size adapted to: 0.0021768959805217
# Iteration:  8
# 	Particles resampled.
# 	Epsilon: 8.4545242833480181
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4874000000000001
# 	Step-size adapted to: 0.0024758901798954
# Iteration:  9
# 	Particles resampled.
# 	Epsilon: 7.8983731197243525
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4848000000000000
# 	Step-size adapted to: 0.0028122925364725
# Iteration:  10
# 	Particles resampled.
# 	Epsilon: 3.2701482345400654
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4602000000000001
# 	Step-size adapted to: 0.0031553518147555
# Iteration:  11
# 	Particles resampled.
# 	Epsilon: 3.2700754198620334
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4044000000000000
# 	Step-size adapted to: 0.0034428513194713
# Iteration:  12
# 	Particles resampled.
# 	Epsilon: 3.2700227005168783
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4046000000000000
# 	Step-size adapted to: 0.0037569219807246
# Iteration:  13
# 	Particles resampled.
# 	Epsilon: 3.2699576395514702
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4004000000000000
# 	Step-size adapted to: 0.0040910432054949
# Iteration:  14
# 	Particles resampled.
# 	Epsilon: 3.2698777196543123
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4070000000000000
# 	Step-size adapted to: 0.0044696048309126
# Iteration:  15
# 	Particles resampled.
# 	Epsilon: 3.2697788235624006
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4078000000000001
# 	Step-size adapted to: 0.0048851500426624
# Iteration:  16
# 	Particles resampled.
# 	Epsilon: 3.2696590284426716
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4238000000000000
# 	Step-size adapted to: 0.0053822150027904
# Iteration:  17
# 	Particles resampled.
# 	Epsilon: 3.2694967962101904
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4399999999999999
# 	Step-size adapted to: 0.0059780833108150
# Iteration:  18
# 	Particles resampled.
# 	Epsilon: 3.2693128367282407
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4440000000000000
# 	Step-size adapted to: 0.0066532136927372
# Iteration:  19
# 	Particles resampled.
# 	Epsilon: 3.2690837927955592
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4512000000000000
# 	Step-size adapted to: 0.0074312939823032
# Iteration:  20
# 	Particles resampled.
# 	Epsilon: 3.2688089395864925
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4464000000000000
# 	Step-size adapted to: 0.0082804722351375
# Iteration:  21
# 	Particles resampled.
# 	Epsilon: 3.2684796969945427
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4554000000000000
# 	Step-size adapted to: 0.0092683002271707
# Iteration:  22
# 	Particles resampled.
# 	Epsilon: 3.2681276335761043
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4392000000000000
# 	Step-size adapted to: 0.0102902824659619
# Iteration:  23
# 	Particles resampled.
# 	Epsilon: 3.2677754053294263
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4198000000000000
# 	Step-size adapted to: 0.0113146687119975
# Iteration:  24
# 	Particles resampled.
# 	Epsilon: 3.2674077766042595
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4050000000000000
# 	Step-size adapted to: 0.0123493076404443
# Iteration:  25
# 	Particles resampled.
# 	Epsilon: 3.2670181567903152
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3944000000000000
# 	Step-size adapted to: 0.0134073089193483
# Iteration:  26
# 	Particles resampled.
# 	Epsilon: 3.2666308414108340
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3698000000000000
# 	Step-size adapted to: 0.0143780106316481
# Iteration:  27
# 	Particles resampled.
# 	Epsilon: 3.2662287240950469
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3530000000000000
# 	Step-size adapted to: 0.0152900149851099
# Iteration:  28
# 	Particles resampled.
# 	Epsilon: 3.2657973432922294
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3474000000000000
# 	Step-size adapted to: 0.0162144042757467
# Iteration:  29
# 	Particles resampled.
# 	Epsilon: 3.2653398480137703
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3442000000000000
# 	Step-size adapted to: 0.0171671899317810
# Iteration:  30
# 	Particles resampled.
# 	Epsilon: 3.2648666706940928
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3416000000000000
# 	Step-size adapted to: 0.0181523494751518
# Iteration:  31
# 	Particles resampled.
# 	Epsilon: 3.2643696352860174
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3314000000000000
# 	Step-size adapted to: 0.0190964031392137
# Iteration:  32
# 	Particles resampled.
# 	Epsilon: 3.2639064457958060
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3300000000000000
# 	Step-size adapted to: 0.0200754966649998
# Iteration:  33
# 	Particles resampled.
# 	Epsilon: 3.2633606093110781
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3274000000000000
# 	Step-size adapted to: 0.0210773709889231
# Iteration:  34
# 	Particles resampled.
# 	Epsilon: 3.2628054577794616
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3256000000000000
# 	Step-size adapted to: 0.0221093368233845
# Iteration:  35
# 	Particles resampled.
# 	Epsilon: 3.2621530221678690
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3388000000000000
# 	Step-size adapted to: 0.0233454008739092
# Iteration:  36
# 	Particles resampled.
# 	Epsilon: 3.2614629956935621
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3416000000000000
# 	Step-size adapted to: 0.0246851043755389
# Iteration:  37
# 	Particles resampled.
# 	Epsilon: 3.2607136018110481
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3582000000000000
# 	Step-size adapted to: 0.0263192339291975
# Iteration:  38
# 	Particles resampled.
# 	Epsilon: 3.2599064286506705
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3364000000000000
# 	Step-size adapted to: 0.0277573314029480
# Iteration:  39
# 	Particles resampled.
# 	Epsilon: 3.2590067181491706
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3506000000000000
# 	Step-size adapted to: 0.0294825923693482
# Iteration:  40
# 	Particles resampled.
# 	Epsilon: 3.2579932123294477
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3546000000000000
# 	Step-size adapted to: 0.0313777800281020
# Iteration:  41
# 	Particles resampled.
# 	Epsilon: 3.2569140677015151
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3468000000000000
# 	Step-size adapted to: 0.0332648072899647
# Iteration:  42
# 	Particles resampled.
# 	Epsilon: 3.2557015541867114
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3718000000000000
# 	Step-size adapted to: 0.0357089015199325
# Iteration:  43
# 	Particles resampled.
# 	Epsilon: 3.2544530994351435
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3622000000000000
# 	Step-size adapted to: 0.0381490173552381
# Iteration:  44
# 	Particles resampled.
# 	Epsilon: 3.2530517289447602
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3564000000000001
# 	Step-size adapted to: 0.0406378541317529
# Iteration:  45
# 	Particles resampled.
# 	Epsilon: 3.2514677556448817
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3520000000000000
# 	Step-size adapted to: 0.0431939310315377
# Iteration:  46
# 	Particles resampled.
# 	Epsilon: 3.2497021293148696
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3683999999999999
# 	Step-size adapted to: 0.0462887985566430
# Iteration:  47
# 	Particles resampled.
# 	Epsilon: 3.2476376283462733
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3614000000000001
# 	Step-size adapted to: 0.0494320994692130
# Iteration:  48
# 	Particles resampled.
# 	Epsilon: 3.2452205420816562
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3586000000000000
# 	Step-size adapted to: 0.0527149976263008
# Iteration:  49
# 	Particles resampled.
# 	Epsilon: 3.2427787984658289
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3744000000000000
# 	Step-size adapted to: 0.0566617851352823
# Iteration:  50
# 	Particles resampled.
# 	Epsilon: 3.2399204283914149
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3716000000000000
# 	Step-size adapted to: 0.0608188637562163
# Iteration:  51
# 	Particles resampled.
# 	Epsilon: 3.2366604407862170
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3624000000000001
# 	Step-size adapted to: 0.0649813301385564
# Iteration:  52
# 	Particles resampled.
# 	Epsilon: 3.2333333364759751
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3652000000000000
# 	Step-size adapted to: 0.0695259455380845
# Iteration:  53
# 	Particles resampled.
# 	Epsilon: 3.2295998105089652
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3772000000000000
# 	Step-size adapted to: 0.0748360708979257
# Iteration:  54
# 	Particles resampled.
# 	Epsilon: 3.2249586760334070
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3750000000000000
# 	Step-size adapted to: 0.0804632050655025
# Iteration:  55
# 	Particles resampled.
# 	Epsilon: 3.2196753438587384
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3670000000000000
# 	Step-size adapted to: 0.0861680965902055
# Iteration:  56
# 	Particles resampled.
# 	Epsilon: 3.2139376344547625
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3704000000000000
# 	Step-size adapted to: 0.0924344736022531
# Iteration:  57
# 	Particles resampled.
# 	Epsilon: 3.2073278143157848
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3702000000000000
# 	Step-size adapted to: 0.0991466433369604
# Iteration:  58
# 	Particles resampled.
# 	Epsilon: 3.2008053009432995
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3842000000000000
# 	Step-size adapted to: 0.1070932553270915
# Iteration:  59
# 	Particles resampled.
# 	Epsilon: 3.1930232450253504
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3688000000000000
# 	Step-size adapted to: 0.1147894981303315
# Iteration:  60
# 	Particles resampled.
# 	Epsilon: 3.1835676249843994
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3702000000000000
# 	Step-size adapted to: 0.1231249877500167
# Iteration:  61
# 	Particles resampled.
# 	Epsilon: 3.1737949347776211
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3818000000000000
# 	Step-size adapted to: 0.1328339696646836
# Iteration:  62
# 	Particles resampled.
# 	Epsilon: 3.1625849820046339
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3726000000000000
# 	Step-size adapted to: 0.1426508448243723
# Iteration:  63
# 	Particles resampled.
# 	Epsilon: 3.1504440614888147
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3794000000000000
# 	Step-size adapted to: 0.1537149633396269
# Iteration:  64
# 	Particles resampled.
# 	Epsilon: 3.1380277454070091
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3632000000000000
# 	Step-size adapted to: 0.1643009816883309
# Iteration:  65
# 	Particles resampled.
# 	Epsilon: 3.1251747642816223
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3416000000000000
# 	Step-size adapted to: 0.1737295882767514
# Iteration:  66
# 	Particles resampled.
# 	Epsilon: 3.1130317757617956
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3578000000000000
# 	Step-size adapted to: 0.1851932732484885
# Iteration:  67
# 	Particles resampled.
# 	Epsilon: 3.1018247309191920
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3640000000000000
# 	Step-size adapted to: 0.1980263296729619
# Iteration:  68
# 	Particles resampled.
# 	Epsilon: 3.0896298718167872
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3578000000000000
# 	Step-size adapted to: 0.2110932544380394
# Iteration:  69
# 	Particles resampled.
# 	Epsilon: 3.0772722030455157
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3544000000000000
# 	Step-size adapted to: 0.2246401974951623
# Iteration:  70
# 	Particles resampled.
# 	Epsilon: 3.0633736135325997
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3614000000000001
# 	Step-size adapted to: 0.2398946815129835
# Iteration:  71
# 	Particles resampled.
# 	Epsilon: 3.0477325467916234
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3520000000000000
# 	Step-size adapted to: 0.2549837964994332
# Iteration:  72
# 	Particles resampled.
# 	Epsilon: 3.0312360579139566
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3592000000000000
# 	Step-size adapted to: 0.2719994379680687
# Iteration:  73
# 	Particles resampled.
# 	Epsilon: 3.0157044075346167
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3490000000000000
# 	Step-size adapted to: 0.2886745704987074
# Iteration:  74
# 	Particles resampled.
# 	Epsilon: 2.9995804625588769
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3406000000000000
# 	Step-size adapted to: 0.3050879208045463
# Iteration:  75
# 	Particles resampled.
# 	Epsilon: 2.9825317512980951
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3304000000000000
# 	Step-size adapted to: 0.3207942654329060
# Iteration:  76
# 	Particles resampled.
# 	Epsilon: 2.9652626675682052
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3136000000000000
# 	Step-size adapted to: 0.3344876640118828
# Iteration:  77
# 	Particles resampled.
# 	Epsilon: 2.9467076626913213
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3260000000000000
# 	Step-size adapted to: 0.3509346416492984
# Iteration:  78
# 	Particles resampled.
# 	Epsilon: 2.9278587721402838
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3210000000000000
# 	Step-size adapted to: 0.3672710017719094
# Iteration:  79
# 	Particles resampled.
# 	Epsilon: 2.9060542537577456
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3272000000000000
# 	Step-size adapted to: 0.3855612249585416
# Iteration:  80
# 	Particles resampled.
# 	Epsilon: 2.8803955114444166
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3182000000000000
# 	Step-size adapted to: 0.4029449692931215
# Iteration:  81
# 	Particles resampled.
# 	Epsilon: 2.8545632464331616
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3044000000000000
# 	Step-size adapted to: 0.4182168174170223
# Iteration:  82
# 	Particles resampled.
# 	Epsilon: 2.8280308520756652
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2940000000000000
# 	Step-size adapted to: 0.4318161849960701
# Iteration:  83
# 	Particles resampled.
# 	Epsilon: 2.8042364582250840
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2864000000000000
# 	Step-size adapted to: 0.4441667255756551
# Iteration:  84
# 	Particles resampled.
# 	Epsilon: 2.7822545688598597
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2608000000000000
# 	Step-size adapted to: 0.4510598338529976
# Iteration:  85
# 	Particles resampled.
# 	Epsilon: 2.7636682726539390
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2634000000000000
# 	Step-size adapted to: 0.4586557827159876
# Iteration:  86
# 	Particles resampled.
# 	Epsilon: 2.7454124104130946
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2446000000000000
# 	Step-size adapted to: 0.4620162206049778
# Iteration:  87
# 	Particles resampled.
# 	Epsilon: 2.7297280239051931
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2478000000000000
# 	Step-size adapted to: 0.4661465175262964
# Iteration:  88
# 	Particles resampled.
# 	Epsilon: 2.7154483389130091
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2360000000000000
# 	Step-size adapted to: 0.4675470568374376
# Iteration:  89
# 	Particles resampled.
# 	Epsilon: 2.7020896878386802
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2312000000000000
# 	Step-size adapted to: 0.4678276692468445
# Iteration:  90
# 	Particles resampled.
# 	Epsilon: 2.6895850608754341
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2194000000000000
# 	Step-size adapted to: 0.4653547416466854
# Iteration:  91
# 	Particles resampled.
# 	Epsilon: 2.6789882258111448
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2086000000000000
# 	Step-size adapted to: 0.4604019903836075
# Iteration:  92
# 	Particles resampled.
# 	Epsilon: 2.6685220158300944
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2116000000000000
# 	Step-size adapted to: 0.4561857166699033
# Iteration:  93
# 	Particles resampled.
# 	Epsilon: 2.6582366733615697
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2086000000000000
# 	Step-size adapted to: 0.4513305509603200
# Iteration:  94
# 	Particles resampled.
# 	Epsilon: 2.6484620210210759
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2174000000000000
# 	Step-size adapted to: 0.4484961063646656
# Iteration:  95
# 	Particles resampled.
# 	Epsilon: 2.6391062072188678
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2104000000000000
# 	Step-size adapted to: 0.4441223111238571
# Iteration:  96
# 	Particles resampled.
# 	Epsilon: 2.6304248638247771
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2128000000000000
# 	Step-size adapted to: 0.4403192359111976
# Iteration:  97
# 	Particles resampled.
# 	Epsilon: 2.6229900329037243
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1952000000000000
# 	Step-size adapted to: 0.4327239518061081
# Iteration:  98
# 	Particles resampled.
# 	Epsilon: 2.6168578155490740
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1919999999999999
# 	Step-size adapted to: 0.4245798110603039
# Iteration:  99
# 	Particles resampled.
# 	Epsilon: 2.6117434413548675
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1916000000000000
# 	Step-size adapted to: 0.4165056387788961
# Iteration:  100
# 	Particles resampled.
# 	Epsilon: 2.6071356235141687
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2042000000000000
# 	Step-size adapted to: 0.4111672228516566
# Iteration:  101
# 	Particles resampled.
# 	Epsilon: 2.6022410688698194
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2131999999999999
# 	Step-size adapted to: 0.4077278836277340
# Iteration:  102
# 	Particles resampled.
# 	Epsilon: 2.5977743100995765
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1879999999999999
# 	Step-size adapted to: 0.3992548760320468
# Iteration:  103
# 	Particles resampled.
# 	Epsilon: 2.5938061141105782
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2136000000000000
# 	Step-size adapted to: 0.3959943723832125
# Iteration:  104
# 	Particles resampled.
# 	Epsilon: 2.5896634580216498
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2042000000000000
# 	Step-size adapted to: 0.3909188524675026
# Iteration:  105
# 	Particles resampled.
# 	Epsilon: 2.5854290549996879
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2180000000000000
# 	Step-size adapted to: 0.3885803618400476
# Iteration:  106
# 	Particles resampled.
# 	Epsilon: 2.5814085010210239
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2260000000000000
# 	Step-size adapted to: 0.3878039777592430
# Iteration:  107
# 	Particles resampled.
# 	Epsilon: 2.5770996316318113
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2312000000000000
# 	Step-size adapted to: 0.3880367299645776
# Iteration:  108
# 	Particles resampled.
# 	Epsilon: 2.5732083415784563
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2204000000000000
# 	Step-size adapted to: 0.3861786167001583
# Iteration:  109
# 	Particles resampled.
# 	Epsilon: 2.5695164966998081
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2120000000000000
# 	Step-size adapted to: 0.3827186025685131
# Iteration:  110
# 	Particles resampled.
# 	Epsilon: 2.5662786280997327
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2130000000000000
# 	Step-size adapted to: 0.3794792810664559
# Iteration:  111
# 	Particles resampled.
# 	Epsilon: 2.5632253519479753
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2094000000000000
# 	Step-size adapted to: 0.3755907050163216
# Iteration:  112
# 	Particles resampled.
# 	Epsilon: 2.5601375396465844
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2181999999999999
# 	Step-size adapted to: 0.3733812441754797
# Iteration:  113
# 	Particles resampled.
# 	Epsilon: 2.5566722754339763
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2006000000000000
# 	Step-size adapted to: 0.3679326849112696
# Iteration:  114
# 	Particles resampled.
# 	Epsilon: 2.5535165986009871
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2030000000000000
# 	Step-size adapted to: 0.3629989711633161
# Iteration:  115
# 	Particles resampled.
# 	Epsilon: 2.5502620956673847
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2070000000000000
# 	Step-size adapted to: 0.3588483945531585
# Iteration:  116
# 	Particles resampled.
# 	Epsilon: 2.5474170116819908
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1978000000000000
# 	Step-size adapted to: 0.3531171953525614
# Iteration:  117
# 	Particles resampled.
# 	Epsilon: 2.5448052714223133
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2154000000000000
# 	Step-size adapted to: 0.3505488257811145
# Iteration:  118
# 	Particles resampled.
# 	Epsilon: 2.5423697982900428
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2044000000000000
# 	Step-size adapted to: 0.3460903956363097
# Iteration:  119
# 	Particles resampled.
# 	Epsilon: 2.5399317955456064
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2108000000000000
# 	Step-size adapted to: 0.3427838247727714
# Iteration:  120
# 	Particles resampled.
# 	Epsilon: 2.5374805194347521
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2131999999999999
# 	Step-size adapted to: 0.3399165002674507
# Iteration:  121
# 	Particles resampled.
# 	Epsilon: 2.5349909010963225
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2176000000000000
# 	Step-size adapted to: 0.3378155376798931
# Iteration:  122
# 	Particles resampled.
# 	Epsilon: 2.5327860884468842
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2134000000000000
# 	Step-size adapted to: 0.3350232726469465
# Iteration:  123
# 	Particles resampled.
# 	Epsilon: 2.5306267381609988
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2134000000000000
# 	Step-size adapted to: 0.3322540874997499
# Iteration:  124
# 	Particles resampled.
# 	Epsilon: 2.5286310547471387
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2212000000000000
# 	Step-size adapted to: 0.3307953810223802
# Iteration:  125
# 	Particles resampled.
# 	Epsilon: 2.5266437529482673
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2228000000000000
# 	Step-size adapted to: 0.3296066586348171
# Iteration:  126
# 	Particles resampled.
# 	Epsilon: 2.5246482321835408
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2252000000000000
# 	Step-size adapted to: 0.3288165511623122
# Iteration:  127
# 	Particles resampled.
# 	Epsilon: 2.5223663192668817
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2334000000000001
# 	Step-size adapted to: 0.3293760147085650
# Iteration:  128
# 	Particles resampled.
# 	Epsilon: 2.5196105627920806
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2368000000000000
# 	Step-size adapted to: 0.3304977991114069
# Iteration:  129
# 	Particles resampled.
# 	Epsilon: 2.5174468921189392
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2304000000000000
# 	Step-size adapted to: 0.3305639052816258
# Iteration:  130
# 	Particles resampled.
# 	Epsilon: 2.5153262444240401
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2272000000000000
# 	Step-size adapted to: 0.3301014396157337
# Iteration:  131
# 	Particles resampled.
# 	Epsilon: 2.5131549357116678
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2140000000000000
# 	Step-size adapted to: 0.3274711632324666
# Iteration:  132
# 	Particles resampled.
# 	Epsilon: 2.5113413900461645
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2020000000000000
# 	Step-size adapted to: 0.3229185098804381
# Iteration:  133
# 	Particles resampled.
# 	Epsilon: 2.5098732553220384
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2020000000000000
# 	Step-size adapted to: 0.3184291495901228
# Iteration:  134
# 	Particles resampled.
# 	Epsilon: 2.5084630755728896
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2012000000000000
# 	Step-size adapted to: 0.3138766266683857
# Iteration:  135
# 	Particles resampled.
# 	Epsilon: 2.5070862355256676
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2046000000000000
# 	Step-size adapted to: 0.3099155992730237
# Iteration:  136
# 	Particles resampled.
# 	Epsilon: 2.5056409039482586
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2290000000000000
# 	Step-size adapted to: 0.3097606802063814
# Iteration:  137
# 	Particles resampled.
# 	Epsilon: 2.5041511618861398
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2240000000000000
# 	Step-size adapted to: 0.3088327906959448
# Iteration:  138
# 	Particles resampled.
# 	Epsilon: 2.5025884213366876
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2286000000000000
# 	Step-size adapted to: 0.3086166833888396
# Iteration:  139
# 	Particles resampled.
# 	Epsilon: 2.5012392158143943
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2161999999999999
# 	Step-size adapted to: 0.3064945580254858
# Iteration:  140
# 	Particles resampled.
# 	Epsilon: 2.5001026900161971
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2272000000000000
# 	Step-size adapted to: 0.3060657658687959
# Iteration:  141
# 	Particles resampled.
# 	Epsilon: 2.4990941139930500
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2076000000000000
# 	Step-size adapted to: 0.3026569542693914
# Iteration:  142
# 	Particles resampled.
# 	Epsilon: 2.4980059933357257
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2354000000000001
# 	Step-size adapted to: 0.3034752322240537
# Iteration:  143
# 	Particles resampled.
# 	Epsilon: 2.4968404556162285
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2198000000000000
# 	Step-size adapted to: 0.3019314485342697
# Iteration:  144
# 	Particles resampled.
# 	Epsilon: 2.4957864307092565
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2294000000000000
# 	Step-size adapted to: 0.3018408826852660
# Iteration:  145
# 	Particles resampled.
# 	Epsilon: 2.4947499707468341
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2362000000000000
# 	Step-size adapted to: 0.3027780412668841
# Iteration:  146
# 	Particles resampled.
# 	Epsilon: 2.4936874250848842
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2108000000000000
# 	Step-size adapted to: 0.2998852795433707
# Iteration:  147
# 	Particles resampled.
# 	Epsilon: 2.4927278669991644
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2181999999999999
# 	Step-size adapted to: 0.2981211656474552
# Iteration:  148
# 	Particles resampled.
# 	Epsilon: 2.4917947266229619
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2258000000000000
# 	Step-size adapted to: 0.2974957680968573
# Iteration:  149
# 	Particles resampled.
# 	Epsilon: 2.4907728594176382
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2158000000000000
# 	Step-size adapted to: 0.2953910288094913
# Iteration:  150
# 	Particles resampled.
# 	Epsilon: 2.4897051619502175
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2200000000000000
# 	Step-size adapted to: 0.2939177599070089
# Iteration:  151
# 	Particles resampled.
# 	Epsilon: 2.4887594315856032
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2324000000000001
# 	Step-size adapted to: 0.2942706729243582
# Iteration:  152
# 	Particles resampled.
# 	Epsilon: 2.4878807206684077
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2186000000000000
# 	Step-size adapted to: 0.2925981014458878
# Iteration:  153
# 	Particles resampled.
# 	Epsilon: 2.4869883734436482
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2140000000000000
# 	Step-size adapted to: 0.2902666548550526
# Iteration:  154
# 	Particles resampled.
# 	Epsilon: 2.4860657008914835
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2423999999999999
# 	Step-size adapted to: 0.2920718985879321
# Iteration:  155
# 	Particles resampled.
# 	Epsilon: 2.4849472383368507
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2348000000000000
# 	Step-size adapted to: 0.2927737129849487
# Iteration:  156
# 	Particles resampled.
# 	Epsilon: 2.4836922485922885
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2413999999999999
# 	Step-size adapted to: 0.2944472883074292
# Iteration:  157
# 	Particles resampled.
# 	Epsilon: 2.4825474405956194
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2288000000000000
# 	Step-size adapted to: 0.2942706729243582
# Iteration:  158
# 	Particles resampled.
# 	Epsilon: 2.4814556804528340
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2342000000000000
# 	Step-size adapted to: 0.2948892906587784
# Iteration:  159
# 	Particles resampled.
# 	Epsilon: 2.4805905824542043
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2060000000000000
# 	Step-size adapted to: 0.2913717665258589
# Iteration:  160
# 	Particles resampled.
# 	Epsilon: 2.4797456705517926
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2068000000000000
# 	Step-size adapted to: 0.2880113819457515
# Iteration:  161
# 	Particles resampled.
# 	Epsilon: 2.4790074688841881
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2292000000000000
# 	Step-size adapted to: 0.2878962004308119
# Iteration:  162
# 	Particles resampled.
# 	Epsilon: 2.4782522087337191
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2030000000000000
# 	Step-size adapted to: 0.2840357186081883
# Iteration:  163
# 	Particles resampled.
# 	Epsilon: 2.4775046546339254
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2140000000000000
# 	Step-size adapted to: 0.2817724978130015
# Iteration:  164
# 	Particles resampled.
# 	Epsilon: 2.4767090263400338
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2328000000000000
# 	Step-size adapted to: 0.2821672555758967
# Iteration:  165
# 	Particles resampled.
# 	Epsilon: 2.4759430139344976
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2256000000000000
# 	Step-size adapted to: 0.2815471699579107
# Iteration:  166
# 	Particles resampled.
# 	Epsilon: 2.4751980014981747
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2178000000000000
# 	Step-size adapted to: 0.2798349597715111
# Iteration:  167
# 	Particles resampled.
# 	Epsilon: 2.4744658328942779
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2214000000000000
# 	Step-size adapted to: 0.2786342528145398
# Iteration:  168
# 	Particles resampled.
# 	Epsilon: 2.4737190545844046
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2232000000000000
# 	Step-size adapted to: 0.2776885050372619
# Iteration:  169
# 	Particles resampled.
# 	Epsilon: 2.4729286016043219
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2310000000000000
# 	Step-size adapted to: 0.2778273840066295
# Iteration:  170
# 	Particles resampled.
# 	Epsilon: 2.4720912436138578
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2260000000000000
# 	Step-size adapted to: 0.2772722845231330
# Iteration:  171
# 	Particles resampled.
# 	Epsilon: 2.4711310213747542
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2272000000000000
# 	Step-size adapted to: 0.2768843749248779
# Iteration:  172
# 	Particles resampled.
# 	Epsilon: 2.4701817146791898
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2254000000000000
# 	Step-size adapted to: 0.2762482726605697
# Iteration:  173
# 	Particles resampled.
# 	Epsilon: 2.4692726609035929
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2112000000000001
# 	Step-size adapted to: 0.2736637053947121
# Iteration:  174
# 	Particles resampled.
# 	Epsilon: 2.4685060898144044
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2130000000000000
# 	Step-size adapted to: 0.2713474220490155
# Iteration:  175
# 	Particles resampled.
# 	Epsilon: 2.4678788746517171
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2010000000000000
# 	Step-size adapted to: 0.2674412724526347
# Iteration:  176
# 	Particles resampled.
# 	Epsilon: 2.4672269626444705
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2066000000000000
# 	Step-size adapted to: 0.2643304434015890
# Iteration:  177
# 	Particles resampled.
# 	Epsilon: 2.4665632997951263
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2038000000000000
# 	Step-size adapted to: 0.2608902967504165
# Iteration:  178
# 	Particles resampled.
# 	Epsilon: 2.4659407322910716
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2036000000000000
# 	Step-size adapted to: 0.2574691739185605
# Iteration:  179
# 	Particles resampled.
# 	Epsilon: 2.4653054939184242
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2146000000000000
# 	Step-size adapted to: 0.2554942744001731
# Iteration:  180
# 	Particles resampled.
# 	Epsilon: 2.4647091527247436
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2228000000000000
# 	Step-size adapted to: 0.2545761486302938
# Iteration:  181
# 	Particles resampled.
# 	Epsilon: 2.4641573282114608
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2098000000000000
# 	Step-size adapted to: 0.2520178705807365
# Iteration:  182
# 	Particles resampled.
# 	Epsilon: 2.4635977080398801
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2034000000000000
# 	Step-size adapted to: 0.2486882241325120
# Iteration:  183
# 	Particles resampled.
# 	Epsilon: 2.4630674948778308
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2130000000000000
# 	Step-size adapted to: 0.2465833326892050
# Iteration:  184
# 	Particles resampled.
# 	Epsilon: 2.4625887861657034
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2151999999999999
# 	Step-size adapted to: 0.2447653508561368
# Iteration:  185
# 	Particles resampled.
# 	Epsilon: 2.4621292309856528
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2098000000000000
# 	Step-size adapted to: 0.2423056631447918
# Iteration:  186
# 	Particles resampled.
# 	Epsilon: 2.4616634177406702
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2102000000000001
# 	Step-size adapted to: 0.2399186721806477
# Iteration:  187
# 	Particles resampled.
# 	Epsilon: 2.4612042575813113
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2204000000000000
# 	Step-size adapted to: 0.2387698220004047
# Iteration:  188
# 	Particles resampled.
# 	Epsilon: 2.4606339249547826
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2272000000000000
# 	Step-size adapted to: 0.2384357781348705
# Iteration:  189
# 	Particles resampled.
# 	Epsilon: 2.4600403924481142
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2181999999999999
# 	Step-size adapted to: 0.2370331488690005
# Iteration:  190
# 	Particles resampled.
# 	Epsilon: 2.4595219249618303
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2212000000000000
# 	Step-size adapted to: 0.2359924941333178
# Iteration:  191
# 	Particles resampled.
# 	Epsilon: 2.4590651444116327
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2220000000000000
# 	Step-size adapted to: 0.2350504095819996
# Iteration:  192
# 	Particles resampled.
# 	Epsilon: 2.4586526487542515
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2088000000000000
# 	Step-size adapted to: 0.2325720338376900
# Iteration:  193
# 	Particles resampled.
# 	Epsilon: 2.4582785656344965
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2122000000000001
# 	Step-size adapted to: 0.2305113264866147
# Iteration:  194
# 	Particles resampled.
# 	Epsilon: 2.4579253272031218
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1924000000000000
# 	Step-size adapted to: 0.2262181954269029
# Iteration:  195
# 	Particles resampled.
# 	Epsilon: 2.4576078734096187
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2024000000000000
# 	Step-size adapted to: 0.2231178260812023
# Iteration:  196
# 	Particles resampled.
# 	Epsilon: 2.4573143208780674
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2012000000000000
# 	Step-size adapted to: 0.2199279516027186
# Iteration:  197
# 	Particles resampled.
# 	Epsilon: 2.4570423869093023
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2200000000000000
# 	Step-size adapted to: 0.2188310563679892
# Iteration:  198
# 	Particles resampled.
# 	Epsilon: 2.4567458361005277
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2024000000000000
# 	Step-size adapted to: 0.2158319293624438
# Iteration:  199
# 	Particles resampled.
# 	Epsilon: 2.4564654427345576
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2108000000000000
# 	Step-size adapted to: 0.2137698566263916
# Iteration:  200
# 	Particles resampled.
# 	Epsilon: 2.4561948022330462
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2034000000000000
# 	Step-size adapted to: 0.2109455408657143
# Iteration:  201
# 	Particles resampled.
# 	Epsilon: 2.4559414744676435
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2088000000000000
# 	Step-size adapted to: 0.2087213272905005
# Iteration:  202
# 	Particles resampled.
# 	Epsilon: 2.4556936944230872
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2118000000000000
# 	Step-size adapted to: 0.2068305791638528
# Iteration:  203
# 	Particles resampled.
# 	Epsilon: 2.4554268577367133
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2400000000000000
# 	Step-size adapted to: 0.2078673217562736
# Iteration:  204
# 	Particles resampled.
# 	Epsilon: 2.4551253079339044
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2276000000000000
# 	Step-size adapted to: 0.2076180305747899
# Iteration:  205
# 	Particles resampled.
# 	Epsilon: 2.4548514153014342
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2278000000000000
# 	Step-size adapted to: 0.2073897763040222
# Iteration:  206
# 	Particles resampled.
# 	Epsilon: 2.4546017246491214
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2126000000000000
# 	Step-size adapted to: 0.2055933112045492
# Iteration:  207
# 	Particles resampled.
# 	Epsilon: 2.4543329618590066
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2250000000000000
# 	Step-size adapted to: 0.2050799698705706
# Iteration:  208
# 	Particles resampled.
# 	Epsilon: 2.4540539933590915
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2526000000000000
# 	Step-size adapted to: 0.2074105163186361
# Iteration:  209
# 	Particles resampled.
# 	Epsilon: 2.4537953339201324
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2392000000000000
# 	Step-size adapted to: 0.2083668024655891
# Iteration:  210
# 	Particles resampled.
# 	Epsilon: 2.4535346434117842
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2140000000000000
# 	Step-size adapted to: 0.2067065180384139
# Iteration:  211
# 	Particles resampled.
# 	Epsilon: 2.4532685023386795
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2218000000000000
# 	Step-size adapted to: 0.2058607563107690
# Iteration:  212
# 	Particles resampled.
# 	Epsilon: 2.4530329327261184
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2138000000000000
# 	Step-size adapted to: 0.2042000192498186
# Iteration:  213
# 	Particles resampled.
# 	Epsilon: 2.4528177264695001
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2104000000000000
# 	Step-size adapted to: 0.2022086327925152
# Iteration:  214
# 	Particles resampled.
# 	Epsilon: 2.4526123919668024
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1938000000000000
# 	Step-size adapted to: 0.1985815803842779
# Iteration:  215
# 	Particles resampled.
# 	Epsilon: 2.4523939647695729
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2102000000000001
# 	Step-size adapted to: 0.1966253221942270
# Iteration:  216
# 	Particles resampled.
# 	Epsilon: 2.4521964059272503
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2164000000000000
# 	Step-size adapted to: 0.1952928056940332
# Iteration:  217
# 	Particles resampled.
# 	Epsilon: 2.4519851877593419
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2220000000000000
# 	Step-size adapted to: 0.1945131947326608
# Iteration:  218
# 	Particles resampled.
# 	Epsilon: 2.4517855464107359
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2486000000000000
# 	Step-size adapted to: 0.1963306053038628
# Iteration:  219
# 	Particles resampled.
# 	Epsilon: 2.4515556762558028
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2338000000000000
# 	Step-size adapted to: 0.1967039880552280
# Iteration:  220
# 	Particles resampled.
# 	Epsilon: 2.4513358663630900
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2222000000000000
# 	Step-size adapted to: 0.1959383364928224
# Iteration:  221
# 	Particles resampled.
# 	Epsilon: 2.4511332261612253
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2020000000000000
# 	Step-size adapted to: 0.1932143124425225
# Iteration:  222
# 	Particles resampled.
# 	Epsilon: 2.4509303828606281
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2161999999999999
# 	Step-size adapted to: 0.1918857225928265
# Iteration:  223
# 	Particles resampled.
# 	Epsilon: 2.4507356320559106
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2198000000000000
# 	Step-size adapted to: 0.1909095966445233
# Iteration:  224
# 	Particles resampled.
# 	Epsilon: 2.4505294099832673
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2248000000000000
# 	Step-size adapted to: 0.1904138764088097
# Iteration:  225
# 	Particles resampled.
# 	Epsilon: 2.4503107929262753
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2206000000000000
# 	Step-size adapted to: 0.1895210310199311
# Iteration:  226
# 	Particles resampled.
# 	Epsilon: 2.4500930727113328
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2256000000000000
# 	Step-size adapted to: 0.1891045430564306
# Iteration:  227
# 	Particles resampled.
# 	Epsilon: 2.4498982235831970
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2296000000000000
# 	Step-size adapted to: 0.1890667259296581
# Iteration:  228
# 	Particles resampled.
# 	Epsilon: 2.4497075428408372
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2220000000000000
# 	Step-size adapted to: 0.1883119695450502
# Iteration:  229
# 	Particles resampled.
# 	Epsilon: 2.4495036810148401
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2338000000000000
# 	Step-size adapted to: 0.1886701024056651
# Iteration:  230
# 	Particles resampled.
# 	Epsilon: 2.4493113814154048
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2336000000000000
# 	Step-size adapted to: 0.1890100144190311
# Iteration:  231
# 	Particles resampled.
# 	Epsilon: 2.4491332014146332
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2364000000000001
# 	Step-size adapted to: 0.1896158152295189
# Iteration:  232
# 	Particles resampled.
# 	Epsilon: 2.4489491193002912
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2262000000000000
# 	Step-size adapted to: 0.1892558872204697
# Iteration:  233
# 	Particles resampled.
# 	Epsilon: 2.4487566509640919
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2230000000000000
# 	Step-size adapted to: 0.1885946494562988
# Iteration:  234
# 	Particles resampled.
# 	Epsilon: 2.4485616130270662
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2304000000000000
# 	Step-size adapted to: 0.1886323721583345
# Iteration:  235
# 	Particles resampled.
# 	Epsilon: 2.4483629589014457
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2374000000000001
# 	Step-size adapted to: 0.1893316047178478
# Iteration:  236
# 	Particles resampled.
# 	Epsilon: 2.4481728864396222
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2188000000000000
# 	Step-size adapted to: 0.1882743109171295
# Iteration:  237
# 	Particles resampled.
# 	Epsilon: 2.4479799809019065
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2262000000000000
# 	Step-size adapted to: 0.1879169293463915
# Iteration:  238
# 	Particles resampled.
# 	Epsilon: 2.4478152777803293
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2118000000000000
# 	Step-size adapted to: 0.1862146424419366
# Iteration:  239
# 	Particles resampled.
# 	Epsilon: 2.4476646499853283
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2184000000000000
# 	Step-size adapted to: 0.1851377235993776
# Iteration:  240
# 	Particles resampled.
# 	Epsilon: 2.4475029411661162
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2236000000000000
# 	Step-size adapted to: 0.1845462297787139
# Iteration:  241
# 	Particles resampled.
# 	Epsilon: 2.4473310536247186
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2218000000000000
# 	Step-size adapted to: 0.1837911392300017
# Iteration:  242
# 	Particles resampled.
# 	Epsilon: 2.4471611305245453
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2304000000000000
# 	Step-size adapted to: 0.1838279011339156
# Iteration:  243
# 	Particles resampled.
# 	Epsilon: 2.4470148259827260
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2258000000000000
# 	Step-size adapted to: 0.1834422675984669
# Iteration:  244
# 	Particles resampled.
# 	Epsilon: 2.4468835950083188
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2134000000000000
# 	Step-size adapted to: 0.1819259980008707
# Iteration:  245
# 	Particles resampled.
# 	Epsilon: 2.4467526724869568
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2131999999999999
# 	Step-size adapted to: 0.1804042200331717
# Iteration:  246
# 	Particles resampled.
# 	Epsilon: 2.4466330608742322
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2161999999999999
# 	Step-size adapted to: 0.1791637155770140
# ...
# 	Approx AP: 0.2938000000000000
# 	Step-size adapted to: 0.2585011131167118
# Iteration:  336
# 	Particles resampled.
# 	Epsilon: 2.4366786281731061
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2804000000000000
# 	Step-size adapted to: 0.2650981142722060
# Iteration:  337
# 	Particles resampled.
# 	Epsilon: 2.4365443616983709
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2722000000000000
# 	Step-size adapted to: 0.2707511138999817
# Iteration:  338
# 	Particles resampled.
# 	Epsilon: 2.4363886458128090
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2824000000000000
# 	Step-size adapted to: 0.2779385371893859
# Iteration:  339
# 	Particles resampled.
# 	Epsilon: 2.4362286556587169
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2844000000000000
# 	Step-size adapted to: 0.2856022189876917
# Iteration:  340
# 	Particles resampled.
# 	Epsilon: 2.4360638187290919
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2870000000000000
# 	Step-size adapted to: 0.2938589822329899
# Iteration:  341
# 	Particles resampled.
# 	Epsilon: 2.4358977422754173
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2810000000000000
# 	Step-size adapted to: 0.3014487444828318
# Iteration:  342
# 	Particles resampled.
# 	Epsilon: 2.4357174349790220
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2994000000000000
# 	Step-size adapted to: 0.3120926191480055
# Iteration:  343
# 	Particles resampled.
# 	Epsilon: 2.4355390052787742
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2874000000000000
# 	Step-size adapted to: 0.3211794496157117
# Iteration:  344
# 	Particles resampled.
# 	Epsilon: 2.4353479978961596
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2868000000000001
# 	Step-size adapted to: 0.3304317061610986
# Iteration:  345
# 	Particles resampled.
# 	Epsilon: 2.4351366631391160
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2816000000000000
# 	Step-size adapted to: 0.3390677703711979
# Iteration:  346
# 	Particles resampled.
# 	Epsilon: 2.4349333106208189
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2622000000000000
# 	Step-size adapted to: 0.3445709431423779
# Iteration:  347
# 	Particles resampled.
# 	Epsilon: 2.4347284155165929
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2440000000000000
# 	Step-size adapted to: 0.3469914014649735
# Iteration:  348
# 	Particles resampled.
# 	Epsilon: 2.4345254264108460
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2332000000000000
# 	Step-size adapted to: 0.3475470320932856
# Iteration:  349
# 	Particles resampled.
# 	Epsilon: 2.4343122487583644
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2204000000000000
# 	Step-size adapted to: 0.3458828036827405
# Iteration:  350
# 	Particles resampled.
# 	Epsilon: 2.4340243716922028
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2372000000000000
# 	Step-size adapted to: 0.3471302257885733
# Iteration:  351
# 	Particles resampled.
# 	Epsilon: 2.4337259017814632
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2530000000000000
# 	Step-size adapted to: 0.3511452656151576
# Iteration:  352
# 	Particles resampled.
# 	Epsilon: 2.4334325178030793
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2608000000000000
# 	Step-size adapted to: 0.3565947560825591
# Iteration:  353
# 	Particles resampled.
# 	Epsilon: 2.4331334721312836
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2802000000000000
# 	Step-size adapted to: 0.3656585593388704
# Iteration:  354
# 	Particles resampled.
# 	Epsilon: 2.4328817076944960
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2630000000000000
# 	Step-size adapted to: 0.3717419757363577
# Iteration:  355
# 	Particles resampled.
# 	Epsilon: 2.4326450426298329
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2738000000000000
# 	Step-size adapted to: 0.3799729249308311
# Iteration:  356
# 	Particles resampled.
# 	Epsilon: 2.4323985192316817
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2606000000000001
# 	Step-size adapted to: 0.3858312123005562
# Iteration:  357
# 	Particles resampled.
# 	Epsilon: 2.4321613369028925
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2556000000000000
# 	Step-size adapted to: 0.3908015944013501
# Iteration:  358
# 	Particles resampled.
# 	Epsilon: 2.4319007046859848
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2558000000000000
# 	Step-size adapted to: 0.3958755918894608
# Iteration:  359
# 	Particles resampled.
# 	Epsilon: 2.4315670884019709
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3018000000000000
# 	Step-size adapted to: 0.4103457101924483
# Iteration:  360
# 	Particles resampled.
# 	Epsilon: 2.4312053179831050
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2916000000000000
# 	Step-size adapted to: 0.4231810069799501
# Iteration:  361
# 	Particles resampled.
# 	Epsilon: 2.4308508474821680
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2808000000000000
# 	Step-size adapted to: 0.4340674774455063
# Iteration:  362
# 	Particles resampled.
# 	Epsilon: 2.4305162238626474
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2892000000000000
# 	Step-size adapted to: 0.4471079212335911
# Iteration:  363
# 	Particles resampled.
# 	Epsilon: 2.4300938352125243
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3212000000000000
# 	Step-size adapted to: 0.4679680386019670
# Iteration:  364
# 	Particles resampled.
# 	Epsilon: 2.4293307977408860
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3064000000000000
# 	Step-size adapted to: 0.4861902460107990
# Iteration:  365
# 	Particles resampled.
# 	Epsilon: 2.4287960033296323
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2858000000000001
# 	Step-size adapted to: 0.4999459537101126
# Iteration:  366
# 	Particles resampled.
# 	Epsilon: 2.4283741194904378
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2618000000000000
# 	Step-size adapted to: 0.5079586263150437
# Iteration:  367
# 	Particles resampled.
# 	Epsilon: 2.4280461774353204
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2558000000000000
# 	Step-size adapted to: 0.5145537396178307
# Iteration:  368
# 	Particles resampled.
# 	Epsilon: 2.4276513990012276
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2832000000000000
# 	Step-size adapted to: 0.5284245327821947
# Iteration:  369
# 	Particles resampled.
# 	Epsilon: 2.4271581249128333
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2828000000000001
# 	Step-size adapted to: 0.5425607170600666
# Iteration:  370
# 	Particles resampled.
# 	Epsilon: 2.4265445903929272
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2846000000000000
# 	Step-size adapted to: 0.5575766596612415
# Iteration:  371
# 	Particles resampled.
# 	Epsilon: 2.4258301145372356
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2920000000000000
# 	Step-size adapted to: 0.5751322417460398
# Iteration:  372
# 	Particles resampled.
# 	Epsilon: 2.4250014997106346
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2942000000000000
# 	Step-size adapted to: 0.5938934938481777
# Iteration:  373
# 	Particles resampled.
# 	Epsilon: 2.4240148699414545
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2762000000000000
# 	Step-size adapted to: 0.6077721144823204
# Iteration:  374
# 	Particles resampled.
# 	Epsilon: 2.4230755125277206
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2580000000000000
# 	Step-size adapted to: 0.6163407646823100
# Iteration:  375
# 	Particles resampled.
# 	Epsilon: 2.4220457568144598
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2746000000000000
# 	Step-size adapted to: 0.6302395593221007
# Iteration:  376
# 	Particles resampled.
# 	Epsilon: 2.4210965046852326
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2560000000000000
# 	Step-size adapted to: 0.6384861603607350
# Iteration:  377
# 	Particles resampled.
# 	Epsilon: 2.4199916983392304
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2650000000000000
# 	Step-size adapted to: 0.6497580091786983
# Iteration:  378
# 	Particles resampled.
# 	Epsilon: 2.4187106699943404
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2490000000000000
# 	Step-size adapted to: 0.6559601236647052
# Iteration:  379
# 	Particles resampled.
# 	Epsilon: 2.4179172171949781
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2482000000000000
# 	Step-size adapted to: 0.6619566033921639
# Iteration:  380
# 	Particles resampled.
# 	Epsilon: 2.4172113673168916
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2320000000000000
# 	Step-size adapted to: 0.6626188910842115
# Iteration:  381
# 	Particles resampled.
# 	Epsilon: 2.4166316771845904
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2360000000000000
# 	Step-size adapted to: 0.6646097325264967
# Iteration:  382
# 	Particles resampled.
# 	Epsilon: 2.4160147514495778
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2240000000000000
# 	Step-size adapted to: 0.6626188910842115
# Iteration:  383
# 	Particles resampled.
# 	Epsilon: 2.4154023003389731
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2536000000000000
# 	Step-size adapted to: 0.6704841075134214
# Iteration:  384
# 	Particles resampled.
# 	Epsilon: 2.4146764426696006
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2544000000000000
# 	Step-size adapted to: 0.6787141145889781
# Iteration:  385
# 	Particles resampled.
# 	Epsilon: 2.4138174318599916
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2468000000000000
# 	Step-size adapted to: 0.6844393253726170
# Iteration:  386
# 	Particles resampled.
# 	Epsilon: 2.4129676500123147
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2344000000000001
# 	Step-size adapted to: 0.6859467494469241
# Iteration:  387
# 	Particles resampled.
# 	Epsilon: 2.4123432839864445
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2262000000000000
# 	Step-size adapted to: 0.6846446879730785
# Iteration:  388
# 	Particles resampled.
# 	Epsilon: 2.4115702524857627
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2426000000000000
# 	Step-size adapted to: 0.6889715648583618
# Iteration:  389
# 	Particles resampled.
# 	Epsilon: 2.4108461766921478
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2290000000000000
# 	Step-size adapted to: 0.6886271651830264
# Iteration:  390
# 	Particles resampled.
# 	Epsilon: 2.4102168707048017
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2238000000000000
# 	Step-size adapted to: 0.6864957264079872
# Iteration:  391
# 	Particles resampled.
# 	Epsilon: 2.4095892891282502
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2338000000000000
# 	Step-size adapted to: 0.6878013081981005
# Iteration:  392
# 	Particles resampled.
# 	Epsilon: 2.4089509106597240
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2258000000000000
# 	Step-size adapted to: 0.6863584409917048
# Iteration:  393
# 	Particles resampled.
# 	Epsilon: 2.4082602866659206
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2332000000000000
# 	Step-size adapted to: 0.6874574935048375
# Iteration:  394
# 	Particles resampled.
# 	Epsilon: 2.4075115769276922
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2338000000000000
# 	Step-size adapted to: 0.6887649043895244
# Iteration:  395
# 	Particles resampled.
# 	Epsilon: 2.4068970916331343
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2238000000000000
# 	Step-size adapted to: 0.6866330392840987
# Iteration:  396
# 	Particles resampled.
# 	Epsilon: 2.4063557785931233
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2268000000000000
# 	Step-size adapted to: 0.6855353048429804
# Iteration:  397
# 	Particles resampled.
# 	Epsilon: 2.4058037174255213
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2460000000000000
# 	Step-size adapted to: 0.6910415830276774
# Iteration:  398
# 	Particles resampled.
# 	Epsilon: 2.4051988659769092
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2474000000000000
# 	Step-size adapted to: 0.6970798732761312
# Iteration:  399
# 	Particles resampled.
# 	Epsilon: 2.4046802595499712
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2330000000000000
# 	Step-size adapted to: 0.6981262776931574
# Iteration:  400
# 	Particles resampled.
# 	Epsilon: 2.4041535203676458
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2396000000000000
# 	Step-size adapted to: 0.7014853391241234
# Iteration:  401
# 	Particles resampled.
# 	Epsilon: 2.4036436733537432
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2254000000000000
# 	Step-size adapted to: 0.6998737768511821
# Iteration:  402
# 	Particles resampled.
# 	Epsilon: 2.4031947452718438
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2270000000000000
# 	Step-size adapted to: 0.6988247531503728
# Iteration:  403
# 	Particles resampled.
# 	Epsilon: 2.4027055738977481
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2244000000000000
# 	Step-size adapted to: 0.6968707806796061
# Iteration:  404
# 	Particles resampled.
# 	Epsilon: 2.4022618842315433
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2316000000000000
# 	Step-size adapted to: 0.6974285003622778
# Iteration:  405
# 	Particles resampled.
# 	Epsilon: 2.4017474872908133
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2420000000000000
# 	Step-size adapted to: 0.7016256502225904
# Iteration:  406
# 	Particles resampled.
# 	Epsilon: 2.4010724696247907
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2520000000000000
# 	Step-size adapted to: 0.7093861367997983
# Iteration:  407
# 	Particles resampled.
# 	Epsilon: 2.4002907144646990
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2622000000000000
# 	Step-size adapted to: 0.7208996889962086
# Iteration:  408
# 	Particles resampled.
# 	Epsilon: 2.3993443330408013
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2432000000000000
# 	Step-size adapted to: 0.7256733627385100
# Iteration:  409
# 	Particles resampled.
# 	Epsilon: 2.3986186425627252
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2290000000000000
# 	Step-size adapted to: 0.7253106167511948
# Iteration:  410
# 	Particles resampled.
# 	Epsilon: 2.3978446826406667
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2184000000000000
# 	Step-size adapted to: 0.7211159913466377
# Iteration:  411
# 	Particles resampled.
# 	Epsilon: 2.3972312909882909
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2276000000000000
# 	Step-size adapted to: 0.7202511711529165
# Iteration:  412
# 	Particles resampled.
# 	Epsilon: 2.3966385607364580
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2176000000000000
# 	Step-size adapted to: 0.7157994285542306
# Iteration:  413
# 	Particles resampled.
# 	Epsilon: 2.3960979186521651
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2151999999999999
# 	Step-size adapted to: 0.7105220631174012
# Iteration:  414
# 	Particles resampled.
# 	Epsilon: 2.3955279024098703
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2266000000000000
# 	Step-size adapted to: 0.7093152017329308
# Iteration:  415
# 	Particles resampled.
# 	Epsilon: 2.3948542086047500
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2328000000000000
# 	Step-size adapted to: 0.7103089384687616
# Iteration:  416
# 	Particles resampled.
# 	Epsilon: 2.3942295279746335
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2464000000000000
# 	Step-size adapted to: 0.7161574177583506
# Iteration:  417
# 	Particles resampled.
# 	Epsilon: 2.3935897803536044
# 	Weights computed and normalised.
# Error was raised:

# %% [markdown]
# # Random Walk Metropolis Only

# %% [markdown]
# #### SMC

# %%
SMC_RWM = SMCAdaptive(generate_settings(δ=0.001, adaptiveδ=False, d=d, integrator='rwm', quantile_value=0.1))
_ = SMC_RWM.sample()
# Out:
# Stochastic Kernel: RWM.
# Setting initial epsilon to εmax = 6367087446543.3310546875000000
# Iteration:  1
# 	Particles resampled.
# 	Epsilon: 124.9657979742095080
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0891999999999999
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  2
# 	Particles resampled.
# 	Epsilon: 29.0047240600496927
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0776000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  3
# 	Particles resampled.
# 	Epsilon: 21.2564351402290761
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0626000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  4
# 	Particles resampled.
# 	Epsilon: 19.4469638687264457
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0506000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  5
# 	Particles resampled.
# 	Epsilon: 16.2918652692676922
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0192000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  6
# 	Particles resampled.
# 	Epsilon: 14.6218093784066312
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0140000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  7
# 	Particles resampled.
# 	Epsilon: 13.5929130267825933
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0028000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  8
# 	Particles resampled.
# 	Epsilon: 12.8590206956918678
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0028000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  9
# 	Particles resampled.
# 	Epsilon: 12.5242683445648346
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0016000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  10
# 	Particles resampled.
# 	Epsilon: 12.2162324395156734
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0026000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  11
# 	Particles resampled.
# 	Epsilon: 11.6787653837077450
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0008000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  12
# 	Particles resampled.
# 	Epsilon: 11.4363755503933255
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0008000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  13
# 	Particles resampled.
# 	Epsilon: 11.2198631118300476
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0000000000000000
# 	Step-size kept fixed at: 0.0010000000000000

# %% [markdown]
# #### MS

# %%
MS_RWM = MSAdaptive(generate_settings(δ=0.01, adaptiveδ=False, d=d, integrator='rwm', quantile_value=0.1))
_ = MS_RWM.sample()
# Out:
# Integrator: RWM.
# Setting initial epsilon to εmax = 6367087446543.3310546875000000
# Iteration:  1
# 	Trajectories constructed.
# 	Epsilon: 118.1127167680561030
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9494000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  2
# 	Trajectories constructed.
# 	Epsilon: 27.7788087345293064
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9520000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  3
# 	Trajectories constructed.
# 	Epsilon: 20.3649293322110267
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9604000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  4
# 	Trajectories constructed.
# 	Epsilon: 18.7953740813573127
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9460000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  5
# 	Trajectories constructed.
# 	Epsilon: 16.9756949047944019
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9512000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  6
# 	Trajectories constructed.
# 	Epsilon: 15.6851830194597515
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9436000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  7
# 	Trajectories constructed.
# 	Epsilon: 14.4355716536576644
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9366000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  8
# 	Trajectories constructed.
# 	Epsilon: 13.2402925098979285
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9220000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  9
# 	Trajectories constructed.
# 	Epsilon: 12.4143772988509600
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9084000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  10
# 	Trajectories constructed.
# 	Epsilon: 11.7497727258849132
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9062000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  11
# 	Trajectories constructed.
# 	Epsilon: 11.2390726789044759
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8822000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  12
# 	Trajectories constructed.
# 	Epsilon: 10.9799037892680680
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8354000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  13
# 	Trajectories constructed.
# 	Epsilon: 10.6312493395600161
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8192000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  14
# 	Trajectories constructed.
# 	Epsilon: 10.3324197883851596
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8336000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  15
# 	Trajectories constructed.
# 	Epsilon: 10.1324204486612768
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7728000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  16
# 	Trajectories constructed.
# 	Epsilon: 9.9922897936765036
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.6690000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  17
# 	Trajectories constructed.
# 	Epsilon: 9.9339473393973812
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.6734000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  18
# 	Trajectories constructed.
# 	Epsilon: 9.8429734198052028
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.6183999999999999
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  19
# 	Trajectories constructed.
# 	Epsilon: 9.7525648207115605
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.6640000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  20
# 	Trajectories constructed.
# 	Epsilon: 9.7077902025545910
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.5266000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  21
# 	Trajectories constructed.
# 	Epsilon: 9.6742331709361498
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.4158000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  22
# 	Trajectories constructed.
# 	Epsilon: 9.6504922109006870
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.4004000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  23
# 	Trajectories constructed.
# 	Epsilon: 9.6321951595026771
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.3068000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  24
# 	Trajectories constructed.
# 	Epsilon: 9.6174533456078013
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.5270000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  25
# 	Trajectories constructed.
# 	Epsilon: 9.6022977924821493
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.4202000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  26
# 	Trajectories constructed.
# 	Epsilon: 9.5825057422760089
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2614000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  27
# 	Trajectories constructed.
# 	Epsilon: 9.5702458144587759
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.3940000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  28
# 	Trajectories constructed.
# 	Epsilon: 9.5578317590516786
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2576000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  29
# 	Trajectories constructed.
# 	Epsilon: 9.5460336346566361
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1054000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  30
# 	Trajectories constructed.
# 	Epsilon: 9.5360665704486216
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.3590000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  31
# 	Trajectories constructed.
# 	Epsilon: 9.5276232354143602
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2224000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  32
# 	Trajectories constructed.
# 	Epsilon: 9.5199831708797511
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.3640000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  33
# 	Trajectories constructed.
# 	Epsilon: 9.5118544542176746
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1228000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  34
# 	Trajectories constructed.
# 	Epsilon: 9.5038945250405042
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.4164000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  35
# 	Trajectories constructed.
# 	Epsilon: 9.4960271293207583
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.3086000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  36
# 	Trajectories constructed.
# 	Epsilon: 9.4902609376805867
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.4058000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  37
# 	Trajectories constructed.
# 	Epsilon: 9.4823794084378825
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1902000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  38
# 	Trajectories constructed.
# 	Epsilon: 9.4754500037487279
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0676000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  39
# 	Trajectories constructed.
# 	Epsilon: 9.4703228747585779
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0416000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  40
# 	Trajectories constructed.
# 	Epsilon: 9.4653747025701804
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0650000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  41
# 	Trajectories constructed.
# 	Epsilon: 9.4632855028236733
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.3990000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  42
# 	Trajectories constructed.
# 	Epsilon: 9.4558587849228282
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2538000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  43
# 	Trajectories constructed.
# 	Epsilon: 9.4513530545667415
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0616000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  44
# 	Trajectories constructed.
# 	Epsilon: 9.4462003783820272
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1772000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  45
# 	Trajectories constructed.
# 	Epsilon: 9.4431315601083643
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1674000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  46
# 	Trajectories constructed.
# 	Epsilon: 9.4393694411344828
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2484000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  47
# 	Trajectories constructed.
# 	Epsilon: 9.4364168093346112
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1078000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  48
# 	Trajectories constructed.
# 	Epsilon: 9.4335101066533706
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.4168000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  49
# 	Trajectories constructed.
# 	Epsilon: 9.4290482774454762
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0996000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  50
# 	Trajectories constructed.
# 	Epsilon: 9.4230374152089436
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1558000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  51
# 	Trajectories constructed.
# 	Epsilon: 9.4187839972879672
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0304000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  52
# 	Trajectories constructed.
# 	Epsilon: 9.4150716783786432
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.5548000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  53
# 	Trajectories constructed.
# 	Epsilon: 9.4088734462246215
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0752000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  54
# 	Trajectories constructed.
# 	Epsilon: 9.4043572436573353
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.5386000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  55
# 	Trajectories constructed.
# 	Epsilon: 9.3998297618423710
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0766000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  56
# 	Trajectories constructed.
# 	Epsilon: 9.3941447596434706
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.5230000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  57
# 	Trajectories constructed.
# 	Epsilon: 9.3856775117866569
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0956000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  58
# 	Trajectories constructed.
# 	Epsilon: 9.3739998541006617
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.3760000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  59
# 	Trajectories constructed.
# 	Epsilon: 9.3673361300622506
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.3164000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  60
# 	Trajectories constructed.
# 	Epsilon: 9.3607658254901995
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2382000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  61
# 	Trajectories constructed.
# 	Epsilon: 9.3564189610737127
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.4502000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  62
# 	Trajectories constructed.
# 	Epsilon: 9.3483291846450705
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2298000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  63
# 	Trajectories constructed.
# 	Epsilon: 9.3430421966432213
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2686000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  64
# 	Trajectories constructed.
# 	Epsilon: 9.3376326568527812
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1842000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  65
# 	Trajectories constructed.
# 	Epsilon: 9.3331706485445647
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.4002000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  66
# 	Trajectories constructed.
# 	Epsilon: 9.3281181475588895
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.3336000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  67
# 	Trajectories constructed.
# 	Epsilon: 9.3204473480507559
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2304000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  68
# 	Trajectories constructed.
# 	Epsilon: 9.3045933197608210
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.3566000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  69
# 	Trajectories constructed.
# 	Epsilon: 9.2846771187178074
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1444000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  70
# 	Trajectories constructed.
# 	Epsilon: 9.2676443093144076
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2394000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  71
# 	Trajectories constructed.
# 	Epsilon: 9.2436571114800614
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1536000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  72
# 	Trajectories constructed.
# 	Epsilon: 9.2369263985536865
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.6684000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  73
# 	Trajectories constructed.
# 	Epsilon: 9.2266762396205468
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.3136000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  74
# 	Trajectories constructed.
# 	Epsilon: 9.2170673799297766
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.3456000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  75
# 	Trajectories constructed.
# 	Epsilon: 9.2098768428220126
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1668000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  76
# 	Trajectories constructed.
# 	Epsilon: 9.2027912765140112
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1682000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  77
# 	Trajectories constructed.
# 	Epsilon: 9.1967287369037685
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2708000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  78
# 	Trajectories constructed.
# 	Epsilon: 9.1902861442869384
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.4206000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  79
# 	Trajectories constructed.
# 	Epsilon: 9.1815437686526824
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2580000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  80
# 	Trajectories constructed.
# 	Epsilon: 9.1755646519163303
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1768000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  81
# 	Trajectories constructed.
# 	Epsilon: 9.1690125999680614
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2854000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  82
# 	Trajectories constructed.
# 	Epsilon: 9.1628622433593847
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.3574000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  83
# 	Trajectories constructed.
# 	Epsilon: 9.1547050706476814
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2128000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  84
# 	Trajectories constructed.
# 	Epsilon: 9.1504656556641244
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1044000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  85
# 	Trajectories constructed.
# 	Epsilon: 9.1442613021194337
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2980000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  86
# 	Trajectories constructed.
# 	Epsilon: 9.1380358779829276
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0424000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  87
# 	Trajectories constructed.
# 	Epsilon: 9.1335261986915519
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.3826000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  88
# 	Trajectories constructed.
# 	Epsilon: 9.1315866487579207
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1206000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  89
# 	Trajectories constructed.
# 	Epsilon: 9.1274053471823233
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0998000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  90
# 	Trajectories constructed.
# 	Epsilon: 9.1170020580467632
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2850000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  91
# 	Trajectories constructed.
# 	Epsilon: 9.1085213214039040
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1312000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  92
# 	Trajectories constructed.
# 	Epsilon: 9.1041379331745329
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2426000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  93
# 	Trajectories constructed.
# 	Epsilon: 9.0999857861524731
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0764000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  94
# 	Trajectories constructed.
# 	Epsilon: 9.0970732985673006
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.5024000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  95
# 	Trajectories constructed.
# 	Epsilon: 9.0935027175911145
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1116000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  96
# 	Trajectories constructed.
# 	Epsilon: 9.0891830651139482
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1772000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  97
# 	Trajectories constructed.
# 	Epsilon: 9.0849834387879440
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1308000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  98
# 	Trajectories constructed.
# 	Epsilon: 9.0813534307066579
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.4204000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  99
# 	Trajectories constructed.
# 	Epsilon: 9.0760603975753114
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0898000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  100
# 	Trajectories constructed.
# 	Epsilon: 9.0715444795816413
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0764000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  101
# 	Trajectories constructed.
# 	Epsilon: 9.0667724114786914
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.3016000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  102
# 	Trajectories constructed.
# 	Epsilon: 9.0628925230673190
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1486000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  103
# 	Trajectories constructed.
# 	Epsilon: 9.0563920180674504
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.3968000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  104
# 	Trajectories constructed.
# 	Epsilon: 9.0508969832362176
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2018000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  105
# 	Trajectories constructed.
# 	Epsilon: 9.0402259997771068
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.3762000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  106
# 	Trajectories constructed.
# 	Epsilon: 9.0269921789806808
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.4798000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  107
# 	Trajectories constructed.
# 	Epsilon: 9.0074066668545232
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2464000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  108
# 	Trajectories constructed.
# 	Epsilon: 8.9921876786688024
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.3416000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  109
# 	Trajectories constructed.
# 	Epsilon: 8.9728217159522803
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2472000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  110
# 	Trajectories constructed.
# 	Epsilon: 8.9535054686169673
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.4802000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  111
# 	Trajectories constructed.
# 	Epsilon: 8.9458522460473144
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1222000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  112
# 	Trajectories constructed.
# 	Epsilon: 8.9381570151075085
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0818000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  113
# 	Trajectories constructed.
# 	Epsilon: 8.9316786102010735
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0990000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  114
# 	Trajectories constructed.
# 	Epsilon: 8.9266259435603335
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0116000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  115
# 	Trajectories constructed.
# 	Epsilon: 8.9221164989747628
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2330000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  116
# 	Trajectories constructed.
# 	Epsilon: 8.9202380657830140
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0232000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  117
# 	Trajectories constructed.
# 	Epsilon: 8.9163553762388243
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2204000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  118
# 	Trajectories constructed.
# 	Epsilon: 8.9146962265579734
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0218000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  119
# 	Trajectories constructed.
# 	Epsilon: 8.9108949508724518
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.3532000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  120
# 	Trajectories constructed.
# 	Epsilon: 8.9094354369046744
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0652000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  121
# 	Trajectories constructed.
# 	Epsilon: 8.9060555987609238
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0590000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  122
# 	Trajectories constructed.
# 	Epsilon: 8.9051323544524870
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0194000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  123
# 	Trajectories constructed.
# 	Epsilon: 8.9016383204424461
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.3462000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  124
# 	Trajectories constructed.
# 	Epsilon: 8.8993016599766843
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0984000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  125
# 	Trajectories constructed.
# 	Epsilon: 8.8961181403859513
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0816000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  126
# 	Trajectories constructed.
# 	Epsilon: 8.8944647139375483
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2384000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  127
# 	Trajectories constructed.
# 	Epsilon: 8.8929683805813138
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1524000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  128
# 	Trajectories constructed.
# 	Epsilon: 8.8903013472439909
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1072000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  129
# 	Trajectories constructed.
# 	Epsilon: 8.8879625922028218
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0102000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  130
# 	Trajectories constructed.
# 	Epsilon: 8.8862565320408997
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.5306000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  131
# 	Trajectories constructed.
# 	Epsilon: 8.8849447667957957
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0498000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  132
# 	Trajectories constructed.
# 	Epsilon: 8.8832115265993288
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2616000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  133
# 	Trajectories constructed.
# 	Epsilon: 8.8759076570403757
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0060000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  134
# 	Trajectories constructed.
# 	Epsilon: 8.8752588762491325
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.4116000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  135
# 	Trajectories constructed.
# 	Epsilon: 8.8708628410605179
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0742000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  136
# 	Trajectories constructed.
# 	Epsilon: 8.8672760822447305
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2452000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  137
# 	Trajectories constructed.
# 	Epsilon: 8.8645327669271072
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1532000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  138
# 	Trajectories constructed.
# 	Epsilon: 8.8605516899032448
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1230000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  139
# 	Trajectories constructed.
# 	Epsilon: 8.8586846702997182
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1910000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  140
# 	Trajectories constructed.
# 	Epsilon: 8.8548957884919162
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0786000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  141
# 	Trajectories constructed.
# 	Epsilon: 8.8521462759710463
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1298000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  142
# 	Trajectories constructed.
# 	Epsilon: 8.8507569622196076
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1210000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  143
# 	Trajectories constructed.
# 	Epsilon: 8.8476221952468581
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2552000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  144
# 	Trajectories constructed.
# 	Epsilon: 8.8445106186000491
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0752000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  145
# 	Trajectories constructed.
# 	Epsilon: 8.8411159840790781
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2454000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  146
# 	Trajectories constructed.
# 	Epsilon: 8.8378660536697815
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0976000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  147
# 	Trajectories constructed.
# 	Epsilon: 8.8337174287983053
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0608000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  148
# 	Trajectories constructed.
# 	Epsilon: 8.8317228520164992
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0756000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  149
# 	Trajectories constructed.
# 	Epsilon: 8.8304452548158121
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1412000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  150
# 	Trajectories constructed.
# 	Epsilon: 8.8261851708416756
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0334000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  151
# 	Trajectories constructed.
# 	Epsilon: 8.8244338217855525
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1050000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  152
# 	Trajectories constructed.
# 	Epsilon: 8.8212169352126448
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0290000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  153
# 	Trajectories constructed.
# 	Epsilon: 8.8197802940918280
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0004000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  154
# 	Trajectories constructed.
# 	Epsilon: 8.8195267156152184
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.4970000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  155
# 	Trajectories constructed.
# 	Epsilon: 8.8182170325272402
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0088000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  156
# 	Trajectories constructed.
# 	Epsilon: 8.8168189973725166
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.4500000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  157
# 	Trajectories constructed.
# 	Epsilon: 8.8160115223256703
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0010000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  158
# 	Trajectories constructed.
# 	Epsilon: 8.8158863181020148
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.6148000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  159
# 	Trajectories constructed.
# 	Epsilon: 8.8151128154888561
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0144000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  160
# 	Trajectories constructed.
# 	Epsilon: 8.8140667659785450
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1572000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  161
# 	Trajectories constructed.
# 	Epsilon: 8.8119972649322467
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0106000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  162
# 	Trajectories constructed.
# 	Epsilon: 8.8101093118616003
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0632000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  163
# 	Trajectories constructed.
# 	Epsilon: 8.8097179787244393
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0006000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  164
# 	Trajectories constructed.
# 	Epsilon: 8.8090675489211350
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0000000000000000
# 	Step-size kept fixed at: 0.0100000000000000

# %%
plt.plot(MS_RWM.PROP_MOVED)

# %% [markdown]
# # Switch

# %% [markdown]
# #### SMC

# %%
SMC_RT = SMCAdaptive(generate_settings(δ=0.001, adaptiveδ=True, d=d, integrator='rwm_then_thug', quantile_value=0.1))
_ = SMC_RT.sample()
# Out:
# Stochastic Kernel: RWM.
# Setting initial epsilon to εmax = 6367087446543.3310546875000000
# Iteration:  1
# 	Particles resampled.
# 	Epsilon: 115.1655960575225777
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0904000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  2
# 	Particles resampled.
# 	Epsilon: 26.4832187112850974
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0712000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  3
# 	Particles resampled.
# 	Epsilon: 20.2238117612027430
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0578000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  4
# 	Particles resampled.
# 	Epsilon: 18.7901407887903886
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0370000000000000
# 	Step-size adapted to: 0.0010000000000000
#
#
# ####################################
# ### SWITCHING TO THUG KERNEL ###
# ####################################
#
#
# Iteration:  5
# 	Particles resampled.
# 	Epsilon: 16.3679011958713900
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0532000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  6
# 	Particles resampled.
# 	Epsilon: 15.1060031679882130
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0846000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  7
# 	Particles resampled.
# 	Epsilon: 14.2676980038722832
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0592000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  8
# 	Particles resampled.
# 	Epsilon: 14.2676978940146579
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0634000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  9
# 	Particles resampled.
# 	Epsilon: 14.2676977805596259
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0679999999999999
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  10
# 	Particles resampled.
# 	Epsilon: 14.2676976748837330
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0550000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  11
# 	Particles resampled.
# 	Epsilon: 14.2676975720094354
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0608000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  12
# 	Particles resampled.
# 	Epsilon: 14.2676974700727062
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0552000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  13
# 	Particles resampled.
# 	Epsilon: 14.2676973657278943
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0532000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  14
# 	Particles resampled.
# 	Epsilon: 14.2676972673757394
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0608000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  15
# 	Particles resampled.
# 	Epsilon: 14.2676971541272124
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0606000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  16
# 	Particles resampled.
# 	Epsilon: 14.2676970317956204
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0669999999999999
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  17
# 	Particles resampled.
# 	Epsilon: 14.2676968918286793
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0679999999999999
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  18
# 	Particles resampled.
# 	Epsilon: 14.2676967750322596
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0576000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  19
# 	Particles resampled.
# 	Epsilon: 14.2676966902511602
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0588000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  20
# 	Particles resampled.
# 	Epsilon: 14.2676965725857734
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0714000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  21
# 	Particles resampled.
# 	Epsilon: 14.2676963885754571
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0694000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  22
# 	Particles resampled.
# 	Epsilon: 14.2676962724967851
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0636000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  23
# 	Particles resampled.
# 	Epsilon: 14.2676961528403794
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0620000000000001
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  24
# 	Particles resampled.
# 	Epsilon: 14.2676960647362101
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0604000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  25
# 	Particles resampled.
# 	Epsilon: 14.2676959537567996
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0656000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  26
# 	Particles resampled.
# 	Epsilon: 14.2676958434034216
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0552000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  27
# 	Particles resampled.
# 	Epsilon: 14.2676957470733718
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0628000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  28
# 	Particles resampled.
# 	Epsilon: 14.2676956103066832
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0639999999999999
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  29
# 	Particles resampled.
# 	Epsilon: 14.2676954156440736
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0732000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  30
# 	Particles resampled.
# 	Epsilon: 14.2676953037919549
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0678000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  31
# 	Particles resampled.
# 	Epsilon: 14.2676952123549885
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0736000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  32
# 	Particles resampled.
# 	Epsilon: 14.2676950937642442
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0718000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  33
# 	Particles resampled.
# 	Epsilon: 14.2676949835813023
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0580000000000001
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  34
# 	Particles resampled.
# 	Epsilon: 14.2676948819010896
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0594000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  35
# 	Particles resampled.
# 	Epsilon: 14.2676948001427455
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0474000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  36
# 	Particles resampled.
# 	Epsilon: 14.2676946729774503
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0610000000000001
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  37
# 	Particles resampled.
# 	Epsilon: 14.2676945484789304
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0688000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  38
# 	Particles resampled.
# 	Epsilon: 14.2676944328567892
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0684000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  39
# 	Particles resampled.
# 	Epsilon: 14.2676942984167034
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0754000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  40
# 	Particles resampled.
# 	Epsilon: 14.2676941159549955
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0702000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  41
# 	Particles resampled.
# 	Epsilon: 14.2676939833734284
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0612000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  42
# 	Particles resampled.
# 	Epsilon: 14.2676938776211912
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0702000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  43
# 	Particles resampled.
# 	Epsilon: 14.2676937703184450
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0612000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  44
# 	Particles resampled.
# 	Epsilon: 14.2676936656996940
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0580000000000001
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  45
# 	Particles resampled.
# 	Epsilon: 14.2676935501200788
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0614000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  46
# 	Particles resampled.
# 	Epsilon: 14.2676934140752785
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0659999999999999
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  47
# 	Particles resampled.
# 	Epsilon: 14.2676932934866887
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0554000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  48
# 	Particles resampled.
# 	Epsilon: 14.2676931695169635
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0606000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  49
# 	Particles resampled.
# 	Epsilon: 14.2676930556415424
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0572000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  50
# 	Particles resampled.
# 	Epsilon: 14.2676929428505943
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0620000000000001
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  51
# 	Particles resampled.
# 	Epsilon: 14.2676927888949052
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0654000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  52
# 	Particles resampled.
# 	Epsilon: 14.2676926757773241
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0662000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  53
# 	Particles resampled.
# 	Epsilon: 14.2676925564417445
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0642000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  54
# 	Particles resampled.
# 	Epsilon: 14.2676924179249163
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0638000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  55
# 	Particles resampled.
# 	Epsilon: 14.2676922291446964
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0638000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  56
# 	Particles resampled.
# 	Epsilon: 14.2676920595510559
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0708000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  57
# 	Particles resampled.
# 	Epsilon: 14.2676919291018915
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0659999999999999
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  58
# 	Particles resampled.
# 	Epsilon: 14.2676917892860935
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0649999999999999
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  59
# 	Particles resampled.
# 	Epsilon: 14.2676916390885875
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0672000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  60
# 	Particles resampled.
# 	Epsilon: 14.2676913888545602
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0700000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  61
# 	Particles resampled.
# 	Epsilon: 14.2676912491796024
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0692000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  62
# 	Particles resampled.
# 	Epsilon: 14.2676910583091097
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0598000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  63
# 	Particles resampled.
# 	Epsilon: 14.2676908776132922
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0620000000000001
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  64
# 	Particles resampled.
# 	Epsilon: 14.2676906813825042
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0666000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  65
# 	Particles resampled.
# 	Epsilon: 14.2676904953957155
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0588000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  66
# 	Particles resampled.
# 	Epsilon: 14.2676902980722833
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0566000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  67
# 	Particles resampled.
# 	Epsilon: 14.2676901265531448
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0800000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  68
# 	Particles resampled.
# 	Epsilon: 14.2676898570895609
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0790000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  69
# 	Particles resampled.
# 	Epsilon: 14.2676895399641026
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0676000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  70
# 	Particles resampled.
# 	Epsilon: 14.2676893805745770
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0624000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  71
# 	Particles resampled.
# 	Epsilon: 14.2676891797239680
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0668000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  72
# 	Particles resampled.
# 	Epsilon: 14.2676889942345362
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0636000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  73
# 	Particles resampled.
# 	Epsilon: 14.2676887720524874
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0682000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  74
# 	Particles resampled.
# 	Epsilon: 14.2676884126864252
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0644000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  75
# 	Particles resampled.
# 	Epsilon: 14.2676881794736072
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0642000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  76
# 	Particles resampled.
# 	Epsilon: 14.2676879939764945
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0544000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  77
# 	Particles resampled.
# 	Epsilon: 14.2676878309473985
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0556000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  78
# 	Particles resampled.
# 	Epsilon: 14.2676876521891103
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0628000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  79
# 	Particles resampled.
# 	Epsilon: 14.2676873558618134
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0634000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  80
# 	Particles resampled.
# 	Epsilon: 14.2676871171961785
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0704000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  81
# 	Particles resampled.
# 	Epsilon: 14.2676869385086906
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0582000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  82
# 	Particles resampled.
# 	Epsilon: 14.2676867642669478
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0649999999999999
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  83
# 	Particles resampled.
# 	Epsilon: 14.2676865412836484
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0688000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  84
# 	Particles resampled.
# 	Epsilon: 14.2676863677293966
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0639999999999999
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  85
# 	Particles resampled.
# 	Epsilon: 14.2676861028859232
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0676000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  86
# 	Particles resampled.
# 	Epsilon: 14.2676858446756754
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0760000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  87
# 	Particles resampled.
# 	Epsilon: 14.2676854879415398
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0780000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  88
# 	Particles resampled.
# 	Epsilon: 14.2676850495752010
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0669999999999999
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  89
# 	Particles resampled.
# 	Epsilon: 14.2676848541911010
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0668000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  90
# 	Particles resampled.
# 	Epsilon: 14.2676845595874404
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0674000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  91
# 	Particles resampled.
# 	Epsilon: 14.2676842220392430
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0662000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  92
# 	Particles resampled.
# 	Epsilon: 14.2676840377804393
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0648000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  93
# 	Particles resampled.
# 	Epsilon: 14.2676838345442718
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0646000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  94
# 	Particles resampled.
# 	Epsilon: 14.2676835878333517
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0632000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  95
# 	Particles resampled.
# 	Epsilon: 14.2676833595477888
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0618000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  96
# 	Particles resampled.
# 	Epsilon: 14.2676831422475665
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0639999999999999
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  97
# 	Particles resampled.
# 	Epsilon: 14.2676829094950683
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0574000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  98
# 	Particles resampled.
# 	Epsilon: 14.2676826673258095
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0658000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  99
# 	Particles resampled.
# 	Epsilon: 14.2676823659193115
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0628000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  100
# 	Particles resampled.
# 	Epsilon: 14.2676821108166134
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0644000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  101
# 	Particles resampled.
# 	Epsilon: 14.2676818474742131
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0592000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  102
# 	Particles resampled.
# 	Epsilon: 14.2676815625264055
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0592000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  103
# 	Particles resampled.
# 	Epsilon: 14.2676813329682890
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0624000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  104
# 	Particles resampled.
# 	Epsilon: 14.2676810327517885
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0666000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  105
# 	Particles resampled.
# 	Epsilon: 14.2676807832888990
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0664000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  106
# 	Particles resampled.
# 	Epsilon: 14.2676805151864237
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0596000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  107
# 	Particles resampled.
# 	Epsilon: 14.2676802526976694
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0590000000000001
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  108
# 	Particles resampled.
# 	Epsilon: 14.2676800145659737
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0608000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  109
# 	Particles resampled.
# 	Epsilon: 14.2676797842712890
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0592000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  110
# 	Particles resampled.
# 	Epsilon: 14.2676795578143079
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0629999999999999
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  111
# 	Particles resampled.
# 	Epsilon: 14.2676793347858446
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0628000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  112
# 	Particles resampled.
# 	Epsilon: 14.2676790630011663
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0744000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  113
# 	Particles resampled.
# 	Epsilon: 14.2676786884394478
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0632000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  114
# 	Particles resampled.
# 	Epsilon: 14.2676783840913206
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0674000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  115
# 	Particles resampled.
# 	Epsilon: 14.2676779904370328
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0622000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  116
# 	Particles resampled.
# 	Epsilon: 14.2676776482659591
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0636000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  117
# 	Particles resampled.
# 	Epsilon: 14.2676773240890711
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0730000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  118
# 	Particles resampled.
# 	Epsilon: 14.2676767419893995
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0712000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  119
# 	Particles resampled.
# 	Epsilon: 14.2676762747781165
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0690000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  120
# 	Particles resampled.
# 	Epsilon: 14.2676759977047496
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0606000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  121
# 	Particles resampled.
# 	Epsilon: 14.2676757205833127
# 	Weights computed and normalised.
# Error was raised:

# %% [markdown]
# #### Markov Snippets

# %%
MS_RWM = MSAdaptive(generate_settings(δ=0.001, adaptiveδ=False, d=d, integrator='rwm_then_thug', quantile_value=0.1))
_ = MS_RWM.sample()
# Out:
# Integrator: RWM.
# Setting initial epsilon to εmax = 6367087446543.3310546875000000
# Iteration:  1
# 	Trajectories constructed.
# 	Epsilon: 118.1127167680561030
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9574000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  2
# 	Trajectories constructed.
# 	Epsilon: 28.6068128034241589
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9522000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  3
# 	Trajectories constructed.
# 	Epsilon: 20.6970509786296510
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9514000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  4
# 	Trajectories constructed.
# 	Epsilon: 19.4483278955367602
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9470000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  5
# 	Trajectories constructed.
# 	Epsilon: 19.4379719574436294
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9586000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  6
# 	Trajectories constructed.
# 	Epsilon: 19.4325253163726117
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9638000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  7
# 	Trajectories constructed.
# 	Epsilon: 19.4269175564258028
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9606000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  8
# 	Trajectories constructed.
# 	Epsilon: 19.4222546532668119
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9586000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  9
# 	Trajectories constructed.
# 	Epsilon: 19.4180416871186097
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9648000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  10
# 	Trajectories constructed.
# 	Epsilon: 19.4137952718036324
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9558000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  11
# 	Trajectories constructed.
# 	Epsilon: 19.4096460531250905
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9636000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  12
# 	Trajectories constructed.
# 	Epsilon: 19.4055719156908353
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9616000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  13
# 	Trajectories constructed.
# 	Epsilon: 19.4012519107674599
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9598000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  14
# 	Trajectories constructed.
# 	Epsilon: 19.3967128236425879
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9596000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  15
# 	Trajectories constructed.
# 	Epsilon: 19.3915461528588082
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9658000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  16
# 	Trajectories constructed.
# 	Epsilon: 19.3863503975556313
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9594000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  17
# 	Trajectories constructed.
# 	Epsilon: 19.3810598757137278
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9666000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  18
# 	Trajectories constructed.
# 	Epsilon: 19.3747574754511653
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9598000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  19
# 	Trajectories constructed.
# 	Epsilon: 19.3684593992670813
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9576000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  20
# 	Trajectories constructed.
# 	Epsilon: 19.3625104406273501
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9606000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  21
# 	Trajectories constructed.
# 	Epsilon: 19.3559255358735456
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9622000000000001
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  22
# 	Trajectories constructed.
# 	Epsilon: 19.3485300395330135
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9534000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  23
# 	Trajectories constructed.
# 	Epsilon: 19.3411577231317366
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9680000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  24
# 	Trajectories constructed.
# 	Epsilon: 19.3337820876836410
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9616000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  25
# 	Trajectories constructed.
# 	Epsilon: 19.3261237077945012
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9586000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  26
# 	Trajectories constructed.
# 	Epsilon: 19.3179940458766453
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9668000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  27
# 	Trajectories constructed.
# 	Epsilon: 19.3095807931100758
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9631999999999999
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  28
# 	Trajectories constructed.
# 	Epsilon: 19.3011632747177018
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9684000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  29
# 	Trajectories constructed.
# 	Epsilon: 19.2921890394235938
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9636000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  30
# 	Trajectories constructed.
# 	Epsilon: 19.2830349472620703
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9614000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  31
# 	Trajectories constructed.
# 	Epsilon: 19.2739905663193056
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9678000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  32
# 	Trajectories constructed.
# 	Epsilon: 19.2648999444211526
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9646000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  33
# 	Trajectories constructed.
# 	Epsilon: 19.2542576708142334
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9651999999999999
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  34
# 	Trajectories constructed.
# 	Epsilon: 19.2431469677411897
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9592000000000001
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  35
# 	Trajectories constructed.
# 	Epsilon: 19.2323115761546184
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9676000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  36
# 	Trajectories constructed.
# 	Epsilon: 19.2210753661456124
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9692000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  37
# 	Trajectories constructed.
# 	Epsilon: 19.2078197521011411
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9664000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  38
# 	Trajectories constructed.
# 	Epsilon: 19.1945584007496457
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9634000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  39
# 	Trajectories constructed.
# 	Epsilon: 19.1820515442620803
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9690000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  40
# 	Trajectories constructed.
# 	Epsilon: 19.1681898315284798
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9712000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  41
# 	Trajectories constructed.
# 	Epsilon: 19.1514199175470488
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9641999999999999
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  42
# 	Trajectories constructed.
# 	Epsilon: 19.1343328635709327
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9604000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  43
# 	Trajectories constructed.
# 	Epsilon: 19.1180716184834942
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9654000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  44
# 	Trajectories constructed.
# 	Epsilon: 19.1002630556428841
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9646000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  45
# 	Trajectories constructed.
# 	Epsilon: 19.0833105961092144
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9600000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  46
# 	Trajectories constructed.
# 	Epsilon: 19.0643215610592520
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9644000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  47
# 	Trajectories constructed.
# 	Epsilon: 19.0442098586159076
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9658000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  48
# 	Trajectories constructed.
# 	Epsilon: 19.0241751098104288
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9690000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  49
# 	Trajectories constructed.
# 	Epsilon: 19.0029308560973966
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9671999999999999
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  50
# 	Trajectories constructed.
# 	Epsilon: 18.9816273357869747
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9746000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  51
# 	Trajectories constructed.
# 	Epsilon: 18.9581416579451876
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9656000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  52
# 	Trajectories constructed.
# 	Epsilon: 18.9357755739886464
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9716000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  53
# 	Trajectories constructed.
# 	Epsilon: 18.9129094730432072
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9716000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  54
# 	Trajectories constructed.
# 	Epsilon: 18.8884504890110918
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9658000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  55
# 	Trajectories constructed.
# 	Epsilon: 18.8620327726190098
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9674000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  56
# 	Trajectories constructed.
# 	Epsilon: 18.8357838230405363
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9608000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  57
# 	Trajectories constructed.
# 	Epsilon: 18.8090597361405720
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9666000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  58
# 	Trajectories constructed.
# 	Epsilon: 18.7816690909926081
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9722000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  59
# 	Trajectories constructed.
# 	Epsilon: 18.7515377424615615
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9616000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  60
# 	Trajectories constructed.
# 	Epsilon: 18.7226091107649637
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9666000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  61
# 	Trajectories constructed.
# 	Epsilon: 18.6948773155831276
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9668000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  62
# 	Trajectories constructed.
# 	Epsilon: 18.6671586491214185
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9708000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  63
# 	Trajectories constructed.
# 	Epsilon: 18.6367969500586348
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9668000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  64
# 	Trajectories constructed.
# 	Epsilon: 18.6059018247482904
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9638000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  65
# 	Trajectories constructed.
# 	Epsilon: 18.5724159925178505
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9654000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  66
# 	Trajectories constructed.
# 	Epsilon: 18.5358836167876397
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9666000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  67
# 	Trajectories constructed.
# 	Epsilon: 18.4988264634125557
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9686000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  68
# 	Trajectories constructed.
# 	Epsilon: 18.4569762398775197
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9628000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  69
# 	Trajectories constructed.
# 	Epsilon: 18.4110481187262245
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9588000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  70
# 	Trajectories constructed.
# 	Epsilon: 18.3719062196599836
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9651999999999999
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  71
# 	Trajectories constructed.
# 	Epsilon: 18.3347711924396251
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9700000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  72
# 	Trajectories constructed.
# 	Epsilon: 18.2903506300723961
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9678000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  73
# 	Trajectories constructed.
# 	Epsilon: 18.2492815709873462
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9676000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  74
# 	Trajectories constructed.
# 	Epsilon: 18.2105834677180951
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9714000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  75
# 	Trajectories constructed.
# 	Epsilon: 18.1717338711550376
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9684000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  76
# 	Trajectories constructed.
# 	Epsilon: 18.1289625661015137
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9646000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  77
# 	Trajectories constructed.
# 	Epsilon: 18.0830944698766842
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9676000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  78
# 	Trajectories constructed.
# 	Epsilon: 18.0349697975510210
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9654000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  79
# 	Trajectories constructed.
# 	Epsilon: 17.9866542614293721
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9666000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  80
# 	Trajectories constructed.
# 	Epsilon: 17.9359730579222401
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9631999999999999
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  81
# 	Trajectories constructed.
# 	Epsilon: 17.8867561977012457
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9688000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  82
# 	Trajectories constructed.
# 	Epsilon: 17.8374303811512718
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9716000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  83
# 	Trajectories constructed.
# 	Epsilon: 17.7830995412873420
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9688000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  84
# 	Trajectories constructed.
# 	Epsilon: 17.7275652117796056
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9668000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  85
# 	Trajectories constructed.
# 	Epsilon: 17.6761305922725569
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9716000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  86
# 	Trajectories constructed.
# 	Epsilon: 17.6206008529498881
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9702000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  87
# 	Trajectories constructed.
# 	Epsilon: 17.5602450006498856
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9684000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  88
# 	Trajectories constructed.
# 	Epsilon: 17.5019959288426463
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9708000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  89
# 	Trajectories constructed.
# 	Epsilon: 17.4415723899092150
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9684000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  90
# 	Trajectories constructed.
# 	Epsilon: 17.3782564465531806
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9630000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  91
# 	Trajectories constructed.
# 	Epsilon: 17.3175563028081712
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9694000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  92
# 	Trajectories constructed.
# 	Epsilon: 17.2424225613232132
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9641999999999999
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  93
# 	Trajectories constructed.
# 	Epsilon: 17.1697045256635406
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9724000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  94
# 	Trajectories constructed.
# 	Epsilon: 17.0950582233048571
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9640000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  95
# 	Trajectories constructed.
# 	Epsilon: 17.0269024312270396
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9686000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  96
# 	Trajectories constructed.
# 	Epsilon: 16.9554926418933114
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9656000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  97
# 	Trajectories constructed.
# 	Epsilon: 16.8741704076755141
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9690000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  98
# 	Trajectories constructed.
# 	Epsilon: 16.7920623736232422
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9712000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  99
# 	Trajectories constructed.
# 	Epsilon: 16.7033356897978962
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9716000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  100
# 	Trajectories constructed.
# 	Epsilon: 16.6145535087341614
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9690000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  101
# 	Trajectories constructed.
# 	Epsilon: 16.5229480066924808
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9630000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  102
# 	Trajectories constructed.
# 	Epsilon: 16.4250760411020131
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9714000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  103
# 	Trajectories constructed.
# 	Epsilon: 16.3300875853411291
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9708000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  104
# 	Trajectories constructed.
# 	Epsilon: 16.2258645696968387
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9708000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  105
# 	Trajectories constructed.
# 	Epsilon: 16.1235627896844598
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9708000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  106
# 	Trajectories constructed.
# 	Epsilon: 16.0200582636588820
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9684000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  107
# 	Trajectories constructed.
# 	Epsilon: 15.9137183403144640
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9694000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  108
# 	Trajectories constructed.
# 	Epsilon: 15.8083717155517824
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9746000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  109
# 	Trajectories constructed.
# 	Epsilon: 15.6982057997749287
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9670000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  110
# 	Trajectories constructed.
# 	Epsilon: 15.5778320565739961
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9636000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  111
# 	Trajectories constructed.
# 	Epsilon: 15.4457447137304680
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9661999999999999
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  112
# 	Trajectories constructed.
# 	Epsilon: 15.3146495501665463
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9658000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  113
# 	Trajectories constructed.
# 	Epsilon: 15.1715314186856016
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9668000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  114
# 	Trajectories constructed.
# 	Epsilon: 15.0299339706668498
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9654000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  115
# 	Trajectories constructed.
# 	Epsilon: 14.8949698688857701
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9692000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  116
# 	Trajectories constructed.
# 	Epsilon: 14.7718815425315668
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9696000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  117
# 	Trajectories constructed.
# 	Epsilon: 14.6491623267850013
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9676000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  118
# 	Trajectories constructed.
# 	Epsilon: 14.5254496283052408
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9661999999999999
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  119
# 	Trajectories constructed.
# 	Epsilon: 14.3936543299817306
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9608000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  120
# 	Trajectories constructed.
# 	Epsilon: 14.2614855640818003
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9680000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  121
# 	Trajectories constructed.
# 	Epsilon: 14.1498589897023059
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9681999999999999
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  122
# 	Trajectories constructed.
# 	Epsilon: 14.0413777575919045
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9698000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  123
# 	Trajectories constructed.
# 	Epsilon: 13.9293456499063311
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9636000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  124
# 	Trajectories constructed.
# 	Epsilon: 13.8276470417383130
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9646000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  125
# 	Trajectories constructed.
# 	Epsilon: 13.7227274780115032
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9648000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  126
# 	Trajectories constructed.
# 	Epsilon: 13.6160390458797043
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9634000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  127
# 	Trajectories constructed.
# 	Epsilon: 13.5084942607386491
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9636000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  128
# 	Trajectories constructed.
# 	Epsilon: 13.4072598982827298
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9660000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  129
# 	Trajectories constructed.
# 	Epsilon: 13.2985921125253999
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9600000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  130
# 	Trajectories constructed.
# 	Epsilon: 13.2075022121368146
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9594000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  131
# 	Trajectories constructed.
# 	Epsilon: 13.1116173872512487
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9671999999999999
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  132
# 	Trajectories constructed.
# 	Epsilon: 13.0234830364302265
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9624000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  133
# 	Trajectories constructed.
# 	Epsilon: 12.9420556498539323
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9660000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  134
# 	Trajectories constructed.
# 	Epsilon: 12.8591620736489336
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9610000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  135
# 	Trajectories constructed.
# 	Epsilon: 12.7877515541585680
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9661999999999999
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  136
# 	Trajectories constructed.
# 	Epsilon: 12.7126076392115017
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9610000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  137
# 	Trajectories constructed.
# 	Epsilon: 12.6317118049943957
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9594000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  138
# 	Trajectories constructed.
# 	Epsilon: 12.5589387112465971
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9592000000000001
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  139
# 	Trajectories constructed.
# 	Epsilon: 12.4976913036667074
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9610000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  140
# 	Trajectories constructed.
# 	Epsilon: 12.4287732234456243
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9494000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  141
# 	Trajectories constructed.
# 	Epsilon: 12.3704098125340867
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9592000000000001
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  142
# 	Trajectories constructed.
# 	Epsilon: 12.3194582184826693
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9614000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  143
# 	Trajectories constructed.
# 	Epsilon: 12.2674048862026126
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9534000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  144
# 	Trajectories constructed.
# 	Epsilon: 12.2186795769747931
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9572000000000001
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  145
# 	Trajectories constructed.
# 	Epsilon: 12.1730839583342814
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9516000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  146
# 	Trajectories constructed.
# 	Epsilon: 12.1287480867185185
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9530000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  147
# 	Trajectories constructed.
# 	Epsilon: 12.0842150302693998
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9512000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  148
# 	Trajectories constructed.
# 	Epsilon: 12.0402135247979629
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9548000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  149
# 	Trajectories constructed.
# 	Epsilon: 11.9969002054860603
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9524000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  150
# 	Trajectories constructed.
# 	Epsilon: 11.9583233752230775
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9502000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  151
# 	Trajectories constructed.
# 	Epsilon: 11.9189307496968837
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9552000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  152
# 	Trajectories constructed.
# 	Epsilon: 11.8840022736423272
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9546000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  153
# 	Trajectories constructed.
# 	Epsilon: 11.8492429150255578
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9466000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  154
# 	Trajectories constructed.
# 	Epsilon: 11.8127814479521422
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9484000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  155
# 	Trajectories constructed.
# 	Epsilon: 11.7620721456738302
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9426000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  156
# 	Trajectories constructed.
# 	Epsilon: 11.7195248934389422
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9524000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  157
# 	Trajectories constructed.
# 	Epsilon: 11.6887708562652683
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9496000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  158
# 	Trajectories constructed.
# 	Epsilon: 11.6626395578263704
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9452000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  159
# 	Trajectories constructed.
# 	Epsilon: 11.6353195898484465
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9438000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  160
# 	Trajectories constructed.
# 	Epsilon: 11.6132655383105980
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9542000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  161
# 	Trajectories constructed.
# 	Epsilon: 11.5892453090364835
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9378000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  162
# 	Trajectories constructed.
# 	Epsilon: 11.5646008382267880
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9458000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  163
# 	Trajectories constructed.
# 	Epsilon: 11.5401707233188819
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9488000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  164
# 	Trajectories constructed.
# 	Epsilon: 11.5178343744778964
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9462000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  165
# 	Trajectories constructed.
# 	Epsilon: 11.4958769374996308
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9444000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  166
# 	Trajectories constructed.
# 	Epsilon: 11.4719813897082510
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9330000000000001
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  167
# 	Trajectories constructed.
# 	Epsilon: 11.4504303179869105
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9388000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  168
# 	Trajectories constructed.
# 	Epsilon: 11.4327138498089713
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9340000000000001
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  169
# 	Trajectories constructed.
# 	Epsilon: 11.4135004888633951
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9386000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  170
# 	Trajectories constructed.
# 	Epsilon: 11.3944317644135289
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9372000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  171
# 	Trajectories constructed.
# 	Epsilon: 11.3751151674414395
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9372000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  172
# 	Trajectories constructed.
# 	Epsilon: 11.3569343818973696
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9378000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  173
# 	Trajectories constructed.
# 	Epsilon: 11.3389185772873979
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9298000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  174
# 	Trajectories constructed.
# 	Epsilon: 11.3221385379378585
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9288000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  175
# 	Trajectories constructed.
# 	Epsilon: 11.3085603858523065
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9388000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  176
# 	Trajectories constructed.
# 	Epsilon: 11.2954048148255985
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9370000000000001
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  177
# 	Trajectories constructed.
# 	Epsilon: 11.2809179048719521
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9268000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  178
# 	Trajectories constructed.
# 	Epsilon: 11.2682061062973506
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9302000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  179
# 	Trajectories constructed.
# 	Epsilon: 11.2559754738997437
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9332000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  180
# 	Trajectories constructed.
# 	Epsilon: 11.2439656804526891
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9210000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  181
# 	Trajectories constructed.
# 	Epsilon: 11.2336882953804356
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9419999999999999
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  182
# 	Trajectories constructed.
# 	Epsilon: 11.2199540370552846
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9170000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  183
# 	Trajectories constructed.
# 	Epsilon: 11.2070402302297971
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9186000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  184
# 	Trajectories constructed.
# 	Epsilon: 11.1940636079272320
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9152000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  185
# 	Trajectories constructed.
# 	Epsilon: 11.1815073316553040
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9137999999999999
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  186
# 	Trajectories constructed.
# 	Epsilon: 11.1722481625661931
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9302000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  187
# 	Trajectories constructed.
# 	Epsilon: 11.1637104611106537
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9292000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  188
# 	Trajectories constructed.
# 	Epsilon: 11.1527762875061551
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9050000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  189
# 	Trajectories constructed.
# 	Epsilon: 11.1449749140308416
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9226000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  190
# 	Trajectories constructed.
# 	Epsilon: 11.1373365950964942
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9120000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  191
# 	Trajectories constructed.
# 	Epsilon: 11.1291191877996436
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9116000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  192
# 	Trajectories constructed.
# 	Epsilon: 11.1213832021947781
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9100000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  193
# 	Trajectories constructed.
# 	Epsilon: 11.1134570411999647
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9078000000000001
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  194
# 	Trajectories constructed.
# 	Epsilon: 11.1062565334046592
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9198000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  195
# 	Trajectories constructed.
# 	Epsilon: 11.0980582738071067
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9044000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  196
# 	Trajectories constructed.
# 	Epsilon: 11.0898524183077551
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9286000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  197
# 	Trajectories constructed.
# 	Epsilon: 11.0808137703068201
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9126000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  198
# 	Trajectories constructed.
# 	Epsilon: 11.0726559928202839
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8954000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  199
# 	Trajectories constructed.
# 	Epsilon: 11.0661555560756533
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9080000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  200
# 	Trajectories constructed.
# 	Epsilon: 11.0594289518221309
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8978000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  201
# 	Trajectories constructed.
# 	Epsilon: 11.0531909087658775
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8888000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  202
# 	Trajectories constructed.
# 	Epsilon: 11.0468767096114213
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9014000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  203
# 	Trajectories constructed.
# 	Epsilon: 11.0409270446764527
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8890000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  204
# 	Trajectories constructed.
# 	Epsilon: 11.0349163661776188
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8778000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  205
# 	Trajectories constructed.
# 	Epsilon: 11.0286597858577569
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8942000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  206
# 	Trajectories constructed.
# 	Epsilon: 11.0215076699697168
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8952000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  207
# 	Trajectories constructed.
# 	Epsilon: 11.0149667093758055
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8866000000000001
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  208
# 	Trajectories constructed.
# 	Epsilon: 11.0085379768915406
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8905999999999999
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  209
# 	Trajectories constructed.
# 	Epsilon: 11.0028562006449508
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9058000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  210
# 	Trajectories constructed.
# 	Epsilon: 10.9975306805369133
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# ...
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9136000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  284
# 	Trajectories constructed.
# 	Epsilon: 9.8370404923985362
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8964000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  285
# 	Trajectories constructed.
# 	Epsilon: 9.8309297968756670
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8984000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  286
# 	Trajectories constructed.
# 	Epsilon: 9.8249248199238295
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8804000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  287
# 	Trajectories constructed.
# 	Epsilon: 9.8197887465351918
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8764000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  288
# 	Trajectories constructed.
# 	Epsilon: 9.8141530592652071
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8752000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  289
# 	Trajectories constructed.
# 	Epsilon: 9.8089199281090504
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9074000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  290
# 	Trajectories constructed.
# 	Epsilon: 9.8039565749200719
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8782000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  291
# 	Trajectories constructed.
# 	Epsilon: 9.7981181500716890
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8930000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  292
# 	Trajectories constructed.
# 	Epsilon: 9.7921362027389556
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8956000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  293
# 	Trajectories constructed.
# 	Epsilon: 9.7881275682439099
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8600000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  294
# 	Trajectories constructed.
# 	Epsilon: 9.7835890571490918
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8746000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  295
# 	Trajectories constructed.
# 	Epsilon: 9.7768314863210364
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8692000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  296
# 	Trajectories constructed.
# 	Epsilon: 9.7722038085108682
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8838000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  297
# 	Trajectories constructed.
# 	Epsilon: 9.7669889892456041
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8760000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  298
# 	Trajectories constructed.
# 	Epsilon: 9.7622404321435727
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8838000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  299
# 	Trajectories constructed.
# 	Epsilon: 9.7577000571670709
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8430000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  300
# 	Trajectories constructed.
# 	Epsilon: 9.7535610653744840
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8710000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  301
# 	Trajectories constructed.
# 	Epsilon: 9.7487973654751983
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8600000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  302
# 	Trajectories constructed.
# 	Epsilon: 9.7448158167509522
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8612000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  303
# 	Trajectories constructed.
# 	Epsilon: 9.7417896992967297
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8712000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  304
# 	Trajectories constructed.
# 	Epsilon: 9.7373960900629637
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8518000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  305
# 	Trajectories constructed.
# 	Epsilon: 9.7338738026092884
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8592000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  306
# 	Trajectories constructed.
# 	Epsilon: 9.7308534049125708
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8608000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  307
# 	Trajectories constructed.
# 	Epsilon: 9.7275799882066334
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8718000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  308
# 	Trajectories constructed.
# 	Epsilon: 9.7241635705763816
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8633999999999999
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  309
# 	Trajectories constructed.
# 	Epsilon: 9.7214719395512645
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8590000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  310
# 	Trajectories constructed.
# 	Epsilon: 9.7182854920651032
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8512000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  311
# 	Trajectories constructed.
# 	Epsilon: 9.7151393588402328
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8588000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  312
# 	Trajectories constructed.
# 	Epsilon: 9.7118467320555428
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8398000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  313
# 	Trajectories constructed.
# 	Epsilon: 9.7082148711265415
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8408000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  314
# 	Trajectories constructed.
# 	Epsilon: 9.7047840466008886
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8526000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  315
# 	Trajectories constructed.
# 	Epsilon: 9.7014738144908961
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8610000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  316
# 	Trajectories constructed.
# 	Epsilon: 9.6984354899478955
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8584000000000001
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  317
# 	Trajectories constructed.
# 	Epsilon: 9.6955430878650244
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8370000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  318
# 	Trajectories constructed.
# 	Epsilon: 9.6930785434841962
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8444000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  319
# 	Trajectories constructed.
# 	Epsilon: 9.6901555001300110
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8556000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  320
# 	Trajectories constructed.
# 	Epsilon: 9.6864728646569489
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8520000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  321
# 	Trajectories constructed.
# 	Epsilon: 9.6833325140498943
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8274000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  322
# 	Trajectories constructed.
# 	Epsilon: 9.6811737340104784
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8484000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  323
# 	Trajectories constructed.
# 	Epsilon: 9.6782012828137702
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8666000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  324
# 	Trajectories constructed.
# 	Epsilon: 9.6725521753769890
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8440000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  325
# 	Trajectories constructed.
# 	Epsilon: 9.6694921286842828
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8228000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  326
# 	Trajectories constructed.
# 	Epsilon: 9.6670082734614411
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8290000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  327
# 	Trajectories constructed.
# 	Epsilon: 9.6641667969530474
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8594000000000001
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  328
# 	Trajectories constructed.
# 	Epsilon: 9.6597123457387468
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8336000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  329
# 	Trajectories constructed.
# 	Epsilon: 9.6571336982752811
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8456000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  330
# 	Trajectories constructed.
# 	Epsilon: 9.6542600658943982
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8348000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  331
# 	Trajectories constructed.
# 	Epsilon: 9.6516795622031619
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8442000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  332
# 	Trajectories constructed.
# 	Epsilon: 9.6484288875207778
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8270000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  333
# 	Trajectories constructed.
# 	Epsilon: 9.6457325853951019
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8302000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  334
# 	Trajectories constructed.
# 	Epsilon: 9.6432239001420434
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8490000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  335
# 	Trajectories constructed.
# 	Epsilon: 9.6404731303983269
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8490000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  336
# 	Trajectories constructed.
# 	Epsilon: 9.6375615922717124
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8400000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  337
# 	Trajectories constructed.
# 	Epsilon: 9.6341300741089739
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8314000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  338
# 	Trajectories constructed.
# 	Epsilon: 9.6299974123760279
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8411999999999999
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  339
# 	Trajectories constructed.
# 	Epsilon: 9.6264482713936737
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8381999999999999
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  340
# 	Trajectories constructed.
# 	Epsilon: 9.6236602371761197
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8390000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  341
# 	Trajectories constructed.
# 	Epsilon: 9.6194062458333587
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8302000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  342
# 	Trajectories constructed.
# 	Epsilon: 9.6140029375615548
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8494000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  343
# 	Trajectories constructed.
# 	Epsilon: 9.6102230470404884
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8466000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  344
# 	Trajectories constructed.
# 	Epsilon: 9.6070139393078051
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8058000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  345
# 	Trajectories constructed.
# 	Epsilon: 9.6036932264438466
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8431999999999999
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  346
# 	Trajectories constructed.
# 	Epsilon: 9.6002856723068568
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8502000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  347
# 	Trajectories constructed.
# 	Epsilon: 9.5964348700665578
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8658000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  348
# 	Trajectories constructed.
# 	Epsilon: 9.5930983418025022
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8394000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  349
# 	Trajectories constructed.
# 	Epsilon: 9.5904573787686438
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8692000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  350
# 	Trajectories constructed.
# 	Epsilon: 9.5876995590873904
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8680000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  351
# 	Trajectories constructed.
# 	Epsilon: 9.5828297222662453
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8194000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  352
# 	Trajectories constructed.
# 	Epsilon: 9.5776920342058247
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8572000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  353
# 	Trajectories constructed.
# 	Epsilon: 9.5717079368596387
# ValueError was raised:

# %% [markdown]
# # Testing Things
