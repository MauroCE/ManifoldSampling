# %% [markdown]
# The aim of this experiment is simply to test that MS-RWM outperforms MS-RWM on the G and K example.

# %%
import numpy as np
from numpy.random import rand, randn
from numpy import ones, exp, log, diag, vstack, pi, array, r_, isfinite, logspace, zeros, eye, quantile
from numpy.linalg import norm, solve
from numpy.random import default_rng, choice, randint
from scipy.optimize import fsolve
from scipy.stats import multivariate_normal as MVN
from scipy.special import ndtri, ndtr
from scipy.stats import uniform as udist
from scipy.stats import norm as ndist
from scipy.linalg import block_diag

import time
from math import prod
from warnings import catch_warnings, filterwarnings, resetwarnings


import matplotlib.pyplot as plt
from matplotlib import rc
from ipywidgets.widgets import interact


from RWM import RWM
from Manifolds.Manifold import Manifold
from Manifolds.GKManifoldNew import GKManifold, data_generator, find_point_on_manifold, find_point_on_manifold_from_θ
from markov_snippets import MSAdaptiveTolerancesAdaptiveδ, MSAdaptiveTolerancesAdaptiveδSwitchIntegrator
from markov_snippets import SMCAdaptiveTolerancesAdaptiveδ
# from tangential_hug_functions import HugTangentialMultivariate
# from utils import ESS_univariate, prep_contour
from copy import deepcopy

# %% [markdown]
# # G and K settings

# %%
def generate_setting(m, B, δ, N, ϵ0=20, thinning=10, thug=True, verbose=True, initialization='init_RWMϵ0', burnin=100, δ0=0.01, kernel_type='uniform', ϵmin=1e-4, quantile_value=0.01, maxiter=50, ϵprop_switch=0.05, pmoved_switch=0.15, switch_strategy='ap', δmin=1e-4, δmax=100.0, ap_target=0.3, use_autograd=False, init_manifold_prior=True):
    """Generates an object from which one can grab the settings. This allows one to run multiple scenarios."""
    θ0        = array([3.0, 1.0, 2.0, 0.5])      # True parameter value on U(0, 10) scale.
    d         = 4 + m                            # Dimensionality of ξ=(θ, z)
    ystar     = data_generator(θ0, m, seed=1234) # Observed data
    q         = MVN(zeros(d), eye(d))            # Proposal distribution for THUG
    ξ0        = find_point_on_manifold_from_θ(ystar=ystar, θfixed=ndtri(θ0/10), ϵ=1e-5, maxiter=5000, tol=1e-15, kernel_type=kernel_type)
    resetwarnings()
    manifold  = GKManifold(ystar, kernel_type=kernel_type, use_autograd=use_autograd)
    if δ0 is None:
        δ0 = δ
    return {
        'θ0': θ0,
        'm' : m,
        'd' : d,
        'ystar': ystar,
        'q': q,
        'ξ0': ξ0,
        'B': B,
        'δ': δ,
        'N': N,
        'manifold': manifold,
        'thinning': thinning,
        'thug': thug,
        'verbose': verbose,
        'initialization': initialization,
        'burnin': burnin,
        'δ0': δ0,
        'kernel_type': kernel_type,
        'ϵmin': ϵmin,
        'quantile_value': quantile_value,
        'maxiter': maxiter,
        'ϵprop_switch': ϵprop_switch,
        'pmoved_switch': pmoved_switch,
        'switch_strategy': switch_strategy,
        'δmin': δmin,
        'δmax': δmax,
        'ap_target': ap_target,
        'ϵ0': ϵ0,
        'use_autograd': use_autograd,
        'init_manifold_prior': init_manifold_prior
    }

# %%
SETTINGS = generate_setting(
    m=50, 
    B=20, 
    δ=0.01, 
    N=5000, 
    thinning=10, 
    δ0=0.01, 
    kernel_type='uniform', 
    thug=False, 
    verbose=True, 
    initialization='init_prior', 
    burnin=100, 
    maxiter=100, 
    ϵmin=1e-8, 
    quantile_value=0.9,
    δmin=1e-3, 
    δmax=10.0, 
    ap_target=0.2
)

# %% [markdown]
# # SMC-RWM

# %%
SMC_RWM = SMCAdaptiveTolerancesAdaptiveδ(SETTINGS)
_ = SMC_RWM.sample()
# Out:
# Kernel: RWM.
# Initializing particles from prior.
# Initial Epsilon: {:.3f} 7714535797754.47
# Iteration:  1
# 	Particles resampled.
# 	Epsilon: 655160424.777918
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.81420000
# 	Step-size adapted to: 0.01359477
# Iteration:  2
# 	Particles resampled.
# 	Epsilon: 123666528.952347
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.75660000
# 	Step-size adapted to: 0.01795709
# Iteration:  3
# 	Particles resampled.
# 	Epsilon: 29984766.918943
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.72640000
# 	Step-size adapted to: 0.02336374
# Iteration:  4
# 	Particles resampled.
# 	Epsilon: 8907587.134207
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.69960000
# 	Step-size adapted to: 0.02999363
# Iteration:  5
# 	Particles resampled.
# 	Epsilon: 1764714.777835
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.70060000
# 	Step-size adapted to: 0.03852414
# Iteration:  6
# 	Particles resampled.
# 	Epsilon: 362327.747505
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.70160000
# 	Step-size adapted to: 0.04950557
# Iteration:  7
# 	Particles resampled.
# 	Epsilon: 53467.715079
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.70860000
# 	Step-size adapted to: 0.06384033
# Iteration:  8
# 	Particles resampled.
# 	Epsilon: 9711.924302
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.70660000
# 	Step-size adapted to: 0.08224356
# Iteration:  9
# 	Particles resampled.
# 	Epsilon: 1791.079202
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.72120000
# 	Step-size adapted to: 0.10672817
# Iteration:  10
# 	Particles resampled.
# 	Epsilon: 482.847198
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.71360000
# 	Step-size adapted to: 0.13797674
# Iteration:  11
# 	Particles resampled.
# 	Epsilon: 311.385680
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.68160000
# 	Step-size adapted to: 0.17554319
# Iteration:  12
# 	Particles resampled.
# 	Epsilon: 274.483849
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.61280000
# 	Step-size adapted to: 0.21578555
# Iteration:  13
# 	Particles resampled.
# 	Epsilon: 251.188665
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.59500000
# 	Step-size adapted to: 0.26290299
# Iteration:  14
# 	Particles resampled.
# 	Epsilon: 218.999452
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.61680000
# 	Step-size adapted to: 0.32381912
# Iteration:  15
# 	Particles resampled.
# 	Epsilon: 152.747667
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.63420000
# 	Step-size adapted to: 0.40233501
# Iteration:  16
# 	Particles resampled.
# 	Epsilon: 79.579965
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.64760000
# 	Step-size adapted to: 0.50324901
# Iteration:  17
# 	Particles resampled.
# 	Epsilon: 48.566298
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.65440000
# 	Step-size adapted to: 0.63161820
# Iteration:  18
# 	Particles resampled.
# 	Epsilon: 47.354538
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.65420000
# 	Step-size adapted to: 0.79265264
# Iteration:  19
# 	Particles resampled.
# 	Epsilon: 47.354534
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.57620000
# 	Step-size adapted to: 0.95669544
# Iteration:  20
# 	Particles resampled.
# 	Epsilon: 47.325738
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.59140000
# 	Step-size adapted to: 1.16349664
# Iteration:  21
# 	Particles resampled.
# 	Epsilon: 45.955591
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.58100000
# 	Step-size adapted to: 1.40766150
# Iteration:  22
# 	Particles resampled.
# 	Epsilon: 38.181326
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.57760000
# 	Step-size adapted to: 1.70017267
# Iteration:  23
# 	Particles resampled.
# 	Epsilon: 33.679920
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.58500000
# 	Step-size adapted to: 2.06107937
# Iteration:  24
# 	Particles resampled.
# 	Epsilon: 33.679920
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.21420000
# 	Step-size adapted to: 2.07576511
# Iteration:  25
# 	Particles resampled.
# 	Epsilon: 33.679919
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.27460000
# 	Step-size adapted to: 2.15465327
# Iteration:  26
# 	Particles resampled.
# 	Epsilon: 33.679914
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.24100000
# 	Step-size adapted to: 2.19927952
# Iteration:  27
# 	Particles resampled.
# 	Epsilon: 33.679828
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.21800000
# 	Step-size adapted to: 2.21916237
# Iteration:  28
# 	Particles resampled.
# 	Epsilon: 33.678563
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.19320000
# 	Step-size adapted to: 2.21163003
# Iteration:  29
# 	Particles resampled.
# 	Epsilon: 33.670150
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.17640000
# 	Step-size adapted to: 2.18568617
# Iteration:  30
# 	Particles resampled.
# 	Epsilon: 33.638469
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.16180000
# 	Step-size adapted to: 2.14433571
# Iteration:  31
# 	Particles resampled.
# 	Epsilon: 33.578092
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.14940000
# 	Step-size adapted to: 2.09076455
# Iteration:  32
# 	Particles resampled.
# 	Epsilon: 33.426511
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.15020000
# 	Step-size adapted to: 2.03934732
# Iteration:  33
# 	Particles resampled.
# 	Epsilon: 33.115692
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.12880000
# 	Step-size adapted to: 1.96802365
# Iteration:  34
# 	Particles resampled.
# 	Epsilon: 32.634295
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.11940000
# 	Step-size adapted to: 1.89028916
# Iteration:  35
# 	Particles resampled.
# 	Epsilon: 31.998949
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.11540000
# 	Step-size adapted to: 1.81199747
# Iteration:  36
# 	Particles resampled.
# 	Epsilon: 31.274032
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.11700000
# 	Step-size adapted to: 1.73833857
# Iteration:  37
# 	Particles resampled.
# 	Epsilon: 30.381654
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.11460000
# 	Step-size adapted to: 1.66567395
# Iteration:  38
# 	Particles resampled.
# 	Epsilon: 29.367300
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.10040000
# 	Step-size adapted to: 1.58475499
# Iteration:  39
# 	Particles resampled.
# 	Epsilon: 28.323020
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.09280000
# 	Step-size adapted to: 1.50204846
# Iteration:  40
# 	Particles resampled.
# 	Epsilon: 27.329522
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.08760000
# 	Step-size adapted to: 1.41996158
# Iteration:  41
# 	Particles resampled.
# 	Epsilon: 26.333926
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.08400000
# 	Step-size adapted to: 1.33994667
# Iteration:  42
# 	Particles resampled.
# 	Epsilon: 25.398622
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.07980000
# 	Step-size adapted to: 1.26178806
# Iteration:  43
# 	Particles resampled.
# 	Epsilon: 24.561696
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.07080000
# 	Step-size adapted to: 1.18285359
# Iteration:  44
# 	Particles resampled.
# 	Epsilon: 23.692388
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.06800000
# 	Step-size adapted to: 1.10730575
# Iteration:  45
# 	Particles resampled.
# 	Epsilon: 23.051907
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.06100000
# 	Step-size adapted to: 1.03296139
# Iteration:  46
# 	Particles resampled.
# 	Epsilon: 22.495577
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.06440000
# 	Step-size adapted to: 0.96524803
# Iteration:  47
# 	Particles resampled.
# 	Epsilon: 21.907011
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.05300000
# 	Step-size adapted to: 0.89684683
# Iteration:  48
# 	Particles resampled.
# 	Epsilon: 21.479243
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.05200000
# 	Step-size adapted to: 0.83287627
# Iteration:  49
# 	Particles resampled.
# 	Epsilon: 21.076392
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.04700000
# 	Step-size adapted to: 0.77153736
# Iteration:  50
# 	Particles resampled.
# 	Epsilon: 20.772332
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.04180000
# 	Step-size adapted to: 0.71286003
# Iteration:  51
# 	Particles resampled.
# 	Epsilon: 20.502106
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.04780000
# 	Step-size adapted to: 0.66062417
# Iteration:  52
# 	Particles resampled.
# 	Epsilon: 20.303882
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.03480000
# 	Step-size adapted to: 0.60824946
# Iteration:  53
# 	Particles resampled.
# 	Epsilon: 20.141447
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.03680000
# 	Step-size adapted to: 0.56058736
# Iteration:  54
# 	Particles resampled.
# 	Epsilon: 20.002283
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.04060000
# 	Step-size adapted to: 0.51764263
# Iteration:  55
# 	Particles resampled.
# 	Epsilon: 19.915983
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.03780000
# 	Step-size adapted to: 0.47731903
# Iteration:  56
# 	Particles resampled.
# 	Epsilon: 19.826663
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.03100000
# 	Step-size adapted to: 0.43864266
# Iteration:  57
# 	Particles resampled.
# 	Epsilon: 19.746924
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.03280000
# 	Step-size adapted to: 0.40346312
# Iteration:  58
# 	Particles resampled.
# 	Epsilon: 19.691659
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.02880000
# 	Step-size adapted to: 0.37036355
# Iteration:  59
# 	Particles resampled.
# 	Epsilon: 19.641523
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.02860000
# 	Step-size adapted to: 0.33994543
# Iteration:  60
# 	Particles resampled.
# 	Epsilon: 19.602687
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.02640000
# 	Step-size adapted to: 0.31168252
# Iteration:  61
# 	Particles resampled.
# 	Epsilon: 19.567134
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.02880000
# 	Step-size adapted to: 0.28611250
# Iteration:  62
# 	Particles resampled.
# 	Epsilon: 19.539910
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.02460000
# 	Step-size adapted to: 0.26208925
# Iteration:  63
# 	Particles resampled.
# 	Epsilon: 19.517050
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.01900000
# 	Step-size adapted to: 0.23941180
# Iteration:  64
# 	Particles resampled.
# 	Epsilon: 19.498996
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.02140000
# 	Step-size adapted to: 0.21895913
# Iteration:  65
# 	Particles resampled.
# 	Epsilon: 19.483482
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.02340000
# 	Step-size adapted to: 0.20045406
# Iteration:  66
# 	Particles resampled.
# 	Epsilon: 19.470865
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.01840000
# 	Step-size adapted to: 0.18305471
# Iteration:  67
# 	Particles resampled.
# 	Epsilon: 19.461074
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.01520000
# 	Step-size adapted to: 0.16689837
# Iteration:  68
# 	Particles resampled.
# 	Epsilon: 19.452626
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.01320000
# 	Step-size adapted to: 0.15201590
# Iteration:  69
# 	Particles resampled.
# 	Epsilon: 19.447550
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.01680000
# 	Step-size adapted to: 0.13870995
# Iteration:  70
# 	Particles resampled.
# 	Epsilon: 19.441349
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.01360000
# 	Step-size adapted to: 0.12636633
# Iteration:  71
# 	Particles resampled.
# 	Epsilon: 19.436468
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.01280000
# 	Step-size adapted to: 0.11507512
# Iteration:  72
# 	Particles resampled.
# 	Epsilon: 19.433182
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.01280000
# 	Step-size adapted to: 0.10479280
# Iteration:  73
# 	Particles resampled.
# 	Epsilon: 19.430392
# 	Weights computed and normalised.

# %% [markdown]
# # Markov Snippets RWM with adaptive step size

# %%
MS_RWM = MSAdaptiveTolerancesAdaptiveδ(SETTINGS)
_ = MS_RWM.sample()
# Out:
# Integrator: RWM.
# Initializing particles from prior.
# Iteration:  1
# 	Trajectories constructed.
# 	Epsilon: 28.721902
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.954
# 	Step-size adapted to: 0.01457613
# Iteration:  2
# 	Trajectories constructed.
# 	Epsilon: 19.702821
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.993
# 	Step-size adapted to: 0.02166689
# Iteration:  3
# 	Trajectories constructed.
# 	Epsilon: 19.361059
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.918
# 	Step-size adapted to: 0.03102785
# Iteration:  4
# 	Trajectories constructed.
# 	Epsilon: 15.689542
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.931
# 	Step-size adapted to: 0.04471393
# Iteration:  5
# 	Trajectories constructed.
# 	Epsilon: 13.430275
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.919
# 	Step-size adapted to: 0.06407057
# Iteration:  6
# 	Trajectories constructed.
# 	Epsilon: 12.340709
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.624
# 	Step-size adapted to: 0.07921654
# Iteration:  7
# 	Trajectories constructed.
# 	Epsilon: 11.743180
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.454
# 	Step-size adapted to: 0.08992582
# Iteration:  8
# 	Trajectories constructed.
# 	Epsilon: 11.338761
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.347
# 	Step-size adapted to: 0.09676497
# Iteration:  9
# 	Trajectories constructed.
# 	Epsilon: 11.026977
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.296
# 	Step-size adapted to: 0.10150267
# Iteration:  10
# 	Trajectories constructed.
# 	Epsilon: 10.658979
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.249
# 	Step-size adapted to: 0.10399940
# Iteration:  11
# 	Trajectories constructed.
# 	Epsilon: 10.354103
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.222
# 	Step-size adapted to: 0.10517074
# Iteration:  12
# 	Trajectories constructed.
# 	Epsilon: 10.196430
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.169
# 	Step-size adapted to: 0.10355316
# Iteration:  13
# 	Trajectories constructed.
# 	Epsilon: 10.080588
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.128
# 	Step-size adapted to: 0.09989155
# Iteration:  14
# 	Trajectories constructed.
# 	Epsilon: 9.977781
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.147
# 	Step-size adapted to: 0.09725974
# Iteration:  15
# 	Trajectories constructed.
# 	Epsilon: 9.885641
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.128
# 	Step-size adapted to: 0.09381128
# Iteration:  16
# 	Trajectories constructed.
# 	Epsilon: 9.796705
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.143
# 	Step-size adapted to: 0.09118452
# Iteration:  17
# 	Trajectories constructed.
# 	Epsilon: 9.712325
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.154
# 	Step-size adapted to: 0.08909339
# Iteration:  18
# 	Trajectories constructed.
# 	Epsilon: 9.614520
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.166
# 	Step-size adapted to: 0.08760912
# Iteration:  19
# 	Trajectories constructed.
# 	Epsilon: 9.511282
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.155
# 	Step-size adapted to: 0.08565992
# Iteration:  20
# 	Trajectories constructed.
# 	Epsilon: 9.426501
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.159
# 	Step-size adapted to: 0.08393017
# Iteration:  21
# 	Trajectories constructed.
# 	Epsilon: 9.325141
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.166
# 	Step-size adapted to: 0.08253192
# Iteration:  22
# 	Trajectories constructed.
# 	Epsilon: 9.218148
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.160
# 	Step-size adapted to: 0.08091386
# Iteration:  23
# 	Trajectories constructed.
# 	Epsilon: 9.103360
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.217
# 	Step-size adapted to: 0.08162088
# Iteration:  24
# 	Trajectories constructed.
# 	Epsilon: 8.994521
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.159
# 	Step-size adapted to: 0.07994869
# Iteration:  25
# 	Trajectories constructed.
# 	Epsilon: 8.895227
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.174
# 	Step-size adapted to: 0.07890820
# Iteration:  26
# 	Trajectories constructed.
# 	Epsilon: 8.808056
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.151
# 	Step-size adapted to: 0.07701384
# Iteration:  27
# 	Trajectories constructed.
# 	Epsilon: 8.724731
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.189
# 	Step-size adapted to: 0.07658376
# Iteration:  28
# 	Trajectories constructed.
# 	Epsilon: 8.648545
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.160
# 	Step-size adapted to: 0.07506730
# Iteration:  29
# 	Trajectories constructed.
# 	Epsilon: 8.576005
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.157
# 	Step-size adapted to: 0.07347058
# Iteration:  30
# 	Trajectories constructed.
# 	Epsilon: 8.500213
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.149
# 	Step-size adapted to: 0.07163509
# Iteration:  31
# 	Trajectories constructed.
# 	Epsilon: 8.430564
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.171
# 	Step-size adapted to: 0.07061800
# Iteration:  32
# 	Trajectories constructed.
# 	Epsilon: 8.347687
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.180
# 	Step-size adapted to: 0.06992933
# Iteration:  33
# 	Trajectories constructed.
# 	Epsilon: 8.267880
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.172
# 	Step-size adapted to: 0.06895024
# Iteration:  34
# 	Trajectories constructed.
# 	Epsilon: 8.191005
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.177
# 	Step-size adapted to: 0.06817549
# Iteration:  35
# 	Trajectories constructed.
# 	Epsilon: 8.107886
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.180
# 	Step-size adapted to: 0.06749038
# Iteration:  36
# 	Trajectories constructed.
# 	Epsilon: 8.020026
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.232
# 	Step-size adapted to: 0.06857206
# Iteration:  37
# 	Trajectories constructed.
# 	Epsilon: 7.917496
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.210
# 	Step-size adapted to: 0.06890888
# Iteration:  38
# 	Trajectories constructed.
# 	Epsilon: 7.813551
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.213
# 	Step-size adapted to: 0.06936519
# Iteration:  39
# 	Trajectories constructed.
# 	Epsilon: 7.717619
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.180
# 	Step-size adapted to: 0.06868873
# Iteration:  40
# 	Trajectories constructed.
# 	Epsilon: 7.627557
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.154
# 	Step-size adapted to: 0.06712020
# Iteration:  41
# 	Trajectories constructed.
# 	Epsilon: 7.558457
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.165
# 	Step-size adapted to: 0.06596901
# Iteration:  42
# 	Trajectories constructed.
# 	Epsilon: 7.486207
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.188
# 	Step-size adapted to: 0.06556127
# Iteration:  43
# 	Trajectories constructed.
# 	Epsilon: 7.423876
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.164
# 	Step-size adapted to: 0.06437885
# Iteration:  44
# 	Trajectories constructed.
# 	Epsilon: 7.363268
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.166
# 	Step-size adapted to: 0.06329999
# Iteration:  45
# 	Trajectories constructed.
# 	Epsilon: 7.298763
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.169
# 	Step-size adapted to: 0.06233263
# Iteration:  46
# 	Trajectories constructed.
# 	Epsilon: 7.226362
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.195
# 	Step-size adapted to: 0.06216456
# Iteration:  47
# 	Trajectories constructed.
# 	Epsilon: 7.140091
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.177
# 	Step-size adapted to: 0.06145991
# Iteration:  48
# 	Trajectories constructed.
# 	Epsilon: 7.045904
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.205
# 	Step-size adapted to: 0.06161375
# Iteration:  49
# 	Trajectories constructed.
# 	Epsilon: 6.953162
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.171
# 	Step-size adapted to: 0.06073895
# Iteration:  50
# 	Trajectories constructed.
# 	Epsilon: 6.866441
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.165
# 	Step-size adapted to: 0.05968526
# Iteration:  51
# 	Trajectories constructed.
# 	Epsilon: 6.813126
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.123
# 	Step-size adapted to: 0.05742531
# Iteration:  52
# 	Trajectories constructed.
# 	Epsilon: 6.770862
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.124
# 	Step-size adapted to: 0.05529514
# Iteration:  53
# 	Trajectories constructed.
# 	Epsilon: 6.726996
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.152
# 	Step-size adapted to: 0.05397306
# Iteration:  54
# 	Trajectories constructed.
# 	Epsilon: 6.684134
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.136
# 	Step-size adapted to: 0.05228372
# Iteration:  55
# 	Trajectories constructed.
# 	Epsilon: 6.639636
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.152
# 	Step-size adapted to: 0.05104385
# Iteration:  56
# 	Trajectories constructed.
# 	Epsilon: 6.586151
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.165
# 	Step-size adapted to: 0.05015835
# Iteration:  57
# 	Trajectories constructed.
# 	Epsilon: 6.540534
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.154
# 	Step-size adapted to: 0.04902278
# Iteration:  58
# 	Trajectories constructed.
# 	Epsilon: 6.488204
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.161
# 	Step-size adapted to: 0.04808571
# Iteration:  59
# 	Trajectories constructed.
# 	Epsilon: 6.439806
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.181
# 	Step-size adapted to: 0.04762154
# Iteration:  60
# 	Trajectories constructed.
# 	Epsilon: 6.383478
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.201
# 	Step-size adapted to: 0.04764535
# Iteration:  61
# 	Trajectories constructed.
# 	Epsilon: 6.298373
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.286
# 	Step-size adapted to: 0.04973879
# Iteration:  62
# 	Trajectories constructed.
# 	Epsilon: 6.144259
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.318
# 	Step-size adapted to: 0.05275112
# Iteration:  63
# 	Trajectories constructed.
# 	Epsilon: 5.990014
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.288
# 	Step-size adapted to: 0.05512399
# Iteration:  64
# 	Trajectories constructed.
# 	Epsilon: 5.879575
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.222
# 	Step-size adapted to: 0.05573371
# Iteration:  65
# 	Trajectories constructed.
# 	Epsilon: 5.801843
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.194
# 	Step-size adapted to: 0.05556676
# Iteration:  66
# 	Trajectories constructed.
# 	Epsilon: 5.734915
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.184
# 	Step-size adapted to: 0.05513502
# Iteration:  67
# 	Trajectories constructed.
# 	Epsilon: 5.674520
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.163
# 	Step-size adapted to: 0.05411358
# Iteration:  68
# 	Trajectories constructed.
# 	Epsilon: 5.612489
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.183
# 	Step-size adapted to: 0.05364483
# Iteration:  69
# 	Trajectories constructed.
# 	Epsilon: 5.546435
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.167
# 	Step-size adapted to: 0.05277223
# Iteration:  70
# 	Trajectories constructed.
# 	Epsilon: 5.486973
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.176
# 	Step-size adapted to: 0.05215318
# Iteration:  71
# 	Trajectories constructed.
# 	Epsilon: 5.431969
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.150
# 	Step-size adapted to: 0.05087568
# Iteration:  72
# 	Trajectories constructed.
# 	Epsilon: 5.378639
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.179
# 	Step-size adapted to: 0.05033422
# Iteration:  73
# 	Trajectories constructed.
# 	Epsilon: 5.331221
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.127
# 	Step-size adapted to: 0.04853014
# Iteration:  74
# 	Trajectories constructed.
# 	Epsilon: 5.291366
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.138
# 	Step-size adapted to: 0.04703938
# Iteration:  75
# 	Trajectories constructed.
# 	Epsilon: 5.253465
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.196
# 	Step-size adapted to: 0.04695478
# Iteration:  76
# 	Trajectories constructed.
# 	Epsilon: 5.202187
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.190
# 	Step-size adapted to: 0.04671125
# Iteration:  77
# 	Trajectories constructed.
# 	Epsilon: 5.137879
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.234
# 	Step-size adapted to: 0.04752164
# Iteration:  78
# 	Trajectories constructed.
# 	Epsilon: 5.068536
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.221
# 	Step-size adapted to: 0.04803285
# Iteration:  79
# 	Trajectories constructed.
# 	Epsilon: 5.019896
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.169
# 	Step-size adapted to: 0.04729408
# Iteration:  80
# 	Trajectories constructed.
# 	Epsilon: 4.979239
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.157
# 	Step-size adapted to: 0.04627885
# Iteration:  81
# 	Trajectories constructed.
# 	Epsilon: 4.944881
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.156
# 	Step-size adapted to: 0.04526278
# Iteration:  82
# 	Trajectories constructed.
# 	Epsilon: 4.910851
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.154
# 	Step-size adapted to: 0.04423804
# Iteration:  83
# 	Trajectories constructed.
# 	Epsilon: 4.882397
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.137
# 	Step-size adapted to: 0.04286626
# Iteration:  84
# 	Trajectories constructed.
# 	Epsilon: 4.855124
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.135
# 	Step-size adapted to: 0.04149965
# Iteration:  85
# 	Trajectories constructed.
# 	Epsilon: 4.829996
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.142
# 	Step-size adapted to: 0.04031748
# Iteration:  86
# 	Trajectories constructed.
# 	Epsilon: 4.803794
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.183
# 	Step-size adapted to: 0.03998423
# Iteration:  87
# 	Trajectories constructed.
# 	Epsilon: 4.770540
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.186
# 	Step-size adapted to: 0.03970135
# Iteration:  88
# 	Trajectories constructed.
# 	Epsilon: 4.729090
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.198
# 	Step-size adapted to: 0.03965770
# Iteration:  89
# 	Trajectories constructed.
# 	Epsilon: 4.693806
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.188
# 	Step-size adapted to: 0.03941652
# Iteration:  90
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [4], in <cell line: 2>()
#       1 MS_RWM = MSAdaptiveTolerancesAdaptiveδ(SETTINGS)
# ----> 2 _ = MS_RWM.sample()
#
# File ~/Documents/University/ManifoldSampling/markov_snippets.py:662, in MSAdaptiveTolerancesAdaptiveδ.sample(self)
#     660 # Compute trajectories
#     661 Z = apply_along_axis(self.ψ, 1, z)                                        # (N, B+1, 2d)
# --> 662 self.ZNK = vstack((self.ZNK, Z.reshape(1, self.N*(self.B+1), 2*self.d)))  # (N(B+1), 2d)
#     663 self.verboseprint("\tTrajectories constructed.")
#     665 # Adaptively choose ϵ
#
# File <__array_function__ internals>:180, in vstack(*args, **kwargs)
#
# File /opt/anaconda3/envs/manifold-sampling/lib/python3.10/site-packages/numpy/core/shape_base.py:282, in vstack(tup)
#     280 if not isinstance(arrs, list):
#     281     arrs = [arrs]
# --> 282 return _nx.concatenate(arrs, 0)
#
# File <__array_function__ internals>:180, in concatenate(*args, **kwargs)
#
# KeyboardInterrupt:
