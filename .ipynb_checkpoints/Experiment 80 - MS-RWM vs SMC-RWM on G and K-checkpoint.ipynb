# %% [markdown]
# The aim of this experiment is simply to test that MS-RWM outperforms MS-RWM on the G and K example.

# %%
import numpy as np
from numpy.random import rand, randn
from numpy import ones, exp, log, diag, vstack, pi, array, r_, isfinite, logspace, zeros, eye, quantile
from numpy.linalg import norm, solve
from numpy.random import default_rng, choice, randint
from scipy.optimize import fsolve
from scipy.stats import multivariate_normal as MVN
from scipy.special import ndtri, ndtr
from scipy.stats import uniform as udist
from scipy.stats import norm as ndist
from scipy.linalg import block_diag

import time
from math import prod
from warnings import catch_warnings, filterwarnings, resetwarnings


import matplotlib.pyplot as plt
from matplotlib import rc
from ipywidgets.widgets import interact


from RWM import RWM
from Manifolds.Manifold import Manifold
from Manifolds.GKManifoldNew import GKManifold, data_generator, find_point_on_manifold, find_point_on_manifold_from_θ
from markov_snippets import MSAdaptiveTolerancesAdaptiveδ, MSAdaptiveTolerancesAdaptiveδSwitchIntegrator
from markov_snippets import SMCAdaptiveTolerancesAdaptiveδ
# from tangential_hug_functions import HugTangentialMultivariate
# from utils import ESS_univariate, prep_contour
from copy import deepcopy

# %% [markdown]
# # G and K settings

# %%
def generate_setting(m, B, δ, N, ϵ0=20, thinning=10, thug=True, verbose=True, initialization='init_RWMϵ0', burnin=100, δ0=0.01, kernel_type='uniform', ϵmin=1e-4, quantile_value=0.01, maxiter=50, ϵprop_switch=0.05, pmoved_switch=0.15, switch_strategy='ap', δmin=1e-4, δmax=100.0, ap_target=0.3, use_autograd=False, init_manifold_prior=True):
    """Generates an object from which one can grab the settings. This allows one to run multiple scenarios."""
    θ0        = array([3.0, 1.0, 2.0, 0.5])      # True parameter value on U(0, 10) scale.
    d         = 4 + m                            # Dimensionality of ξ=(θ, z)
    ystar     = data_generator(θ0, m, seed=1234) # Observed data
    q         = MVN(zeros(d), eye(d))            # Proposal distribution for THUG
    ξ0        = find_point_on_manifold_from_θ(ystar=ystar, θfixed=ndtri(θ0/10), ϵ=1e-5, maxiter=5000, tol=1e-15, kernel_type=kernel_type)
    resetwarnings()
    manifold  = GKManifold(ystar, kernel_type=kernel_type, use_autograd=use_autograd)
    if δ0 is None:
        δ0 = δ
    return {
        'θ0': θ0,
        'm' : m,
        'd' : d,
        'ystar': ystar,
        'q': q,
        'ξ0': ξ0,
        'B': B,
        'δ': δ,
        'N': N,
        'manifold': manifold,
        'thinning': thinning,
        'thug': thug,
        'verbose': verbose,
        'initialization': initialization,
        'burnin': burnin,
        'δ0': δ0,
        'kernel_type': kernel_type,
        'ϵmin': ϵmin,
        'quantile_value': quantile_value,
        'maxiter': maxiter,
        'ϵprop_switch': ϵprop_switch,
        'pmoved_switch': pmoved_switch,
        'switch_strategy': switch_strategy,
        'δmin': δmin,
        'δmax': δmax,
        'ap_target': ap_target,
        'ϵ0': ϵ0,
        'use_autograd': use_autograd,
        'init_manifold_prior': init_manifold_prior
    }

# %%
SETTINGS = generate_setting(
    m=50, 
    B=20, 
    δ=0.01, 
    N=5000, 
    thinning=10, 
    δ0=0.01, 
    kernel_type='uniform', 
    thug=False, 
    verbose=True, 
    initialization='init_prior', 
    burnin=100, 
    maxiter=100, 
    ϵmin=1e-8, 
    quantile_value=0.9,
    δmin=1e-3, 
    δmax=10.0, 
    ap_target=0.2
)

# %% [markdown]
# # SMC-RWM

# %%
SMC_RWM = SMCAdaptiveTolerancesAdaptiveδ(SETTINGS)
_ = SMC_RWM.sample()
# Out:
# Kernel: RWM.
# Initializing particles from prior.
# Initial Epsilon: {:.3f} 7714535797754.47
# Iteration:  1
# 	Particles resampled.
# 	Epsilon: 655160424.777918
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.81420000
# 	Step-size adapted to: 0.01359477
# Iteration:  2
# 	Particles resampled.
# 	Epsilon: 123666528.952347
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.75660000
# 	Step-size adapted to: 0.01795709
# Iteration:  3
# 	Particles resampled.
# 	Epsilon: 29984766.918943
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.72640000
# 	Step-size adapted to: 0.02336374
# Iteration:  4
# 	Particles resampled.
# 	Epsilon: 8907587.134207
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.69960000
# 	Step-size adapted to: 0.02999363
# Iteration:  5
# 	Particles resampled.
# 	Epsilon: 1764714.777835
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.70060000
# 	Step-size adapted to: 0.03852414
# Iteration:  6
# 	Particles resampled.
# 	Epsilon: 362327.747505
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.70160000
# 	Step-size adapted to: 0.04950557
# Iteration:  7
# 	Particles resampled.
# 	Epsilon: 53467.715079
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.70860000
# 	Step-size adapted to: 0.06384033
# Iteration:  8
# 	Particles resampled.
# 	Epsilon: 9711.924302
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.70660000
# 	Step-size adapted to: 0.08224356
# Iteration:  9
# 	Particles resampled.
# 	Epsilon: 1791.079202
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.72120000
# 	Step-size adapted to: 0.10672817
# Iteration:  10
# 	Particles resampled.
# 	Epsilon: 482.847198
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.71360000
# 	Step-size adapted to: 0.13797674
# Iteration:  11
# 	Particles resampled.
# 	Epsilon: 311.385680
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.68160000
# 	Step-size adapted to: 0.17554319
# Iteration:  12
# 	Particles resampled.
# 	Epsilon: 274.483849
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.61280000
# 	Step-size adapted to: 0.21578555
# Iteration:  13
# 	Particles resampled.
# 	Epsilon: 251.188665
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.59500000
# 	Step-size adapted to: 0.26290299
# Iteration:  14
# 	Particles resampled.
# 	Epsilon: 218.999452
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.61680000
# 	Step-size adapted to: 0.32381912
# Iteration:  15
# 	Particles resampled.
# 	Epsilon: 152.747667
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.63420000
# 	Step-size adapted to: 0.40233501
# Iteration:  16
# 	Particles resampled.
# 	Epsilon: 79.579965
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.64760000
# 	Step-size adapted to: 0.50324901
# Iteration:  17
# 	Particles resampled.
# 	Epsilon: 48.566298
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.65440000
# 	Step-size adapted to: 0.63161820
# Iteration:  18
# 	Particles resampled.
# 	Epsilon: 47.354538
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.65420000
# 	Step-size adapted to: 0.79265264
# Iteration:  19
# 	Particles resampled.
# 	Epsilon: 47.354534
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.57620000
# 	Step-size adapted to: 0.95669544
# Iteration:  20
# 	Particles resampled.
# 	Epsilon: 47.325738
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.59140000
# 	Step-size adapted to: 1.16349664
# Iteration:  21
# 	Particles resampled.
# 	Epsilon: 45.955591
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.58100000
# 	Step-size adapted to: 1.40766150
# Iteration:  22
# 	Particles resampled.
# 	Epsilon: 38.181326
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.57760000
# 	Step-size adapted to: 1.70017267
# Iteration:  23
# 	Particles resampled.
# 	Epsilon: 33.679920
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.58500000
# 	Step-size adapted to: 2.06107937
# Iteration:  24
# 	Particles resampled.
# 	Epsilon: 33.679920
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.21420000
# 	Step-size adapted to: 2.07576511
# Iteration:  25
# 	Particles resampled.
# 	Epsilon: 33.679919
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.27460000
# 	Step-size adapted to: 2.15465327
# Iteration:  26
# 	Particles resampled.
# 	Epsilon: 33.679914
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.24100000
# 	Step-size adapted to: 2.19927952
# Iteration:  27
# 	Particles resampled.
# 	Epsilon: 33.679828
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.21800000
# 	Step-size adapted to: 2.21916237
# Iteration:  28
# 	Particles resampled.
# 	Epsilon: 33.678563
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.19320000
# 	Step-size adapted to: 2.21163003
# Iteration:  29
# 	Particles resampled.
# 	Epsilon: 33.670150
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.17640000
# 	Step-size adapted to: 2.18568617
# Iteration:  30
# 	Particles resampled.
# 	Epsilon: 33.638469
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.16180000
# 	Step-size adapted to: 2.14433571
# Iteration:  31
# 	Particles resampled.
# 	Epsilon: 33.578092
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.14940000
# 	Step-size adapted to: 2.09076455
# Iteration:  32
# 	Particles resampled.
# 	Epsilon: 33.426511
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.15020000
# 	Step-size adapted to: 2.03934732
# Iteration:  33
# 	Particles resampled.
# 	Epsilon: 33.115692
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.12880000
# 	Step-size adapted to: 1.96802365
# Iteration:  34
# 	Particles resampled.
# 	Epsilon: 32.634295
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.11940000
# 	Step-size adapted to: 1.89028916
# Iteration:  35
# 	Particles resampled.
# 	Epsilon: 31.998949
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.11540000
# 	Step-size adapted to: 1.81199747
# Iteration:  36
# 	Particles resampled.
# 	Epsilon: 31.274032
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.11700000
# 	Step-size adapted to: 1.73833857
# Iteration:  37
# 	Particles resampled.
# 	Epsilon: 30.381654
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.11460000
# 	Step-size adapted to: 1.66567395
# Iteration:  38
# 	Particles resampled.
# 	Epsilon: 29.367300
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.10040000
# 	Step-size adapted to: 1.58475499
# Iteration:  39
# 	Particles resampled.
# 	Epsilon: 28.323020
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.09280000
# 	Step-size adapted to: 1.50204846
# Iteration:  40
# 	Particles resampled.
# 	Epsilon: 27.329522
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.08760000
# 	Step-size adapted to: 1.41996158
# Iteration:  41
# 	Particles resampled.
# 	Epsilon: 26.333926
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.08400000
# 	Step-size adapted to: 1.33994667
# Iteration:  42
# 	Particles resampled.
# 	Epsilon: 25.398622
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.07980000
# 	Step-size adapted to: 1.26178806
# Iteration:  43
# 	Particles resampled.
# 	Epsilon: 24.561696
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.07080000
# 	Step-size adapted to: 1.18285359
# Iteration:  44
# 	Particles resampled.
# 	Epsilon: 23.692388
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.06800000
# 	Step-size adapted to: 1.10730575
# Iteration:  45
# 	Particles resampled.
# 	Epsilon: 23.051907
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.06100000
# 	Step-size adapted to: 1.03296139
# Iteration:  46
# 	Particles resampled.
# 	Epsilon: 22.495577
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.06440000
# 	Step-size adapted to: 0.96524803
# Iteration:  47
# 	Particles resampled.
# 	Epsilon: 21.907011
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.05300000
# 	Step-size adapted to: 0.89684683
# Iteration:  48
# 	Particles resampled.
# 	Epsilon: 21.479243
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.05200000
# 	Step-size adapted to: 0.83287627
# Iteration:  49
# 	Particles resampled.
# 	Epsilon: 21.076392
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.04700000
# 	Step-size adapted to: 0.77153736
# Iteration:  50
# 	Particles resampled.
# 	Epsilon: 20.772332
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.04180000
# 	Step-size adapted to: 0.71286003
# Iteration:  51
# 	Particles resampled.
# 	Epsilon: 20.502106
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.04780000
# 	Step-size adapted to: 0.66062417
# Iteration:  52
# 	Particles resampled.
# 	Epsilon: 20.303882
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.03480000
# 	Step-size adapted to: 0.60824946
# Iteration:  53
# 	Particles resampled.
# 	Epsilon: 20.141447
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.03680000
# 	Step-size adapted to: 0.56058736
# Iteration:  54
# 	Particles resampled.
# 	Epsilon: 20.002283
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.04060000
# 	Step-size adapted to: 0.51764263
# Iteration:  55
# 	Particles resampled.
# 	Epsilon: 19.915983
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.03780000
# 	Step-size adapted to: 0.47731903
# Iteration:  56
# 	Particles resampled.
# 	Epsilon: 19.826663
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.03100000
# 	Step-size adapted to: 0.43864266
# Iteration:  57
# 	Particles resampled.
# 	Epsilon: 19.746924
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.03280000
# 	Step-size adapted to: 0.40346312
# Iteration:  58
# 	Particles resampled.
# 	Epsilon: 19.691659
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.02880000
# 	Step-size adapted to: 0.37036355
# Iteration:  59
# 	Particles resampled.
# 	Epsilon: 19.641523
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.02860000
# 	Step-size adapted to: 0.33994543
# Iteration:  60
# 	Particles resampled.
# 	Epsilon: 19.602687
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.02640000
# 	Step-size adapted to: 0.31168252
# Iteration:  61
# 	Particles resampled.
# 	Epsilon: 19.567134
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.02880000
# 	Step-size adapted to: 0.28611250
# Iteration:  62
# 	Particles resampled.
# 	Epsilon: 19.539910
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.02460000
# 	Step-size adapted to: 0.26208925
# Iteration:  63
# 	Particles resampled.
# 	Epsilon: 19.517050
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.01900000
# 	Step-size adapted to: 0.23941180
# Iteration:  64
# 	Particles resampled.
# 	Epsilon: 19.498996
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.02140000
# 	Step-size adapted to: 0.21895913
# Iteration:  65
# 	Particles resampled.
# 	Epsilon: 19.483482
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.02340000
# 	Step-size adapted to: 0.20045406
# Iteration:  66
# 	Particles resampled.
# 	Epsilon: 19.470865
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.01840000
# 	Step-size adapted to: 0.18305471
# Iteration:  67
# 	Particles resampled.
# 	Epsilon: 19.461074
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.01520000
# 	Step-size adapted to: 0.16689837
# Iteration:  68
# 	Particles resampled.
# 	Epsilon: 19.452626
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.01320000
# 	Step-size adapted to: 0.15201590
# Iteration:  69
# 	Particles resampled.
# 	Epsilon: 19.447550
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.01680000
# 	Step-size adapted to: 0.13870995
# Iteration:  70
# 	Particles resampled.
# 	Epsilon: 19.441349
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.01360000
# 	Step-size adapted to: 0.12636633
# Iteration:  71
# 	Particles resampled.
# 	Epsilon: 19.436468
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.01280000
# 	Step-size adapted to: 0.11507512
# Iteration:  72
# 	Particles resampled.
# 	Epsilon: 19.433182
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.01280000
# 	Step-size adapted to: 0.10479280
# Iteration:  73
# 	Particles resampled.
# 	Epsilon: 19.430392
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.01440000
# 	Step-size adapted to: 0.09550562
# Iteration:  74
# 	Particles resampled.
# 	Epsilon: 19.427682
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.00920000
# 	Step-size adapted to: 0.08681549
# Iteration:  75
# 	Particles resampled.
# 	Epsilon: 19.425537
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.01000000
# 	Step-size adapted to: 0.07894766
# Iteration:  76
# 	Particles resampled.
# 	Epsilon: 19.423705
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.01120000
# 	Step-size adapted to: 0.07183595
# Iteration:  77
# 	Particles resampled.
# 	Epsilon: 19.422404
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.01260000
# 	Step-size adapted to: 0.06541065
# Iteration:  78
# 	Particles resampled.
# 	Epsilon: 19.421564
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.00820000
# 	Step-size adapted to: 0.05942916
# Iteration:  79
# 	Particles resampled.
# 	Epsilon: 19.420480
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.01100000
# 	Step-size adapted to: 0.05407030
# Iteration:  80
# 	Particles resampled.
# 	Epsilon: 19.419697
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.01020000
# 	Step-size adapted to: 0.04917499
# Iteration:  81
# 	Particles resampled.
# 	Epsilon: 19.419085
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.00900000
# 	Step-size adapted to: 0.04469605
# Iteration:  82
# 	Particles resampled.
# 	Epsilon: 19.418621
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.00760000
# 	Step-size adapted to: 0.04059663
# Iteration:  83
# 	Particles resampled.
# 	Epsilon: 19.418332
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.01040000
# 	Step-size adapted to: 0.03692486
# Iteration:  84
# 	Particles resampled.
# 	Epsilon: 19.417667
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.00880000
# 	Step-size adapted to: 0.03355833
# Iteration:  85
# 	Particles resampled.
# 	Epsilon: 19.417447
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.00760000
# 	Step-size adapted to: 0.03048044
# Iteration:  86
# 	Particles resampled.
# 	Epsilon: 19.417199
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.00860000
# 	Step-size adapted to: 0.02769869
# Iteration:  87
# 	Particles resampled.
# 	Epsilon: 19.416973
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.00820000
# 	Step-size adapted to: 0.02516578
# Iteration:  88
# 	Particles resampled.
# 	Epsilon: 19.416832
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.01000000
# 	Step-size adapted to: 0.02288508
# Iteration:  89
# 	Particles resampled.
# 	Epsilon: 19.416772
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.01240000
# 	Step-size adapted to: 0.02083606
# Iteration:  90
# 	Particles resampled.
# 	Epsilon: 19.416661
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.00960000
# 	Step-size adapted to: 0.01894396
# Iteration:  91
# 	Particles resampled.
# 	Epsilon: 19.416590
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.01300000
# 	Step-size adapted to: 0.01725298
# Iteration:  92
# 	Particles resampled.
# 	Epsilon: 19.416551
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.01140000
# 	Step-size adapted to: 0.01570038
# Iteration:  93
# 	Particles resampled.
# 	Epsilon: 19.416508
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.01240000
# 	Step-size adapted to: 0.01429465
# Iteration:  94
# 	Particles resampled.
# 	Epsilon: 19.416472
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.01520000
# 	Step-size adapted to: 0.01303301
# Iteration:  95
# 	Particles resampled.
# 	Epsilon: 19.416451
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.02520000
# 	Step-size adapted to: 0.01194228
# Iteration:  96
# 	Particles resampled.
# 	Epsilon: 19.395389
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.08500000
# 	Step-size adapted to: 0.01127497
# Iteration:  97
# 	Particles resampled.
# 	Epsilon: 19.353524
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.08540000
# 	Step-size adapted to: 0.01064707
# Iteration:  98
# 	Particles resampled.
# 	Epsilon: 19.290545
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.08940000
# 	Step-size adapted to: 0.01007427
# Iteration:  99
# 	Particles resampled.
# 	Epsilon: 19.228944
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.11920000
# 	Step-size adapted to: 0.00967539
# Iteration:  100
# 	Particles resampled.
# 	Epsilon: 19.179535
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.12340000
# 	Step-size adapted to: 0.00931182

# %% [markdown]
# # Markov Snippets RWM with adaptive step size

# %%
class MSAdaptiveTolerancesAdaptiveδ:

    def __init__(self, SETTINGS):
        """Markov Snippets sampler that can choose between THUG or RWM integrators.
        The sequence of target distributions is NOT fixed here. It is adaptively
        chosen based on the  distribution of distances at the previous round, i.e.
        we choose a small quantile of all the distances.
        The step size is chosen adaptively like in a standard SMC sampler (a la
        Chang) using the proxy for the acceptance probability.

        Tolerances
        ----------
        Adaptively chosen.

        Initialization
        --------------
        We allow for multiple initialization procedures.
            1. init_RWMϵ0:  Starting from x0 ∈ Manifold, sample from ηϵ0 using RWM
                            with some thinning and some burn-in.
            2. init_THUGϵ0: Starting from x0 ∈ Manifold, sample from ηϵ0 using THUG
                            with some thinning and some burn-in.
            3. init_prior: Sample from the prior.

        Parameters
        ----------

        :param SETTINGS: Dictionary containing various variables necessary for
                         running the Markov Snippets algorithm.
        :type SETTINGS: dict
        """
        # Store variables
        self.N  = SETTINGS['N']       # Number of particles
        self.B  = SETTINGS['B']       # Number of integration steps
        self.δ  = SETTINGS['δ']       # Step-size for each integration step
        self.d  = SETTINGS['d']       # Dim of x-component of particle
        self.manifold = SETTINGS['manifold']
        self.SETTINGS = SETTINGS
        self.thug     = SETTINGS['thug']
        self.verbose = SETTINGS['verbose']
        self.verboseprint = print if self.verbose else lambda *a, **k: None
        self.initialization = SETTINGS['initialization']
        self.ϵmin = SETTINGS['ϵmin']
        self.maxiter = SETTINGS['maxiter']
        self.quantile_value = SETTINGS['quantile_value']
        self.ap_target = SETTINGS['ap_target']  # target acceptance probability used to adapt δ
        self.δmin = SETTINGS['δmin']
        self.δmax = SETTINGS['δmax'] # both used for adaptation
        self.init_manifold_prior = SETTINGS['init_manifold_prior']

        # Check arguments
        assert isinstance(self.N,  int), "N must be an integer."
        assert isinstance(self.B, int), "B must be an integer."
        assert isinstance(self.δ, float), "δ must be a float."
        assert isinstance(self.d, int), "d must be an integer."
        assert isinstance(self.thug, bool), "thug must be boolean variable."
        assert isinstance(self.initialization, str), "initialization must be a string."
        assert isinstance(self.ϵmin, float), "ϵmin must be a float."
        assert isinstance(self.maxiter, int), "maxiter must be an integer."
        assert isinstance(self.quantile_value, float), "quantile_value must be float."
        assert self.quantile_value >= 0 and self.quantile_value <= 1, "quantile value must be in [0, 1]."
        assert isinstance(self.ap_target, float), "ap_target must be float."
        assert self.ap_target >= 0 and self.ap_target <= 1, "ap_target must be in [0, 1]."
        assert isinstance(self.δmin, float), "δmin must be float."
        assert isinstance(self.δmax, float), "δmax, must be float."
        assert (0 <= self.δmin) and (self.δmin <= self.δmax), "step sizes must be positive and ordered."



        # Initialize the arrays storing ϵ and logηϵ as empty. If we initialize
        # from a small ϵ0 then we add it (and the corresponding logηϵ0) to the
        # list below. Otherwise, we consider it -np.inf and use the prior instead.
        self.ϵs     = []
        self.log_ηs = []
        self.δs     = [SETTINGS['δ']]

        # Choose correct integrator based on user input
        if self.thug:
            self.verboseprint("Integrator: THUG.")
            self.ψ = generate_THUGIntegrator(self.B, self.δ, self.manifold.fullJacobian)
            self.ψ_generator = lambda B, δ: generate_THUGIntegrator(B, δ, self.manifold.fullJacobian)
        else:
            self.verboseprint("Integrator: RWM.")
            self.ψ = generate_RWMIntegrator(self.B, self.δ)
            self.ψ_generator = generate_RWMIntegrator

        # Choose initialization procedure
        if self.initialization == 'init_RWMϵ0':
            self.initializer = init_RWMϵ0
            self.ϵs.append(SETTINGS['ϵ0'])
            self.log_ηs.append(FilamentaryDistribution(self.manifold.generate_logηϵ, self.ϵs[0]))
        elif self.initialization == 'init_THUGϵ0':
            self.initializer = init_THUGϵ0
            self.ϵs.append(SETTINGS['ϵ0'])
            self.log_ηs.append(FilamentaryDistribution(self.manifold.generate_logηϵ, self.ϵs[0]))
        elif self.initialization == 'init_prior':
            self.initializer = init_prior
            # self.ϵs.append(-np.inf)
            # self.log_ηs.append(FilamentaryDistribution(self.manifold.generate_logprior, -np.inf))
        elif self.initialization == 'init_on_manifold':
            self.initializer = init_on_manifold
            if self.init_manifold_prior:
                self.ϵs.append(-np.inf)
                self.log_ηs.append(FilamentaryDistribution(self.manifold.generate_logprior, -np.inf))
            else:
                self.ϵs.append(SETTINGS['ϵ0'])
                self.log_ηs.append(FilamentaryDistribution(self.manifold.generate_logηϵ, self.ϵs[0]))
        else:
            raise ValueError("Initializer must be one of three options.")

    def initialize_particles(self):
        """Initializes based on the user input. 3 options available, see docs."""
        z0 = self.initializer(self)
        return z0

    def compute_weights_safely(self, log_μnm1_z, log_μn_ψk_z):
        """Safely computes the weights."""
        if False: #self.SETTINGS['kernel_type']  == 'uniform':
#             # Sanity checks
#             assert len(unique(log_μnm1_z)) == 1, "There should be only one value in log_μnm1_z."
#             assert abs(unique(log_μnm1_z)[0]) < np.inf, "Unique value in log_μnm1_z should be finite."
#             assert len(unique(log_μn_ψk_z)) == 2, "There should be only two values in log_μn_ψk_z."
#             # in log_μn_ψk_z one value should be -np.inf, and the other should be finite
#             assert sum(unique(log_μn_ψk_z) == -np.inf) == 1, "One value should be -np.inf in log_μn_ψk_z."
#             assert sum(abs(unique(log_μn_ψk_z)) < np.inf) == 1, "One value should be finite in log_μn_ψk_z."
#             # we must have that the finite value of log_μn_ψk_z is larger than the finite value of log_μnm1_z
#             assert unique(log_μn_ψk_z)[unique(log_μn_ψk_z) > -np.inf][0] >= unique(log_μnm1_z)[unique(log_μnm1_z) > -np.inf][0], "Finite value of log_μn_ψk_z should be larger than finite value of log_μnm1_z."
#             # If all these conditions are true, then it's simple: we just set the weight to 0 when log_μn_ψk_z
#             # is -np.inf, otherwise we set it to 1 / number of non inf.
#             w = zeros(self.N * (self.B + 1))
#             w[log_μn_ψk_z.flatten() != -np.inf] = 1
#             W = w / w.sum()
#             return W
            pass
        else:
            
#             W = exp(log_μn_ψk_z - log_μnm1_z)                                            # (N, B+1)
#             #### Normalize weights
#             W = W / W.sum()
#             return W
            logW    = log_μn_ψk_z - log_μnm1_z
            logsumW = logsumexp(logW)
            return exp(logW - logsumW)

    def sample(self):
        """Starts the Markov Snippets sampler."""
        starting_time = time()
        ## Storage
        #### Store z_n^{(i)}
        self.ZN  = zeros((1, self.N, 2*self.d))
        #### Store z_{n, k}^{(i)} so basically all the N(T+1) particles
        self.ZNK  = zeros((1, self.N*(self.B+1), 2*self.d))
        self.Wbar = zeros(self.N*(self.B+1))
        self.DISTANCES = zeros(self.N) #zeros(self.N*(self.B+1))
        self.ESS  = [self.N]
        self.K_RESAMPLED = zeros(self.N)
        # Store proxy metrics for acceptance probabilities
        self.prop_moved = [] # Stores the proportion of particles with k >= 1
        # Initialize particles
        z = self.initialize_particles()   # (N, 2d)
        self.ZN[0] = z
        # If initializing from the prior, we need to find ϵmax and set ϵ0 to it
        if self.initialization == 'init_prior':
            # compute distances
            distances = norm(apply_along_axis(self.manifold.q, 1, z[:, :self.d]), axis=1)
            self.ϵmax      = np.max(distances)
            self.ϵs.append(self.ϵmax)
            self.log_ηs.append(FilamentaryDistribution(self.manifold.generate_logηϵ, self.ϵmax))
            print("Setting initial epsilon to ϵmax= {:.10f}".format(self.ϵmax))
        # Keep running until an error arises or we reach ϵ_min
        n = 1
        try:
            while (n <= self.maxiter) or abs(self.ϵs[-1]) <= self.ϵmin:
                self.verboseprint("Iteration: ", n)
                # Compute trajectories
                Z = apply_along_axis(self.ψ, 1, z)                                        # (N, B+1, 2d)
                self.ZNK = vstack((self.ZNK, Z.reshape(1, self.N*(self.B+1), 2*self.d)))  # (N(B+1), 2d)
                self.verboseprint("\tTrajectories constructed.")

                # Adaptively choose ϵ
                distances = norm(apply_along_axis(self.manifold.q, 1, z[:, :self.d]), axis=1)
                self.DISTANCES = vstack((self.DISTANCES, distances))
                ϵ = clip(quantile(unique(distances), self.quantile_value), self.ϵmin, self.ϵmax)
                # ϵ = max(self.ϵmin, quantile(unique(distances), self.quantile_value))
                self.ϵs.append(ϵ)
                self.log_ηs.append(FilamentaryDistribution(self.manifold.generate_logηϵ, ϵ))
                self.verboseprint("\tEpsilon: {:.6f}".format(ϵ))

                # Compute weights.
                #### Log-Denominator: shared for each point in the same trajectory
                log_μnm1_z  = apply_along_axis(self.log_ηs[-2], 1, Z[:, 0, :self.d])        # (N, )
                log_μnm1_z  = repeat(log_μnm1_z, self.B+1, axis=0).reshape(self.N, self.B+1) # (N, B+1)
                #### Log-Numerator: different for each point on a trajectory.
                log_μn_ψk_z = apply_along_axis(self.log_ηs[-1], 2, Z[:, :, :self.d])          # (N, B+1)
                #### Put weights together
                # W = exp(log_μn_ψk_z - log_μnm1_z)                                            # (N, B+1)
                # #### Normalize weights
                # W = W / W.sum()
                W = self.compute_weights_safely(log_μnm1_z, log_μn_ψk_z)
                self.verboseprint("\tWeights computed and normalized.")
                # store weights (remember these are \bar{w})
                self.Wbar = vstack((self.Wbar, W.flatten()))
                # compute ESS
                self.ESS.append(1 / np.sum(W**2))
                # Resample down to N particles
                resampling_indeces = choice(a=arange(self.N*(self.B+1)), size=self.N, p=W.flatten())
                unravelled_indeces = unravel_index(resampling_indeces, (self.N, self.B+1))
                self.K_RESAMPLED = vstack((self.K_RESAMPLED, unravelled_indeces[1]))
                indeces = dstack(unravelled_indeces).squeeze()
                z = vstack([Z[tuple(ix)] for ix in indeces])     # (N, 2d)
                self.verboseprint("\tParticles Resampled.")

                # Rejuvenate velocities of N particles
                z[:, self.d:] = normal(loc=0.0, scale=1.0, size=(self.N, self.d))
                self.ZN = vstack((self.ZN, z[None, ...]))
                self.verboseprint("\tVelocities refreshed.")

                # Compute proxy acceptance probabilities
                self.prop_moved.append(sum(self.K_RESAMPLED[-1] >= 1) / self.N)
                self.verboseprint("\tProp Moved: {:.3f}".format(self.prop_moved[-1]))

                # Adapt δ based on proxy acceptance probability
                self.δ = clip(exp(log(self.δ) + 0.5*(self.prop_moved[-1] - self.ap_target)), self.δmin, self.δmax)
                self.δs.append(self.δ)
                self.ψ = self.ψ_generator(self.B, self.δ)
                self.verboseprint("\tStep-size adapted to: {:.8f}".format(self.δ))

                n += 1
            self.total_time = time() - starting_time
        except ValueError as e:
            print("ValueError was raised: ", e)
        return z
# Out:
#   Input In [125]
#     else:
#     ^
# IndentationError: expected an indented block after 'if' statement on line 117

# %%
MS_RWM = MSAdaptiveTolerancesAdaptiveδ(SETTINGS)
_ = MS_RWM.sample()
# Out:
# Integrator: RWM.
# Initializing particles from prior.
# Setting initial epsilon to ϵmax= 26424181035566.8085937500
# Iteration:  1
# 	Trajectories constructed.
# 	Epsilon: 471449396.976745
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.953
# 	Step-size adapted to: 0.01457030
# Iteration:  2
# 	Trajectories constructed.
# 	Epsilon: 52046297.334063
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.954
# 	Step-size adapted to: 0.02124210
# Iteration:  3
# 	Trajectories constructed.
# 	Epsilon: 8953683.404334
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.947
# 	Step-size adapted to: 0.03085766
# Iteration:  4
# 	Trajectories constructed.
# 	Epsilon: 1892404.727969
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.949
# 	Step-size adapted to: 0.04487968
# Iteration:  5
# 	Trajectories constructed.
# 	Epsilon: 418043.914653
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.946
# 	Step-size adapted to: 0.06518211
# Iteration:  6
# 	Trajectories constructed.
# 	Epsilon: 96044.649919
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.949
# 	Step-size adapted to: 0.09481097
# Iteration:  7
# 	Trajectories constructed.
# 	Epsilon: 18520.487989
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.944
# 	Step-size adapted to: 0.13752216
# Iteration:  8
# 	Trajectories constructed.
# 	Epsilon: 3100.997683
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.944
# 	Step-size adapted to: 0.19945429
# Iteration:  9
# 	Trajectories constructed.
# 	Epsilon: 707.869958
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.945
# 	Step-size adapted to: 0.28950863
# Iteration:  10
# 	Trajectories constructed.
# 	Epsilon: 369.512220
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.933
# 	Step-size adapted to: 0.41775080
# Iteration:  11
# 	Trajectories constructed.
# 	Epsilon: 310.852157
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.929
# 	Step-size adapted to: 0.60147507
# Iteration:  12
# 	Trajectories constructed.
# 	Epsilon: 216.010909
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.942
# 	Step-size adapted to: 0.87164749
# Iteration:  13
# 	Trajectories constructed.
# 	Epsilon: 66.987184
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.936
# 	Step-size adapted to: 1.25964485
# Iteration:  14
# 	Trajectories constructed.
# 	Epsilon: 47.354536
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.937
# 	Step-size adapted to: 1.82053391
# Iteration:  15
# 	Trajectories constructed.
# 	Epsilon: 47.354536
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.922
# 	Step-size adapted to: 2.61255799
# Iteration:  16
# 	Trajectories constructed.
# 	Epsilon: 47.354428
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.909
# 	Step-size adapted to: 3.72448957
# Iteration:  17
# 	Trajectories constructed.
# 	Epsilon: 47.301185
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.903
# 	Step-size adapted to: 5.29217764
# Iteration:  18
# 	Trajectories constructed.
# 	Epsilon: 43.967674
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.903
# 	Step-size adapted to: 7.52273534
# Iteration:  19
# 	Trajectories constructed.
# 	Epsilon: 33.679920
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.905
# 	Step-size adapted to: 10.00000000
# Iteration:  20
# 	Trajectories constructed.
# 	Epsilon: 33.679920
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.852
# 	Step-size adapted to: 10.00000000
# Iteration:  21
# 	Trajectories constructed.
# 	Epsilon: 33.679920
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.469
# 	Step-size adapted to: 10.00000000
# Iteration:  22
# 	Trajectories constructed.
# 	Epsilon: 33.679920
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.453
# 	Step-size adapted to: 10.00000000
# Iteration:  23
# 	Trajectories constructed.
# 	Epsilon: 33.679919
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.444
# 	Step-size adapted to: 10.00000000
# Iteration:  24
# 	Trajectories constructed.
# 	Epsilon: 33.679887
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.417
# 	Step-size adapted to: 10.00000000
# Iteration:  25
# 	Trajectories constructed.
# 	Epsilon: 33.679527
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.398
# 	Step-size adapted to: 10.00000000
# Iteration:  26
# 	Trajectories constructed.
# 	Epsilon: 33.677032
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.382
# 	Step-size adapted to: 10.00000000
# Iteration:  27
# 	Trajectories constructed.
# 	Epsilon: 33.659256
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.356
# 	Step-size adapted to: 10.00000000
# Iteration:  28
# 	Trajectories constructed.
# 	Epsilon: 33.606462
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.328
# 	Step-size adapted to: 10.00000000
# Iteration:  29
# 	Trajectories constructed.
# 	Epsilon: 33.464468
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.297
# 	Step-size adapted to: 10.00000000
# Iteration:  30
# 	Trajectories constructed.
# 	Epsilon: 33.149789
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.287
# 	Step-size adapted to: 10.00000000
# Iteration:  31
# 	Trajectories constructed.
# 	Epsilon: 32.613669
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.273
# 	Step-size adapted to: 10.00000000
# Iteration:  32
# 	Trajectories constructed.
# 	Epsilon: 31.886201
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.248
# 	Step-size adapted to: 10.00000000
# Iteration:  33
# 	Trajectories constructed.
# 	Epsilon: 30.903317
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.223
# 	Step-size adapted to: 10.00000000
# Iteration:  34
# 	Trajectories constructed.
# 	Epsilon: 29.832090
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.204
# 	Step-size adapted to: 10.00000000
# Iteration:  35
# 	Trajectories constructed.
# 	Epsilon: 28.777447
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.221
# 	Step-size adapted to: 10.00000000
# Iteration:  36
# 	Trajectories constructed.
# 	Epsilon: 27.617218
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.190
# 	Step-size adapted to: 9.95012479
# Iteration:  37
# 	Trajectories constructed.
# 	Epsilon: 26.591743
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.163
# 	Step-size adapted to: 9.76578639
# Iteration:  38
# 	Trajectories constructed.
# 	Epsilon: 25.536557
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.180
# 	Step-size adapted to: 9.66958211
# Iteration:  39
# 	Trajectories constructed.
# 	Epsilon: 24.522620
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.143
# 	Step-size adapted to: 9.39694929
# Iteration:  40
# 	Trajectories constructed.
# 	Epsilon: 23.732912
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.142
# 	Step-size adapted to: 9.12835126
# Iteration:  41
# 	Trajectories constructed.
# 	Epsilon: 23.053956
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.108
# 	Step-size adapted to: 8.71621508
# Iteration:  42
# 	Trajectories constructed.
# 	Epsilon: 22.573737
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.137
# 	Step-size adapted to: 8.44424457
# Iteration:  43
# 	Trajectories constructed.
# 	Epsilon: 22.081640
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.132
# 	Step-size adapted to: 8.16359873
# Iteration:  44
# 	Trajectories constructed.
# 	Epsilon: 21.606369
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.132
# 	Step-size adapted to: 7.89228021
# Iteration:  45
# 	Trajectories constructed.
# 	Epsilon: 21.227636
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.111
# 	Step-size adapted to: 7.54801861
# Iteration:  46
# 	Trajectories constructed.
# 	Epsilon: 20.916805
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.124
# 	Step-size adapted to: 7.26584857
# Iteration:  47
# 	Trajectories constructed.
# 	Epsilon: 20.605272
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.089
# 	Step-size adapted to: 6.87495497
# Iteration:  48
# 	Trajectories constructed.
# 	Epsilon: 20.378117
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.072
# 	Step-size adapted to: 6.44745251
# Iteration:  49
# 	Trajectories constructed.
# 	Epsilon: 20.201223
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.089
# 	Step-size adapted to: 6.09997756
# Iteration:  50
# 	Trajectories constructed.
# 	Epsilon: 20.056259
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.090
# 	Step-size adapted to: 5.77238357
# Iteration:  51
# 	Trajectories constructed.
# 	Epsilon: 19.948298
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.079
# 	Step-size adapted to: 5.43459550
# Iteration:  52
# 	Trajectories constructed.
# 	Epsilon: 19.845217
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.076
# 	Step-size adapted to: 5.10737255
# Iteration:  53
# 	Trajectories constructed.
# 	Epsilon: 19.773194
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.042
# 	Step-size adapted to: 4.71988811
# Iteration:  54
# 	Trajectories constructed.
# 	Epsilon: 19.705054
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.078
# 	Step-size adapted to: 4.43969239
# Iteration:  55
# 	Trajectories constructed.
# 	Epsilon: 19.650142
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.063
# 	Step-size adapted to: 4.14658495
# Iteration:  56
# 	Trajectories constructed.
# 	Epsilon: 19.611343
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.067
# 	Step-size adapted to: 3.87902989
# Iteration:  57
# 	Trajectories constructed.
# 	Epsilon: 19.574812
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.057
# 	Step-size adapted to: 3.61064018
# Iteration:  58
# 	Trajectories constructed.
# 	Epsilon: 19.544464
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.029
# 	Step-size adapted to: 3.31509106
# Iteration:  59
# 	Trajectories constructed.
# 	Epsilon: 19.525130
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.069
# 	Step-size adapted to: 3.10491113
# Iteration:  60
# 	Trajectories constructed.
# 	Epsilon: 19.508671
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.062
# 	Step-size adapted to: 2.89818620
# Iteration:  61
# 	Trajectories constructed.
# 	Epsilon: 19.491210
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.043
# 	Step-size adapted to: 2.67937911
# Iteration:  62
# 	Trajectories constructed.
# 	Epsilon: 19.474627
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.034
# 	Step-size adapted to: 2.46621625
# Iteration:  63
# 	Trajectories constructed.
# 	Epsilon: 19.464040
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.070
# 	Step-size adapted to: 2.31054885
# Iteration:  64
# 	Trajectories constructed.
# 	Epsilon: 19.454451
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.058
# 	Step-size adapted to: 2.15175781
# Iteration:  65
# 	Trajectories constructed.
# 	Epsilon: 19.446062
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.057
# 	Step-size adapted to: 2.00347885
# Iteration:  66
# 	Trajectories constructed.
# 	Epsilon: 19.440706
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.043
# 	Step-size adapted to: 1.85259080
# Iteration:  67
# 	Trajectories constructed.
# 	Epsilon: 19.435938
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.066
# 	Step-size adapted to: 1.73218756
# Iteration:  68
# 	Trajectories constructed.
# 	Epsilon: 19.432735
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.045
# 	Step-size adapted to: 1.60333381
# Iteration:  69
# 	Trajectories constructed.
# 	Epsilon: 19.429999
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.044
# 	Step-size adapted to: 1.48287844
# Iteration:  70
# 	Trajectories constructed.
# 	Epsilon: 19.427716
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.051
# 	Step-size adapted to: 1.37614360
# Iteration:  71
# 	Trajectories constructed.
# 	Epsilon: 19.425456
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.033
# 	Step-size adapted to: 1.26577565
# Iteration:  72
# 	Trajectories constructed.
# 	Epsilon: 19.423742
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.042
# 	Step-size adapted to: 1.16962723
# Iteration:  73
# 	Trajectories constructed.
# 	Epsilon: 19.422181
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.052
# 	Step-size adapted to: 1.08598248
# Iteration:  74
# 	Trajectories constructed.
# 	Epsilon: 19.421075
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.047
# 	Step-size adapted to: 1.00620426
# Iteration:  75
# 	Trajectories constructed.
# 	Epsilon: 19.420267
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.063
# 	Step-size adapted to: 0.93968092
# Iteration:  76
# 	Trajectories constructed.
# 	Epsilon: 19.419478
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.031
# 	Step-size adapted to: 0.86354013
# Iteration:  77
# 	Trajectories constructed.
# 	Epsilon: 19.418995
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.047
# 	Step-size adapted to: 0.79978294
# Iteration:  78
# 	Trajectories constructed.
# 	Epsilon: 19.418556
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.033
# 	Step-size adapted to: 0.73578678
# Iteration:  79
# 	Trajectories constructed.
# 	Epsilon: 19.418118
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.052
# 	Step-size adapted to: 0.68323603
# Iteration:  80
# 	Trajectories constructed.
# 	Epsilon: 19.417797
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.039
# 	Step-size adapted to: 0.63032803
# Iteration:  81
# 	Trajectories constructed.
# 	Epsilon: 19.417536
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.025
# 	Step-size adapted to: 0.57757619
# Iteration:  82
# 	Trajectories constructed.
# 	Epsilon: 19.417344
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.039
# 	Step-size adapted to: 0.53301010
# Iteration:  83
# 	Trajectories constructed.
# 	Epsilon: 19.417159
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.033
# 	Step-size adapted to: 0.49040931
# Iteration:  84
# 	Trajectories constructed.
# 	Epsilon: 19.417040
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.021
# 	Step-size adapted to: 0.44837968
# Iteration:  85
# 	Trajectories constructed.
# 	Epsilon: 19.416951
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.019
# 	Step-size adapted to: 0.40954237
# Iteration:  86
# 	Trajectories constructed.
# 	Epsilon: 19.416869
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.033
# 	Step-size adapted to: 0.37669671
# Iteration:  87
# 	Trajectories constructed.
# 	Epsilon: 19.416785
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.032
# 	Step-size adapted to: 0.34631209
# Iteration:  88
# 	Trajectories constructed.
# 	Epsilon: 19.416713
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.036
# 	Step-size adapted to: 0.31904762
# Iteration:  89
# 	Trajectories constructed.
# 	Epsilon: 19.416652
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.043
# 	Step-size adapted to: 0.29493069
# Iteration:  90
# 	Trajectories constructed.
# 	Epsilon: 19.416610
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.040
# 	Step-size adapted to: 0.27222811
# Iteration:  91
# 	Trajectories constructed.
# 	Epsilon: 19.416576
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.028
# 	Step-size adapted to: 0.24976997
# Iteration:  92
# 	Trajectories constructed.
# 	Epsilon: 19.416550
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.026
# 	Step-size adapted to: 0.22898131
# Iteration:  93
# 	Trajectories constructed.
# 	Epsilon: 19.416529
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.027
# 	Step-size adapted to: 0.21000690
# Iteration:  94
# 	Trajectories constructed.
# 	Epsilon: 19.416514
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.018
# 	Step-size adapted to: 0.19177837
# Iteration:  95
# 	Trajectories constructed.
# 	Epsilon: 19.416502
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.021
# 	Step-size adapted to: 0.17532482
# Iteration:  96
# 	Trajectories constructed.
# 	Epsilon: 19.416491
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.042
# 	Step-size adapted to: 0.16202334
# Iteration:  97
# 	Trajectories constructed.
# 	Epsilon: 19.416484
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.025
# 	Step-size adapted to: 0.14841915
# Iteration:  98
# 	Trajectories constructed.
# 	Epsilon: 19.416478
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.017
# 	Step-size adapted to: 0.13541449
# Iteration:  99
# 	Trajectories constructed.
# 	Epsilon: 19.416473
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.020
# 	Step-size adapted to: 0.12374715
# Iteration:  100
# 	Trajectories constructed.
# 	Epsilon: 19.416469
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.021
# 	Step-size adapted to: 0.11313031

# %%
fig, ax = plt.subplots()
ax.plot(MS_RWM.ϵs)
ax.plot(SMC_RWM.ϵs)
ax.set_yscale('log')
