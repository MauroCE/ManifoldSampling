# %% [markdown]
# # Try with 20 observations

# %%
import numpy as np
from numpy import zeros, eye, array, diag, exp, ones, tanh, cosh, dstack, log, hstack, vstack, sinh
from numpy.linalg import solve, norm
from numpy.random import choice, default_rng, randint, randn
from scipy.stats import multivariate_normal as MVN
from scipy.special import logsumexp
from scipy.stats import uniform as udist
import math
import time
from copy import deepcopy

import matplotlib.pyplot as plt
from matplotlib import rc
from ipywidgets.widgets import IntSlider
from ipywidgets.widgets import interact
from warnings import resetwarnings, catch_warnings, filterwarnings

from Manifolds.GKManifoldNew import GKManifold, data_generator, find_point_on_manifold, find_point_on_manifold_from_θ
from markov_snippets import MSAdaptive, SMCAdaptive
from tangential_hug_functions import TangentialHugSampler
from RWM import RWM

# %%
seed = 1234
m = 20     # number of latent variables
d = m + 4  # dimensionality of x-component

# %%
def generate_settings(
    d=d, 
    N=2000,
    B=20,
    δ=0.01,
    δmin=1e-3,
    δmax=100.0,
    εmin=1e-16,
    min_pm=1e-4,
    maxiter=500,
    verbose=False,
    εs_fixed=None,
    adaptiveε=True,
    adaptiveδ=False,
    z0_manual=None,
    pm_target=0.23,
    pm_switch=0.1,
    prior_seed=seed,
    low_memory=True,
    integrator='rwm',
    εprop_switch=0.01,
    ε0_manual=None,
    quantile_value=0.9,
    initialization='manual',
    switch_strategy='pm',
    kernel='uniform',
    prior_scale=7,
    thinning=10,
    burnin=100,
    use_autograd=False,
    stopping_criterion={'εmin', 'pm'},
    resampling_seed=1234,
    mh_kernel_seed=1234):
    # here d represents m+4
    # Generate the manifold
    θ0        = array([3.0, 1.0, 2.0, 0.5])       # True parameter value on U(0, 10) scale.
    ystar     = data_generator(θ0, m, seed=seed)  # Observed data
    q         = MVN(zeros(d), eye(d))             # Proposal distribution for THUG
    resetwarnings()
    manifold  = GKManifold(ystar, kernel_type=kernel, use_autograd=use_autograd)
    # grab arguments
    arguments = locals()
    return arguments

# %%
def generate_initial_particles(ϵ0, N=5000, s=0.001):
    # Generate Manifold
    θ0        = array([3.0, 1.0, 2.0, 0.5])       # True parameter value on U(0, 10) scale.
    ystar     = data_generator(θ0, m, seed=1234)  # Observed data
    resetwarnings()
    manifold  = GKManifold(ystar, kernel_type='uniform', use_autograd=False, θtrue=θ0)

    # Generate target distribution
    ξ0 = manifold.sample()               # Initial point on manifold                            # Starting epsilon
    logηε0 = manifold.generate_logηε(ε0)  # Target filamentary distribution

    # Sample from it using RWM
    s_rwm, a_rwm = RWM(x0=ξ0, s=s, N=N, logpi=logηε0)

    # Add velocities to particles
    v0_manual = randn(*s_rwm.shape)
    z0_manual = np.hstack((s_rwm, v0_manual))
    return z0_manual

def generate_initial_particles_on_manifold(N=5000, θtrue=False):
    # Generate Manifold
    θ0        = array([3.0, 1.0, 2.0, 0.5])       # True parameter value on U(0, 10) scale.
    ystar     = data_generator(θ0, m, seed=1234)  # Observed data
    resetwarnings()
    manifold  = GKManifold(ystar, kernel_type='uniform', use_autograd=False, θtrue=θ0)
    # Sample N times
    x0_manual = np.vstack([manifold.sample(fromtheta=θtrue) for _ in range(N)])
    v0_manual = randn(*x0_manual.shape)
    return np.hstack((x0_manual, v0_manual))

def generate_particles_on_manifold_then_rwm(ϵ0, N=5000, θtrue=False, δrwm=0.001):
    """First, generate particles on the manifold. Then use RWM to actually sample from a filamentary
    distribution of sorts."""
    # Generate manifold (used only to generate filamentary distribution)
    θ0        = array([3.0, 1.0, 2.0, 0.5])       # True parameter value on U(0, 10) scale.
    ystar     = data_generator(θ0, m, seed=1234)  # Observed data
    manifold  = GKManifold(ystar, kernel_type='uniform', use_autograd=False, θtrue=θ0)
    # Sample on manifold
    on_manifold = generate_initial_particles_on_manifold(N=N, θtrue=θtrue)
    x0_on_manifold = on_manifold[:, :on_manifold.shape[1]//2]
    # Store filamentary samples
    filamentary_samples = []
    for x0 in x0_on_manifold:
        filamentary_samples.append(RWM(x0, s=δrwm, N=1, logpi=manifold.generate_logηε(ϵ0))[0].flatten())
    # Create array
    v0_manual = randn(*x0_on_manifold.shape)
    x0_manual = np.vstack(filamentary_samples)
    return np.hstack((x0_manual, v0_manual))

def sample_from_filamentary(ε0, N=2000, n_per_sample=10, s=1.0):
    samples = []
    acceptances = []
    # Generate Manifold
    θ0        = array([3.0, 1.0, 2.0, 0.5])       # True parameter value on U(0, 10) scale.
    ystar     = data_generator(θ0, m, seed=1234)  # Observed data
    resetwarnings()
    manifold  = GKManifold(ystar, kernel_type='uniform', use_autograd=False, θtrue=θ0)
    # Construct filamentary distribution
    logηε0 = manifold.generate_logηε(ε0)
    while len(acceptances) < N:
        with catch_warnings():
            filterwarnings('error')
            try:
                # Sample on the manifold
                ξ0 = manifold.sample()
                # Sample starting from ξ0 and perform 10 steps of RWM. Grab the final point
                s_rwm, a_rwm = RWM(x0=ξ0, s=s, N=n_per_sample, logpi=logηε0)
                samples.append(s_rwm[-1])
                acceptances.append(int(sum(a_rwm == 1) > 0))
            except RuntimeWarning:
                continue
    print("Acceptance Probability: {:.3f}".format(np.mean(acceptances)*100))
    x0_manual = vstack(samples)
    v0_manual = v0_manual = randn(*x0_manual.shape)
    return hstack((x0_manual, v0_manual))

# %%
ε0_manual = 20.0
init_particles = sample_from_filamentary(ε0_manual, s=0.3, n_per_sample=10)
# Out:
# Acceptance Probability: 75.700

# %% [markdown]
# # START FROM PRIOR

# %%
N      = 2000
B      = 20
δmin   = 1e-3
min_pm = 1e-4
pm_switch = 0.1
quantile_value = 0.5

# %% [markdown]
# ### SMC-RWM $\delta=0.001$

# %%
SMC_RWM_0001_PRIOR = SMCAdaptive(generate_settings(
        d=d, 
        N=N,
        B=B,
        δ=0.001,
        δmin=δmin,
        min_pm=min_pm,
        verbose=True,
        εs_fixed=None,
        adaptiveε=True,
        adaptiveδ=False,
        z0_manual=None,
        pm_target=0.23,
        pm_switch=pm_switch,
        prior_seed=seed,
        low_memory=True,
        integrator='rwm',
        εprop_switch=0.01,
        ε0_manual=None,
        quantile_value=quantile_value,
        initialization='prior',
        switch_strategy='pm',
        kernel='uniform',
        use_autograd=False,
        stopping_criterion={'εmin', 'pm'},
        resampling_seed=1234,
        mh_kernel_seed=1234))
_ = SMC_RWM_0001_PRIOR.sample()
# Out:
# Stochastic Kernel: RWM.
# Stopping criterion:  εmin, pm.
# Setting initial epsilon to εmax = 6446696817851.2958984375000000
# Iteration:  1
# 	Particles resampled.
# 	Epsilon: 16021.6268746205860225
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4860000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  2
# 	Particles resampled.
# 	Epsilon: 522.3549807385128361
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4610000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  3
# 	Particles resampled.
# 	Epsilon: 84.5446067776424997
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4835000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  4
# 	Particles resampled.
# 	Epsilon: 44.4120582208767232
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4725000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  5
# 	Particles resampled.
# 	Epsilon: 26.9112228679312153
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4705000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  6
# 	Particles resampled.
# 	Epsilon: 21.6209891058064123
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4515000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  7
# 	Particles resampled.
# 	Epsilon: 19.5757171523363702
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4700000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  8
# 	Particles resampled.
# 	Epsilon: 18.1300128845182371
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4320000000000001
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  9
# 	Particles resampled.
# 	Epsilon: 17.2378989372640170
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4635000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  10
# 	Particles resampled.
# 	Epsilon: 16.9546775523686293
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3920000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  11
# 	Particles resampled.
# 	Epsilon: 16.9310993070672815
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3480000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  12
# 	Particles resampled.
# 	Epsilon: 16.8706878920587222
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3630000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  13
# 	Particles resampled.
# 	Epsilon: 16.7145880061843926
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3555000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  14
# 	Particles resampled.
# 	Epsilon: 16.5758148320048164
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3530000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  15
# 	Particles resampled.
# 	Epsilon: 16.4312635725467544
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3340000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  16
# 	Particles resampled.
# 	Epsilon: 16.3101015286692927
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3480000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  17
# 	Particles resampled.
# 	Epsilon: 16.1715637580267106
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3535000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  18
# 	Particles resampled.
# 	Epsilon: 16.0408332584033957
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3420000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  19
# 	Particles resampled.
# 	Epsilon: 15.9106444452293125
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3540000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  20
# 	Particles resampled.
# 	Epsilon: 15.7748323539772066
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3375000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  21
# 	Particles resampled.
# 	Epsilon: 15.6434044164617010
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3300000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  22
# 	Particles resampled.
# 	Epsilon: 15.5210095756704085
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3595000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  23
# 	Particles resampled.
# 	Epsilon: 15.3874861609283489
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3420000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  24
# 	Particles resampled.
# 	Epsilon: 15.2557918787950850
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3535000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  25
# 	Particles resampled.
# 	Epsilon: 15.0950940727007890
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3370000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  26
# 	Particles resampled.
# 	Epsilon: 14.9501946094502784
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3385000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  27
# 	Particles resampled.
# 	Epsilon: 14.7852866854965370
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3505000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  28
# 	Particles resampled.
# 	Epsilon: 14.6138386226232466
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3120000000000001
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  29
# 	Particles resampled.
# 	Epsilon: 14.4467384222861401
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3250000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  30
# 	Particles resampled.
# 	Epsilon: 14.2800347071423985
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3455000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  31
# 	Particles resampled.
# 	Epsilon: 14.0872823031826790
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3490000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  32
# 	Particles resampled.
# 	Epsilon: 13.8931749062429812
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3405000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  33
# 	Particles resampled.
# 	Epsilon: 13.7132563758885428
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3335000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  34
# 	Particles resampled.
# 	Epsilon: 13.5379485800214727
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3310000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  35
# 	Particles resampled.
# 	Epsilon: 13.3431194748130189
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3300000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  36
# 	Particles resampled.
# 	Epsilon: 13.1381519821889672
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3455000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  37
# 	Particles resampled.
# 	Epsilon: 12.9506258066320932
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3435000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  38
# 	Particles resampled.
# 	Epsilon: 12.7585769076682745
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3555000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  39
# 	Particles resampled.
# 	Epsilon: 12.5346982474203656
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3510000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  40
# 	Particles resampled.
# 	Epsilon: 12.3165654871066383
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3710000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  41
# 	Particles resampled.
# 	Epsilon: 12.0559056641435820
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3495000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  42
# 	Particles resampled.
# 	Epsilon: 11.7936933622268931
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3630000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  43
# 	Particles resampled.
# 	Epsilon: 11.5377685976793103
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3470000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  44
# 	Particles resampled.
# 	Epsilon: 11.2546364980626574
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3660000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  45
# 	Particles resampled.
# 	Epsilon: 10.9813757435425341
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3585000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  46
# 	Particles resampled.
# 	Epsilon: 10.7059143559520820
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3695000000000001
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  47
# 	Particles resampled.
# 	Epsilon: 10.4163078686518649
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3530000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  48
# 	Particles resampled.
# 	Epsilon: 10.1390525456168596
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3470000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  49
# 	Particles resampled.
# 	Epsilon: 9.8948872519317845
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3570000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  50
# 	Particles resampled.
# 	Epsilon: 9.6403944401219199
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3335000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  51
# 	Particles resampled.
# 	Epsilon: 9.3822246203273973
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3105000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  52
# 	Particles resampled.
# 	Epsilon: 9.1584995159812159
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3275000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  53
# 	Particles resampled.
# 	Epsilon: 8.9374119767054800
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3460000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  54
# 	Particles resampled.
# 	Epsilon: 8.6780139592198964
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3260000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  55
# 	Particles resampled.
# 	Epsilon: 8.4255940660442086
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3485000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  56
# 	Particles resampled.
# 	Epsilon: 8.1987369259578724
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3380000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  57
# 	Particles resampled.
# 	Epsilon: 8.0249784624301377
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3245000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  58
# 	Particles resampled.
# 	Epsilon: 7.8410010501755814
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3405000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  59
# 	Particles resampled.
# 	Epsilon: 7.6510599432837356
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3080000000000001
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  60
# 	Particles resampled.
# 	Epsilon: 7.4982736934586249
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3010000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  61
# 	Particles resampled.
# 	Epsilon: 7.3374978707024638
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3085000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  62
# 	Particles resampled.
# 	Epsilon: 7.1826800700155884
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3240000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  63
# 	Particles resampled.
# 	Epsilon: 7.0321955460753847
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3040000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  64
# 	Particles resampled.
# 	Epsilon: 6.8850210750158602
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2970000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  65
# 	Particles resampled.
# 	Epsilon: 6.7403449384500194
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2825000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  66
# 	Particles resampled.
# 	Epsilon: 6.6002973672160969
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3050000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  67
# 	Particles resampled.
# 	Epsilon: 6.4653005098180234
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2825000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  68
# 	Particles resampled.
# 	Epsilon: 6.3517316055919721
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2755000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  69
# 	Particles resampled.
# 	Epsilon: 6.2453325592575801
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2775000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  70
# 	Particles resampled.
# 	Epsilon: 6.1306942652246716
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2365000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  71
# 	Particles resampled.
# 	Epsilon: 6.0352736020717614
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2570000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  72
# 	Particles resampled.
# 	Epsilon: 5.9236907091036350
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2520000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  73
# 	Particles resampled.
# 	Epsilon: 5.8235035515658691
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2755000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  74
# 	Particles resampled.
# 	Epsilon: 5.7230537044798258
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2685000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  75
# 	Particles resampled.
# 	Epsilon: 5.6265998698021509
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2425000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  76
# 	Particles resampled.
# 	Epsilon: 5.5406575960289555
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2175000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  77
# 	Particles resampled.
# 	Epsilon: 5.4569673483034959
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2350000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  78
# 	Particles resampled.
# 	Epsilon: 5.3876861364455300
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2245000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  79
# 	Particles resampled.
# 	Epsilon: 5.3096211268467295
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2395000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  80
# 	Particles resampled.
# 	Epsilon: 5.2296257377014390
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2290000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  81
# 	Particles resampled.
# 	Epsilon: 5.1541127221248679
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2285000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  82
# 	Particles resampled.
# 	Epsilon: 5.0766218236955805
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2165000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  83
# 	Particles resampled.
# 	Epsilon: 5.0098895268525947
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2140000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  84
# 	Particles resampled.
# 	Epsilon: 4.9401720953330726
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2075000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  85
# 	Particles resampled.
# 	Epsilon: 4.8754472176285368
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2095000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  86
# 	Particles resampled.
# 	Epsilon: 4.8151246172043800
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2200000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  87
# 	Particles resampled.
# 	Epsilon: 4.7553369224777295
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1960000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  88
# 	Particles resampled.
# 	Epsilon: 4.6964732090697661
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2065000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  89
# 	Particles resampled.
# 	Epsilon: 4.6371323064108347
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2045000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  90
# 	Particles resampled.
# 	Epsilon: 4.5798564360522471
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2025000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  91
# 	Particles resampled.
# 	Epsilon: 4.5352266213761432
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1805000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  92
# 	Particles resampled.
# 	Epsilon: 4.4846186081507708
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1925000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  93
# 	Particles resampled.
# 	Epsilon: 4.4341019269501221
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1770000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  94
# 	Particles resampled.
# 	Epsilon: 4.3880357554567384
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1555000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  95
# 	Particles resampled.
# 	Epsilon: 4.3480141635200873
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1725000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  96
# 	Particles resampled.
# 	Epsilon: 4.2982426371688724
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1685000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  97
# 	Particles resampled.
# 	Epsilon: 4.2519261073371784
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1565000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  98
# 	Particles resampled.
# 	Epsilon: 4.2037797393775618
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1515000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  99
# 	Particles resampled.
# 	Epsilon: 4.1567069305697055
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1680000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  100
# 	Particles resampled.
# 	Epsilon: 4.1149598812727373
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1590000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  101
# 	Particles resampled.
# 	Epsilon: 4.0698267102462014
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1500000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  102
# 	Particles resampled.
# 	Epsilon: 4.0359108109156754
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1450000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  103
# 	Particles resampled.
# 	Epsilon: 3.9946609376280788
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1510000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  104
# 	Particles resampled.
# 	Epsilon: 3.9560515783753183
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1795000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  105
# 	Particles resampled.
# 	Epsilon: 3.9103364669758061
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1675000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  106
# 	Particles resampled.
# 	Epsilon: 3.8671906803489446
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1670000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  107
# 	Particles resampled.
# 	Epsilon: 3.8232266786089664
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1525000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  108
# 	Particles resampled.
# 	Epsilon: 3.7801104158113996
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1530000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  109
# 	Particles resampled.
# 	Epsilon: 3.7344743608162769
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1615000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  110
# 	Particles resampled.
# 	Epsilon: 3.6955575907574554
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1240000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  111
# 	Particles resampled.
# 	Epsilon: 3.6636645829093402
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1245000000000001
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  112
# 	Particles resampled.
# 	Epsilon: 3.6291556100921758
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1340000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  113
# 	Particles resampled.
# 	Epsilon: 3.5952491437156944
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1220000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  114
# 	Particles resampled.
# 	Epsilon: 3.5644574517362972
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1235000000000001
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  115
# 	Particles resampled.
# 	Epsilon: 3.5370497624754762
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1135000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  116
# 	Particles resampled.
# 	Epsilon: 3.5095034204142164
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1170000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  117
# 	Particles resampled.
# 	Epsilon: 3.4810136845371291
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1050000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  118
# 	Particles resampled.
# 	Epsilon: 3.4518443190244059
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1045000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  119
# 	Particles resampled.
# 	Epsilon: 3.4266502520207665
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0955000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  120
# 	Particles resampled.
# 	Epsilon: 3.4047284596963947
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0925000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  121
# 	Particles resampled.
# 	Epsilon: 3.3790343558425109
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0900000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  122
# 	Particles resampled.
# 	Epsilon: 3.3541491363487270
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0860000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  123
# 	Particles resampled.
# 	Epsilon: 3.3322233998718032
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0875000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  124
# 	Particles resampled.
# 	Epsilon: 3.3063383958670425
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0710000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  125
# 	Particles resampled.
# 	Epsilon: 3.2867911338776969
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0725000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  126
# 	Particles resampled.
# 	Epsilon: 3.2669340544971730
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0735000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  127
# 	Particles resampled.
# 	Epsilon: 3.2485711786531510
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0625000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  128
# 	Particles resampled.
# 	Epsilon: 3.2288407252829612
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0685000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  129
# 	Particles resampled.
# 	Epsilon: 3.2060352229451832
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0785000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  130
# 	Particles resampled.
# 	Epsilon: 3.1878184100785893
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0725000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  131
# 	Particles resampled.
# 	Epsilon: 3.1686789819553196
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0755000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  132
# 	Particles resampled.
# 	Epsilon: 3.1510833097938220
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0700000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  133
# 	Particles resampled.
# 	Epsilon: 3.1318068259873808
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0665000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  134
# 	Particles resampled.
# 	Epsilon: 3.1127772218437020
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0885000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  135
# 	Particles resampled.
# 	Epsilon: 3.0963099595831762
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0825000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  136
# 	Particles resampled.
# 	Epsilon: 3.0761345458648650
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0785000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  137
# 	Particles resampled.
# 	Epsilon: 3.0570736544285273
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0655000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  138
# 	Particles resampled.
# 	Epsilon: 3.0413415087401341
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0625000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  139
# 	Particles resampled.
# 	Epsilon: 3.0223358675654892
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0575000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  140
# 	Particles resampled.
# 	Epsilon: 3.0033635018851510
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0669999999999999
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  141
# 	Particles resampled.
# 	Epsilon: 2.9873083793901709
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0405000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  142
# 	Particles resampled.
# 	Epsilon: 2.9744254825910197
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0629999999999999
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  143
# 	Particles resampled.
# 	Epsilon: 2.9604731550312149
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0525000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  144
# 	Particles resampled.
# 	Epsilon: 2.9448924223365425
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0570000000000001
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  145
# 	Particles resampled.
# 	Epsilon: 2.9298419294309022
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0475000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  146
# 	Particles resampled.
# 	Epsilon: 2.9149130694123579
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0525000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  147
# 	Particles resampled.
# 	Epsilon: 2.9019861628833890
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0420000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  148
# 	Particles resampled.
# 	Epsilon: 2.8888878722167024
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0415000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  149
# 	Particles resampled.
# 	Epsilon: 2.8773274864941332
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0540000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  150
# 	Particles resampled.
# 	Epsilon: 2.8594513343263963
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0460000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  151
# 	Particles resampled.
# 	Epsilon: 2.8469188785865560
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0330000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  152
# 	Particles resampled.
# 	Epsilon: 2.8332031429445301
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0645000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  153
# 	Particles resampled.
# 	Epsilon: 2.8181216385962675
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0510000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  154
# 	Particles resampled.
# 	Epsilon: 2.8027068608787773
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0330000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  155
# 	Particles resampled.
# 	Epsilon: 2.7912333139559586
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0420000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  156
# 	Particles resampled.
# 	Epsilon: 2.7823944444350444
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0515000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  157
# 	Particles resampled.
# 	Epsilon: 2.7716129435416912
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0350000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  158
# 	Particles resampled.
# 	Epsilon: 2.7620969021902209
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0325000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  159
# 	Particles resampled.
# 	Epsilon: 2.7523130781617171
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0285000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  160
# 	Particles resampled.
# 	Epsilon: 2.7426101267672314
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0240000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  161
# 	Particles resampled.
# 	Epsilon: 2.7344253398783409
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0335000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  162
# 	Particles resampled.
# 	Epsilon: 2.7247076901942560
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0230000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  163
# 	Particles resampled.
# 	Epsilon: 2.7168182547719297
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0380000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  164
# 	Particles resampled.
# 	Epsilon: 2.7080984719039343
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0115000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  165
# 	Particles resampled.
# 	Epsilon: 2.6981714084834336
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0175000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  166
# 	Particles resampled.
# 	Epsilon: 2.6912284108815916
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0270000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  167
# 	Particles resampled.
# 	Epsilon: 2.6813124682050717
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0285000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  168
# 	Particles resampled.
# 	Epsilon: 2.6694931554492842
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0445000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  169
# 	Particles resampled.
# 	Epsilon: 2.6595852556753430
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0280000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  170
# 	Particles resampled.
# 	Epsilon: 2.6526182541523626
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0200000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  171
# 	Particles resampled.
# 	Epsilon: 2.6451035394384097
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0275000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  172
# 	Particles resampled.
# 	Epsilon: 2.6356242425202283
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0150000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  173
# 	Particles resampled.
# 	Epsilon: 2.6293839564154133
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0120000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  174
# 	Particles resampled.
# 	Epsilon: 2.6196393639042297
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0265000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  175
# 	Particles resampled.
# 	Epsilon: 2.6116047534751976
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0255000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  176
# 	Particles resampled.
# 	Epsilon: 2.6000233630028120
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0250000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  177
# 	Particles resampled.
# 	Epsilon: 2.5920238538115927
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0100000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  178
# 	Particles resampled.
# 	Epsilon: 2.5843787573414900
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0085000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  179
# 	Particles resampled.
# 	Epsilon: 2.5780681586992586
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0340000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  180
# 	Particles resampled.
# 	Epsilon: 2.5696004950956066
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0125000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  181
# 	Particles resampled.
# 	Epsilon: 2.5628885940966404
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0380000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  182
# 	Particles resampled.
# 	Epsilon: 2.5555262532549170
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0150000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  183
# 	Particles resampled.
# 	Epsilon: 2.5448572249939407
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0230000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  184
# 	Particles resampled.
# 	Epsilon: 2.5351562938878516
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0270000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  185
# 	Particles resampled.
# 	Epsilon: 2.5253478837370169
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0245000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  186
# 	Particles resampled.
# 	Epsilon: 2.5158207330277680
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0305000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  187
# 	Particles resampled.
# 	Epsilon: 2.5089941775981481
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0120000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  188
# 	Particles resampled.
# 	Epsilon: 2.5012884649276055
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0180000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  189
# 	Particles resampled.
# 	Epsilon: 2.4942490398481763
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0155000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  190
# 	Particles resampled.
# 	Epsilon: 2.4878573622468121
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0260000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  191
# 	Particles resampled.
# 	Epsilon: 2.4826659478541875
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0135000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  192
# 	Particles resampled.
# 	Epsilon: 2.4746766397094651
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0130000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  193
# 	Particles resampled.
# 	Epsilon: 2.4678684228277730
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0310000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  194
# 	Particles resampled.
# 	Epsilon: 2.4598055413032145
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0285000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  195
# 	Particles resampled.
# 	Epsilon: 2.4533152052054565
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0285000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  196
# 	Particles resampled.
# 	Epsilon: 2.4463448501552594
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0090000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  197
# 	Particles resampled.
# 	Epsilon: 2.4403069944403466
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0060000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  198
# 	Particles resampled.
# 	Epsilon: 2.4353701911395071
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0250000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  199
# 	Particles resampled.
# 	Epsilon: 2.4266691484297631
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0130000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  200
# 	Particles resampled.
# 	Epsilon: 2.4217896806599581
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0120000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  201
# 	Particles resampled.
# 	Epsilon: 2.4181155158212260
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0020000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  202
# 	Particles resampled.
# 	Epsilon: 2.4130004489579884
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0095000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  203
# 	Particles resampled.
# 	Epsilon: 2.4087077558095831
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0120000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  204
# 	Particles resampled.
# 	Epsilon: 2.4035303041048768
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0110000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  205
# 	Particles resampled.
# 	Epsilon: 2.3976688164387903
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0120000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  206
# 	Particles resampled.
# 	Epsilon: 2.3908360926218339
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0070000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  207
# 	Particles resampled.
# 	Epsilon: 2.3822363570813923
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0225000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  208
# 	Particles resampled.
# 	Epsilon: 2.3765168514841899
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0075000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  209
# 	Particles resampled.
# 	Epsilon: 2.3676227159830905
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0235000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  210
# 	Particles resampled.
# 	Epsilon: 2.3616057275779188
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0145000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  211
# 	Particles resampled.
# 	Epsilon: 2.3517363753183469
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0380000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  212
# 	Particles resampled.
# 	Epsilon: 2.3422760018391089
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0350000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  213
# 	Particles resampled.
# 	Epsilon: 2.3301608739158048
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0300000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  214
# 	Particles resampled.
# 	Epsilon: 2.3181907130773247
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0400000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  215
# 	Particles resampled.
# 	Epsilon: 2.3071632761047542
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0325000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  216
# 	Particles resampled.
# 	Epsilon: 2.2940059195093285
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0669999999999999
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  217
# 	Particles resampled.
# 	Epsilon: 2.2791854339313184
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0515000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  218
# 	Particles resampled.
# 	Epsilon: 2.2633641832108142
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0320000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  219
# 	Particles resampled.
# 	Epsilon: 2.2513224138298846
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0610000000000001
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  220
# 	Particles resampled.
# 	Epsilon: 2.2345664443638138
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0525000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  221
# 	Particles resampled.
# 	Epsilon: 2.2192928141742585
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0325000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  222
# 	Particles resampled.
# 	Epsilon: 2.2055211010223972
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0485000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  223
# 	Particles resampled.
# 	Epsilon: 2.1887746705016271
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0415000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  224
# 	Particles resampled.
# 	Epsilon: 2.1721086443427091
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0440000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  225
# 	Particles resampled.
# 	Epsilon: 2.1519843903795146
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0430000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  226
# 	Particles resampled.
# 	Epsilon: 2.1298295248070946
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0665000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  227
# 	Particles resampled.
# 	Epsilon: 2.1089118982137807
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0505000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  228
# 	Particles resampled.
# 	Epsilon: 2.0866531544849849
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0610000000000001
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  229
# 	Particles resampled.
# 	Epsilon: 2.0629961284315272
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0780000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  230
# 	Particles resampled.
# 	Epsilon: 2.0348834573595402
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0605000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  231
# 	Particles resampled.
# 	Epsilon: 2.0108677374098449
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0700000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  232
# 	Particles resampled.
# 	Epsilon: 1.9841762692701455
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0695000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  233
# 	Particles resampled.
# 	Epsilon: 1.9579374238442324
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0750000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  234
# 	Particles resampled.
# 	Epsilon: 1.9249708656509459
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0645000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  235
# 	Particles resampled.
# 	Epsilon: 1.8923455856734557
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0910000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  236
# 	Particles resampled.
# 	Epsilon: 1.8551709995437062
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0905000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  237
# 	Particles resampled.
# 	Epsilon: 1.8161401007133176
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1040000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  238
# 	Particles resampled.
# 	Epsilon: 1.7780436520936598
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0875000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  239
# 	Particles resampled.
# 	Epsilon: 1.7404595682961344
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0865000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  240
# 	Particles resampled.
# 	Epsilon: 1.7091170991865157
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0975000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  241
# 	Particles resampled.
# 	Epsilon: 1.6778081060029342
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0820000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  242
# 	Particles resampled.
# 	Epsilon: 1.6476079894061062
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0610000000000001
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  243
# 	Particles resampled.
# 	Epsilon: 1.6189401610494478
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0685000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  244
# 	Particles resampled.
# 	Epsilon: 1.5838057920200115
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0715000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  245
# 	Particles resampled.
# 	Epsilon: 1.5505286053618204
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0770000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  246
# 	Particles resampled.
# 	Epsilon: 1.5186698521170894
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0495000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  247
# 	Particles resampled.
# 	Epsilon: 1.4875521063840311
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0830000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  248
# 	Particles resampled.
# 	Epsilon: 1.4505068328220947
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0565000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  249
# 	Particles resampled.
# 	Epsilon: 1.4273054289047289
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0720000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  250
# 	Particles resampled.
# 	Epsilon: 1.3984527076448465
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0530000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  251
# 	Particles resampled.
# 	Epsilon: 1.3713870592005870
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0625000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  252
# 	Particles resampled.
# 	Epsilon: 1.3375962329432429
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0450000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  253
# 	Particles resampled.
# 	Epsilon: 1.3125154939659147
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0500000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  254
# 	Particles resampled.
# 	Epsilon: 1.2863961254703429
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0525000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  255
# 	Particles resampled.
# 	Epsilon: 1.2560180264709460
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0455000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  256
# 	Particles resampled.
# 	Epsilon: 1.2247454703017220
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0465000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  257
# 	Particles resampled.
# 	Epsilon: 1.1931422391523714
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0540000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  258
# 	Particles resampled.
# 	Epsilon: 1.1678305661126973
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0610000000000001
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  259
# 	Particles resampled.
# 	Epsilon: 1.1472230783111976
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0200000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  260
# 	Particles resampled.
# 	Epsilon: 1.1186001960023961
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0330000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  261
# 	Particles resampled.
# 	Epsilon: 1.0994988750432479
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0330000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  262
# 	Particles resampled.
# 	Epsilon: 1.0762728745725121
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0075000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  263
# 	Particles resampled.
# 	Epsilon: 1.0626111884970408
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0280000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  264
# 	Particles resampled.
# 	Epsilon: 1.0464713764559470
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0130000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  265
# 	Particles resampled.
# 	Epsilon: 1.0304971822098969
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0165000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  266
# 	Particles resampled.
# 	Epsilon: 1.0119766306163496
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0040000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  267
# 	Particles resampled.
# 	Epsilon: 0.9923808400920855
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0075000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  268
# 	Particles resampled.
# 	Epsilon: 0.9775780409810142
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0135000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  269
# 	Particles resampled.
# 	Epsilon: 0.9619990616007581
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0054999999999999
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  270
# 	Particles resampled.
# 	Epsilon: 0.9490551631958283
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0150000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  271
# 	Particles resampled.
# 	Epsilon: 0.9302488924380453
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0115000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  272
# 	Particles resampled.
# 	Epsilon: 0.9119669864707010
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0060000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  273
# 	Particles resampled.
# 	Epsilon: 0.8989582893719812
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0170000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  274
# 	Particles resampled.
# 	Epsilon: 0.8771947863232298
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0170000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  275
# 	Particles resampled.
# 	Epsilon: 0.8584387178781868
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0060000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  276
# 	Particles resampled.
# 	Epsilon: 0.8479702085342927
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0020000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  277
# 	Particles resampled.
# 	Epsilon: 0.8440019046018007
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0014999999999999
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  278
# 	Particles resampled.
# 	Epsilon: 0.8361217058781387
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0054999999999999
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  279
# 	Particles resampled.
# 	Epsilon: 0.8275840019169232
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0054999999999999
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  280
# 	Particles resampled.
# 	Epsilon: 0.8167545278682280
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0000000000000000
# 	Step-size kept fixed at: 0.0010000000000000

# %% [markdown]
# ### SMC-RT $\delta=0.1$

# %%
SMC_RT_0001_PRIOR = SMCAdaptive(generate_settings(
        d=d, 
        N=N,
        B=B,
        δ=0.01,
        δmin=δmin,
        min_pm=min_pm,
        verbose=True,
        εs_fixed=None,
        adaptiveε=True,
        adaptiveδ=False,
        z0_manual=None,
        pm_target=0.23,
        pm_switch=1e-3,
        prior_seed=seed,
        low_memory=True,
        integrator='rwm_then_thug',
        εprop_switch=0.01,
        ε0_manual=None,
        quantile_value=quantile_value,
        initialization='prior',
        switch_strategy='pm',
        kernel='uniform',
        use_autograd=False,
        stopping_criterion={'εmin', 'pm'},
        resampling_seed=1234,
        mh_kernel_seed=1234))
_ = SMC_RT_0001_PRIOR.sample()
# Out:
# Stochastic Kernel: RWM.
# Stopping criterion:  εmin, pm.
# Setting initial epsilon to εmax = 6446696817851.2958984375000000
# Iteration:  1
# 	Particles resampled.
# 	Epsilon: 16021.6268746205860225
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2910000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  2
# 	Particles resampled.
# 	Epsilon: 507.3768479511655300
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2790000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  3
# 	Particles resampled.
# 	Epsilon: 79.1528831563204278
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2635000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  4
# 	Particles resampled.
# 	Epsilon: 38.3960140131867576
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2544999999999999
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  5
# 	Particles resampled.
# 	Epsilon: 25.1506120449503818
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2330000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  6
# 	Particles resampled.
# 	Epsilon: 20.7489487385924249
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2390000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  7
# 	Particles resampled.
# 	Epsilon: 18.4690342730296422
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1810000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  8
# 	Particles resampled.
# 	Epsilon: 17.4120225380890048
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1590000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  9
# 	Particles resampled.
# 	Epsilon: 16.8132335841092591
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1580000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  10
# 	Particles resampled.
# 	Epsilon: 15.7158267860378746
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1395000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  11
# 	Particles resampled.
# 	Epsilon: 13.8274914964894222
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1284999999999999
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  12
# 	Particles resampled.
# 	Epsilon: 12.3699328884214239
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0995000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  13
# 	Particles resampled.
# 	Epsilon: 11.3844462729678817
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0685000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  14
# 	Particles resampled.
# 	Epsilon: 10.5930836395915851
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0500000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  15
# 	Particles resampled.
# 	Epsilon: 9.9922592187730181
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0480000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  16
# 	Particles resampled.
# 	Epsilon: 9.3825028640802213
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0355000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  17
# 	Particles resampled.
# 	Epsilon: 8.8849756080016533
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0130000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  18
# 	Particles resampled.
# 	Epsilon: 8.5536613231887575
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0210000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  19
# 	Particles resampled.
# 	Epsilon: 8.2413913652506530
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0230000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  20
# 	Particles resampled.
# 	Epsilon: 7.8614049482496089
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0150000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  21
# 	Particles resampled.
# 	Epsilon: 7.3116117374720009
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0185000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  22
# 	Particles resampled.
# 	Epsilon: 6.8281314187776623
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0260000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  23
# 	Particles resampled.
# 	Epsilon: 6.1708941368746117
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0385000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  24
# 	Particles resampled.
# 	Epsilon: 5.7119888495696278
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0220000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  25
# 	Particles resampled.
# 	Epsilon: 5.3618112782508103
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0100000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  26
# 	Particles resampled.
# 	Epsilon: 5.1430594536755780
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0054999999999999
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  27
# 	Particles resampled.
# 	Epsilon: 4.8910854322888957
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0145000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  28
# 	Particles resampled.
# 	Epsilon: 4.6330530909265413
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0010000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  29
# 	Particles resampled.
# 	Epsilon: 4.2782392128498676
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0014999999999999
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  30
# 	Particles resampled.
# 	Epsilon: 4.0394249877999311
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0000000000000000
# 	Step-size kept fixed at: 0.0100000000000000
#
#
# ####################################
# ### SWITCHING TO THUG KERNEL ###
# ####################################

# %% [markdown]
# ### SMC-RT $\delta=0.001$

# %%
SMC_RT_0001_PRIOR = SMCAdaptive(generate_settings(
        d=d, 
        N=N,
        B=B,
        δ=0.001,
        δmin=δmin,
        min_pm=min_pm,
        verbose=True,
        εs_fixed=None,
        adaptiveε=True,
        adaptiveδ=False,
        z0_manual=None,
        pm_target=0.23,
        pm_switch=0.005,
        prior_seed=seed,
        low_memory=True,
        integrator='rwm_then_thug',
        εprop_switch=0.01,
        ε0_manual=None,
        quantile_value=quantile_value,
        initialization='prior',
        switch_strategy='pm',
        kernel='uniform',
        use_autograd=False,
        stopping_criterion={'εmin', 'pm'},
        resampling_seed=1234,
        mh_kernel_seed=1234))
_ = SMC_RT_0001_PRIOR.sample()
# Out:
# Stochastic Kernel: RWM.
# Stopping criterion:  εmin, pm.
# Setting initial epsilon to εmax = 6446696817851.2958984375000000
# Iteration:  1
# 	Particles resampled.
# 	Epsilon: 16021.6268746205860225
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4860000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  2
# 	Particles resampled.
# 	Epsilon: 522.3549807385128361
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4610000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  3
# 	Particles resampled.
# 	Epsilon: 84.5446067776424997
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4835000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  4
# 	Particles resampled.
# 	Epsilon: 44.4120582208767232
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4725000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  5
# 	Particles resampled.
# 	Epsilon: 26.9112228679312153
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4705000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  6
# 	Particles resampled.
# 	Epsilon: 21.6209891058064123
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4515000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  7
# 	Particles resampled.
# 	Epsilon: 19.5757171523363702
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4700000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  8
# 	Particles resampled.
# 	Epsilon: 18.1300128845182371
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4320000000000001
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  9
# 	Particles resampled.
# 	Epsilon: 17.2378989372640170
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4635000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  10
# 	Particles resampled.
# 	Epsilon: 16.9546775523686293
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3920000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  11
# 	Particles resampled.
# 	Epsilon: 16.9310993070672815
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3480000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  12
# 	Particles resampled.
# 	Epsilon: 16.8706878920587222
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3630000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  13
# 	Particles resampled.
# 	Epsilon: 16.7145880061843926
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3555000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  14
# 	Particles resampled.
# 	Epsilon: 16.5758148320048164
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3530000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  15
# 	Particles resampled.
# 	Epsilon: 16.4312635725467544
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3340000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  16
# 	Particles resampled.
# 	Epsilon: 16.3101015286692927
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3480000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  17
# 	Particles resampled.
# 	Epsilon: 16.1715637580267106
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3535000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  18
# 	Particles resampled.
# 	Epsilon: 16.0408332584033957
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3420000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  19
# 	Particles resampled.
# 	Epsilon: 15.9106444452293125
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3540000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  20
# 	Particles resampled.
# 	Epsilon: 15.7748323539772066
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3375000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  21
# 	Particles resampled.
# 	Epsilon: 15.6434044164617010
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3300000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  22
# 	Particles resampled.
# 	Epsilon: 15.5210095756704085
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3595000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  23
# 	Particles resampled.
# 	Epsilon: 15.3874861609283489
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3420000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  24
# 	Particles resampled.
# 	Epsilon: 15.2557918787950850
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3535000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  25
# 	Particles resampled.
# 	Epsilon: 15.0950940727007890
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3370000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  26
# 	Particles resampled.
# 	Epsilon: 14.9501946094502784
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3385000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  27
# 	Particles resampled.
# 	Epsilon: 14.7852866854965370
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3505000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  28
# 	Particles resampled.
# 	Epsilon: 14.6138386226232466
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3120000000000001
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  29
# 	Particles resampled.
# 	Epsilon: 14.4467384222861401
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3250000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  30
# 	Particles resampled.
# 	Epsilon: 14.2800347071423985
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3455000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  31
# 	Particles resampled.
# 	Epsilon: 14.0872823031826790
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3490000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  32
# 	Particles resampled.
# 	Epsilon: 13.8931749062429812
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3405000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  33
# 	Particles resampled.
# 	Epsilon: 13.7132563758885428
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3335000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  34
# 	Particles resampled.
# 	Epsilon: 13.5379485800214727
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3310000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  35
# 	Particles resampled.
# 	Epsilon: 13.3431194748130189
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3300000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  36
# 	Particles resampled.
# 	Epsilon: 13.1381519821889672
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3455000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  37
# 	Particles resampled.
# 	Epsilon: 12.9506258066320932
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3435000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  38
# 	Particles resampled.
# 	Epsilon: 12.7585769076682745
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3555000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  39
# 	Particles resampled.
# 	Epsilon: 12.5346982474203656
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3510000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  40
# 	Particles resampled.
# 	Epsilon: 12.3165654871066383
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3710000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  41
# 	Particles resampled.
# 	Epsilon: 12.0559056641435820
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3495000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  42
# 	Particles resampled.
# 	Epsilon: 11.7936933622268931
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3630000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  43
# 	Particles resampled.
# 	Epsilon: 11.5377685976793103
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3470000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  44
# 	Particles resampled.
# 	Epsilon: 11.2546364980626574
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3660000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  45
# 	Particles resampled.
# 	Epsilon: 10.9813757435425341
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3585000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  46
# 	Particles resampled.
# 	Epsilon: 10.7059143559520820
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3695000000000001
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  47
# 	Particles resampled.
# 	Epsilon: 10.4163078686518649
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3530000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  48
# 	Particles resampled.
# 	Epsilon: 10.1390525456168596
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3470000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  49
# 	Particles resampled.
# 	Epsilon: 9.8948872519317845
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3570000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  50
# 	Particles resampled.
# 	Epsilon: 9.6403944401219199
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3335000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  51
# 	Particles resampled.
# 	Epsilon: 9.3822246203273973
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3105000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  52
# 	Particles resampled.
# 	Epsilon: 9.1584995159812159
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3275000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  53
# 	Particles resampled.
# 	Epsilon: 8.9374119767054800
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3460000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  54
# 	Particles resampled.
# 	Epsilon: 8.6780139592198964
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3260000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  55
# 	Particles resampled.
# 	Epsilon: 8.4255940660442086
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3485000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  56
# 	Particles resampled.
# 	Epsilon: 8.1987369259578724
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3380000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  57
# 	Particles resampled.
# 	Epsilon: 8.0249784624301377
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3245000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  58
# 	Particles resampled.
# 	Epsilon: 7.8410010501755814
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3405000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  59
# 	Particles resampled.
# 	Epsilon: 7.6510599432837356
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3080000000000001
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  60
# 	Particles resampled.
# 	Epsilon: 7.4982736934586249
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3010000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  61
# 	Particles resampled.
# 	Epsilon: 7.3374978707024638
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3085000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  62
# 	Particles resampled.
# 	Epsilon: 7.1826800700155884
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3240000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  63
# 	Particles resampled.
# 	Epsilon: 7.0321955460753847
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3040000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  64
# 	Particles resampled.
# 	Epsilon: 6.8850210750158602
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2970000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  65
# 	Particles resampled.
# 	Epsilon: 6.7403449384500194
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2825000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  66
# 	Particles resampled.
# 	Epsilon: 6.6002973672160969
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3050000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  67
# 	Particles resampled.
# 	Epsilon: 6.4653005098180234
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2825000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  68
# 	Particles resampled.
# 	Epsilon: 6.3517316055919721
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2755000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  69
# 	Particles resampled.
# 	Epsilon: 6.2453325592575801
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2775000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  70
# 	Particles resampled.
# 	Epsilon: 6.1306942652246716
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2365000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  71
# 	Particles resampled.
# 	Epsilon: 6.0352736020717614
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2570000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  72
# 	Particles resampled.
# 	Epsilon: 5.9236907091036350
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2520000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  73
# 	Particles resampled.
# 	Epsilon: 5.8235035515658691
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2755000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  74
# 	Particles resampled.
# 	Epsilon: 5.7230537044798258
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2685000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  75
# 	Particles resampled.
# 	Epsilon: 5.6265998698021509
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2425000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  76
# 	Particles resampled.
# 	Epsilon: 5.5406575960289555
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2175000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  77
# 	Particles resampled.
# 	Epsilon: 5.4569673483034959
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2350000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  78
# 	Particles resampled.
# 	Epsilon: 5.3876861364455300
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2245000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  79
# 	Particles resampled.
# 	Epsilon: 5.3096211268467295
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2395000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  80
# 	Particles resampled.
# 	Epsilon: 5.2296257377014390
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2290000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  81
# 	Particles resampled.
# 	Epsilon: 5.1541127221248679
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2285000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  82
# 	Particles resampled.
# 	Epsilon: 5.0766218236955805
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2165000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  83
# 	Particles resampled.
# 	Epsilon: 5.0098895268525947
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2140000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  84
# 	Particles resampled.
# 	Epsilon: 4.9401720953330726
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2075000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  85
# 	Particles resampled.
# 	Epsilon: 4.8754472176285368
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2095000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  86
# 	Particles resampled.
# 	Epsilon: 4.8151246172043800
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2200000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  87
# 	Particles resampled.
# 	Epsilon: 4.7553369224777295
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1960000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  88
# 	Particles resampled.
# 	Epsilon: 4.6964732090697661
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2065000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  89
# 	Particles resampled.
# 	Epsilon: 4.6371323064108347
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2045000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  90
# 	Particles resampled.
# 	Epsilon: 4.5798564360522471
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2025000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  91
# 	Particles resampled.
# 	Epsilon: 4.5352266213761432
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1805000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  92
# 	Particles resampled.
# 	Epsilon: 4.4846186081507708
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1925000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  93
# 	Particles resampled.
# 	Epsilon: 4.4341019269501221
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1770000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  94
# 	Particles resampled.
# 	Epsilon: 4.3880357554567384
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1555000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  95
# 	Particles resampled.
# 	Epsilon: 4.3480141635200873
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1725000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  96
# 	Particles resampled.
# 	Epsilon: 4.2982426371688724
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1685000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  97
# 	Particles resampled.
# 	Epsilon: 4.2519261073371784
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1565000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  98
# 	Particles resampled.
# 	Epsilon: 4.2037797393775618
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1515000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  99
# 	Particles resampled.
# 	Epsilon: 4.1567069305697055
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1680000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  100
# 	Particles resampled.
# 	Epsilon: 4.1149598812727373
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1590000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  101
# 	Particles resampled.
# 	Epsilon: 4.0698267102462014
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1500000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  102
# 	Particles resampled.
# 	Epsilon: 4.0359108109156754
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1450000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  103
# 	Particles resampled.
# 	Epsilon: 3.9946609376280788
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1510000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  104
# 	Particles resampled.
# 	Epsilon: 3.9560515783753183
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1795000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  105
# 	Particles resampled.
# 	Epsilon: 3.9103364669758061
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1675000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  106
# 	Particles resampled.
# 	Epsilon: 3.8671906803489446
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1670000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  107
# 	Particles resampled.
# 	Epsilon: 3.8232266786089664
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1525000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  108
# 	Particles resampled.
# 	Epsilon: 3.7801104158113996
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1530000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  109
# 	Particles resampled.
# 	Epsilon: 3.7344743608162769
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1615000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  110
# 	Particles resampled.
# 	Epsilon: 3.6955575907574554
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1240000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  111
# 	Particles resampled.
# 	Epsilon: 3.6636645829093402
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1245000000000001
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  112
# 	Particles resampled.
# 	Epsilon: 3.6291556100921758
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1340000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  113
# 	Particles resampled.
# 	Epsilon: 3.5952491437156944
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1220000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  114
# 	Particles resampled.
# 	Epsilon: 3.5644574517362972
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1235000000000001
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  115
# 	Particles resampled.
# 	Epsilon: 3.5370497624754762
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1135000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  116
# 	Particles resampled.
# 	Epsilon: 3.5095034204142164
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1170000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  117
# 	Particles resampled.
# 	Epsilon: 3.4810136845371291
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1050000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  118
# 	Particles resampled.
# 	Epsilon: 3.4518443190244059
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1045000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  119
# 	Particles resampled.
# 	Epsilon: 3.4266502520207665
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0955000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  120
# 	Particles resampled.
# 	Epsilon: 3.4047284596963947
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0925000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  121
# 	Particles resampled.
# 	Epsilon: 3.3790343558425109
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0900000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  122
# 	Particles resampled.
# 	Epsilon: 3.3541491363487270
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0860000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  123
# 	Particles resampled.
# 	Epsilon: 3.3322233998718032
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0875000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  124
# 	Particles resampled.
# 	Epsilon: 3.3063383958670425
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0710000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  125
# 	Particles resampled.
# 	Epsilon: 3.2867911338776969
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0725000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  126
# 	Particles resampled.
# 	Epsilon: 3.2669340544971730
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0735000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  127
# 	Particles resampled.
# 	Epsilon: 3.2485711786531510
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0625000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  128
# 	Particles resampled.
# 	Epsilon: 3.2288407252829612
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0685000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  129
# 	Particles resampled.
# 	Epsilon: 3.2060352229451832
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0785000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  130
# 	Particles resampled.
# 	Epsilon: 3.1878184100785893
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0725000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  131
# 	Particles resampled.
# 	Epsilon: 3.1686789819553196
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0755000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  132
# 	Particles resampled.
# 	Epsilon: 3.1510833097938220
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0700000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  133
# 	Particles resampled.
# 	Epsilon: 3.1318068259873808
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0665000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  134
# 	Particles resampled.
# 	Epsilon: 3.1127772218437020
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0885000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  135
# 	Particles resampled.
# 	Epsilon: 3.0963099595831762
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0825000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  136
# 	Particles resampled.
# 	Epsilon: 3.0761345458648650
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0785000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  137
# 	Particles resampled.
# 	Epsilon: 3.0570736544285273
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0655000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  138
# 	Particles resampled.
# 	Epsilon: 3.0413415087401341
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0625000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  139
# 	Particles resampled.
# 	Epsilon: 3.0223358675654892
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0575000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  140
# 	Particles resampled.
# 	Epsilon: 3.0033635018851510
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0669999999999999
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  141
# 	Particles resampled.
# 	Epsilon: 2.9873083793901709
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0405000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  142
# 	Particles resampled.
# 	Epsilon: 2.9744254825910197
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0629999999999999
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  143
# 	Particles resampled.
# 	Epsilon: 2.9604731550312149
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0525000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  144
# 	Particles resampled.
# 	Epsilon: 2.9448924223365425
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0570000000000001
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  145
# 	Particles resampled.
# 	Epsilon: 2.9298419294309022
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0475000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  146
# 	Particles resampled.
# 	Epsilon: 2.9149130694123579
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0525000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  147
# 	Particles resampled.
# 	Epsilon: 2.9019861628833890
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0420000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  148
# 	Particles resampled.
# 	Epsilon: 2.8888878722167024
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0415000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  149
# 	Particles resampled.
# 	Epsilon: 2.8773274864941332
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0540000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  150
# 	Particles resampled.
# 	Epsilon: 2.8594513343263963
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0460000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  151
# 	Particles resampled.
# 	Epsilon: 2.8469188785865560
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0330000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  152
# 	Particles resampled.
# 	Epsilon: 2.8332031429445301
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0645000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  153
# 	Particles resampled.
# 	Epsilon: 2.8181216385962675
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0510000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  154
# 	Particles resampled.
# 	Epsilon: 2.8027068608787773
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0330000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  155
# 	Particles resampled.
# 	Epsilon: 2.7912333139559586
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0420000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  156
# 	Particles resampled.
# 	Epsilon: 2.7823944444350444
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0515000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  157
# 	Particles resampled.
# 	Epsilon: 2.7716129435416912
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0350000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  158
# 	Particles resampled.
# 	Epsilon: 2.7620969021902209
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0325000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  159
# 	Particles resampled.
# 	Epsilon: 2.7523130781617171
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0285000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  160
# 	Particles resampled.
# 	Epsilon: 2.7426101267672314
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0240000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  161
# 	Particles resampled.
# 	Epsilon: 2.7344253398783409
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0335000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  162
# 	Particles resampled.
# 	Epsilon: 2.7247076901942560
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0230000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  163
# 	Particles resampled.
# 	Epsilon: 2.7168182547719297
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0380000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  164
# 	Particles resampled.
# 	Epsilon: 2.7080984719039343
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0115000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  165
# 	Particles resampled.
# 	Epsilon: 2.6981714084834336
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0175000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  166
# 	Particles resampled.
# 	Epsilon: 2.6912284108815916
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0270000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  167
# 	Particles resampled.
# 	Epsilon: 2.6813124682050717
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0285000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  168
# 	Particles resampled.
# 	Epsilon: 2.6694931554492842
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0445000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  169
# 	Particles resampled.
# 	Epsilon: 2.6595852556753430
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0280000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  170
# 	Particles resampled.
# 	Epsilon: 2.6526182541523626
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0200000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  171
# 	Particles resampled.
# 	Epsilon: 2.6451035394384097
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0275000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  172
# 	Particles resampled.
# 	Epsilon: 2.6356242425202283
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0150000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  173
# 	Particles resampled.
# 	Epsilon: 2.6293839564154133
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0120000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  174
# 	Particles resampled.
# 	Epsilon: 2.6196393639042297
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0265000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  175
# 	Particles resampled.
# 	Epsilon: 2.6116047534751976
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0255000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  176
# 	Particles resampled.
# 	Epsilon: 2.6000233630028120
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0250000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  177
# 	Particles resampled.
# 	Epsilon: 2.5920238538115927
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0100000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  178
# 	Particles resampled.
# 	Epsilon: 2.5843787573414900
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0085000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  179
# 	Particles resampled.
# 	Epsilon: 2.5780681586992586
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0340000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  180
# 	Particles resampled.
# 	Epsilon: 2.5696004950956066
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0125000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  181
# 	Particles resampled.
# 	Epsilon: 2.5628885940966404
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0380000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  182
# 	Particles resampled.
# 	Epsilon: 2.5555262532549170
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0150000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  183
# 	Particles resampled.
# 	Epsilon: 2.5448572249939407
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0230000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  184
# 	Particles resampled.
# 	Epsilon: 2.5351562938878516
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0270000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  185
# 	Particles resampled.
# 	Epsilon: 2.5253478837370169
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0245000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  186
# 	Particles resampled.
# 	Epsilon: 2.5158207330277680
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0305000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  187
# 	Particles resampled.
# 	Epsilon: 2.5089941775981481
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0120000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  188
# 	Particles resampled.
# 	Epsilon: 2.5012884649276055
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0180000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  189
# 	Particles resampled.
# 	Epsilon: 2.4942490398481763
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0155000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  190
# 	Particles resampled.
# 	Epsilon: 2.4878573622468121
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0260000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  191
# 	Particles resampled.
# 	Epsilon: 2.4826659478541875
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0135000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  192
# 	Particles resampled.
# 	Epsilon: 2.4746766397094651
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0130000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  193
# 	Particles resampled.
# 	Epsilon: 2.4678684228277730
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0310000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  194
# 	Particles resampled.
# 	Epsilon: 2.4598055413032145
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0285000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  195
# 	Particles resampled.
# 	Epsilon: 2.4533152052054565
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0285000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  196
# 	Particles resampled.
# 	Epsilon: 2.4463448501552594
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0090000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  197
# 	Particles resampled.
# 	Epsilon: 2.4403069944403466
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0060000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  198
# 	Particles resampled.
# 	Epsilon: 2.4353701911395071
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0250000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  199
# 	Particles resampled.
# 	Epsilon: 2.4266691484297631
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0130000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  200
# 	Particles resampled.
# 	Epsilon: 2.4217896806599581
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0120000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  201
# 	Particles resampled.
# 	Epsilon: 2.4181155158212260
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0020000000000000
# 	Step-size kept fixed at: 0.0010000000000000
#
#
# ####################################
# ### SWITCHING TO THUG KERNEL ###
# ####################################
#
#
# Iteration:  202
# 	Particles resampled.
# 	Epsilon: 2.4130004489579884
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4325000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  203
# 	Particles resampled.
# 	Epsilon: 2.4104258154527329
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3430000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  204
# 	Particles resampled.
# 	Epsilon: 2.4082181567788936
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3635000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  205
# 	Particles resampled.
# 	Epsilon: 2.4050002853502299
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3860000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  206
# 	Particles resampled.
# 	Epsilon: 2.4020110945635054
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3745000000000001
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  207
# 	Particles resampled.
# 	Epsilon: 2.4001626676116996
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3450000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  208
# 	Particles resampled.
# 	Epsilon: 2.3988405101720764
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3105000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  209
# 	Particles resampled.
# 	Epsilon: 2.3976525968171574
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3085000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  210
# 	Particles resampled.
# 	Epsilon: 2.3965934394271651
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2845000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  211
# 	Particles resampled.
# 	Epsilon: 2.3956291316523202
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2615000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  212
# 	Particles resampled.
# 	Epsilon: 2.3945788913745436
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2670000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  213
# 	Particles resampled.
# 	Epsilon: 2.3938851546839377
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2320000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  214
# 	Particles resampled.
# 	Epsilon: 2.3931997054290397
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2350000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  215
# 	Particles resampled.
# 	Epsilon: 2.3926491566470451
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2215000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  216
# 	Particles resampled.
# 	Epsilon: 2.3921549640423789
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2160000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  217
# 	Particles resampled.
# 	Epsilon: 2.3917336159794624
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2025000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  218
# 	Particles resampled.
# 	Epsilon: 2.3913113070771321
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1960000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  219
# 	Particles resampled.
# 	Epsilon: 2.3909464444929003
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1845000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  220
# 	Particles resampled.
# 	Epsilon: 2.3905824213510205
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1935000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  221
# 	Particles resampled.
# 	Epsilon: 2.3902248973878231
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1940000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  222
# 	Particles resampled.
# 	Epsilon: 2.3899166118265152
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1630000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  223
# 	Particles resampled.
# 	Epsilon: 2.3896752724987422
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1475000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  224
# 	Particles resampled.
# 	Epsilon: 2.3894563273428933
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1200000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  225
# 	Particles resampled.
# 	Epsilon: 2.3892535567614730
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1284999999999999
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  226
# 	Particles resampled.
# 	Epsilon: 2.3890661034194807
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1360000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  227
# 	Particles resampled.
# 	Epsilon: 2.3889089838669073
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1050000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  228
# 	Particles resampled.
# 	Epsilon: 2.3887834817352678
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0975000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  229
# 	Particles resampled.
# 	Epsilon: 2.3886581591893030
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1015000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  230
# 	Particles resampled.
# 	Epsilon: 2.3885276986734518
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1020000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  231
# 	Particles resampled.
# 	Epsilon: 2.3884223930809227
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0770000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  232
# 	Particles resampled.
# 	Epsilon: 2.3883410106534519
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0725000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  233
# 	Particles resampled.
# 	Epsilon: 2.3882864156708621
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0615000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  234
# 	Particles resampled.
# 	Epsilon: 2.3882430744199223
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0450000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  235
# 	Particles resampled.
# 	Epsilon: 2.3882022617358558
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0465000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  236
# 	Particles resampled.
# 	Epsilon: 2.3881628957281333
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0415000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  237
# 	Particles resampled.
# 	Epsilon: 2.3881254696335223
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0300000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  238
# 	Particles resampled.
# 	Epsilon: 2.3880903780521763
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0495000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  239
# 	Particles resampled.
# 	Epsilon: 2.3880549292663686
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0515000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  240
# 	Particles resampled.
# 	Epsilon: 2.3880097345673814
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0275000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  241
# 	Particles resampled.
# 	Epsilon: 2.3879783516424999
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0140000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  242
# 	Particles resampled.
# 	Epsilon: 2.3879481894996344
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0410000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  243
# 	Particles resampled.
# 	Epsilon: 2.3879090786970840
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0330000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  244
# 	Particles resampled.
# 	Epsilon: 2.3878828819151874
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0235000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  245
# 	Particles resampled.
# 	Epsilon: 2.3878634272669355
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0255000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  246
# 	Particles resampled.
# 	Epsilon: 2.3878425453650745
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0200000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  247
# 	Particles resampled.
# 	Epsilon: 2.3878235313786735
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0110000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  248
# 	Particles resampled.
# 	Epsilon: 2.3878113659015958
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0140000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  249
# 	Particles resampled.
# 	Epsilon: 2.3877973159799328
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0250000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  250
# 	Particles resampled.
# 	Epsilon: 2.3877849887634586
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0190000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  251
# 	Particles resampled.
# 	Epsilon: 2.3877765769453987
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0004999999999999
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  252
# 	Particles resampled.
# 	Epsilon: 2.3877717191266106
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0105000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  253
# 	Particles resampled.
# 	Epsilon: 2.3877635520183849
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0054999999999999
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  254
# 	Particles resampled.
# 	Epsilon: 2.3877578063544949
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0024999999999999
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  255
# 	Particles resampled.
# 	Epsilon: 2.3877545396092215
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0004999999999999
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  256
# 	Particles resampled.
# 	Epsilon: 2.3877498058683235
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0044999999999999
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  257
# 	Particles resampled.
# 	Epsilon: 2.3877483765119898
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0020000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  258
# 	Particles resampled.
# 	Epsilon: 2.3877466450158793
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0145000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  259
# 	Particles resampled.
# 	Epsilon: 2.3877398118035611
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0000000000000000
# 	Step-size kept fixed at: 0.0010000000000000

# %% [markdown]
# ### MS-RWM $\delta=0.001$

# %%
MS_RWM_0001_PRIOR = MSAdaptive(generate_settings(
        d=d, 
        N=N,
        B=B,
        δ=0.001,
        δmin=δmin,
        min_pm=min_pm,
        verbose=True,
        εs_fixed=None,
        adaptiveε=True,
        adaptiveδ=True,
        z0_manual=None,
        pm_target=0.23,
        pm_switch=pm_switch,
        prior_seed=seed,
        low_memory=True,
        integrator='rwm',
        εprop_switch=0.01,
        ε0_manual=None,
        quantile_value=quantile_value,
        initialization='prior',
        switch_strategy='pm',
        kernel='uniform',
        use_autograd=False,
        stopping_criterion={'εmin', 'pm'},
        resampling_seed=1234))
_ = MS_RWM_0001_PRIOR.sample()
# Out:
# Integrator: RWM.
# Stopping criterion:  εmin, pm.
# Setting initial epsilon to εmax = 6446696817851.2958984375000000
# Iteration:  1
# 	Trajectories constructed.
# 	Epsilon: 16995.6902395905053709
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9395000000000000
# 	Step-size adapted to: 0.0014258241536823
# Iteration:  2
# 	Trajectories constructed.
# 	Epsilon: 459.0954998099410318
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9570000000000000
# 	Step-size adapted to: 0.0020508410965418
# Iteration:  3
# 	Trajectories constructed.
# 	Epsilon: 88.7467737837301627
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9535000000000000
# 	Step-size adapted to: 0.0029446795510655
# Iteration:  4
# 	Trajectories constructed.
# 	Epsilon: 42.9039687438075745
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9580000000000000
# 	Step-size adapted to: 0.0042376124108969
# Iteration:  5
# 	Trajectories constructed.
# 	Epsilon: 28.1125362829689998
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9575000000000000
# 	Step-size adapted to: 0.0060967143809844
# Iteration:  6
# 	Trajectories constructed.
# 	Epsilon: 22.8688778941623454
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9535000000000000
# 	Step-size adapted to: 0.0087539059933235
# Iteration:  7
# 	Trajectories constructed.
# 	Epsilon: 20.3510526281573974
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9470000000000000
# 	Step-size adapted to: 0.0125284242146775
# Iteration:  8
# 	Trajectories constructed.
# 	Epsilon: 18.7502199228539830
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9470000000000000
# 	Step-size adapted to: 0.0179304430985015
# Iteration:  9
# 	Trajectories constructed.
# 	Epsilon: 17.1761500844848065
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9485000000000000
# 	Step-size adapted to: 0.0256809635619341
# Iteration:  10
# 	Trajectories constructed.
# 	Epsilon: 14.9501103687103285
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9370000000000001
# 	Step-size adapted to: 0.0365707960585259
# Iteration:  11
# 	Trajectories constructed.
# 	Epsilon: 13.2228460828213485
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9155000000000000
# 	Step-size adapted to: 0.0515215414089230
# Iteration:  12
# 	Trajectories constructed.
# 	Epsilon: 12.2355684148031081
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8680000000000000
# 	Step-size adapted to: 0.0708808288545272
# Iteration:  13
# 	Trajectories constructed.
# 	Epsilon: 11.4840156139394729
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7554999999999999
# 	Step-size adapted to: 0.0921806279975293
# Iteration:  14
# 	Trajectories constructed.
# 	Epsilon: 10.6762430822758674
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.6455000000000000
# 	Step-size adapted to: 0.1134656332134432
# Iteration:  15
# 	Trajectories constructed.
# 	Epsilon: 9.9698687452251846
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.5325000000000000
# 	Step-size adapted to: 0.1319931463965291
# Iteration:  16
# 	Trajectories constructed.
# 	Epsilon: 9.2717211005858751
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.4730000000000000
# 	Step-size adapted to: 0.1490452572859632
# Iteration:  17
# 	Trajectories constructed.
# 	Epsilon: 8.6792562202690142
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.3295000000000000
# 	Step-size adapted to: 0.1566478041899618
# Iteration:  18
# 	Trajectories constructed.
# 	Epsilon: 8.0255917479918679
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2845000000000000
# 	Step-size adapted to: 0.1609751491556010
# Iteration:  19
# 	Trajectories constructed.
# 	Epsilon: 7.5187619460372650
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2470000000000000
# 	Step-size adapted to: 0.1623492696622362
# Iteration:  20
# 	Trajectories constructed.
# 	Epsilon: 7.0771789164868437
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1705000000000000
# 	Step-size adapted to: 0.1575905163233671
# Iteration:  21
# 	Trajectories constructed.
# 	Epsilon: 6.6487747722693502
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1835000000000000
# 	Step-size adapted to: 0.1539688023887636
# Iteration:  22
# 	Trajectories constructed.
# 	Epsilon: 6.2713756495461759
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1085000000000000
# 	Step-size adapted to: 0.1448936463718726
# Iteration:  23
# 	Trajectories constructed.
# 	Epsilon: 6.0273424372541742
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1375000000000000
# 	Step-size adapted to: 0.1383449217858752
# Iteration:  24
# 	Trajectories constructed.
# 	Epsilon: 5.7830651228818528
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1385000000000000
# 	Step-size adapted to: 0.1321582409921503
# Iteration:  25
# 	Trajectories constructed.
# 	Epsilon: 5.5456780825886067
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1425000000000000
# 	Step-size adapted to: 0.1265009730205440
# Iteration:  26
# 	Trajectories constructed.
# 	Epsilon: 5.3660744512507810
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1815000000000000
# 	Step-size adapted to: 0.1234702208164579
# Iteration:  27
# 	Trajectories constructed.
# 	Epsilon: 5.1425433106278664
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1445000000000000
# 	Step-size adapted to: 0.1183031029332458
# Iteration:  28
# 	Trajectories constructed.
# 	Epsilon: 4.9052443810676714
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1550000000000000
# 	Step-size adapted to: 0.1139488883443541
# Iteration:  29
# 	Trajectories constructed.
# 	Epsilon: 4.6808097377253981
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1625000000000000
# 	Step-size adapted to: 0.1101672868380423
# Iteration:  30
# 	Trajectories constructed.
# 	Epsilon: 4.4736108994296604
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1420000000000000
# 	Step-size adapted to: 0.1054250211237328
# Iteration:  31
# 	Trajectories constructed.
# 	Epsilon: 4.2855585361914734
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1550000000000000
# 	Step-size adapted to: 0.1015447918344792
# Iteration:  32
# 	Trajectories constructed.
# 	Epsilon: 4.1006193762672565
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1920000000000000
# 	Step-size adapted to: 0.0996336540912328
# Iteration:  33
# 	Trajectories constructed.
# 	Epsilon: 3.9389693998227391
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1830000000000000
# 	Step-size adapted to: 0.0973195603174742
# Iteration:  34
# 	Trajectories constructed.
# 	Epsilon: 3.7752455220137615
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1705000000000000
# 	Step-size adapted to: 0.0944669464217568
# Iteration:  35
# 	Trajectories constructed.
# 	Epsilon: 3.6401269165287231
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1245000000000000
# 	Step-size adapted to: 0.0896129642675254
# Iteration:  36
# 	Trajectories constructed.
# 	Epsilon: 3.5102214371884548
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1340000000000000
# 	Step-size adapted to: 0.0854131440035476
# Iteration:  37
# 	Trajectories constructed.
# 	Epsilon: 3.4140264201259449
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1845000000000000
# 	Step-size adapted to: 0.0834919316297935
# Iteration:  38
# 	Trajectories constructed.
# 	Epsilon: 3.3252035922683998
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1195000000000000
# 	Step-size adapted to: 0.0790041197625221
# Iteration:  39
# 	Trajectories constructed.
# 	Epsilon: 3.2333301719202314
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1290000000000000
# 	Step-size adapted to: 0.0751134772455170
# Iteration:  40
# 	Trajectories constructed.
# 	Epsilon: 3.1479615886938550
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2225000000000000
# 	Step-size adapted to: 0.0748323291879245
# Iteration:  41
# 	Trajectories constructed.
# 	Epsilon: 3.0418439345193922
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2050000000000000
# 	Step-size adapted to: 0.0739027470652446
# Iteration:  42
# 	Trajectories constructed.
# 	Epsilon: 2.9257688423905193
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2080000000000000
# 	Step-size adapted to: 0.0730942716146164
# Iteration:  43
# 	Trajectories constructed.
# 	Epsilon: 2.8024307450464789
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1980000000000000
# 	Step-size adapted to: 0.0719340696354855
# Iteration:  44
# 	Trajectories constructed.
# 	Epsilon: 2.6731241523948688
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1690000000000000
# 	Step-size adapted to: 0.0697732012639883
# Iteration:  45
# 	Trajectories constructed.
# 	Epsilon: 2.5609820697419678
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1525000000000000
# 	Step-size adapted to: 0.0671212039986898
# Iteration:  46
# 	Trajectories constructed.
# 	Epsilon: 2.4631395940709133
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1485000000000000
# 	Step-size adapted to: 0.0644409950702654
# Iteration:  47
# 	Trajectories constructed.
# 	Epsilon: 2.3649694504435046
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1300000000000000
# 	Step-size adapted to: 0.0612981706549419
# Iteration:  48
# 	Trajectories constructed.
# 	Epsilon: 2.2775448585828766
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1295000000000000
# 	Step-size adapted to: 0.0582940482611408
# Iteration:  49
# 	Trajectories constructed.
# 	Epsilon: 2.1907637426450428
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2145000000000000
# 	Step-size adapted to: 0.0578440155165078
# Iteration:  50
# 	Trajectories constructed.
# 	Epsilon: 2.1161445416623099
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1415000000000000
# 	Step-size adapted to: 0.0553402227794336
# Iteration:  51
# 	Trajectories constructed.
# 	Epsilon: 2.0383684457699309
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1175000000000000
# 	Step-size adapted to: 0.0523132664753030
# Iteration:  52
# 	Trajectories constructed.
# 	Epsilon: 1.9616250442802678
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1520000000000000
# 	Step-size adapted to: 0.0503123211303855
# Iteration:  53
# 	Trajectories constructed.
# 	Epsilon: 1.8939608969227018
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1275000000000000
# 	Step-size adapted to: 0.0477987744477351
# Iteration:  54
# 	Trajectories constructed.
# 	Epsilon: 1.8115504823515836
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1450000000000000
# 	Step-size adapted to: 0.0458098896942956
# Iteration:  55
# 	Trajectories constructed.
# 	Epsilon: 1.7439766050174383
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1455000000000000
# 	Step-size adapted to: 0.0439147388220635
# Iteration:  56
# 	Trajectories constructed.
# 	Epsilon: 1.6736677647119234
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1085000000000000
# 	Step-size adapted to: 0.0413263371454370
# Iteration:  57
# 	Trajectories constructed.
# 	Epsilon: 1.6102598140853326
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1390000000000000
# 	Step-size adapted to: 0.0394881252449626
# Iteration:  58
# 	Trajectories constructed.
# 	Epsilon: 1.5439796654856102
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1040000000000000
# 	Step-size adapted to: 0.0370771174869767
# Iteration:  59
# 	Trajectories constructed.
# 	Epsilon: 1.4957302882245338
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1490000000000000
# 	Step-size adapted to: 0.0356054957164101
# Iteration:  60
# 	Trajectories constructed.
# 	Epsilon: 1.4456430783861653
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1225000000000000
# 	Step-size adapted to: 0.0337422243113604
# Iteration:  61
# 	Trajectories constructed.
# 	Epsilon: 1.3875034612694230
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1310000000000000
# 	Step-size adapted to: 0.0321126489241192
# Iteration:  62
# 	Trajectories constructed.
# 	Epsilon: 1.3432266986053183
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1990000000000000
# 	Step-size adapted to: 0.0316187405441578
# Iteration:  63
# 	Trajectories constructed.
# 	Epsilon: 1.3047516077750347
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1610000000000000
# 	Step-size adapted to: 0.0305464965552834
# Iteration:  64
# 	Trajectories constructed.
# 	Epsilon: 1.2664915642029237
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1485000000000000
# 	Step-size adapted to: 0.0293267479822221
# Iteration:  65
# 	Trajectories constructed.
# 	Epsilon: 1.2209330406401810
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1300000000000000
# 	Step-size adapted to: 0.0278964656056066
# Iteration:  66
# 	Trajectories constructed.
# 	Epsilon: 1.1898461407565786
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1240000000000000
# 	Step-size adapted to: 0.0264564503992572
# Iteration:  67
# 	Trajectories constructed.
# 	Epsilon: 1.1592938691665400
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1440000000000000
# 	Step-size adapted to: 0.0253429351781919
# Iteration:  68
# 	Trajectories constructed.
# 	Epsilon: 1.1232144218656130
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1620000000000000
# 	Step-size adapted to: 0.0244957589871158
# Iteration:  69
# 	Trajectories constructed.
# 	Epsilon: 1.0964794486233642
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0975000000000000
# 	Step-size adapted to: 0.0229255039396213
# Iteration:  70
# 	Trajectories constructed.
# 	Epsilon: 1.0736085092457626
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1080000000000000
# 	Step-size adapted to: 0.0215688468899722
# Iteration:  71
# 	Trajectories constructed.
# 	Epsilon: 1.0503684006093663
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1705000000000000
# 	Step-size adapted to: 0.0209366246301076
# Iteration:  72
# 	Trajectories constructed.
# 	Epsilon: 1.0278924440049972
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0735000000000000
# 	Step-size adapted to: 0.0193607921916218
# Iteration:  73
# 	Trajectories constructed.
# 	Epsilon: 1.0117491729009940
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0985000000000000
# 	Step-size adapted to: 0.0181287667529248
# Iteration:  74
# 	Trajectories constructed.
# 	Epsilon: 0.9991016269011889
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0725000000000000
# 	Step-size adapted to: 0.0167558927102548
# Iteration:  75
# 	Trajectories constructed.
# 	Epsilon: 0.9867682556931173
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0490000000000000
# 	Step-size adapted to: 0.0153060779324158
# Iteration:  76
# 	Trajectories constructed.
# 	Epsilon: 0.9782553435175319
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0340000000000000
# 	Step-size adapted to: 0.0138772387781969
# Iteration:  77
# 	Trajectories constructed.
# 	Epsilon: 0.9707444636541718
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0265000000000000
# 	Step-size adapted to: 0.0125346899930989
# Iteration:  78
# 	Trajectories constructed.
# 	Epsilon: 0.9626468761650386
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2535000000000000
# 	Step-size adapted to: 0.0126828412848493
# Iteration:  79
# 	Trajectories constructed.
# 	Epsilon: 0.9530941210985699
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0795000000000000
# 	Step-size adapted to: 0.0117634821519804
# Iteration:  80
# 	Trajectories constructed.
# 	Epsilon: 0.9455136378274293
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2930000000000000
# 	Step-size adapted to: 0.0121399297626386
# Iteration:  81
# 	Trajectories constructed.
# 	Epsilon: 0.9348292780196367
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1495000000000000
# 	Step-size adapted to: 0.0116610006933841
# Iteration:  82
# 	Trajectories constructed.
# 	Epsilon: 0.9239184925565642
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1510000000000000
# 	Step-size adapted to: 0.0112093696000137
# Iteration:  83
# 	Trajectories constructed.
# 	Epsilon: 0.9142671666300319
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1215000000000000
# 	Step-size adapted to: 0.0106174619553860
# Iteration:  84
# 	Trajectories constructed.
# 	Epsilon: 0.9078734361570303
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2175000000000000
# 	Step-size adapted to: 0.0105513097591172
# Iteration:  85
# 	Trajectories constructed.
# 	Epsilon: 0.9005204827604179
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1310000000000000
# 	Step-size adapted to: 0.0100417359228475
# Iteration:  86
# 	Trajectories constructed.
# 	Epsilon: 0.8945522094154551
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1750000000000000
# 	Step-size adapted to: 0.0097693506482258
# Iteration:  87
# 	Trajectories constructed.
# 	Epsilon: 0.8893408343729908
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1170000000000000
# 	Step-size adapted to: 0.0092326858729192
# Iteration:  88
# 	Trajectories constructed.
# 	Epsilon: 0.8837991331453792
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1505000000000000
# 	Step-size adapted to: 0.0088728850257135
# Iteration:  89
# 	Trajectories constructed.
# 	Epsilon: 0.8779842417833028
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1705000000000000
# 	Step-size adapted to: 0.0086128045749091
# Iteration:  90
# 	Trajectories constructed.
# 	Epsilon: 0.8722859209810104
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1300000000000000
# 	Step-size adapted to: 0.0081927531391279
# Iteration:  91
# 	Trajectories constructed.
# 	Epsilon: 0.8681682486277584
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1380000000000000
# 	Step-size adapted to: 0.0078244230337368
# Iteration:  92
# 	Trajectories constructed.
# 	Epsilon: 0.8637709746002744
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1635000000000000
# 	Step-size adapted to: 0.0075685386204853
# Iteration:  93
# 	Trajectories constructed.
# 	Epsilon: 0.8588981319642858
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1350000000000000
# 	Step-size adapted to: 0.0072174376948036
# Iteration:  94
# 	Trajectories constructed.
# 	Epsilon: 0.8551023167504045
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1645000000000000
# 	Step-size adapted to: 0.0069848952767132
# Iteration:  95
# 	Trajectories constructed.
# 	Epsilon: 0.8515902133233494
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1320000000000000
# 	Step-size adapted to: 0.0066508854754065
# Iteration:  96
# 	Trajectories constructed.
# 	Epsilon: 0.8484687646472222
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1685000000000000
# 	Step-size adapted to: 0.0064494831769975
# Iteration:  97
# 	Trajectories constructed.
# 	Epsilon: 0.8452227847474125
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1595000000000000
# 	Step-size adapted to: 0.0062260991683969
# Iteration:  98
# 	Trajectories constructed.
# 	Epsilon: 0.8421534566807221
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1570000000000000
# 	Step-size adapted to: 0.0060029439066110
# Iteration:  99
# 	Trajectories constructed.
# 	Epsilon: 0.8390504997015462
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1365000000000000
# 	Step-size adapted to: 0.0057287651420160
# Iteration:  100
# 	Trajectories constructed.
# 	Epsilon: 0.8363564269478323
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1495000000000000
# 	Step-size adapted to: 0.0055027611855609
# Iteration:  101
# 	Trajectories constructed.
# 	Epsilon: 0.8337085316256957
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1840000000000000
# 	Step-size adapted to: 0.0053776420638125
# Iteration:  102
# 	Trajectories constructed.
# 	Epsilon: 0.8313262801513994
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1470000000000000
# 	Step-size adapted to: 0.0051590373396228
# Iteration:  103
# 	Trajectories constructed.
# 	Epsilon: 0.8288880395263509
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2005000000000000
# 	Step-size adapted to: 0.0050834999962734
# Iteration:  104
# 	Trajectories constructed.
# 	Epsilon: 0.8266691415551906
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1775000000000000
# 	Step-size adapted to: 0.0049517943210584
# Iteration:  105
# 	Trajectories constructed.
# 	Epsilon: 0.8242046100187281
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2180000000000000
# 	Step-size adapted to: 0.0049221725094323
# Iteration:  106
# 	Trajectories constructed.
# 	Epsilon: 0.8221511667418669
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2170000000000000
# 	Step-size adapted to: 0.0048902821440889
# Iteration:  107
# 	Trajectories constructed.
# 	Epsilon: 0.8198719107744280
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2000000000000000
# 	Step-size adapted to: 0.0048174753281697
# Iteration:  108
# 	Trajectories constructed.
# 	Epsilon: 0.8176788545288450
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1880000000000000
# 	Step-size adapted to: 0.0047173632026892
# Iteration:  109
# 	Trajectories constructed.
# 	Epsilon: 0.8156341007658029
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1580000000000000
# 	Step-size adapted to: 0.0045505586243086
# Iteration:  110
# 	Trajectories constructed.
# 	Epsilon: 0.8137071281919352
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1690000000000000
# 	Step-size adapted to: 0.0044138618093816
# Iteration:  111
# 	Trajectories constructed.
# 	Epsilon: 0.8121259033310202
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1515000000000000
# 	Step-size adapted to: 0.0042439735992117
# Iteration:  112
# 	Trajectories constructed.
# 	Epsilon: 0.8101932571697513
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1760000000000000
# 	Step-size adapted to: 0.0041309194115252
# Iteration:  113
# 	Trajectories constructed.
# 	Epsilon: 0.8086173569170999
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2425000000000000
# 	Step-size adapted to: 0.0041568185082175
# Iteration:  114
# 	Trajectories constructed.
# 	Epsilon: 0.8067461554397068
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1740000000000000
# 	Step-size adapted to: 0.0040420419602949
# Iteration:  115
# 	Trajectories constructed.
# 	Epsilon: 0.8050255500360883
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2055000000000000
# 	Step-size adapted to: 0.0039928289911342
# Iteration:  116
# 	Trajectories constructed.
# 	Epsilon: 0.8033995897521033
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2685000000000000
# 	Step-size adapted to: 0.0040704355155200
# Iteration:  117
# 	Trajectories constructed.
# 	Epsilon: 0.8016832828710142
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2630000000000000
# 	Step-size adapted to: 0.0041381548496572
# Iteration:  118
# 	Trajectories constructed.
# 	Epsilon: 0.7995478675862606
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2165000000000000
# 	Step-size adapted to: 0.0041103163650069
# Iteration:  119
# 	Trajectories constructed.
# 	Epsilon: 0.7972837496446099
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2545000000000000
# 	Step-size adapted to: 0.0041609774058280
# Iteration:  120
# 	Trajectories constructed.
# 	Epsilon: 0.7950463338025038
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2090000000000000
# 	Step-size adapted to: 0.0041175157162407
# Iteration:  121
# 	Trajectories constructed.
# 	Epsilon: 0.7933276982183408
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1915000000000000
# 	Step-size adapted to: 0.0040390115653648
# Iteration:  122
# 	Trajectories constructed.
# 	Epsilon: 0.7914397910557349
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1950000000000000
# 	Step-size adapted to: 0.0039689437445828
# Iteration:  123
# 	Trajectories constructed.
# 	Epsilon: 0.7898926360755535
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2300000000000000
# 	Step-size adapted to: 0.0039689437445828
# Iteration:  124
# 	Trajectories constructed.
# 	Epsilon: 0.7882549400848622
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1945000000000000
# 	Step-size adapted to: 0.0038991165428499
# Iteration:  125
# 	Trajectories constructed.
# 	Epsilon: 0.7865336041867507
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2315000000000000
# 	Step-size adapted to: 0.0039020419771578
# Iteration:  126
# 	Trajectories constructed.
# 	Epsilon: 0.7846862425074166
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1460000000000000
# 	Step-size adapted to: 0.0037415501344219
# Iteration:  127
# 	Trajectories constructed.
# 	Epsilon: 0.7834719150879395
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1930000000000000
# 	Step-size adapted to: 0.0036729677995469
# Iteration:  128
# 	Trajectories constructed.
# 	Epsilon: 0.7822732661149316
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1760000000000000
# 	Step-size adapted to: 0.0035751244974459
# Iteration:  129
# 	Trajectories constructed.
# 	Epsilon: 0.7811383890477464
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2040000000000000
# 	Step-size adapted to: 0.0035289486721512
# Iteration:  130
# 	Trajectories constructed.
# 	Epsilon: 0.7799676477095571
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1405000000000000
# 	Step-size adapted to: 0.0033745095660417
# Iteration:  131
# 	Trajectories constructed.
# 	Epsilon: 0.7789805745284440
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1980000000000000
# 	Step-size adapted to: 0.0033209470557295
# Iteration:  132
# 	Trajectories constructed.
# 	Epsilon: 0.7778600753639676
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2280000000000000
# 	Step-size adapted to: 0.0033176277685940
# Iteration:  133
# 	Trajectories constructed.
# 	Epsilon: 0.7767179057857542
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2710000000000000
# 	Step-size adapted to: 0.0033863410425287
# Iteration:  134
# 	Trajectories constructed.
# 	Epsilon: 0.7752583328962263
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2355000000000000
# 	Step-size adapted to: 0.0033956662967434
# Iteration:  135
# 	Trajectories constructed.
# 	Epsilon: 0.7737941889019921
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2730000000000000
# 	Step-size adapted to: 0.0034694636004262
# Iteration:  136
# 	Trajectories constructed.
# 	Epsilon: 0.7723366715022582
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2245000000000000
# 	Step-size adapted to: 0.0034599356824169
# Iteration:  137
# 	Trajectories constructed.
# 	Epsilon: 0.7708414042409266
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2395000000000000
# 	Step-size adapted to: 0.0034764094711825
# Iteration:  138
# 	Trajectories constructed.
# 	Epsilon: 0.7694673284179321
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2355000000000000
# 	Step-size adapted to: 0.0034859827544596
# Iteration:  139
# 	Trajectories constructed.
# 	Epsilon: 0.7681445949369524
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2200000000000000
# 	Step-size adapted to: 0.0034685963429378
# Iteration:  140
# 	Trajectories constructed.
# 	Epsilon: 0.7667192717048121
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2815000000000000
# 	Step-size adapted to: 0.0035590725811067
# Iteration:  141
# 	Trajectories constructed.
# 	Epsilon: 0.7652217554279688
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2275000000000000
# 	Step-size adapted to: 0.0035546265197476
# Iteration:  142
# 	Trajectories constructed.
# 	Epsilon: 0.7637239794062644
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2595000000000000
# 	Step-size adapted to: 0.0036074458458218
# Iteration:  143
# 	Trajectories constructed.
# 	Epsilon: 0.7619896010809744
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2455000000000000
# 	Step-size adapted to: 0.0036355121676463
# Iteration:  144
# 	Trajectories constructed.
# 	Epsilon: 0.7602827390722128
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2165000000000000
# 	Step-size adapted to: 0.0036110550959919
# Iteration:  145
# 	Trajectories constructed.
# 	Epsilon: 0.7587996015619566
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2275000000000000
# 	Step-size adapted to: 0.0036065440970836
# Iteration:  146
# 	Trajectories constructed.
# 	Epsilon: 0.7574186092454830
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1720000000000000
# 	Step-size adapted to: 0.0035034563157319
# Iteration:  147
# 	Trajectories constructed.
# 	Epsilon: 0.7562439216859429
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2005000000000000
# 	Step-size adapted to: 0.0034521595785288
# Iteration:  148
# 	Trajectories constructed.
# 	Epsilon: 0.7550482963095668
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2180000000000000
# 	Step-size adapted to: 0.0034315086358385
# Iteration:  149
# 	Trajectories constructed.
# 	Epsilon: 0.7536541751425068
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1760000000000000
# 	Step-size adapted to: 0.0033400975060813
# Iteration:  150
# 	Trajectories constructed.
# 	Epsilon: 0.7525711953635150
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1955000000000000
# 	Step-size adapted to: 0.0032829749228364
# Iteration:  151
# 	Trajectories constructed.
# 	Epsilon: 0.7513125437350366
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2160000000000000
# 	Step-size adapted to: 0.0032600743439134
# Iteration:  152
# 	Trajectories constructed.
# 	Epsilon: 0.7502779194081554
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2140000000000000
# 	Step-size adapted to: 0.0032340977939036
# Iteration:  153
# 	Trajectories constructed.
# 	Epsilon: 0.7490048370231476
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2120000000000000
# 	Step-size adapted to: 0.0032051215026587
# Iteration:  154
# 	Trajectories constructed.
# 	Epsilon: 0.7479286741736251
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2490000000000000
# 	Step-size adapted to: 0.0032357152471301
# Iteration:  155
# 	Trajectories constructed.
# 	Epsilon: 0.7468742666768960
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1960000000000000
# 	Step-size adapted to: 0.0031811730104929
# Iteration:  156
# 	Trajectories constructed.
# 	Epsilon: 0.7459517705191199
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1475000000000000
# 	Step-size adapted to: 0.0030526192726543
# Iteration:  157
# 	Trajectories constructed.
# 	Epsilon: 0.7450678678655281
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1595000000000000
# 	Step-size adapted to: 0.0029468888891270
# Iteration:  158
# 	Trajectories constructed.
# 	Epsilon: 0.7442086031827617
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2725000000000000
# 	Step-size adapted to: 0.0030101803683339
# Iteration:  159
# 	Trajectories constructed.
# 	Epsilon: 0.7433540311964835
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1885000000000000
# 	Step-size adapted to: 0.0029483627019941
# Iteration:  160
# 	Trajectories constructed.
# 	Epsilon: 0.7425028269772104
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1585000000000000
# 	Step-size adapted to: 0.0028448205783976
# Iteration:  161
# 	Trajectories constructed.
# 	Epsilon: 0.7416798922196414
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1815000000000000
# 	Step-size adapted to: 0.0027766634248807
# Iteration:  162
# 	Trajectories constructed.
# 	Epsilon: 0.7407373803080597
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2625000000000000
# 	Step-size adapted to: 0.0028221528057557
# Iteration:  163
# 	Trajectories constructed.
# 	Epsilon: 0.7395086395937074
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2930000000000000
# 	Step-size adapted to: 0.0029124655776810
# Iteration:  164
# 	Trajectories constructed.
# 	Epsilon: 0.7380783321420870
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2520000000000000
# 	Step-size adapted to: 0.0029446795510655
# Iteration:  165
# 	Trajectories constructed.
# 	Epsilon: 0.7369004779152390
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2405000000000000
# 	Step-size adapted to: 0.0029601797711844
# Iteration:  166
# 	Trajectories constructed.
# 	Epsilon: 0.7357239267362470
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1540000000000000
# 	Step-size adapted to: 0.0028498033730835
# Iteration:  167
# 	Trajectories constructed.
# 	Epsilon: 0.7348093973004769
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1730000000000000
# 	Step-size adapted to: 0.0027697304361653
# Iteration:  168
# 	Trajectories constructed.
# 	Epsilon: 0.7340944763050925
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1970000000000000
# 	Step-size adapted to: 0.0027244048483873
# Iteration:  169
# 	Trajectories constructed.
# 	Epsilon: 0.7332744101220432
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1895000000000000
# 	Step-size adapted to: 0.0026697904868801
# Iteration:  170
# 	Trajectories constructed.
# 	Epsilon: 0.7324406218183486
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1965000000000000
# 	Step-size adapted to: 0.0026254439354201
# Iteration:  171
# 	Trajectories constructed.
# 	Epsilon: 0.7317937774198620
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1835000000000000
# 	Step-size adapted to: 0.0025651065045438
# Iteration:  172
# 	Trajectories constructed.
# 	Epsilon: 0.7311065135991965
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2090000000000000
# 	Step-size adapted to: 0.0025383137941333
# Iteration:  173
# 	Trajectories constructed.
# 	Epsilon: 0.7303034164623050
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1900000000000000
# 	Step-size adapted to: 0.0024880518134457
# Iteration:  174
# 	Trajectories constructed.
# 	Epsilon: 0.7294927562602047
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2555000000000000
# 	Step-size adapted to: 0.0025199775682610
# Iteration:  175
# 	Trajectories constructed.
# 	Epsilon: 0.7287620354155460
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2185000000000000
# 	Step-size adapted to: 0.0025055292758921
# Iteration:  176
# 	Trajectories constructed.
# 	Epsilon: 0.7280036408637103
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2350000000000000
# 	Step-size adapted to: 0.0025118009353897
# Iteration:  177
# 	Trajectories constructed.
# 	Epsilon: 0.7271901050600896
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2190000000000000
# 	Step-size adapted to: 0.0024980239516798
# Iteration:  178
# 	Trajectories constructed.
# 	Epsilon: 0.7264052058289376
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2740000000000000
# 	Step-size adapted to: 0.0025535894580629
# Iteration:  179
# 	Trajectories constructed.
# 	Epsilon: 0.7254937920115089
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2310000000000000
# 	Step-size adapted to: 0.0025548665720438
# Iteration:  180
# 	Trajectories constructed.
# 	Epsilon: 0.7246247586126460
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2555000000000000
# 	Step-size adapted to: 0.0025876496689730
# Iteration:  181
# 	Trajectories constructed.
# 	Epsilon: 0.7236080546462131
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2795000000000000
# 	Step-size adapted to: 0.0026524931260392
# Iteration:  182
# 	Trajectories constructed.
# 	Epsilon: 0.7225060419062951
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2695000000000000
# 	Step-size adapted to: 0.0027054006068944
# Iteration:  183
# 	Trajectories constructed.
# 	Epsilon: 0.7212411438306816
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2885000000000000
# 	Step-size adapted to: 0.0027857022611644
# Iteration:  184
# 	Trajectories constructed.
# 	Epsilon: 0.7198517132080035
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2635000000000000
# 	Step-size adapted to: 0.0028327557468665
# Iteration:  185
# 	Trajectories constructed.
# 	Epsilon: 0.7186494763846771
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2595000000000000
# 	Step-size adapted to: 0.0028748485655216
# Iteration:  186
# 	Trajectories constructed.
# 	Epsilon: 0.7174860336801983
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2580000000000000
# 	Step-size adapted to: 0.0029153794999770
# Iteration:  187
# 	Trajectories constructed.
# 	Epsilon: 0.7163869138665089
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2350000000000000
# 	Step-size adapted to: 0.0029226770668848
# Iteration:  188
# 	Trajectories constructed.
# 	Epsilon: 0.7151952209195779
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2290000000000000
# 	Step-size adapted to: 0.0029212160936251
# Iteration:  189
# 	Trajectories constructed.
# 	Epsilon: 0.7141627713881354
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1885000000000000
# 	Step-size adapted to: 0.0028612254154312
# Iteration:  190
# 	Trajectories constructed.
# 	Epsilon: 0.7133180445808365
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1655000000000000
# 	Step-size adapted to: 0.0027704229553356
# Iteration:  191
# 	Trajectories constructed.
# 	Epsilon: 0.7125011578938640
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1755000000000000
# 	Step-size adapted to: 0.0026959482560336
# Iteration:  192
# 	Trajectories constructed.
# 	Epsilon: 0.7117035510200640
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2110000000000000
# 	Step-size adapted to: 0.0026704580179398
# Iteration:  193
# 	Trajectories constructed.
# 	Epsilon: 0.7107467632347594
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2390000000000000
# 	Step-size adapted to: 0.0026825021580112
# Iteration:  194
# 	Trajectories constructed.
# 	Epsilon: 0.7098365019270697
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2275000000000000
# 	Step-size adapted to: 0.0026791511251455
# Iteration:  195
# 	Trajectories constructed.
# 	Epsilon: 0.7089649412344329
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2550000000000000
# 	Step-size adapted to: 0.0027128506977432
# Iteration:  196
# 	Trajectories constructed.
# 	Epsilon: 0.7081074222204702
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2080000000000000
# 	Step-size adapted to: 0.0026831728673859
# Iteration:  197
# 	Trajectories constructed.
# 	Epsilon: 0.7070982789572066
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2615000000000000
# 	Step-size adapted to: 0.0027257673914189
# Iteration:  198
# 	Trajectories constructed.
# 	Epsilon: 0.7059865001708077
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2675000000000000
# 	Step-size adapted to: 0.0027773576775149
# Iteration:  199
# 	Trajectories constructed.
# 	Epsilon: 0.7047842684271880
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2805000000000000
# 	Step-size adapted to: 0.0028483788275631
# Iteration:  200
# 	Trajectories constructed.
# 	Epsilon: 0.7034997707766270
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2205000000000000
# 	Step-size adapted to: 0.0028348811105885
# Iteration:  201
# 	Trajectories constructed.
# 	Epsilon: 0.7024183193989880
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2675000000000000
# 	Step-size adapted to: 0.0028885365795047
# Iteration:  202
# 	Trajectories constructed.
# 	Epsilon: 0.7013415613022185
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2225000000000000
# 	Step-size adapted to: 0.0028777248519907
# Iteration:  203
# 	Trajectories constructed.
# 	Epsilon: 0.7003010483488571
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2380000000000000
# 	Step-size adapted to: 0.0028892588039239
# Iteration:  204
# 	Trajectories constructed.
# 	Epsilon: 0.6990916231418381
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2635000000000000
# 	Step-size adapted to: 0.0029380614702086
# Iteration:  205
# 	Trajectories constructed.
# 	Epsilon: 0.6977068163654718
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2950000000000000
# 	Step-size adapted to: 0.0030351170788659
# Iteration:  206
# 	Trajectories constructed.
# 	Epsilon: 0.6961106723616868
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2405000000000000
# 	Step-size adapted to: 0.0030510933445318
# Iteration:  207
# 	Trajectories constructed.
# 	Epsilon: 0.6945137727026602
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2180000000000000
# 	Step-size adapted to: 0.0030328415944700
# Iteration:  208
# 	Trajectories constructed.
# 	Epsilon: 0.6932357347228180
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2540000000000000
# 	Step-size adapted to: 0.0030694549342835
# Iteration:  209
# 	Trajectories constructed.
# 	Epsilon: 0.6920894377867601
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1575000000000000
# 	Step-size adapted to: 0.0029601797711844
# Iteration:  210
# 	Trajectories constructed.
# 	Epsilon: 0.6909867016944031
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1765000000000000
# 	Step-size adapted to: 0.0028820446783284
# Iteration:  211
# 	Trajectories constructed.
# 	Epsilon: 0.6900692594337915
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2125000000000000
# 	Step-size adapted to: 0.0028569367945778
# Iteration:  212
# 	Trajectories constructed.
# 	Epsilon: 0.6891486310329402
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2270000000000000
# 	Step-size adapted to: 0.0028526546018334
# Iteration:  213
# 	Trajectories constructed.
# 	Epsilon: 0.6881852216590344
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1670000000000000
# 	Step-size adapted to: 0.0027641965110627
# Iteration:  214
# 	Trajectories constructed.
# ...
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0660000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1046
# 	Trajectories constructed.
# 	Epsilon: 0.0699395279058842
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0885000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1047
# 	Trajectories constructed.
# 	Epsilon: 0.0693554617950151
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0850000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1048
# 	Trajectories constructed.
# 	Epsilon: 0.0688940871029885
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0785000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1049
# 	Trajectories constructed.
# 	Epsilon: 0.0683649484841563
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1305000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1050
# 	Trajectories constructed.
# 	Epsilon: 0.0677299079681551
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0700000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1051
# 	Trajectories constructed.
# 	Epsilon: 0.0671262911454883
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0610000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1052
# 	Trajectories constructed.
# 	Epsilon: 0.0665363627765683
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0725000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1053
# 	Trajectories constructed.
# 	Epsilon: 0.0660593289400447
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0915000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1054
# 	Trajectories constructed.
# 	Epsilon: 0.0654817826026089
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0495000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1055
# 	Trajectories constructed.
# 	Epsilon: 0.0649779914182839
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0765000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1056
# 	Trajectories constructed.
# 	Epsilon: 0.0645064285865859
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0550000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1057
# 	Trajectories constructed.
# 	Epsilon: 0.0640492765826793
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0680000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1058
# 	Trajectories constructed.
# 	Epsilon: 0.0633868841030081
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1020000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1059
# 	Trajectories constructed.
# 	Epsilon: 0.0626258389026163
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0570000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1060
# 	Trajectories constructed.
# 	Epsilon: 0.0619892387518609
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1090000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1061
# 	Trajectories constructed.
# 	Epsilon: 0.0614321708638508
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1120000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1062
# 	Trajectories constructed.
# 	Epsilon: 0.0608329833046045
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0725000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1063
# 	Trajectories constructed.
# 	Epsilon: 0.0602327919871558
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0900000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1064
# 	Trajectories constructed.
# 	Epsilon: 0.0596213799050640
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0400000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1065
# 	Trajectories constructed.
# 	Epsilon: 0.0590735724727189
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0635000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1066
# 	Trajectories constructed.
# 	Epsilon: 0.0584583440797921
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0635000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1067
# 	Trajectories constructed.
# 	Epsilon: 0.0579010459373988
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0725000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1068
# 	Trajectories constructed.
# 	Epsilon: 0.0572228245494474
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0380000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1069
# 	Trajectories constructed.
# 	Epsilon: 0.0565488465698035
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0275000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1070
# 	Trajectories constructed.
# 	Epsilon: 0.0559726162996674
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0670000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1071
# 	Trajectories constructed.
# 	Epsilon: 0.0553490195827709
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0660000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1072
# 	Trajectories constructed.
# 	Epsilon: 0.0546395239135667
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0360000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1073
# 	Trajectories constructed.
# 	Epsilon: 0.0541002753371511
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0205000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1074
# 	Trajectories constructed.
# 	Epsilon: 0.0537743541297117
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0555000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1075
# 	Trajectories constructed.
# 	Epsilon: 0.0533378583005327
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0380000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1076
# 	Trajectories constructed.
# 	Epsilon: 0.0528462775486189
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0225000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1077
# 	Trajectories constructed.
# 	Epsilon: 0.0524005737793418
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0190000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1078
# 	Trajectories constructed.
# 	Epsilon: 0.0518893155960118
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0095000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1079
# 	Trajectories constructed.
# 	Epsilon: 0.0515645191505529
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0630000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1080
# 	Trajectories constructed.
# 	Epsilon: 0.0513389700635555
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0270000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1081
# 	Trajectories constructed.
# 	Epsilon: 0.0509381500997428
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0725000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1082
# 	Trajectories constructed.
# 	Epsilon: 0.0504069399307318
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0205000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1083
# 	Trajectories constructed.
# 	Epsilon: 0.0499155126011274
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1705000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1084
# 	Trajectories constructed.
# 	Epsilon: 0.0493957017365270
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0245000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1085
# 	Trajectories constructed.
# 	Epsilon: 0.0490578165669364
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0235000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1086
# 	Trajectories constructed.
# 	Epsilon: 0.0484347990739717
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0040000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1087
# 	Trajectories constructed.
# 	Epsilon: 0.0481587640511694
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0135000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1088
# 	Trajectories constructed.
# 	Epsilon: 0.0476907656459750
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0770000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1089
# 	Trajectories constructed.
# 	Epsilon: 0.0473820399906643
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0215000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1090
# 	Trajectories constructed.
# 	Epsilon: 0.0468927845059388
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0110000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1091
# 	Trajectories constructed.
# 	Epsilon: 0.0465613560369871
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0260000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1092
# 	Trajectories constructed.
# 	Epsilon: 0.0462730595550540
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0160000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1093
# 	Trajectories constructed.
# 	Epsilon: 0.0458924606716131
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0020000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1094
# 	Trajectories constructed.
# 	Epsilon: 0.0456615093184910
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0060000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1095
# 	Trajectories constructed.
# 	Epsilon: 0.0453332146876610
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0175000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1096
# 	Trajectories constructed.
# 	Epsilon: 0.0451200546025151
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0065000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1097
# 	Trajectories constructed.
# 	Epsilon: 0.0447302538948289
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0560000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1098
# 	Trajectories constructed.
# 	Epsilon: 0.0445383876308324
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0125000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1099
# 	Trajectories constructed.
# 	Epsilon: 0.0442957037495950
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0025000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1100
# 	Trajectories constructed.
# 	Epsilon: 0.0440121455136521
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0460000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1101
# 	Trajectories constructed.
# 	Epsilon: 0.0436700942705846
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0005000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1102
# 	Trajectories constructed.
# 	Epsilon: 0.0435424062655101
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0100000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1103
# 	Trajectories constructed.
# 	Epsilon: 0.0431930093816519
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0030000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1104
# 	Trajectories constructed.
# 	Epsilon: 0.0428966069343457
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0565000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1105
# 	Trajectories constructed.
# 	Epsilon: 0.0427552204620266
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0140000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1106
# 	Trajectories constructed.
# 	Epsilon: 0.0425903073047818
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0040000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1107
# 	Trajectories constructed.
# 	Epsilon: 0.0421901273082453
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.4630000000000000
# 	Step-size adapted to: 0.0011235575104672
# Iteration:  1108
# 	Trajectories constructed.
# 	Epsilon: 0.0418415368835579
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0040000000000000
# 	Step-size adapted to: 0.0010035061321521
# Iteration:  1109
# 	Trajectories constructed.
# 	Epsilon: 0.0417009469738586
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0015000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1110
# 	Trajectories constructed.
# 	Epsilon: 0.0413316402467434
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1720000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1111
# 	Trajectories constructed.
# 	Epsilon: 0.0411843539869749
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0100000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1112
# 	Trajectories constructed.
# 	Epsilon: 0.0406479227108785
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0040000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1113
# 	Trajectories constructed.
# 	Epsilon: 0.0402289897306651
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0705000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1114
# 	Trajectories constructed.
# 	Epsilon: 0.0399700101780438
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0015000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1115
# 	Trajectories constructed.
# 	Epsilon: 0.0396763401936039
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0000000000000000
# 	Step-size adapted to: 0.0010000000000000

# %% [markdown]
# ### MS-RT $\delta=0.001$

# %%
fig, ax = plt.subplots()
ax.plot(SMC_RWM_0001_PRIOR.εs, label='SMC-RWM-0001_A', markevery=[-1], marker='o')
ax.plot(SMC_RT_0001_PRIOR.εs, label='SMC-RT-0001_A', markevery=[-1], marker='o')
ax.plot(MS_RWM_0001_PRIOR.εs, label='MS_RWM_0001_A', markevery=[-1], marker='o')
ax.set_yscale('log')
ax.set_ylim([0.001, 100])
ax.legend()
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(np.array(SMC_RWM_0001_PRIOR.ESS)/N, label='SMC-RWM-0001_A', markevery=[-1], marker='o')
ax.plot(np.array(SMC_RT_0001_PRIOR.ESS)/N, label='SMC-RT-0001_A', markevery=[-1], marker='o')
ax.plot(np.array(MS_RWM_0001_PRIOR.ESS)/N, label='MS_RWM_0001_A', markevery=[-1], marker='o')
ax.legend()
ax.set_yscale('log')
plt.show()

# %%
MS_RWM_0001_PRIOR.ESS
# Out:
# [42000,
#  20227.864666179456,
#  20882.280311462746,
#  20730.354725174075,
#  20180.063473307415,
#  19585.25152384854,
#  18301.50409943908,
#  15435.890520344276,
#  10366.90935469493,
#  3688.1979689754203,
#  1634.2745557957585,
#  811.1136072568241,
#  682.8575022128423,
#  1520.6390308930963,
#  1427.762986168696,
#  1609.3916918176926,
#  1252.1974212243324,
#  1056.4917281229948,
#  716.7245161681171,
#  1080.120287776092,
#  1045.9318297855937,
#  773.0090119117326,
#  854.1412377227135,
#  760.8956841394163,
#  866.8157024580141,
#  828.3933293338171,
#  816.252415037964,
#  919.940276612574,
#  830.4773786708853,
#  1173.320625722115,
#  1052.888394262977,
#  757.220552533621,
#  735.2645462532473,
#  1178.2834027551112,
#  773.4404354499605,
#  1019.871634310143,
#  875.232272055089,
#  751.0090632054624,
#  1038.8278546493184,
#  928.9648410992314,
#  732.7013444705185,
#  999.9508543619282,
#  873.1224283492246,
#  1024.0890208594944,
#  939.5602105407698,
#  1202.5479895184553,
#  1130.2638198775353,
#  1076.8477808088674,
#  1288.0028903993714,
#  738.555925882197,
#  1079.4025547153994,
#  1192.7250531435561,
#  795.7266933810428,
#  1173.1180410355887,
#  799.6536133000798,
#  872.8477287822856,
#  1008.06267832958,
#  795.0558683017559,
#  1252.9901051537577,
#  790.1945571779537,
#  1353.4331549292028,
#  929.7788739316228,
#  677.8216962191691,
#  929.2914029884679,
#  902.2164745926278,
#  1007.5053543784244,
#  978.5439795423513,
#  974.8136855051712,
#  766.005914426407,
#  1356.416614130596,
#  1291.7832859643204,
#  627.6735255601934,
#  1192.6876000497725,
#  1246.038222006336,
#  1486.2186046466106,
#  1683.3865816887253,
#  1901.592858973464,
#  1866.6509150070278,
#  170.44554943502752,
#  1507.508659107136,
#  532.0868938192334,
#  1157.2833619274602,
#  989.1791841528452,
#  1103.6376564506772,
#  781.5540751074362,
#  1063.511075169304,
#  864.5127564767955,
#  1134.6709534018853,
#  992.5698259255091,
#  814.6551950335873,
#  1110.7172991099212,
#  1001.7079529133069,
#  796.472913910749,
#  970.6941107559276,
#  947.7924845283443,
#  1143.8424284788357,
#  926.7729189905592,
#  875.8404750668748,
#  1135.7296799715605,
#  943.8362415587058,
#  1041.8422911203156,
#  946.8039534895053,
#  1201.8759225952444,
#  829.8213027899643,
#  1100.8678913301271,
#  1015.862525957225,
#  904.8437611849101,
#  1246.854556721626,
#  1194.7980970798433,
#  1039.8409334062342,
#  994.8890198996385,
#  1021.8880943116309,
#  878.9208395421348,
#  1062.844762375197,
#  1223.874957192061,
#  1212.794783235481,
#  867.8649747145777,
#  1194.8280784745311,
#  1268.8568444646178,
#  1096.8488119843494,
#  1235.8432425342858,
#  1085.893328764563,
#  1104.8631473415674,
#  1035.8392359083578,
#  1110.8878083303825,
#  972.894500764099,
#  1243.9278226095223,
#  1043.9073777512178,
#  1243.9104141230493,
#  827.9503502269808,
#  1254.9379127142504,
#  911.903405920237,
#  916.9161451894466,
#  1017.902210215545,
#  1285.89934548873,
#  1049.9169493727131,
#  1234.9035667194157,
#  1171.8989520010466,
#  1155.9163311375403,
#  1164.8910281527922,
#  1096.8716564031865,
#  1142.8647966256,
#  1219.843379221853,
#  1262.881427321134,
#  1222.9017801285788,
#  959.9099369019291,
#  1198.9035873495136,
#  1007.9253905255433,
#  1030.8828134712876,
#  1257.934892337796,
#  1271.8884895659673,
#  913.9419833535013,
#  1271.8990413652955,
#  1125.9181928275561,
#  956.9349753884339,
#  1249.936092458782,
#  1175.967990694912,
#  1269.9465147286553,
#  753.9479842388614,
#  1122.926590954664,
#  1037.9546496016226,
#  1071.955643595769,
#  1035.9143401443075,
#  1156.8949479946696,
#  1271.9126818333714,
#  1369.9176842689544,
#  1392.9542380791013,
#  1133.9363155949718,
#  959.957447546057,
#  1018.9575471360621,
#  1017.9585351226355,
#  1076.945949120078,
#  1204.9406252306908,
#  1041.9512597076941,
#  942.9547583781174,
#  1252.9355902352484,
#  1204.9344621730215,
#  1234.932004282349,
#  981.9479733689509,
#  1126.9339895947166,
#  1251.9308233347203,
#  1114.934636137749,
#  1349.8970155821464,
#  1208.8643660001956,
#  1322.890921582168,
#  1328.9047226264724,
#  1170.934305929965,
#  1264.9043345152388,
#  1130.9316839168898,
#  1172.9590503648815,
#  1101.9636768739506,
#  1156.9422370340578,
#  1023.956308504652,
#  1244.8604587966963,
#  1171.9276028662632,
#  913.9298732858549,
#  1233.9385119946862,
#  1178.9294517621831,
#  1074.9334901835662,
#  1250.9146230628028,
#  1304.899408410677,
#  1144.914174015718,
#  1080.936182059601,
#  1243.9075519741402,
#  1234.9092594824501,
#  1103.909800330022,
#  1385.9149583558676,
#  1296.9036683186418,
#  1001.9160325127247,
#  1175.9412280067904,
#  1124.9540001353353,
#  1191.9316315308863,
#  862.7714685145313,
#  1160.9537435725151,
#  1123.9435543962395,
#  1167.8966584982832,
#  1092.902470173424,
#  1305.809728795108,
#  1363.7175227920736,
#  1410.6548030945798,
#  1318.748905376708,
#  1292.5662784808228,
#  1233.7714006788071,
#  1283.79523915478,
#  1282.7245990488548,
#  1412.5004115406362,
#  1212.4528558432933,
#  1361.617508009975,
#  1367.404509871697,
#  1306.3879209079191,
#  1356.4205536245463,
#  1360.5393406723383,
#  1342.3704648710377,
#  1230.633881341287,
#  1150.5190749905344,
#  1367.2037658723777,
#  1241.1643189516922,
#  1405.1400167095019,
#  1358.8253345756525,
#  1335.0960335182228,
#  1291.078735609187,
#  1322.2149954686909,
#  1222.1876455125062,
#  1275.3749760301266,
#  1129.6069910608458,
#  1120.5365616119504,
#  1072.6877528348455,
#  1155.7702606807254,
#  1100.8589394736232,
#  750.8492339175855,
#  803.888695010618,
#  1145.8915120039867,
#  968.8835871877671,
#  725.8992131112213,
#  1259.8951988574831,
#  1329.9103125932172,
#  700.9219529421293,
#  1159.947658037944,
#  936.9381499154217,
#  1110.947201615077,
#  867.9556097146778,
#  1055.9602332596837,
#  984.9582230896904,
#  890.9687968131773,
#  727.9618886803639,
#  1166.9582416268568,
#  960.9658458161102,
#  912.9611543290473,
#  774.9629572944784,
#  1203.9598268748853,
#  1029.966237360803,
#  1178.9676054443557,
#  945.9652220497517,
#  951.9797474453467,
#  1086.9763815784968,
#  888.9662927738996,
#  1125.9740761764986,
#  1021.9685169651457,
#  1075.9682110495241,
#  1144.960211789808,
#  1131.9637187800379,
#  1096.9663793326527,
#  1047.971195047599,
#  989.9740019320246,
#  1047.9707922228413,
#  1132.972424380649,
#  976.9792586390134,
#  1091.972179807284,
#  1156.9730726443781,
#  1035.9770007798177,
#  1045.973024254369,
#  1187.9755052383266,
#  1034.9850680681943,
#  1063.9828831212117,
#  977.9855454264479,
#  1090.9730856009028,
#  1017.9776096270573,
#  1189.976569478045,
#  1066.9788023383235,
#  1192.9766939614815,
#  1226.9778225537864,
#  1283.9879458344762,
#  1029.9801062890883,
#  1145.9874414183182,
#  1102.987052327664,
#  1042.9854491579574,
#  999.9794011570826,
#  1176.9847809282871,
#  1068.9839812975902,
#  1021.9860105709428,
#  1190.9850470065346,
#  977.9831894038393,
#  1196.9777713058447,
#  1174.9820092564607,
#  1100.9820452753268,
#  1219.9859666024909,
#  1262.9803105821186,
#  1280.9733585178974,
#  1170.988523327604,
#  1254.985520889606,
#  1085.9893118754808,
#  1040.9887846119927,
#  1130.9759488408893,
#  954.9891783972989,
#  1185.9889149038765,
#  1062.989420828149,
#  1055.987631442421,
#  1274.9848389688627,
#  1160.9861844255292,
#  1159.9900978066235,
#  1551.986156238077,
#  1049.9909606772765,
#  963.9895126223547,
#  1307.9820906593538,
#  1140.9838627734061,
#  1143.9837830298181,
#  1307.9851033070254,
#  1060.9831913249227,
#  1322.9839175022883,
#  1225.9849729720938,
#  1097.9820470394914,
#  1274.981415065685,
#  1322.9842633348712,
#  1101.9775208707672,
#  1080.9853245467145,
#  1223.9829636217846,
#  1020.9874377312873,
#  1079.989106461759,
#  964.991601720005,
#  1221.9856646407395,
#  1187.9900033305762,
#  955.9894904456709,
#  1192.9874292973325,
#  922.9904973589119,
#  1087.98885657271,
#  1131.9885912874395,
#  1068.9901271056917,
#  934.9898776457845,
#  1135.9926313926433,
#  1277.9845476261332,
#  989.9928883486613,
#  1038.991636459654,
#  1125.9898242977122,
#  1252.9855591021123,
#  1101.9912527232402,
#  1290.9895077534102,
#  1072.989721958194,
#  1023.9896458551307,
#  1227.9897163161227,
#  1065.9890967574927,
#  1214.9924005506548,
#  1316.9910574517226,
#  1246.989565422501,
#  1025.9874333317912,
#  1197.988475280215,
#  1042.9897161214585,
#  1116.9842531239399,
#  1268.9892824228425,
#  1022.9893550294938,
#  1098.990473581855,
#  942.9928747448209,
#  1258.993819954995,
#  1176.9911883731795,
#  1090.9915598641244,
#  1116.992707777754,
#  1130.9884770994058,
#  1003.989573013536,
#  1230.9864680416335,
#  1129.9906679067005,
#  1222.9868257302662,
#  1296.9905451344853,
#  1037.989430924635,
#  1098.9900445912021,
#  1177.9875871498796,
#  1315.985332502138,
#  1054.9867970011792,
#  1183.991188531272,
#  1229.9906577107754,
#  1087.9915132818412,
#  1131.9908383030597,
#  1196.9905011030594,
#  1239.988920385269,
#  1137.9901617814694,
#  1175.9794642356721,
#  1108.9927999570086,
#  1042.9868754333136,
#  1208.9864947355227,
#  996.9882924300151,
#  1228.9872833084164,
#  1164.986213350134,
#  1205.99256714184,
#  1171.9878083296649,
#  994.9885570258384,
#  1123.9880288634122,
#  1149.9895420166051,
#  1078.9903711568452,
#  1363.980615906819,
#  1177.9886776126477,
#  1354.9721270434418,
#  1189.9837714566645,
#  1108.9850805289766,
#  1186.986856377759,
#  1113.9829642431725,
#  1094.9858004369025,
#  1230.9813372926187,
#  1270.980303347121,
#  1105.9858615594655,
#  1107.9889049111016,
#  1217.9903125746698,
#  1164.9883510418945,
#  1049.9913139694168,
#  895.9943944302547,
#  1184.98806379165,
#  995.9885331990042,
#  958.9879829875747,
#  1167.9872809189662,
#  994.9880947237075,
#  1131.9892897753439,
#  1061.9865829287528,
#  1194.9865910206745,
#  1346.9859068392534,
#  1102.9891260855372,
#  1212.983659539158,
#  989.9871362181716,
#  1323.9857949459874,
#  1245.986289147051,
#  1307.990152939363,
#  1266.9891852328803,
#  922.9946662971796,
#  1084.994677757243,
#  1085.9951964761117,
#  1280.9947335492425,
#  1280.9946493759392,
#  717.996480547879,
#  905.9940521372216,
#  1155.9863697372018,
#  955.9943606375045,
#  1149.9933579957383,
#  1232.9943640574018,
#  988.9946306802871,
#  1040.9919527265947,
#  1122.9925427606083,
#  950.9935612554757,
#  1150.9943787498155,
#  909.9915235644285,
#  896.9957177977138,
#  979.9954227434272,
#  938.9964518318552,
#  913.997322730858,
#  926.9957602320727,
#  898.9976581505749,
#  1164.9969818450973,
#  955.9967938236076,
#  1109.9946459229632,
#  1137.995604349099,
#  907.9967303668608,
#  1258.995226401048,
#  1095.9973308177634,
#  816.9938538258311,
#  803.9976431082233,
#  873.9962361642503,
#  889.997513064796,
#  861.9973420019634,
#  723.9975347101943,
#  696.9978786384773,
#  746.9973677242706,
#  819.9983783085206,
#  968.9966423656738,
#  719.99797429068,
#  808.9971010872976,
#  731.99743052591,
#  977.9969878066386,
#  675.9949003149845,
#  714.9939207793074,
#  1087.997018936845,
#  840.9959955307266,
#  1013.9967713298636,
#  1000.9939474529954,
#  854.9965139136121,
#  836.9934711355866,
#  1249.9952017031387,
#  957.9935802902115,
#  1097.9951596771855,
#  868.9975122211412,
#  747.9973597417622,
#  1183.996908769827,
#  993.9972746753474,
#  976.9970326709488,
#  915.9969397121288,
#  580.998248884238,
#  1345.99486505105,
#  1059.9967511006942,
#  749.9976408726552,
#  793.996055854455,
#  1112.996971814982,
#  672.9980108856286,
#  1286.9972486071217,
#  766.9986466492743,
#  932.9965208327797,
#  1227.9951520806621,
#  628.9980586269095,
#  824.9949158210799,
#  790.9966188930043,
#  1103.993707555369,
#  1224.9930731301065,
#  1309.9957329776196,
#  711.9979793422141,
#  1062.9962331385213,
#  645.996931935149,
#  1125.9953318238126,
#  912.9982763916082,
#  1130.9974511258354,
#  757.9971577885624,
#  852.9970546450866,
#  810.9966434981749,
#  879.9975960675428,
#  716.9981772612076,
#  838.9984658438048,
#  650.998925591544,
#  1011.9976368933203,
#  786.998554300193,
#  832.9985218020939,
#  1092.998151816631,
#  500.9985737722732,
#  1561.9982767160727,
#  524.9988445526695,
#  1092.9983118592877,
#  436.99898128984717,
#  1033.9966635040519,
#  761.9964732318016,
#  1051.9967466103217,
#  1310.997058799313,
#  852.9959035832765,
#  722.997646988265,
#  1013.9977342241483,
#  878.9963304965065,
#  1003.9952207652318,
#  982.9967296384945,
#  1426.9959259586715,
#  869.9982348749008,
#  1139.9957612170763,
#  1470.9987008391936,
#  313.9976970826751,
#  942.997902018387,
#  826.9983920565454,
#  812.9989915662185,
#  1009.9986920107827,
#  550.9979277661514,
#  749.9981985855592,
#  1027.9972357737597,
#  714.9972937793088,
#  1216.9973672056806,
#  1457.9974225143087,
#  635.9978247991914,
#  668.9978926572492,
#  993.9973187915546,
#  1170.9975415924393,
#  655.9980737502991,
#  835.9973109687554,
#  748.9988031559212,
#  905.998083938815,
#  557.9976949009063,
#  870.9982361978292,
#  558.9980348291324,
#  1074.9983111979925,
#  802.9970589412721,
#  914.9984154013914,
#  1109.998193390649,
#  1363.9982996802278,
#  784.9990733408449,
#  580.9986284067054,
#  819.997947375531,
#  1221.998692748889,
#  300.99904507241837,
#  1189.9977230289803,
#  983.9980296633069,
#  1037.9986605270774,
#  540.9979654552909,
#  880.9984369537667,
#  1275.9977168774974,
#  1361.9975747435992,
#  1783.9987645619785,
#  1752.9991697178805,
#  69.99970958599691,
#  1079.9989299760912,
#  774.9995702846596,
#  453.9996125755073,
#  1244.9996648053534,
#  223.99983002656734,
#  559.9990300564943,
#  491.9986249591748,
#  1686.9984174279982,
#  1788.9986386628566,
#  1082.9992382148937,
#  189.99987557624684,
#  591.999490026166,
#  712.999201237992,
#  863.998910381961,
#  675.9988543270122,
#  1658.9982195613668,
#  1339.9986067988218,
#  234.99908298433203,
#  874.9984667320765,
#  916.9979197537111,
#  945.9971545199752,
#  553.9979081657362,
#  528.9978455924464,
#  1218.9982008786183,
#  836.9988732626989,
#  792.9980166940098,
#  483.99943388783095,
#  884.9987850868365,
#  664.999012666052,
#  518.9990507895039,
#  977.9989264813508,
#  623.9980628657556,
#  1249.9984071833776,
#  1346.9988065134276,
#  229.99900266242503,
#  968.9984037934768,
#  939.9986746898331,
#  1218.9991414632818,
#  403.99918703608085,
#  647.9993275153732,
#  973.9990314657083,
#  963.9994320098803,
#  422.9986461270448,
#  957.9984436494884,
#  562.9994712210905,
#  1045.9994908179094,
#  467.99956947434976,
#  1078.9996044130658,
#  1401.9992311851145,
#  146.99944379129175,
#  818.9983852812726,
#  793.999713834469,
#  1193.9995658054172,
#  658.9998125205232,
#  90.99982241396906,
#  921.9993139765623,
#  1336.9996801248283,
#  402.9997049252573,
#  112.9998612495674,
#  1594.9992257853867,
#  501.999821228247,
#  718.9987672234639,
#  116.99969730943671,
#  1026.9994760902239,
#  295.99939905785595,
#  251.99979801358987,
#  961.9992289181037,
#  870.9994251133425,
#  497.99945659488594,
#  545.9992021213077,
#  1111.9990358998718,
#  666.999136831898,
#  543.999595810926,
#  1572.9965938662758,
#  1631.9995054334402,
#  69.9997370534663,
#  1073.998379636771,
#  812.998907398593,
#  1470.9984182646947,
#  182.99915083042808,
#  1017.9980808390112,
#  795.9976462943,
#  1081.9985504692588,
#  627.9993658583805,
#  1668.9984735349772,
#  323.99969828774385,
#  905.9990227856701,
#  1374.9993674701418,
#  214.99945717504698,
#  571.9994528103825,
#  1113.9993313853831,
#  566.9992441994718,
#  635.9995045514896,
#  337.99956903303644,
#  678.9996536373834,
#  653.9992636511047,
#  1077.9992451202745,
#  1658.9991408011174,
#  93.99940758540406,
#  818.9995459156884,
#  911.9995249617685,
#  956.9996962945847,
#  641.9997840327932,
#  108.99984980409093,
#  1243.9987333385288,
#  1268.998824734209,
#  337.99961201639445,
#  639.9996825214658,
#  293.9989433138436,
#  1314.99770612063,
#  1549.998859868628,
#  645.9988332703576,
#  860.999156051362,
#  304.99905255858704,
#  1084.9981200458374,
#  744.9990676773281,
#  781.9993436810161,
#  1082.999621823501,
#  218.99958381235157,
#  1040.9985319273758,
#  561.9993761923678,
#  1477.9990532525273,
#  1067.9992453158304,
#  318.99957245127905,
#  945.9990262793847,
#  725.9982414595705,
#  1445.9994306313522,
#  115.99955286722549,
#  1408.999246700151,
#  374.99928254021256,
#  1784.9988090930115,
#  427.9996510277866,
#  1665.999146454075,
#  1897.9996921966538,
#  84.9999648453113,
#  690.9993377189392,
#  1707.9997512404207,
#  266.99988010190845,
#  118.99993646610606,
#  996.9998372014686,
#  514.9997743899528,
#  1938.9998084098625,
#  39.99979131434989,
#  1097.999311899292,
#  530.999586167833,
#  1621.9997928618925,
#  56.99991017461938,
#  633.9995028377102,
#  861.998188040183,
#  1110.9989056485401,
#  157.99946004502965,
#  1199.9982929590635,
#  904.9986156935688,
#  514.9992844464907,
#  1036.9983808165996,
#  925.9983486643151,
#  435.99905532020205,
#  1049.9988588686565,
#  934.997546620525,
#  1616.9990803531277,
#  1029.9997381523785,
#  1606.9994373278748,
#  135.9996587152005,
#  864.9993742399272,
#  281.9992301773172,
#  835.9996303321853,
#  518.9996105607504,
#  1740.9993082725318,
#  1871.999456784226,
#  190.99937848943486,
#  1720.9993779669967,
#  280.9997218350702,
#  606.9994829665218,
#  667.9996840201865,
#  353.99933453186065,
#  294.99969376874736,
#  1298.9996866882911,
#  123.99986359525826,
#  1387.9993736495392,
#  1276.999377636019,
#  975.9995143486634,
#  143.999321160874,
#  1318.9985406908818,
#  1093.999284277964,
#  161.99939953459662,
#  526.9993238743167,
#  1080.9985753699243,
#  1072.998381101716,
#  297.99890569643713,
#  1411.9993532350115,
#  591.9993798555801,
#  511.9994039064764,
#  1664.9985452873816,
#  658.9991735374645,
#  1672.9986254394867,
#  1555.9994001602654,
#  119.99956300849632,
#  1049.9991796412303,
#  570.9990417978906,
#  649.9996251535513,
#  944.9990208876181,
#  326.9998571062801,
#  814.9994645698201,
#  1089.999744481262,
#  1454.9997193499867,
#  78.99977013622656,
#  1506.9994706808607,
#  79.99983209345983,
#  535.9994777445887,
#  959.9989117902425,
#  129.999376761596,
#  980.9991960033323,
#  845.9989661749279,
#  968.999130802323,
#  503.99925532015897,
#  396.99910687993685,
#  1225.9985256477735,
#  680.999286370805,
#  737.9989647558718,
#  842.9993528206098,
#  390.9994847521556,
#  1157.9989494002023,
#  435.99912323113074,
#  1312.9990710391676,
#  603.9989111010206,
#  1451.998228157349,
#  265.99917706013076,
#  913.9991708386984,
#  1119.99932555278,
#  882.9994491604019,
#  866.9996779976584,
#  213.99931155655548,
#  929.999309557991,
#  455.9992517991555,
#  405.999820859981,
#  919.998977829444,
#  789.9995312873474,
#  418.9987080527006,
#  548.9995529975486,
#  617.9992413761291,
#  608.9986364364073,
#  688.9988672723024,
#  712.9987023838618,
#  877.998765957597,
#  1347.999113260801,
#  999.9992660357179,
#  153.99950737729228,
#  1151.9989649021866,
#  402.99949353919953,
#  1576.9984254644432,
#  1277.998483603438,
#  186.99928965778628,
#  1024.9976974346218,
#  1045.9984877693862,
#  1086.998894447744,
#  1218.999093333405,
#  226.9991456469205,
#  886.998664470084,
#  1132.9987773557782,
#  629.9994448690268,
#  636.9987983962728,
#  1203.9993022511094,
#  548.99939690199,
#  410.99923045971,
#  1553.9992292793831,
#  699.9997049230121,
#  308.99940768616574,
#  436.998746073729,
#  1111.998859698764,
#  1079.9993222699927,
#  172.9994839257776,
#  987.9984242781152,
#  664.9991783623258,
#  643.9987561965008,
#  479.99870429295356,
#  909.9971368704771,
#  979.9977767010008,
#  938.9981943981564,
#  784.997132958466,
#  1300.9966594265175,
#  944.996855452796,
#  713.9976203873371,
#  1226.997663283785,
#  598.9969355385978,
#  951.9976102041568,
#  489.9980868243886,
#  971.9976417202267,
#  986.9971553579421,
#  810.998742993233,
#  459.99865860689374,
#  867.9977058547389,
#  939.9982530115686,
#  919.9983379970024,
#  681.9983992668165,
#  718.997057507024,
#  871.9972622197506,
#  801.9981926890326,
#  838.9988066074282,
#  916.9989436652128,
#  1060.9991776226411,
#  484.998885362512,
#  1077.9991478435547,
#  486.9995343819936,
#  731.9992019426339,
#  1076.9986464662416,
#  372.99881500501925,
#  800.9988844278519,
#  718.9990857933901,
#  762.9994819813488,
#  864.9986511235873,
#  377.99920869431435,
#  942.998653141231,
#  623.99846985675,
#  753.9985337344866,
#  1068.9976190435066,
#  1008.997632842724,
#  1098.9980589901234,
#  1600.997621753226,
#  278.9990040547942,
#  1063.9963055309354,
#  968.9979064243847,
#  1119.997392902148,
#  1231.998024447062,
#  343.9980305557461,
#  1098.9966237615706,
#  922.996827345625,
#  1074.9973770128672,
#  1130.9864483288359,
#  692.9945215649796,
#  1277.996488780789,
#  1446.9977985644562,
#  694.9980927423417,
#  856.9943259995855,
#  767.9968823914339,
#  1012.9937478473279,
#  608.9968473067515,
#  1164.992019727966,
#  1262.9924159785528,
#  866.9935677920805,
#  1456.9935877793546,
#  1083.9953968390337,
#  1041.9931674457162,
#  908.9969424330658,
#  1239.9943338661985,
#  724.9947897019606,
#  1010.9973059067855,
#  1038.997434914911,
#  791.9966049442731,
#  828.9962184337738,
#  1221.9946572863387,
#  753.9967367603085,
#  986.9937081906238,
#  838.9971232102115,
#  882.9955450261007,
#  927.9940725774347,
#  1056.9966858602963,
#  1236.9956210602293,
#  766.9957888472788,
#  1229.99416340721,
#  1392.9934150759946,
#  851.9961039347944,
#  1355.9959510706872,
#  1298.9955146526925,
#  879.994812364065,
#  1153.996542583818,
#  776.9967300718048,
#  984.9975444680115,
#  770.9967312805725,
#  1170.9943634879191,
#  815.9950938517391,
#  1139.9930665395082,
#  952.9964007839408,
#  1133.9948208324583,
#  995.9952831775308,
#  1070.9973422596722,
#  1207.9969486476766,
#  682.9974892219425,
#  889.9966076396624,
#  1011.997232670688,
#  589.9972290749735,
#  1025.9971650376724,
#  671.99738821663,
#  717.9970307614029,
#  927.9974372917125,
#  1075.9950575102205,
#  722.9980730552469,
#  1154.9970650359676,
#  830.9951820598742,
#  913.9905322763543,
#  1349.9907169855005,
#  1305.9938344328782,
#  796.9961041258911,
#  1144.9939436047705,
#  1366.994516288641,
#  916.9959242415139,
#  1112.9969142159268,
#  ...]

# %% [markdown]
# # FIXED STEP SIZE

# %% [markdown]
# ### SMC-RWM

# %%
SMC_RWM_01 = SMCAdaptive(generate_settings(
        d=d, 
        N=N,
        B=B,
        δ=0.1,
        δmin=δmin,
        min_pm=min_pm,
        verbose=True,
        εs_fixed=None,
        adaptiveε=True,
        adaptiveδ=False,
        z0_manual=init_particles,
        pm_target=0.23,
        pm_switch=pm_switch,
        prior_seed=seed,
        low_memory=True,
        integrator='rwm',
        εprop_switch=0.01,
        ε0_manual=ε0_manual,
        quantile_value=quantile_value,
        initialization='manual',
        switch_strategy='pm',
        kernel='uniform',
        use_autograd=False,
        stopping_criterion={'εmin', 'pm'}))
_ = SMC_RWM_01.sample()
# Out:
# Stochastic Kernel: RWM.
# Stopping criterion:  εmin, pm.
# Iteration:  1
# 	Particles resampled.
# 	Epsilon: 0.0000000268051501
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0000000000000000
# 	Step-size kept fixed at: 0.1000000000000000

# %%
SMC_RWM_001 = SMCAdaptive(generate_settings(
        d=d, 
        N=N,
        B=B,
        δ=0.01,
        δmin=δmin,
        min_pm=min_pm,
        verbose=True,
        εs_fixed=None,
        adaptiveε=True,
        adaptiveδ=False,
        z0_manual=init_particles,
        pm_target=0.23,
        pm_switch=pm_switch,
        prior_seed=seed,
        low_memory=True,
        integrator='rwm',
        εprop_switch=0.01,
        ε0_manual=ε0_manual,
        quantile_value=quantile_value,
        initialization='manual',
        switch_strategy='pm',
        kernel='uniform',
        use_autograd=False,
        stopping_criterion={'εmin', 'pm'}))
_ = SMC_RWM_001.sample()
# Out:
# Stochastic Kernel: RWM.
# Stopping criterion:  εmin, pm.
# Iteration:  1
# 	Particles resampled.
# 	Epsilon: 0.0000000265153272
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0000000000000000
# 	Step-size kept fixed at: 0.0100000000000000

# %%
SMC_RWM_0001 = SMCAdaptive(generate_settings(
        d=d, 
        N=2000,
        B=20,
        δ=0.001,
        δmin=1e-3,
        min_pm=1e-4,
        verbose=True,
        εs_fixed=None,
        adaptiveε=True,
        adaptiveδ=False,
        z0_manual=init_particles,
        pm_target=0.23,
        pm_switch=0.1,
        prior_seed=seed,
        low_memory=True,
        integrator='rwm',
        εprop_switch=0.01,
        ε0_manual=ε0_manual,
        quantile_value=0.9,
        initialization='manual',
        switch_strategy='pm',
        kernel='uniform',
        use_autograd=False,
        stopping_criterion={'εmin', 'pm'}))
_ = SMC_RWM_0001.sample()
# Out:
# Stochastic Kernel: RWM.
# Stopping criterion:  εmin, pm.
# Iteration:  1
# 	Particles resampled.
# 	Epsilon: 16.5631044179340634
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4900000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  2
# 	Particles resampled.
# 	Epsilon: 14.6134849862661582
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4015000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  3
# 	Particles resampled.
# 	Epsilon: 13.5177601177125730
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3430000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  4
# 	Particles resampled.
# 	Epsilon: 12.8114533557872754
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2610000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  5
# 	Particles resampled.
# 	Epsilon: 12.1586389216278299
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2430000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  6
# 	Particles resampled.
# 	Epsilon: 11.5961772270198509
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2225000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  7
# 	Particles resampled.
# 	Epsilon: 11.3030545915769594
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1919999999999999
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  8
# 	Particles resampled.
# 	Epsilon: 10.9800519308743088
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1870000000000001
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  9
# 	Particles resampled.
# 	Epsilon: 10.6631227505282631
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1705000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  10
# 	Particles resampled.
# 	Epsilon: 10.4237386193415009
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1560000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  11
# 	Particles resampled.
# 	Epsilon: 10.2213056360594550
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1515000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  12
# 	Particles resampled.
# 	Epsilon: 10.0460927276037300
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1575000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  13
# 	Particles resampled.
# 	Epsilon: 9.7944358290309363
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1294999999999999
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  14
# 	Particles resampled.
# 	Epsilon: 9.5801601012064523
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1450000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  15
# 	Particles resampled.
# 	Epsilon: 9.3942513318108070
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1294999999999999
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  16
# 	Particles resampled.
# 	Epsilon: 9.1556404584845179
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1120000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  17
# 	Particles resampled.
# 	Epsilon: 8.9308448806741225
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0970000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  18
# 	Particles resampled.
# 	Epsilon: 8.7840288525240755
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1035000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  19
# 	Particles resampled.
# 	Epsilon: 8.6503888232447022
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1010000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  20
# 	Particles resampled.
# 	Epsilon: 8.5081380285778039
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0855000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  21
# 	Particles resampled.
# 	Epsilon: 8.3692693802860525
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0885000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  22
# 	Particles resampled.
# 	Epsilon: 8.2365388753763913
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0940000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  23
# 	Particles resampled.
# 	Epsilon: 8.0796981320675378
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0725000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  24
# 	Particles resampled.
# 	Epsilon: 7.9288736639795525
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0805000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  25
# 	Particles resampled.
# 	Epsilon: 7.7940320925016264
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0710000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  26
# 	Particles resampled.
# 	Epsilon: 7.6512428939797408
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0795000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  27
# 	Particles resampled.
# 	Epsilon: 7.5105342565531492
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0730000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  28
# 	Particles resampled.
# 	Epsilon: 7.3176741702693135
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0629999999999999
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  29
# 	Particles resampled.
# 	Epsilon: 7.1646699116330943
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0530000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  30
# 	Particles resampled.
# 	Epsilon: 6.9905895116482286
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0530000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  31
# 	Particles resampled.
# 	Epsilon: 6.8879870957916740
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0460000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  32
# 	Particles resampled.
# 	Epsilon: 6.7578074776762733
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0350000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  33
# 	Particles resampled.
# 	Epsilon: 6.5999428599736349
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0270000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  34
# 	Particles resampled.
# 	Epsilon: 6.4785899983814366
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0250000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  35
# 	Particles resampled.
# 	Epsilon: 6.3123583829464325
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0200000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  36
# 	Particles resampled.
# 	Epsilon: 6.1381249416477868
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0155000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  37
# 	Particles resampled.
# 	Epsilon: 5.9673956706948026
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0170000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  38
# 	Particles resampled.
# 	Epsilon: 5.8543383019060409
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0090000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  39
# 	Particles resampled.
# 	Epsilon: 5.7631550218454919
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0090000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  40
# 	Particles resampled.
# 	Epsilon: 5.6324538359806855
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0050000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  41
# 	Particles resampled.
# 	Epsilon: 5.4320875077376982
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0075000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  42
# 	Particles resampled.
# 	Epsilon: 5.3486286899958397
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0080000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  43
# 	Particles resampled.
# 	Epsilon: 5.1420304408806210
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0020000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  44
# 	Particles resampled.
# 	Epsilon: 4.8165419431005638
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0034999999999999
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  45
# 	Particles resampled.
# 	Epsilon: 4.7223928102111321
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0020000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  46
# 	Particles resampled.
# 	Epsilon: 4.2120455575109226
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0014999999999999
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  47
# 	Particles resampled.
# 	Epsilon: 3.8815285214503157
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0004999999999999
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  48
# 	Particles resampled.
# 	Epsilon: 3.1650094297754205
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0010000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  49
# 	Particles resampled.
# 	Epsilon: 2.5142303080226491
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0004999999999999
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  50
# 	Particles resampled.
# 	Epsilon: 0.2480883461517851
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0000000000000000
# 	Step-size kept fixed at: 0.0010000000000000

# %% [markdown]
# ### SMC-RT

# %%
SMC_RT_01 = SMCAdaptive(generate_settings(
        d=d, 
        N=N,
        B=B,
        δ=0.1,
        δmin=1e-3,
        min_pm=1e-4,
        verbose=True,
        εs_fixed=None,
        adaptiveε=True,
        adaptiveδ=False,
        z0_manual=init_particles,
        pm_target=0.23,
        pm_switch=0.01,
        prior_seed=seed,
        low_memory=True,
        integrator='rwm_then_thug',
        εprop_switch=0.01,
        ε0_manual=ε0_manual,
        quantile_value=0.3,
        initialization='manual',
        switch_strategy='pm',
        kernel='uniform',
        use_autograd=False,
        stopping_criterion={'εmin', 'pm'}))
_ = SMC_RT_01.sample()
# Out:
# Stochastic Kernel: RWM.
# Stopping criterion:  εmin, pm.
# Iteration:  1
# 	Particles resampled.
# 	Epsilon: 0.0000000044084009
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0000000000000000
# 	Step-size kept fixed at: 0.1000000000000000
#
#
# ####################################
# ### SWITCHING TO THUG KERNEL ###
# ####################################

# %%
SMC_RT_001 = SMCAdaptive(generate_settings(
        d=d, 
        N=N,
        B=B,
        δ=0.01,
        δmin=δmin,
        min_pm=min_pm,
        verbose=True,
        εs_fixed=None,
        adaptiveε=True,
        adaptiveδ=False,
        z0_manual=init_particles,
        pm_target=0.23,
        pm_switch=pm_switch,
        prior_seed=seed,
        low_memory=True,
        integrator='rwm_then_thug',
        εprop_switch=0.01,
        ε0_manual=ε0_manual,
        quantile_value=quantile_value,
        initialization='manual',
        switch_strategy='pm',
        kernel='uniform',
        use_autograd=False,
        stopping_criterion={'εmin', 'pm'}))
_ = SMC_RT_001.sample()
# Out:
# Stochastic Kernel: RWM.
# Stopping criterion:  εmin, pm.
# Iteration:  1
# 	Particles resampled.
# 	Epsilon: 14.6090738258715049
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1065000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  2
# 	Particles resampled.
# 	Epsilon: 10.2168393978358232
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0295000000000000
# 	Step-size kept fixed at: 0.0100000000000000
#
#
# ####################################
# ### SWITCHING TO THUG KERNEL ###
# ####################################
#
#
# Iteration:  3
# 	Particles resampled.
# 	Epsilon: 0.0000005384791395
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0000000000000000
# 	Step-size kept fixed at: 0.0100000000000000

# %%
SMC_RT_0001 = SMCAdaptive(generate_settings(
        d=d, 
        N=N,
        B=B,
        δ=0.001,
        δmin=δmin,
        min_pm=min_pm,
        verbose=True,
        εs_fixed=None,
        adaptiveε=True,
        adaptiveδ=False,
        z0_manual=init_particles,
        pm_target=0.23,
        pm_switch=pm_switch,
        prior_seed=seed,
        low_memory=True,
        integrator='rwm_then_thug',
        εprop_switch=0.01,
        ε0_manual=ε0_manual,
        quantile_value=quantile_value,
        initialization='manual',
        switch_strategy='pm',
        kernel='uniform',
        use_autograd=False,
        stopping_criterion={'εmin', 'pm'}))
_ = SMC_RT_0001.sample()
# Out:
# Stochastic Kernel: RWM.
# Stopping criterion:  εmin, pm.
# Iteration:  1
# 	Particles resampled.
# 	Epsilon: 14.6090738258715049
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4615000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  2
# 	Particles resampled.
# 	Epsilon: 7.6290382543749207
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4505000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  3
# 	Particles resampled.
# 	Epsilon: 3.0049087761573530
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2640000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  4
# 	Particles resampled.
# 	Epsilon: 2.3347066465779576
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2015000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  5
# 	Particles resampled.
# 	Epsilon: 1.9272497860079931
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1445000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  6
# 	Particles resampled.
# 	Epsilon: 1.6694051898578657
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1155000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  7
# 	Particles resampled.
# 	Epsilon: 1.4788010793172730
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1040000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  8
# 	Particles resampled.
# 	Epsilon: 1.2720515845200588
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1025000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  9
# 	Particles resampled.
# 	Epsilon: 1.0136726916273522
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0600000000000001
# 	Step-size kept fixed at: 0.0010000000000000
#
#
# ####################################
# ### SWITCHING TO THUG KERNEL ###
# ####################################
#
#
# Iteration:  10
# 	Particles resampled.
# 	Epsilon: 0.8741216177490265
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4570000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  11
# 	Particles resampled.
# 	Epsilon: 0.7793826603970150
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4325000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  12
# 	Particles resampled.
# 	Epsilon: 0.7220408428282236
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4515000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  13
# 	Particles resampled.
# 	Epsilon: 0.6602320623271227
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4140000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  14
# 	Particles resampled.
# 	Epsilon: 0.6447337223140717
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4190000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  15
# 	Particles resampled.
# 	Epsilon: 0.6310239540264231
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4175000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  16
# 	Particles resampled.
# 	Epsilon: 0.6215448266034811
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4140000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  17
# 	Particles resampled.
# 	Epsilon: 0.5825618168004207
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4455000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  18
# 	Particles resampled.
# 	Epsilon: 0.5514000162600883
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4265000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  19
# 	Particles resampled.
# 	Epsilon: 0.5334068342261757
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4085000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  20
# 	Particles resampled.
# 	Epsilon: 0.5068983748139798
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4195000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  21
# 	Particles resampled.
# 	Epsilon: 0.4965290773572993
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3620000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  22
# 	Particles resampled.
# 	Epsilon: 0.4907065546714952
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3625000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  23
# 	Particles resampled.
# 	Epsilon: 0.4862936978474370
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3375000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  24
# 	Particles resampled.
# 	Epsilon: 0.4822303216552576
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3139999999999999
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  25
# 	Particles resampled.
# 	Epsilon: 0.4790780111782136
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2930000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  26
# 	Particles resampled.
# 	Epsilon: 0.4760994912454284
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3060000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  27
# 	Particles resampled.
# 	Epsilon: 0.4734116438642006
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2945000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  28
# 	Particles resampled.
# 	Epsilon: 0.4708241765190387
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3220000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  29
# 	Particles resampled.
# 	Epsilon: 0.4683456710858140
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3115000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  30
# 	Particles resampled.
# 	Epsilon: 0.4653877851017966
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3185000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  31
# 	Particles resampled.
# 	Epsilon: 0.4625303228845777
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3169999999999999
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  32
# 	Particles resampled.
# 	Epsilon: 0.4599158463610692
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2915000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  33
# 	Particles resampled.
# 	Epsilon: 0.4576220684809875
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2950000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  34
# 	Particles resampled.
# 	Epsilon: 0.4557163320287536
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2765000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  35
# 	Particles resampled.
# 	Epsilon: 0.4540339562281846
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2770000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  36
# 	Particles resampled.
# 	Epsilon: 0.4524901187057438
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2735000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  37
# 	Particles resampled.
# 	Epsilon: 0.4511952185626227
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2760000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  38
# 	Particles resampled.
# 	Epsilon: 0.4500033626670012
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2570000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  39
# 	Particles resampled.
# 	Epsilon: 0.4488156746297981
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2735000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  40
# 	Particles resampled.
# 	Epsilon: 0.4477485036730842
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2385000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  41
# 	Particles resampled.
# 	Epsilon: 0.4467768303621454
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2360000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  42
# 	Particles resampled.
# 	Epsilon: 0.4458054420317494
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2514999999999999
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  43
# 	Particles resampled.
# 	Epsilon: 0.4449660554687155
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2590000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  44
# 	Particles resampled.
# 	Epsilon: 0.4440107636670662
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2420000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  45
# 	Particles resampled.
# 	Epsilon: 0.4429939918536000
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2355000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  46
# 	Particles resampled.
# 	Epsilon: 0.4421288807125352
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2490000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  47
# 	Particles resampled.
# 	Epsilon: 0.4411531499697310
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2570000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  48
# 	Particles resampled.
# 	Epsilon: 0.4403590189259815
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2210000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  49
# 	Particles resampled.
# 	Epsilon: 0.4395947571583618
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2280000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  50
# 	Particles resampled.
# 	Epsilon: 0.4389372979513460
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2080000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  51
# 	Particles resampled.
# 	Epsilon: 0.4382773579825671
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2200000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  52
# 	Particles resampled.
# 	Epsilon: 0.4376383441915465
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2105000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  53
# 	Particles resampled.
# 	Epsilon: 0.4370238581141482
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2070000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  54
# 	Particles resampled.
# 	Epsilon: 0.4363249003798295
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2150000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  55
# 	Particles resampled.
# 	Epsilon: 0.4355991218187226
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2125000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  56
# 	Particles resampled.
# 	Epsilon: 0.4349377849010837
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2300000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  57
# 	Particles resampled.
# 	Epsilon: 0.4342307217615318
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2225000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  58
# 	Particles resampled.
# 	Epsilon: 0.4336424598340413
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2315000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  59
# 	Particles resampled.
# 	Epsilon: 0.4330026318960440
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2135000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  60
# 	Particles resampled.
# 	Epsilon: 0.4324352801179082
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2180000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  61
# 	Particles resampled.
# 	Epsilon: 0.4319329094797046
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2080000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  62
# 	Particles resampled.
# 	Epsilon: 0.4314260189543917
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1980000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  63
# 	Particles resampled.
# 	Epsilon: 0.4309540374385329
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2040000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  64
# 	Particles resampled.
# 	Epsilon: 0.4304502980287640
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2115000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  65
# 	Particles resampled.
# 	Epsilon: 0.4300200069324273
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1935000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  66
# 	Particles resampled.
# 	Epsilon: 0.4296381700472512
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1850000000000001
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  67
# 	Particles resampled.
# 	Epsilon: 0.4293201526706535
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1710000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  68
# 	Particles resampled.
# 	Epsilon: 0.4290853309787462
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1540000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  69
# 	Particles resampled.
# 	Epsilon: 0.4288581819554255
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1505000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  70
# 	Particles resampled.
# 	Epsilon: 0.4286950301135918
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1235000000000001
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  71
# 	Particles resampled.
# 	Epsilon: 0.4285593722005843
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1030000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  72
# 	Particles resampled.
# 	Epsilon: 0.4284489717448090
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0810000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  73
# 	Particles resampled.
# 	Epsilon: 0.4283810076741889
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0629999999999999
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  74
# 	Particles resampled.
# 	Epsilon: 0.4283320866559078
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0240000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  75
# 	Particles resampled.
# 	Epsilon: 0.4283045613893626
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0260000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  76
# 	Particles resampled.
# 	Epsilon: 0.4282839888629995
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0145000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  77
# 	Particles resampled.
# 	Epsilon: 0.4282679005891015
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0060000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  78
# 	Particles resampled.
# 	Epsilon: 0.4282592028163803
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0065000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  79
# 	Particles resampled.
# 	Epsilon: 0.4282499059243146
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0070000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  80
# 	Particles resampled.
# 	Epsilon: 0.4282428864537088
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0000000000000000
# 	Step-size kept fixed at: 0.0010000000000000

# %% [markdown]
# # Adaptive Step Size

# %%
SMC_RT_001_ADAPTIVE = SMCAdaptive(generate_settings(
        d=d, 
        N=N,
        B=B,
        δ=0.001,
        δmin=δmin,
        min_pm=min_pm,
        verbose=True,
        εs_fixed=None,
        adaptiveε=True,
        adaptiveδ=True,
        z0_manual=init_particles,
        pm_target=0.23,
        pm_switch=pm_switch,
        prior_seed=seed,
        low_memory=True,
        integrator='rwm_then_thug',
        εprop_switch=0.01,
        ε0_manual=ε0_manual,
        quantile_value=quantile_value,
        initialization='manual',
        switch_strategy='pm',
        kernel='uniform',
        use_autograd=False,
        stopping_criterion={'εmin', 'pm'}))
_ = SMC_RT_001_ADAPTIVE.sample()
# Out:
# Stochastic Kernel: RWM.
# Stopping criterion:  εmin, pm.
# Iteration:  1
# 	Particles resampled.
# 	Epsilon: 14.6090738258715049
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4615000000000000
# 	Step-size adapted to: 0.0011227151582559
# Iteration:  2
# 	Particles resampled.
# 	Epsilon: 7.6290382543749207
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4455000000000000
# 	Step-size adapted to: 0.0012504456402765
# Iteration:  3
# 	Particles resampled.
# 	Epsilon: 3.1730465878133698
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2200000000000000
# 	Step-size adapted to: 0.0012442090166272
# Iteration:  4
# 	Particles resampled.
# 	Epsilon: 2.4880962142821552
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1490000000000000
# 	Step-size adapted to: 0.0011948253212348
# Iteration:  5
# 	Particles resampled.
# 	Epsilon: 2.0271691751336709
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1025000000000000
# 	Step-size adapted to: 0.0011210323479418
# Iteration:  6
# 	Particles resampled.
# 	Epsilon: 1.7625262822558179
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0985000000000000
# 	Step-size adapted to: 0.0010496953718203
#
#
# ####################################
# ### SWITCHING TO THUG KERNEL ###
# ####################################
#
#
# Iteration:  7
# 	Particles resampled.
# 	Epsilon: 1.4856253377915412
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3225000000000000
# 	Step-size adapted to: 0.0010993839747738
# Iteration:  8
# 	Particles resampled.
# 	Epsilon: 1.2639197547219470
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4325000000000000
# 	Step-size adapted to: 0.0012165269053343
# Iteration:  9
# 	Particles resampled.
# 	Epsilon: 0.9940107041102075
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4160000000000000
# 	Step-size adapted to: 0.0013350917285285
# Iteration:  10
# 	Particles resampled.
# 	Epsilon: 0.7859870420516487
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3660000000000000
# 	Step-size adapted to: 0.0014290358698539
# Iteration:  11
# 	Particles resampled.
# 	Epsilon: 0.5805799854074903
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3195000000000000
# 	Step-size adapted to: 0.0014944376765518
# Iteration:  12
# 	Particles resampled.
# 	Epsilon: 0.5226394202217948
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2975000000000000
# 	Step-size adapted to: 0.0015457357336334
# Iteration:  13
# 	Particles resampled.
# 	Epsilon: 0.4627065974373139
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2840000000000000
# 	Step-size adapted to: 0.0015880391243159
# Iteration:  14
# 	Particles resampled.
# 	Epsilon: 0.3035100419923145
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2850000000000000
# 	Step-size adapted to: 0.0016323162199554
# Iteration:  15
# 	Particles resampled.
# 	Epsilon: 0.2025022243522920
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2755000000000000
# 	Step-size adapted to: 0.0016698770483904
# Iteration:  16
# 	Particles resampled.
# 	Epsilon: 0.2024884247285847
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2320000000000000
# 	Step-size adapted to: 0.0016715477606557
# Iteration:  17
# 	Particles resampled.
# 	Epsilon: 0.2024818065149463
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2080000000000000
# 	Step-size adapted to: 0.0016532614941405
# Iteration:  18
# 	Particles resampled.
# 	Epsilon: 0.2024758688625530
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2045000000000000
# 	Step-size adapted to: 0.0016323162199554
# Iteration:  19
# 	Particles resampled.
# 	Epsilon: 0.2024674275280063
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2090000000000000
# 	Step-size adapted to: 0.0016152665669674
# Iteration:  20
# 	Particles resampled.
# 	Epsilon: 0.2024559726239259
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2085000000000000
# 	Step-size adapted to: 0.0015979954499506
# Iteration:  21
# 	Particles resampled.
# 	Epsilon: 0.2024445778511618
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1975000000000000
# 	Step-size adapted to: 0.0015722378710162
# Iteration:  22
# 	Particles resampled.
# 	Epsilon: 0.2024311643032032
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2070000000000000
# 	Step-size adapted to: 0.0015542607023423
# Iteration:  23
# 	Particles resampled.
# 	Epsilon: 0.2024064724707059
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1925000000000000
# 	Step-size adapted to: 0.0015253898244749
# Iteration:  24
# 	Particles resampled.
# 	Epsilon: 0.2023789844483478
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1940000000000000
# 	Step-size adapted to: 0.0014981784447552
# Iteration:  25
# 	Particles resampled.
# 	Epsilon: 0.2023474092055000
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1935000000000000
# 	Step-size adapted to: 0.0014710846708147
# Iteration:  26
# 	Particles resampled.
# 	Epsilon: 0.2023137674695439
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1975000000000000
# 	Step-size adapted to: 0.0014473727262476
# Iteration:  27
# 	Particles resampled.
# 	Epsilon: 0.2022787158002184
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2065000000000000
# 	Step-size adapted to: 0.0014304656204799
# Iteration:  28
# 	Particles resampled.
# 	Epsilon: 0.2022280604918142
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2040000000000000
# 	Step-size adapted to: 0.0014119899196677
# Iteration:  29
# 	Particles resampled.
# 	Epsilon: 0.2021881597293395
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2060000000000000
# 	Step-size adapted to: 0.0013951472984698
# Iteration:  30
# 	Particles resampled.
# 	Epsilon: 0.2021477117033781
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2005000000000000
# 	Step-size adapted to: 0.0013747198982457
# Iteration:  31
# 	Particles resampled.
# 	Epsilon: 0.2021074928005236
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2020000000000000
# 	Step-size adapted to: 0.0013556079157094
# Iteration:  32
# 	Particles resampled.
# 	Epsilon: 0.2020628585794331
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2120000000000000
# 	Step-size adapted to: 0.0013434621822521
# Iteration:  33
# 	Particles resampled.
# 	Epsilon: 0.2020183131043966
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1940000000000000
# 	Step-size adapted to: 0.0013194962038551
# Iteration:  34
# 	Particles resampled.
# 	Epsilon: 0.2019733047660001
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1855000000000000
# 	Step-size adapted to: 0.0012904616208729
# Iteration:  35
# 	Particles resampled.
# 	Epsilon: 0.2019287838462547
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1960000000000000
# 	Step-size adapted to: 0.0012687091928249
# Iteration:  36
# 	Particles resampled.
# 	Epsilon: 0.2018820902271543
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2000000000000000
# 	Step-size adapted to: 0.0012498205737360
# Iteration:  37
# 	Particles resampled.
# 	Epsilon: 0.2018382181531338
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1810000000000000
# 	Step-size adapted to: 0.0012195720274143
# Iteration:  38
# 	Particles resampled.
# 	Epsilon: 0.2017932417584840
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1965000000000000
# 	Step-size adapted to: 0.0011993143278162
# Iteration:  39
# 	Particles resampled.
# 	Epsilon: 0.2017420994502607
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1879999999999999
# 	Step-size adapted to: 0.0011743913342775
# Iteration:  40
# 	Particles resampled.
# 	Epsilon: 0.2016816046523834
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1925000000000000
# 	Step-size adapted to: 0.0011525766485370
# Iteration:  41
# 	Particles resampled.
# 	Epsilon: 0.2016186618154665
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2065000000000000
# 	Step-size adapted to: 0.0011391131260118
# Iteration:  42
# 	Particles resampled.
# 	Epsilon: 0.2015146005737304
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2350000000000000
# 	Step-size adapted to: 0.0011419644715237
# Iteration:  43
# 	Particles resampled.
# 	Epsilon: 0.2013785025562513
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2395000000000000
# 	Step-size adapted to: 0.0011474017059721
# Iteration:  44
# 	Particles resampled.
# 	Epsilon: 0.2012703845387916
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2330000000000000
# 	Step-size adapted to: 0.0011491241000036
# Iteration:  45
# 	Particles resampled.
# 	Epsilon: 0.2012060978615578
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2060000000000000
# 	Step-size adapted to: 0.0011354170177815
# Iteration:  46
# 	Particles resampled.
# 	Epsilon: 0.2011577360707765
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2095000000000000
# 	Step-size adapted to: 0.0011238384349589
# Iteration:  47
# 	Particles resampled.
# 	Epsilon: 0.2010985706370761
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2035000000000000
# 	Step-size adapted to: 0.0011090457933651
# Iteration:  48
# 	Particles resampled.
# 	Epsilon: 0.2010452995340440
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2105000000000000
# 	Step-size adapted to: 0.0010982851403078
# Iteration:  49
# 	Particles resampled.
# 	Epsilon: 0.2009948304843970
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1960000000000000
# 	Step-size adapted to: 0.0010797720996220
# Iteration:  50
# 	Particles resampled.
# 	Epsilon: 0.2009389253913120
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2020000000000000
# 	Step-size adapted to: 0.0010647606158008
# Iteration:  51
# 	Particles resampled.
# 	Epsilon: 0.2008900110349958
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1975000000000000
# 	Step-size adapted to: 0.0010475980790685
# Iteration:  52
# 	Particles resampled.
# 	Epsilon: 0.2008351359003802
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1925000000000000
# 	Step-size adapted to: 0.0010281386176350
# Iteration:  53
# 	Particles resampled.
# 	Epsilon: 0.2007790038936729
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1965000000000000
# 	Step-size adapted to: 0.0010110607224447
# Iteration:  54
# 	Particles resampled.
# 	Epsilon: 0.2007154738802160
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2075000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  55
# 	Particles resampled.
# 	Epsilon: 0.2006360590252387
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2155000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  56
# 	Particles resampled.
# 	Epsilon: 0.2005479420671805
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2035000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  57
# 	Particles resampled.
# 	Epsilon: 0.2004565110920885
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2065000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  58
# 	Particles resampled.
# 	Epsilon: 0.2003732955370171
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2285000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  59
# 	Particles resampled.
# 	Epsilon: 0.2003091961205419
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2125000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  60
# 	Particles resampled.
# 	Epsilon: 0.2002504939324652
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1945000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  61
# 	Particles resampled.
# 	Epsilon: 0.2001888500426216
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2125000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  62
# 	Particles resampled.
# 	Epsilon: 0.2001287752666816
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2180000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  63
# 	Particles resampled.
# 	Epsilon: 0.2000586520198744
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1865000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  64
# 	Particles resampled.
# 	Epsilon: 0.1999926378771608
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1895000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  65
# 	Particles resampled.
# 	Epsilon: 0.1999250856229920
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2000000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  66
# 	Particles resampled.
# 	Epsilon: 0.1998562570333806
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2070000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  67
# 	Particles resampled.
# 	Epsilon: 0.1997866800753300
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2050000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  68
# 	Particles resampled.
# 	Epsilon: 0.1997272804541560
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1955000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  69
# 	Particles resampled.
# 	Epsilon: 0.1996610984085270
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1835000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  70
# 	Particles resampled.
# 	Epsilon: 0.1995973207040719
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2015000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  71
# 	Particles resampled.
# 	Epsilon: 0.1995301703160755
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2115000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  72
# 	Particles resampled.
# 	Epsilon: 0.1994570761109588
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2165000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  73
# 	Particles resampled.
# 	Epsilon: 0.1993804318584916
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1875000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  74
# 	Particles resampled.
# 	Epsilon: 0.1993034060322877
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1975000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  75
# 	Particles resampled.
# 	Epsilon: 0.1992298869077644
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1955000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  76
# 	Particles resampled.
# 	Epsilon: 0.1991687399259813
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1955000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  77
# 	Particles resampled.
# 	Epsilon: 0.1991018035893471
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1875000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  78
# 	Particles resampled.
# 	Epsilon: 0.1990393365008677
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1830000000000001
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  79
# 	Particles resampled.
# 	Epsilon: 0.1989775047019163
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1940000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  80
# 	Particles resampled.
# 	Epsilon: 0.1989130440272866
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1815000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  81
# 	Particles resampled.
# 	Epsilon: 0.1988403454186342
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2025000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  82
# 	Particles resampled.
# 	Epsilon: 0.1987645392614442
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1975000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  83
# 	Particles resampled.
# 	Epsilon: 0.1986897181445278
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1905000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  84
# 	Particles resampled.
# 	Epsilon: 0.1986124865751163
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1950000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  85
# 	Particles resampled.
# 	Epsilon: 0.1985433785658453
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1850000000000001
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  86
# 	Particles resampled.
# 	Epsilon: 0.1984647197783777
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1990000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  87
# 	Particles resampled.
# 	Epsilon: 0.1983952328046256
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1970000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  88
# 	Particles resampled.
# 	Epsilon: 0.1983403650821685
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1885000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  89
# 	Particles resampled.
# 	Epsilon: 0.1982730295249577
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2025000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  90
# 	Particles resampled.
# 	Epsilon: 0.1982015297713998
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1889999999999999
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  91
# 	Particles resampled.
# 	Epsilon: 0.1981385298619430
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2050000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  92
# 	Particles resampled.
# 	Epsilon: 0.1980709500492737
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1980000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  93
# 	Particles resampled.
# 	Epsilon: 0.1980147028083880
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2010000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  94
# 	Particles resampled.
# 	Epsilon: 0.1979550465228522
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2015000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  95
# 	Particles resampled.
# 	Epsilon: 0.1978980885445450
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1830000000000001
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  96
# 	Particles resampled.
# 	Epsilon: 0.1978529926624428
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1960000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  97
# 	Particles resampled.
# 	Epsilon: 0.1978120964669131
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1860000000000001
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  98
# 	Particles resampled.
# 	Epsilon: 0.1977721266007418
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1875000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  99
# 	Particles resampled.
# 	Epsilon: 0.1977334322390040
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1775000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  100
# 	Particles resampled.
# 	Epsilon: 0.1976969849367120
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1875000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  101
# 	Particles resampled.
# 	Epsilon: 0.1976544543397529
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1850000000000001
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  102
# 	Particles resampled.
# 	Epsilon: 0.1976078248768333
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1919999999999999
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  103
# 	Particles resampled.
# 	Epsilon: 0.1975518729143269
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2060000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  104
# 	Particles resampled.
# 	Epsilon: 0.1974944394798318
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1970000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  105
# 	Particles resampled.
# 	Epsilon: 0.1974448532853292
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2130000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  106
# 	Particles resampled.
# 	Epsilon: 0.1974015825201792
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1985000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  107
# 	Particles resampled.
# 	Epsilon: 0.1973624654427980
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1970000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  108
# 	Particles resampled.
# 	Epsilon: 0.1973255848937487
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1970000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  109
# 	Particles resampled.
# 	Epsilon: 0.1972873803481297
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2000000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  110
# 	Particles resampled.
# 	Epsilon: 0.1972436162179382
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1975000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  111
# 	Particles resampled.
# 	Epsilon: 0.1972004079076036
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2065000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  112
# 	Particles resampled.
# 	Epsilon: 0.1971607357686982
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1835000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  113
# 	Particles resampled.
# 	Epsilon: 0.1971193792675095
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1870000000000001
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  114
# 	Particles resampled.
# 	Epsilon: 0.1970792539812140
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1980000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  115
# 	Particles resampled.
# 	Epsilon: 0.1970374392025681
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1889999999999999
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  116
# 	Particles resampled.
# 	Epsilon: 0.1969941971348211
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1850000000000001
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  117
# 	Particles resampled.
# 	Epsilon: 0.1969502252549004
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2100000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  118
# 	Particles resampled.
# 	Epsilon: 0.1969045349456236
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2045000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  119
# 	Particles resampled.
# 	Epsilon: 0.1968681303972092
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2045000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  120
# 	Particles resampled.
# 	Epsilon: 0.1968339695971388
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2075000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  121
# 	Particles resampled.
# 	Epsilon: 0.1968015632127084
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1815000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  122
# 	Particles resampled.
# 	Epsilon: 0.1967670541638587
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1945000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  123
# 	Particles resampled.
# 	Epsilon: 0.1967357529325867
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1945000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  124
# 	Particles resampled.
# 	Epsilon: 0.1967049375055369
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1990000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  125
# 	Particles resampled.
# 	Epsilon: 0.1966737757006517
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1865000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  126
# 	Particles resampled.
# 	Epsilon: 0.1966396091799936
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1805000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  127
# 	Particles resampled.
# 	Epsilon: 0.1966070780172619
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1680000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  128
# 	Particles resampled.
# 	Epsilon: 0.1965759239047484
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1765000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  129
# 	Particles resampled.
# 	Epsilon: 0.1965472939499196
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1915000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  130
# 	Particles resampled.
# 	Epsilon: 0.1965117123173757
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2095000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  131
# 	Particles resampled.
# 	Epsilon: 0.1964687320927664
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2080000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  132
# 	Particles resampled.
# 	Epsilon: 0.1964273516319894
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2110000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  133
# 	Particles resampled.
# 	Epsilon: 0.1963922165924123
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2100000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  134
# 	Particles resampled.
# 	Epsilon: 0.1963589939508707
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1925000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  135
# 	Particles resampled.
# 	Epsilon: 0.1963287262136653
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2135000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  136
# 	Particles resampled.
# 	Epsilon: 0.1962897620385474
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2145000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  137
# 	Particles resampled.
# 	Epsilon: 0.1962515056978135
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1919999999999999
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  138
# 	Particles resampled.
# 	Epsilon: 0.1962135901483261
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1985000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  139
# 	Particles resampled.
# 	Epsilon: 0.1961723246601250
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1985000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  140
# 	Particles resampled.
# 	Epsilon: 0.1961357173658146
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2115000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  141
# 	Particles resampled.
# 	Epsilon: 0.1961002889788042
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2065000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  142
# 	Particles resampled.
# 	Epsilon: 0.1960662684943238
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1889999999999999
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  143
# 	Particles resampled.
# 	Epsilon: 0.1960357682765210
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2060000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  144
# 	Particles resampled.
# 	Epsilon: 0.1960046082016159
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1980000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  145
# 	Particles resampled.
# 	Epsilon: 0.1959694736082754
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1925000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  146
# 	Particles resampled.
# 	Epsilon: 0.1959363030180524
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2040000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  147
# 	Particles resampled.
# 	Epsilon: 0.1958971493595695
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2015000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  148
# 	Particles resampled.
# 	Epsilon: 0.1958571796512345
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2110000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  149
# 	Particles resampled.
# 	Epsilon: 0.1958144305034036
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2030000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  150
# 	Particles resampled.
# 	Epsilon: 0.1957721310142120
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2050000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  151
# 	Particles resampled.
# 	Epsilon: 0.1957307721601282
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2015000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  152
# 	Particles resampled.
# 	Epsilon: 0.1956994794174347
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1955000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  153
# 	Particles resampled.
# 	Epsilon: 0.1956718624022020
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2075000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  154
# 	Particles resampled.
# 	Epsilon: 0.1956451542516967
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2110000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  155
# 	Particles resampled.
# 	Epsilon: 0.1956223244668194
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2015000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  156
# 	Particles resampled.
# 	Epsilon: 0.1956002976116275
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2030000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  157
# 	Particles resampled.
# 	Epsilon: 0.1955758290707160
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1905000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  158
# 	Particles resampled.
# 	Epsilon: 0.1955505606286980
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2090000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  159
# 	Particles resampled.
# 	Epsilon: 0.1955248055236290
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1929999999999999
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  160
# 	Particles resampled.
# 	Epsilon: 0.1955011782845545
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1855000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  161
# 	Particles resampled.
# 	Epsilon: 0.1954810023098795
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2025000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  162
# 	Particles resampled.
# 	Epsilon: 0.1954624576646349
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1885000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  163
# 	Particles resampled.
# 	Epsilon: 0.1954431685459086
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1940000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  164
# 	Particles resampled.
# 	Epsilon: 0.1954193478457290
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1879999999999999
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  165
# 	Particles resampled.
# 	Epsilon: 0.1953989419735355
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1919999999999999
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  166
# 	Particles resampled.
# 	Epsilon: 0.1953750007902612
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1985000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  167
# 	Particles resampled.
# 	Epsilon: 0.1953543756584762
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1940000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  168
# 	Particles resampled.
# 	Epsilon: 0.1953296292928283
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1950000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  169
# 	Particles resampled.
# 	Epsilon: 0.1953035591680582
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1899999999999999
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  170
# 	Particles resampled.
# 	Epsilon: 0.1952792496994339
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2070000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  171
# 	Particles resampled.
# 	Epsilon: 0.1952513765467144
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1905000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  172
# 	Particles resampled.
# 	Epsilon: 0.1952249540228856
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1975000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  173
# 	Particles resampled.
# 	Epsilon: 0.1952037399339503
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2000000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  174
# 	Particles resampled.
# 	Epsilon: 0.1951825671781128
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1970000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  175
# 	Particles resampled.
# 	Epsilon: 0.1951599022054672
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2035000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  176
# 	Particles resampled.
# 	Epsilon: 0.1951337745824860
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1925000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  177
# 	Particles resampled.
# 	Epsilon: 0.1951088250892679
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2135000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  178
# 	Particles resampled.
# 	Epsilon: 0.1950871490755106
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1835000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  179
# 	Particles resampled.
# 	Epsilon: 0.1950641732545304
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1825000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  180
# 	Particles resampled.
# 	Epsilon: 0.1950425994415253
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1825000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  181
# 	Particles resampled.
# 	Epsilon: 0.1950190034002192
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1929999999999999
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  182
# 	Particles resampled.
# 	Epsilon: 0.1949894567986951
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1935000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  183
# 	Particles resampled.
# 	Epsilon: 0.1949648104917265
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1960000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  184
# 	Particles resampled.
# 	Epsilon: 0.1949334657698826
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2030000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  185
# 	Particles resampled.
# 	Epsilon: 0.1948948866850222
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2045000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  186
# 	Particles resampled.
# 	Epsilon: 0.1948580242293626
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1925000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  187
# 	Particles resampled.
# 	Epsilon: 0.1948190221509509
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1909999999999999
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  188
# 	Particles resampled.
# 	Epsilon: 0.1947832739731677
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1940000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  189
# 	Particles resampled.
# 	Epsilon: 0.1947461424885100
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1915000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  190
# 	Particles resampled.
# 	Epsilon: 0.1947104656981013
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2030000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  191
# 	Particles resampled.
# 	Epsilon: 0.1946726782326012
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2005000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  192
# 	Particles resampled.
# 	Epsilon: 0.1946373740726902
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1980000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  193
# 	Particles resampled.
# 	Epsilon: 0.1946040744516425
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1919999999999999
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  194
# 	Particles resampled.
# 	Epsilon: 0.1945677704519437
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2130000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  195
# 	Particles resampled.
# 	Epsilon: 0.1945298641446301
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2195000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  196
# 	Particles resampled.
# 	Epsilon: 0.1944947598221763
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2220000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  197
# 	Particles resampled.
# 	Epsilon: 0.1944651592381140
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1895000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  198
# 	Particles resampled.
# 	Epsilon: 0.1944369712136850
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1840000000000001
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  199
# 	Particles resampled.
# 	Epsilon: 0.1944077145662807
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2060000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  200
# 	Particles resampled.
# 	Epsilon: 0.1943810223745429
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1980000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  201
# 	Particles resampled.
# 	Epsilon: 0.1943514312515869
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2140000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  202
# 	Particles resampled.
# 	Epsilon: 0.1943247825058899
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2055000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  203
# 	Particles resampled.
# 	Epsilon: 0.1942974488206182
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1895000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  204
# 	Particles resampled.
# 	Epsilon: 0.1942674050981812
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2035000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  205
# 	Particles resampled.
# 	Epsilon: 0.1942328914263899
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2065000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  206
# 	Particles resampled.
# 	Epsilon: 0.1941911476933611
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2005000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  207
# 	Particles resampled.
# 	Epsilon: 0.1941544275609574
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1650000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  208
# 	Particles resampled.
# 	Epsilon: 0.1941210579182949
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2095000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  209
# 	Particles resampled.
# 	Epsilon: 0.1940757792255106
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1889999999999999
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  210
# 	Particles resampled.
# 	Epsilon: 0.1940367092465955
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1970000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  211
# 	Particles resampled.
# 	Epsilon: 0.1939989253375655
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2035000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  212
# 	Particles resampled.
# 	Epsilon: 0.1939668124660336
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1899999999999999
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  213
# 	Particles resampled.
# 	Epsilon: 0.1939388773017033
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1955000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  214
# 	Particles resampled.
# 	Epsilon: 0.1939063835181753
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1860000000000001
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  215
# 	Particles resampled.
# 	Epsilon: 0.1938794509232005
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1935000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  216
# 	Particles resampled.
# 	Epsilon: 0.1938528573281807
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1860000000000001
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  217
# 	Particles resampled.
# 	Epsilon: 0.1938264512916664
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1899999999999999
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  218
# 	Particles resampled.
# 	Epsilon: 0.1937981516286042
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2005000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  219
# 	Particles resampled.
# 	Epsilon: 0.1937697240299343
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1899999999999999
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  220
# 	Particles resampled.
# 	Epsilon: 0.1937321810392429
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2045000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  221
# 	Particles resampled.
# 	Epsilon: 0.1936890949421974
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1985000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  222
# 	Particles resampled.
# 	Epsilon: 0.1936510643406585
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1960000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  223
# 	Particles resampled.
# 	Epsilon: 0.1936119151138312
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1940000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  224
# 	Particles resampled.
# 	Epsilon: 0.1935730261787886
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2060000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  225
# 	Particles resampled.
# 	Epsilon: 0.1935288248510315
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2065000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  226
# 	Particles resampled.
# 	Epsilon: 0.1934724416896330
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2075000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  227
# 	Particles resampled.
# 	Epsilon: 0.1934239541709060
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2015000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  228
# 	Particles resampled.
# 	Epsilon: 0.1933797820093050
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1995000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  229
# 	Particles resampled.
# 	Epsilon: 0.1933323761503677
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1990000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  230
# 	Particles resampled.
# 	Epsilon: 0.1932833507138856
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2105000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  231
# 	Particles resampled.
# 	Epsilon: 0.1932277076605771
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2135000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  232
# 	Particles resampled.
# 	Epsilon: 0.1931760120132791
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2070000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  233
# 	Particles resampled.
# 	Epsilon: 0.1931254944600674
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2045000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  234
# 	Particles resampled.
# 	Epsilon: 0.1930788505531036
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2085000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  235
# 	Particles resampled.
# 	Epsilon: 0.1930376682980964
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2000000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  236
# 	Particles resampled.
# 	Epsilon: 0.1929984751560668
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1889999999999999
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  237
# 	Particles resampled.
# 	Epsilon: 0.1929571077165005
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2030000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  238
# 	Particles resampled.
# 	Epsilon: 0.1929146471161042
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1945000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  239
# 	Particles resampled.
# 	Epsilon: 0.1928780343096990
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1990000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  240
# 	Particles resampled.
# 	Epsilon: 0.1928378843908652
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1820000000000001
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  241
# 	Particles resampled.
# 	Epsilon: 0.1927960964995830
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2030000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  242
# 	Particles resampled.
# 	Epsilon: 0.1927514165357521
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2000000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  243
# 	Particles resampled.
# 	Epsilon: 0.1927109772488997
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1990000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  244
# 	Particles resampled.
# 	Epsilon: 0.1926697107858914
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1925000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  245
# 	Particles resampled.
# 	Epsilon: 0.1926333586738465
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1970000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  246
# 	Particles resampled.
# 	Epsilon: 0.1926007297488810
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1855000000000000
# ...
# 	Epsilon: 0.0469863280768283
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0810000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  965
# 	Particles resampled.
# 	Epsilon: 0.0469354157332858
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0580000000000001
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  966
# 	Particles resampled.
# 	Epsilon: 0.0468945412641277
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0665000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  967
# 	Particles resampled.
# 	Epsilon: 0.0468501691782773
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0550000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  968
# 	Particles resampled.
# 	Epsilon: 0.0468034146676800
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0750000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  969
# 	Particles resampled.
# 	Epsilon: 0.0467570825507690
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0555000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  970
# 	Particles resampled.
# 	Epsilon: 0.0467152540748158
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0530000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  971
# 	Particles resampled.
# 	Epsilon: 0.0466786661612638
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0620000000000001
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  972
# 	Particles resampled.
# 	Epsilon: 0.0466446252519712
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0495000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  973
# 	Particles resampled.
# 	Epsilon: 0.0466127778128091
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0515000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  974
# 	Particles resampled.
# 	Epsilon: 0.0465681575152715
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0515000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  975
# 	Particles resampled.
# 	Epsilon: 0.0465264577522344
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0485000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  976
# 	Particles resampled.
# 	Epsilon: 0.0464909831269265
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0420000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  977
# 	Particles resampled.
# 	Epsilon: 0.0464544376942752
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0639999999999999
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  978
# 	Particles resampled.
# 	Epsilon: 0.0464182357691433
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0605000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  979
# 	Particles resampled.
# 	Epsilon: 0.0463847902364480
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0410000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  980
# 	Particles resampled.
# 	Epsilon: 0.0463527590879389
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0495000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  981
# 	Particles resampled.
# 	Epsilon: 0.0463144287203152
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0575000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  982
# 	Particles resampled.
# 	Epsilon: 0.0462789783055724
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0485000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  983
# 	Particles resampled.
# 	Epsilon: 0.0462477244432865
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0585000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  984
# 	Particles resampled.
# 	Epsilon: 0.0462200483537176
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0545000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  985
# 	Particles resampled.
# 	Epsilon: 0.0461881288490184
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0385000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  986
# 	Particles resampled.
# 	Epsilon: 0.0461552031629225
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0445000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  987
# 	Particles resampled.
# 	Epsilon: 0.0461178677118745
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0555000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  988
# 	Particles resampled.
# 	Epsilon: 0.0460828491664235
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0515000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  989
# 	Particles resampled.
# 	Epsilon: 0.0460450407411728
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0505000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  990
# 	Particles resampled.
# 	Epsilon: 0.0460056794949842
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0465000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  991
# 	Particles resampled.
# 	Epsilon: 0.0459709218689010
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0570000000000001
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  992
# 	Particles resampled.
# 	Epsilon: 0.0459365716053835
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0355000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  993
# 	Particles resampled.
# 	Epsilon: 0.0459036567900161
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0370000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  994
# 	Particles resampled.
# 	Epsilon: 0.0458801718986040
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0480000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  995
# 	Particles resampled.
# 	Epsilon: 0.0458522875787448
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0510000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  996
# 	Particles resampled.
# 	Epsilon: 0.0458283220219952
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0285000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  997
# 	Particles resampled.
# 	Epsilon: 0.0458060271061415
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0595000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  998
# 	Particles resampled.
# 	Epsilon: 0.0457773870047521
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0490000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  999
# 	Particles resampled.
# 	Epsilon: 0.0457454443841886
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0565000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1000
# 	Particles resampled.
# 	Epsilon: 0.0457201478499460
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0210000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1001
# 	Particles resampled.
# 	Epsilon: 0.0457011032676361
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0375000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1002
# 	Particles resampled.
# 	Epsilon: 0.0456793606100478
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0450000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1003
# 	Particles resampled.
# 	Epsilon: 0.0456571644540489
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0405000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1004
# 	Particles resampled.
# 	Epsilon: 0.0456343737535942
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0565000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1005
# 	Particles resampled.
# 	Epsilon: 0.0456128865583315
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0210000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1006
# 	Particles resampled.
# 	Epsilon: 0.0455943925144657
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0345000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1007
# 	Particles resampled.
# 	Epsilon: 0.0455744958266985
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0320000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1008
# 	Particles resampled.
# 	Epsilon: 0.0455531785184079
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0240000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1009
# 	Particles resampled.
# 	Epsilon: 0.0455306962712952
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0215000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1010
# 	Particles resampled.
# 	Epsilon: 0.0455142441245994
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0310000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1011
# 	Particles resampled.
# 	Epsilon: 0.0454897314046590
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0400000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1012
# 	Particles resampled.
# 	Epsilon: 0.0454680426662651
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0355000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1013
# 	Particles resampled.
# 	Epsilon: 0.0454515468645369
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0495000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1014
# 	Particles resampled.
# 	Epsilon: 0.0454303987741976
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0405000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1015
# 	Particles resampled.
# 	Epsilon: 0.0454141019076658
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0355000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1016
# 	Particles resampled.
# 	Epsilon: 0.0453976551042118
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0265000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1017
# 	Particles resampled.
# 	Epsilon: 0.0453874612219752
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0150000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1018
# 	Particles resampled.
# 	Epsilon: 0.0453770292832556
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0250000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1019
# 	Particles resampled.
# 	Epsilon: 0.0453609346319416
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0275000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1020
# 	Particles resampled.
# 	Epsilon: 0.0453502106484428
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0190000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1021
# 	Particles resampled.
# 	Epsilon: 0.0453334758569084
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0375000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1022
# 	Particles resampled.
# 	Epsilon: 0.0453214758718245
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0195000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1023
# 	Particles resampled.
# 	Epsilon: 0.0453084570241887
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0315000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1024
# 	Particles resampled.
# 	Epsilon: 0.0452972635146958
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0245000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1025
# 	Particles resampled.
# 	Epsilon: 0.0452861070981855
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0260000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1026
# 	Particles resampled.
# 	Epsilon: 0.0452721483542019
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0170000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1027
# 	Particles resampled.
# 	Epsilon: 0.0452624233552110
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0210000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1028
# 	Particles resampled.
# 	Epsilon: 0.0452516188148963
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0425000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1029
# 	Particles resampled.
# 	Epsilon: 0.0452410535891867
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0200000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1030
# 	Particles resampled.
# 	Epsilon: 0.0452321317011305
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0200000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1031
# 	Particles resampled.
# 	Epsilon: 0.0452230934370867
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0265000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1032
# 	Particles resampled.
# 	Epsilon: 0.0452159757162567
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0140000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1033
# 	Particles resampled.
# 	Epsilon: 0.0452097044140396
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0185000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1034
# 	Particles resampled.
# 	Epsilon: 0.0452050772364874
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0200000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1035
# 	Particles resampled.
# 	Epsilon: 0.0451998408639622
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0125000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1036
# 	Particles resampled.
# 	Epsilon: 0.0451955478688103
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0245000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1037
# 	Particles resampled.
# 	Epsilon: 0.0451917749492147
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0054999999999999
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1038
# 	Particles resampled.
# 	Epsilon: 0.0451888314179160
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0190000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1039
# 	Particles resampled.
# 	Epsilon: 0.0451858043727948
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0150000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1040
# 	Particles resampled.
# 	Epsilon: 0.0451832453318700
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0030000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1041
# 	Particles resampled.
# 	Epsilon: 0.0451812937986086
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0030000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1042
# 	Particles resampled.
# 	Epsilon: 0.0451798164788937
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0050000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1043
# 	Particles resampled.
# 	Epsilon: 0.0451785153057457
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0014999999999999
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1044
# 	Particles resampled.
# 	Epsilon: 0.0451778723733731
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0075000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  1045
# 	Particles resampled.
# 	Epsilon: 0.0451772039390998
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0000000000000000
# 	Step-size adapted to: 0.0010000000000000

# %% [markdown]
# ### MS RWM

# %%
MS_RWM_001_ADAPTIVE = MSAdaptive(generate_settings(
        d=d, 
        N=N,
        B=B,
        δ=0.001,
        δmin=δmin,
        min_pm=min_pm,
        verbose=True,
        εs_fixed=None,
        adaptiveε=True,
        adaptiveδ=True,
        z0_manual=init_particles,
        pm_target=0.23,
        pm_switch=pm_switch,
        prior_seed=seed,
        low_memory=True,
        integrator='rwm',
        εprop_switch=0.01,
        ε0_manual=ε0_manual,
        quantile_value=quantile_value,
        initialization='manual',
        switch_strategy='pm',
        kernel='uniform',
        use_autograd=False,
        stopping_criterion={'εmin', 'pm'},
        resampling_seed=1234))
_ = MS_RWM_001_ADAPTIVE.sample()
# Out:
# Integrator: RWM.
# Stopping criterion:  εmin, pm.
# Iteration:  1
# 	Trajectories constructed.
# 	Epsilon: 14.5399972504226973
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9440000000000000
# 	Step-size adapted to: 0.0014290358698539
# Iteration:  2
# 	Trajectories constructed.
# 	Epsilon: 7.1486353603374466
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9495000000000000
# 	Step-size adapted to: 0.0020477671409401
# Iteration:  3
# 	Trajectories constructed.
# 	Epsilon: 1.9385990841414951
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8995000000000000
# 	Step-size adapted to: 0.0028619408112058
# Iteration:  4
# 	Trajectories constructed.
# 	Epsilon: 1.3737709706537147
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8510000000000000
# 	Step-size adapted to: 0.0039039934859829
# Iteration:  5
# 	Trajectories constructed.
# 	Epsilon: 1.0519847168988943
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7970000000000000
# 	Step-size adapted to: 0.0051836010596362
# Iteration:  6
# 	Trajectories constructed.
# 	Epsilon: 0.8266270953840056
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7665000000000000
# 	Step-size adapted to: 0.0067784604235904
# Iteration:  7
# 	Trajectories constructed.
# 	Epsilon: 0.6638502997334856
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7305000000000000
# 	Step-size adapted to: 0.0087058916707833
# Iteration:  8
# 	Trajectories constructed.
# 	Epsilon: 0.5447402228822064
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.6390000000000000
# 	Step-size adapted to: 0.0106813582242362
# Iteration:  9
# 	Trajectories constructed.
# 	Epsilon: 0.4630787797317165
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.4845000000000000
# 	Step-size adapted to: 0.0121308282288184
# Iteration:  10
# 	Trajectories constructed.
# 	Epsilon: 0.4031194904371194
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.3625000000000000
# 	Step-size adapted to: 0.0129617148390652
# Iteration:  11
# 	Trajectories constructed.
# 	Epsilon: 0.3556300543195145
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2295000000000000
# 	Step-size adapted to: 0.0129584748153753
# Iteration:  12
# 	Trajectories constructed.
# 	Epsilon: 0.3139450147375945
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1990000000000000
# 	Step-size adapted to: 0.0127591670809695
# Iteration:  13
# 	Trajectories constructed.
# 	Epsilon: 0.2813934907986980
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1820000000000000
# 	Step-size adapted to: 0.0124565924895641
# Iteration:  14
# 	Trajectories constructed.
# 	Epsilon: 0.2572456550074524
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1485000000000000
# 	Step-size adapted to: 0.0119591897551178
# Iteration:  15
# 	Trajectories constructed.
# 	Epsilon: 0.2344463534796345
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1265000000000000
# 	Step-size adapted to: 0.0113560427144169
# Iteration:  16
# 	Trajectories constructed.
# 	Epsilon: 0.2153847047407515
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1040000000000000
# 	Step-size adapted to: 0.0106626821936368
# Iteration:  17
# 	Trajectories constructed.
# 	Epsilon: 0.1991559482200073
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1025000000000000
# 	Step-size adapted to: 0.0100041499309177
# Iteration:  18
# 	Trajectories constructed.
# 	Epsilon: 0.1793218305557905
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1010000000000000
# 	Step-size adapted to: 0.0093792518527276
# Iteration:  19
# 	Trajectories constructed.
# 	Epsilon: 0.1642443431795758
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0945000000000000
# 	Step-size adapted to: 0.0087648552176547
# Iteration:  20
# 	Trajectories constructed.
# 	Epsilon: 0.1525349178940533
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1345000000000000
# 	Step-size adapted to: 0.0083561684277877
# Iteration:  21
# 	Trajectories constructed.
# 	Epsilon: 0.1403602067056168
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0425000000000000
# 	Step-size adapted to: 0.0076083779349374
# Iteration:  22
# 	Trajectories constructed.
# 	Epsilon: 0.1294403888810680
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0885000000000000
# 	Step-size adapted to: 0.0070886860573100
# Iteration:  23
# 	Trajectories constructed.
# 	Epsilon: 0.1215370676015297
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0750000000000000
# 	Step-size adapted to: 0.0065600616448983
# Iteration:  24
# 	Trajectories constructed.
# 	Epsilon: 0.1152288997568485
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0960000000000000
# 	Step-size adapted to: 0.0061349381707823
# Iteration:  25
# 	Trajectories constructed.
# 	Epsilon: 0.1092410121768752
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0870000000000000
# 	Step-size adapted to: 0.0057116046002730
# Iteration:  26
# 	Trajectories constructed.
# 	Epsilon: 0.1032623866005710
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0425000000000000
# 	Step-size adapted to: 0.0052004751686544
# Iteration:  27
# 	Trajectories constructed.
# 	Epsilon: 0.0968439858120244
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0370000000000000
# 	Step-size adapted to: 0.0047220829253599
# Iteration:  28
# 	Trajectories constructed.
# 	Epsilon: 0.0928386618009203
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0310000000000000
# 	Step-size adapted to: 0.0042748542147740
# Iteration:  29
# 	Trajectories constructed.
# 	Epsilon: 0.0892658125840074
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1110000000000000
# 	Step-size adapted to: 0.0040279195420823
# Iteration:  30
# 	Trajectories constructed.
# 	Epsilon: 0.0867717983836264
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1250000000000000
# 	Step-size adapted to: 0.0038219088623699
# Iteration:  31
# 	Trajectories constructed.
# 	Epsilon: 0.0835063629013639
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0815000000000000
# 	Step-size adapted to: 0.0035484113631862
# Iteration:  32
# 	Trajectories constructed.
# 	Epsilon: 0.0793825307207745
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0905000000000000
# 	Step-size adapted to: 0.0033093440581250
# Iteration:  33
# 	Trajectories constructed.
# 	Epsilon: 0.0761835761459147
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0995000000000000
# 	Step-size adapted to: 0.0031003034692304
# Iteration:  34
# 	Trajectories constructed.
# 	Epsilon: 0.0723666450271160
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1030000000000000
# 	Step-size adapted to: 0.0029095545678508
# Iteration:  35
# 	Trajectories constructed.
# 	Epsilon: 0.0688917999230192
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1025000000000000
# 	Step-size adapted to: 0.0027298591105282
# Iteration:  36
# 	Trajectories constructed.
# 	Epsilon: 0.0658242295188660
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1640000000000000
# 	Step-size adapted to: 0.0026412439516814
# Iteration:  37
# 	Trajectories constructed.
# 	Epsilon: 0.0630741136503711
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1440000000000000
# 	Step-size adapted to: 0.0025300776652613
# Iteration:  38
# 	Trajectories constructed.
# 	Epsilon: 0.0598372932603328
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1640000000000000
# 	Step-size adapted to: 0.0024479476998953
# Iteration:  39
# 	Trajectories constructed.
# 	Epsilon: 0.0560010936594076
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1450000000000000
# 	Step-size adapted to: 0.0023460897356736
# Iteration:  40
# 	Trajectories constructed.
# 	Epsilon: 0.0529305428269204
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0815000000000000
# 	Step-size adapted to: 0.0021782025100296
# Iteration:  41
# 	Trajectories constructed.
# 	Epsilon: 0.0503094898656729
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1080000000000000
# 	Step-size adapted to: 0.0020493035423743
# Iteration:  42
# 	Trajectories constructed.
# 	Epsilon: 0.0482724384227198
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1305000000000000
# 	Step-size adapted to: 0.0019498452296198
# Iteration:  43
# 	Trajectories constructed.
# 	Epsilon: 0.0450887420971896
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0925000000000000
# 	Step-size adapted to: 0.0018202975923459
# Iteration:  44
# 	Trajectories constructed.
# 	Epsilon: 0.0423348865917413
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1085000000000000
# 	Step-size adapted to: 0.0017130064762794
# Iteration:  45
# 	Trajectories constructed.
# 	Epsilon: 0.0398558986576657
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1695000000000000
# 	Step-size adapted to: 0.0016619639409191
# Iteration:  46
# 	Trajectories constructed.
# 	Epsilon: 0.0375129147375710
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1010000000000000
# 	Step-size adapted to: 0.0015581512152129
# Iteration:  47
# 	Trajectories constructed.
# 	Epsilon: 0.0353042958438433
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0495000000000000
# 	Step-size adapted to: 0.0014236870207023
# Iteration:  48
# 	Trajectories constructed.
# 	Epsilon: 0.0341628886565606
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0645000000000000
# 	Step-size adapted to: 0.0013106195967315
# Iteration:  49
# 	Trajectories constructed.
# 	Epsilon: 0.0330765332478573
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0620000000000000
# 	Step-size adapted to: 0.0012050246220857
# Iteration:  50
# 	Trajectories constructed.
# 	Epsilon: 0.0319565938002404
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1575000000000000
# 	Step-size adapted to: 0.0011621247375993
# Iteration:  51
# 	Trajectories constructed.
# 	Epsilon: 0.0310371091972797
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0950000000000000
# 	Step-size adapted to: 0.0010862702070477
# Iteration:  52
# 	Trajectories constructed.
# 	Epsilon: 0.0299237437511253
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0890000000000000
# 	Step-size adapted to: 0.0010123253385682
# Iteration:  53
# 	Trajectories constructed.
# 	Epsilon: 0.0288869345586428
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1350000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  54
# 	Trajectories constructed.
# 	Epsilon: 0.0280024778036373
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0740000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  55
# 	Trajectories constructed.
# 	Epsilon: 0.0269244844420048
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1015000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  56
# 	Trajectories constructed.
# 	Epsilon: 0.0260079995278774
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0890000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  57
# 	Trajectories constructed.
# 	Epsilon: 0.0253971339336190
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0745000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  58
# 	Trajectories constructed.
# 	Epsilon: 0.0248164320236854
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0455000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  59
# 	Trajectories constructed.
# 	Epsilon: 0.0240290306499498
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1030000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  60
# 	Trajectories constructed.
# 	Epsilon: 0.0233638500287396
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0580000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  61
# 	Trajectories constructed.
# 	Epsilon: 0.0225284678995893
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1240000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  62
# 	Trajectories constructed.
# 	Epsilon: 0.0219237081274476
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0650000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  63
# 	Trajectories constructed.
# 	Epsilon: 0.0212095751987361
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0420000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  64
# 	Trajectories constructed.
# 	Epsilon: 0.0204357891463553
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0245000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  65
# 	Trajectories constructed.
# 	Epsilon: 0.0200421673549102
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0575000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  66
# 	Trajectories constructed.
# 	Epsilon: 0.0195819152408453
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0345000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  67
# 	Trajectories constructed.
# 	Epsilon: 0.0190738932930247
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0195000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  68
# 	Trajectories constructed.
# 	Epsilon: 0.0187165688343315
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0185000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  69
# 	Trajectories constructed.
# 	Epsilon: 0.0183903851472986
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0165000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  70
# 	Trajectories constructed.
# 	Epsilon: 0.0180540916334782
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0450000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  71
# 	Trajectories constructed.
# 	Epsilon: 0.0176801454584707
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0045000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  72
# 	Trajectories constructed.
# 	Epsilon: 0.0173379394067151
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0190000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  73
# 	Trajectories constructed.
# 	Epsilon: 0.0170956737481558
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0115000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  74
# 	Trajectories constructed.
# 	Epsilon: 0.0165517458999295
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0075000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  75
# 	Trajectories constructed.
# 	Epsilon: 0.0161999410147591
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0005000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  76
# 	Trajectories constructed.
# 	Epsilon: 0.0161138895173824
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0050000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  77
# 	Trajectories constructed.
# 	Epsilon: 0.0159851434557981
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1170000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  78
# 	Trajectories constructed.
# 	Epsilon: 0.0156620272348467
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0015000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  79
# 	Trajectories constructed.
# 	Epsilon: 0.0153024738894668
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0010000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  80
# 	Trajectories constructed.
# 	Epsilon: 0.0152862990591013
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.3325000000000000
# 	Step-size adapted to: 0.0010525860068944
# Iteration:  81
# 	Trajectories constructed.
# 	Epsilon: 0.0150505863715455
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0070000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  82
# 	Trajectories constructed.
# 	Epsilon: 0.0147343807718115
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0035000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  83
# 	Trajectories constructed.
# 	Epsilon: 0.0145534167873441
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0020000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  84
# 	Trajectories constructed.
# 	Epsilon: 0.0144544001901931
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1125000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  85
# 	Trajectories constructed.
# 	Epsilon: 0.0139550972362755
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0025000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  86
# 	Trajectories constructed.
# 	Epsilon: 0.0136274267183462
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2030000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  87
# 	Trajectories constructed.
# 	Epsilon: 0.0133498956818884
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0015000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  88
# 	Trajectories constructed.
# 	Epsilon: 0.0130968336247097
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0005000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  89
# 	Trajectories constructed.
# 	Epsilon: 0.0127650756101195
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0000000000000000
# 	Step-size adapted to: 0.0010000000000000

# %% [markdown]
# ### MS-RT

# %%
MS_RT_001_ADAPTIVE = MSAdaptive(generate_settings(
        d=d, 
        N=N,
        B=B,
        δ=0.001,
        δmin=δmin,
        min_pm=min_pm,
        verbose=True,
        εs_fixed=None,
        adaptiveε=True,
        adaptiveδ=True,
        z0_manual=init_particles,
        pm_target=[0.23, 0.23],
        pm_switch=pm_switch,
        prior_seed=seed,
        low_memory=True,
        integrator='rwm_then_thug',
        εprop_switch=0.01,
        ε0_manual=ε0_manual,
        quantile_value=quantile_value,
        initialization='manual',
        switch_strategy='pm',
        kernel='uniform',
        use_autograd=False,
        stopping_criterion={'εmin', 'pm'},
        resampling_seed=1234))
_ = MS_RT_001_ADAPTIVE.sample()
# Out:
# Integrator: RWM.
# Stopping criterion:  εmin, pm.
# Iteration:  1
# 	Trajectories constructed.
# 	Epsilon: 14.5399972504226973
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9440000000000000
# 	Step-size adapted to: 0.0014290358698539
# Iteration:  2
# 	Trajectories constructed.
# 	Epsilon: 7.1486353603374466
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9540000000000000
# 	Step-size adapted to: 0.0020523798043075
# Iteration:  3
# 	Trajectories constructed.
# 	Epsilon: 1.9102718614272871
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8905000000000000
# 	Step-size adapted to: 0.0028555086832381
# Iteration:  4
# 	Trajectories constructed.
# 	Epsilon: 1.3408708975652828
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8300000000000000
# 	Step-size adapted to: 0.0038545335461787
# Iteration:  5
# 	Trajectories constructed.
# 	Epsilon: 1.0353365774809891
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8110000000000001
# 	Step-size adapted to: 0.0051538808809422
# Iteration:  6
# 	Trajectories constructed.
# 	Epsilon: 0.8062444303030953
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8155000000000000
# 	Step-size adapted to: 0.0069067555648574
# Iteration:  7
# 	Trajectories constructed.
# 	Epsilon: 0.6234714522899921
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7305000000000000
# 	Step-size adapted to: 0.0088706670817116
# Iteration:  8
# 	Trajectories constructed.
# 	Epsilon: 0.5075350421352050
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.6085000000000000
# 	Step-size adapted to: 0.0107188084777342
# Iteration:  9
# 	Trajectories constructed.
# 	Epsilon: 0.4253186290441994
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.5070000000000000
# 	Step-size adapted to: 0.0123110840639133
# Iteration:  10
# 	Trajectories constructed.
# 	Epsilon: 0.3681568991466074
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.3635000000000000
# 	Step-size adapted to: 0.0131608958856862
# Iteration:  11
# 	Trajectories constructed.
# 	Epsilon: 0.3181315959361131
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2675000000000000
# 	Step-size adapted to: 0.0134099906492963
# Iteration:  12
# 	Trajectories constructed.
# 	Epsilon: 0.2774418975040011
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1845000000000000
# 	Step-size adapted to: 0.0131083574490679
# Iteration:  13
# 	Trajectories constructed.
# 	Epsilon: 0.2418413058004555
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1535000000000000
# 	Step-size adapted to: 0.0126164308480369
# Iteration:  14
# 	Trajectories constructed.
# 	Epsilon: 0.2120039880016298
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1230000000000000
# 	Step-size adapted to: 0.0119591897551178
# Iteration:  15
# 	Trajectories constructed.
# 	Epsilon: 0.1915626322914756
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1020000000000000
# 	Step-size adapted to: 0.0112177797806372
# Iteration:  16
# 	Trajectories constructed.
# 	Epsilon: 0.1716460190729468
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0755000000000000
# 	Step-size adapted to: 0.0103838321963132
#
#
# ####################################
# ### SWITCHING TO THUG INTEGRATOR ###
# ####################################
#
#
# Iteration:  17
# 	Trajectories constructed.
# 	Epsilon: 0.1591192453328783
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9900000000000000
# 	Step-size adapted to: 0.0151841177999397
# Iteration:  18
# 	Trajectories constructed.
# 	Epsilon: 0.1411444458789913
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9975000000000001
# 	Step-size adapted to: 0.0222869209071928
# Iteration:  19
# 	Trajectories constructed.
# 	Epsilon: 0.1350681589668418
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9990000000000000
# 	Step-size adapted to: 0.0327368056504285
# Iteration:  20
# 	Trajectories constructed.
# 	Epsilon: 0.1272857435978687
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9990000000000000
# 	Step-size adapted to: 0.0480864291957017
# Iteration:  21
# 	Trajectories constructed.
# 	Epsilon: 0.1238944315356958
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 1.0000000000000000
# 	Step-size adapted to: 0.0706685050129688
# Iteration:  22
# 	Trajectories constructed.
# 	Epsilon: 0.1149816591776808
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8000000000000000
# 	Step-size adapted to: 0.0939722945503580
# Iteration:  23
# 	Trajectories constructed.
# 	Epsilon: 0.1103761381290474
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8855000000000000
# 	Step-size adapted to: 0.1304186942460540
# Iteration:  24
# 	Trajectories constructed.
# 	Epsilon: 0.1069641140175383
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.5669999999999999
# 	Step-size adapted to: 0.1543542059484541
# Iteration:  25
# 	Trajectories constructed.
# 	Epsilon: 0.1030573712337336
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.4695000000000000
# 	Step-size adapted to: 0.1739903782027134
# Iteration:  26
# 	Trajectories constructed.
# 	Epsilon: 0.0987571689515381
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2650000000000000
# 	Step-size adapted to: 0.1770620081935235
# Iteration:  27
# 	Trajectories constructed.
# 	Epsilon: 0.0936655687172728
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1785000000000000
# 	Step-size adapted to: 0.1725608624430750
# Iteration:  28
# 	Trajectories constructed.
# 	Epsilon: 0.0892044828504309
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.4795000000000000
# 	Step-size adapted to: 0.1954881961786879
# Iteration:  29
# 	Trajectories constructed.
# 	Epsilon: 0.0857422218858158
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1140000000000000
# 	Step-size adapted to: 0.1844724260485334
# Iteration:  30
# 	Trajectories constructed.
# 	Epsilon: 0.0815898306617000
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.3070000000000000
# 	Step-size adapted to: 0.1917131031329027
# Iteration:  31
# 	Trajectories constructed.
# 	Epsilon: 0.0778527107080953
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1225000000000000
# 	Step-size adapted to: 0.1816805636090603
# Iteration:  32
# 	Trajectories constructed.
# 	Epsilon: 0.0739132579682611
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1175000000000000
# 	Step-size adapted to: 0.1717431419700780
# Iteration:  33
# 	Trajectories constructed.
# 	Epsilon: 0.0695834909021727
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.4930000000000000
# 	Step-size adapted to: 0.1958795638082190
# Iteration:  34
# 	Trajectories constructed.
# 	Epsilon: 0.0651159596519889
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1450000000000000
# 	Step-size adapted to: 0.1877291063441990
# Iteration:  35
# 	Trajectories constructed.
# 	Epsilon: 0.0620187175645857
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0575000000000000
# 	Step-size adapted to: 0.1722160856099476
# Iteration:  36
# 	Trajectories constructed.
# 	Epsilon: 0.0590210175198191
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1770000000000000
# 	Step-size adapted to: 0.1677122980882605
# Iteration:  37
# 	Trajectories constructed.
# 	Epsilon: 0.0569160496590934
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1440000000000000
# 	Step-size adapted to: 0.1606535205930618
# Iteration:  38
# 	Trajectories constructed.
# 	Epsilon: 0.0547622101495369
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0745000000000000
# 	Step-size adapted to: 0.1486359458895483
# Iteration:  39
# 	Trajectories constructed.
# 	Epsilon: 0.0528210974325665
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1890000000000000
# 	Step-size adapted to: 0.1456199287967063
# Iteration:  40
# 	Trajectories constructed.
# 	Epsilon: 0.0509107204925064
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2700000000000000
# 	Step-size adapted to: 0.1485616464930005
# Iteration:  41
# 	Trajectories constructed.
# 	Epsilon: 0.0485163945692184
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1510000000000000
# 	Step-size adapted to: 0.1428078470890941
# Iteration:  42
# 	Trajectories constructed.
# 	Epsilon: 0.0460701997596367
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1460000000000000
# 	Step-size adapted to: 0.1369341290023486
# Iteration:  43
# 	Trajectories constructed.
# 	Epsilon: 0.0437988477448160
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1695000000000000
# 	Step-size adapted to: 0.1328538962545905
# Iteration:  44
# 	Trajectories constructed.
# 	Epsilon: 0.0416825876826225
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2615000000000000
# 	Step-size adapted to: 0.1349629100068107
# Iteration:  45
# 	Trajectories constructed.
# 	Epsilon: 0.0398313647746635
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1340000000000000
# 	Step-size adapted to: 0.1286377095297919
# Iteration:  46
# 	Trajectories constructed.
# 	Epsilon: 0.0380763401592635
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0685000000000000
# 	Step-size adapted to: 0.1186585451387722
# Iteration:  47
# 	Trajectories constructed.
# 	Epsilon: 0.0368908855350263
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1565000000000000
# 	Step-size adapted to: 0.1143769988812101
# Iteration:  48
# 	Trajectories constructed.
# 	Epsilon: 0.0355119398621927
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1570000000000000
# 	Step-size adapted to: 0.1102775092268895
# Iteration:  49
# 	Trajectories constructed.
# 	Epsilon: 0.0346605397525544
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1330000000000000
# 	Step-size adapted to: 0.1050566785253632
# Iteration:  50
# 	Trajectories constructed.
# 	Epsilon: 0.0334078925775580
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1580000000000000
# 	Step-size adapted to: 0.1013419052050684
# Iteration:  51
# 	Trajectories constructed.
# 	Epsilon: 0.0323676204972458
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2455000000000000
# 	Step-size adapted to: 0.1021303562719339
# Iteration:  52
# 	Trajectories constructed.
# 	Epsilon: 0.0315070156556361
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1125000000000000
# 	Step-size adapted to: 0.0963030509474957
# Iteration:  53
# 	Trajectories constructed.
# 	Epsilon: 0.0305187813687318
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1180000000000000
# 	Step-size adapted to: 0.0910583035765039
# Iteration:  54
# 	Trajectories constructed.
# 	Epsilon: 0.0296764601261302
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1155000000000000
# 	Step-size adapted to: 0.0859916329292473
# Iteration:  55
# 	Trajectories constructed.
# 	Epsilon: 0.0288048352718450
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2990000000000000
# 	Step-size adapted to: 0.0890101136684381
# Iteration:  56
# 	Trajectories constructed.
# 	Epsilon: 0.0280426453410619
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1165000000000000
# 	Step-size adapted to: 0.0840994477188877
# Iteration:  57
# 	Trajectories constructed.
# 	Epsilon: 0.0275078423061978
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2100000000000000
# 	Step-size adapted to: 0.0832626442324816
# Iteration:  58
# 	Trajectories constructed.
# 	Epsilon: 0.0268525411314794
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1720000000000000
# 	Step-size adapted to: 0.0808827034824581
# Iteration:  59
# 	Trajectories constructed.
# 	Epsilon: 0.0260939322922367
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1390000000000000
# 	Step-size adapted to: 0.0772850086865036
# Iteration:  60
# 	Trajectories constructed.
# 	Epsilon: 0.0255252556787497
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0955000000000000
# 	Step-size adapted to: 0.0722585023750291
# Iteration:  61
# 	Trajectories constructed.
# 	Epsilon: 0.0249456080585106
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0990000000000000
# 	Step-size adapted to: 0.0676772444447305
# Iteration:  62
# 	Trajectories constructed.
# 	Epsilon: 0.0243458558105492
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.3070000000000000
# 	Step-size adapted to: 0.0703336255824475
# Iteration:  63
# 	Trajectories constructed.
# 	Epsilon: 0.0236201632553090
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1370000000000000
# 	Step-size adapted to: 0.0671379863974019
# Iteration:  64
# 	Trajectories constructed.
# 	Epsilon: 0.0229768173927315
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1135000000000000
# 	Step-size adapted to: 0.0633389206252582
# Iteration:  65
# 	Trajectories constructed.
# 	Epsilon: 0.0224281134849743
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1245000000000000
# 	Step-size adapted to: 0.0600843855521051
# Iteration:  66
# 	Trajectories constructed.
# 	Epsilon: 0.0220174104358009
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1285000000000000
# 	Step-size adapted to: 0.0571111860341449
# Iteration:  67
# 	Trajectories constructed.
# 	Epsilon: 0.0216432772125029
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0945000000000000
# 	Step-size adapted to: 0.0533700645592808
# Iteration:  68
# 	Trajectories constructed.
# 	Epsilon: 0.0213700669365263
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0625000000000000
# 	Step-size adapted to: 0.0490823745555600
# Iteration:  69
# 	Trajectories constructed.
# 	Epsilon: 0.0209754462852751
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1575000000000000
# 	Step-size adapted to: 0.0473350009665402
# Iteration:  70
# 	Trajectories constructed.
# 	Epsilon: 0.0205960358364666
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0880000000000000
# 	Step-size adapted to: 0.0440907495641550
# Iteration:  71
# 	Trajectories constructed.
# 	Epsilon: 0.0200134117171834
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0880000000000000
# 	Step-size adapted to: 0.0410688530143516
# Iteration:  72
# 	Trajectories constructed.
# 	Epsilon: 0.0194500102070141
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0540000000000000
# 	Step-size adapted to: 0.0376092488424440
# Iteration:  73
# 	Trajectories constructed.
# 	Epsilon: 0.0190354177500950
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1440000000000000
# 	Step-size adapted to: 0.0360263278380424
# Iteration:  74
# 	Trajectories constructed.
# 	Epsilon: 0.0186734873769504
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1405000000000000
# 	Step-size adapted to: 0.0344496900389088
# Iteration:  75
# 	Trajectories constructed.
# 	Epsilon: 0.0179869292343040
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1550000000000000
# 	Step-size adapted to: 0.0331817491376896
# Iteration:  76
# 	Trajectories constructed.
# 	Epsilon: 0.0173324564729727
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1735000000000000
# 	Step-size adapted to: 0.0322574814731081
# Iteration:  77
# 	Trajectories constructed.
# 	Epsilon: 0.0168089859313027
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1210000000000000
# 	Step-size adapted to: 0.0305464965552834
# Iteration:  78
# 	Trajectories constructed.
# 	Epsilon: 0.0164106369887585
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1335000000000000
# 	Step-size adapted to: 0.0291076201289660
# Iteration:  79
# 	Trajectories constructed.
# 	Epsilon: 0.0160955695573860
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1080000000000000
# 	Step-size adapted to: 0.0273851254719032
# Iteration:  80
# 	Trajectories constructed.
# 	Epsilon: 0.0157987794280757
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1430000000000000
# 	Step-size adapted to: 0.0262194106246659
# Iteration:  81
# 	Trajectories constructed.
# 	Epsilon: 0.0155645427170577
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1015000000000000
# 	Step-size adapted to: 0.0245877905346196
# Iteration:  82
# 	Trajectories constructed.
# 	Epsilon: 0.0153664281114567
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0760000000000000
# 	Step-size adapted to: 0.0227655857786061
# Iteration:  83
# 	Trajectories constructed.
# 	Epsilon: 0.0151668809383718
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1350000000000000
# 	Step-size adapted to: 0.0217095010254779
# Iteration:  84
# 	Trajectories constructed.
# 	Epsilon: 0.0150073945363252
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1185000000000000
# 	Step-size adapted to: 0.0205323152774801
# Iteration:  85
# 	Trajectories constructed.
# 	Epsilon: 0.0148199220651184
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1105000000000000
# 	Step-size adapted to: 0.0193414410766002
# Iteration:  86
# 	Trajectories constructed.
# 	Epsilon: 0.0146676706061124
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0955000000000000
# 	Step-size adapted to: 0.0180835014412577
# Iteration:  87
# 	Trajectories constructed.
# 	Epsilon: 0.0145657378893985
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1635000000000000
# 	Step-size adapted to: 0.0174921113622861
# Iteration:  88
# 	Trajectories constructed.
# 	Epsilon: 0.0144788436850427
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1345000000000000
# 	Step-size adapted to: 0.0166764909483574
# Iteration:  89
# 	Trajectories constructed.
# 	Epsilon: 0.0143670967956864
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1400000000000000
# 	Step-size adapted to: 0.0159426833524421
# Iteration:  90
# 	Trajectories constructed.
# 	Epsilon: 0.0142367011935396
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1500000000000000
# 	Step-size adapted to: 0.0153175617967759
# Iteration:  91
# 	Trajectories constructed.
# 	Epsilon: 0.0141315055388022
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2325000000000000
# 	Step-size adapted to: 0.0153367207208548
# Iteration:  92
# 	Trajectories constructed.
# 	Epsilon: 0.0140022185566948
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1655000000000000
# 	Step-size adapted to: 0.0148500020010568
# Iteration:  93
# 	Trajectories constructed.
# 	Epsilon: 0.0138644110111667
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1990000000000000
# 	Step-size adapted to: 0.0146216016455428
# Iteration:  94
# 	Trajectories constructed.
# 	Epsilon: 0.0137502637511884
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1635000000000000
# 	Step-size adapted to: 0.0141434270962201
# Iteration:  95
# 	Trajectories constructed.
# 	Epsilon: 0.0136231393271405
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1320000000000000
# 	Step-size adapted to: 0.0134671043902873
# Iteration:  96
# 	Trajectories constructed.
# 	Epsilon: 0.0135293969175419
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1125000000000000
# 	Step-size adapted to: 0.0126987047490549
# Iteration:  97
# 	Trajectories constructed.
# 	Epsilon: 0.0134600033088588
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0990000000000000
# 	Step-size adapted to: 0.0118935947630468
# Iteration:  98
# 	Trajectories constructed.
# 	Epsilon: 0.0134089399093011
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0715000000000000
# 	Step-size adapted to: 0.0109874092105385
# Iteration:  99
# 	Trajectories constructed.
# 	Epsilon: 0.0133678208997914
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1905000000000000
# 	Step-size adapted to: 0.0107725367288167
# Iteration:  100
# 	Trajectories constructed.
# 	Epsilon: 0.0133052906034738
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1790000000000000
# 	Step-size adapted to: 0.0105013098814809
# Iteration:  101
# 	Trajectories constructed.
# 	Epsilon: 0.0132444388552252
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1500000000000000
# 	Step-size adapted to: 0.0100895476313928
# Iteration:  102
# 	Trajectories constructed.
# 	Epsilon: 0.0131846295945645
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1270000000000000
# 	Step-size adapted to: 0.0095830891667644
# Iteration:  103
# 	Trajectories constructed.
# 	Epsilon: 0.0131376857007843
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1645000000000000
# 	Step-size adapted to: 0.0092743265806711
# Iteration:  104
# 	Trajectories constructed.
# 	Epsilon: 0.0130964883945575
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1785000000000000
# 	Step-size adapted to: 0.0090385611779019
# Iteration:  105
# 	Trajectories constructed.
# 	Epsilon: 0.0130464183467693
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2175000000000000
# 	Step-size adapted to: 0.0089822463377320
# Iteration:  106
# 	Trajectories constructed.
# 	Epsilon: 0.0130093222247742
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1155000000000000
# 	Step-size adapted to: 0.0084824557411767
# Iteration:  107
# 	Trajectories constructed.
# 	Epsilon: 0.0129744135396659
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1145000000000000
# 	Step-size adapted to: 0.0080064702816854
# Iteration:  108
# 	Trajectories constructed.
# 	Epsilon: 0.0129513927283341
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1630000000000000
# 	Step-size adapted to: 0.0077426964075321
# Iteration:  109
# 	Trajectories constructed.
# 	Epsilon: 0.0129286742813400
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1405000000000000
# 	Step-size adapted to: 0.0074038489990977
# Iteration:  110
# 	Trajectories constructed.
# 	Epsilon: 0.0129084284919966
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1140000000000000
# 	Step-size adapted to: 0.0069866417188285
# Iteration:  111
# 	Trajectories constructed.
# 	Epsilon: 0.0128936295531301
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1040000000000000
# 	Step-size adapted to: 0.0065600616448983
# Iteration:  112
# 	Trajectories constructed.
# 	Epsilon: 0.0128819628895247
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0780000000000000
# 	Step-size adapted to: 0.0060799714485203
# Iteration:  113
# 	Trajectories constructed.
# 	Epsilon: 0.0128716843766008
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1030000000000000
# 	Step-size adapted to: 0.0057058958505233
# Iteration:  114
# 	Trajectories constructed.
# 	Epsilon: 0.0128600404168194
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1430000000000000
# 	Step-size adapted to: 0.0054630104375436
# Iteration:  115
# 	Trajectories constructed.
# 	Epsilon: 0.0128488075676792
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2285000000000000
# 	Step-size adapted to: 0.0054589147158031
# Iteration:  116
# 	Trajectories constructed.
# 	Epsilon: 0.0128312074606890
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2090000000000000
# 	Step-size adapted to: 0.0054018959834904
# Iteration:  117
# 	Trajectories constructed.
# 	Epsilon: 0.0128166681713929
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1330000000000000
# 	Step-size adapted to: 0.0051461558548388
# Iteration:  118
# 	Trajectories constructed.
# 	Epsilon: 0.0128011236020610
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1430000000000000
# 	Step-size adapted to: 0.0049270971438485
# Iteration:  119
# 	Trajectories constructed.
# 	Epsilon: 0.0127906524491340
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1580000000000000
# 	Step-size adapted to: 0.0047528764348619
# Iteration:  120
# 	Trajectories constructed.
# 	Epsilon: 0.0127833438007236
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1550000000000000
# 	Step-size adapted to: 0.0045779440501758
# Iteration:  121
# 	Trajectories constructed.
# 	Epsilon: 0.0127766365624655
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0775000000000000
# 	Step-size adapted to: 0.0042418521428204
# Iteration:  122
# 	Trajectories constructed.
# 	Epsilon: 0.0127707632948062
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1425000000000000
# 	Step-size adapted to: 0.0040602721362487
# Iteration:  123
# 	Trajectories constructed.
# 	Epsilon: 0.0127648788045697
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1140000000000000
# 	Step-size adapted to: 0.0038314755879502
# Iteration:  124
# 	Trajectories constructed.
# 	Epsilon: 0.0127603978801061
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1050000000000000
# 	Step-size adapted to: 0.0035993382171713
# Iteration:  125
# 	Trajectories constructed.
# 	Epsilon: 0.0127556661591184
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1130000000000000
# 	Step-size adapted to: 0.0033948174862749
# Iteration:  126
# 	Trajectories constructed.
# 	Epsilon: 0.0127513219229522
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1320000000000000
# 	Step-size adapted to: 0.0032324811492015
# Iteration:  127
# 	Trajectories constructed.
# 	Epsilon: 0.0127459914040396
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2000000000000000
# 	Step-size adapted to: 0.0031843557746202
# Iteration:  128
# 	Trajectories constructed.
# 	Epsilon: 0.0127397702210859
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1945000000000000
# 	Step-size adapted to: 0.0031283321402799
# Iteration:  129
# 	Trajectories constructed.
# 	Epsilon: 0.0127328251085501
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1730000000000000
# 	Step-size adapted to: 0.0030404331839892
# Iteration:  130
# 	Trajectories constructed.
# 	Epsilon: 0.0127275407796939
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2465000000000000
# 	Step-size adapted to: 0.0030656205126285
# Iteration:  131
# 	Trajectories constructed.
# 	Epsilon: 0.0127220480691586
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1950000000000000
# 	Step-size adapted to: 0.0030124388504351
# Iteration:  132
# 	Trajectories constructed.
# 	Epsilon: 0.0127165004268222
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2010000000000000
# 	Step-size adapted to: 0.0029690736446377
# Iteration:  133
# 	Trajectories constructed.
# 	Epsilon: 0.0127103753818490
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1990000000000000
# 	Step-size adapted to: 0.0029234078274927
# Iteration:  134
# 	Trajectories constructed.
# 	Epsilon: 0.0127057800186267
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2060000000000000
# 	Step-size adapted to: 0.0028885365795047
# Iteration:  135
# 	Trajectories constructed.
# 	Epsilon: 0.0127013317073184
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1585000000000000
# 	Step-size adapted to: 0.0027870954605658
# Iteration:  136
# 	Trajectories constructed.
# 	Epsilon: 0.0126971640866619
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1520000000000000
# 	Step-size adapted to: 0.0026804910356578
# Iteration:  137
# 	Trajectories constructed.
# 	Epsilon: 0.0126935303873975
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1415000000000000
# 	Step-size adapted to: 0.0025644653080705
# Iteration:  138
# 	Trajectories constructed.
# 	Epsilon: 0.0126908828730600
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1130000000000000
# 	Step-size adapted to: 0.0024187478768320
# Iteration:  139
# 	Trajectories constructed.
# 	Epsilon: 0.0126888990132668
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1405000000000000
# 	Step-size adapted to: 0.0023128950309263
# Iteration:  140
# 	Trajectories constructed.
# 	Epsilon: 0.0126865535142281
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1010000000000000
# 	Step-size adapted to: 0.0021684226199906
# Iteration:  141
# 	Trajectories constructed.
# 	Epsilon: 0.0126850362159635
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1935000000000000
# 	Step-size adapted to: 0.0021292078305382
# Iteration:  142
# 	Trajectories constructed.
# 	Epsilon: 0.0126832354426933
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1355000000000000
# 	Step-size adapted to: 0.0020309425588553
# Iteration:  143
# 	Trajectories constructed.
# 	Epsilon: 0.0126814559233456
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1100000000000000
# 	Step-size adapted to: 0.0019126696716767
# Iteration:  144
# 	Trajectories constructed.
# 	Epsilon: 0.0126801390660127
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2495000000000000
# 	Step-size adapted to: 0.0019314094087401
# Iteration:  145
# 	Trajectories constructed.
# 	Epsilon: 0.0126787318723786
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1395000000000000
# 	Step-size adapted to: 0.0018459609832074
# Iteration:  146
# 	Trajectories constructed.
# 	Epsilon: 0.0126775735151212
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1750000000000000
# 	Step-size adapted to: 0.0017958887055440
# Iteration:  147
# 	Trajectories constructed.
# 	Epsilon: 0.0126761231326527
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1385000000000000
# 	Step-size adapted to: 0.0017155779140901
# Iteration:  148
# 	Trajectories constructed.
# 	Epsilon: 0.0126747660191048
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1300000000000000
# 	Step-size adapted to: 0.0016319081919060
# Iteration:  149
# 	Trajectories constructed.
# 	Epsilon: 0.0126735621907164
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1255000000000000
# 	Step-size adapted to: 0.0015488302986341
# Iteration:  150
# 	Trajectories constructed.
# 	Epsilon: 0.0126725995710255
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2565000000000000
# 	Step-size adapted to: 0.0015694888608274
# Iteration:  151
# 	Trajectories constructed.
# 	Epsilon: 0.0126717480294676
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1100000000000000
# 	Step-size adapted to: 0.0014780889449828
# Iteration:  152
# 	Trajectories constructed.
# 	Epsilon: 0.0126709321295567
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1300000000000000
# 	Step-size adapted to: 0.0014060016964968
# Iteration:  153
# 	Trajectories constructed.
# 	Epsilon: 0.0126701435543471
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0970000000000000
# 	Step-size adapted to: 0.0013155436470432
# Iteration:  154
# 	Trajectories constructed.
# 	Epsilon: 0.0126695067494872
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1110000000000000
# 	Step-size adapted to: 0.0012395519702343
# Iteration:  155
# 	Trajectories constructed.
# 	Epsilon: 0.0126689332827074
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1030000000000000
# 	Step-size adapted to: 0.0011632874435930
# Iteration:  156
# 	Trajectories constructed.
# 	Epsilon: 0.0126683718439974
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2085000000000000
# 	Step-size adapted to: 0.0011508490795648
# Iteration:  157
# 	Trajectories constructed.
# 	Epsilon: 0.0126677075462673
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1250000000000000
# 	Step-size adapted to: 0.0010919881220282
# Iteration:  158
# 	Trajectories constructed.
# 	Epsilon: 0.0126671536913595
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1410000000000000
# 	Step-size adapted to: 0.0010444599943120
# Iteration:  159
# 	Trajectories constructed.
# 	Epsilon: 0.0126665907759125
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1055000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  160
# 	Trajectories constructed.
# 	Epsilon: 0.0126662107984407
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1335000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  161
# 	Trajectories constructed.
# 	Epsilon: 0.0126659005486127
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1070000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  162
# 	Trajectories constructed.
# 	Epsilon: 0.0126656187506647
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0815000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  163
# 	Trajectories constructed.
# 	Epsilon: 0.0126653334511602
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0615000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  164
# 	Trajectories constructed.
# 	Epsilon: 0.0126650716388444
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0545000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  165
# 	Trajectories constructed.
# 	Epsilon: 0.0126648502653284
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1355000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  166
# 	Trajectories constructed.
# 	Epsilon: 0.0126646485073360
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0580000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  167
# 	Trajectories constructed.
# 	Epsilon: 0.0126644784409258
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0720000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  168
# 	Trajectories constructed.
# 	Epsilon: 0.0126642909564402
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1050000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  169
# 	Trajectories constructed.
# 	Epsilon: 0.0126640710122930
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0955000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  170
# 	Trajectories constructed.
# 	Epsilon: 0.0126637116417381
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0950000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  171
# 	Trajectories constructed.
# 	Epsilon: 0.0126635199037757
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0870000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  172
# 	Trajectories constructed.
# 	Epsilon: 0.0126633339842929
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0650000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  173
# 	Trajectories constructed.
# 	Epsilon: 0.0126631065293813
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0560000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  174
# 	Trajectories constructed.
# 	Epsilon: 0.0126629967229786
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0445000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  175
# 	Trajectories constructed.
# 	Epsilon: 0.0126628793198812
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0250000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  176
# 	Trajectories constructed.
# 	Epsilon: 0.0126626973486778
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0145000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  177
# 	Trajectories constructed.
# 	Epsilon: 0.0126625177669887
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0935000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  178
# 	Trajectories constructed.
# 	Epsilon: 0.0126623620218759
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1515000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  179
# 	Trajectories constructed.
# 	Epsilon: 0.0126620618155394
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1175000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  180
# 	Trajectories constructed.
# 	Epsilon: 0.0126618264640350
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0575000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  181
# 	Trajectories constructed.
# 	Epsilon: 0.0126616283126596
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0635000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  182
# 	Trajectories constructed.
# 	Epsilon: 0.0126614697277259
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1640000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  183
# 	Trajectories constructed.
# 	Epsilon: 0.0126612748096468
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0615000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  184
# 	Trajectories constructed.
# 	Epsilon: 0.0126610639784777
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0495000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  185
# 	Trajectories constructed.
# 	Epsilon: 0.0126608316138075
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1150000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  186
# 	Trajectories constructed.
# 	Epsilon: 0.0126604511241681
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0640000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  187
# 	Trajectories constructed.
# 	Epsilon: 0.0126602281854471
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1860000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  188
# 	Trajectories constructed.
# 	Epsilon: 0.0126600245482554
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0410000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  189
# 	Trajectories constructed.
# 	Epsilon: 0.0126598376687719
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0760000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  190
# 	Trajectories constructed.
# 	Epsilon: 0.0126596430106840
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0420000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  191
# 	Trajectories constructed.
# 	Epsilon: 0.0126594717615337
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0535000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  192
# 	Trajectories constructed.
# 	Epsilon: 0.0126593351571793
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0615000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  193
# 	Trajectories constructed.
# 	Epsilon: 0.0126592174735902
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0555000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  194
# 	Trajectories constructed.
# 	Epsilon: 0.0126590791921860
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0695000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  195
# 	Trajectories constructed.
# 	Epsilon: 0.0126589094945566
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0290000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  196
# 	Trajectories constructed.
# 	Epsilon: 0.0126587635247882
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0700000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  197
# 	Trajectories constructed.
# 	Epsilon: 0.0126586069582639
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0810000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  198
# 	Trajectories constructed.
# 	Epsilon: 0.0126584103759301
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1325000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  199
# 	Trajectories constructed.
# 	Epsilon: 0.0126581651248948
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1190000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  200
# 	Trajectories constructed.
# 	Epsilon: 0.0126578517098356
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0795000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  201
# 	Trajectories constructed.
# 	Epsilon: 0.0126576715468313
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0410000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  202
# 	Trajectories constructed.
# 	Epsilon: 0.0126575014671964
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0225000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  203
# 	Trajectories constructed.
# 	Epsilon: 0.0126573647939406
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0975000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  204
# 	Trajectories constructed.
# 	Epsilon: 0.0126572250425545
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0735000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  205
# 	Trajectories constructed.
# 	Epsilon: 0.0126570639880477
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0515000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  206
# 	Trajectories constructed.
# 	Epsilon: 0.0126568496527386
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1375000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  207
# 	Trajectories constructed.
# 	Epsilon: 0.0126567262833373
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0295000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  208
# 	Trajectories constructed.
# 	Epsilon: 0.0126565481267829
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1110000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  209
# 	Trajectories constructed.
# 	Epsilon: 0.0126563709812595
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0640000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  210
# 	Trajectories constructed.
# 	Epsilon: 0.0126561256513987
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0615000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  211
# 	Trajectories constructed.
# 	Epsilon: 0.0126558434394315
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0835000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  212
# 	Trajectories constructed.
# 	Epsilon: 0.0126556375445078
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0620000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  213
# 	Trajectories constructed.
# 	Epsilon: 0.0126554398998702
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1230000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  214
# ...
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0600000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  434
# 	Trajectories constructed.
# 	Epsilon: 0.0126122372118977
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0925000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  435
# 	Trajectories constructed.
# 	Epsilon: 0.0126121246728212
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0470000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  436
# 	Trajectories constructed.
# 	Epsilon: 0.0126119138262794
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0305000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  437
# 	Trajectories constructed.
# 	Epsilon: 0.0126117358294943
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0415000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  438
# 	Trajectories constructed.
# 	Epsilon: 0.0126115920363541
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0895000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  439
# 	Trajectories constructed.
# 	Epsilon: 0.0126113869389912
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0935000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  440
# 	Trajectories constructed.
# 	Epsilon: 0.0126112528792893
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1085000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  441
# 	Trajectories constructed.
# 	Epsilon: 0.0126111152960118
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0475000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  442
# 	Trajectories constructed.
# 	Epsilon: 0.0126109429751388
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0455000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  443
# 	Trajectories constructed.
# 	Epsilon: 0.0126107752405904
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0590000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  444
# 	Trajectories constructed.
# 	Epsilon: 0.0126106384226322
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0515000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  445
# 	Trajectories constructed.
# 	Epsilon: 0.0126104773725212
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0370000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  446
# 	Trajectories constructed.
# 	Epsilon: 0.0126103757272043
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0570000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  447
# 	Trajectories constructed.
# 	Epsilon: 0.0126102423660996
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0355000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  448
# 	Trajectories constructed.
# 	Epsilon: 0.0126101351831587
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0225000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  449
# 	Trajectories constructed.
# 	Epsilon: 0.0126099536355193
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0470000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  450
# 	Trajectories constructed.
# 	Epsilon: 0.0126097617995295
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1040000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  451
# 	Trajectories constructed.
# 	Epsilon: 0.0126095343833232
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0750000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  452
# 	Trajectories constructed.
# 	Epsilon: 0.0126093639521960
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0760000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  453
# 	Trajectories constructed.
# 	Epsilon: 0.0126091895602103
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0905000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  454
# 	Trajectories constructed.
# 	Epsilon: 0.0126089726801928
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0490000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  455
# 	Trajectories constructed.
# 	Epsilon: 0.0126086659382715
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1520000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  456
# 	Trajectories constructed.
# 	Epsilon: 0.0126083628920117
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1195000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  457
# 	Trajectories constructed.
# 	Epsilon: 0.0126081563261425
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0605000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  458
# 	Trajectories constructed.
# 	Epsilon: 0.0126079667433836
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0840000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  459
# 	Trajectories constructed.
# 	Epsilon: 0.0126077824258450
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1345000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  460
# 	Trajectories constructed.
# 	Epsilon: 0.0126075814708137
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0370000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  461
# 	Trajectories constructed.
# 	Epsilon: 0.0126073848494787
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0990000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  462
# 	Trajectories constructed.
# 	Epsilon: 0.0126072182778600
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0445000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  463
# 	Trajectories constructed.
# 	Epsilon: 0.0126069631992432
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0530000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  464
# 	Trajectories constructed.
# 	Epsilon: 0.0126068211568924
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0310000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  465
# 	Trajectories constructed.
# 	Epsilon: 0.0126067065278497
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0240000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  466
# 	Trajectories constructed.
# 	Epsilon: 0.0126065971835347
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1065000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  467
# 	Trajectories constructed.
# 	Epsilon: 0.0126063619988382
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0890000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  468
# 	Trajectories constructed.
# 	Epsilon: 0.0126060729091463
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0565000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  469
# 	Trajectories constructed.
# 	Epsilon: 0.0126058558650945
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1270000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  470
# 	Trajectories constructed.
# 	Epsilon: 0.0126057189135386
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0460000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  471
# 	Trajectories constructed.
# 	Epsilon: 0.0126055688554016
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0735000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  472
# 	Trajectories constructed.
# 	Epsilon: 0.0126053763486085
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1160000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  473
# 	Trajectories constructed.
# 	Epsilon: 0.0126051579862081
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0730000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  474
# 	Trajectories constructed.
# 	Epsilon: 0.0126049659915231
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0560000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  475
# 	Trajectories constructed.
# 	Epsilon: 0.0126048091405330
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0510000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  476
# 	Trajectories constructed.
# 	Epsilon: 0.0126046606640514
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0655000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  477
# 	Trajectories constructed.
# 	Epsilon: 0.0126045229688662
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0860000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  478
# 	Trajectories constructed.
# 	Epsilon: 0.0126043981617299
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0270000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  479
# 	Trajectories constructed.
# 	Epsilon: 0.0126042614449583
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1565000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  480
# 	Trajectories constructed.
# 	Epsilon: 0.0126041217727141
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0450000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  481
# 	Trajectories constructed.
# 	Epsilon: 0.0126039688299828
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0890000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  482
# 	Trajectories constructed.
# 	Epsilon: 0.0126038280294211
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0570000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  483
# 	Trajectories constructed.
# 	Epsilon: 0.0126036339467199
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0435000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  484
# 	Trajectories constructed.
# 	Epsilon: 0.0126034036125050
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0245000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  485
# 	Trajectories constructed.
# 	Epsilon: 0.0126032457099500
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0215000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  486
# 	Trajectories constructed.
# 	Epsilon: 0.0126031525303965
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0260000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  487
# 	Trajectories constructed.
# 	Epsilon: 0.0126029955795747
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1730000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  488
# 	Trajectories constructed.
# 	Epsilon: 0.0126027823852861
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0675000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  489
# 	Trajectories constructed.
# 	Epsilon: 0.0126025370266484
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2795000000000000
# 	Step-size adapted to: 0.0010250588237827
# Iteration:  490
# 	Trajectories constructed.
# 	Epsilon: 0.0126023029868307
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0610000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  491
# 	Trajectories constructed.
# 	Epsilon: 0.0126020870149674
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0500000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  492
# 	Trajectories constructed.
# 	Epsilon: 0.0126019263428754
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0720000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  493
# 	Trajectories constructed.
# 	Epsilon: 0.0126017178081408
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0660000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  494
# 	Trajectories constructed.
# 	Epsilon: 0.0126014961990856
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0700000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  495
# 	Trajectories constructed.
# 	Epsilon: 0.0126013011385956
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0360000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  496
# 	Trajectories constructed.
# 	Epsilon: 0.0126011432349920
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0295000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  497
# 	Trajectories constructed.
# 	Epsilon: 0.0126009439831352
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0745000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  498
# 	Trajectories constructed.
# 	Epsilon: 0.0126007703318502
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0840000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  499
# 	Trajectories constructed.
# 	Epsilon: 0.0126004613653737
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1035000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  500
# 	Trajectories constructed.
# 	Epsilon: 0.0126001486734758
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1530000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  501
# 	Trajectories constructed.
# 	Epsilon: 0.0125997444874090
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1595000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  502
# 	Trajectories constructed.
# 	Epsilon: 0.0125994308148880
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1695000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  503
# 	Trajectories constructed.
# 	Epsilon: 0.0125990998279525
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0590000000000000
# 	Step-size adapted to: 0.0010000000000000
# Iteration:  504
# 	Trajectories constructed.
# 	Epsilon: 0.0125988616267594
# ValueError was raised:

# %% [markdown]
# # Plot

# %%
fig, ax = plt.subplots()
# ax.plot(SMC_RWM_01.εs, label='SMC-RWM-01', markevery=[-1], marker='o')
# ax.plot(SMC_RWM_001.εs, label='SMC-RWM-001', markevery=[-1], marker='o')
# ax.plot(SMC_RWM_0001.εs, label='SMC-RWM-0001', markevery=[-1], marker='o')
ax.plot(SMC_RT_001_ADAPTIVE.εs, label='SMC-RWM-001_A', markevery=[-1], marker='o')
ax.plot(MS_RT_001_ADAPTIVE.εs, label='MS-RT-001_A', markevery=[-1], marker='o')
ax.plot(MS_RWM_001_ADAPTIVE.εs, label='MS_RWM_001_A', markevery=[-1], marker='o')
ax.set_yscale('log')
ax.legend()
plt.show()
