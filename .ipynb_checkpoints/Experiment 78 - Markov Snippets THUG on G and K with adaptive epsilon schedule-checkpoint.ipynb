# %% [markdown]
# Similar to Experiment 76 but here the list of $\epsilon$s is adaptively chosen based on the distance of the particles, as done in Chang's code. The only thing to be careful about is that in Chang's code he was using a uniform kernel, whereas here are using a normal kernel.

# %%
import numpy as np
from numpy.random import rand, randn
from numpy import ones, exp, log, diag, vstack, pi, array, r_, isfinite, logspace, zeros, eye, quantile
from numpy.linalg import norm, solve
from numpy.random import default_rng, choice, randint
from scipy.optimize import fsolve
from scipy.stats import multivariate_normal as MVN
from scipy.special import ndtri, ndtr
from scipy.stats import uniform as udist
from scipy.stats import norm as ndist
from scipy.linalg import block_diag

import time
from math import prod
from warnings import catch_warnings, filterwarnings, resetwarnings


import matplotlib.pyplot as plt
from matplotlib import rc
from ipywidgets.widgets import interact


from RWM import RWM
from Manifolds.Manifold import Manifold
from Manifolds.GKManifoldNew import GKManifold, data_generator, find_point_on_manifold, find_point_on_manifold_from_θ
from markov_snippets import MSAdaptiveTolerances
# from tangential_hug_functions import HugTangentialMultivariate
# from utils import ESS_univariate, prep_contour
from copy import deepcopy

# %% [markdown]
# # G-and-K Functions and Settings

# %%
# class GKManifold(Manifold):
#     def __init__(self, ystar, kernel_type='normal'):
#         assert kernel_type in ['normal', 'uniform']
#         self.m = len(ystar)            # Number constraints = dimensionality of the data
#         self.d = 4                     # Manifold has dimension 4 (like the parameter θ)
#         self.n = self.d + self.m       # Dimension of ambient space is m + 4
#         self.ystar = ystar
#         self.kernel_type = kernel_type
#         # N(0, 1) ---> U(0, 10).
#         self.G    = lambda θ: 10*ndtr(θ)
#         # U(0, 10) ---> N(0, 1)
#         self.Ginv = lambda θ: ndtri(θ/10)

#     def q(self, ξ):
#         """Constraint for G and K."""
#         ξ = r_[self.G(ξ[:4]), ξ[4:]]   # expecting theta part to be N(0, 1)
#         with catch_warnings():
#             filterwarnings('error')
#             try:
#                 return (ξ[0] + ξ[1]*(1 + 0.8*(1 - exp(-ξ[2]*ξ[4:]))/(1 + exp(-ξ[2]*ξ[4:]))) * ((1 + ξ[4:]**2)**ξ[3])*ξ[4:]) - self.ystar
#             except RuntimeWarning:
#                 raise ValueError("Constraint found Overflow warning.")
                
#     def _q_raw_uniform(self, ξ):
#         """Constraint function expecting ξ[:4] ~ U(0, 10). It doesn't do any warning check."""
#         return (ξ[0] + ξ[1]*(1 + 0.8*(1 - exp(-ξ[2]*ξ[4:]))/(1 + exp(-ξ[2]*ξ[4:]))) * ((1 + ξ[4:]**2)**ξ[3])*ξ[4:]) - self.ystar
#     def _q_raw_normal(self, ξ):
#         """Same as `_q_raw_uniform` except expects ξ[:4]~N(0,1)."""
#         ξ = r_[self.G(ξ[:4]), ξ[4:]] 
#         return self._q_raw_uniform(ξ)

#     def Q(self, ξ):
#         """Transpose of Jacobian for G and K. """
#         ξ = r_[self.G(ξ[:4]), ξ[4:]]
#         return vstack((
#         ones(len(ξ[4:])),
#         (1 + 0.8 * (1 - exp(-ξ[2] * ξ[4:])) / (1 + exp(-ξ[2] * ξ[4:]))) * ((1 + ξ[4:]**2)**ξ[3]) * ξ[4:],
#         8 * ξ[1] * (ξ[4:]**2) * ((1 + ξ[4:]**2)**ξ[3]) * exp(ξ[2]*ξ[4:]) / (5 * (1 + exp(ξ[2]*ξ[4:]))**2),
#         ξ[1]*ξ[4:]*((1+ξ[4:]**2)**ξ[3])*(1 + 9*exp(ξ[2]*ξ[4:]))*log(1 + ξ[4:]**2) / (5*(1 + exp(ξ[2]*ξ[4:]))),
#         diag(ξ[1]*((1+ξ[4:]**2)**(ξ[3]-1))*(((18*ξ[3] + 9)*(ξ[4:]**2) + 9)*exp(2*ξ[2]*ξ[4:]) + (8*ξ[2]*ξ[4:]**3 + (20*ξ[3] + 10)*ξ[4:]**2 + 8*ξ[2]*ξ[4:] + 10)*exp(ξ[2]*ξ[4:]) + (2*ξ[3] + 1)*ξ[4:]**2 + 1) / (5*(1 + exp(ξ[2]*ξ[4:]))**2))
#     ))
    
#     def J(self, ξ):
#         """Safely computes Jacobian."""
#         with catch_warnings():
#             filterwarnings('error')
#             try:
#                 return self.Q(ξ).T
#             except RuntimeWarning:
#                 raise ValueError("J computation found Runtime warning.")
                
#     def fullJacobian(self, ξ):
#         """J_f(G(ξ)) * J_G(ξ)."""
#         JGbar = block_diag(10*np.diag(ndist.pdf(ξ[:4])), eye(len(ξ[4:])))
#         return self.J(ξ) @ JGbar
                
#     def log_parameter_prior(self, θ):
#         """IMPORTANT: Typically the prior distribution is a U(0, 10) for all four parameters.
#         We keep the same prior but since we don't want to work on a constrained space, we 
#         reparametrize the problem to an unconstrained space N(0, 1)."""
#         with catch_warnings():
#             filterwarnings('error')
#             try:
#                 return udist.logpdf(self.G(θ), loc=0.0, scale=10.0).sum() + ndist.logpdf(θ).sum()
#             except RuntimeWarning:
#                 return -np.inf
            
#     def logprior(self, ξ):
#         """Computes the prior distribution for G and K problem. Notice this is already reparametrized."""
#         return self.log_parameter_prior(ξ[:4]) - ξ[4:]@ξ[4:]/2

#     def logη(self, ξ):
#         """log posterior for c-rwm. This is on the manifold."""
#         try:
#             J = self.J(ξ)
#             logprior = self.logprior(ξ)
#             correction_term  = - prod(np.linalg.slogdet(J@J.T))/2 
#             return  logprior + correction_term
#         except ValueError as e:
#             return -np.inf
        
#     def generate_logηϵ(self, ϵ):
#         """Returns the log abc posterior for THUG."""
#         if self.kernel_type not in ['normal', 'uniform']:
#             raise NotImplementedError
#         else:
#             if self.kernel_type == 'normal':
#                 def log_abc_posterior(ξ):
#                     """Log-ABC-posterior."""
#                     u = self.q(ξ)
#                     m = len(u)
#                     return self.logprior(ξ) - u@u/(2*ϵ**2) - m*log(ϵ) - m*log(2*pi)/2
#                 return log_abc_posterior
#             else:
#                 # uniform kernel
#                 def log_abc_posterior(ξ):
#                     with np.errstate(divide='ignore'):
#                         try:
#                             return log(float(norm(self.q(ξ)) <= ϵ) / ϵ**(self.m))
#                         except ValueError:
#                             return -np.inf
#                 return log_abc_posterior
            
#     def indicator_kernel(self, ξ, ϵ):
#         """Implements the indicator kernel or approximation to the identity. Notice usually we have
#         used the Gaussian kernel but for Markov Snippets, I want to check it works with indicator
#         kernel first. The expression for the kernel is
        
#         k_ϵ(y) prop (1 / ϵ^m) * I(||f(x) - y|| < ϵ)
        
#         Sometimes the function q could run in an Overflow error, which is caught by the context manager
#         in q and then raises ValueError. This means that f(x) is too large. Another way to look at it is to
#         say that it is unsuitable and therefore we simply make sure to return 0 with the indicator function.
#         """
#         try:
#             return log(float(norm(self.q(ξ)) <= ϵ) / (ϵ**self.m))
#         except ValueError:
#             return -np.inf
            
#     def logp(self, v):
#         """Log density for normal on the tangent space."""
#         return MVN(mean=zeros(self.d), cov=eye(self.d)).logpdf(v)
    
#     def is_on_manifold(self, ξ, tol=1e-8):
#         """Checks if ξ is on the ystar manifold."""
#         return np.max(abs(self.q(ξ))) < tol
    
    
# """
# OTHER FUNCTIONS
# """    
# def generate_powers_of_ten(max_exponent, min_exponent):
#     """E.g. generate_powers_of_ten(2, -1) will return 100, 10, 0, 0.1."""
#     number_of_powers = max_exponent + abs(min_exponent) + 1
#     return logspace(start=max_exponent, stop=min_exponent, num=number_of_powers, endpoint=True)


# def data_generator(θ0, m, seed):
#     """Stochastic Simulator. Generates y given θ."""
#     rng = default_rng(seed)
#     z = rng.normal(size=m)
#     ξ = r_[θ0, z]
#     return ξ[0] + ξ[1]*(1 + 0.8*(1 - exp(-ξ[2]*ξ[4:]))/(1 + exp(-ξ[2]*ξ[4:]))) * ((1 + ξ[4:]**2)**ξ[3])*ξ[4:]

# def find_point_on_manifold(ystar, ϵ, max_iter=1000, tol=1.49012e-08, kernel_type='normal'):
#     """Find a point on the data manifold."""
#     i = 0
#     manifold = GKManifold(ystar=ystar, kernel_type=kernel_type)
#     log_abc_posterior = manifold.generate_logηϵ(ϵ)
#     with catch_warnings():
#         filterwarnings('error')
#         while i <= max_iter:
#             i += 1
#             try: 
#                 # Sample θ from U(0, 10)
#                 θfixed = randn(4)
#                 function = lambda z: manifold._q_raw_normal(r_[θfixed, z])
#                 z_guess  = randn(manifold.m)
#                 z_found  = fsolve(function, z_guess, xtol=tol)
#                 ξ_found  = r_[θfixed, z_found]
#                 if not isfinite([log_abc_posterior(ξ_found)]):
#                     pass
#                 else:
#                     resetwarnings()
#                     return ξ_found

#             except RuntimeWarning:
#                 continue
#         resetwarnings()
#         raise ValueError("Couldn't find a point, try again.") 
        
        
# def find_point_on_manifold_from_θ(ystar, θfixed, ϵ, maxiter=2000, tol=1.49012e-08, kernel_type='normal'):
#     """Same as the above but we provide the θfixed. Can be used to find a point where
#     the theta is already θ0."""
#     i = 0
#     manifold = GKManifold(ystar=ystar, kernel_type=kernel_type)
#     log_abc_posterior = manifold.generate_logηϵ(ϵ)
#     function = lambda z: manifold._q_raw_normal(r_[θfixed, z])
#     with catch_warnings():
#         filterwarnings('error')
#         while i <= maxiter:
#             i += 1
#             try:
#                 z_guess  = randn(manifold.m)
#                 z_found  = fsolve(function, z_guess, xtol=tol)
#                 ξ_found  = r_[θfixed, z_found]
#                 if not isfinite([log_abc_posterior(ξ_found)]):
#                     resetwarnings()
#                     raise ValueError("Couldn't find a point.")
#                 else:
#                     resetwarnings()
#                     return ξ_found
#             except RuntimeWarning:
#                 continue
#         resetwarnings()
#         raise ValueError("Couldn't find a point, try again.")

# %%
def generate_setting(m, B, δ, N, thinning=10, thug=True, verbose=True, initialization='init_RWMϵ0', burnin=100, δ0=0.01, kernel_type='uniform', ϵmin=1e-4, quantile_value=0.01, maxiter=50):
    """Generates an object from which one can grab the settings. This allows one to run multiple scenarios."""
    θ0        = array([3.0, 1.0, 2.0, 0.5])      # True parameter value on U(0, 10) scale.
    d         = 4 + m                            # Dimensionality of ξ=(θ, z)
    ystar     = data_generator(θ0, m, seed=1234) # Observed data
    q         = MVN(zeros(d), eye(d))            # Proposal distribution for THUG
    ξ0        = find_point_on_manifold_from_θ(ystar=ystar, θfixed=ndtri(θ0/10), ϵ=1e-5, maxiter=5000, tol=1e-15, kernel_type=kernel_type)
    resetwarnings()
    manifold  = GKManifold(ystar, kernel_type=kernel_type)
    if δ0 is None:
        δ0 = δ
    return {
        'θ0': θ0,
        'm' : m,
        'd' : d,
        'ystar': ystar,
        'q': q,
        'ξ0': ξ0,
        'B': B,
        'δ': δ,
        'N': N,
        'manifold': manifold,
        'thinning': thinning,
        'thug': thug,
        'verbose': verbose,
        'initialization': initialization,
        'burnin': burnin,
        'δ0': δ0,
        'kernel_type': kernel_type,
        'ϵmin': ϵmin,
        'quantile_value': quantile_value,
        'maxiter': maxiter
    }

# %%
# def generate_setting(m, B, δ, N, quantile_value, ϵmin, ϵ0, maxiter, thinning=10, kernel_type='normal', δ0=None, verbose=True):
#     """Generates an object from which one can grab the settings. This allows one to run multiple scenarios."""
#     θ0        = array([3.0, 1.0, 2.0, 0.5])      # True parameter value on U(0, 10) scale.
#     d         = 4 + m                            # Dimensionality of ξ=(θ, z)
#     ystar     = data_generator(θ0, m, seed=1234) # Observed data
#     q         = MVN(zeros(d), eye(d))            # Proposal distribution for THUG
#     ξ0        = find_point_on_manifold_from_θ(ystar=ystar, θfixed=ndtri(θ0/10), ϵ=1e-5, maxiter=5000, tol=1e-15, kernel_type=kernel_type)
#     resetwarnings()
#     manifold  = GKManifold(ystar, kernel_type=kernel_type)
#     if δ0 is None:
#         δ0 = δ
#     return {
#         'θ0': θ0,
#         'm' : m,
#         'd' : d,
#         'ystar': ystar,
#         'q': q,
#         'ξ0': ξ0,
#         'B': B,
#         'δ': δ,
#         'N': N,
#         'manifold': manifold,
#         'thinning': thinning,
#         'quantile_value': quantile_value,
#         'ϵmin': ϵmin,
#         'ϵ0': ϵ0,
#         'maxiter': maxiter,
#         'kernel_type': kernel_type,
#         'δ0': δ0,
#         'verbose': verbose
#     }

# %% [markdown]
# # Multivariate Markov Snippets

# %%
# def linear_project(v, J):
#     """Projects by solving linear system."""
#     return J.T.dot(solve(J.dot(J.T), J.dot(v)))

# def THUGIntegratorMultivariate(z0, B, δ):
#     """THUG Integrator for the 2D example (ie using gradients, not jacobians)."""
#     trajectory = zeros((B + 1, len(z0)))
#     x0, v0 = z0[:len(z0)//2], z0[len(z0)//2:]
#     x, v = x0, v0
#     trajectory[0, :] = z0
#     # Integrate
#     for b in range(B):
#         x = x + δ*v/2
#         v = v - 2*linear_project(v, SETTINGS50['manifold'].fullJacobian(x))
#         x = x + δ*v/2
#         trajectory[b+1, :] = np.hstack((x, v))
#     return trajectory

# def generate_THUGIntegratorMultivariate(B, δ):
#     """Returns a THUG integrator for a given B and δ."""
#     integrator = lambda z: THUGIntegratorMultivariate(z, B, δ)
#     return integrator

# #### Random Walk Integrator
# def RWMIntegrator(z0, B, δ):
#     """Basically returns B+1 points on the line starting at x0 with direction v0."""
#     trajectory = zeros((B+1, len(z0)))
#     x0, v0 = z0[:len(z0)//2], z0[len(z0)//2:]
#     bs  = np.arange(B+1).reshape(-1, 1) # 0, 1, ..., B
#     xbs = x0 + δ*bs*v0     # move them by b*δ
#     vbs = np.repeat(v0.reshape(1, -1), repeats=B+1, axis=0)
#     zbs = np.hstack((xbs, vbs))
#     return zbs

# def generate_RWMIntegrator(B, δ):
#     """Generates the integrator above."""
#     integrator = lambda z: RWMIntegrator(z, B, δ)
#     return integrator


# #### Metropolis-Hastings version of THUG-ψ for SMC
# def THUG_MH(z0, B, δ, logpi):
#     """Similar to THUGIntegratoUnivariateOnlyEnd but this uses a MH step.
#     Notice this returns a single z = (x, v), not the whole trajectory."""
#     x0, v0 = z0[:len(z0)//2], z0[len(z0)//2:]
#     x, v = x0, v0
#     logu = np.log(np.random.rand())
#     for _ in range(B):
#         x = x + δ*v/2
#         v = v - 2*linear_project(v, SETTINGS50['manifold'].fullJacobian(x))
#         x = x + δ*v/2
#     if logu <= logpi(x) - logpi(x0):
#         # accept new point
#         return np.concatenate((x, v))
#     else:
#         # accept old point
#         return z0
    
# #### Metropolis-Hastings version of RWM-ψ for SMC 
# def RWM_MH(z0, B, δ, logpi):
#     """Similar to RWMIntegrator but this uses a MH step. Notice this has to return a single z = (x, v)
#     not the whole trajectory. Since this is RWM, we simply need to perform """
#     x0, v0 = z0[:len(z0)//2], z0[len(z0)//2:]
#     logu = np.log(np.random.rand())
#     x_new = x0 + B*δ*v0
#     if logu <= logpi(x_new) - logpi(x0):
#         # accept new position, old velocity
#         return np.concatenate((x_new, v0))
#     else:
#         # accept old position and old velocity
#         return z0

# %%
# class MultivariateMarkovSnippetsTHUG:
    
#     def __init__(self, SETTINGS, force_rwm=True, adaptiveB=False, ρ=None, Bprop=0.1, Bmin=10, Bmax=60, δmin=1e-4):
#         """Multivariate Markov Snippets SMC samplers corresponding exactly to Algorithm 1 in Christophe's notes.
#         It uses the Multivariate THUG kernel as its mutation kernel. The sequence of distributions is fixed here 
#         since we provide ϵs, i.e. a list of tolerances which automatically fully specify the posterior 
#         distributions used at each round.
        
#         Parameters
#         ----------
        
#         :param N: Number of particles
#         :type N:  int
        
#         :param B: Number of bounces for the THUG integrator. Equivalent to `L` Leapfrog steps in HMC.
#         :type B: int
        
#         :param δ: Step-size used at each bounce, for the THUG integrator.
#         :type δ: float
        
#         :param d: Dimensionality of the `x` component of each particle, and equally dimensionality of 
#                   `v` component of each particle. Therefore each particle has dimension `2d`.
        
#         :param ϵs: Tolerances that fully specify the sequence of target filamentary distributions.
#         :type ϵs: iterable
#         """
#         assert Bprop < 1 and Bprop > 0.0, "Bprop must be between [0, 1]."
#         # Input variables
#         self.N  = SETTINGS['N']       
#         self.B  = SETTINGS['B']
#         self.δ  = SETTINGS['δ']
#         self.δ0 = SETTINGS['δ0']
#         self.d  = SETTINGS['d']
#         self.manifold = SETTINGS['manifold']
#         self.SETTINGS = SETTINGS
#         self.quantile_value = SETTINGS['quantile_value']
#         self.ϵ_min = SETTINGS['ϵ_min']
#         self.ϵs     = []
#         self.log_ηs = []
#         self.maxiter = SETTINGS['maxiter']
#         self.adaptiveB = adaptiveB
#         self.ρ = ρ
#         self.Bprop = Bprop
#         self.Bmin = Bmin
#         self.Bmax = Bmax
#         self.δmin = δmin
        
#         # Variables derived from the above
#         if not force_rwm:
#             self.ψ = generate_THUGIntegratorMultivariate(self.B, self.δ)
#             self.ψ_generator = generate_THUGIntegratorMultivariate
#         else:
#             self.ψ = generate_RWMIntegrator(self.B, self.δ)
#             self.ψ_generator = generate_RWMIntegrator
            
#         # choose function to compute distances
#         if self.manifold.kernel_type == 'uniform':
#             # distance function is linear in ||f(x) - y||
#             self.compute_distances = lambda XNK: norm(np.apply_along_axis(self.manifold.q, 1, XNK), axis=1)
#         elif self.manifold.kernel_type == 'normal':
#             # distance function is quadratic in ||f(x) - y||
#             self.compute_distances = lambda XNK: norm(np.apply_along_axis(self.manifold.q, 1, XNK), axis=1)**2
#         else:
#             raise ValueError("Manifold has an unexpected kernel type.")
            
#         if adaptiveB and (ρ is None):
#             raise ValueError("ρ can't be None if using adaptive strategy.")
    
#     def initialize_particles(self):
#         """There's three strategies:
        
#         1. Start with ϵ0=infinity and sample from the prior using RWM.
#         2. Start with ϵ0=infinity ans sample from the prior using THUG.
#         3. Start with large but finite ϵ0 and sample from ηϵ0 with THUG.
#         4. Start with large but finite ϵ0 and samlpe from ηϵ0 with RWM.
        
#         Here we use strategy 4.
#         """
#         # Initialize first position on the manifold
#         x0 = self.SETTINGS['ξ0']
#         # Grab ϵ0
#         ϵ0 = self.SETTINGS['ϵ0']
#         log_ηϵ0 = self.manifold.generate_logηϵ(ϵ0)
# #         ϵ0 = np.inf
#         self.ϵs.append(ϵ0)
# #         log_ηϵ0 = self.manifold.logprior
#         self.log_ηs.append(log_ηϵ0)
#         # Sample using RWM
#         burn_in = 100
#         thinning = 10
#         ### try initializing using Tangential Hug as MCMC kernel?
#         TO_BE_THINNED, acceptance = RWM(x0, self.δ0, burn_in + thinning*self.N, log_ηϵ0)
# #         q = MVN(zeros(self.d), eye(self.d))
# #         TO_BE_THINNED, acceptance = HugTangentialMultivariate(x0, self.B*self.δ, self.B, burn_in + thinning*self.N, 0.0, q, log_ηϵ0, self.manifold.fullJacobian, method='linear')
#         print("Initializing particles. Acceptance: ", np.mean(acceptance)*100)
#         # Thin the samples to obtain the particles
#         initialized_particles = TO_BE_THINNED[burn_in:][::thinning]
#         # Refresh velocities and form particles
#         v0 = np.random.normal(loc=0.0, scale=1.0, size=(self.N, self.d))
#         z0 = np.hstack((initialized_particles, v0))
#         self.starting_particles = z0
#         return z0
        
#     def sample(self, manual_initialization=False, z_starting=None):
#         """Starts the Markov Snippets sampler."""
#         if manual_initialization and (z_starting is None):
#             raise ValueError("If manual initialization, must provide z.")
            
#         if manual_initialization:
#             self.ϵs.append(self.SETTINGS['ϵ0'])
#             self.log_ηs.append(self.manifold.generate_logηϵ(self.SETTINGS['ϵ0']))
        
#         starting_time = time.time() 
        
#         # Initialize particles
#         if not manual_initialization:
#             z = self.initialize_particles()   # (N, 2d)
#         else:
#             z = z_starting
        
#         ## Storage
#         #### Store z_n^{(i)}
# #         self.ZN  = np.zeros((N, 2*self.d))  #np.zeros((self.P+1, N, 2*self.d))
#         #### Store z_{n, k}^{(i)} so basically all the N(T+1) particles
# #         self.ZNK  = zeros((1, N*(B+1), 2*self.d)) #np.zeros((self.P, N*(B+1), 2*self.d))
# #         self.Wbar = zeros((1, N*(B+1)))
# #         self.DISTANCES = zeros(N*(B+1))
#         self.ESS  = [self.N]
#         self.K_RESAMPLED = zeros((1, self.N))
#         self.Bs = [self.B]
#         self.δs = [self.δ]
#         self.AP2 = []
        
# #         self.ZN = z
#         # For each target distribution, run the following loop
#         n = 1 # counts the iteration number, basically equivalent to n before
#         while n <= self.maxiter:
#             try:
#                 print("Iteration: ", n)
                
#                 ##### RECONSTRUCT PATHS
#                 Z = np.apply_along_axis(self.ψ, 1, z)
# #                 self.ZNK = np.vstack((self.ZNK, Z.reshape(1, N*(B+1), 2*self.d)))
                
#                 ##### ADAPTIVELY CHOOSE ϵ (choose it based on ALL particles, not just the starting points)
#                 ## Compute distances ||f(x)-y|| for all particles
# #                 distances = norm(np.apply_along_axis(self.manifold.q, 1, self.ZNK[-1, :, :self.d]), axis=1)
#                 distances = norm(np.apply_along_axis(self.manifold.q, 1, Z.reshape(self.N*(self.B+1), 2*self.d)[:, :self.d]), axis=1)
# #                 self.DISTANCES = np.vstack((self.DISTANCES, distances))
#                 ## Find ϵ based on quantile value and store it
# #                 ϵ = max(self.ϵ_min, min(self.ϵs[-1], quantile(np.unique(distances), self.quantile_value)))
#                 ϵ = max(self.ϵ_min, quantile(np.unique(distances), self.quantile_value))
#                 print("\tEpsilon: ", ϵ)
#                 self.ϵs.append(ϵ)
#                 # Use ϵ to construct the target distribution
#                 self.log_ηs.append(self.manifold.generate_logηϵ(ϵ))

#                 ##### COMPUTE WEIGHTS
#                 # Log-Denominator: shared for each point in the same trajectory
#                 log_μnm1_z  = np.apply_along_axis(self.log_ηs[-2], 1, Z[:, 0, :self.d])  # (N, )
#                 log_μnm1_z  = np.repeat(log_μnm1_z, self.B+1, axis=0).reshape(self.N, self.B+1)     # (N, B+1)
#                 # Log-Numerator: different for each point on a trajectory.
#                 log_μn_ψk_z = np.apply_along_axis(self.log_ηs[-1], 2, Z[:, :, :self.d])    # (N, B+1)
#                 # Compute weights, normalize and store
#                 W = exp(log_μn_ψk_z - log_μnm1_z)
#                 W = W / W.sum()
# #                 self.Wbar = np.vstack((self.Wbar, W.flatten()))

#                 ##### COMPUTE ESS
#                 self.ESS.append(1 / np.sum(W**2))

#                 ##### RESAMPLE PARTICLES
#                 resampling_indeces = choice(a=np.arange(self.N*(self.B+1)), size=self.N, p=W.flatten())
#                 unravelled_indeces = np.unravel_index(resampling_indeces, (self.N, self.B+1))
#                 self.K_RESAMPLED = np.vstack((self.K_RESAMPLED, unravelled_indeces[1]))
#                 indeces = np.dstack(unravelled_indeces).squeeze()
#                 z = np.vstack([Z[tuple(ix)] for ix in indeces])     # (N, 2d)

#                 ##### REJUVENATE VELOCITIES
#                 z[:, self.d:] = np.random.normal(loc=0.0, scale=1.0, size=(self.N, self.d))
# #                 self.ZN = np.vstack((self.ZN, z))
                
#                 ##### UPDATE B OR δ IF ADAPTIVE
#                 if self.adaptiveB:
#                     τ = unravelled_indeces[1]
#                     τ_median = int(np.median(τ))
#                     difference = (self.B//2) - τ_median
#                     ### Adjust step size, keep B fixed
#                     self.δ = max(self.δmin, (np.max(τ) / self.B) * self.δ)
#                     print("\tSetting δ: {:.5f}".format(self.δ))
#                     self.ψ = self.ψ_generator(self.B, self.δ)
                    
# #                     if difference >= self.ρ*self.B:
# #                         # Left-skewed: decrease B
# #                         self.B = max(self.Bmin, np.floor((1-self.Bprop)*self.B).astype(int)) 
# #                         print("\tLeft-skewed. B = ", self.B)
# #                     elif -difference >= self.ρ*self.B:
# #                         # Right-skewed: leave B unchanged
# #                         print("\tRight-skewed.")
# #                         pass
# #                     else:
# #                         # Uniform: increase B
# #                         self.B = min(self.Bmax, np.ceil((1+self.Bprop)*self.B).astype(int))
# #                         print("\tUniform. B = ", self.B)
# #                     # Update integrator
# #                     self.ψ = self.ψ_generator(self.B, self.δ)
# #                     if difference >= self.ρ*self.B:
# #                         # left-skewed
# #                         B_new = max(self.Bmin, np.ceil(quantile(τ, q=0.95)).astype(int))  # Decrease B
# #                         if B_new != self.Bmin:
# #                             self.δ = max(self.δmin, (B_new / self.B) * self.δ)                # Decrease δ
# #                         else:
# #                             # if we can't decrease B, only decrease δ using Bmult
# #                             self.δ = max(self.δmin, (1-self.Bmult)*self.δ)
# #                         self.B = B_new
                        
# #                         print("\tIndices distribution is left-skewed. B: ", self.B, " δ: {:.6f}".format(self.δ))
# #                         self.ψ = self.ψ_generator(self.B, self.δ)
# #                     elif -difference >= self.ρ*self.B:
# #                         # right-skewed
# #                         self.δ = max(self.δ, self.δ*quantile(τ, q=0.05))  # Increase δ
# #                         print("\tIndices distribution is right-skewed. B: ", self.B, " δ: {:.6f}".format(self.δ))
# #                         self.ψ = self.ψ_generator(self.B, self.δ)
# #                     else:
# #                         # uniform
# #                         B_new = min(self.Bmax, np.ceil(self.Bmult*self.B).astype(int)) # Increase B
# #                         if B_new != self.Bmax:
# #                             self.δ = self.Bmult * self.δ  # increase δ
# #                         else:
# #                             # if we can't increase B, we still increase δ
# #                             self.δ = self.Bmult * self.δ
# #                         self.B = B_new
# #                         self.ψ = self.ψ_generator(self.B, self.δ)
# #                         print("\tInidices distribution is approximately flat. B: ", self.B, " δ: {:.6f}".format(self.δ))
#                 self.Bs.append(self.B)
#                 self.δs.append(self.δ)
                
#                 # Compute fake acceptance probabilities just to see what they look like
#                 self.AP2.append(sum(self.K_RESAMPLED[-1] >= 1) / (self.N*self.B))
#                 print("\tFake AP 2: {:.5f}".format(self.AP2[-1]))
              
                        
                    
#             except (ValueError, RuntimeError, KeyboardInterrupt) as e:
#                 print("EXITING: ", e)
#                 self.total_time = time.time() - starting_time
#                 return z
#             n += 1
                
#         self.total_time = time.time() - starting_time
#         return z

# %% [markdown]
# ### Common Settings

# %%
N       = 5000
B       = 20
δ       = 0.01
δ0      = 0.01
m       = 50
ϵmin    = 1e-4
ϵ0      = 20
maxiter = 50
thinning= 10
burnin  = 100
quantile_value = 0.01
kernel_type = 'uniform'
initialization = 'init_prior'

# %% [markdown]
# ### Try

# %%
SETTINGS50 = generate_setting(
    m=m, B=B, δ=δ, N=N, thinning=thinning, δ0=δ0, 
    kernel_type=kernel_type, thug=False, verbose=True, initialization=initialization,
    burnin=burnin, maxiter=maxiter, ϵmin=ϵmin, quantile_value=quantile_value)

# %%
# Instantitate the algorithm
MSRWM = MSAdaptiveTolerances(SETTINGS50)
# Sample
zP = MSRWM.sample()
# Out:
# Integrator: RWM.
# Initializing particles from prior.
# Iteration:  1
# 	Trajectories constructed.
# 	Epsilon: 27.950858
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.047
# Iteration:  2
# 	Trajectories constructed.
# 	Epsilon: 19.828983
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.050
# Iteration:  3
# 	Trajectories constructed.
# 	Epsilon: 19.148685
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.048
# Iteration:  4
# 	Trajectories constructed.
# 	Epsilon: 18.855953
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.050
# Iteration:  5
# 	Trajectories constructed.
# 	Epsilon: 18.472274
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.048
# Iteration:  6
# 	Trajectories constructed.
# 	Epsilon: 17.995294
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.049
# Iteration:  7
# 	Trajectories constructed.
# 	Epsilon: 17.469696
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.050
# Iteration:  8
# 	Trajectories constructed.
# 	Epsilon: 16.368416
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.048
# Iteration:  9
# 	Trajectories constructed.
# 	Epsilon: 14.575315
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.048
# Iteration:  10
# 	Trajectories constructed.
# 	Epsilon: 12.831241
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.049
# Iteration:  11
# 	Trajectories constructed.
# 	Epsilon: 11.325981
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.046
# Iteration:  12
# 	Trajectories constructed.
# 	Epsilon: 10.386500
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.045
# Iteration:  13
# 	Trajectories constructed.
# 	Epsilon: 9.824402
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.046
# Iteration:  14
# 	Trajectories constructed.
# 	Epsilon: 9.424744
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.042
# Iteration:  15
# 	Trajectories constructed.
# 	Epsilon: 9.099859
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.042
# Iteration:  16
# 	Trajectories constructed.
# 	Epsilon: 8.879582
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.043
# Iteration:  17
# 	Trajectories constructed.
# 	Epsilon: 8.516972
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.039
# Iteration:  18
# 	Trajectories constructed.
# 	Epsilon: 8.345408
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.041
# Iteration:  19
# 	Trajectories constructed.
# 	Epsilon: 8.182001
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.039
# Iteration:  20
# 	Trajectories constructed.
# 	Epsilon: 7.897565
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.038
# Iteration:  21
# 	Trajectories constructed.
# 	Epsilon: 7.774159
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.038
# Iteration:  22
# 	Trajectories constructed.
# 	Epsilon: 7.641293
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.034
# Iteration:  23
# 	Trajectories constructed.
# 	Epsilon: 7.522837
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.034
# Iteration:  24
# 	Trajectories constructed.
# 	Epsilon: 7.475032
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.033
# Iteration:  25
# 	Trajectories constructed.
# 	Epsilon: 7.428655
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.031
# Iteration:  26
# 	Trajectories constructed.
# 	Epsilon: 7.386660
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.031
# Iteration:  27
# 	Trajectories constructed.
# 	Epsilon: 7.345484
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.032
# Iteration:  28
# 	Trajectories constructed.
# 	Epsilon: 7.305890
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.030
# Iteration:  29
# 	Trajectories constructed.
# 	Epsilon: 7.275378
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.029
# Iteration:  30
# 	Trajectories constructed.
# 	Epsilon: 7.240503
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.027
# Iteration:  31
# 	Trajectories constructed.
# 	Epsilon: 7.215717
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.025
# Iteration:  32
# 	Trajectories constructed.
# 	Epsilon: 7.195663
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.026
# Iteration:  33
# 	Trajectories constructed.
# 	Epsilon: 7.171082
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.028
# Iteration:  34
# 	Trajectories constructed.
# 	Epsilon: 7.136719
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.030
# Iteration:  35
# 	Trajectories constructed.
# 	Epsilon: 7.104784
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.027
# Iteration:  36
# 	Trajectories constructed.
# 	Epsilon: 7.081533
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.026
# Iteration:  37
# 	Trajectories constructed.
# 	Epsilon: 7.060917
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.025
# Iteration:  38
# 	Trajectories constructed.
# 	Epsilon: 7.040571
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.020
# Iteration:  39
# 	Trajectories constructed.
# 	Epsilon: 7.026813
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.021
# Iteration:  40
# 	Trajectories constructed.
# 	Epsilon: 7.014772

# %% [markdown]
# ### MS-THUG (adaptive $\epsilon$ but fixed $\delta$ and $B$)

# %%
SETTINGS50 = generate_setting(
    m=m, ϵ0=ϵ0, B=B, δ=δ, N=N, quantile_value=quantile_value, 
    ϵ_min=ϵ_min, maxiter=maxiter, kernel_type=kernel_type)

# %%
# Instantitate the algorithm
MSTHUG = MultivariateMarkovSnippetsTHUG(SETTINGS50, force_rwm=False)

# %%
# Initialize particles
z_starting = MSTHUG.initialize_particles()
# Out:
# Initializing particles. Acceptance:  77.72654690618762

# %%
# Sample
zP = MSTHUG.sample(manual_initialization=True, z_starting=z_starting)
# Out:
# Iteration:  1
# EXITING:  J computation found Runtime warning.

# %%
def plot_histogram(n):
    fig, ax = plt.subplots(figsize=(20, 4))
    bins        = np.arange(-0.5, SETTINGS50['B']+0.5, step=1.0)
    bins_labels = np.arange(SETTINGS50['B'])
    _ = ax.hist(MSTHUG.K_RESAMPLED[n, :], density=True, bins=bins, edgecolor='k', color='lightsalmon')
    ax.set_xticks(bins_labels)
    ax.set_xticklabels(bins_labels)
    plt.show()

resetwarnings()
interact(plot_histogram, n=(0, len(MSTHUG.ϵs) - 2))
# Out:
# interactive(children=(IntSlider(value=50, description='n'), Output()), _dom_classes=('widget-interact',))
# <function __main__.plot_histogram(n)>

# %%
fig, ax = plt.subplots()
ax.plot(np.array(MSTHUG.ESS) / (MSTHUG.N*(MSTHUG.B+1)), label='MS')
ax.legend()
ax.set_title("ESS / number of particles ")
plt.show()

# %% [markdown]
# ### MS-RWM

# %%
SETTINGS50_rwm = generate_setting(
    m=m, ϵ0=ϵ0, B=B, δ=δ, N=N, quantile_value=quantile_value, 
    ϵ_min=ϵ_min, maxiter=maxiter, thinning=thinning, kernel_type=kernel_type, δ0 = δ0
)

# %%
MSRWM = MultivariateMarkovSnippetsTHUG(SETTINGS50_rwm, force_rwm=True)

# %%
# Sample
zP_rwm = MSRWM.sample(manual_initialization=True, z_starting=z_starting)
# Out:
# Iteration:  1
# 	Epsilon:  18.824334822982138
# 	Fake AP 2: 0.04721
# Iteration:  2
# 	Epsilon:  14.964819488513937
# 	Fake AP 2: 0.04765
# Iteration:  3
# 	Epsilon:  12.746970189438947
# 	Fake AP 2: 0.04850
# Iteration:  4
# 	Epsilon:  10.532256428474131
# 	Fake AP 2: 0.04723
# Iteration:  5
# 	Epsilon:  8.835493676916466
# 	Fake AP 2: 0.04787
# Iteration:  6
# 	Epsilon:  7.54305739882532
# 	Fake AP 2: 0.04657
# Iteration:  7
# 	Epsilon:  6.701928031127629
# 	Fake AP 2: 0.04855
# Iteration:  8
# 	Epsilon:  6.013567631583986
# 	Fake AP 2: 0.04662
# Iteration:  9
# 	Epsilon:  5.504313100693387
# 	Fake AP 2: 0.04624
# Iteration:  10
# 	Epsilon:  5.067889037172733
# 	Fake AP 2: 0.04417
# Iteration:  11
# 	Epsilon:  4.687036433376503
# 	Fake AP 2: 0.04462
# Iteration:  12
# 	Epsilon:  4.241187045360235
# 	Fake AP 2: 0.04076
# Iteration:  13
# 	Epsilon:  3.9355099886348666
# 	Fake AP 2: 0.03964
# Iteration:  14
# 	Epsilon:  3.73150454452002
# 	Fake AP 2: 0.04044
# Iteration:  15
# 	Epsilon:  3.568933737649319
# 	Fake AP 2: 0.03561
# Iteration:  16
# 	Epsilon:  3.4649834463666482
# 	Fake AP 2: 0.03680
# Iteration:  17
# 	Epsilon:  3.370004932767555
# 	Fake AP 2: 0.03213
# Iteration:  18
# 	Epsilon:  3.2930775254491644
# 	Fake AP 2: 0.03471
# Iteration:  19
# 	Epsilon:  3.207446573027367
# 	Fake AP 2: 0.03101
# Iteration:  20
# 	Epsilon:  3.1235973435833957
# 	Fake AP 2: 0.03309
# Iteration:  21
# 	Epsilon:  3.0481866931944395
# 	Fake AP 2: 0.03335
# Iteration:  22
# 	Epsilon:  2.9650631318492633
# 	Fake AP 2: 0.03059
# Iteration:  23
# 	Epsilon:  2.884948180188811
# 	Fake AP 2: 0.03052
# Iteration:  24
# 	Epsilon:  2.8252952988741282
# 	Fake AP 2: 0.03028
# Iteration:  25
# 	Epsilon:  2.7520543314884294
# 	Fake AP 2: 0.02683
# Iteration:  26
# 	Epsilon:  2.695257545679881
# 	Fake AP 2: 0.03361
# Iteration:  27
# 	Epsilon:  2.624563809791407
# 	Fake AP 2: 0.03152
# Iteration:  28
# 	Epsilon:  2.55566447321936
# 	Fake AP 2: 0.03200
# Iteration:  29
# 	Epsilon:  2.4927293204600627
# 	Fake AP 2: 0.03189
# Iteration:  30
# 	Epsilon:  2.425979118241665
# 	Fake AP 2: 0.02744
# Iteration:  31
# 	Epsilon:  2.3749383536267645
# 	Fake AP 2: 0.02957
# Iteration:  32
# 	Epsilon:  2.324952793854911
# 	Fake AP 2: 0.02784
# Iteration:  33
# 	Epsilon:  2.2813726592992905
# 	Fake AP 2: 0.02574
# Iteration:  34
# 	Epsilon:  2.248300446709055
# 	Fake AP 2: 0.02310
# Iteration:  35
# 	Epsilon:  2.2144530356423893
# 	Fake AP 2: 0.02329
# Iteration:  36
# 	Epsilon:  2.181795575406889
# 	Fake AP 2: 0.02816
# Iteration:  37
# 	Epsilon:  2.149826963358054
# 	Fake AP 2: 0.02335
# Iteration:  38
# 	Epsilon:  2.116705710482346
# 	Fake AP 2: 0.02354
# Iteration:  39
# 	Epsilon:  2.0856273911292837
# 	Fake AP 2: 0.02306
# Iteration:  40
# 	Epsilon:  2.052701549853354
# 	Fake AP 2: 0.02379
# Iteration:  41
# 	Epsilon:  2.022091904314114
# 	Fake AP 2: 0.02359
# Iteration:  42
# 	Epsilon:  1.9891908097546198
# 	Fake AP 2: 0.02392
# Iteration:  43
# 	Epsilon:  1.9539159244943918
# 	Fake AP 2: 0.02322
# Iteration:  44
# 	Epsilon:  1.921622438242256
# 	Fake AP 2: 0.01957
# Iteration:  45
# 	Epsilon:  1.899950622456611
# 	Fake AP 2: 0.01757
# Iteration:  46
# 	Epsilon:  1.8814845044747743
# 	Fake AP 2: 0.01340
# Iteration:  47
# 	Epsilon:  1.8665413569239273
# 	Fake AP 2: 0.01535
# Iteration:  48
# 	Epsilon:  1.8521274031963273
# 	Fake AP 2: 0.01511
# Iteration:  49
# 	Epsilon:  1.8371146017796673
# 	Fake AP 2: 0.01617
# Iteration:  50
# 	Epsilon:  1.822553990118504
# 	Fake AP 2: 0.01576
# Iteration:  51
# 	Epsilon:  1.808094342895814
# 	Fake AP 2: 0.01503
# Iteration:  52
# 	Epsilon:  1.796361129060999
# 	Fake AP 2: 0.01193
# Iteration:  53
# 	Epsilon:  1.7867085103572442
# 	Fake AP 2: 0.01193
# Iteration:  54
# 	Epsilon:  1.77801093880036
# 	Fake AP 2: 0.01113
# Iteration:  55
# 	Epsilon:  1.766721535691336
# 	Fake AP 2: 0.01406
# Iteration:  56
# 	Epsilon:  1.753603372526188
# 	Fake AP 2: 0.01425
# Iteration:  57
# 	Epsilon:  1.737803630035229
# 	Fake AP 2: 0.01471
# Iteration:  58
# 	Epsilon:  1.7234197622386571
# 	Fake AP 2: 0.01422
# Iteration:  59
# 	Epsilon:  1.710226550708511
# 	Fake AP 2: 0.01380
# Iteration:  60
# 	Epsilon:  1.6960836033392346
# 	Fake AP 2: 0.01368
# Iteration:  61
# 	Epsilon:  1.6795900696020303
# 	Fake AP 2: 0.01590
# Iteration:  62
# 	Epsilon:  1.6396605584041033
# 	Fake AP 2: 0.02222
# Iteration:  63
# 	Epsilon:  1.589199702334876
# 	Fake AP 2: 0.02016
# Iteration:  64
# 	Epsilon:  1.5653277655898608
# 	Fake AP 2: 0.01783
# Iteration:  65
# 	Epsilon:  1.548876074638007
# 	Fake AP 2: 0.01313
# Iteration:  66
# 	Epsilon:  1.5359857175335825
# 	Fake AP 2: 0.01299
# Iteration:  67
# 	Epsilon:  1.524451471948562
# 	Fake AP 2: 0.01185
# Iteration:  68
# 	Epsilon:  1.513163999186124
# 	Fake AP 2: 0.01195
# Iteration:  69
# 	Epsilon:  1.5030225271890378
# 	Fake AP 2: 0.01159
# Iteration:  70
# 	Epsilon:  1.492855767570423
# 	Fake AP 2: 0.01188
# Iteration:  71
# 	Epsilon:  1.4808368429193506
# 	Fake AP 2: 0.01213
# Iteration:  72
# 	Epsilon:  1.4681058637504811
# 	Fake AP 2: 0.01314
# Iteration:  73
# 	Epsilon:  1.4551792556729328
# 	Fake AP 2: 0.01071
# Iteration:  74
# 	Epsilon:  1.4420921981116168
# 	Fake AP 2: 0.01100
# Iteration:  75
# 	Epsilon:  1.4317915296797454
# 	Fake AP 2: 0.00898
# Iteration:  76
# 	Epsilon:  1.4240634707648088
# 	Fake AP 2: 0.00902
# Iteration:  77
# 	Epsilon:  1.4174831811958382
# 	Fake AP 2: 0.00772
# Iteration:  78
# 	Epsilon:  1.4104500573943834
# 	Fake AP 2: 0.00955
# Iteration:  79
# 	Epsilon:  1.4035250187231245
# 	Fake AP 2: 0.00834
# Iteration:  80
# 	Epsilon:  1.3978768224897906
# 	Fake AP 2: 0.00687
# Iteration:  81
# 	Epsilon:  1.3929031558443115
# 	Fake AP 2: 0.00768
# Iteration:  82
# 	Epsilon:  1.387308405721087
# 	Fake AP 2: 0.00824
# Iteration:  83
# 	Epsilon:  1.3796154000618586
# 	Fake AP 2: 0.00949
# Iteration:  84
# 	Epsilon:  1.3687918705284228
# 	Fake AP 2: 0.01100
# Iteration:  85
# 	Epsilon:  1.353899243077573
# 	Fake AP 2: 0.01404
# Iteration:  86
# 	Epsilon:  1.33686435634207
# 	Fake AP 2: 0.01262
# Iteration:  87
# 	Epsilon:  1.3235869580931132
# 	Fake AP 2: 0.01148
# Iteration:  88
# 	Epsilon:  1.3140795809813692
# 	Fake AP 2: 0.00885
# Iteration:  89
# 	Epsilon:  1.307208691997082
# 	Fake AP 2: 0.00778
# Iteration:  90
# 	Epsilon:  1.3015733062150188
# 	Fake AP 2: 0.00632
# Iteration:  91
# 	Epsilon:  1.297040136682397
# 	Fake AP 2: 0.00574
# Iteration:  92
# 	Epsilon:  1.293305884845476
# 	Fake AP 2: 0.00784
# Iteration:  93
# 	Epsilon:  1.288175752868242
# 	Fake AP 2: 0.00689
# Iteration:  94
# 	Epsilon:  1.283740583622396
# 	Fake AP 2: 0.00578
# Iteration:  95
# 	Epsilon:  1.2798762797994938
# 	Fake AP 2: 0.00560
# Iteration:  96
# 	Epsilon:  1.2766934758964048
# 	Fake AP 2: 0.00542
# Iteration:  97
# 	Epsilon:  1.2731608602331352
# 	Fake AP 2: 0.00573
# Iteration:  98
# 	Epsilon:  1.2701442964489964
# 	Fake AP 2: 0.00491
# Iteration:  99
# 	Epsilon:  1.2672475626864323
# 	Fake AP 2: 0.00415
# Iteration:  100
# 	Epsilon:  1.2649834422482782
# 	Fake AP 2: 0.00434

# %%
def plot_histogram_rwm(n):
    fig, ax = plt.subplots(figsize=(20, 4))
    bins        = np.arange(-0.5, SETTINGS50_rwm['B']+0.5, step=1.0)
    bins_labels = np.arange(SETTINGS50_rwm['B'])
    _ = ax.hist(MSRWM.K_RESAMPLED[n, :], density=True, bins=bins, edgecolor='k', color='lightsalmon')
    ax.set_xticks(bins_labels)
    ax.set_xticklabels(bins_labels)
    plt.show()

resetwarnings()
interact(plot_histogram_rwm, n=(0, len(MSRWM.ϵs) - 2))
# Out:
# interactive(children=(IntSlider(value=49, description='n', max=99), Output()), _dom_classes=('widget-interact'…
# <function __main__.plot_histogram_rwm(n)>

# %%
fig, ax = plt.subplots()
ax.plot(np.array(MSTHUG.ESS) / (MSTHUG.N*(MSTHUG.B+1)), label='MS-THUG')
ax.plot(np.array(MSRWM.ESS) / (MSRWM.N*(MSRWM.B+1)), label='MS-RWM')
ax.legend()
ax.set_title("ESS / number of particles ")
plt.show()

# %% [markdown]
# ### SMC-RWM

# %%
class SMCAdaptiveEpsilon:
    
    def __init__(self, SETTINGS, force_rwm=False):
            def __init__(self, SETTINGS, force_rwm=True, adaptiveB=False, ρ=None, Bprop=0.1, Bmin=10, Bmax=60, δmin=1e-4):

        """Metropolised version. A simple SMC sampler that can choose between RWM or THUG mutation kernel.
        It adaptively chooses the sequence of ϵ based on quantile of the distances.
        
        Parameters
        ----------
        
        :param N: Number of particles
        :type N:  int
        
        :param B: Number of bounces for the THUG integrator. Equivalent to `L` Leapfrog steps in HMC.
        :type B: int
        
        :param δ: Step-size used at each bounce, for the THUG integrator.
        :type δ: float
        
        :param d: Dimensionality of the `x` component of each particle, and equally dimensionality of 
                  `v` component of each particle. Therefore each particle has dimension `2d`.
        
        :param ϵs: Tolerances that fully specify the sequence of target filamentary distributions.
        :type ϵs: iterable
        """
        # Input variables
        self.N  = SETTINGS['N']       
        self.δ  = SETTINGS['δ']
        self.d  = SETTINGS['d']
        self.manifold = SETTINGS['manifold']
        self.SETTINGS = SETTINGS
        self.B = SETTINGS['B']
        
        # choose function to compute distances with
        if self.manifold.kernel_type == 'uniform':
            # distance function is linear in ||f(x) - y||
            self.compute_distances = lambda XNK: norm(np.apply_along_axis(self.manifold.q, 1, XNK), axis=1)
        elif self.manifold.kernel_type == 'normal':
            # distance function is quadratic in ||f(x) - y||
            self.compute_distances = lambda XNK: norm(np.apply_along_axis(self.manifold.q, 1, XNK), axis=1)**2
        else:
            raise ValueError("Manifold has an unexpected kernel type.")
        
        # Variables derived from the above
        if not force_rwm:
            self.ψ = generate_THUGIntegratorMultivariate(self.B, self.δ)
            self.ψ_generator = generate_THUGIntegratorMultivariate
        else:
            self.ψ = generate_RWMIntegrator(self.B, self.δ)
            self.ψ_generator = generate_RWMIntegrator
        
        # Variables derived from the above
        self.P  = len(self.ϵs) - 1                                       # Number of target distributions
        self.log_ηs = [self.manifold.generate_logηϵ(ϵ) for ϵ in self.ϵs]     # List of filamentary distributions 
        
    
    def initialize_particles(self):
        """Initialize by sampling with RWM on distribution with ϵ0."""
        # Initialize first position on the manifold
        x0 = self.SETTINGS['ξ0']
        # Sample using RWM
        burn_in = 100
        thinning = 10
        ### try initializing using Tangential Hug as MCMC kernel?
        #TO_BE_THINNED, acceptance = RWM(x0, self.δ, burn_in + thinning*self.N, self.log_ηs[0])
        q = MVN(zeros(self.d), eye(self.d))
        TO_BE_THINNED, acceptance = HugTangentialMultivariate(x0, self.B*self.δ, self.B, burn_in + thinning*self.N, 0.0, q, self.log_ηs[0], self.manifold.fullJacobian, method='linear')
        print("Initializing particles. Acceptance: ", np.mean(acceptance)*100)
        # Thin the samples to obtain the particles
        initialized_particles = TO_BE_THINNED[burn_in:][::thinning]
        # Refresh velocities and form particles
        v0 = np.random.normal(loc=0.0, scale=1.0, size=(self.N, self.d))
        z0 = np.hstack((initialized_particles, v0))
        self.starting_particles = z0
        return z0
        
    def sample(self):
        """Starts the Markov Snippets sampler."""
        starting_time = time.time()
        # Initialize particles
        z = self.initialize_particles()   # (N, 2d)
        # Storage
        self.PARTICLES    = zeros((self.P+1, self.N, 2*self.d))
        self.PARTICLES[0] = z
        self.WEIGHTS      = zeros((self.P+1, self.N))
        self.WEIGHTS[0]   = 1 / self.N
        self.ESS          = zeros(self.P+1)
        self.ESS[0]       = 1 / np.sum(self.WEIGHTS[0]**2)
        # For each target distribution, run the following loop
        for n in range(1, self.P+1):
            # Standard SMC sampler, we mutate the particles and then we resample
            ### Mutation step: 
            ###### Refresh velocities
            z[:, self.d:] = np.random.normal(loc=0.0, scale=1.0, size=(self.N, self.d))
            ###### Mutate positions 
            M = lambda z: THUG_MH(z, self.B, self.δ, self.log_ηs[n-1])
            Z = np.apply_along_axis(M, 1, z)
            ### Compute weights
            # Notice in this case the weight is different because we are not using the uniform kernel anymore
            # Importantly: this is now the INCREMENTAL weight and so has to be multiplied by the previous one.
            w_incremental = exp(np.apply_along_axis(self.log_ηs[n], 1, Z[:, :self.d]) - np.apply_along_axis(self.log_ηs[n-1], 1, Z[:, :self.d]))
#             w = (abs(np.apply_along_axis(f, 1, Z[:, :p]) - level_set_value) <= self.ϵs[n]).astype(float)
            w = w_incremental # since we resample, no need to multiply #self.WEIGHTS[n-1] * w_incremental
            w = w / w.sum()
            self.WEIGHTS[n] = w
            self.ESS[n]     = 1 / np.sum(w**2)
            ### Resample
            indeces = choice(a=np.arange(self.N), size=self.N, p=w)
            z = z[indeces, :]
            self.PARTICLES[n] = z
        self.total_time = time.time() - starting_time
        return z

# %% [markdown]
# ### MS-THUG with adaptive B

# %%
SETTINGS50_adaptiveB = generate_setting(
    m=50, ϵ0=10, B=20, δ=0.01, N=5000, quantile_value=0.01, 
    ϵ_min=0.00001, maxiter=100, δ0=0.005, thinning=10, kernel_type='uniform')

# %%
MSTHUG_ADAPTIVEB = MultivariateMarkovSnippetsTHUG(SETTINGS50_adaptiveB, adaptiveB=True, ρ=0.05, Bmult=1.1)

# %%
zP_adaptiveB = MSTHUG_ADAPTIVEB.sample(manual_initialization=False)
# Out:
# Initializing particles. Acceptance:  15.582834331337326
# Iteration:  1
# 	Epsilon:  9.036854384873067
# 	Indices distribution is left-skewed. B:  16  δ: 0.008000
# Iteration:  2
# 	Epsilon:  7.927954217219865
# 	Indices distribution is left-skewed. B:  15  δ: 0.007500
# Iteration:  3
# 	Epsilon:  7.047928492987681
# 	Indices distribution is right-skewed. B:  15  δ: 0.007500
# Iteration:  4
# 	Epsilon:  6.297377700955622
# 	Indices distribution is left-skewed. B:  15  δ: 0.007500
# Iteration:  5
# 	Epsilon:  5.569106394259943
# 	Indices distribution is left-skewed. B:  14  δ: 0.007000
# Iteration:  6
# 	Epsilon:  5.001188969210141
# 	Indices distribution is left-skewed. B:  13  δ: 0.006500
# Iteration:  7
# 	Epsilon:  4.614499197179461
# 	Indices distribution is left-skewed. B:  12  δ: 0.006000
# Iteration:  8
# 	Epsilon:  4.287119473295334
# 	Indices distribution is left-skewed. B:  11  δ: 0.005500
# Iteration:  9
# 	Epsilon:  4.079679932231742
# 	Indices distribution is right-skewed. B:  11  δ: 0.005500
# Iteration:  10
# 	Epsilon:  3.870827925842886
# 	Inidices distribution is approximately flat. B:  13  δ: 0.006050
# Iteration:  11
# 	Epsilon:  3.700085554165105
# 	Indices distribution is left-skewed. B:  11  δ: 0.005119
# Iteration:  12
# 	Epsilon:  3.488570436532618
# 	Indices distribution is left-skewed. B:  11  δ: 0.005119
# Iteration:  13
# 	Epsilon:  3.284966478625448
# 	Indices distribution is left-skewed. B:  10  δ: 0.000100
# Iteration:  14
# 	Epsilon:  3.1431967777298433
# 	Inidices distribution is approximately flat. B:  11  δ: 0.000110
# Iteration:  15
# 	Epsilon:  3.0938792865414144
# 	Indices distribution is right-skewed. B:  11  δ: 0.000440
# Iteration:  16
# 	Epsilon:  3.0760973109584744
# 	Indices distribution is right-skewed. B:  11  δ: 0.003080
# Iteration:  17
# 	Epsilon:  3.0315616895276154
# 	Indices distribution is right-skewed. B:  11  δ: 0.012320
# Iteration:  18
# 	Epsilon:  2.973353922887005
# 	Indices distribution is left-skewed. B:  10  δ: 0.000100
# Iteration:  19
# 	Epsilon:  2.8708675416270735
# 	Inidices distribution is approximately flat. B:  11  δ: 0.000110
# Iteration:  20
# 	Epsilon:  2.7782902183971934
# 	Indices distribution is right-skewed. B:  11  δ: 0.000440
# Iteration:  21
# 	Epsilon:  2.7523843644349326
# 	Indices distribution is right-skewed. B:  11  δ: 0.002640
# Iteration:  22
# 	Epsilon:  2.715698163489491
# 	Indices distribution is right-skewed. B:  11  δ: 0.010560
# Iteration:  23
# 	Epsilon:  2.6722189445362137
# 	Indices distribution is left-skewed. B:  10  δ: 0.000100
# Iteration:  24
# 	Epsilon:  2.584814013582933
# 	Inidices distribution is approximately flat. B:  11  δ: 0.000110
# Iteration:  25
# 	Epsilon:  2.5393881051650182
# 	Indices distribution is right-skewed. B:  11  δ: 0.000110
# Iteration:  26
# 	Epsilon:  2.523329132157537
# 	Indices distribution is right-skewed. B:  11  δ: 0.000660
# Iteration:  27
# 	Epsilon:  2.4869862273216623
# 	Indices distribution is right-skewed. B:  11  δ: 0.003960
# Iteration:  28
# 	Epsilon:  2.452754645102465
# 	Inidices distribution is approximately flat. B:  13  δ: 0.004356
# Iteration:  29
# 	Epsilon:  2.405178848315356
# 	Indices distribution is left-skewed. B:  10  δ: 0.000100
# Iteration:  30
# 	Epsilon:  2.343615548923309
# 	Inidices distribution is approximately flat. B:  11  δ: 0.000110
# Iteration:  31
# 	Epsilon:  2.313579728623407
# 	Indices distribution is right-skewed. B:  11  δ: 0.000660
# Iteration:  32
# 	Epsilon:  2.303149658082128
# 	Indices distribution is right-skewed. B:  11  δ: 0.003300
# Iteration:  33
# 	Epsilon:  2.2911597179626844
# 	Indices distribution is left-skewed. B:  10  δ: 0.000100
# Iteration:  34
# 	Epsilon:  2.2488929442697954
# 	Inidices distribution is approximately flat. B:  11  δ: 0.000110
# Iteration:  35
# 	Epsilon:  2.2224664163854584
# 	Indices distribution is right-skewed. B:  11  δ: 0.000220
# Iteration:  36
# 	Epsilon:  2.215736570909762
# 	Indices distribution is right-skewed. B:  11  δ: 0.001320
# Iteration:  37
# 	Epsilon:  2.206630207711247
# 	Indices distribution is right-skewed. B:  11  δ: 0.003960
# Iteration:  38
# 	Epsilon:  2.192500276780515
# 	Indices distribution is left-skewed. B:  10  δ: 0.000100
# Iteration:  39
# 	Epsilon:  2.170649912408411
# 	Inidices distribution is approximately flat. B:  11  δ: 0.000110
# Iteration:  40
# 	Epsilon:  2.159826986495888
# 	Indices distribution is right-skewed. B:  11  δ: 0.000440
# Iteration:  41
# 	Epsilon:  2.149522056235985
# 	Indices distribution is right-skewed. B:  11  δ: 0.002640
# Iteration:  42
# 	Epsilon:  2.1409240045286513
# 	Indices distribution is left-skewed. B:  10  δ: 0.000100
# Iteration:  43
# 	Epsilon:  2.113830479838421
# 	Inidices distribution is approximately flat. B:  11  δ: 0.000110
# Iteration:  44
# 	Epsilon:  2.1047325781413404
# 	Indices distribution is right-skewed. B:  11  δ: 0.000110
# Iteration:  45
# 	Epsilon:  2.102204572731107
# 	Indices distribution is right-skewed. B:  11  δ: 0.000110
# Iteration:  46
# 	Epsilon:  2.1001722377983882
# 	Indices distribution is right-skewed. B:  11  δ: 0.000550
# Iteration:  47
# 	Epsilon:  2.096059558296773
# 	Indices distribution is right-skewed. B:  11  δ: 0.002200
# Iteration:  48
# 	Epsilon:  2.090256165936662
# 	Indices distribution is left-skewed. B:  10  δ: 0.000100
# Iteration:  49
# 	Epsilon:  2.073193165110004
# 	Inidices distribution is approximately flat. B:  11  δ: 0.000110
# Iteration:  50
# 	Epsilon:  2.0674804308680046
# 	Indices distribution is right-skewed. B:  11  δ: 0.000330
# Iteration:  51
# 	Epsilon:  2.050977920228409
# 	Indices distribution is right-skewed. B:  11  δ: 0.001650
# Iteration:  52
# 	Epsilon:  2.0431039415471557
# 	Inidices distribution is approximately flat. B:  13  δ: 0.001815
# Iteration:  53
# 	Epsilon:  2.0324323123711805
# 	Indices distribution is left-skewed. B:  10  δ: 0.000100
# Iteration:  54
# 	Epsilon:  2.0174517069675715
# 	Inidices distribution is approximately flat. B:  11  δ: 0.000110
# Iteration:  55
# 	Epsilon:  2.0108491105515345
# 	Indices distribution is right-skewed. B:  11  δ: 0.000440
# Iteration:  56
# 	Epsilon:  2.0067614033506658
# 	Indices distribution is right-skewed. B:  11  δ: 0.002200
# Iteration:  57
# 	Epsilon:  2.001030770203199
# 	Indices distribution is left-skewed. B:  10  δ: 0.000100
# Iteration:  58
# 	Epsilon:  1.9814265523460073
# 	Inidices distribution is approximately flat. B:  11  δ: 0.000110
# Iteration:  59
# 	Epsilon:  1.9692445577427535
# 	Indices distribution is right-skewed. B:  11  δ: 0.000110
# Iteration:  60
# 	Epsilon:  1.9666953107054694
# 	Indices distribution is right-skewed. B:  11  δ: 0.000550
# Iteration:  61
# 	Epsilon:  1.9609375396307445
# 	Indices distribution is right-skewed. B:  11  δ: 0.002750
# Iteration:  62
# 	Epsilon:  1.9529970539818462
# 	Indices distribution is left-skewed. B:  10  δ: 0.000100
# Iteration:  63
# 	Epsilon:  1.9240007379792647
# 	Inidices distribution is approximately flat. B:  11  δ: 0.000110
# Iteration:  64
# 	Epsilon:  1.9087819556424612
# 	Indices distribution is right-skewed. B:  11  δ: 0.000220
# Iteration:  65
# 	Epsilon:  1.9045680520359618
# 	Indices distribution is right-skewed. B:  11  δ: 0.001320
# Iteration:  66
# 	Epsilon:  1.897307713812258
# 	Indices distribution is right-skewed. B:  11  δ: 0.002640
# Iteration:  67
# 	Epsilon:  1.8824016517352622
# 	Indices distribution is left-skewed. B:  10  δ: 0.000100
# Iteration:  68
# 	Epsilon:  1.865023674507389
# 	Indices distribution is right-skewed. B:  10  δ: 0.000100
# Iteration:  69
# 	Epsilon:  1.856990004239548
# 	Indices distribution is right-skewed. B:  10  δ: 0.000200
# Iteration:  70
# 	Epsilon:  1.8481429678698167
# 	Indices distribution is right-skewed. B:  10  δ: 0.001000
# Iteration:  71
# 	Epsilon:  1.8400861512472284
# 	Indices distribution is right-skewed. B:  10  δ: 0.003000
# Iteration:  72
# 	Epsilon:  1.8304421170306595
# 	Indices distribution is left-skewed. B:  10  δ: 0.000100
# Iteration:  73
# 	Epsilon:  1.807778915136462
# 	Inidices distribution is approximately flat. B:  11  δ: 0.000110
# Iteration:  74
# 	Epsilon:  1.7998385099941931
# 	Indices distribution is right-skewed. B:  11  δ: 0.000550
# Iteration:  75
# 	Epsilon:  1.7938032200517273
# 	Indices distribution is right-skewed. B:  11  δ: 0.002200
# Iteration:  76
# 	Epsilon:  1.787450859121189
# 	Indices distribution is left-skewed. B:  10  δ: 0.000100
# Iteration:  77
# 	Epsilon:  1.7648432898036275
# 	Inidices distribution is approximately flat. B:  11  δ: 0.000110
# Iteration:  78
# 	Epsilon:  1.7514616140656432
# 	Indices distribution is right-skewed. B:  11  δ: 0.000440
# Iteration:  79
# 	Epsilon:  1.7474559556944682
# 	Indices distribution is right-skewed. B:  11  δ: 0.001760
# Iteration:  80
# 	Epsilon:  1.743239811768906
# 	Indices distribution is left-skewed. B:  10  δ: 0.000100
# Iteration:  81
# 	Epsilon:  1.734956913624482
# 	Indices distribution is left-skewed. B:  10  δ: 0.000100
# Iteration:  82
# 	Epsilon:  1.730280710571703
# 	Indices distribution is right-skewed. B:  10  δ: 0.000100
# Iteration:  83
# 	Epsilon:  1.727185046353072
# 	Indices distribution is right-skewed. B:  10  δ: 0.000200
# Iteration:  84
# 	Epsilon:  1.7236872560310683
# 	Indices distribution is right-skewed. B:  10  δ: 0.000800
# Iteration:  85
# 	Epsilon:  1.7204864704984495
# 	Indices distribution is right-skewed. B:  10  δ: 0.002400
# Iteration:  86
# 	Epsilon:  1.715585538201044
# 	Indices distribution is left-skewed. B:  10  δ: 0.000100
# Iteration:  87
# 	Epsilon:  1.7061137813242062
# 	Inidices distribution is approximately flat. B:  11  δ: 0.000110
# Iteration:  88
# 	Epsilon:  1.701068876840683
# 	Indices distribution is right-skewed. B:  11  δ: 0.000440
# Iteration:  89
# 	Epsilon:  1.6980388083573763
# 	Indices distribution is right-skewed. B:  11  δ: 0.001760
# Iteration:  90
# 	Epsilon:  1.6945907013293873
# 	Indices distribution is left-skewed. B:  10  δ: 0.000100
# Iteration:  91
# 	Epsilon:  1.6826133084116244
# 	Inidices distribution is approximately flat. B:  11  δ: 0.000110
# Iteration:  92
# 	Epsilon:  1.679925986700498
# 	Indices distribution is right-skewed. B:  11  δ: 0.000440
# Iteration:  93
# 	Epsilon:  1.6781321286570776
# 	Indices distribution is right-skewed. B:  11  δ: 0.001320
# Iteration:  94
# 	Epsilon:  1.6753982876759599
# 	Indices distribution is left-skewed. B:  10  δ: 0.000100
# Iteration:  95
# 	Epsilon:  1.667490477247752
# 	Inidices distribution is approximately flat. B:  11  δ: 0.000110
# Iteration:  96
# 	Epsilon:  1.6643005151681591
# 	Indices distribution is right-skewed. B:  11  δ: 0.000440
# Iteration:  97
# 	Epsilon:  1.6611729750798034
# 	Indices distribution is right-skewed. B:  11  δ: 0.001320
# Iteration:  98
# 	Epsilon:  1.6586767588369329
# 	Indices distribution is left-skewed. B:  10  δ: 0.000100
# Iteration:  99
# 	Epsilon:  1.6528100081188424
# 	Inidices distribution is approximately flat. B:  11  δ: 0.000110
# Iteration:  100
# 	Epsilon:  1.646244671055988
# 	Indices distribution is right-skewed. B:  11  δ: 0.000440

# %%
def plot_histogram_adaptiveB(n):
    fig, ax = plt.subplots(figsize=(20, 4))
    bins        = np.arange(-0.5, MSTHUG_ADAPTIVEB.Bmax+0.5, step=1.0)
    bins_labels = np.arange(MSTHUG_ADAPTIVEB.Bmax)
    _ = ax.hist(MSTHUG_ADAPTIVEB.K_RESAMPLED[n, :], density=True, bins=bins, edgecolor='k', color='lightsalmon')
    ax.set_xticks(bins_labels)
    ax.set_xticklabels(bins_labels)
    plt.show()

resetwarnings()
interact(plot_histogram_adaptiveB, n=(0, len(MSTHUG_ADAPTIVEB.ϵs) - 2))
# Out:
# interactive(children=(IntSlider(value=49, description='n', max=99), Output()), _dom_classes=('widget-interact'…
# <function __main__.plot_histogram_adaptiveB(n)>

# %%
fig, ax = plt.subplots()
ax.plot(np.array(MSTHUG_ADAPTIVEB.ESS) / MSTHUG_ADAPTIVEB.N * (np.array(MSTHUG_ADAPTIVEB.Bs) + 1), label='MS')
ax.legend()
ax.set_title("ESS / number of particles ")
plt.show()

# %%
fig, ax = plt.subplots(ncols=2, figsize=(8, 4))
# Bs
ax[0].plot(MSTHUG_ADAPTIVEB.Bs, label='Bs')
ax[0].legend()
ax[0].set_title("Bs")

# δs
ax[1].plot(MSTHUG_ADAPTIVEB.δs, label='δs')
ax[1].legend()
ax[1].set_title("δs")

plt.show()

# %% [markdown]
# ### Change only $B$ based on histogram

# %%
SETTINGS50_adaptiveB2 = generate_setting(
    m=50, ϵ0=10, B=20, δ=0.01, N=5000, quantile_value=0.01, 
    ϵ_min=0.00001, maxiter=100, δ0=0.003, thinning=10, kernel_type='uniform')

# %%
MSTHUG_ADAPTIVEB2 = MultivariateMarkovSnippetsTHUG(
    SETTINGS50_adaptiveB2, 
    adaptiveB=True, 
    ρ=0.3, 
    Bprop=0.1, 
    Bmin=5)

# %%
zP_adaptiveB2 = MSTHUG_ADAPTIVEB2.sample(manual_initialization=False)
# Out:
# Initializing particles. Acceptance:  29.91816367265469
# Iteration:  1
# 	Epsilon:  9.087188783718288
# 	Setting δ: 0.01000
# 	Fake AP 2: 0.04409
# Iteration:  2
# 	Epsilon:  8.007700284661905
# 	Setting δ: 0.01000
# 	Fake AP 2: 0.04484
# Iteration:  3
# 	Epsilon:  7.145827686701823
# 	Setting δ: 0.01000
# 	Fake AP 2: 0.04433
# Iteration:  4
# 	Epsilon:  5.928356473039128
# 	Setting δ: 0.01000
# 	Fake AP 2: 0.04670
# Iteration:  5
# 	Epsilon:  4.5364885687458605
# 	Setting δ: 0.01000
# 	Fake AP 2: 0.04513
# Iteration:  6
# 	Epsilon:  3.9452815814096245
# 	Setting δ: 0.00850
# 	Fake AP 2: 0.04354
# Iteration:  7
# 	Epsilon:  3.606631769657402
# 	Setting δ: 0.00808
# 	Fake AP 2: 0.04359
# Iteration:  8
# 	Epsilon:  3.41866476676093
# 	Setting δ: 0.00808
# 	Fake AP 2: 0.04054
# Iteration:  9
# 	Epsilon:  3.248985452716742
# 	Setting δ: 0.00606
# 	Fake AP 2: 0.03760
# Iteration:  10
# 	Epsilon:  3.107112120629359
# 	Setting δ: 0.00606
# 	Fake AP 2: 0.04146
# Iteration:  11
# 	Epsilon:  2.9553376348180924
# 	Setting δ: 0.00575
# 	Fake AP 2: 0.03712
# Iteration:  12
# 	Epsilon:  2.862396819230767
# 	Setting δ: 0.00547
# 	Fake AP 2: 0.04009
# Iteration:  13
# 	Epsilon:  2.752344744240667
# 	Setting δ: 0.00547
# 	Fake AP 2: 0.03889
# Iteration:  14
# 	Epsilon:  2.658576045768515
# 	Setting δ: 0.00410
# 	Fake AP 2: 0.03988
# Iteration:  15
# 	Epsilon:  2.5706955571955867
# 	Setting δ: 0.00410
# 	Fake AP 2: 0.04367
# Iteration:  16
# 	Epsilon:  2.4678352375539965
# 	Setting δ: 0.00328
# 	Fake AP 2: 0.03951
# Iteration:  17
# 	Epsilon:  2.389220071943789
# 	Setting δ: 0.00328
# 	Fake AP 2: 0.04270
# Iteration:  18
# 	Epsilon:  2.312992525260868
# 	Setting δ: 0.00328
# 	Fake AP 2: 0.04166
# Iteration:  19
# 	Epsilon:  2.2435444121723966
# 	Setting δ: 0.00328
# 	Fake AP 2: 0.04185
# Iteration:  20
# 	Epsilon:  2.185889505915654
# 	Setting δ: 0.00328
# 	Fake AP 2: 0.04246
# Iteration:  21
# 	Epsilon:  2.131715133756565
# 	Setting δ: 0.00328
# 	Fake AP 2: 0.04196
# Iteration:  22
# 	Epsilon:  2.062420823325342
# 	Setting δ: 0.00328
# 	Fake AP 2: 0.04319
# Iteration:  23
# 	Epsilon:  1.9753760092016275
# 	Setting δ: 0.00328
# 	Fake AP 2: 0.04083
# Iteration:  24
# 	Epsilon:  1.90334802242074
# 	Setting δ: 0.00328
# 	Fake AP 2: 0.04255
# Iteration:  25
# 	Epsilon:  1.8372284093725753
# 	Setting δ: 0.00328
# 	Fake AP 2: 0.03879
# Iteration:  26
# 	Epsilon:  1.7606883394574215
# 	Setting δ: 0.00312
# 	Fake AP 2: 0.04007
# Iteration:  27
# 	Epsilon:  1.7072299601697882
# 	Setting δ: 0.00265
# 	Fake AP 2: 0.04213
# Iteration:  28
# 	Epsilon:  1.6631204179383547
# 	Setting δ: 0.00265
# 	Fake AP 2: 0.04267
# Iteration:  29
# 	Epsilon:  1.6163333257935721
# 	Setting δ: 0.00252
# 	Fake AP 2: 0.04314
# Iteration:  30
# 	Epsilon:  1.5682453749397858
# 	Setting δ: 0.00252
# 	Fake AP 2: 0.04244
# Iteration:  31
# 	Epsilon:  1.504104243290707
# 	Setting δ: 0.00252
# 	Fake AP 2: 0.04244
# Iteration:  32
# 	Epsilon:  1.4342189490076422
# 	Setting δ: 0.00252
# 	Fake AP 2: 0.04135
# Iteration:  33
# 	Epsilon:  1.387486995969693
# 	Setting δ: 0.00252
# 	Fake AP 2: 0.04264
# Iteration:  34
# 	Epsilon:  1.3516540921701792
# 	Setting δ: 0.00164
# 	Fake AP 2: 0.04048
# Iteration:  35
# 	Epsilon:  1.3121497440370498
# 	Setting δ: 0.00164
# 	Fake AP 2: 0.04160
# Iteration:  36
# 	Epsilon:  1.2898885230656674
# 	Setting δ: 0.00164
# 	Fake AP 2: 0.04376
# Iteration:  37
# 	Epsilon:  1.267264211353678
# 	Setting δ: 0.00164
# 	Fake AP 2: 0.04285
# Iteration:  38
# 	Epsilon:  1.2340423724061091
# 	Setting δ: 0.00164
# 	Fake AP 2: 0.04306
# Iteration:  39
# 	Epsilon:  1.2028932298371284
# 	Setting δ: 0.00164
# 	Fake AP 2: 0.04151
# Iteration:  40
# 	Epsilon:  1.1810330275195238
# 	Setting δ: 0.00131
# 	Fake AP 2: 0.04221
# Iteration:  41
# 	Epsilon:  1.1558723769018
# 	Setting δ: 0.00131
# 	Fake AP 2: 0.04442
# Iteration:  42
# 	Epsilon:  1.1223913162113643
# 	Setting δ: 0.00131
# 	Fake AP 2: 0.04406
# Iteration:  43
# 	Epsilon:  1.097258852011329
# 	Setting δ: 0.00131
# 	Fake AP 2: 0.04264
# Iteration:  44
# 	Epsilon:  1.07845154610971
# 	Setting δ: 0.00131
# 	Fake AP 2: 0.04110
# Iteration:  45
# 	Epsilon:  1.059431412874256
# 	Setting δ: 0.00131
# 	Fake AP 2: 0.04181
# Iteration:  46
# 	Epsilon:  1.041043982994331
# 	Setting δ: 0.00131
# 	Fake AP 2: 0.04289
# Iteration:  47
# 	Epsilon:  1.025874931571557
# 	Setting δ: 0.00124
# 	Fake AP 2: 0.04034
# Iteration:  48
# 	Epsilon:  1.009060749425334
# 	Setting δ: 0.00106
# 	Fake AP 2: 0.04119
# Iteration:  49
# 	Epsilon:  0.9948772982208829
# 	Setting δ: 0.00106
# 	Fake AP 2: 0.04557
# Iteration:  50
# 	Epsilon:  0.980030915969017
# 	Setting δ: 0.00106
# 	Fake AP 2: 0.04394
# Iteration:  51
# 	Epsilon:  0.9668515076997688
# 	Setting δ: 0.00106
# 	Fake AP 2: 0.04580
# Iteration:  52
# 	Epsilon:  0.9520918684349485
# 	Setting δ: 0.00106
# 	Fake AP 2: 0.04056
# Iteration:  53
# 	Epsilon:  0.9398808721837507
# 	Setting δ: 0.00106
# 	Fake AP 2: 0.04303
# Iteration:  54
# 	Epsilon:  0.9278714072477318
# 	Setting δ: 0.00106
# 	Fake AP 2: 0.03929
# Iteration:  55
# 	Epsilon:  0.9176076225239035
# 	Setting δ: 0.00106
# 	Fake AP 2: 0.03929
# Iteration:  56
# 	Epsilon:  0.8929494800337733
# 	Setting δ: 0.00106
# 	Fake AP 2: 0.04185
# Iteration:  57
# 	Epsilon:  0.8795962635468977
# 	Setting δ: 0.00079
# 	Fake AP 2: 0.03952
# Iteration:  58
# 	Epsilon:  0.870795118602699
# 	Setting δ: 0.00075
# 	Fake AP 2: 0.04205
# Iteration:  59
# 	Epsilon:  0.8613298699802835
# 	Setting δ: 0.00075
# 	Fake AP 2: 0.04337
# Iteration:  60
# 	Epsilon:  0.854745108129338
# 	Setting δ: 0.00075
# 	Fake AP 2: 0.04375
# Iteration:  61
# 	Epsilon:  0.848298196032665
# 	Setting δ: 0.00064
# 	Fake AP 2: 0.04017
# Iteration:  62
# 	Epsilon:  0.8408270567248121
# 	Setting δ: 0.00064
# 	Fake AP 2: 0.04457
# Iteration:  63
# 	Epsilon:  0.8318930151294521
# 	Setting δ: 0.00064
# 	Fake AP 2: 0.04433
# Iteration:  64
# 	Epsilon:  0.8239324617433531
# 	Setting δ: 0.00064
# 	Fake AP 2: 0.04327
# Iteration:  65
# 	Epsilon:  0.8152539279979087
# 	Setting δ: 0.00064
# 	Fake AP 2: 0.04194
# Iteration:  66
# 	Epsilon:  0.8082960840539554
# 	Setting δ: 0.00061
# 	Fake AP 2: 0.04262
# Iteration:  67
# 	Epsilon:  0.8014340431267577
# 	Setting δ: 0.00061
# 	Fake AP 2: 0.04490
# Iteration:  68
# 	Epsilon:  0.7923693679603954
# 	Setting δ: 0.00055
# 	Fake AP 2: 0.04330
# Iteration:  69
# 	Epsilon:  0.7833701395747683
# 	Setting δ: 0.00055
# 	Fake AP 2: 0.04698
# Iteration:  70
# 	Epsilon:  0.7765362145969673
# 	Setting δ: 0.00055
# 	Fake AP 2: 0.04329
# Iteration:  71
# 	Epsilon:  0.7695814499556626
# 	Setting δ: 0.00055
# 	Fake AP 2: 0.04203
# Iteration:  72
# 	Epsilon:  0.7622824394553216
# 	Setting δ: 0.00055
# 	Fake AP 2: 0.04307
# Iteration:  73
# 	Epsilon:  0.7567149305784067
# 	Setting δ: 0.00055
# 	Fake AP 2: 0.04311
# Iteration:  74
# 	Epsilon:  0.7525335044269585
# 	Setting δ: 0.00055
# 	Fake AP 2: 0.04187
# Iteration:  75
# 	Epsilon:  0.7485433049218834
# 	Setting δ: 0.00055
# 	Fake AP 2: 0.04155
# Iteration:  76
# 	Epsilon:  0.7442737583192525
# 	Setting δ: 0.00055
# 	Fake AP 2: 0.04181
# Iteration:  77
# 	Epsilon:  0.7396700599155988
# 	Setting δ: 0.00055
# 	Fake AP 2: 0.03939
# Iteration:  78
# 	Epsilon:  0.7352030666639235
# 	Setting δ: 0.00055
# 	Fake AP 2: 0.04476
# Iteration:  79
# 	Epsilon:  0.7301752917376861
# 	Setting δ: 0.00055
# 	Fake AP 2: 0.04134
# Iteration:  80
# 	Epsilon:  0.7255845812677064
# 	Setting δ: 0.00055
# 	Fake AP 2: 0.04267
# Iteration:  81
# 	Epsilon:  0.7213685334897082
# 	Setting δ: 0.00055
# 	Fake AP 2: 0.04149
# Iteration:  82
# 	Epsilon:  0.7182637748530136
# 	Setting δ: 0.00055
# 	Fake AP 2: 0.03978
# Iteration:  83
# 	Epsilon:  0.7145895598585609
# 	Setting δ: 0.00055
# 	Fake AP 2: 0.04147
# Iteration:  84
# 	Epsilon:  0.7104230245012615
# 	Setting δ: 0.00055
# 	Fake AP 2: 0.04099
# Iteration:  85
# 	Epsilon:  0.7051805159501523
# 	Setting δ: 0.00055
# 	Fake AP 2: 0.03989
# Iteration:  86
# 	Epsilon:  0.7006458494943765
# 	Setting δ: 0.00055
# 	Fake AP 2: 0.03708
# Iteration:  87
# 	Epsilon:  0.6969653838978883
# 	Setting δ: 0.00055
# 	Fake AP 2: 0.04316
# Iteration:  88
# 	Epsilon:  0.6900336518093007
# 	Setting δ: 0.00055
# 	Fake AP 2: 0.03894
# Iteration:  89
# 	Epsilon:  0.6865971350112963
# 	Setting δ: 0.00049
# 	Fake AP 2: 0.03852
# Iteration:  90
# 	Epsilon:  0.6817054923076254
# 	Setting δ: 0.00049
# 	Fake AP 2: 0.03965
# Iteration:  91
# 	Epsilon:  0.6779457274545899
# 	Setting δ: 0.00049
# 	Fake AP 2: 0.04073
# Iteration:  92
# 	Epsilon:  0.6750658540076685
# 	Setting δ: 0.00049
# 	Fake AP 2: 0.04038
# Iteration:  93
# 	Epsilon:  0.6718385248942792
# 	Setting δ: 0.00049
# 	Fake AP 2: 0.03940
# Iteration:  94
# 	Epsilon:  0.6694648389199052
# 	Setting δ: 0.00047
# 	Fake AP 2: 0.04057
# Iteration:  95
# 	Epsilon:  0.6659809458944076
# 	Setting δ: 0.00047
# 	Fake AP 2: 0.04207
# Iteration:  96
# 	Epsilon:  0.6627888726607606
# 	Setting δ: 0.00047
# 	Fake AP 2: 0.03877
# Iteration:  97
# 	Epsilon:  0.6593856560947281
# 	Setting δ: 0.00047
# 	Fake AP 2: 0.04415
# Iteration:  98
# 	Epsilon:  0.6561503695963149
# 	Setting δ: 0.00047
# 	Fake AP 2: 0.03912
# Iteration:  99
# 	Epsilon:  0.6497848480501545
# 	Setting δ: 0.00035
# 	Fake AP 2: 0.03682
# Iteration:  100
# 	Epsilon:  0.6464893416372057
# 	Setting δ: 0.00035
# 	Fake AP 2: 0.04613

# %%
def plot_histogram_adaptiveB2(n):
    fig, ax = plt.subplots(figsize=(20, 4))
    bins        = np.arange(-0.5, MSTHUG_ADAPTIVEB2.Bmax+0.5, step=1.0)
    bins_labels = np.arange(MSTHUG_ADAPTIVEB2.Bmax)
    _ = ax.hist(MSTHUG_ADAPTIVEB2.K_RESAMPLED[n, :], density=True, bins=bins, edgecolor='k', color='lightsalmon')
    ax.set_xticks(bins_labels)
    ax.set_xticklabels(bins_labels)
    plt.show()

resetwarnings()
interact(plot_histogram_adaptiveB2, n=(0, len(MSTHUG_ADAPTIVEB2.ϵs) - 2))
# Out:
# interactive(children=(IntSlider(value=49, description='n', max=99), Output()), _dom_classes=('widget-interact'…
# <function __main__.plot_histogram_adaptiveB2(n)>

# %%
fig, ax = plt.subplots()
ax.plot(np.array(MSTHUG_ADAPTIVEB2.ESS) / MSTHUG_ADAPTIVEB2.N * (np.array(MSTHUG_ADAPTIVEB2.Bs) + 1), label='MS')
ax.legend()
ax.set_title("ESS / number of particles ")
plt.show()

# %% [markdown]
# ### RWM verision

# %%
# Why is the schedule not decreasing even for RWM? Could it be that because we are using a gaussian kernel
# this strategy makes little sense? 
# Remember: particles are chosen based on their weights, which depend both on the prior density and on the kernel
# which in this case is Gaussian. They are NOT chosen based on their distance, although this plays a role
# through the kernel.

# %%
# Out:
# Initializing particles. Acceptance:  21.269461077844312
# Iteration:  1
# 	Epsilon:  20.32787924307508
# Iteration:  2
# 	Epsilon:  19.304184141086324
# Iteration:  3
# 	Epsilon:  19.148477729764128
# Iteration:  4
# 	Epsilon:  18.997707594031613
# Iteration:  5
# 	Epsilon:  18.875985034248604
# Iteration:  6
# 	Epsilon:  18.725407026137656
# Iteration:  7
# 	Epsilon:  18.725407026137656
# Iteration:  8
# 	Epsilon:  18.725407026137656
# Iteration:  9
# 	Epsilon:  18.725407026137656
# Iteration:  10
# 	Epsilon:  18.725407026137656
# Iteration:  11
# 	Epsilon:  18.725407026137656
# Iteration:  12
# 	Epsilon:  18.725407026137656
# Iteration:  13
# 	Epsilon:  18.725407026137656
# Iteration:  14
# EXITING:

# %%
# Out:
# interactive(children=(IntSlider(value=14, description='n', max=29), Output()), _dom_classes=('widget-interact'…
# <function __main__.plot_histogram_rwm(n)>

# %%
fig, ax = plt.subplots(nrows=MSRWM.DISTANCES.shape[0], figsize=(4, 30))
for i in range(1, MSRWM.DISTANCES.shape[0]):
    _ = ax[i].hist(MSRWM.DISTANCES[i], bins=MSRWM.B, density=True)

# %% [markdown]
# #### Distribution of distances of initial particles

# %%
_ = plt.hist(norm(np.apply_along_axis(MSRWM.manifold.q, 1, MSRWM.starting_particles[:, :MSRWM.d]), axis=1), bins=MSRWM.B, density=True)

# %%
fig, ax = plt.subplots()
ax.plot(np.array(MSRWM.ESS) / (MSRWM.N*(MSRWM.B+1)), label='MS')
ax.legend()
ax.set_title("ESS / number of particles ")
plt.show()
