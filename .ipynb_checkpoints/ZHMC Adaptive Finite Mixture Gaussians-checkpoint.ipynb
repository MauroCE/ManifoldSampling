# %%
import numpy as np
from scipy.stats import multivariate_normal
from Manifolds.RotatedEllipse import RotatedEllipse
from Zappa.zappa import zappa_adaptive, zappa_adaptive
from Zappa.ZappaAdaptive import ZappaAdaptive
from utils import logf_Jacobian
from utils import logp as logp_scale
import matplotlib.pyplot as plt
from sklearn.mixture import GaussianMixture
import scipy

# %%
mu = np.zeros(2)
Sigma = np.array([[1.0, 0.99], [0.99, 2.0]])
target = multivariate_normal(mu, Sigma)

logf = lambda xy: logf_Jacobian(xy, Sigma)
K = lambda xy: xy
s = 0.5
n = 500
tol = 1.48e-08
a_guess = 1.0
ap_star = 0.6
exponent = (2/3)

# %%
x = target.rvs()
z = target.pdf(x)
ellipse = RotatedEllipse(mu, Sigma, z)
ZappaObj = ZappaAdaptive(x, ellipse, logf, logp_scale, s, n, tol, a_guess, K, ap_star, exponent)

# %%
out = ZappaObj.sample()

# %%
out.keys()
# Out:
# dict_keys(['samples', 'vxs', 'vys', 'flagxs', 'flagys', 'nfevxs', 'nfevys', 'njevxs', 'njevys', 'axs', 'ays', 'statusesx', 'statusesy', 'logaps', 'events', 'gxs', 'gys', 'txs', 'tys', 'vsamples', 'vprimesamples', 'ys', 'Qxs', 'Qys', 'LogScales', 'avg_ls'])

# %%
plt.plot(np.exp(out['LogScales']))
plt.show()

# %%
not_inf_logaps = out['logaps'] != -np.inf
plt.plot(out['logaps'][not_inf_logaps])
plt.show()

# %%
plt.scatter(*out['samples'].T)

# %%
out['LogScales'][-1]
# Out:
# 0.24245740545976496

# %% [markdown]
# # Multiple ones

# %% [markdown]
# We have a training pair $(u, \lambda_u)$

# %%
# Generate a dataset of 30 points
def gen_data(num=10):
    zs = []
    szs = []
    for _ in range(num):
        x = target.rvs()
        z = target.pdf(x)
        ellipse = RotatedEllipse(mu, Sigma, z)
        ZappaObj = ZappaAdaptive(x, ellipse, logf, logp_scale, s, n, tol, a_guess, K, ap_star, exponent)
        out = ZappaObj.sample()
        zs.append(z)
        szs.append(np.exp(out['LogScales'][-1]))
    return np.array(zs).reshape(-1, 1), np.array(szs)

# %%
zs, szs = gen_data(num=200)

# %%
mix = GaussianMixture(n_components=20)

# %%
mix.fit(zs, szs)
# Out:
# GaussianMixture(covariance_type='full', init_params='kmeans', max_iter=100,
#                 means_init=None, n_components=20, n_init=1,
#                 precisions_init=None, random_state=None, reg_covar=1e-06,
#                 tol=0.001, verbose=0, verbose_interval=10, warm_start=False,
#                 weights_init=None)

# %%
min_val = np.min(mix.means_)
max_val = np.max(mix.means_)
range_vals = max_val - min_val
xmin = np.min(mix.means_) - 0.1 * range_vals
xmax = np.max(mix.means_) + 0.1 * range_vals
xdata = np.linspace(xmin, xmax, 200)
fig, ax = plt.subplots()
ax.plot(xdata, np.exp(mix.score_samples(xdata.reshape(-1, 1))))
plt.show()
