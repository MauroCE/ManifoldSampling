# %% [markdown]
# Same as experiment 83 (i.e. fixed step size but adaptive $\epsilon$ schedule) except here we switch to THUG sooner. Notice before we used `pm_switch=0.05` whereas now we use larger values.

# %%
import numpy as np
from numpy import zeros, eye, array, diag, exp, ones, save
from numpy.linalg import solve, norm
from numpy.random import choice, default_rng
from scipy.stats import multivariate_normal as MVN
from scipy.special import logsumexp
from scipy.stats import uniform as udist
import math
import time
from copy import deepcopy
from itertools import product

import matplotlib.pyplot as plt
from matplotlib import rc
from ipywidgets.widgets import IntSlider
from ipywidgets.widgets import interact
from warnings import resetwarnings

from Manifolds.GeneralizedEllipseNew import GeneralizedEllipse
from markov_snippets import MSAdaptive, SMCAdaptive

# %%
def generate_settings(
    d=10, 
    N=5000,
    B=20,
    δ=0.1,
    δmin=1e-3,
    δmax=100.0,
    εmin=1e-16,
    min_pm=1e-4,
    maxiter=500,
    verbose=True,
    εs_fixed=None,
    adaptiveε=True,
    adaptiveδ=True,
    z0_manual=None,
    pm_target=0.23,
    pm_switch=0.1,
    prior_seed=1234,
    low_memory=True,
    integrator='rwm',
    εprop_switch=0.01,
    ε0_manual=None,
    quantile_value=0.9,
    initialization='prior',
    switch_strategy='pm',
    prior='uniform',
    kernel='uniform',
    prior_scale=7,
    thinning=10,
    burnin=100,
    stopping_criterion={'maxiter', 'εmin', 'pm'}):
    # Generate the manifold
    μ = zeros(d)
    Σ = diag(np.r_[0.1, ones(d-1)])  
    level_set_value = -23
    manifold = GeneralizedEllipse(μ, Σ, exp(level_set_value), prior=prior, kernel=kernel, prior_scale=prior_scale)
    # grab arguments
    arguments = locals()
    return arguments

# %%
# Rename using: SAMPLER_INTEGRATOR_STEPSIZE_PM
MS_RT_1_00 = MS_RT_00
MS_RT_1_01 = MS_RT_1
MS_RT_1_02 = MS_RT_1_new
MS_RT_1_03 = MS_RT_1_new_new
MS_RT_1_04 = MS_RT_1_new_new_new
MS_RT_1_05 = MS_RT_1_new_new_new_new
MS_RT_1_06 = MS_RT_1_06
MS_THUG_1  = MS_THUG

# %%
### SETTINGS
# DELTA = 1.0
SETTINGS_RT_1_00 = generate_settings(integrator='rwm_then_thug', adaptiveδ=False, pm_switch=0.0, stopping_criterion={'maxiter', 'εmin'}, δ=1.0)
SETTINGS_RT_1_01 = generate_settings(integrator='rwm_then_thug', adaptiveδ=False, pm_switch=0.1, δ=1.0)
SETTINGS_RT_1_02 = generate_settings(integrator='rwm_then_thug', adaptiveδ=False, pm_switch=0.2, δ=1.0)
SETTINGS_RT_1_03 = generate_settings(integrator='rwm_then_thug', adaptiveδ=False, pm_switch=0.3, δ=1.0)
SETTINGS_RT_1_04 = generate_settings(integrator='rwm_then_thug', adaptiveδ=False, pm_switch=0.4, δ=1.0)
SETTINGS_RT_1_05 = generate_settings(integrator='rwm_then_thug', adaptiveδ=False, pm_switch=0.5, δ=1.0)
SETTINGS_RT_1_06 = generate_settings(integrator='rwm_then_thug', adaptiveδ=False, pm_switch=0.6, δ=1.0)
SETTINGS_THUG_1  = generate_settings(integrator='thug', adaptiveδ=False, δ=1.0)
SETTINGS_RWM_1   = generate_settings(integrator='rwm', adaptiveδ=False, δ=1.0)
# DELTA = 0.05
SETTINGS_RT_005_00 = generate_settings(integrator='rwm_then_thug', adaptiveδ=False, pm_switch=0.0, stopping_criterion={'maxiter', 'εmin'}, δ=0.05)
SETTINGS_RT_005_01 = generate_settings(integrator='rwm_then_thug', adaptiveδ=False, pm_switch=0.1, δ=0.05)
SETTINGS_RT_005_02 = generate_settings(integrator='rwm_then_thug', adaptiveδ=False, pm_switch=0.2, δ=0.05)
SETTINGS_RT_005_03 = generate_settings(integrator='rwm_then_thug', adaptiveδ=False, pm_switch=0.3, δ=0.05)
SETTINGS_RT_005_04 = generate_settings(integrator='rwm_then_thug', adaptiveδ=False, pm_switch=0.4, δ=0.05)
SETTINGS_RT_005_05 = generate_settings(integrator='rwm_then_thug', adaptiveδ=False, pm_switch=0.5, δ=0.05)
SETTINGS_RT_005_06 = generate_settings(integrator='rwm_then_thug', adaptiveδ=False, pm_switch=0.6, δ=0.05)
SETTINGS_RT_005_07 = generate_settings(integrator='rwm_then_thug', adaptiveδ=False
sample()
# Out:
# Stochastic Kernel: RWM.
# Stopping criterion:  maxiter, εmin, pm.
# Setting initial epsilon to εmax = 359.0601375830774487
# Iteration:  1
# 	Particles resampled.
# 	Epsilon: 255.7844687658531200
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4930000000000000
# 	Step-size kept fixed at: 0.0500000000000000
# Iteration:  2
# 	Particles resampled.
# 	Epsilon: 214.5193033214989100
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.5060000000000000
# 	Step-size kept fixed at: 0.0500000000000000
# Iteration:  3
# 	Particles resampled.
# 	Epsilon: 185.6042313480931796
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4900000000000000
# 	Step-size kept fixed at: 0.0500000000000000
# Iteration:  4
# 	Particles resampled.
# 	Epsilon: 160.1975979375834811
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4988000000000000
# 	Step-size kept fixed at: 0.0500000000000000
# Iteration:  5
# ...

# %%
SMC_RT_005_05 = SMCAdaptive(SETTINGS_RT_005_05)
_ = SMC_RT_005_05.sample()
# Out:
# Stochastic Kernel: RWM.
# Stopping criterion:  maxiter, εmin, pm.
# Setting initial epsilon to εmax = 359.0601375830774487
# Iteration:  1
# 	Particles resampled.
# 	Epsilon: 259.0474788083880640
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.5107999999999999
# 	Step-size kept fixed at: 0.0500000000000000
# Iteration:  2
# 	Particles resampled.
# 	Epsilon: 218.7533292089382257
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.5000000000000000
# 	Step-size kept fixed at: 0.0500000000000000
#
#
# ####################################
# ### SWITCHING TO THUG KERNEL ###
# ####################################
#
#
# Iteration:  3
# 	Particles resampled.
# 	Epsilon: 187.0870904752626132
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.5760000000000001
# 	Step-size kept fixed at: 0.0500000000000000
# Iteration:  4
# 	Particles resampled.
# 	Epsilon: 165.6132872528431506
# 	Weights computed and normalised.
# ...

# %%
SMC_RT_005_06 = SMCAdaptive(SETTINGS_RT_005_06)
_ = SMC_RT_005_06.sample()
# Out:
# Stochastic Kernel: RWM.
# Stopping criterion:  maxiter, εmin, pm.
# Setting initial epsilon to εmax = 359.0601375830774487
# Iteration:  1
# 	Particles resampled.
# 	Epsilon: 260.6685800546576388
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4988000000000000
# 	Step-size kept fixed at: 0.0500000000000000
#
#
# ####################################
# ### SWITCHING TO THUG KERNEL ###
# ####################################
#
#
# Iteration:  2
# 	Particles resampled.
# 	Epsilon: 217.1195875467642509
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.5600000000000001
# 	Step-size kept fixed at: 0.0500000000000000
# Iteration:  3
# 	Particles resampled.
# 	Epsilon: 187.5400775338512176
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.5694000000000000
# 	Step-size kept fixed at: 0.0500000000000000
# Iteration:  4
# 	Particles resampled.
# 	Epsilon: 161.2953606057686784
# 	Weights computed and normalised.
# ...

# %%
SMC_RT_005_07 = SMCAdaptive(SETTINGS_RT_005_07)
_ = SMC_RT_005_07.sample()
# Out:
# Stochastic Kernel: RWM.
# Stopping criterion:  maxiter, εmin, pm.
# Setting initial epsilon to εmax = 359.0601375830774487
# Iteration:  1
# 	Particles resampled.
# 	Epsilon: 257.9265485819198034
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.5076000000000001
# 	Step-size kept fixed at: 0.0500000000000000
#
#
# ####################################
# ### SWITCHING TO THUG KERNEL ###
# ####################################
#
#
# Iteration:  2
# 	Particles resampled.
# 	Epsilon: 219.5556176824501051
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.5671999999999999
# 	Step-size kept fixed at: 0.0500000000000000
# Iteration:  3
# 	Particles resampled.
# 	Epsilon: 187.7575973858456848
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.5690000000000000
# 	Step-size kept fixed at: 0.0500000000000000
# Iteration:  4
# 	Particles resampled.
# 	Epsilon: 159.5333086955626243
# 	Weights computed and normalised.
# ...

# %%
SMC_THUG_005 = SMCAdaptive(SETTINGS_THUG_005)
_ = SMC_THUG_005.sample()
# Out:
# Stochastic Kernel: THUG.
# Stopping criterion:  maxiter, εmin, pm.
# Setting initial epsilon to εmax = 359.0601375830774487
# Iteration:  1
# 	Particles resampled.
# 	Epsilon: 256.2656967447242664
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.5680000000000001
# 	Step-size kept fixed at: 0.0500000000000000
# Iteration:  2
# 	Particles resampled.
# 	Epsilon: 220.7350131407345373
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.5580000000000001
# 	Step-size kept fixed at: 0.0500000000000000
# Iteration:  3
# 	Particles resampled.
# 	Epsilon: 187.9123793257000727
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.5711999999999999
# 	Step-size kept fixed at: 0.0500000000000000
# Iteration:  4
# 	Particles resampled.
# 	Epsilon: 164.2326094655897180
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.5816000000000000
# 	Step-size kept fixed at: 0.0500000000000000
# Iteration:  5
# ...

# %%
rc('font',**{'family':'STIXGeneral'})
LW = 3
fig, ax = plt.subplots(figsize=(12, 6))
# MS SWITCH 
ax.plot(MS_RT_005_00.εs, MS_RT_005_00.PROP_MOVED, color=lighten_color('black', 0.1))
ax.plot(MS_RT_005_01.εs, MS_RT_005_01.PROP_MOVED, color=lighten_color('black', 0.2))
ax.plot(MS_RT_005_02.εs, MS_RT_005_02.PROP_MOVED, color=lighten_color('black', 0.3))
ax.plot(MS_RT_005_03.εs, MS_RT_005_03.PROP_MOVED, color=lighten_color('black', 0.4))
ax.plot(MS_RT_005_04.εs, MS_RT_005_04.PROP_MOVED, color=lighten_color('black', 0.5))
ax.plot(MS_RT_005_05.εs, MS_RT_005_05.PROP_MOVED, color=lighten_color('black', 0.6))
ax.plot(MS_RT_005_06.εs, MS_RT_005_06.PROP_MOVED, color=lighten_color('black', 0.7))
ax.plot(MS_RT_005_07.εs, MS_RT_005_07.PROP_MOVED, color=lighten_color('black', 0.8))
ax.plot(MS_THUG_005.εs, MS_THUG_005.PROP_MOVED, color=lighten_color('black', 1.0))
ax.plot(MS_RWM_005.εs, MS_RWM_005.PROP_MOVED, color='red')
ax.plot(SMC_RT_005_00.εs, SMC_RT_005_00.APS, color=lighten_color('darkblue', 0.1))
ax.plot(SMC_RT_005_01.εs, SMC_RT_005_01.APS, color=lighten_color('darkblue', 0.2))
ax.plot(SMC_RT_005_02.εs, SMC_RT_005_02.APS, color=lighten_color('darkblue', 0.3))
ax.plot(SMC_RT_005_03.εs, SMC_RT_005_03.APS, color=lighten_color('darkblue', 0.4))
ax.plot(SMC_RT_005_04.εs, SMC_RT_005_04.APS, color=lighten_color('darkblue', 0.5))
ax.plot(SMC_RT_005_05.εs, SMC_RT_005_05.APS, color=lighten_color('darkblue', 0.6))
ax.plot(SMC_RT_005_06.εs, SMC_RT_005_06.APS, color=lighten_color('darkblue', 0.7))
ax.plot(SMC_RT_005_07.εs, SMC_RT_005_07.APS, color=lighten_color('darkblue', 0.8))
ax.plot(SMC_THUG_005.εs, SMC_THUG_005.APS, color='purple')
ax.plot(SMC_RWM_005.εs, SMC_RWM_005.APS, color='darkblue')
ax.set_xscale('log')
ax.tick_params(axis='both', which='major', labelsize=15)
ax.set_xlabel(r'$\mathregular{\epsilon}$', fontsize=25)
ax.set_ylabel('Proportion of particles moved', fontsize=25)
# ax.legend(fontsize=15)
plt.show()

# %%
def plot_histogram(n):
    fig, ax = plt.subplots(figsize=(20, 4))
    _, bins, _ = ax.hist(MS_RT_005_06.K_RESAMPLED[n, :], density=True, bins=21, edgecolor='k', color='lightsalmon')
    ax.set_xticks(bins)
    ax.set_xticklabels(bins.astype(int))
    return plt.show()

resetwarnings()
interact(plot_histogram, n=(0, len(MS_RT_005_06.ϵs) - 2))
# Out:
# interactive(children=(IntSlider(value=126, description='n', max=253), Output()), _dom_classes=('widget-interac…
# <function __main__.plot_histogram(n)>

# %%
MS_RT_00 = MSAdaptive(SETTINGS_TEST)
_ = MS_RT_00.sample()
# Out:
# Integrator: RWM.
# Stopping criterion:  maxiter, εmin,
# Setting initial epsilon to εmax = 359.0601375830774487
# Iteration:  1
# 	Trajectories constructed.
# 	Epsilon: 257.2843954776984674
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.5512000000000000
# 	Step-size kept fixed at: 1.0000000000000000
# Iteration:  2
# 	Trajectories constructed.
# 	Epsilon: 214.3541931782844472
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.5542000000000000
# 	Step-size kept fixed at: 1.0000000000000000
# Iteration:  3
# 	Trajectories constructed.
# 	Epsilon: 179.2163371875774089
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.5646000000000000
# 	Step-size kept fixed at: 1.0000000000000000
# Iteration:  4
# 	Trajectories constructed.
# 	Epsilon: 148.5086924069205452
# 	Weights computed and normalized.
# 	Particles Resampled.
# ...

# %%
# delta = 1.0
SETTINGS_RWM_1           = generate_settings(integrator='rwm', adaptiveδ=False, δ=1.0)
SETTINGS_THUG_1          = generate_settings(integrator='thug', adaptiveδ=False, δ=1.0)
SETTINGS_RWM_THEN_THUG_1 = generate_settings(integrator='rwm_then_thug', adaptiveδ=False, δ=1.0)

# delta = 0.05
SETTINGS_RWM_005           = generate_settings(integrator='rwm', adaptiveδ=False, δ=0.05)
SETTINGS_THUG_005          = generate_settings(integrator='thug', adaptiveδ=False, δ=0.05)
SETTINGS_RWM_THEN_THUG_005 = generate_settings(integrator='rwm_then_thug', adaptiveδ=False, δ=0.05)

# delta = 0.001
SETTINGS_RWM_0001           = generate_settings(integrator='rwm', adaptiveδ=False, δ=0.001)
SETTINGS_THUG_0001          = generate_settings(integrator='thug', adaptiveδ=False, δ=0.001)
SETTINGS_RWM_THEN_THUG_0001 = generate_settings(integrator='rwm_then_thug', adaptiveδ=False, δ=0.001)

# %% [markdown]
# # Switching

# %% [markdown]
# ## $\delta=1.0$

# %% [markdown]
# #### SMC

# %%
SMC_RT_1 = SMCAdaptive(SETTINGS_RWM_THEN_THUG_1)
_ = SMC_RT_1.sample()
# Out:
# Stochastic Kernel: RWM.
# Setting initial epsilon to εmax = 359.0601375830774487
# Iteration:  1
# 	Particles resampled.
# 	Epsilon: 258.4945850518209909
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0416000000000000
# 	Step-size kept fixed at: 1.0000000000000000
#
#
# ####################################
# ### SWITCHING TO THUG KERNEL ###
# ####################################
#
#
# Iteration:  2
# 	Particles resampled.
# 	Epsilon: 218.7153288726690334
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2802000000000000
# 	Step-size kept fixed at: 1.0000000000000000
# Iteration:  3
# 	Particles resampled.
# 	Epsilon: 183.6155912838585493
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2910000000000000
# 	Step-size kept fixed at: 1.0000000000000000
# Iteration:  4
# 	Particles resampled.
# 	Epsilon: 154.7799998772719050
# 	Weights computed and normalised.
# 	Mutation step done.
# ...

# %% [markdown]
# #### Markov Snippets

# %%
MS_RT_1 = MSAdaptive(SETTINGS_RWM_THEN_THUG_1)
_ = MS_RT_1.sample()
# Out:
# Integrator: RWM.
# Setting initial epsilon to εmax = 359.0601375830774487
# Iteration:  1
# 	Trajectories constructed.
# 	Epsilon: 257.2843954776984674
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.5460000000000000
# 	Step-size kept fixed at: 1.0000000000000000
# Iteration:  2
# 	Trajectories constructed.
# 	Epsilon: 213.7916804761001401
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.5644000000000000
# 	Step-size kept fixed at: 1.0000000000000000
# Iteration:  3
# 	Trajectories constructed.
# 	Epsilon: 179.5852539235991117
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.5840000000000000
# 	Step-size kept fixed at: 1.0000000000000000
# Iteration:  4
# 	Trajectories constructed.
# 	Epsilon: 149.4856857096951330
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# ...

# %%
# Colors
SMC_RWM_COLOR = 'orange'     # warm, light
SMC_RT_COLOR = 'lightcoral'  # warm, light
MS_RWM_COLOR = 'thistle'   # cold, light
MS_RT_COLOR = 'lightskyblue' # cold, light
SMC_RT_LINE_COLOR = 'firebrick'  # warm, dark
MS_RT_LINE_COLOR = 'royalblue'   # cold, dark

# %%
rc('font',**{'family':'STIXGeneral'})
LW = 3
fig, ax = plt.subplots(figsize=(12, 6))
# SMC SWITCH
# ax.plot(SMC_RT_1.εs, SMC_RT_1.APS, label='SMC-RT', color=SMC_RT_COLOR) 
# MS SWITCH 
ax.plot(MS_RT_00.εs[:-59], MS_RT_00.PROP_MOVED[:-59], label='MS-RT pm=0.0', color=lighten_color('black', 0.1), zorder=1, lw=LW)
ax.plot(MS_RT_1.εs, MS_RT_1.PROP_MOVED, label='MS-RT pm=0.1', color=lighten_color('black', 0.2), zorder=2, lw=LW)
ax.plot(MS_RT_1_new.εs, MS_RT_1_new.PROP_MOVED, label='MS-RT pm=0.2', color=lighten_color('black', 0.3), zorder=3, lw=LW)
ax.plot(MS_RT_1_new_new.εs, MS_RT_1_new_new.PROP_MOVED, label='MS-RT pm=0.3', color=lighten_color('black', 0.4), zorder=4, lw=LW)
ax.plot(MS_RT_1_new_new_new.εs, MS_RT_1_new_new_new.PROP_MOVED, label='MS-RT pm=0.4', color=lighten_color('black', 0.5), zorder=5, lw=LW)
ax.plot(MS_RT_1_new_new_new_new.εs, MS_RT_1_new_new_new_new.PROP_MOVED, label='MS-RT pm=0.5', color=lighten_color('black', 0.6), zorder=6, lw=LW)
ax.plot(MS_RT_1_06.εs, MS_RT_1_06.PROP_MOVED, label='MS-RT pm=0.6', color=lighten_color('black', 0.7), zorder=7, lw=LW)
ax.plot(MS_THUG.εs, MS_THUG.PROP_MOVED, label='MS-THUG', color=lighten_color('black', 1.0), zorder=8, lw=LW)
ax.set_xscale('log')
ax.tick_params(axis='both', which='major', labelsize=15)
ax.set_xlabel(r'$\mathregular{\epsilon}$', fontsize=25)
ax.set_ylabel('Proportion of particles moved', fontsize=25)
ax.legend(fontsize=15)
plt.savefig('figures/ms_prop_particles_moved_switch.png')
plt.show()

# %%
rc('font',**{'family':'STIXGeneral'})

fig, ax = plt.subplots(figsize=(10, 5))
ax.plot(MS_RT_00.εs, MS_RT_00.PROP_MOVED, label='MS-RT pm=0.0', color='purple')
ax.plot(SMC_RT_1.εs, SMC_RT_1.APS, label='SMC-RT', color=SMC_RT_COLOR)
ax.plot(MS_RT_1_old.εs, MS_RT_1_old.PROP_MOVED, label='MS-RT pm=0.05', color=lighten_color('black', 0.05), zorder=8)
ax.plot(MS_RT_1.εs, MS_RT_1.PROP_MOVED, label='MS-RT pm=0.1', color=lighten_color('black', 0.1), zorder=7)
# ax.axvline(x=SMC_RT_1.εs[SMC_RT_1.n_switch], color=SMC_RT_LINE_COLOR, linestyle='--')
# ax.axvline(x=MS_RT_1.εs[MS_RT_1.n_switch], color=MS_RT_LINE_COLOR, linestyle='--')
# ax.plot(SMC_RT_1_new.εs, SMC_RT_1_new.APS, label='SMC-RT', color=SMC_RT_COLOR)
ax.plot(MS_RT_1_new.εs, MS_RT_1_new.PROP_MOVED, label='MS-RT pm=0.2', color=lighten_color('black', 0.2), zorder=6)
ax.plot(MS_RT_1_new_new.εs, MS_RT_1_new_new.PROP_MOVED, label='MS-RT pm=0.3', color=lighten_color('black', 0.3), zorder=5)
ax.plot(MS_RT_1_new_new_new.εs, MS_RT_1_new_new_new.PROP_MOVED, label='MS-RT pm=0.4', color=lighten_color('black', 0.4), zorder=4)
ax.plot(MS_RT_1_new_new_new_new.εs, MS_RT_1_new_new_new_new.PROP_MOVED, label='MS-RT pm=0.5', color=lighten_color('black', 0.5), zorder=3)
ax.plot(MS_RT_1_06.εs, MS_RT_1_06.PROP_MOVED, label='MS-RT pm=0.6', color=lighten_color('black', 0.6), zorder=2)
ax.plot(MS_THUG.εs, MS_THUG.PROP_MOVED, label='MS-THUG', color=lighten_color('black', 1.0), zorder=1)
# ax.axvline(x=SMC_RT_1_new.εs[SMC_RT_1_new.n_switch], color='red', linestyle='--')
# ax.axvline(x=MS_RT_1_new.εs[MS_RT_1_new.n_switch], color='blue', linestyle='--')
ax.set_xscale('log')
ax.legend()
plt.show()

# %% [markdown]
# ### Try with even larger pm_switch

# %%
# delta = 1.0
SETTINGS_RT_1_new = generate_settings(integrator='rwm_then_thug', adaptiveδ=False, δ=1.0, pm_switch=0.2)

# %%
SMC_RT_1_new = SMCAdaptive(SETTINGS_RT_1_new)
_ = SMC_RT_1_new.sample()
# Out:
# Stochastic Kernel: RWM.
# Setting initial epsilon to εmax = 359.0601375830774487
# Iteration:  1
# 	Particles resampled.
# 	Epsilon: 257.1534623954585186
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0486000000000000
# 	Step-size kept fixed at: 1.0000000000000000
#
#
# ####################################
# ### SWITCHING TO THUG KERNEL ###
# ####################################
#
#
# Iteration:  2
# 	Particles resampled.
# 	Epsilon: 218.5649190995446531
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2826000000000000
# 	Step-size kept fixed at: 1.0000000000000000
# Iteration:  3
# 	Particles resampled.
# 	Epsilon: 179.5008445492919122
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2932000000000000
# 	Step-size kept fixed at: 1.0000000000000000
# Iteration:  4
# 	Particles resampled.
# 	Epsilon: 151.8516359143490604
# 	Weights computed and normalised.
# 	Mutation step done.
# ...

# %%
MS_RT_1_new = MSAdaptive(SETTINGS_RT_1_new)
_ = MS_RT_1_new.sample()
# Out:
# Integrator: RWM.
# Setting initial epsilon to εmax = 359.0601375830774487
# Iteration:  1
# 	Trajectories constructed.
# 	Epsilon: 257.2843954776984674
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.5482000000000000
# 	Step-size kept fixed at: 1.0000000000000000
# Iteration:  2
# 	Trajectories constructed.
# 	Epsilon: 210.8547321639559868
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.5612000000000000
# 	Step-size kept fixed at: 1.0000000000000000
# Iteration:  3
# 	Trajectories constructed.
# 	Epsilon: 175.4687677129139729
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.5926000000000000
# 	Step-size kept fixed at: 1.0000000000000000
# Iteration:  4
# 	Trajectories constructed.
# 	Epsilon: 145.9982812439670852
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# ...

# %% [markdown]
# ### Try even larger

# %%
SETTINGS_RT_1_new_new = generate_settings(integrator='rwm_then_thug', adaptiveδ=False, δ=1.0, pm_switch=0.3)

# %%
MS_RT_1_new_new = MSAdaptive(SETTINGS_RT_1_new_new)
_ = MS_RT_1_new_new.sample()
# Out:
# Integrator: RWM.
# Setting initial epsilon to εmax = 359.0601375830774487
# Iteration:  1
# 	Trajectories constructed.
# 	Epsilon: 257.2843954776984674
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.5438000000000000
# 	Step-size kept fixed at: 1.0000000000000000
# Iteration:  2
# 	Trajectories constructed.
# 	Epsilon: 212.5905742599638586
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.5676000000000000
# 	Step-size kept fixed at: 1.0000000000000000
# Iteration:  3
# 	Trajectories constructed.
# 	Epsilon: 178.3537592264850673
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.5724000000000000
# 	Step-size kept fixed at: 1.0000000000000000
# Iteration:  4
# 	Trajectories constructed.
# 	Epsilon: 151.8076432487252418
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# ...

# %% [markdown]
# ### Try even largerrr

# %%
SETTINGS_RT_1_new_new_new = generate_settings(integrator='rwm_then_thug', adaptiveδ=False, δ=1.0, pm_switch=0.4)

# %%
MS_RT_1_new_new_new = MSAdaptive(SETTINGS_RT_1_new_new_new)
_ = MS_RT_1_new_new_new.sample()
# Out:
# Integrator: RWM.
# Setting initial epsilon to εmax = 359.0601375830774487
# Iteration:  1
# 	Trajectories constructed.
# 	Epsilon: 257.2843954776984674
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.5562000000000000
# 	Step-size kept fixed at: 1.0000000000000000
# Iteration:  2
# 	Trajectories constructed.
# 	Epsilon: 215.4568279471426706
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.5722000000000000
# 	Step-size kept fixed at: 1.0000000000000000
# Iteration:  3
# 	Trajectories constructed.
# 	Epsilon: 180.4721011593359776
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.5786000000000000
# 	Step-size kept fixed at: 1.0000000000000000
# Iteration:  4
# 	Trajectories constructed.
# 	Epsilon: 150.7247729695131966
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# ...

# %% [markdown]
# ### even largerrr

# %%
SETTINGS_RT_1_new_new_new_new = generate_settings(integrator='rwm_then_thug', adaptiveδ=False, δ=1.0, pm_switch=0.5)

# %%
MS_RT_1_new_new_new_new = MSAdaptive(SETTINGS_RT_1_new_new_new_new)
_ = MS_RT_1_new_new_new_new.sample()
# Out:
# Integrator: RWM.
# Setting initial epsilon to εmax = 359.0601375830774487
# Iteration:  1
# 	Trajectories constructed.
# 	Epsilon: 257.2843954776984674
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.5506000000000000
# 	Step-size kept fixed at: 1.0000000000000000
# Iteration:  2
# 	Trajectories constructed.
# 	Epsilon: 212.5679949884594180
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.5762000000000000
# 	Step-size kept fixed at: 1.0000000000000000
# Iteration:  3
# 	Trajectories constructed.
# 	Epsilon: 179.3439763323625584
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.5742000000000000
# 	Step-size kept fixed at: 1.0000000000000000
# Iteration:  4
# 	Trajectories constructed.
# 	Epsilon: 150.5701226888661211
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# ...

# %% [markdown]
# ### with 0.6

# %%
SETTINGS_RT_1_06 = generate_settings(integrator='rwm_then_thug', adaptiveδ=False, δ=1.0, pm_switch=0.6)

# %%
MS_RT_1_06 = MSAdaptive(SETTINGS_RT_1_06)
_ = MS_RT_1_06.sample()
# Out:
# Integrator: RWM.
# Setting initial epsilon to εmax = 359.0601375830774487
# Iteration:  1
# 	Trajectories constructed.
# 	Epsilon: 257.2843954776984674
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.5407999999999999
# 	Step-size kept fixed at: 1.0000000000000000
#
#
# ####################################
# ### SWITCHING TO THUG INTEGRATOR ###
# ####################################
#
#
# Iteration:  2
# 	Trajectories constructed.
# 	Epsilon: 212.4244818686197789
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8736000000000000
# 	Step-size kept fixed at: 1.0000000000000000
# Iteration:  3
# 	Trajectories constructed.
# 	Epsilon: 154.5958176583429236
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9150000000000000
# 	Step-size kept fixed at: 1.0000000000000000
# Iteration:  4
# 	Trajectories constructed.
# ...

# %% [markdown]
# ### try very small

# %%
SETTINGS_RT_1_old = generate_settings(integrator='rwm_then_thug', adaptiveδ=False, δ=1.0, pm_switch=0.05)

# %%
MS_RT_1_old = MSAdaptive(SETTINGS_RT_1_old)
_ = MS_RT_1_old.sample()
# Out:
# Integrator: RWM.
# Setting initial epsilon to εmax = 359.0601375830774487
# Iteration:  1
# 	Trajectories constructed.
# 	Epsilon: 257.2843954776984674
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.5352000000000000
# 	Step-size kept fixed at: 1.0000000000000000
# Iteration:  2
# 	Trajectories constructed.
# 	Epsilon: 210.9525032199069869
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.5486000000000000
# 	Step-size kept fixed at: 1.0000000000000000
# Iteration:  3
# 	Trajectories constructed.
# 	Epsilon: 173.3984382928760510
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.5842000000000001
# 	Step-size kept fixed at: 1.0000000000000000
# Iteration:  4
# 	Trajectories constructed.
# 	Epsilon: 145.2812387348177481
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# ...

# %% [markdown]
# ### Only THUG (corresponding to pm_switch=1.0)

# %%
SETTINGS_THUG = generate_settings(integrator='thug', adaptiveδ=False, δ=1.0)

# %%
MS_THUG = MSAdaptive(SETTINGS_THUG)
_ = MS_THUG.sample()
# Out:
# Integrator: THUG.
# Setting initial epsilon to εmax = 359.0601375830774487
# Iteration:  1
# 	Trajectories constructed.
# 	Epsilon: 257.2843954776984674
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8524000000000000
# 	Step-size kept fixed at: 1.0000000000000000
# Iteration:  2
# 	Trajectories constructed.
# 	Epsilon: 185.2213724452308554
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9028000000000000
# 	Step-size kept fixed at: 1.0000000000000000
# Iteration:  3
# 	Trajectories constructed.
# 	Epsilon: 97.3292692139214211
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9266000000000000
# 	Step-size kept fixed at: 1.0000000000000000
# Iteration:  4
# 	Trajectories constructed.
# 	Epsilon: 69.9135232940172955
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# ...

# %% [markdown]
# # Save data

# %%
### MS
# pm=0.0 (MS-RT), δ=1.0
save('experiment84/ms_rt_1_00_epsilon.npy', MS_RT_1_00.εs)
save('experiment84/ms_rt_1_00_propmoved.npy', MS_RT_1_00.PROP_MOVED)
save('experiment84/ms_rt_1_00_ess.npy', MS_RT_1_00.ESS)
save('experiment84/ms_rt_1_00_kresampled.npy', MS_RT_1_00.K_RESAMPLED)
# pm=0.1 (MS-RT), δ=1.0
save('experiment84/ms_rt_1_01_epsilon.npy', MS_RT_1_01.εs)
save('experiment84/ms_rt_1_01_propmoved.npy', MS_RT_1_01.PROP_MOVED)
save('experiment84/ms_rt_1_01_ess.npy', MS_RT_1_01.ESS)
save('experiment84/ms_rt_1_01_kresampled.npy', MS_RT_1_01.K_RESAMPLED)
# pm=0.2 (MS-RT), δ=1.0
save('experiment84/ms_rt_1_02_epsilon.npy', MS_RT_1_02.εs)
save('experiment84/ms_rt_1_02_propmoved.npy', MS_RT_1_02.PROP_MOVED)
save('experiment84/ms_rt_1_02_ess.npy', MS_RT_1_02.ESS)
save('experiment84/ms_rt_1_02_kresampled.npy', MS_RT_1_02.K_RESAMPLED)
# pm=0.3 (MS-RT), δ=1.0
save('experiment84/ms_rt_1_03_epsilon.npy', MS_RT_1_03.εs)
save('experiment84/ms_rt_1_03_propmoved.npy', MS_RT_1_03.PROP_MOVED)
save('experiment84/ms_rt_1_03_ess.npy', MS_RT_1_03.ESS)
save('experiment84/ms_rt_1_03_kresampled.npy', MS_RT_1_03.K_RESAMPLED)
# pm=0.4 (MS-RT), δ=1.0
save('experiment84/ms_rt_1_04_epsilon.npy', MS_RT_1_04.εs)
save('experiment84/ms_rt_1_04_propmoved.npy', MS_RT_1_04.PROP_MOVED)
save('experiment84/ms_rt_1_04_ess.npy', MS_RT_1_04.ESS)
save('experiment84/ms_rt_1_04_kresampled.npy', MS_RT_1_04.K_RESAMPLED)
# pm=0.5 (MS-RT), δ=1.0
save('experiment84/ms_rt_1_05_epsilon.npy', MS_RT_1_05.εs)
save('experiment84/ms_rt_1_05_propmoved.npy', MS_RT_1_05.PROP_MOVED)
save('experiment84/ms_rt_1_05_ess.npy', MS_RT_1_05.ESS)
save('experiment84/ms_rt_1_05_kresampled.npy', MS_RT_1_05.K_RESAMPLED)
# pm=0.6 (MS-RT), δ=1.0
save('experiment84/ms_rt_1_06_epsilon.npy', MS_RT_1_06.εs)
save('experiment84/ms_rt_1_06_propmoved.npy', MS_RT_1_06.PROP_MOVED)
save('experiment84/ms_rt_1_06_ess.npy', MS_RT_1_06.ESS)
save('experiment84/ms_rt_1_06_kresampled.npy', MS_RT_1_06.K_RESAMPLED)
# pm=1.0 (MS-THUG), δ=1.0
save('experiment84/ms_thug_1_epsilon.npy', MS_THUG_1.εs)
save('experiment84/ms_thug_1_propmoved.npy', MS_THUG_1.PROP_MOVED)
save('experiment84/ms_thug_1_ess.npy', MS_THUG_1.ESS)
save('experiment84/ms_thug_1_kresampled.npy', MS_THUG_1.K_RESAMPLED)
##### DELTA=0.05
### MS
# pm=0.0 (MS-RT), δ=0.05
save('experiment84/ms_rt_005_00_epsilon.npy', MS_RT_005_00.εs)
save('experiment84/ms_rt_005_00_propmoved.npy', MS_RT_005_00.PROP_MOVED)
save('experiment84/ms_rt_005_00_ess.npy', MS_RT_005_00.ESS)
save('experiment84/ms_rt_005_00_kresampled.npy', MS_RT_005_00.K_RESAMPLED)
# pm=0.1 (MS-RT), δ=0.05
save('experiment84/ms_rt_005_01_epsilon.npy', MS_RT_005_01.εs)
save('experiment84/ms_rt_005_01_propmoved.npy', MS_RT_005_01.PROP_MOVED)
save('experiment84/ms_rt_005_01_ess.npy', MS_RT_005_01.ESS)
save('experiment84/ms_rt_005_01_kresampled.npy', MS_RT_005_01.K_RESAMPLED)
# pm=0.2 (MS-RT), δ=0.05
save('experiment84/ms_rt_005_02_epsilon.npy', MS_RT_005_02.εs)
save('experiment84/ms_rt_005_02_propmoved.npy', MS_RT_005_02.PROP_MOVED)
save('experiment84/ms_rt_005_02_ess.npy', MS_RT_005_02.ESS)
save('experiment84/ms_rt_005_02_kresampled.npy', MS_RT_005_02.K_RESAMPLED)
# pm=0.3 (MS-RT), δ=0.05
save('experiment84/ms_rt_005_03_epsilon.npy', MS_RT_005_03.εs)
save('experiment84/ms_rt_005_03_propmoved.npy', MS_RT_005_03.PROP_MOVED)
save('experiment84/ms_rt_005_03_ess.npy', MS_RT_005_03.ESS)
save('experiment84/ms_rt_005_03_kresampled.npy', MS_RT_005_03.K_RESAMPLED)
# pm=0.4 (MS-RT), δ=0.05
save('experiment84/ms_rt_005_04_epsilon.npy', MS_RT_005_04.εs)
save('experiment84/ms_rt_005_04_propmoved.npy', MS_RT_005_04.PROP_MOVED)
save('experiment84/ms_rt_005_04_ess.npy', MS_RT_005_04.ESS)
save('experiment84/ms_rt_005_04_kresampled.npy', MS_RT_005_04.K_RESAMPLED)
# pm=0.5 (MS-RT), δ=0.05
save('experiment84/ms_rt_005_05_epsilon.npy', MS_RT_005_05.εs)
save('experiment84/ms_rt_005_05_propmoved.npy', MS_RT_005_05.PROP_MOVED)
save('experiment84/ms_rt_005_05_ess.npy', MS_RT_005_05.ESS)
save('experiment84/ms_rt_005_05_kresampled.npy', MS_RT_005_05.K_RESAMPLED)
# pm=0.6 (MS-RT), δ=0.05
save('experiment84/ms_rt_005_06_epsilon.npy', MS_RT_005_06.εs)
