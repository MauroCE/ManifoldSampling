# %% [markdown]
# This is used as a "fourth core" to perform seemingly parallel experiments. In this case we do stuff related to experiment 94.

# %%
import numpy as np
from numpy import zeros, eye, array, diag, exp, ones, tanh, cosh, dstack, log, hstack, vstack, sinh
from numpy.linalg import solve, norm
from numpy.random import choice, default_rng, randint, randn
from scipy.stats import multivariate_normal as MVN
from scipy.special import logsumexp, ndtr
from scipy.stats import uniform as udist
import math
import time
from copy import deepcopy

import matplotlib.pyplot as plt
from matplotlib import rc
from ipywidgets.widgets import IntSlider
from ipywidgets.widgets import interact
from warnings import resetwarnings, catch_warnings, filterwarnings
import seaborn as sns
import pickle

from Manifolds.GKManifoldNew import GKManifold, data_generator, find_point_on_manifold, find_point_on_manifold_from_θ
from markov_snippets import MSAdaptive, SMCAdaptive
from tangential_hug_functions import TangentialHugSampler
from tangential_hug_functions import HugTangentialMultivariate
from RWM import RWM
from utils import ESS_univariate
from utils import send_notification_to_iphone

seed = 1234
m = 20     # number of latent variables
d = m + 4  # dimensionality of x-component

def generate_settings(
    d=d, 
    N=2000,
    B=20,
    δ=0.01,
    δmin=1e-3,
    δmax=100.0,
    εmin=1e-16,
    min_pm=1e-4,
    maxiter=500,
    verbose=False,
    εs_fixed=None,
    adaptiveε=True,
    adaptiveδ=False,
    z0_manual=None,
    pm_target=0.23,
    pd_target=0.4,
    dm_target=0.01,
    pm_switch=0.1,
    prior_seed=seed,
    low_memory=True,
    integrator='rwm',
    εprop_switch=0.01,
    ε0_manual=None,
    quantile_value=0.9,
    initialization='manual',
    switch_strategy='pm',
    kernel='uniform',
    prior_scale=7,
    thinning=10,
    burnin=100,
    use_autograd=False,
    stopping_criterion={'εmin', 'pm'},
    resampling_seed=1234,
    mh_kernel_seed=1234,
    resampling_scheme='multinomial',
    prop_hug=0.5,
    projection_method='qr',
    metropolised=False,
    δadaptation_method='ap',
    prop_esjd=0.95,
    adaptiveB=False,
    Bmin=5,
    Bmax=100,
    proxy_ap_metric='dm',
    adaptiveN=False,
    NBbudget=None,
    Badaptation_method=None,
    adaptive_prophug=False,
    min_prop_hug=0.1,
    max_prop_hug=0.9):
    # here d represents m+4
    # Generate the manifold
    θ0        = array([3.0, 1.0, 2.0, 0.5])       # True parameter value on U(0, 10) scale.
    ystar     = data_generator(θ0, m, seed=seed)  # Observed data
    q         = MVN(zeros(d), eye(d))             # Proposal distribution for THUG
    resetwarnings()
    manifold  = GKManifold(ystar, kernel_type=kernel, use_autograd=use_autograd)
    # grab arguments
    arguments = locals()
    return arguments

δmin   = 1e-3
min_pm = 1e-4
pm_switch = 0.1

with open("experiment93/second_particles10k.pkl", "rb") as file:
    P1_10k = pickle.load(file)

# %% [markdown]
# ### B=20, N=2500, prop_hug=0.1

# %%
B20N2k_HAN_01 = MSAdaptive(generate_settings(d=d, N=2500, B=20,
        δ=0.01, δmin=δmin, min_pm=(1/2500), verbose=True, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=P1_10k[:2500], pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='hug_and_nhug',
        εprop_switch=0.01, ε0_manual=200.0, quantile_value=0.5, initialization='manual',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=1000, δadaptation_method=None, adaptiveB=False,
        Bmin=5, Bmax=100, proxy_ap_metric='pm', prop_esjd=0.95, Badaptation_method=None, prop_hug=0.1))
B20N2k_HAN_01_PARTICLES = B20N2k_HAN_01.sample()
# Out:
# Integrator: HUG + NHUG.
# Prop Hug  :  0.1
# Stopping criterion:  maxiter, εmin, pm.
# Resampling: MULTINOMIAL.
# Iteration:  1
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 54.7133582196436166
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9544000000000000
# 	Particle Diversity: 0.4688000000000000
# 	Moved Diversity: 0.4474227200000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  2
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 32.3335774382488381
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9496000000000000
# 	Particle Diversity: 0.4468000000000000
# 	Moved Diversity: 0.4242812800000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  3
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 25.0924385198178115
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9428000000000000
# 	Particle Diversity: 0.4468000000000000
# 	Moved Diversity: 0.4212430400000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  4
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 21.4043823966349649
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9492000000000000
# 	Particle Diversity: 0.4648000000000000
# 	Moved Diversity: 0.4411881600000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  5
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 19.3461054135189450
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9532000000000000
# 	Particle Diversity: 0.4536000000000000
# 	Moved Diversity: 0.4323715200000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  6
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 17.8592038502126016
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9544000000000000
# 	Particle Diversity: 0.4556000000000000
# 	Moved Diversity: 0.4348246400000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  7
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 17.1616627246583207
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9440000000000000
# 	Particle Diversity: 0.4516000000000000
# 	Moved Diversity: 0.4263104000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  8
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 16.4536822582713498
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9440000000000000
# 	Particle Diversity: 0.4448000000000000
# 	Moved Diversity: 0.4198912000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  9
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 15.3041687219604103
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9480000000000000
# 	Particle Diversity: 0.4660000000000000
# 	Moved Diversity: 0.4417680000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  10
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 14.1869711554385702
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9432000000000000
# 	Particle Diversity: 0.4608000000000000
# 	Moved Diversity: 0.4346265600000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  11
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 13.1710195995286270
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9408000000000000
# 	Particle Diversity: 0.4552000000000000
# 	Moved Diversity: 0.4282521600000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  12
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 12.2418076132786755
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9448000000000000
# 	Particle Diversity: 0.4724000000000000
# 	Moved Diversity: 0.4463235200000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  13
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 11.4089990256070415
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9404000000000000
# 	Particle Diversity: 0.4540000000000000
# 	Moved Diversity: 0.4269416000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  14
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 10.5691368550662084
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9240000000000000
# 	Particle Diversity: 0.4508000000000000
# 	Moved Diversity: 0.4165392000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  15
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 9.7954690236703268
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9264000000000000
# 	Particle Diversity: 0.4544000000000000
# 	Moved Diversity: 0.4209561600000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  16
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 9.0855740538184762
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9260000000000000
# 	Particle Diversity: 0.4564000000000000
# 	Moved Diversity: 0.4226264000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  17
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 8.3820870955537163
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9368000000000000
# 	Particle Diversity: 0.4436000000000000
# 	Moved Diversity: 0.4155644800000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  18
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 7.7025806335382336
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9292000000000000
# 	Particle Diversity: 0.4368000000000000
# 	Moved Diversity: 0.4058745600000001
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  19
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 7.0984987754211799
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9292000000000000
# 	Particle Diversity: 0.4364000000000000
# 	Moved Diversity: 0.4055028800000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  20
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 6.4547987988568174
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9096000000000000
# 	Particle Diversity: 0.4472000000000000
# 	Moved Diversity: 0.4067731200000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  21
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 5.8657656305741011
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9088000000000001
# 	Particle Diversity: 0.4392000000000000
# 	Moved Diversity: 0.3991449600000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  22
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 5.3875209278035658
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9104000000000000
# 	Particle Diversity: 0.4440000000000000
# 	Moved Diversity: 0.4042176000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  23
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 4.9757626234228240
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8912000000000000
# 	Particle Diversity: 0.4428000000000000
# 	Moved Diversity: 0.3946233600000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  24
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 4.5950456332434184
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8904000000000000
# 	Particle Diversity: 0.4360000000000000
# 	Moved Diversity: 0.3882144000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  25
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 4.2664498758183784
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8804000000000000
# 	Particle Diversity: 0.4364000000000000
# 	Moved Diversity: 0.3842065600000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  26
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 3.9928095511686479
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8612000000000000
# 	Particle Diversity: 0.4336000000000000
# 	Moved Diversity: 0.3734163200000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  27
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 3.7546599504615052
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8616000000000000
# 	Particle Diversity: 0.4492000000000000
# 	Moved Diversity: 0.3870307200000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  28
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 3.5620241267497539
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8592000000000000
# 	Particle Diversity: 0.4420000000000000
# 	Moved Diversity: 0.3797664000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  29
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 3.3858006386649691
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8444000000000000
# 	Particle Diversity: 0.4512000000000000
# 	Moved Diversity: 0.3809932800000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  30
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 3.2354920800027998
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8336000000000000
# 	Particle Diversity: 0.4432000000000000
# 	Moved Diversity: 0.3694515200000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  31
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 3.0939697521190315
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8344000000000000
# 	Particle Diversity: 0.4524000000000000
# 	Moved Diversity: 0.3774825600000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  32
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 2.9416229109216805
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8448000000000000
# 	Particle Diversity: 0.4444000000000000
# 	Moved Diversity: 0.3754291200000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  33
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 2.7864318575310927
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8380000000000000
# 	Particle Diversity: 0.4472000000000000
# 	Moved Diversity: 0.3747536000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  34
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 2.6427624054425580
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8220000000000000
# 	Particle Diversity: 0.4528000000000000
# 	Moved Diversity: 0.3722016000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  35
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 2.5228775848448564
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8092000000000000
# 	Particle Diversity: 0.4496000000000000
# 	Moved Diversity: 0.3638163200000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  36
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 2.4259707132156860
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8112000000000000
# 	Particle Diversity: 0.4540000000000000
# 	Moved Diversity: 0.3682848000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  37
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 2.3395716299748588
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7972000000000000
# 	Particle Diversity: 0.4536000000000000
# 	Moved Diversity: 0.3616099200000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  38
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 2.2629891640109068
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7960000000000000
# 	Particle Diversity: 0.4476000000000000
# 	Moved Diversity: 0.3562896000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  39
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 2.1891337002574955
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7907999999999999
# 	Particle Diversity: 0.4516000000000000
# 	Moved Diversity: 0.3571252800000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  40
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 2.1218665489020285
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7876000000000000
# 	Particle Diversity: 0.4444000000000000
# 	Moved Diversity: 0.3500094400000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  41
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 2.0569081174579145
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7927999999999999
# 	Particle Diversity: 0.4632000000000000
# 	Moved Diversity: 0.3672249600000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  42
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.9935268949743579
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7572000000000000
# 	Particle Diversity: 0.4572000000000000
# 	Moved Diversity: 0.3461918400000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  43
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.9314360520144214
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7760000000000000
# 	Particle Diversity: 0.4412000000000000
# 	Moved Diversity: 0.3423712000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  44
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.8835517644498059
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7800000000000000
# 	Particle Diversity: 0.4608000000000000
# 	Moved Diversity: 0.3594240000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  45
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.8371052387006570
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7536000000000000
# 	Particle Diversity: 0.4476000000000000
# 	Moved Diversity: 0.3373113600000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  46
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.7963835689860803
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7784000000000000
# 	Particle Diversity: 0.4536000000000000
# 	Moved Diversity: 0.3530822400000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  47
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.7494863214450187
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7628000000000000
# 	Particle Diversity: 0.4524000000000000
# 	Moved Diversity: 0.3450907200000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  48
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.7007104781834477
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7675999999999999
# 	Particle Diversity: 0.4512000000000000
# 	Moved Diversity: 0.3463411199999999
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  49
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.6534652760772994
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7472000000000000
# 	Particle Diversity: 0.4472000000000000
# 	Moved Diversity: 0.3341478400000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  50
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.6087058176490352
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7576000000000001
# 	Particle Diversity: 0.4560000000000000
# 	Moved Diversity: 0.3454656000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  51
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.5693434009611607
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7536000000000000
# 	Particle Diversity: 0.4584000000000000
# 	Moved Diversity: 0.3454502400000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  52
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.5286783580251873
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7544000000000000
# 	Particle Diversity: 0.4612000000000000
# 	Moved Diversity: 0.3479292800000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  53
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.4922293652926535
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7392000000000000
# 	Particle Diversity: 0.4508000000000000
# 	Moved Diversity: 0.3332313600000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  54
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.4602714858842958
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7440000000000000
# 	Particle Diversity: 0.4564000000000000
# 	Moved Diversity: 0.3395616000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  55
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.4332106258733375
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7568000000000000
# 	Particle Diversity: 0.4644000000000000
# 	Moved Diversity: 0.3514579200000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  56
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.4069388815483490
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7304000000000000
# 	Particle Diversity: 0.4560000000000000
# 	Moved Diversity: 0.3330624000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  57
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.3845247123720670
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7392000000000000
# 	Particle Diversity: 0.4508000000000000
# 	Moved Diversity: 0.3332313600000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  58
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.3636822246774152
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7320000000000000
# 	Particle Diversity: 0.4616000000000000
# 	Moved Diversity: 0.3378912000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  59
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.3376293821625171
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7308000000000000
# 	Particle Diversity: 0.4556000000000000
# 	Moved Diversity: 0.3329524800000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  60
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.3113179631088814
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7296000000000000
# 	Particle Diversity: 0.4696000000000000
# 	Moved Diversity: 0.3426201600000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  61
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.2867350833111364
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7000000000000000
# 	Particle Diversity: 0.4492000000000000
# 	Moved Diversity: 0.3144400000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  62
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.2647179181394910
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7423999999999999
# 	Particle Diversity: 0.4644000000000000
# 	Moved Diversity: 0.3447705599999999
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  63
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.2445416459336518
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7151999999999999
# 	Particle Diversity: 0.4608000000000000
# 	Moved Diversity: 0.3295641599999999
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  64
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.2281437914444806
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7160000000000000
# 	Particle Diversity: 0.4580000000000000
# 	Moved Diversity: 0.3279280000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  65
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.2089003527591013
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7380000000000000
# 	Particle Diversity: 0.4716000000000000
# 	Moved Diversity: 0.3480408000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  66
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.1880538503573606
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7096000000000000
# 	Particle Diversity: 0.4436000000000000
# 	Moved Diversity: 0.3147785600000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  67
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.1726257337294175
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.6992000000000000
# 	Particle Diversity: 0.4536000000000000
# 	Moved Diversity: 0.3171571200000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  68
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.1564078115783989
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.6960000000000000
# 	Particle Diversity: 0.4608000000000000
# 	Moved Diversity: 0.3207168000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  69
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.1403852476886509
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7068000000000000
# 	Particle Diversity: 0.4548000000000000
# 	Moved Diversity: 0.3214526400000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  70
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.1228620927291901
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7036000000000000
# 	Particle Diversity: 0.4552000000000000
# 	Moved Diversity: 0.3202787200000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  71
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.1065659630608660
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7012000000000000
# 	Particle Diversity: 0.4460000000000000
# 	Moved Diversity: 0.3127352000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  72
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.0955912849869642
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7024000000000000
# 	Particle Diversity: 0.4696000000000000
# 	Moved Diversity: 0.3298470400000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  73
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.0823407686874369
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.6908000000000000
# 	Particle Diversity: 0.4552000000000000
# 	Moved Diversity: 0.3144521600000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  74
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.0729956311422011
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.6820000000000001
# 	Particle Diversity: 0.4532000000000000
# 	Moved Diversity: 0.3090824000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  75
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.0641375757240388
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.6716000000000000
# 	Particle Diversity: 0.4664000000000000
# 	Moved Diversity: 0.3132342400000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  76
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.0577037114282817
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.6808000000000000
# 	Particle Diversity: 0.4720000000000000
# 	Moved Diversity: 0.3213375999999999
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  77
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.0514616062446969
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.6780000000000000
# 	Particle Diversity: 0.4776000000000000
# 	Moved Diversity: 0.3238128000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  78
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.0446267639026128
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.6840000000000001
# 	Particle Diversity: 0.4748000000000000
# 	Moved Diversity: 0.3247632000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  79
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.0393745764599847
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.6899999999999999
# 	Particle Diversity: 0.4752000000000000
# 	Moved Diversity: 0.3278880000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  80
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.0328370072694097
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.6792000000000000
# 	Particle Diversity: 0.4700000000000000
# 	Moved Diversity: 0.3192240000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  81
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.0246396613553164
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.6788000000000000
# 	Particle Diversity: 0.4616000000000000
# 	Moved Diversity: 0.3133340800000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  82
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.0156406094741743
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.6916000000000000
# 	Particle Diversity: 0.4636000000000000
# 	Moved Diversity: 0.3206257600000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  83
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.0065932783334519
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.6868000000000000
# 	Particle Diversity: 0.4732000000000000
# 	Moved Diversity: 0.3249937600000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  84
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.9976299705445818
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.6960000000000000
# 	Particle Diversity: 0.4724000000000000
# 	Moved Diversity: 0.3287904000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  85
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.9903059283957694
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.6712000000000000
# 	Particle Diversity: 0.4760000000000000
# 	Moved Diversity: 0.3194912000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  86
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.9830145907045232
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.6952000000000000
# 	Particle Diversity: 0.4792000000000000
# 	Moved Diversity: 0.3331398400000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  87
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.9746384578459861
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.6879999999999999
# 	Particle Diversity: 0.4872000000000000
# 	Moved Diversity: 0.3351936000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  88
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.9647569992501276
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.6964000000000000
# 	Particle Diversity: 0.4704000000000000
# 	Moved Diversity: 0.3275865600000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  89
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.9548540964295111
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.6899999999999999
# 	Particle Diversity: 0.4692000000000000
# 	Moved Diversity: 0.3237480000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  90
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.9461498068097460
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.6556000000000000
# 	Particle Diversity: 0.4712000000000000
# 	Moved Diversity: 0.3089187200000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  91
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.9381640138738366
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.6764000000000000
# 	Particle Diversity: 0.4720000000000000
# 	Moved Diversity: 0.3192608000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  92
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.9301961367252314
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.6812000000000000
# 	Particle Diversity: 0.4716000000000000
# 	Moved Diversity: 0.3212539200000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  93
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.9235744007850661
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.6732000000000000
# 	Particle Diversity: 0.4900000000000000
# 	Moved Diversity: 0.3298680000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  94
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.9171468552019977
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.6908000000000000
# 	Particle Diversity: 0.4704000000000000
# 	Moved Diversity: 0.3249523200000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  95
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.9102801775340273
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.6924000000000000
# 	Particle Diversity: 0.4896000000000000
# 	Moved Diversity: 0.3389990400000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  96
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.9027360325266077
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.6804000000000000
# 	Particle Diversity: 0.4736000000000000
# 	Moved Diversity: 0.3222374400000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  97
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.8948859019450273
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.6684000000000000
# 	Particle Diversity: 0.4720000000000000
# 	Moved Diversity: 0.3154848000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  98
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.8879034244985924
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.6916000000000000
# 	Particle Diversity: 0.4792000000000000
# 	Moved Diversity: 0.3314147200000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  99
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.8808507682986677
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.6788000000000000
# 	Particle Diversity: 0.4712000000000000
# 	Moved Diversity: 0.3198505600000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  100
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.8732288278288864
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.6664000000000000
# 	Particle Diversity: 0.4676000000000000
# 	Moved Diversity: 0.3116086400000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  101
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.8659841919949383
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.6712000000000000
# 	Particle Diversity: 0.4772000000000000
# 	Moved Diversity: 0.3202966400000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  102
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.8593310659831054
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.6716000000000000
# 	Particle Diversity: 0.4832000000000000
# 	Moved Diversity: 0.3245171200000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  103
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.8530795154354019
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.6728000000000000
# 	Particle Diversity: 0.4748000000000000
# 	Moved Diversity: 0.3194454400000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  104
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.8465980941051993
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.6796000000000000
# 	Particle Diversity: 0.4788000000000000
# 	Moved Diversity: 0.3253924800000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  105
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.8401822651608122
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.6919999999999999
# 	Particle Diversity: 0.4760000000000000
# 	Moved Diversity: 0.3293920000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  106
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.8333232249132075
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.6680000000000000
# 	Particle Diversity: 0.4704000000000000
# 	Moved Diversity: 0.3142272000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  107
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.8275849126378341
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.6716000000000000
# 	Particle Diversity: 0.4856000000000000
# 	Moved Diversity: 0.3261289600000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  108
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.8215357692948916
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.6788000000000000
# 	Particle Diversity: 0.4624000000000000
# 	Moved Diversity: 0.3138771200000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  109
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.8147294340790570
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.6692000000000000
# 	Particle Diversity: 0.4772000000000000
# 	Moved Diversity: 0.3193422400000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  110
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.8075158349779878
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.6808000000000000
# 	Particle Diversity: 0.4812000000000000
# 	Moved Diversity: 0.3276009600000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  111
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.8000760982561674
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.6788000000000000
# 	Particle Diversity: 0.4684000000000000
# 	Moved Diversity: 0.3179499200000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  112
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7922611881252331
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.6832000000000000
# 	Particle Diversity: 0.4656000000000000
# 	Moved Diversity: 0.3180979200000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  113
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7832095582050030
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.6664000000000000
# 	Particle Diversity: 0.4616000000000000
# 	Moved Diversity: 0.3076102400000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  114
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7760397958186098
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.6592000000000000
# 	Particle Diversity: 0.4684000000000000
# 	Moved Diversity: 0.3087692800000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  115
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7698533481939773
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.6700000000000000
# 	Particle Diversity: 0.4768000000000000
# 	Moved Diversity: 0.3194560000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  116
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7638125238252312
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.6692000000000000
# 	Particle Diversity: 0.4780000000000000
# 	Moved Diversity: 0.3198776000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  117
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7582988730453657
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.6644000000000000
# 	Particle Diversity: 0.4760000000000000
# 	Moved Diversity: 0.3162544000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  118
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7532526240790167
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.6948000000000000
# 	Particle Diversity: 0.4824000000000000
# 	Moved Diversity: 0.3351715200000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  119
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7484120797341957
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.6804000000000000
# 	Particle Diversity: 0.4720000000000000
# 	Moved Diversity: 0.3211488000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  120
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7430374183611435
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.6568000000000001
# 	Particle Diversity: 0.4752000000000000
# 	Moved Diversity: 0.3121113600000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  121
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7355276787891477
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.6716000000000000
# 	Particle Diversity: 0.4736000000000000
# 	Moved Diversity: 0.3180697600000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  122
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7270694197659231
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.6832000000000000
# 	Particle Diversity: 0.4536000000000000
# 	Moved Diversity: 0.3098995200000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  123
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7204663751832208
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.6516000000000000
# 	Particle Diversity: 0.4628000000000000
# 	Moved Diversity: 0.3015604800000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  124
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7149851326617788
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.6667999999999999
# 	Particle Diversity: 0.4732000000000000
# 	Moved Diversity: 0.3155297600000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  125
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7095096864406623
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.6676000000000000
# 	Particle Diversity: 0.4668000000000000
# 	Moved Diversity: 0.3116356800000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  126
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7045497042512699
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.6700000000000000
# 	Particle Diversity: 0.4736000000000000
# 	Moved Diversity: 0.3173120000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  127
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7001661800069625
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.6904000000000000
# 	Particle Diversity: 0.4844000000000000
# 	Moved Diversity: 0.3344297600000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  128
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.6935681564818432
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.6672000000000000
# 	Particle Diversity: 0.4664000000000000
# 	Moved Diversity: 0.3111820800000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  129
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.6854234695596003
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.6536000000000000
# 	Particle Diversity: 0.4612000000000000
# 	Moved Diversity: 0.3014403200000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  130
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.6799466115198322
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.6672000000000000
# 	Particle Diversity: 0.4688000000000000
# 	Moved Diversity: 0.3127833600000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  131
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.6754436151381376
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.6876000000000000
# 	Particle Diversity: 0.4924000000000000
# 	Moved Diversity: 0.3385742400000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  132
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.6723915017149118
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# ...
# 	Epsilon: 0.1019222507040303
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1624000000000000
# 	Particle Diversity: 0.3976000000000000
# 	Moved Diversity: 0.0645702400000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  526
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.1018574217283901
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1852000000000000
# 	Particle Diversity: 0.3440000000000000
# 	Moved Diversity: 0.0637088000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  527
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.1017880263530879
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1900000000000000
# 	Particle Diversity: 0.3448000000000000
# 	Moved Diversity: 0.0655120000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  528
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.1017052154239603
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1864000000000000
# 	Particle Diversity: 0.3948000000000000
# 	Moved Diversity: 0.0735907200000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  529
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.1015962582590176
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2240000000000000
# 	Particle Diversity: 0.3568000000000000
# 	Moved Diversity: 0.0799232000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  530
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.1015063603595114
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1544000000000000
# 	Particle Diversity: 0.4556000000000000
# 	Moved Diversity: 0.0703446400000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  531
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.1014378177577709
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0924000000000000
# 	Particle Diversity: 0.4348000000000000
# 	Moved Diversity: 0.0401755200000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  532
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.1013853704602740
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0668000000000000
# 	Particle Diversity: 0.4556000000000000
# 	Moved Diversity: 0.0304340800000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  533
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.1013428927136818
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0648000000000000
# 	Particle Diversity: 0.4060000000000000
# 	Moved Diversity: 0.0263088000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  534
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.1013040737790585
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0420000000000000
# 	Particle Diversity: 0.3388000000000000
# 	Moved Diversity: 0.0142296000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  535
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.1012768534375326
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0612000000000000
# 	Particle Diversity: 0.2992000000000000
# 	Moved Diversity: 0.0183110400000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  536
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.1012465276746905
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0372000000000000
# 	Particle Diversity: 0.4164000000000000
# 	Moved Diversity: 0.0154900800000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  537
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.1012146221953990
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0604000000000000
# 	Particle Diversity: 0.2372000000000000
# 	Moved Diversity: 0.0143268800000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  538
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.1011949072085325
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0312000000000000
# 	Particle Diversity: 0.4784000000000000
# 	Moved Diversity: 0.0149260800000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  539
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.1011684445063881
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0324000000000000
# 	Particle Diversity: 0.3760000000000000
# 	Moved Diversity: 0.0121824000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  540
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.1011435623348012
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0640000000000000
# 	Particle Diversity: 0.2108000000000000
# 	Moved Diversity: 0.0134912000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  541
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.1011181629759716
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0368000000000000
# 	Particle Diversity: 0.5416000000000000
# 	Moved Diversity: 0.0199308800000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  542
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.1010850818501680
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0656000000000000
# 	Particle Diversity: 0.1952000000000000
# 	Moved Diversity: 0.0128051200000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  543
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.1010599007884161
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0288000000000000
# 	Particle Diversity: 0.4912000000000000
# 	Moved Diversity: 0.0141465600000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  544
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.1010440930418252
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0136000000000000
# 	Particle Diversity: 0.5900000000000000
# 	Moved Diversity: 0.0080240000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  545
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.1010271437314545
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0436000000000000
# 	Particle Diversity: 0.0820000000000000
# 	Moved Diversity: 0.0035752000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  546
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.1010072230599489
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0336000000000000
# 	Particle Diversity: 0.4972000000000000
# 	Moved Diversity: 0.0167059200000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  547
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.1009763285642562
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0660000000000000
# 	Particle Diversity: 0.1672000000000000
# 	Moved Diversity: 0.0110352000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  548
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.1009521911198926
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0336000000000000
# 	Particle Diversity: 0.3312000000000000
# 	Moved Diversity: 0.0111283200000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  549
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.1009335243350561
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0476000000000000
# 	Particle Diversity: 0.1492000000000000
# 	Moved Diversity: 0.0071019200000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  550
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.1009156001522304
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0216000000000000
# 	Particle Diversity: 0.4188000000000000
# 	Moved Diversity: 0.0090460800000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  551
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.1008982178588314
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0256000000000000
# 	Particle Diversity: 0.2080000000000000
# 	Moved Diversity: 0.0053248000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  552
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.1008854495637148
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0348000000000000
# 	Particle Diversity: 0.4000000000000000
# 	Moved Diversity: 0.0139200000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  553
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.1008555548448826
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0252000000000000
# 	Particle Diversity: 0.5860000000000000
# 	Moved Diversity: 0.0147672000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  554
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.1008346563264407
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1456000000000000
# 	Particle Diversity: 0.0648000000000000
# 	Moved Diversity: 0.0094348800000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  555
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.1008233358947069
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0188000000000000
# 	Particle Diversity: 0.4236000000000000
# 	Moved Diversity: 0.0079636800000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  556
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.1008088286602405
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0152000000000000
# 	Particle Diversity: 0.3560000000000000
# 	Moved Diversity: 0.0054112000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  557
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.1007972282728672
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0052000000000000
# 	Particle Diversity: 0.5552000000000000
# 	Moved Diversity: 0.0028870400000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  558
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.1007890880430024
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0192000000000000
# 	Particle Diversity: 0.1000000000000000
# 	Moved Diversity: 0.0019200000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  559
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.1007768702298571
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0032000000000000
# 	Particle Diversity: 0.3272000000000000
# 	Moved Diversity: 0.0010470400000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  560
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.1007726756529267
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0568000000000000
# 	Particle Diversity: 0.0716000000000000
# 	Moved Diversity: 0.0040668800000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  561
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.1007635826681971
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0116000000000000
# 	Particle Diversity: 0.2528000000000000
# 	Moved Diversity: 0.0029324800000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  562
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.1007496514527900
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0016000000000000
# 	Particle Diversity: 0.5812000000000000
# 	Moved Diversity: 0.0009299200000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  563
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.1007312473644974
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0328000000000000
# 	Particle Diversity: 0.0232000000000000
# 	Moved Diversity: 0.0007609600000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  564
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.1007216153475784
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0112000000000000
# 	Particle Diversity: 0.1232000000000000
# 	Moved Diversity: 0.0013798400000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  565
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.1007183125762136
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0116000000000000
# 	Particle Diversity: 0.1464000000000000
# 	Moved Diversity: 0.0016982400000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  566
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.1007101848950378
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0016000000000000
# 	Particle Diversity: 0.6100000000000000
# 	Moved Diversity: 0.0009760000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  567
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.1007038425705291
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0008000000000000
# 	Particle Diversity: 0.6256000000000000
# 	Moved Diversity: 0.0005004800000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  568
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.1007000712054557
# 	Weights computed and normalized.
# 	SMC Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0000000000000000
# 	Particle Diversity: 0.6328000000000000
# 	Moved Diversity: 0.0000000000000000
# 	Step-size kept fixed at: 0.0100000000000000

# %%
with open("experiment94/B20N2k_HAN_01_ess.pkl", "wb") as file:
    pickle.dump(B20N2k_HAN_01.ESS, file)
    
with open("experiment94/B20N2k_HAN_01_ess_smc.pkl", "wb") as file:
    pickle.dump(B20N2k_HAN_01.ESS_SMC, file)
    
with open("experiment94/B20N2k_HAN_01_epsilons.pkl", "wb") as file:
    pickle.dump(B20N2k_HAN_01.εs, file)
    
with open("experiment94/B20N2k_HAN_01_pm.pkl", "wb") as file:
    pickle.dump(B20N2k_HAN_01.PROP_MOVED, file)
    
with open("experiment94/B20N2k_HAN_01_pd.pkl", "wb") as file:
    pickle.dump(B20N2k_HAN_01.P_DIVERSITY, file)
    
with open("experiment94/B20N2k_HAN_01_dm.pkl", "wb") as file:
    pickle.dump(B20N2k_HAN_01.DIV_MOVED, file)
    
with open("experiment94/B20N2k_HAN_01_K_RESAMPLED.pkl", "wb") as file:
    pickle.dump(B20N2k_HAN_01.K_RESAMPLED, file)
    
with open("experiment94/B20N2k_HAN_01_N_RESAMPLED.pkl", "wb") as file:
    pickle.dump(B20N2k_HAN_01.N_RESAMPLED, file)

# %%
send_notification_to_iphone("Fourth core finished: B=20, N=2500, PH=0.1")

# %% [markdown]
# Plot the version with $B=20$

# %%
# for reference MS-RWM
with open("experiment93/B20N2500_epsilons.pkl", "rb") as file:
    B20N2500_EPSILONS = pickle.load(file)

with open("experiment93/B20N2500_pm.pkl", "rb") as file:
        B20N2500_PM = pickle.load(file)

# PH=0.5
with open("experiment94/B20N2k_HAN_05_epsilons.pkl", "rb") as file:
    B20N2k_HAN_05_EPSILONS = pickle.load(file)
    
with open("experiment94/B20N2k_HAN_05_pm.pkl", "rb") as file:
    B20N2k_HAN_05_PM = pickle.load(file)
    
# PH=0.3
with open("experiment94/B20N2k_HAN_03_epsilons.pkl", "rb") as file:
    B20N2k_HAN_03_EPSILONS = pickle.load(file)
    
with open("experiment94/B20N2k_HAN_03_pm.pkl", "rb") as file:
    B20N2k_HAN_03_PM = pickle.load(file)

# %%
rc('font',**{'family':'STIXGeneral'})
fig, ax = plt.subplots(figsize=(16, 6), ncols=2)
# EPSILON / ITERATION
# ax.plot(B10N5k_HAN.εs, label='phug'+ r'$\mathregular{=0.5}$', color='lightsalmon', lw=3)
ax[0].plot(B20N2k_HAN_05_EPSILONS, label=r'$\mathregular{p_{hug}}$' + r'$\mathregular{=0.5}$', color='mediumvioletred', lw=3)
ax[0].plot(B20N2k_HAN_03_EPSILONS, label=r'$\mathregular{p_{hug}}$' + r'$\mathregular{=0.3}$', color='lightseagreen', lw=3)
ax[0].plot(B20N2k_HAN_01.εs, label=r'$\mathregular{p_{hug}}$' + r'$\mathregular{=0.1}$', color='yellowgreen', lw=3)
ax[0].plot(B20N2500_EPSILONS, label='MS-RWM ', color='lightsalmon', lw=3)
ax[0].set_xlabel("Iteration", fontsize=20)
ax[0].set_ylabel(r"$\mathregular{\epsilon}$", fontsize=20)
ax[0].tick_params(labelsize=15)
ax[0].legend(fontsize=20)
ax[0].set_yscale('log')
ax[0].grid(True, color='lightgray')
# PROP-MOVED / EPSILON
ax[1].plot(B20N2k_HAN_05_EPSILONS[:-1], B20N2k_HAN_05_PM[1:], label=r'$\mathregular{p_{hug}}$' + r'$\mathregular{=0.5}$', color='mediumvioletred', lw=3)
ax[1].plot(B20N2k_HAN_03_EPSILONS[:-1], B20N2k_HAN_03_PM[1:], label=r'$\mathregular{p_{hug}}$' + r'$\mathregular{=0.3}$', color='lightseagreen', lw=3)
ax[1].plot(B20N2k_HAN_01.εs[:-1], B20N2k_HAN_01.PROP_MOVED[1:], label=r'$\mathregular{p_{hug}}$' + r'$\mathregular{=0.1}$', color='yellowgreen', lw=3)
ax[1].plot(B20N2500_EPSILONS[:-1], B20N2500_PM[1:], label='MS-RWM ', color='lightsalmon', lw=3)
ax[1].set_ylabel("Proportion of particles moved", fontsize=20)
ax[1].set_xlabel(r"$\mathregular{\epsilon}$", fontsize=20)
ax[1].tick_params(labelsize=15)
ax[1].legend(fontsize=20)
ax[1].set_xscale('log')
ax[1].grid(True, color='lightgray')
# plt.savefig("figures/gk20_epsilons_and_pm_mshan_b20.png")
plt.show()
