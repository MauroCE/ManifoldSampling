# %% [markdown]
# # On G and K model

# %%
import numpy as np
from numpy import exp, log, zeros, eye
from numpy.linalg import norm
from numpy.random import uniform, randn, choice
from scipy.stats import norm as ndist
from warnings import catch_warnings, filterwarnings
from scipy.optimize import fsolve

from smc_thug import SMCTHUG, computational_cost
from g_and_k_functions import fnorm, fnorm_broadcast, logprior
from g_and_k_functions import data_generator, grad_fnorm, sample_prior
from g_and_k_functions import log_epanechnikov_kernel, new_point

# %%
# Settings for G and K model
n_latents = 20
seed = 1234
theta0 = np.array([3.0, 1.0, 2.0, 0.5])
n_params = len(theta0)
d = n_latents + n_params

# Generate Data
y_star = data_generator(theta0, n_latents, seed)

# %%
N = 5000
B = 5

smc = SMCTHUG(
    N=N,
    d=d,
    ystar=y_star,
    logprior=logprior,
    ϵmin=0.2,
    pmin=0.2,
    pter=0.01,
    mcmc_iter=B,
    δ0=0.04,
    minstep=0.1/B,
    maxstep=1.0/B,
    manual_initialization=False,
    iterscheme='fixed',
    maxiter=200,
    B=B,
    maxMCMC=10,
    precondition=False
)

smc.sample_prior = lambda: sample_prior(n_params, n_latents)
smc.h = fnorm
smc.h_broadcast = fnorm_broadcast
smc.grad_h = lambda ξ: grad_fnorm(ξ, y_star)
smc.get_γ = lambda i: 0.0 #i**(-1/2)    # Set it to be constant.
# Out:
# ### Stopping Criterion: Minimum Tolerance 0.2

# %%
out = smc.sample()
# Out:
# ### Particles have been initialized from the prior.
#
# ### SMC step:  1
# ϵ = 65968707.985	 N unique starting: 3136
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.5970
# Stepsize used in next SMC iteration: 0.0488
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  2
# ϵ = 5132944.445	 N unique starting: 2880
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.5276
# Stepsize used in next SMC iteration: 0.0575
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  3
# ϵ = 1159902.275	 N unique starting: 2808
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.4856
# Stepsize used in next SMC iteration: 0.0663
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  4
# ϵ = 397372.393	 N unique starting: 2746
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.4408
# Stepsize used in next SMC iteration: 0.0748
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  5
# ϵ = 108107.852	 N unique starting: 2706
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.3920
# Stepsize used in next SMC iteration: 0.0823
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  6
# ϵ = 39376.123	 N unique starting: 2599
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.3542
# Stepsize used in next SMC iteration: 0.0889
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  7
# ϵ = 17783.723	 N unique starting: 2493
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.3258
# Stepsize used in next SMC iteration: 0.0947
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  8
# ϵ = 8808.469	 N unique starting: 2413
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.2998
# Stepsize used in next SMC iteration: 0.0995
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  9
# ϵ = 5109.661	 N unique starting: 2332
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.2746
# Stepsize used in next SMC iteration: 0.1033
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  10
# ϵ = 2904.948	 N unique starting: 2287
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.2576
# Stepsize used in next SMC iteration: 0.1063
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  11
# ϵ = 1719.313	 N unique starting: 2192
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.2510
# Stepsize used in next SMC iteration: 0.1091
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  12
# ϵ = 998.456	 N unique starting: 2145
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.2330
# Stepsize used in next SMC iteration: 0.1109
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  13
# ϵ = 635.366	 N unique starting: 2102
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.2136
# Stepsize used in next SMC iteration: 0.1116
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  14
# ϵ = 423.784	 N unique starting: 2027
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.2266
# Stepsize used in next SMC iteration: 0.1131
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  15
# ϵ = 303.801	 N unique starting: 2022
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.2128
# Stepsize used in next SMC iteration: 0.1138
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  16
# ϵ = 238.358	 N unique starting: 2000
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1950
# Stepsize used in next SMC iteration: 0.1136
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  17
# ϵ = 189.114	 N unique starting: 1945
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.2026
# Stepsize used in next SMC iteration: 0.1137
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  18
# ϵ = 133.812	 N unique starting: 1935
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1922
# Stepsize used in next SMC iteration: 0.1133
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  19
# ϵ = 116.128	 N unique starting: 1934
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.2028
# Stepsize used in next SMC iteration: 0.1134
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  20
# ϵ = 93.137	 N unique starting: 1937
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1968
# Stepsize used in next SMC iteration: 0.1132
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  21
# ϵ = 81.097	 N unique starting: 1901
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1986
# Stepsize used in next SMC iteration: 0.1132
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  22
# ϵ = 74.593	 N unique starting: 1894
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1866
# Stepsize used in next SMC iteration: 0.1124
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  23
# ϵ = 65.206	 N unique starting: 1854
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1862
# Stepsize used in next SMC iteration: 0.1116
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  24
# ϵ = 56.764	 N unique starting: 1825
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1814
# Stepsize used in next SMC iteration: 0.1106
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  25
# ϵ = 54.826	 N unique starting: 1824
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1772
# Stepsize used in next SMC iteration: 0.1094
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  26
# ϵ = 50.437	 N unique starting: 1819
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1828
# Stepsize used in next SMC iteration: 0.1084
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  27
# ϵ = 44.199	 N unique starting: 1811
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1830
# Stepsize used in next SMC iteration: 0.1075
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  28
# ϵ = 41.996	 N unique starting: 1854
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1870
# Stepsize used in next SMC iteration: 0.1068
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  29
# ϵ = 41.472	 N unique starting: 1849
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1880
# Stepsize used in next SMC iteration: 0.1062
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  30
# ϵ = 36.197	 N unique starting: 1866
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1792
# Stepsize used in next SMC iteration: 0.1051
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  31
# ϵ = 34.498	 N unique starting: 1830
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1896
# Stepsize used in next SMC iteration: 0.1045
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  32
# ϵ = 31.386	 N unique starting: 1826
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1850
# Stepsize used in next SMC iteration: 0.1037
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  33
# ϵ = 30.864	 N unique starting: 1831
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1892
# Stepsize used in next SMC iteration: 0.1032
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  34
# ϵ = 27.988	 N unique starting: 1802
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1888
# Stepsize used in next SMC iteration: 0.1026
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  35
# ϵ = 24.979	 N unique starting: 1806
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1944
# Stepsize used in next SMC iteration: 0.1023
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  36
# ϵ = 24.524	 N unique starting: 1804
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1878
# Stepsize used in next SMC iteration: 0.1017
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  37
# ϵ = 23.928	 N unique starting: 1808
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1800
# Stepsize used in next SMC iteration: 0.1007
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  38
# ϵ = 21.972	 N unique starting: 1811
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1814
# Stepsize used in next SMC iteration: 0.0998
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  39
# ϵ = 21.780	 N unique starting: 1782
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1928
# Stepsize used in next SMC iteration: 0.0994
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  40
# ϵ = 21.404	 N unique starting: 1824
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1920
# Stepsize used in next SMC iteration: 0.0990
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  41
# ϵ = 20.607	 N unique starting: 1797
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1864
# Stepsize used in next SMC iteration: 0.0983
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  42
# ϵ = 20.107	 N unique starting: 1816
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1942
# Stepsize used in next SMC iteration: 0.0980
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  43
# ϵ = 19.948	 N unique starting: 1836
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1746
# Stepsize used in next SMC iteration: 0.0968
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  44
# ϵ = 19.922	 N unique starting: 1834
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1808
# Stepsize used in next SMC iteration: 0.0959
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  45
# ϵ = 19.860	 N unique starting: 1821
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.2006
# Stepsize used in next SMC iteration: 0.0959
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  46
# ϵ = 19.434	 N unique starting: 1842
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.2050
# Stepsize used in next SMC iteration: 0.0961
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  47
# ϵ = 19.132	 N unique starting: 1891
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1846
# Stepsize used in next SMC iteration: 0.0954
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  48
# ϵ = 18.687	 N unique starting: 1871
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1882
# Stepsize used in next SMC iteration: 0.0948
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  49
# ϵ = 17.761	 N unique starting: 1864
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1876
# Stepsize used in next SMC iteration: 0.0943
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  50
# ϵ = 17.633	 N unique starting: 1848
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.2004
# Stepsize used in next SMC iteration: 0.0943
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  51
# ϵ = 17.607	 N unique starting: 1892
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1970
# Stepsize used in next SMC iteration: 0.0941
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  52
# ϵ = 17.578	 N unique starting: 1902
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.2056
# Stepsize used in next SMC iteration: 0.0944
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  53
# ϵ = 17.497	 N unique starting: 1896
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.2038
# Stepsize used in next SMC iteration: 0.0946
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  54
# ϵ = 17.380	 N unique starting: 1893
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1930
# Stepsize used in next SMC iteration: 0.0943
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  55
# ϵ = 17.280	 N unique starting: 1904
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1974
# Stepsize used in next SMC iteration: 0.0941
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  56
# ϵ = 17.190	 N unique starting: 1918
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.2008
# Stepsize used in next SMC iteration: 0.0942
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  57
# ϵ = 16.944	 N unique starting: 1940
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.2094
# Stepsize used in next SMC iteration: 0.0946
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  58
# ϵ = 16.770	 N unique starting: 1927
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.2058
# Stepsize used in next SMC iteration: 0.0949
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  59
# ϵ = 16.667	 N unique starting: 1905
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.2044
# Stepsize used in next SMC iteration: 0.0951
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  60
# ϵ = 16.548	 N unique starting: 1936
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1982
# Stepsize used in next SMC iteration: 0.0950
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  61
# ϵ = 16.452	 N unique starting: 1921
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.2020
# Stepsize used in next SMC iteration: 0.0951
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  62
# ϵ = 16.295	 N unique starting: 1907
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.2124
# Stepsize used in next SMC iteration: 0.0957
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  63
# ϵ = 16.155	 N unique starting: 1910
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.2058
# Stepsize used in next SMC iteration: 0.0960
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  64
# ϵ = 16.028	 N unique starting: 1929
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.2064
# Stepsize used in next SMC iteration: 0.0963
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  65
# ϵ = 15.959	 N unique starting: 1935
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1978
# Stepsize used in next SMC iteration: 0.0962
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  66
# ϵ = 15.922	 N unique starting: 1903
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1920
# Stepsize used in next SMC iteration: 0.0958
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  67
# ϵ = 15.898	 N unique starting: 1873
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.2080
# Stepsize used in next SMC iteration: 0.0962
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  68
# ϵ = 15.869	 N unique starting: 1901
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.2168
# Stepsize used in next SMC iteration: 0.0970
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  69
# ϵ = 15.838	 N unique starting: 2015
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.2284
# Stepsize used in next SMC iteration: 0.0984
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  70
# ϵ = 15.799	 N unique starting: 2060
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.2212
# Stepsize used in next SMC iteration: 0.0994
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  71
# ϵ = 15.764	 N unique starting: 2045
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.2174
# Stepsize used in next SMC iteration: 0.1003
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  72
# ϵ = 15.726	 N unique starting: 2041
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.2128
# Stepsize used in next SMC iteration: 0.1009
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  73
# ϵ = 15.667	 N unique starting: 2030
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.2178
# Stepsize used in next SMC iteration: 0.1018
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  74
# ϵ = 15.605	 N unique starting: 2036
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.2192
# Stepsize used in next SMC iteration: 0.1028
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  75
# ϵ = 15.520	 N unique starting: 2032
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.2100
# Stepsize used in next SMC iteration: 0.1033
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  76
# ϵ = 15.434	 N unique starting: 2002
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.2052
# Stepsize used in next SMC iteration: 0.1036
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  77
# ϵ = 15.362	 N unique starting: 1951
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.2088
# Stepsize used in next SMC iteration: 0.1041
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  78
# ϵ = 15.249	 N unique starting: 1980
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.2072
# Stepsize used in next SMC iteration: 0.1044
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  79
# ϵ = 15.112	 N unique starting: 1969
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.2086
# Stepsize used in next SMC iteration: 0.1049
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  80
# ϵ = 14.952	 N unique starting: 1929
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.2006
# Stepsize used in next SMC iteration: 0.1049
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  81
# ϵ = 14.781	 N unique starting: 1900
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.2094
# Stepsize used in next SMC iteration: 0.1054
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  82
# ϵ = 14.599	 N unique starting: 1931
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.2052
# Stepsize used in next SMC iteration: 0.1057
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  83
# ϵ = 14.450	 N unique starting: 1953
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.2026
# Stepsize used in next SMC iteration: 0.1058
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  84
# ϵ = 14.288	 N unique starting: 1936
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1984
# Stepsize used in next SMC iteration: 0.1057
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  85
# ϵ = 14.103	 N unique starting: 1925
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1964
# Stepsize used in next SMC iteration: 0.1055
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  86
# ϵ = 13.930	 N unique starting: 1899
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.2052
# Stepsize used in next SMC iteration: 0.1058
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  87
# ϵ = 13.735	 N unique starting: 1922
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.2004
# Stepsize used in next SMC iteration: 0.1058
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  88
# ϵ = 13.569	 N unique starting: 1910
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1956
# Stepsize used in next SMC iteration: 0.1056
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  89
# ϵ = 13.367	 N unique starting: 1866
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1902
# Stepsize used in next SMC iteration: 0.1051
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  90
# ϵ = 13.170	 N unique starting: 1875
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1900
# Stepsize used in next SMC iteration: 0.1046
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  91
# ϵ = 12.964	 N unique starting: 1824
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1922
# Stepsize used in next SMC iteration: 0.1042
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  92
# ϵ = 12.796	 N unique starting: 1827
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1854
# Stepsize used in next SMC iteration: 0.1034
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  93
# ϵ = 12.616	 N unique starting: 1798
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1896
# Stepsize used in next SMC iteration: 0.1029
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  94
# ϵ = 12.377	 N unique starting: 1799
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1762
# Stepsize used in next SMC iteration: 0.1017
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  95
# ϵ = 12.152	 N unique starting: 1732
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1838
# Stepsize used in next SMC iteration: 0.1008
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  96
# ϵ = 11.920	 N unique starting: 1696
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1782
# Stepsize used in next SMC iteration: 0.0997
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  97
# ϵ = 11.662	 N unique starting: 1679
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1658
# Stepsize used in next SMC iteration: 0.0981
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  98
# ϵ = 11.379	 N unique starting: 1656
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1746
# Stepsize used in next SMC iteration: 0.0968
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  99
# ϵ = 11.114	 N unique starting: 1657
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1784
# Stepsize used in next SMC iteration: 0.0958
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  100
# ϵ = 10.885	 N unique starting: 1692
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1746
# Stepsize used in next SMC iteration: 0.0946
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  101
# ϵ = 10.647	 N unique starting: 1654
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1844
# Stepsize used in next SMC iteration: 0.0938
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  102
# ϵ = 10.446	 N unique starting: 1674
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1616
# Stepsize used in next SMC iteration: 0.0920
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  103
# ϵ = 10.252	 N unique starting: 1649
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1716
# Stepsize used in next SMC iteration: 0.0907
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  104
# ϵ = 10.047	 N unique starting: 1642
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1658
# Stepsize used in next SMC iteration: 0.0892
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  105
# ϵ = 9.889	 N unique starting: 1629
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1758
# Stepsize used in next SMC iteration: 0.0881
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  106
# ϵ = 9.723	 N unique starting: 1684
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1844
# Stepsize used in next SMC iteration: 0.0875
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  107
# ϵ = 9.550	 N unique starting: 1707
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1860
# Stepsize used in next SMC iteration: 0.0868
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  108
# ϵ = 9.379	 N unique starting: 1739
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1806
# Stepsize used in next SMC iteration: 0.0860
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  109
# ϵ = 9.223	 N unique starting: 1727
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1774
# Stepsize used in next SMC iteration: 0.0850
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  110
# ϵ = 9.092	 N unique starting: 1723
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1780
# Stepsize used in next SMC iteration: 0.0841
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  111
# ϵ = 8.942	 N unique starting: 1699
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1810
# Stepsize used in next SMC iteration: 0.0833
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  112
# ϵ = 8.807	 N unique starting: 1697
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1824
# Stepsize used in next SMC iteration: 0.0826
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  113
# ϵ = 8.678	 N unique starting: 1711
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1706
# Stepsize used in next SMC iteration: 0.0814
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  114
# ϵ = 8.551	 N unique starting: 1644
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1784
# Stepsize used in next SMC iteration: 0.0805
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  115
# ϵ = 8.422	 N unique starting: 1697
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1956
# Stepsize used in next SMC iteration: 0.0803
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  116
# ϵ = 8.314	 N unique starting: 1731
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1826
# Stepsize used in next SMC iteration: 0.0796
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  117
# ϵ = 8.213	 N unique starting: 1747
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1856
# Stepsize used in next SMC iteration: 0.0791
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  118
# ϵ = 8.119	 N unique starting: 1735
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1920
# Stepsize used in next SMC iteration: 0.0787
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  119
# ϵ = 8.021	 N unique starting: 1760
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1984
# Stepsize used in next SMC iteration: 0.0787
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  120
# ϵ = 7.912	 N unique starting: 1752
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1908
# Stepsize used in next SMC iteration: 0.0783
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  121
# ϵ = 7.809	 N unique starting: 1716
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1850
# Stepsize used in next SMC iteration: 0.0777
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  122
# ϵ = 7.709	 N unique starting: 1686
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1870
# Stepsize used in next SMC iteration: 0.0772
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  123
# ϵ = 7.623	 N unique starting: 1715
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1984
# Stepsize used in next SMC iteration: 0.0772
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  124
# ϵ = 7.508	 N unique starting: 1766
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.2006
# Stepsize used in next SMC iteration: 0.0772
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  125
# ϵ = 7.393	 N unique starting: 1822
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1896
# Stepsize used in next SMC iteration: 0.0768
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  126
# ϵ = 7.277	 N unique starting: 1781
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1974
# Stepsize used in next SMC iteration: 0.0767
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  127
# ϵ = 7.153	 N unique starting: 1768
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1968
# Stepsize used in next SMC iteration: 0.0766
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  128
# ϵ = 7.033	 N unique starting: 1763
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1966
# Stepsize used in next SMC iteration: 0.0764
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  129
# ϵ = 6.905	 N unique starting: 1800
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1790
# Stepsize used in next SMC iteration: 0.0756
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  130
# ϵ = 6.802	 N unique starting: 1715
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1832
# Stepsize used in next SMC iteration: 0.0750
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  131
# ϵ = 6.688	 N unique starting: 1696
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1794
# Stepsize used in next SMC iteration: 0.0742
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  132
# ϵ = 6.573	 N unique starting: 1682
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1680
# Stepsize used in next SMC iteration: 0.0731
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  133
# ϵ = 6.469	 N unique starting: 1615
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1804
# Stepsize used in next SMC iteration: 0.0723
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  134
# ϵ = 6.375	 N unique starting: 1610
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1816
# Stepsize used in next SMC iteration: 0.0717
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  135
# ϵ = 6.283	 N unique starting: 1659
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1818
# Stepsize used in next SMC iteration: 0.0710
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  136
# ϵ = 6.192	 N unique starting: 1666
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1704
# Stepsize used in next SMC iteration: 0.0700
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  137
# ϵ = 6.098	 N unique starting: 1616
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1786
# Stepsize used in next SMC iteration: 0.0692
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  138
# ϵ = 6.015	 N unique starting: 1659
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1718
# Stepsize used in next SMC iteration: 0.0683
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  139
# ϵ = 5.938	 N unique starting: 1666
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1798
# Stepsize used in next SMC iteration: 0.0676
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  140
# ϵ = 5.859	 N unique starting: 1677
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1754
# Stepsize used in next SMC iteration: 0.0668
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  141
# ϵ = 5.781	 N unique starting: 1660
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1914
# Stepsize used in next SMC iteration: 0.0665
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  142
# ϵ = 5.708	 N unique starting: 1658
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1666
# Stepsize used in next SMC iteration: 0.0654
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  143
# ϵ = 5.631	 N unique starting: 1680
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1996
# Stepsize used in next SMC iteration: 0.0654
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  144
# ϵ = 5.560	 N unique starting: 1723
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1946
# Stepsize used in next SMC iteration: 0.0652
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  145
# ϵ = 5.494	 N unique starting: 1727
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1956
# Stepsize used in next SMC iteration: 0.0650
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  146
# ϵ = 5.431	 N unique starting: 1681
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1768
# Stepsize used in next SMC iteration: 0.0643
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  147
# ϵ = 5.355	 N unique starting: 1665
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1910
# Stepsize used in next SMC iteration: 0.0640
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  148
# ϵ = 5.285	 N unique starting: 1674
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1960
# Stepsize used in next SMC iteration: 0.0639
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  149
# ϵ = 5.217	 N unique starting: 1713
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1962
# Stepsize used in next SMC iteration: 0.0638
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  150
# ϵ = 5.144	 N unique starting: 1701
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.2030
# Stepsize used in next SMC iteration: 0.0639
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  151
# ϵ = 5.072	 N unique starting: 1741
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1932
# Stepsize used in next SMC iteration: 0.0636
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  152
# ϵ = 5.009	 N unique starting: 1744
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1880
# Stepsize used in next SMC iteration: 0.0633
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  153
# ϵ = 4.943	 N unique starting: 1762
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1988
# Stepsize used in next SMC iteration: 0.0632
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  154
# ϵ = 4.878	 N unique starting: 1819
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1980
# Stepsize used in next SMC iteration: 0.0632
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  155
# ϵ = 4.820	 N unique starting: 1844
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1972
# Stepsize used in next SMC iteration: 0.0631
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  156
# ϵ = 4.752	 N unique starting: 1803
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1934
# Stepsize used in next SMC iteration: 0.0629
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  157
# ϵ = 4.693	 N unique starting: 1765
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1918
# Stepsize used in next SMC iteration: 0.0626
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  158
# ϵ = 4.638	 N unique starting: 1771
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1910
# Stepsize used in next SMC iteration: 0.0623
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  159
# ϵ = 4.579	 N unique starting: 1761
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1996
# Stepsize used in next SMC iteration: 0.0623
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  160
# ϵ = 4.523	 N unique starting: 1801
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1846
# Stepsize used in next SMC iteration: 0.0618
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  161
# ϵ = 4.467	 N unique starting: 1793
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1876
# Stepsize used in next SMC iteration: 0.0614
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  162
# ϵ = 4.413	 N unique starting: 1781
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1814
# Stepsize used in next SMC iteration: 0.0609
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  163
# ϵ = 4.353	 N unique starting: 1753
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1966
# Stepsize used in next SMC iteration: 0.0608
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  164
# ϵ = 4.299	 N unique starting: 1798
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1774
# Stepsize used in next SMC iteration: 0.0601
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  165
# ϵ = 4.243	 N unique starting: 1764
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1808
# Stepsize used in next SMC iteration: 0.0595
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  166
# ϵ = 4.192	 N unique starting: 1743
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1720
# Stepsize used in next SMC iteration: 0.0587
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  167
# ϵ = 4.145	 N unique starting: 1697
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1930
# Stepsize used in next SMC iteration: 0.0585
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  168
# ϵ = 4.099	 N unique starting: 1741
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1876
# Stepsize used in next SMC iteration: 0.0581
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  169
# ϵ = 4.051	 N unique starting: 1776
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1958
# Stepsize used in next SMC iteration: 0.0580
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  170
# ϵ = 4.000	 N unique starting: 1871
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1884
# Stepsize used in next SMC iteration: 0.0577
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  171
# ϵ = 3.945	 N unique starting: 1846
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.2020
# Stepsize used in next SMC iteration: 0.0577
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  172
# ϵ = 3.904	 N unique starting: 1848
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1882
# Stepsize used in next SMC iteration: 0.0574
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  173
# ϵ = 3.860	 N unique starting: 1871
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1976
# Stepsize used in next SMC iteration: 0.0573
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  174
# ϵ = 3.813	 N unique starting: 1824
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1858
# Stepsize used in next SMC iteration: 0.0569
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  175
# ϵ = 3.766	 N unique starting: 1821
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1794
# Stepsize used in next SMC iteration: 0.0563
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  176
# ϵ = 3.726	 N unique starting: 1778
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1806
# Stepsize used in next SMC iteration: 0.0558
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  177
# ϵ = 3.682	 N unique starting: 1767
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1902
# Stepsize used in next SMC iteration: 0.0555
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  178
# ϵ = 3.641	 N unique starting: 1790
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1760
# Stepsize used in next SMC iteration: 0.0548
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  179
# ϵ = 3.602	 N unique starting: 1738
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1744
# Stepsize used in next SMC iteration: 0.0542
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  180
# ϵ = 3.567	 N unique starting: 1730
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1680
# Stepsize used in next SMC iteration: 0.0533
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  181
# ϵ = 3.533	 N unique starting: 1704
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1828
# Stepsize used in next SMC iteration: 0.0528
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  182
# ϵ = 3.500	 N unique starting: 1708
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1798
# Stepsize used in next SMC iteration: 0.0523
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  183
# ϵ = 3.462	 N unique starting: 1720
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1834
# Stepsize used in next SMC iteration: 0.0519
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  184
# ϵ = 3.428	 N unique starting: 1726
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1932
# Stepsize used in next SMC iteration: 0.0517
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  185
# ϵ = 3.390	 N unique starting: 1768
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1994
# Stepsize used in next SMC iteration: 0.0517
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  186
# ϵ = 3.357	 N unique starting: 1794
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1944
# Stepsize used in next SMC iteration: 0.0515
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  187
# ϵ = 3.324	 N unique starting: 1810
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1886
# Stepsize used in next SMC iteration: 0.0512
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  188
# ϵ = 3.283	 N unique starting: 1783
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1826
# Stepsize used in next SMC iteration: 0.0508
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  189
# ϵ = 3.246	 N unique starting: 1762
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1822
# Stepsize used in next SMC iteration: 0.0503
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  190
# ϵ = 3.204	 N unique starting: 1763
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1850
# Stepsize used in next SMC iteration: 0.0500
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  191
# ϵ = 3.165	 N unique starting: 1782
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1748
# Stepsize used in next SMC iteration: 0.0493
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  192
# ϵ = 3.121	 N unique starting: 1736
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1802
# Stepsize used in next SMC iteration: 0.0489
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  193
# ϵ = 3.088	 N unique starting: 1702
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1726
# Stepsize used in next SMC iteration: 0.0482
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  194
# ϵ = 3.056	 N unique starting: 1690
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1746
# Stepsize used in next SMC iteration: 0.0476
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  195
# ϵ = 3.024	 N unique starting: 1695
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1710
# Stepsize used in next SMC iteration: 0.0469
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  196
# ϵ = 2.993	 N unique starting: 1710
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1822
# Stepsize used in next SMC iteration: 0.0465
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  197
# ϵ = 2.959	 N unique starting: 1741
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1804
# Stepsize used in next SMC iteration: 0.0460
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  198
# ϵ = 2.925	 N unique starting: 1718
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1860
# Stepsize used in next SMC iteration: 0.0457
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  199
# ϵ = 2.894	 N unique starting: 1756
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1840
# Stepsize used in next SMC iteration: 0.0453
# Alpha used in next SMC iteration: 0.0100
#
# ### SMC step:  200
# ϵ = 2.863	 N unique starting: 1739
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1858
# Stepsize used in next SMC iteration: 0.0450
# Alpha used in next SMC iteration: 0.0100

# %% [markdown]
# # HUG-SMC on Approximate Lifted Distribution (BIP)

# %% [markdown]
# Deterministic Function $F_L:\mathbb{R}^3\to\mathbb{R}$
# $$
# F_L(\xi) = F_L(\theta, \eta) = F(\theta) + \sigma\eta \qquad \sigma > 0
# $$
# where $F:\mathbb{R}^2\to\mathbb{R}$ is given by

# %%
# functions for approximate lifted BIP posterior 
from bip_functions import F, FL, logpriorL, log_epanechnikov_kernelL
from bip_functions import log_posteriorL, grad_FL, FL_broadcast, sample_priorL
from smc_thug import SMCTHUG

from numpy import errstate, log, ones, zeros
from numpy.linalg import norm
import matplotlib.pyplot as plt

# %%
N = 5000
B = 5
σ = 1e-8
y_bip = 1
d_bip = 3

# %%
smc_bip = SMCTHUG(
    N=N,
    d=d_bip,
    ystar=y_bip,
    logprior=logpriorL,
    ϵmin=1e-10,
    pmin=0.3,
    pter=0.01,
    mcmc_iter=B,
    δ0=0.04,
    minstep=0.001,
    maxstep=0.5,
    manual_initialization=False,
    iterscheme='fixed',
    maxiter=200,
    B=B,
    maxMCMC=10,
    precondition=False
)
# Out:
# ### Stopping Criterion: Minimum Tolerance 1e-10
# ### MCMC kernel: HUG.

# %%
smc_bip.h = lambda ξ, ystar: norm(FL(ξ, σ) - ystar)
smc_bip.h_broadcast = lambda ξ, ystar: abs(FL_broadcast(ξ, σ) - ystar)
smc_bip.grad_h = lambda ξ: grad_FL(ξ, σ) * (FL(ξ, σ) - y_bip)
smc_bip.sample_prior = sample_priorL
smc_bip.get_γ = lambda i: i**(-1/20)    # Set it to be constant.

# %%
out_bip = smc_bip.sample()
# Out:
# ### Particles have been initialized from the prior.
#
# ### SMC step:  1
# ϵ = 15.1503500000	 N unique starting: 3142
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.8208
# Stepsize used in next SMC iteration: 0.0519
# Alpha used in next SMC iteration: 0.0060
#
# ### SMC step:  2
# ϵ = 4.5465600000	 N unique starting: 2965
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.8034
# Stepsize used in next SMC iteration: 0.0668
# Alpha used in next SMC iteration: 0.0037
#
# ### SMC step:  3
# ϵ = 2.1489900000	 N unique starting: 2997
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.7828
# Stepsize used in next SMC iteration: 0.0850
# Alpha used in next SMC iteration: 0.0023
#
# ### SMC step:  4
# ϵ = 1.6268100000	 N unique starting: 3002
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.7476
# Stepsize used in next SMC iteration: 0.1063
# Alpha used in next SMC iteration: 0.0015
#
# ### SMC step:  5
# ϵ = 1.4712300000	 N unique starting: 3004
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.7162
# Stepsize used in next SMC iteration: 0.1309
# Alpha used in next SMC iteration: 0.0010
#
# ### SMC step:  6
# ϵ = 1.3350600000	 N unique starting: 3050
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.6860
# Stepsize used in next SMC iteration: 0.1587
# Alpha used in next SMC iteration: 0.0007
#
# ### SMC step:  7
# ϵ = 1.1833900000	 N unique starting: 3001
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.6326
# Stepsize used in next SMC iteration: 0.1875
# Alpha used in next SMC iteration: 0.0005
#
# ### SMC step:  8
# ϵ = 1.0631800000	 N unique starting: 2972
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.6008
# Stepsize used in next SMC iteration: 0.2179
# Alpha used in next SMC iteration: 0.0004
#
# ### SMC step:  9
# ϵ = 0.9791600000	 N unique starting: 3029
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.5525
# Stepsize used in next SMC iteration: 0.2472
# Alpha used in next SMC iteration: 0.0003
#
# ### SMC step:  10
# ϵ = 0.8857700000	 N unique starting: 3020
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.5160
# Stepsize used in next SMC iteration: 0.2754
# Alpha used in next SMC iteration: 0.0003
#
# ### SMC step:  11
# ϵ = 0.7730800000	 N unique starting: 3036
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.4789
# Stepsize used in next SMC iteration: 0.3012
# Alpha used in next SMC iteration: 0.0002
#
# ### SMC step:  12
# ϵ = 0.6601300000	 N unique starting: 2980
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.4439
# Stepsize used in next SMC iteration: 0.3236
# Alpha used in next SMC iteration: 0.0002
#
# ### SMC step:  13
# ϵ = 0.5492100000	 N unique starting: 3017
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.4099
# Stepsize used in next SMC iteration: 0.3419
# Alpha used in next SMC iteration: 0.0002
#
# ### SMC step:  14
# ϵ = 0.4459600000	 N unique starting: 2990
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.3735
# Stepsize used in next SMC iteration: 0.3547
# Alpha used in next SMC iteration: 0.0002
#
# ### SMC step:  15
# ϵ = 0.3546100000	 N unique starting: 2977
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.3466
# Stepsize used in next SMC iteration: 0.3631
# Alpha used in next SMC iteration: 0.0002
#
# ### SMC step:  16
# ϵ = 0.2765900000	 N unique starting: 2998
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.3156
# Stepsize used in next SMC iteration: 0.3659
# Alpha used in next SMC iteration: 0.0002
#
# ### SMC step:  17
# ϵ = 0.2178600000	 N unique starting: 2993
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.2874
# Stepsize used in next SMC iteration: 0.3636
# Alpha used in next SMC iteration: 0.0002
#
# ### SMC step:  18
# ϵ = 0.1702400000	 N unique starting: 2975
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.2665
# Stepsize used in next SMC iteration: 0.3576
# Alpha used in next SMC iteration: 0.0002
#
# ### SMC step:  19
# ϵ = 0.1335300000	 N unique starting: 2987
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.2506
# Stepsize used in next SMC iteration: 0.3489
# Alpha used in next SMC iteration: 0.0002
#
# ### SMC step:  20
# ϵ = 0.1050000000	 N unique starting: 2962
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.2334
# Stepsize used in next SMC iteration: 0.3374
# Alpha used in next SMC iteration: 0.0002
#
# ### SMC step:  21
# ϵ = 0.0830900000	 N unique starting: 2975
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.2277
# Stepsize used in next SMC iteration: 0.3255
# Alpha used in next SMC iteration: 0.0002
#
# ### SMC step:  22
# ϵ = 0.0654400000	 N unique starting: 2942
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.2248
# Stepsize used in next SMC iteration: 0.3134
# Alpha used in next SMC iteration: 0.0002
#
# ### SMC step:  23
# ϵ = 0.0518300000	 N unique starting: 2934
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.2134
# Stepsize used in next SMC iteration: 0.3002
# Alpha used in next SMC iteration: 0.0002
#
# ### SMC step:  24
# ϵ = 0.0402200000	 N unique starting: 2970
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.2096
# Stepsize used in next SMC iteration: 0.2869
# Alpha used in next SMC iteration: 0.0003
#
# ### SMC step:  25
# ϵ = 0.0319500000	 N unique starting: 2976
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.2005
# Stepsize used in next SMC iteration: 0.2730
# Alpha used in next SMC iteration: 0.0003
#
# ### SMC step:  26
# ϵ = 0.0251600000	 N unique starting: 2894
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1961
# Stepsize used in next SMC iteration: 0.2592
# Alpha used in next SMC iteration: 0.0003
#
# ### SMC step:  27
# ϵ = 0.0199100000	 N unique starting: 2920
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1904
# Stepsize used in next SMC iteration: 0.2453
# Alpha used in next SMC iteration: 0.0003
#
# ### SMC step:  28
# ϵ = 0.0158100000	 N unique starting: 2914
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1859
# Stepsize used in next SMC iteration: 0.2317
# Alpha used in next SMC iteration: 0.0004
#
# ### SMC step:  29
# ϵ = 0.0125900000	 N unique starting: 2899
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1810
# Stepsize used in next SMC iteration: 0.2183
# Alpha used in next SMC iteration: 0.0004
#
# ### SMC step:  30
# ϵ = 0.0099300000	 N unique starting: 2852
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1766
# Stepsize used in next SMC iteration: 0.2053
# Alpha used in next SMC iteration: 0.0004
#
# ### SMC step:  31
# ϵ = 0.0079100000	 N unique starting: 2861
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1814
# Stepsize used in next SMC iteration: 0.1935
# Alpha used in next SMC iteration: 0.0005
#
# ### SMC step:  32
# ϵ = 0.0063100000	 N unique starting: 2829
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1853
# Stepsize used in next SMC iteration: 0.1827
# Alpha used in next SMC iteration: 0.0005
#
# ### SMC step:  33
# ϵ = 0.0050600000	 N unique starting: 2889
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1795
# Stepsize used in next SMC iteration: 0.1720
# Alpha used in next SMC iteration: 0.0006
#
# ### SMC step:  34
# ϵ = 0.0039900000	 N unique starting: 2900
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1780
# Stepsize used in next SMC iteration: 0.1618
# Alpha used in next SMC iteration: 0.0007
#
# ### SMC step:  35
# ϵ = 0.0031400000	 N unique starting: 2839
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1728
# Stepsize used in next SMC iteration: 0.1518
# Alpha used in next SMC iteration: 0.0007
#
# ### SMC step:  36
# ϵ = 0.0024600000	 N unique starting: 2829
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1637
# Stepsize used in next SMC iteration: 0.1418
# Alpha used in next SMC iteration: 0.0008
#
# ### SMC step:  37
# ϵ = 0.0019700000	 N unique starting: 2788
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1667
# Stepsize used in next SMC iteration: 0.1327
# Alpha used in next SMC iteration: 0.0009
#
# ### SMC step:  38
# ϵ = 0.0015700000	 N unique starting: 2829
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1554
# Stepsize used in next SMC iteration: 0.1234
# Alpha used in next SMC iteration: 0.0010
#
# ### SMC step:  39
# ϵ = 0.0012500000	 N unique starting: 2785
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1551
# Stepsize used in next SMC iteration: 0.1148
# Alpha used in next SMC iteration: 0.0012
#
# ### SMC step:  40
# ϵ = 0.0010100000	 N unique starting: 2795
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1498
# Stepsize used in next SMC iteration: 0.1065
# Alpha used in next SMC iteration: 0.0013
#
# ### SMC step:  41
# ϵ = 0.0008100000	 N unique starting: 2745
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1484
# Stepsize used in next SMC iteration: 0.0987
# Alpha used in next SMC iteration: 0.0015
#
# ### SMC step:  42
# ϵ = 0.0006500000	 N unique starting: 2735
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1460
# Stepsize used in next SMC iteration: 0.0914
# Alpha used in next SMC iteration: 0.0017
#
# ### SMC step:  43
# ϵ = 0.0005200000	 N unique starting: 2718
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1414
# Stepsize used in next SMC iteration: 0.0844
# Alpha used in next SMC iteration: 0.0019
#
# ### SMC step:  44
# ϵ = 0.0004200000	 N unique starting: 2726
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1362
# Stepsize used in next SMC iteration: 0.0778
# Alpha used in next SMC iteration: 0.0022
#
# ### SMC step:  45
# ϵ = 0.0003300000	 N unique starting: 2705
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1308
# Stepsize used in next SMC iteration: 0.0715
# Alpha used in next SMC iteration: 0.0026
#
# ### SMC step:  46
# ϵ = 0.0002700000	 N unique starting: 2644
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1317
# Stepsize used in next SMC iteration: 0.0657
# Alpha used in next SMC iteration: 0.0029
#
# ### SMC step:  47
# ϵ = 0.0002200000	 N unique starting: 2636
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1294
# Stepsize used in next SMC iteration: 0.0604
# Alpha used in next SMC iteration: 0.0034
#
# ### SMC step:  48
# ϵ = 0.0001800000	 N unique starting: 2662
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1260
# Stepsize used in next SMC iteration: 0.0553
# Alpha used in next SMC iteration: 0.0039
#
# ### SMC step:  49
# ϵ = 0.0001400000	 N unique starting: 2588
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1230
# Stepsize used in next SMC iteration: 0.0506
# Alpha used in next SMC iteration: 0.0045
#
# ### SMC step:  50
# ϵ = 0.0001100000	 N unique starting: 2574
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1177
# Stepsize used in next SMC iteration: 0.0462
# Alpha used in next SMC iteration: 0.0052
#
# ### SMC step:  51
# ϵ = 0.0000900000	 N unique starting: 2597
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1129
# Stepsize used in next SMC iteration: 0.0421
# Alpha used in next SMC iteration: 0.0061
#
# ### SMC step:  52
# ϵ = 0.0000700000	 N unique starting: 2584
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1128
# Stepsize used in next SMC iteration: 0.0383
# Alpha used in next SMC iteration: 0.0071
#
# ### SMC step:  53
# ϵ = 0.0000600000	 N unique starting: 2532
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1167
# Stepsize used in next SMC iteration: 0.0350
# Alpha used in next SMC iteration: 0.0083
#
# ### SMC step:  54
# ϵ = 0.0000500000	 N unique starting: 2559
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1160
# Stepsize used in next SMC iteration: 0.0319
# Alpha used in next SMC iteration: 0.0096
#
# ### SMC step:  55
# ϵ = 0.0000400000	 N unique starting: 2559
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1139
# Stepsize used in next SMC iteration: 0.0291
# Alpha used in next SMC iteration: 0.0112
#
# ### SMC step:  56
# ϵ = 0.0000300000	 N unique starting: 2546
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1152
# Stepsize used in next SMC iteration: 0.0265
# Alpha used in next SMC iteration: 0.0130
#
# ### SMC step:  57
# ϵ = 0.0000300000	 N unique starting: 2501
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1144
# Stepsize used in next SMC iteration: 0.0242
# Alpha used in next SMC iteration: 0.0150
#
# ### SMC step:  58
# ϵ = 0.0000200000	 N unique starting: 2495
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1110
# Stepsize used in next SMC iteration: 0.0220
# Alpha used in next SMC iteration: 0.0175
#
# ### SMC step:  59
# ϵ = 0.0000200000	 N unique starting: 2502
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1112
# Stepsize used in next SMC iteration: 0.0200
# Alpha used in next SMC iteration: 0.0204
#
# ### SMC step:  60
# ϵ = 0.0000100000	 N unique starting: 2514
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1120
# Stepsize used in next SMC iteration: 0.0182
# Alpha used in next SMC iteration: 0.0237
#
# ### SMC step:  61
# ϵ = 0.0000100000	 N unique starting: 2510
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1077
# Stepsize used in next SMC iteration: 0.0165
# Alpha used in next SMC iteration: 0.0276
#
# ### SMC step:  62
# ϵ = 0.0000100000	 N unique starting: 2467
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1090
# Stepsize used in next SMC iteration: 0.0150
# Alpha used in next SMC iteration: 0.0320
#
# ### SMC step:  63
# ϵ = 0.0000100000	 N unique starting: 2405
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1126
# Stepsize used in next SMC iteration: 0.0137
# Alpha used in next SMC iteration: 0.0371
#
# ### SMC step:  64
# ϵ = 0.0000100000	 N unique starting: 2455
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1130
# Stepsize used in next SMC iteration: 0.0125
# Alpha used in next SMC iteration: 0.0429
#
# ### SMC step:  65
# ϵ = 0.0000100000	 N unique starting: 2451
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1149
# Stepsize used in next SMC iteration: 0.0114
# Alpha used in next SMC iteration: 0.0496
#
# ### SMC step:  66
# ϵ = 0.0000000000	 N unique starting: 2431
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1179
# Stepsize used in next SMC iteration: 0.0104
# Alpha used in next SMC iteration: 0.0570
#
# ### SMC step:  67
# ϵ = 0.0000000000	 N unique starting: 2459
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1190
# Stepsize used in next SMC iteration: 0.0095
# Alpha used in next SMC iteration: 0.0654
#
# ### SMC step:  68
# ϵ = 0.0000000000	 N unique starting: 2492
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1175
# Stepsize used in next SMC iteration: 0.0086
# Alpha used in next SMC iteration: 0.0750
#
# ### SMC step:  69
# ϵ = 0.0000000000	 N unique starting: 2471
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1170
# Stepsize used in next SMC iteration: 0.0079
# Alpha used in next SMC iteration: 0.0860
#
# ### SMC step:  70
# ϵ = 0.0000000000	 N unique starting: 2473
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1157
# Stepsize used in next SMC iteration: 0.0072
# Alpha used in next SMC iteration: 0.0985
#
# ### SMC step:  71
# ϵ = 0.0000000000	 N unique starting: 2486
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1180
# Stepsize used in next SMC iteration: 0.0066
# Alpha used in next SMC iteration: 0.1123
#
# ### SMC step:  72
# ϵ = 0.0000000000	 N unique starting: 2485
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1221
# Stepsize used in next SMC iteration: 0.0060
# Alpha used in next SMC iteration: 0.1275
#
# ### SMC step:  73
# ϵ = 0.0000000000	 N unique starting: 2449
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1225
# Stepsize used in next SMC iteration: 0.0055
# Alpha used in next SMC iteration: 0.1443
#
# ### SMC step:  74
# ϵ = 0.0000000000	 N unique starting: 2480
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1245
# Stepsize used in next SMC iteration: 0.0050
# Alpha used in next SMC iteration: 0.1626
#
# ### SMC step:  75
# ϵ = 0.0000000000	 N unique starting: 2481
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1244
# Stepsize used in next SMC iteration: 0.0046
# Alpha used in next SMC iteration: 0.1828
#
# ### SMC step:  76
# ϵ = 0.0000000000	 N unique starting: 2455
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1273
# Stepsize used in next SMC iteration: 0.0042
# Alpha used in next SMC iteration: 0.2045
#
# ### SMC step:  77
# ϵ = 0.0000000000	 N unique starting: 2523
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1333
# Stepsize used in next SMC iteration: 0.0039
# Alpha used in next SMC iteration: 0.2272
#
# ### SMC step:  78
# ϵ = 0.0000000000	 N unique starting: 2490
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1326
# Stepsize used in next SMC iteration: 0.0036
# Alpha used in next SMC iteration: 0.2517
#
# ### SMC step:  79
# ϵ = 0.0000000000	 N unique starting: 2534
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1343
# Stepsize used in next SMC iteration: 0.0033
# Alpha used in next SMC iteration: 0.2776
#
# ### SMC step:  80
# ϵ = 0.0000000000	 N unique starting: 2470
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1318
# Stepsize used in next SMC iteration: 0.0030
# Alpha used in next SMC iteration: 0.3055
#
# ### SMC step:  81
# ϵ = 0.0000000000	 N unique starting: 2439
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1389
# Stepsize used in next SMC iteration: 0.0028
# Alpha used in next SMC iteration: 0.3336
#
# ### SMC step:  82
# ϵ = 0.0000000000	 N unique starting: 2492
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1444
# Stepsize used in next SMC iteration: 0.0026
# Alpha used in next SMC iteration: 0.3619
#
# ### SMC step:  83
# ϵ = 0.0000000000	 N unique starting: 2551
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1436
# Stepsize used in next SMC iteration: 0.0024
# Alpha used in next SMC iteration: 0.3913
#
# ### SMC step:  84
# ϵ = 0.0000000000	 N unique starting: 2554
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1475
# Stepsize used in next SMC iteration: 0.0022
# Alpha used in next SMC iteration: 0.4208
#
# ### SMC step:  85
# ϵ = 0.0000000000	 N unique starting: 2534
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1526
# Stepsize used in next SMC iteration: 0.0021
# Alpha used in next SMC iteration: 0.4498
#
# ### SMC step:  86
# ϵ = 0.0000000000	 N unique starting: 2507
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1519
# Stepsize used in next SMC iteration: 0.0019
# Alpha used in next SMC iteration: 0.4793
#
# ### SMC step:  87
# ϵ = 0.0000000000	 N unique starting: 2547
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1551
# Stepsize used in next SMC iteration: 0.0018
# Alpha used in next SMC iteration: 0.5082
#
# ### SMC step:  88
# ϵ = 0.0000000000	 N unique starting: 2575
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1500
# Stepsize used in next SMC iteration: 0.0017
# Alpha used in next SMC iteration: 0.5381
#
# ### SMC step:  89
# ϵ = 0.0000000000	 N unique starting: 2549
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1578
# Stepsize used in next SMC iteration: 0.0015
# Alpha used in next SMC iteration: 0.5662
#
# ### SMC step:  90
# ϵ = 0.0000000000	 N unique starting: 2561
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1661
# Stepsize used in next SMC iteration: 0.0014
# Alpha used in next SMC iteration: 0.5923
#
# ### SMC step:  91
# ϵ = 0.0000000000	 N unique starting: 2587
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1672
# Stepsize used in next SMC iteration: 0.0013
# Alpha used in next SMC iteration: 0.6176
#
# ### SMC step:  92
# ϵ = 0.0000000000	 N unique starting: 2592
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1640
# Stepsize used in next SMC iteration: 0.0013
# Alpha used in next SMC iteration: 0.6429
#
# ### SMC step:  93
# ϵ = 0.0000000000	 N unique starting: 2591
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1594
# Stepsize used in next SMC iteration: 0.0012
# Alpha used in next SMC iteration: 0.6682
#
# ### SMC step:  94
# ϵ = 0.0000000000	 N unique starting: 2591
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1598
# Stepsize used in next SMC iteration: 0.0011
# Alpha used in next SMC iteration: 0.6925
#
# ### SMC step:  95
# ϵ = 0.0000000000	 N unique starting: 2598
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1691
# Stepsize used in next SMC iteration: 0.0010
# Alpha used in next SMC iteration: 0.7142
#
# ### SMC step:  96
# ϵ = 0.0000000000	 N unique starting: 2595
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1760
# Stepsize used in next SMC iteration: 0.0010
# Alpha used in next SMC iteration: 0.7339
#
# ### SMC step:  97
# ϵ = 0.0000000000	 N unique starting: 2620
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1645
# Stepsize used in next SMC iteration: 0.0010
# Alpha used in next SMC iteration: 0.7544
#
# ### SMC step:  98
# ϵ = 0.0000000000	 N unique starting: 2627
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1608
# Stepsize used in next SMC iteration: 0.0010
# Alpha used in next SMC iteration: 0.7744
#
# ### SMC step:  99
# ϵ = 0.0000000000	 N unique starting: 2615
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1526
# Stepsize used in next SMC iteration: 0.0010
# Alpha used in next SMC iteration: 0.7942
#
# ### SMC step:  100
# ϵ = 0.0000000000	 N unique starting: 2564
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1436
# Stepsize used in next SMC iteration: 0.0010
# Alpha used in next SMC iteration: 0.8137
#
# ### SMC step:  101
# ϵ = 0.0000000000	 N unique starting: 2557
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1348
# Stepsize used in next SMC iteration: 0.0010
# Alpha used in next SMC iteration: 0.8328
#
# ### SMC step:  102
# ϵ = 0.0000000000	 N unique starting: 2490
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1334
# Stepsize used in next SMC iteration: 0.0010
# Alpha used in next SMC iteration: 0.8504
#
# ### SMC step:  103
# ϵ = 0.0000000000	 N unique starting: 2485
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1256
# Stepsize used in next SMC iteration: 0.0010
# Alpha used in next SMC iteration: 0.8672
#
# ### SMC step:  104
# ϵ = 0.0000000000	 N unique starting: 2420
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1173
# Stepsize used in next SMC iteration: 0.0010
# Alpha used in next SMC iteration: 0.8830
#
# ### SMC step:  105
# ϵ = 0.0000000000	 N unique starting: 2340
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1154
# Stepsize used in next SMC iteration: 0.0010
# Alpha used in next SMC iteration: 0.8973
#
# ### SMC step:  106
# ϵ = 0.0000000000	 N unique starting: 2365
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1148
# Stepsize used in next SMC iteration: 0.0010
# Alpha used in next SMC iteration: 0.9100
#
# ### SMC step:  107
# ϵ = 0.0000000000	 N unique starting: 2363
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1110
# Stepsize used in next SMC iteration: 0.0010
# Alpha used in next SMC iteration: 0.9215
#
# ### SMC step:  108
# ϵ = 0.0000000000	 N unique starting: 2329
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1124
# Stepsize used in next SMC iteration: 0.0010
# Alpha used in next SMC iteration: 0.9316
#
# ### SMC step:  109
# ϵ = 0.0000000000	 N unique starting: 2328
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1082
# Stepsize used in next SMC iteration: 0.0010
# Alpha used in next SMC iteration: 0.9407
#
# ### SMC step:  110
# ϵ = 0.0000000000	 N unique starting: 2276
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1044
# Stepsize used in next SMC iteration: 0.0010
# Alpha used in next SMC iteration: 0.9487
#
# ### SMC step:  111
# ϵ = 0.0000000000	 N unique starting: 2274
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.0994
# Stepsize used in next SMC iteration: 0.0010
# Alpha used in next SMC iteration: 0.9559
#
# ### SMC step:  112
# ϵ = 0.0000000000	 N unique starting: 2245
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1007
# Stepsize used in next SMC iteration: 0.0010
# Alpha used in next SMC iteration: 0.9621
#
# ### SMC step:  113
# ϵ = 0.0000000000	 N unique starting: 2225
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.0985
# Stepsize used in next SMC iteration: 0.0010
# Alpha used in next SMC iteration: 0.9675
#
# ### SMC step:  114
# ϵ = 0.0000000000	 N unique starting: 2195
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.0994
# Stepsize used in next SMC iteration: 0.0010
# Alpha used in next SMC iteration: 0.9721
#
# ### SMC step:  115
# ϵ = 0.0000000000	 N unique starting: 2206
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1016
# Stepsize used in next SMC iteration: 0.0010
# Alpha used in next SMC iteration: 0.9761
#
# ### SMC step:  116
# ϵ = 0.0000000000	 N unique starting: 2192
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.0995
# Stepsize used in next SMC iteration: 0.0010
# Alpha used in next SMC iteration: 0.9795
#
# ### SMC step:  117
# ϵ = 0.0000000000	 N unique starting: 2225
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.1134
# Stepsize used in next SMC iteration: 0.0010
# Alpha used in next SMC iteration: 0.9822
# Latest ϵ == ϵmin. Breaking

# %%
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(12, 10))

# Unique Particles
ax[0, 0].plot(*zip(*sorted(zip(out_bip['EPSILON'], out_bip['UNIQUE_PARTICLES']))), label='HUG-SMC')
ax[0, 0].plot(*zip(*sorted(zip(smc_bip_rwm.EPSILON, smc_bip_rwm.n_unique_starting))), label='RWM-SMC')
ax[0, 0].set_xlabel("ϵ")
ax[0, 0].set_ylabel("Unique Particles")
ax[0, 0].set_xscale('log')

# Step Sizes
ax[0, 1].plot(*zip(*sorted(zip(out_bip['EPSILON'], out_bip['STEP_SIZES']))), label='HUG-SMC')
ax[0, 1].plot(*zip(*sorted(zip(smc_bip_rwm.EPSILON, smc_bip_rwm.step_sizes[:-1]))), label='RWM-SMC')
ax[0, 1].set_xlabel("ϵ")
ax[0, 1].set_ylabel("Step Sizes")
ax[0, 1].set_xscale('log')
ax[0, 1].set_yscale('log')

# ESS
ax[1, 0].plot(*zip(*sorted(zip(out_bip['EPSILON'], out_bip['ESS']))), label='HUG-SMC')
ax[1, 0].plot(*zip(*sorted(zip(smc_bip_rwm.EPSILON, smc_bip_rwm.ESS))), label='RWM-SMC')
ax[1, 0].set_xlabel("ϵ")
ax[1, 0].set_ylabel("ESS")
ax[1, 0].set_xscale('log')
ax[1, 0].set_yscale('log')

# Acceptance Probability
ax[1, 1].plot(*zip(*sorted(zip(out_bip['EPSILON'], out_bip['AP']))), label='HUG-SMC')
ax[1, 1].plot(*zip(*sorted(zip(smc_bip_rwm.EPSILON, smc_bip_rwm.accprob))), label='RWM-SMC')
ax[1, 1].set_xlabel("ϵ")
ax[1, 1].set_ylabel("Acceptance probability")
ax[1, 1].set_xscale('log')
ax[1, 1].set_yscale('log')

plt.legend()
plt.show()

# %%
import symnum.numpy as snp
from symnum import (
    numpify, named_array, jacobian, grad, 
    vector_jacobian_product, matrix_hessian_product)
import sympy
import numpy as np

dim_θ = 2
dim_y = 1

@numpify(dim_θ)
def forward_func(θ):
    return snp.array([θ[1]**2 + 3 * θ[0]**2 * (θ[0]**2 - 1)])

def create_fig_if_none(ax, **fig_kw):
    if ax is None:
        fig, ax = plt.subplots(**fig_kw)
    else:
        fig = ax.figure
    return fig, ax

def split_into_integer_parts(n, m):
    return [round(n / m)] * (m - 1) + [n - round(n / m) * (m - 1)]

def grid_on_interval(interval, n_points, cosine_spacing=False):
    if cosine_spacing:
        # Use non-linear spacing with higher density near endpoints
        ts =  ((1 + np.cos(np.linspace(0, 1, n_points) * np.pi)) / 2)
    else:
        ts = np.linspace(0, 1, n_points)
    # If open interval space over range [left + eps, right - eps]
    eps = 10 * np.finfo(np.float64).eps
    left = (float(interval.left) + eps if interval.left_open 
            else float(interval.left))
    right = (float(interval.right) - eps if interval.right_open 
             else float(interval.right))
    return left + ts * (right - left)



def solve_for_limiting_manifold(y, n_points=200, cosine_spacing=False):
    assert n_points % 2 == 0, 'n_points must be even'
    θ = named_array('θ', 2)
    # solve F(θ) = y for θ[1] in terms of θ[0]
    θ_1_gvn_θ_0 = sympy.solve(forward_func(θ)[0] - y, θ[1])
    # find interval(s) over which θ[0] gives real θ[1] solutions
    θ_0_range = sympy.solveset(
        θ_1_gvn_θ_0[0]**2 > 0, θ[0], domain=sympy.Reals)
    θ_0_intervals = (
        θ_0_range.args if isinstance(θ_0_range, sympy.Union) 
        else [θ_0_range])
    # create  grid of values over valid θ[0] interval(s)
    n_intervals = len(θ_0_intervals)
    θ_0_grids = [
        grid_on_interval(intvl, n_pt + 1, cosine_spacing)
        for intvl, n_pt in zip(
            θ_0_intervals, 
            split_into_integer_parts(n_points // 2, n_intervals))]
    # generate NumPy function to calculate θ[1] in terms of θ[0]
    solve_func = sympy.lambdify(θ[0], θ_1_gvn_θ_0)
    manifold_points = []
    for θ_0_grid in θ_0_grids:
        # numerically calculate +/- θ[1] solutions over θ[0] grid
        θ_1_grid_neg, θ_1_grid_pos = solve_func(θ_0_grid)
        # stack θ[0] and θ[1] values in to 2D array in anticlockwise order
        manifold_points.append(np.stack([
            np.concatenate([θ_0_grid, θ_0_grid[-2:0:-1]]),
            np.concatenate([θ_1_grid_neg, θ_1_grid_pos[-2:0:-1]])
        ], -1))
    return manifold_points

def plot_limiting_manifold(y, ax=None, num_points=200):
    manifold_points = solve_for_limiting_manifold(
        y, num_points, cosine_spacing=True)
    fig, ax = create_fig_if_none(ax)
    # repeat first point to close loop by duplicating index
    for component in manifold_points:
        indices = np.arange(component.shape[0] + 1) % component.shape[0]
        line, = ax.plot(component[indices, 0], 
                        component[indices, 1], '-', color='C1', lw=1.)
    return fig, ax, line

# %%
fig, ax = plt.subplots(nrows=2, ncols=3, figsize=(18, 8))
fig.suptitle("Approximate Lifted Distribution with σ = {}".format(σ))
### ROW 1
ax[0, 0].scatter(*out_bip['P'][:, :2, 0].T, s=1, color='silver')
_ = plot_limiting_manifold(y=y_bip, ax=ax[0, 0])
ax[0, 0].set_title("Iteration = 0")

iter1 = 2
ax[0, 1].scatter(*out_bip['P'][out_bip['A'][:, iter1], :2, iter1].T, s=1, color='silver')
_ = plot_limiting_manifold(y=y_bip, ax=ax[0, 1])
ax[0, 1].set_title("Iteration = {}".format(iter1))

iter2 = 5
ax[0, 2].scatter(*out_bip['P'][out_bip['A'][:, iter2], :2, iter2].T, s=1, color='silver')
_ = plot_limiting_manifold(y=y_bip, ax=ax[0, 2])
ax[0, 2].set_title("Iteration = {}".format(iter2))

### ROW 2
iter3 = 10
ax[1, 0].scatter(*out_bip['P'][out_bip['A'][:, iter3], :2, iter3].T, s=1, color='silver')
_ = plot_limiting_manifold(y=y_bip, ax=ax[1, 0])
ax[1, 0].set_title("Iteration = {}".format(iter3))

iter4 = 20
ax[1, 1].scatter(*out_bip['P'][out_bip['A'][:, iter4], :2, iter4].T, s=1, color='silver')
_ = plot_limiting_manifold(y=y_bip, ax=ax[1, 1])
ax[1, 1].set_title("Iteration = {}".format(iter4))

iter5 = 50
ax[1, 2].scatter(*out_bip['P'][out_bip['A'][:, iter5], :2, iter5].T, s=1, color='silver')
_ = plot_limiting_manifold(y=y_bip, ax=ax[1, 2])
ax[1, 2].set_title("Iteration = {}".format(iter5))
plt.show()

# %% [markdown]
# # RWM on Approximate Lifted Distribution (BIP)

# %% [markdown]
# Suppose for Hug/Thug we start with $\delta_0$ and adapt the step size within the range $\delta_{H}\in[\delta_{\min}, \delta_{\max}]$. This means for each particle, and for each MCMC iteration we do $B$ steps, each with stepsize $\delta$. In a way the full step size is $\delta B$.
#
# Perhaps the best way to compare this with RWM is to use a step size within the range $\delta_{R}\in[\delta_{\min}B, \delta_{\max}B]$

# %%
smc_bip_rwm = SMCTHUG(
    N=N,
    d=d_bip,
    ystar=y_bip,
    logprior=logpriorL,
    ϵmin=1e-10,
    pmin=0.3,
    pter=0.01,
    mcmc_iter=B,
    δ0=0.04,
    minstep=0.00001,
    maxstep=0.5,
    manual_initialization=False,
    iterscheme='adaptive',
    maxiter=200,
    B=B,
    maxMCMC=10,
    precondition=True,
    thug=False
)
# Out:
# ### Stopping Criterion: Minimum Tolerance 1e-10
# ### MCMC kernel: RWM with Preconditioning.

# %%
smc_bip_rwm.h = lambda ξ, ystar: norm(FL(ξ, σ) - ystar)
smc_bip_rwm.h_broadcast = lambda ξ, ystar: abs(FL_broadcast(ξ, σ) - ystar)
smc_bip_rwm.grad_h = lambda ξ: grad_FL(ξ, σ) * (FL(ξ, σ) - y_bip)
smc_bip_rwm.sample_prior = sample_priorL
smc_bip_rwm.get_γ = lambda i: i**(-1/20)    # Set it to be constant.

# %%
out_bip_rwm = smc_bip_rwm.sample()
# Out:
# ### Particles have been initialized from the prior.
#
# ### SMC step:  1
# ϵ = 13.0361700000	 N unique starting: 3132
# Metropolis-Hastings steps:  5
# Average Acceptance Probability: 0.3635
# Stepsize used in next SMC iteration: 0.0413
# Alpha used in next SMC iteration: 0.0094
#
# ### SMC step:  2
# ϵ = 3.2661900000	 N unique starting: 2971
# Metropolis-Hastings steps:  10
# Average Acceptance Probability: 0.3768
# Stepsize used in next SMC iteration: 0.0429
# Alpha used in next SMC iteration: 0.0087
#
# ### SMC step:  3
# ϵ = 1.6318100000	 N unique starting: 3023
# Metropolis-Hastings steps:  10
# Average Acceptance Probability: 0.3348
# Stepsize used in next SMC iteration: 0.0437
# Alpha used in next SMC iteration: 0.0084
#
# ### SMC step:  4
# ϵ = 1.2091000000	 N unique starting: 3039
# Metropolis-Hastings steps:  10
# Average Acceptance Probability: 0.2495
# Stepsize used in next SMC iteration: 0.0426
# Alpha used in next SMC iteration: 0.0088
#
# ### SMC step:  5
# ϵ = 0.9692000000	 N unique starting: 2994
# Metropolis-Hastings steps:  10
# Average Acceptance Probability: 0.1777
# Stepsize used in next SMC iteration: 0.0400
# Alpha used in next SMC iteration: 0.0099
#
# ### SMC step:  6
# ϵ = 0.7513300000	 N unique starting: 3002
# Metropolis-Hastings steps:  10
# Average Acceptance Probability: 0.1261
# Stepsize used in next SMC iteration: 0.0367
# Alpha used in next SMC iteration: 0.0116
#
# ### SMC step:  7
# ϵ = 0.5850700000	 N unique starting: 2943
# Metropolis-Hastings steps:  10
# Average Acceptance Probability: 0.0962
# Stepsize used in next SMC iteration: 0.0332
# Alpha used in next SMC iteration: 0.0139
#
# ### SMC step:  8
# ϵ = 0.4577200000	 N unique starting: 2884
# Metropolis-Hastings steps:  10
# Average Acceptance Probability: 0.0733
# Stepsize used in next SMC iteration: 0.0296
# Alpha used in next SMC iteration: 0.0170
#
# ### SMC step:  9
# ϵ = 0.3624600000	 N unique starting: 2798
# Metropolis-Hastings steps:  10
# Average Acceptance Probability: 0.0567
# Stepsize used in next SMC iteration: 0.0262
# Alpha used in next SMC iteration: 0.0210
#
# ### SMC step:  10
# ϵ = 0.2859700000	 N unique starting: 2718
# Metropolis-Hastings steps:  10
# Average Acceptance Probability: 0.0440
# Stepsize used in next SMC iteration: 0.0231
# Alpha used in next SMC iteration: 0.0263
#
# ### SMC step:  11
# ϵ = 0.2313700000	 N unique starting: 2537
# Metropolis-Hastings steps:  10
# Average Acceptance Probability: 0.0369
# Stepsize used in next SMC iteration: 0.0202
# Alpha used in next SMC iteration: 0.0330
#
# ### SMC step:  12
# ϵ = 0.1882200000	 N unique starting: 2448
# Metropolis-Hastings steps:  10
# Average Acceptance Probability: 0.0281
# Stepsize used in next SMC iteration: 0.0176
# Alpha used in next SMC iteration: 0.0416
#
# ### SMC step:  13
# ϵ = 0.1553500000	 N unique starting: 2307
# Metropolis-Hastings steps:  10
# Average Acceptance Probability: 0.0244
# Stepsize used in next SMC iteration: 0.0154
# Alpha used in next SMC iteration: 0.0524
#
# ### SMC step:  14
# ϵ = 0.1304800000	 N unique starting: 2196
# Metropolis-Hastings steps:  10
# Average Acceptance Probability: 0.0194
# Stepsize used in next SMC iteration: 0.0134
# Alpha used in next SMC iteration: 0.0660
#
# ### SMC step:  15
# ϵ = 0.1065600000	 N unique starting: 2046
# Metropolis-Hastings steps:  10
# Average Acceptance Probability: 0.0160
# Stepsize used in next SMC iteration: 0.0116
# Alpha used in next SMC iteration: 0.0830
#
# ### SMC step:  16
# ϵ = 0.0891000000	 N unique starting: 1857
# Metropolis-Hastings steps:  10
# Average Acceptance Probability: 0.0131
# Stepsize used in next SMC iteration: 0.0100
# Alpha used in next SMC iteration: 0.1042
#
# ### SMC step:  17
# ϵ = 0.0756000000	 N unique starting: 1718
# Metropolis-Hastings steps:  10
# Average Acceptance Probability: 0.0117
# Stepsize used in next SMC iteration: 0.0087
# Alpha used in next SMC iteration: 0.1299
#
# ### SMC step:  18
# ϵ = 0.0637300000	 N unique starting: 1592
# Metropolis-Hastings steps:  10
# Average Acceptance Probability: 0.0097
# Stepsize used in next SMC iteration: 0.0075
# Alpha used in next SMC iteration: 0.1611
#
# ### SMC step:  19
# ϵ = 0.0542200000	 N unique starting: 1468
# Metropolis-Hastings steps:  10
# Average Acceptance Probability: 0.0087
# Stepsize used in next SMC iteration: 0.0065
# Alpha used in next SMC iteration: 0.1980
#
# ### SMC step:  20
# ϵ = 0.0473400000	 N unique starting: 1371
# Metropolis-Hastings steps:  10
# Average Acceptance Probability: 0.0074
# Stepsize used in next SMC iteration: 0.0056
# Alpha used in next SMC iteration: 0.2410
#
# ### SMC step:  21
# ϵ = 0.0410600000	 N unique starting: 1291
# Metropolis-Hastings steps:  10
# Average Acceptance Probability: 0.0069
# Stepsize used in next SMC iteration: 0.0049
# Alpha used in next SMC iteration: 0.2900
#
# ### SMC step:  22
# ϵ = 0.0353300000	 N unique starting: 1189
# Metropolis-Hastings steps:  10
# Average Acceptance Probability: 0.0059
# Stepsize used in next SMC iteration: 0.0042
# Alpha used in next SMC iteration: 0.3445
#
# ### SMC step:  23
# ϵ = 0.0310500000	 N unique starting: 1102
# Metropolis-Hastings steps:  10
# Average Acceptance Probability: 0.0052
# Stepsize used in next SMC iteration: 0.0036
# Alpha used in next SMC iteration: 0.4034
#
# ### SMC step:  24
# ϵ = 0.0274800000	 N unique starting: 1016
# Metropolis-Hastings steps:  10
# Average Acceptance Probability: 0.0044
# Stepsize used in next SMC iteration: 0.0031
# Alpha used in next SMC iteration: 0.4653
#
# ### SMC step:  25
# ϵ = 0.0242300000	 N unique starting: 953
# Metropolis-Hastings steps:  10
# Average Acceptance Probability: 0.0034
# Stepsize used in next SMC iteration: 0.0027
# Alpha used in next SMC iteration: 0.5283
#
# ### SMC step:  26
# ϵ = 0.0214800000	 N unique starting: 879
# Metropolis-Hastings steps:  10
# Average Acceptance Probability: 0.0036
# Stepsize used in next SMC iteration: 0.0023
# Alpha used in next SMC iteration: 0.5903
#
# ### SMC step:  27
# ϵ = 0.0189300000	 N unique starting: 822
# Metropolis-Hastings steps:  10
# Average Acceptance Probability: 0.0032
# Stepsize used in next SMC iteration: 0.0020
# Alpha used in next SMC iteration: 0.6495
#
# ### SMC step:  28
# ϵ = 0.0165600000	 N unique starting: 753
# Metropolis-Hastings steps:  10
# Average Acceptance Probability: 0.0029
# Stepsize used in next SMC iteration: 0.0017
# Alpha used in next SMC iteration: 0.7044
#
# ### SMC step:  29
# ϵ = 0.0143600000	 N unique starting: 706
# Metropolis-Hastings steps:  10
# Average Acceptance Probability: 0.0020
# Stepsize used in next SMC iteration: 0.0015
# Alpha used in next SMC iteration: 0.7540
#
# ### SMC step:  30
# ϵ = 0.0127000000	 N unique starting: 645
# Metropolis-Hastings steps:  10
# Average Acceptance Probability: 0.0020
# Stepsize used in next SMC iteration: 0.0013
# Alpha used in next SMC iteration: 0.7976
#
# ### SMC step:  31
# ϵ = 0.0111200000	 N unique starting: 596
# Metropolis-Hastings steps:  10
# Average Acceptance Probability: 0.0018
# Stepsize used in next SMC iteration: 0.0011
# Alpha used in next SMC iteration: 0.8352
#
# ### SMC step:  32
# ϵ = 0.0099800000	 N unique starting: 541
# Metropolis-Hastings steps:  10
# Average Acceptance Probability: 0.0012
# Stepsize used in next SMC iteration: 0.0009
# Alpha used in next SMC iteration: 0.8669
#
# ### SMC step:  33
# ϵ = 0.0087600000	 N unique starting: 495
# Metropolis-Hastings steps:  10
# Average Acceptance Probability: 0.0013
# Stepsize used in next SMC iteration: 0.0008
# Alpha used in next SMC iteration: 0.8933
#
# ### SMC step:  34
# ϵ = 0.0077800000	 N unique starting: 448
# Metropolis-Hastings steps:  10
# Average Acceptance Probability: 0.0012
# Stepsize used in next SMC iteration: 0.0007
# Alpha used in next SMC iteration: 0.9149
#
# ### SMC step:  35
# ϵ = 0.0065700000	 N unique starting: 400
# Metropolis-Hastings steps:  10
# Average Acceptance Probability: 0.0011
# Stepsize used in next SMC iteration: 0.0006
# Alpha used in next SMC iteration: 0.9325
#
# ### SMC step:  36
# ϵ = 0.0058300000	 N unique starting: 371
# Metropolis-Hastings steps:  10
# Average Acceptance Probability: 0.0007
# Stepsize used in next SMC iteration: 0.0005
# Alpha used in next SMC iteration: 0.9466
#
# ### SMC step:  37
# ϵ = 0.0052100000	 N unique starting: 331
# Metropolis-Hastings steps:  10
# Average Acceptance Probability: 0.0005
# Stepsize used in next SMC iteration: 0.0004
# Alpha used in next SMC iteration: 0.9579
#
# ### SMC step:  38
# ϵ = 0.0044900000	 N unique starting: 294
# Metropolis-Hastings steps:  10
# Average Acceptance Probability: 0.0007
# Stepsize used in next SMC iteration: 0.0004
# Alpha used in next SMC iteration: 0.9669
#
# ### SMC step:  39
# ϵ = 0.0039800000	 N unique starting: 279
# Metropolis-Hastings steps:  10
# Average Acceptance Probability: 0.0006
# Stepsize used in next SMC iteration: 0.0003
# Alpha used in next SMC iteration: 0.9740
#
# ### SMC step:  40
# ϵ = 0.0036600000	 N unique starting: 256
# Metropolis-Hastings steps:  10
# Average Acceptance Probability: 0.0006
# Stepsize used in next SMC iteration: 0.0003
# Alpha used in next SMC iteration: 0.9796
#
# ### SMC step:  41
# ϵ = 0.0033000000	 N unique starting: 236
# Metropolis-Hastings steps:  10
# Average Acceptance Probability: 0.0005
# Stepsize used in next SMC iteration: 0.0002
# Alpha used in next SMC iteration: 0.9840
#
# ### SMC step:  42
# ϵ = 0.0028600000	 N unique starting: 220
# Metropolis-Hastings steps:  10
# Average Acceptance Probability: 0.0004
# Stepsize used in next SMC iteration: 0.0002
# Alpha used in next SMC iteration: 0.9875
#
# ### SMC step:  43
# ϵ = 0.0026500000	 N unique starting: 201
# Metropolis-Hastings steps:  10
# Average Acceptance Probability: 0.0004
# Stepsize used in next SMC iteration: 0.0002
# Alpha used in next SMC iteration: 0.9902
#
# ### SMC step:  44
# ϵ = 0.0022700000	 N unique starting: 184
# Metropolis-Hastings steps:  10
# Average Acceptance Probability: 0.0006
# Stepsize used in next SMC iteration: 0.0002
# Alpha used in next SMC iteration: 0.9924
#
# ### SMC step:  45
# ϵ = 0.0020200000	 N unique starting: 172
# Metropolis-Hastings steps:  10
# Average Acceptance Probability: 0.0004
# Stepsize used in next SMC iteration: 0.0001
# Alpha used in next SMC iteration: 0.9940
#
# ### SMC step:  46
# ϵ = 0.0017900000	 N unique starting: 157
# Metropolis-Hastings steps:  10
# Average Acceptance Probability: 0.0002
# Stepsize used in next SMC iteration: 0.0001
# Alpha used in next SMC iteration: 0.9953
#
# ### SMC step:  47
# ϵ = 0.0016100000	 N unique starting: 141
# Metropolis-Hastings steps:  10
# Average Acceptance Probability: 0.0004
# Stepsize used in next SMC iteration: 0.0001
# Alpha used in next SMC iteration: 0.9963
#
# ### SMC step:  48
# ϵ = 0.0014200000	 N unique starting: 132
# Metropolis-Hastings steps:  10
# Average Acceptance Probability: 0.0002
# Stepsize used in next SMC iteration: 0.0001
# Alpha used in next SMC iteration: 0.9971
#
# ### SMC step:  49
# ϵ = 0.0012500000	 N unique starting: 111
# Metropolis-Hastings steps:  10
# Average Acceptance Probability: 0.0003
# Stepsize used in next SMC iteration: 0.0001
# Alpha used in next SMC iteration: 0.9978
#
# ### SMC step:  50
# ϵ = 0.0011700000	 N unique starting: 107
# Metropolis-Hastings steps:  10
# Average Acceptance Probability: 0.0002
# Stepsize used in next SMC iteration: 0.0001
# Alpha used in next SMC iteration: 0.9983
#
# ### SMC step:  51
# ϵ = 0.0010100000	 N unique starting: 96
# Metropolis-Hastings steps:  10
# Average Acceptance Probability: 0.0002
# Stepsize used in next SMC iteration: 0.0001
# Alpha used in next SMC iteration: 0.9986
#
# ### SMC step:  52
# ϵ = 0.0009200000	 N unique starting: 87
# Metropolis-Hastings steps:  10
# Average Acceptance Probability: 0.0001
# Stepsize used in next SMC iteration: 0.0000
# Alpha used in next SMC iteration: 0.9989
#
# ### SMC step:  53
# ϵ = 0.0007800000	 N unique starting: 79
# Metropolis-Hastings steps:  10
# Average Acceptance Probability: 0.0001
# Stepsize used in next SMC iteration: 0.0000
# Alpha used in next SMC iteration: 0.9990
#
# ### SMC step:  54
# ϵ = 0.0006900000	 N unique starting: 73
# Metropolis-Hastings steps:  10
# Average Acceptance Probability: 0.0001
# Stepsize used in next SMC iteration: 0.0000
# Alpha used in next SMC iteration: 0.9990
#
# ### SMC step:  55
# ϵ = 0.0006200000	 N unique starting: 67
# Metropolis-Hastings steps:  10
# Average Acceptance Probability: 0.0001
# Stepsize used in next SMC iteration: 0.0000
# Alpha used in next SMC iteration: 0.9990
#
# ### SMC step:  56
# ϵ = 0.0005700000	 N unique starting: 62
# Metropolis-Hastings steps:  10
# Average Acceptance Probability: 0.0000
# Stepsize used in next SMC iteration: 0.0000
# Alpha used in next SMC iteration: 0.9990
#
# ### SMC step:  57
# ϵ = 0.0005100000	 N unique starting: 54
# Metropolis-Hastings steps:  10
# Average Acceptance Probability: 0.0001
# Stepsize used in next SMC iteration: 0.0000
# Alpha used in next SMC iteration: 0.9990
#
# ### SMC step:  58
# ϵ = 0.0004500000	 N unique starting: 52
# Metropolis-Hastings steps:  10
# Average Acceptance Probability: 0.0001
# Stepsize used in next SMC iteration: 0.0000
# Alpha used in next SMC iteration: 0.9990
#
# ### SMC step:  59
# ϵ = 0.0004100000	 N unique starting: 45
# Metropolis-Hastings steps:  10
# Average Acceptance Probability: 0.0001
# Stepsize used in next SMC iteration: 0.0000
# Alpha used in next SMC iteration: 0.9990
#
# ### SMC step:  60
# ϵ = 0.0003800000	 N unique starting: 40
# Metropolis-Hastings steps:  10
# Average Acceptance Probability: 0.0002
# Stepsize used in next SMC iteration: 0.0000
# Alpha used in next SMC iteration: 0.9990
#
# ### SMC step:  61
# ϵ = 0.0003200000	 N unique starting: 43
# Metropolis-Hastings steps:  10
# Average Acceptance Probability: 0.0000
# Stepsize used in next SMC iteration: 0.0000
# Alpha used in next SMC iteration: 0.9990
#
# ### SMC step:  62
# ϵ = 0.0002900000	 N unique starting: 35
# Metropolis-Hastings steps:  10
# /Users/maurocamara/Documents/University/ManifoldSampling/smc_thug.py:155: RuntimeWarning: divide by zero encountered in double_scalars
#   def adaptive_n_mcmc(self): return min(self.maxMCMC, int(ceil(log(1 - self.pPmoved) / log(1 - self.accprob[-1]))))
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# /var/folders/hy/57_f4xcx08b0ls2_nwwfjscr0000gn/T/ipykernel_15978/1849385318.py in <module>
# ----> 1 out_bip_rwm = smc_bip_rwm.sample()
#
# ~/Documents/University/ManifoldSampling/smc_thug.py in sample(self)
#     282             self.accprob.append(self.avg_acc_prob_within_MCMC[:, -1].mean())
#     283             #self.accprob.append(self.accepted[:, -1].mean())  #accepted[alive]?
# --> 284             self.MCMC_iter.append(self.compute_n_mcmc_iterations())
#     285             print("Average Acceptance Probability: {:.4f}".format(self.accprob[-1]))
#     286
#
# ~/Documents/University/ManifoldSampling/smc_thug.py in adaptive_n_mcmc(self)
#     153
#     154     def fixed_n_mcmc(self):    return self.mcmc_iter
# --> 155     def adaptive_n_mcmc(self): return min(self.maxMCMC, int(ceil(log(1 - self.pPmoved) / log(1 - self.accprob[-1]))))
#     156
#     157     @staticmethod
#
# OverflowError: cannot convert float infinity to integer

# %%
fig, ax = plt.subplots(nrows=2, ncols=3, figsize=(18, 8))
fig.suptitle("Approximate Lifted Distribution with σ = {}".format(σ))
### ROW 1
ax[0, 0].scatter(*smc_bip_rwm.P[:, :2, 0].T, s=1, color='silver')
_ = plot_limiting_manifold(y=y_bip, ax=ax[0, 0])
ax[0, 0].set_title("Iteration = 0")

iter1 = 2
ax[0, 1].scatter(*smc_bip_rwm.P[smc_bip_rwm.A[:, iter1], :2, iter1].T, s=1, color='silver')
_ = plot_limiting_manifold(y=y_bip, ax=ax[0, 1])
ax[0, 1].set_title("Iteration = {}".format(iter1))

iter2 = 5
ax[0, 2].scatter(*smc_bip_rwm.P[smc_bip_rwm.A[:, iter2], :2, iter2].T, s=1, color='silver')
_ = plot_limiting_manifold(y=y_bip, ax=ax[0, 2])
ax[0, 2].set_title("Iteration = {}".format(iter2))

### ROW 2
iter3 = 10
ax[1, 0].scatter(*smc_bip_rwm.P[smc_bip_rwm.A[:, iter3], :2, iter3].T, s=1, color='silver')
_ = plot_limiting_manifold(y=y_bip, ax=ax[1, 0])
ax[1, 0].set_title("Iteration = {}".format(iter3))

iter4 = 20
ax[1, 1].scatter(*smc_bip_rwm.P[smc_bip_rwm.A[:, iter4], :2, iter4].T, s=1, color='silver')
_ = plot_limiting_manifold(y=y_bip, ax=ax[1, 1])
ax[1, 1].set_title("Iteration = {}".format(iter4))

iter5 = 50
ax[1, 2].scatter(*smc_bip_rwm.P[smc_bip_rwm.A[:, iter5], :2, iter5].T, s=1, color='silver')
_ = plot_limiting_manifold(y=y_bip, ax=ax[1, 2])
ax[1, 2].set_title("Iteration = {}".format(iter5))
plt.show()
