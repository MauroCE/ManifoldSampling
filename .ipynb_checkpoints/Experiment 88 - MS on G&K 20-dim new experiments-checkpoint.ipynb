# %%
import numpy as np
from numpy import zeros, eye, array, diag, exp, ones, tanh, cosh, dstack, log, hstack, vstack, sinh
from numpy.linalg import solve, norm
from numpy.random import choice, default_rng, randint, randn
from scipy.stats import multivariate_normal as MVN
from scipy.special import logsumexp, ndtr
from scipy.stats import uniform as udist
import math
import time
from copy import deepcopy

import matplotlib.pyplot as plt
from matplotlib import rc
from ipywidgets.widgets import IntSlider
from ipywidgets.widgets import interact
from warnings import resetwarnings, catch_warnings, filterwarnings
import seaborn as sns

from Manifolds.GKManifoldNew import GKManifold, data_generator, find_point_on_manifold, find_point_on_manifold_from_θ
from markov_snippets import MSAdaptive, SMCAdaptive
from tangential_hug_functions import TangentialHugSampler
from tangential_hug_functions import HugTangentialMultivariate
from RWM import RWM
from utils import ESS_univariate

# %%
seed = 1234
m = 20     # number of latent variables
d = m + 4  # dimensionality of x-component

# %%
def generate_settings(
    d=d, 
    N=2000,
    B=20,
    δ=0.01,
    δmin=1e-3,
    δmax=100.0,
    εmin=1e-16,
    min_pm=1e-4,
    maxiter=500,
    verbose=False,
    εs_fixed=None,
    adaptiveε=True,
    adaptiveδ=False,
    z0_manual=None,
    pm_target=0.23,
    pm_switch=0.1,
    prior_seed=seed,
    low_memory=True,
    integrator='rwm',
    εprop_switch=0.01,
    ε0_manual=None,
    quantile_value=0.9,
    initialization='manual',
    switch_strategy='pm',
    kernel='uniform',
    prior_scale=7,
    thinning=10,
    burnin=100,
    use_autograd=False,
    stopping_criterion={'εmin', 'pm'},
    resampling_seed=1234,
    mh_kernel_seed=1234,
    resampling_scheme='multinomial'):
    # here d represents m+4
    # Generate the manifold
    θ0        = array([3.0, 1.0, 2.0, 0.5])       # True parameter value on U(0, 10) scale.
    ystar     = data_generator(θ0, m, seed=seed)  # Observed data
    q         = MVN(zeros(d), eye(d))             # Proposal distribution for THUG
    resetwarnings()
    manifold  = GKManifold(ystar, kernel_type=kernel, use_autograd=use_autograd)
    # grab arguments
    arguments = locals()
    return arguments

# %%
def generate_initial_particles(ϵ0, N=5000, s=0.001):
    # Generate Manifold
    θ0        = array([3.0, 1.0, 2.0, 0.5])       # True parameter value on U(0, 10) scale.
    ystar     = data_generator(θ0, m, seed=1234)  # Observed data
    resetwarnings()
    manifold  = GKManifold(ystar, kernel_type='uniform', use_autograd=False, θtrue=θ0)

    # Generate target distribution
    ξ0 = manifold.sample()               # Initial point on manifold                            # Starting epsilon
    logηε0 = manifold.generate_logηε(ε0)  # Target filamentary distribution

    # Sample from it using RWM
    s_rwm, a_rwm = RWM(x0=ξ0, s=s, N=N, logpi=logηε0)

    # Add velocities to particles
    v0_manual = randn(*s_rwm.shape)
    z0_manual = np.hstack((s_rwm, v0_manual))
    return z0_manual

def generate_initial_particles_on_manifold(N=5000, θtrue=False):
    # Generate Manifold
    θ0        = array([3.0, 1.0, 2.0, 0.5])       # True parameter value on U(0, 10) scale.
    ystar     = data_generator(θ0, m, seed=1234)  # Observed data
    resetwarnings()
    manifold  = GKManifold(ystar, kernel_type='uniform', use_autograd=False, θtrue=θ0)
    # Sample N times
    x0_manual = np.vstack([manifold.sample(fromtheta=θtrue) for _ in range(N)])
    v0_manual = randn(*x0_manual.shape)
    return np.hstack((x0_manual, v0_manual))

def generate_particles_on_manifold_then_rwm(ϵ0, N=5000, θtrue=False, δrwm=0.001):
    """First, generate particles on the manifold. Then use RWM to actually sample from a filamentary
    distribution of sorts."""
    # Generate manifold (used only to generate filamentary distribution)
    θ0        = array([3.0, 1.0, 2.0, 0.5])       # True parameter value on U(0, 10) scale.
    ystar     = data_generator(θ0, m, seed=1234)  # Observed data
    manifold  = GKManifold(ystar, kernel_type='uniform', use_autograd=False, θtrue=θ0)
    # Sample on manifold
    on_manifold = generate_initial_particles_on_manifold(N=N, θtrue=θtrue)
    x0_on_manifold = on_manifold[:, :on_manifold.shape[1]//2]
    # Store filamentary samples
    filamentary_samples = []
    for x0 in x0_on_manifold:
        filamentary_samples.append(RWM(x0, s=δrwm, N=1, logpi=manifold.generate_logηε(ϵ0))[0].flatten())
    # Create array
    v0_manual = randn(*x0_on_manifold.shape)
    x0_manual = np.vstack(filamentary_samples)
    return np.hstack((x0_manual, v0_manual))

def sample_from_filamentary(ε0, N=2000, n_per_sample=10, s=1.0, fromtheta=False):
    samples = []
    acceptances = []
    # Generate Manifold
    θ0        = array([3.0, 1.0, 2.0, 0.5])       # True parameter value on U(0, 10) scale.
    ystar     = data_generator(θ0, m, seed=1234)  # Observed data
    resetwarnings()
    manifold  = GKManifold(ystar, kernel_type='uniform', use_autograd=False, θtrue=θ0)
    # Construct filamentary distribution
    logηε0 = manifold.generate_logηε(ε0)
    while len(acceptances) < N:
        with catch_warnings():
            filterwarnings('error')
            try:
                # Sample on the manifold
                ξ0 = manifold.sample(fromtheta=fromtheta)
                # Sample starting from ξ0 and perform 10 steps of RWM. Grab the final point
                s_rwm, a_rwm = RWM(x0=ξ0, s=s, N=n_per_sample, logpi=logηε0)
                samples.append(s_rwm[-1])
                acceptances.append(np.mean(a_rwm)) #int(sum(a_rwm == 1) > 0))
            except RuntimeWarning:
                continue
    print("Acceptance Probability: {:.3f}".format(np.mean(acceptances)*100))
    x0_manual = vstack(samples)
    v0_manual = v0_manual = randn(*x0_manual.shape)
    return hstack((x0_manual, v0_manual))

def sample_from_filamentary_with_thug(ε0, N=2000, n_per_sample=10, s=1.0, fromtheta=False):
    samples = []
    acceptances = []
    # Generate Manifold
    θ0        = array([3.0, 1.0, 2.0, 0.5])       # True parameter value on U(0, 10) scale.
    ystar     = data_generator(θ0, m, seed=1234)  # Observed data
    resetwarnings()
    manifold  = GKManifold(ystar, kernel_type='uniform', use_autograd=False, θtrue=θ0)
    # Construct filamentary distribution
    logηε0 = manifold.generate_logηε(ε0)
    while len(acceptances) < N:
        with catch_warnings():
            filterwarnings('error')
            try:
                # Sample on the manifold
                ξ0 = manifold.sample(fromtheta=fromtheta)
                # Sample starting from ξ0 and perform 10 steps of RWM. Grab the final point
                THUG = TangentialHugSampler(ξ0, T=5*s, B=5, N=N, α=0.0, logpi=logηε0, jac=manifold.fullJacobian)
                s_thug, a_thug = THUG.sample() #(x0=ξ0, s=s, N=n_per_sample, logpi=logηε0)
                samples.append(s_thug[-1])
                acceptances.append(np.mean(a_thug)) #int(sum(a_rwm == 1) > 0))
            except RuntimeWarning:
                continue
    print("Acceptance Probability: {:.3f}".format(np.mean(acceptances)*100))
    x0_manual = vstack(samples)
    v0_manual = v0_manual = randn(*x0_manual.shape)
    return hstack((x0_manual, v0_manual))

# %%
N      = 5000
B      = 20
δmin   = 1e-3
min_pm = 1e-4
pm_switch = 0.1
quantile_value = 0.9

# %%
# Sample from filamentary distribution
ε0_20 = 20.0
S20 = sample_from_filamentary(ε0=ε0_20, N=N, n_per_sample=2, s=0.5, fromtheta=True)
# Out:
# Acceptance Probability: 14.990

# %%
SMC_RT_0001_FIL_Tδ_09 = SMCAdaptive(generate_settings(
        d=d, 
        N=N,
        B=B,
        δ=[0.001, 0.01],
        δmin=δmin,
        min_pm=min_pm,
        verbose=True,
        εs_fixed=None,
        adaptiveε=True,
        adaptiveδ=False,
        z0_manual=S20,
        pm_target=0.23,
        pm_switch=pm_switch,
        prior_seed=1111,
        low_memory=True,
        integrator='rwm_then_thug',
        εprop_switch=0.01,
        ε0_manual=ε0_20,
        quantile_value=quantile_value,
        initialization='manual',
        switch_strategy='pm',
        kernel='uniform',
        use_autograd=False,
        stopping_criterion={'εmin', 'pm'},
        resampling_seed=1234,
        mh_kernel_seed=1234))
_ = SMC_RT_0001_FIL_Tδ_09.sample()
# Out:
# Stochastic Kernel: RWM.
# Stopping criterion:  εmin, pm.
# Iteration:  1
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 13.9790414711152540
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.8539000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  2
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 10.3021514168185409
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.8463000000000001
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  3
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 5.2019425120653864
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.8503000000000001
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  4
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 3.0966423476643214
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.7799000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  5
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 2.6106691733559253
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.7361000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  6
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 2.2958641507099005
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.6940999999999999
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  7
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 2.0637638445513709
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.6476000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  8
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 1.9027443448618533
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.6149000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  9
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 1.7845896399123025
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.5803000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  10
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 1.6820083109406498
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.5676000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  11
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 1.5881135969275464
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.5255000000000001
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  12
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 1.5121380651488736
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.5122000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  13
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 1.4396403369159456
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4729000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  14
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 1.3810745485511127
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4534000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  15
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 1.3287074964032382
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4359000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  16
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 1.2817924367436295
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4015000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  17
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 1.2393654143735562
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3798000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  18
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 1.1990170098937387
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3646000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  19
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 1.1628537251081272
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3450000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  20
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 1.1279183038747931
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3263000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  21
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 1.0966568625361723
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3139999999999999
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  22
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 1.0677000070715870
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3048000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  23
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 1.0395694612003932
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2857000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  24
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 1.0155905046818019
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2730000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  25
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.9919458448268182
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2532000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  26
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.9711004616109756
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2557000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  27
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.9504871763497260
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2405000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  28
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.9310632643243045
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2250000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  29
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.9112940792765580
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2144000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  30
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.8944114584038023
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2139000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  31
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.8791175080419533
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1974000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  32
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.8638253736910296
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1938000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  33
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.8492170993380422
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1813000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  34
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.8345012871326637
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1680000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  35
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.8211612205265850
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1717000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  36
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.8073237253732993
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1580000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  37
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.7939384011438176
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1551000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  38
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.7811674448628589
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1485000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  39
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.7705788238390949
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1403000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  40
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.7576743005176161
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1351000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  41
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.7468119682586581
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1252000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  42
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.7352656311414720
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1249000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  43
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.7257069156286290
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1273000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  44
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.7141154031626405
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1211000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  45
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.7022956550390453
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1141000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  46
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.6927046112665896
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1129000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  47
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.6827986347076180
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1081000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  48
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.6735219212674443
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0946000000000000
# 	Step-size kept fixed at: 0.0010000000000000
#
#
# ####################################
# ### SWITCHING TO THUG KERNEL ###
# ####################################
#
#
# Iteration:  49
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.6637819836254001
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4694000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  50
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.6547680391421477
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4671000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  51
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.6469520393711151
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4679000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  52
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.6395948053726769
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4656000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  53
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.6322987172733994
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4701000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  54
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.6250664547087555
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4703000000000001
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  55
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.6181600641720695
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4684000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  56
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.6113918664315250
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4649000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  57
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.6047072944048546
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4626000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  58
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.5985318544701863
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4609000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  59
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.5923856939646148
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4603000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  60
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.5865022435976590
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4547000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  61
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.5808238929081120
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4572000000000001
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  62
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.5751680369603169
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4574000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  63
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.5692815713820195
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4546000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  64
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.5633636805227861
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4448000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  65
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.5571751572803776
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4505000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  66
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.5519091898852276
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4457000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  67
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.5460776141894231
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4447000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  68
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.5406418352411706
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4386000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  69
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.5356842758374614
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4361000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  70
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.5304619949505690
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4379999999999999
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  71
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.5254720390188220
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4407000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  72
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.5206157355268696
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4290000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  73
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.5157546833929483
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4270000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  74
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.5107275269761534
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4355000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  75
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.5053950893346806
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4290000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  76
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.5004158399308978
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4247000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  77
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.4958345281414863
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4170000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  78
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.4913713026794345
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4149000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  79
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.4873616280496137
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3992000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  80
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.4833737243726837
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4125000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  81
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.4791559933703102
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4035000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  82
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.4748690998256735
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4042000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  83
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.4708524492800021
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4062000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  84
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.4666647827095093
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4022000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  85
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.4626877833827741
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3991000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  86
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.4585558471198159
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4004000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  87
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.4543367429139836
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3875000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  88
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.4500296724076893
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3940000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  89
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.4460523454935353
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3948000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  90
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.4421434006548267
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3905999999999999
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  91
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.4384280980944948
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3931000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  92
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.4345551794949791
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.4018000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  93
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.4302471724632350
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3945000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  94
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.4260616287431383
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3921000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  95
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.4221038964856957
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3975000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  96
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.4181805423279857
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3952000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  97
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.4143654482952768
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3723000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  98
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.4107198694117752
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3812000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  99
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.4072790807891941
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3883000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  100
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.4035263359875343
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3716000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  101
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.4000791226505845
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3728000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  102
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.3969258957186400
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3649000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  103
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.3935838789903572
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3590000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  104
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.3905705581727900
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3586000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  105
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.3878906563903239
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3500000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  106
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.3851806681019599
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3395000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  107
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.3825122526776932
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3447000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  108
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.3798728291695779
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3309000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  109
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.3774809644092864
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3264000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  110
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.3751714298902739
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3181000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  111
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.3729825828301075
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3146000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  112
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.3709730591210572
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3151000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  113
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.3690076278615257
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3117000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  114
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.3670140232784810
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.3086000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  115
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.3648647902917630
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2976000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  116
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.3629465060046328
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2998000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  117
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.3611661790911511
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2933000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  118
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.3594121350268528
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2899000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  119
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.3575742788231393
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2806000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  120
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.3559287509804948
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2792000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  121
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.3542008015009199
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2681000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  122
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.3525713282656809
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2715000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  123
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.3512245906347123
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2722000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  124
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.3497983960773695
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2653000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  125
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.3483991956453861
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2556000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  126
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.3471474290184920
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2583000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  127
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.3458259358180965
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2571000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  128
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.3444689074217135
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2508000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  129
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.3432125552923628
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2516000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  130
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.3421006475669158
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2457000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  131
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.3408149029161620
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2477000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  132
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.3396312334375655
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2374000000000001
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  133
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.3385080545144052
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2423000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  134
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.3373486551454404
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2363000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  135
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.3362597811532901
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2471000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  136
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.3351691836696506
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2419000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  137
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.3339650006405866
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2376000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  138
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.3328325140848893
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2422000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  139
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.3317002026002346
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2347000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  140
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.3305495311903949
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2354000000000001
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  141
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.3295506177603008
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2418000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  142
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.3284537704691388
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2408000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  143
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.3272768896684423
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2319000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  144
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.3261431909304983
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2307000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  145
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.3250436520667855
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2243000000000001
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  146
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.3239713237395109
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2278000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  147
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.3228197364636617
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2211000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  148
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.3217389560301516
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2250000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  149
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.3206578038361582
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2158000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  150
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.3197120645989733
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2056000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  151
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.3187638390160487
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2077000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  152
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.3177892200269889
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2013000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  153
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.3169422038623363
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2048000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  154
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.3161401878435741
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2020999999999999
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  155
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.3152336051068342
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1925000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  156
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.3143773896883189
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1968000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  157
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.3135198773613173
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1956000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  158
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.3126434785664522
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1934000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  159
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.3117390621898212
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1945000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  160
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.3108084662253366
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.1867000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  161
# 	Quantile Value:  0.9
# 	Particles resampled.
# 	Epsilon: 0.3098983631293706
# 	Weights computed and normalised.
# Error was raised:

# %% [markdown]
# # Testing Samplers

# %%
def test_rwm(ε0, N, s=0.1):
    """Runs RWM to target filamentary distribution."""
    # Generate Manifold
    θ0        = array([3.0, 1.0, 2.0, 0.5])       # True parameter value on U(0, 10) scale.
    ystar     = data_generator(θ0, m, seed=1234)  # Observed data
    manifold  = GKManifold(ystar, kernel_type='uniform', use_autograd=False, θtrue=θ0)
    
    # Generate filamentary distribution
    logηε0 = manifold.generate_logηε(ε0)
    
    # Find point on manifold
    ξ0 = manifold.sample(fromtheta=True)
    
    # Run RWM
    samples, acceptances = RWM(ξ0, s=s, N=N, logpi=logηε0)
    print("AP: {:.5f}".format(np.mean(acceptances)*100))
    return samples


def test_thug(ε0, N, s=0.1, B=10):
    """Runs RWM to target filamentary distribution."""
    # Generate Manifold
    θ0        = array([3.0, 1.0, 2.0, 0.5])       # True parameter value on U(0, 10) scale.
    ystar     = data_generator(θ0, m, seed=1234)  # Observed data
    manifold  = GKManifold(ystar, kernel_type='uniform', use_autograd=False, θtrue=θ0)
    
    # Generate filamentary distribution
    logηε0 = manifold.generate_logηε(ε0)
    
    # Find point on manifold
    ξ0 = manifold.sample(fromtheta=True)
    
    # Run RWM
    THUGSampler = TangentialHugSampler(ξ0, T=B*s, B=B, N=N, α=0.0, logpi=logηε0, jac=manifold.fullJacobian)
    samples, acceptances = THUGSampler.sample()
    print("AP: {:.5f}".format(np.mean(acceptances)*100))
    return samples

def test_thug2(ε0, N, s=0.1, B=10):
    """Runs RWM to target filamentary distribution."""
    # Generate Manifold
    θ0        = array([3.0, 1.0, 2.0, 0.5])       # True parameter value on U(0, 10) scale.
    ystar     = data_generator(θ0, m, seed=1234)  # Observed data
    manifold  = GKManifold(ystar, kernel_type='uniform', use_autograd=False, θtrue=θ0)
    
    # Generate filamentary distribution
    logηε0 = manifold.generate_logηε(ε0)
    
    # Find point on manifold
    ξ0 = manifold.sample(fromtheta=True)
    
    # Proposal 
    q = MVN(zeros(len(ξ0)), ones(len(ξ0)))
    
    # Run RWM
    samples, acceptances = HugTangentialMultivariate(ξ0, T=B*s, B=B, N=N, α=0, q=q, logpi=logηε0, jac=manifold.fullJacobian)
    print("AP: {:.5f}".format(np.mean(acceptances)*100))
    return samples

# %% [markdown]
# ### RWM

# %%
OUT_RWM20 = test_rwm(ε0=20, N=10000, s=0.01)
# Out:
# AP: 96.09000

# %%
OUT_RWM10 = test_rwm(ε0=10, N=10000, s=0.01)
# Out:
# AP: 92.97000

# %%
OUT_RWM5 = test_rwm(ε0=5, N=10000, s=0.01)
# Out:
# AP: 87.06000

# %%
OUT_RWM1 = test_rwm(ε0=1, N=10000, s=0.01)
# Out:
# AP: 31.27000

# %%
OUT_RWM01 = test_rwm(ε0=0.1, N=10000, s=0.01)
# Out:
# AP: 0.10000

# %%
OUT_RWM001 = test_rwm(ε0=0.01, N=10000, s=0.01)
# Out:
# AP: 0.00000

# %% [markdown]
# ### THUG

# %%
OUT_THUG20 = test_thug(ε0=20, N=10000, s=0.01, B=5)
# Out:
# AP: 90.53000

# %%
OUT_THUG10 = test_thug(ε0=10, N=10000, s=0.01, B=5)
# Out:
# AP: 91.07000

# %%
OUT_THUG5 = test_thug(ε0=5, N=10000, s=0.01, B=5)
# Out:
# AP: 90.99000

# %%
OUT_THUG1 = test_thug(ε0=1, N=10000, s=0.01, B=10)
# Out:
# AP: 82.09000

# %%
OUT_THUG01 = test_thug(ε0=0.1, N=10000, s=0.01, B=10)
# Out:
# AP: 18.33000

# %%
OUT_THUG001 = test_thug(ε0=0.01, N=10000, s=0.01, B=10)
# Out:
# AP: 0.05000

# %%
OUT_THUG001_2 = test_thug2(ε0=0.01, N=10000, s=0.01, B=10)
# Out:
# AP: 0.05000

# %% [markdown]
# # Resampling

# %%
SOMETHING = MSAdaptive(generate_settings(
        d=d, 
        N=5000,
        B=B,
        δ=0.01,
        δmin=δmin,
        min_pm=min_pm,
        verbose=True,
        εs_fixed=None,
        adaptiveε=True,
        adaptiveδ=False,
        z0_manual=None,
        pm_target=0.23,
        pm_switch=pm_switch,
        prior_seed=1111,
        low_memory=True,
        integrator='rwm',
        εprop_switch=0.01,
        ε0_manual=None,
        quantile_value=0.5,
        initialization='prior',
        switch_strategy='pm',
        kernel='uniform',
        use_autograd=False,
        stopping_criterion={'εmin', 'pm'},
        resampling_seed=1234,
        mh_kernel_seed=1234,
        resampling_scheme='systematic'))
_ = SOMETHING.sample()
# Out:
# Integrator: RWM.
# Stopping criterion:  εmin, pm.
# Setting initial epsilon to εmax = 2530215592974.9248046875000000
# Iteration:  1
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 26533.7574199330774718
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8036000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  2
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 523.4121327192124227
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9526000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  3
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 89.3471706233462442
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9524000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  4
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 41.5471808617556562
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9544000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  5
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 27.1267664736254801
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9510000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  6
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 21.8446116812478515
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9534000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  7
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 19.4860064981693704
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9498000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  8
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 18.1814638713810766
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9504000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  9
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 17.4008613465408253
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9464000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  10
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 16.9248268284141687
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9442000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  11
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 16.3621822819412941
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9426000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  12
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 15.1543803698159181
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9490000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  13
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 13.9726602236549091
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9418000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  14
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 12.7541409889646964
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9404000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  15
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 11.5029247342261254
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9350000000000001
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  16
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 10.4296618874314042
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9346000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  17
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 9.4872739245026771
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9286000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  18
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 8.6756788390365891
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9204000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  19
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 8.0462148765941173
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9094000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  20
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 7.4965307258313434
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8996000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  21
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 7.0415553259075221
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8956000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  22
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 6.6450238620518709
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8914000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  23
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 6.2824201677522344
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8752000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  24
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 5.9734089833269532
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8610000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  25
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 5.7185009471003543
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8526000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  26
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 5.4897584466484739
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8401999999999999
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  27
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 5.2800381119558875
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8381999999999999
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  28
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 5.0904200311047187
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8304000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  29
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 4.9077429196338338
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8438000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  30
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 4.6995952047267613
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8464000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  31
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 4.4789284938013481
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8381999999999999
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  32
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 4.2877529869301458
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8250000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  33
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 4.1266818149766609
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8048000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  34
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 3.9815192563977044
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8070000000000001
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  35
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 3.8370678707399311
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8110000000000001
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  36
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 3.6925557980221226
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8052000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  37
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 3.5346689761908747
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8296000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  38
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 3.3662615010277430
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8254000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  39
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 3.1871274780924357
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8254000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  40
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 3.0168543232993903
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8132000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  41
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 2.8591874531341883
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8028000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  42
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 2.7128607440507713
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7850000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  43
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 2.5855268641040117
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7662000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  44
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 2.4689261344106948
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7596000000000001
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  45
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 2.3592145189455298
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7532000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  46
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 2.2556361183977041
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7368000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  47
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 2.1592635248283125
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7422000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  48
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 2.0637007506426110
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7154000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  49
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.9733227167413878
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.6912000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  50
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.8903972021200697
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.6966000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  51
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.8119588519246206
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.6718000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  52
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.7391127827423540
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.6682000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  53
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.6711413489248292
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.6486000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  54
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.6081485604441172
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.6206000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  55
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.5517555131855689
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.6056000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  56
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.4987345202461178
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.5921999999999999
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  57
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.4481995220043713
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.5694000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  58
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.4029823571907696
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.5490000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  59
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.3604163405038188
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.5318000000000001
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  60
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.3217358899236975
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.5246000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  61
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.2844490775188548
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.4922000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  62
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.2502853350341598
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.4770000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  63
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.2162620674745943
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.4564000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  64
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.1838605111459914
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.4536000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  65
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.1508485314460124
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.4494000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  66
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.1183454132340453
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.4450000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  67
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.0883923925506545
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.4242000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  68
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.0581543317072113
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.4088000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  69
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.0299759419860126
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.4000000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  70
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.0020043821009039
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.3874000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  71
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.9752307682253450
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.3636000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  72
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.9500108519520047
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.3474000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  73
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.9275289483577338
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.3068000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  74
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.9068299951140891
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.3022000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  75
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.8873797021755482
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2954000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  76
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.8672338488034392
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.3120000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  77
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.8442764217080840
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.3132000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  78
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.8188088964220765
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.3130000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  79
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7945406261839203
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2988000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  80
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7706136706574909
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2780000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  81
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7487738610882270
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2432000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  82
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7287753792125405
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2250000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  83
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7101898316572258
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1904000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  84
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.6934387555098604
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1650000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  85
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.6789780020858269
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1426000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  86
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.6650677469839981
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1310000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  87
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.6530630288799009
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1060000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  88
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.6419377547335174
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0950000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  89
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.6322120427888694
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0852000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  90
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.6221272777652891
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1002000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  91
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.6111474378159025
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0828000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  92
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.6020204055585301
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0706000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  93
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.5912582302429559
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0782000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  94
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.5815884620882134
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1316000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  95
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.5694349945037612
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1132000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  96
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.5551660116374837
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1052000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  97
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.5418818572105111
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0784000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  98
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.5314934249936936
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0978000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  99
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.5200704992488741
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0708000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  100
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.5128286826382646
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0446000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  101
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.5053503445106092
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0396000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  102
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.4986266091637626
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0328000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  103
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.4917430176883070
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0224000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  104
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.4850105614349237
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0120000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  105
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.4794729052455178
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0080000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  106
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.4746952450352417
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0116000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  107
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.4701306008795509
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0258000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  108
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.4626526431294954
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0170000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  109
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.4578796305182835
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0118000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  110
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.4523067947274222
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0062000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  111
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.4480789821574011
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0190000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  112
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.4431537527187431
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0052000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  113
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.4365443504281692
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0124000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  114
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.4293269296654713
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0004000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  115
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.4266631136327244
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0242000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  116
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.4228011090766387
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0014000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  117
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.4212065974894882
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0018000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  118
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.4185697564186289
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0018000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  119
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.4153210283061806
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2480000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  120
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.4116264703275875
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0024000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  121
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.4092760913359818
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0028000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  122
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.4069352355286133
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0000000000000000
# 	Step-size kept fixed at: 0.0100000000000000

# %%
SOMETHING2 = MSAdaptive(generate_settings(
        d=d, 
        N=5000,
        B=B,
        δ=0.01,
        δmin=δmin,
        min_pm=min_pm,
        verbose=True,
        εs_fixed=None,
        adaptiveε=True,
        adaptiveδ=False,
        z0_manual=None,
        pm_target=0.23,
        pm_switch=pm_switch,
        prior_seed=1111,
        low_memory=True,
        integrator='rwm',
        εprop_switch=0.01,
        ε0_manual=None,
        quantile_value=0.5,
        initialization='prior',
        switch_strategy='pm',
        kernel='uniform',
        use_autograd=False,
        stopping_criterion={'εmin', 'pm'},
        resampling_seed=1234,
        mh_kernel_seed=1234,
        resampling_scheme='multinomial'))
_ = SOMETHING2.sample()
# Out:
# Integrator: RWM.
# Stopping criterion:  εmin, pm.
# Setting initial epsilon to εmax = 2530215592974.9248046875000000
# Iteration:  1
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 26533.7574199330774718
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7782000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  2
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 496.5262376630601580
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9508000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  3
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 87.4223358885503359
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9496000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  4
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 42.3269224925861351
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9522000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  5
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 28.0465418610351058
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9490000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  6
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 22.6499050361835508
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9494000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  7
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 19.6868219804466804
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9478000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  8
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 18.0203480524858293
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9484000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  9
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 17.1670520158321196
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9480000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  10
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 16.2755628265215861
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9454000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  11
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 14.8326005090127140
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9454000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  12
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 13.6344825074805058
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9444000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  13
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 12.6195833372582911
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9356000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  14
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 11.6632940765439681
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9374000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  15
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 10.6536564024795979
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9226000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  16
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 9.7174160446906832
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9206000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  17
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 8.8563615940344711
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9126000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  18
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 8.1697310815968329
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9100000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  19
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 7.6009958492318699
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9014000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  20
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 7.0953778467458486
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8990000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  21
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 6.6815671623311843
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8710000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  22
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 6.3469664742822776
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8614000000000001
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  23
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 6.0618522099365544
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8600000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  24
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 5.8253332327828886
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8338000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  25
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 5.6300604618951180
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8336000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  26
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 5.4577954617391722
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8240000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  27
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 5.3056121423623424
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8194000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  28
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 5.1431555309072543
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8258000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  29
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 4.9568635836866228
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8336000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  30
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 4.7639178367864883
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8246000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  31
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 4.5776225326531792
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8286000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  32
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 4.4163407409966648
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8162000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  33
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 4.2789065329746618
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7970000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  34
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 4.1583603240968339
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8040000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  35
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 4.0456609481195169
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7884000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  36
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 3.9233067523896623
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7974000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  37
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 3.7847363363999809
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7962000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  38
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 3.6246265909826434
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7956000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  39
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 3.4484552479899175
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8040000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  40
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 3.2803368564166577
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8036000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  41
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 3.1098774626674834
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7948000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  42
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 2.9360655452367657
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7922000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  43
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 2.7628880359973103
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7856000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  44
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 2.6064697055354284
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7672000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  45
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 2.4601295740983806
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7504000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  46
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 2.3335868074575634
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7316000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  47
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 2.2194922943958444
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7136000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  48
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 2.1053975747268607
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7054000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  49
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.9994145794050830
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.6682000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  50
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.9075905039105676
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.6830000000000001
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  51
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.8240253609325046
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.6594000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  52
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.7452531411366885
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.6182000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  53
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.6738593293693147
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.6108000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  54
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.6063477121982528
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.6016000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  55
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.5468036753125503
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.5896000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  56
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.4885594803379798
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.5718000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  57
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.4290645750804511
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.5914000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  58
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.3607214419280076
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.5782000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  59
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.2876536653376485
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.5740000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  60
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.2178507063736213
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.5584000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  61
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.1593873807814907
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.5298000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  62
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.1076603652441099
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.4796000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  63
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.0652728483290139
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.4276000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  64
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.0314064856878566
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.4240000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  65
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.9989366210224965
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.3724000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  66
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.9715050857616345
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.3516000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  67
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.9461530413801575
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.3204000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  68
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.9228899349651524
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2990000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  69
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.8997604677808763
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.3010000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  70
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.8786956548061988
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2814000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  71
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.8601187643517270
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2804000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  72
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.8405132018497197
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2732000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  73
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.8204015096033922
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.3194000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  74
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7932175096895450
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.3494000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  75
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7602508533300510
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.3820000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  76
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7241965008693679
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.3364000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  77
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.6941623033070867
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2868000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  78
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.6678154040891169
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2720000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  79
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.6426414280551074
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2408000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  80
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.6225153871298013
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2284000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  81
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.6025000585890657
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2022000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  82
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.5821733192866039
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1586000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  83
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.5660869144961952
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1656000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  84
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.5494315380023413
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1282000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  85
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.5356101334832771
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1188000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  86
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.5232750472057663
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0970000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  87
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.5104299091204881
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1162000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  88
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.4993310553609988
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0998000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  89
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.4885802701226027
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0722000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  90
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.4779786107013168
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0682000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  91
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.4684095014658740
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0894000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  92
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.4570597380804129
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0714000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  93
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.4453588642688812
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1076000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  94
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.4345259653524023
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0902000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  95
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.4246770162266278
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0492000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  96
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.4132603631654471
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0368000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  97
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.4019696686190241
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1176000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  98
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.3922322902708556
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0804000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  99
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.3817769680038406
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0576000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  100
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.3729101210971598
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0390000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  101
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.3649400376071349
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0368000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  102
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.3574436747054132
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0228000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  103
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.3495004667621865
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0152000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  104
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.3417508789105776
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1370000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  105
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.3360998915643883
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0132000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  106
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.3302200783278901
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0126000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  107
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.3263496605049842
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0100000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  108
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.3197301732990785
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0026000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  109
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.3137086367107733
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0914000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  110
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.3118106859410083
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0036000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  111
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.3083124831500900
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0012000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  112
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.3031190687525896
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0008000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  113
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.2999552441157272
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0082000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  114
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.2982284067953887
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0012000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  115
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.2972793510539290
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0000000000000000
# 	Step-size kept fixed at: 0.0100000000000000

# %%
SOMETHING3 = MSAdaptive(generate_settings(
        d=d, 
        N=5000,
        B=B,
        δ=0.01,
        δmin=δmin,
        min_pm=min_pm,
        verbose=True,
        εs_fixed=None,
        adaptiveε=True,
        adaptiveδ=False,
        z0_manual=None,
        pm_target=0.23,
        pm_switch=pm_switch,
        prior_seed=1111,
        low_memory=True,
        integrator='rwm_then_thug',
        εprop_switch=0.01,
        ε0_manual=None,
        quantile_value=0.5,
        initialization='prior',
        switch_strategy='pm',
        kernel='uniform',
        use_autograd=False,
        stopping_criterion={'εmin', 'pm'},
        resampling_seed=1234,
        mh_kernel_seed=1234,
        resampling_scheme='systematic'))
_ = SOMETHING3.sample()
# Out:
# Integrator: RWM.
# Stopping criterion:  εmin, pm.
# Resampling: SYSTEMATIC.
# Setting initial epsilon to εmax = 2530215592974.9248046875000000
# Iteration:  1
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 26533.7574199330774718
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7942000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  2
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 542.2422203324617840
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9520000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  3
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 89.7451291016806749
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9552000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  4
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 42.4833321150171557
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9550000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  5
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 27.3807629572561133
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9468000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  6
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 21.8001766263481329
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9470000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  7
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 19.1930885919445942
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9512000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  8
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 17.8864511865758402
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9510000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  9
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 17.1579668514560595
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9442000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  10
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 16.6452643653530181
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9444000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  11
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 15.7501745120934125
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9514000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  12
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 14.7204294181793909
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9426000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  13
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 13.5789107224310701
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9354000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  14
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 12.3929108062496418
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9374000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  15
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 11.1559584840005126
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9376000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  16
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 9.9948798878072154
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9326000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  17
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 9.0252350064878559
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9174000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  18
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 8.2293355666327042
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9200000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  19
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 7.5788151764215428
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9116000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  20
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 7.0530348164950141
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8978000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  21
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 6.6010304083026794
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8918000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  22
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 6.2240721280045204
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8808000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  23
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 5.8804782803713547
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8640000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  24
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 5.5677370106191741
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8694000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  25
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 5.2429206112353093
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8476000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  26
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 4.9614720672869197
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8450000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  27
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 4.7320854471438460
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8258000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  28
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 4.5409142273663345
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8004000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  29
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 4.3762493025201357
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7924000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  30
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 4.2370563400654939
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7720000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  31
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 4.1147214921652173
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7658000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  32
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 4.0139855099984842
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7622000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  33
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 3.9248116943829991
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7616000000000001
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  34
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 3.8322720404578647
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7880000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  35
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 3.7273368141536736
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7772000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  36
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 3.6315005639887210
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7688000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  37
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 3.5384370697669554
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7688000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  38
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 3.4505816475018047
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7730000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  39
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 3.3631811276545216
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7602000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  40
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 3.2767088480101441
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7568000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  41
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 3.1848433354525252
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7464000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  42
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 3.0990757870498533
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7458000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  43
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 3.0155496298453008
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7498000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  44
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 2.9266060517766608
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7412000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  45
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 2.8351771732578968
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7508000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  46
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 2.7443899017013034
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7428000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  47
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 2.6484387153047710
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7402000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  48
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 2.5507669969542288
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7444000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  49
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 2.4490147943978116
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7496000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  50
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 2.3320354655261530
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7568000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  51
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 2.2130624296503481
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7346000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  52
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 2.1107156033825021
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7146000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  53
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 2.0240127224090148
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.6914000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  54
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.9451872825727747
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.6889999999999999
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  55
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.8708585653184586
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.6490000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  56
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.8017351727314066
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.6384000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  57
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.7385306260247981
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.6244000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  58
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.6790191430650652
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.5952000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  59
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.6254579942644201
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.5804000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  60
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.5757746919675184
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.5586000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  61
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.5325642635276573
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.5370000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  62
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.4937349591050928
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.5272000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  63
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.4583846564085294
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.4984000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  64
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.4246203195070866
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.4984000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  65
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.3922511485516116
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.4790000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  66
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.3602941551231669
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.4638000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  67
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.3280848205613451
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.4718000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  68
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.2970774292928990
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.4748000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  69
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.2683007322294100
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.4570000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  70
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.2397172599979758
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.4492000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  71
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.2135113500202723
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.3958000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  72
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.1910353706309227
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.3704000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  73
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.1713312685458452
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.3630000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  74
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.1523497970400725
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.3366000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  75
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.1352808395677467
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.3078000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  76
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.1201857209299113
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2808000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  77
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.1057513648691177
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2698000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  78
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.0942618704065989
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2364000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  79
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.0831288601892037
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.2000000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  80
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.0736368063585775
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1864000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  81
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.0655845021666757
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1806000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  82
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.0576483651453599
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1776000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  83
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.0506754405022101
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1590000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  84
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.0431611423125178
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1506000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  85
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.0361949210188004
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1698000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  86
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.0275142217483120
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1792000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  87
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.0188539781586736
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1724000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  88
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.0097978389580171
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1622000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  89
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 1.0005274383016021
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1516000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  90
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.9925019875415489
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1140000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  91
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.9858877350446648
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1590000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  92
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.9794475942453413
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1106000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  93
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.9731425370262303
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0838000000000000
# 	Step-size kept fixed at: 0.0100000000000000
#
#
# ####################################
# ### SWITCHING TO THUG INTEGRATOR ###
# ####################################
#
#
# Iteration:  94
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.9684774702844907
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9440000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  95
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.9623175320770514
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9472000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  96
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.9556178902752053
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9478000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  97
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.9482549705795840
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9444000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  98
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.9406945479799762
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9396000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  99
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.9328325254516505
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9414000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  100
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.9252407122524331
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9366000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  101
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.9184613746892751
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9338000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  102
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.9122601611485697
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9388000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  103
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.9062248630031368
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9429999999999999
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  104
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.9002223601963686
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9408000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  105
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.8947882338133789
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9419999999999999
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  106
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.8895282548973360
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9444000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  107
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.8845800469786065
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9384000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  108
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.8799361843368948
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9366000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  109
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.8760089946836134
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9304000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  110
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.8730944373022129
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9300000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  111
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.8704748727891589
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9342000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  112
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.8682361571333125
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9322000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  113
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.8656835107486804
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9316000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  114
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.8614142788933190
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9404000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  115
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.8541770011914022
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9360000000000001
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  116
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.8489694879191086
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9326000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  117
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.8451254386258178
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9300000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  118
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.8417928519890089
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9280000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  119
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.8389499288699793
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9306000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  120
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.8363439873649479
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9248000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  121
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.8338238120001618
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9166000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  122
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.8314236430917136
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9198000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  123
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.8291205637297221
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9176000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  124
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.8269801368374516
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9160000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  125
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.8249657916082378
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9124000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  126
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.8225927102522590
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9304000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  127
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.8198598145240015
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9282000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  128
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.8173023290480521
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9266000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  129
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.8151295853149649
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9226000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  130
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.8132989653379796
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9116000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  131
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.8118383245864883
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9058000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  132
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.8104080436318637
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9166000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  133
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.8088349190877597
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9192000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  134
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.8072876834549340
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9248000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  135
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.8058798632061772
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9198000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  136
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.8046034271256102
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9182000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  137
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.8034556473569434
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9224000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  138
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.8024011380102686
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9056000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  139
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.8015078020411107
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9032000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  140
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.8006763423043572
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9020000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  141
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7999879672009391
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9070000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  142
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7993881620477215
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8986000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  143
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7988530421254907
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9052000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  144
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7982716776526858
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9104000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  145
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7972975500973493
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9194000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  146
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7962802203691872
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9216000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  147
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7955327314652243
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9026000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  148
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7950156800281294
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8946000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  149
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7945872186698362
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8792000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  150
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7942398568894075
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8683999999999999
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  151
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7939215926954031
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8638000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  152
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7936443720092909
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8576000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  153
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7933959784602860
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8462000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  154
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7931665616295177
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8562000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  155
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7929246556175823
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8642000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  156
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7926527843506058
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8622000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  157
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7922813571788974
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8756000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  158
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7917924734697115
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8786000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  159
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7913655182331434
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8668000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  160
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7910468147305869
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8572000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  161
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7907995785147846
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8476000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  162
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7905854287034592
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8420000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  163
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7903930591671400
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8348000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  164
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7902126029525918
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8460000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  165
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7900146147456845
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8574000000000001
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  166
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7898029218154348
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8282000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  167
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7896376545681176
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8312000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  168
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7895024888759397
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8190000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  169
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7893771724511492
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8210000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  170
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7892573605540069
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8200000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  171
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7891311192988769
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8198000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  172
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7890101293357753
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8226000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  173
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7888975137663553
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8220000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  174
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7887773827310166
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8242000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  175
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7886500930925996
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8204000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  176
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7885254003300247
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8242000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  177
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7884004324512437
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8248000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  178
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7882701388510471
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8342000000000001
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  179
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7881523625591583
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8276000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  180
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7880381958524167
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8256000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  181
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7879319735973168
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8128000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  182
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7878226862560239
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8292000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  183
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7877111123759204
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8270000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  184
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7875976710636041
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8184000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  185
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7874772835428054
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8188000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  186
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7873422028181716
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8278000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  187
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7872138030689108
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8350000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  188
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7870928717300355
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8216000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  189
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7869701099133427
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8296000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  190
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7868565872200899
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8176000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  191
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7867506663165814
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8108000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  192
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# ...
# 	Epsilon: 0.7733355118204157
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8410000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  345
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7732025791820900
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8552000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  346
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7730914993379092
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8400000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  347
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7730027929677754
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8244000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  348
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7729287175786860
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8224000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  349
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7728570148089534
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8126000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  350
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7727847839412985
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8320000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  351
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7727098232358111
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8258000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  352
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7726398198198992
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8048000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  353
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7725728236185517
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8172000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  354
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7725130329778392
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8120000000000001
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  355
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7724520053286961
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8094000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  356
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7723908027446755
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8196000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  357
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7723247665783306
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8116000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  358
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7722481234658205
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8250000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  359
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7721695399664505
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8224000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  360
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7720947900607056
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8330000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  361
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7720207676123404
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8136000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  362
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7719527776996947
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8169999999999999
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  363
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7718886245203982
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8010000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  364
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7718257125935075
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8016000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  365
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7717663525380256
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8078000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  366
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7717045790398891
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8096000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  367
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7716303589546780
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8248000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  368
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7715400092153017
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8302000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  369
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7714522021945360
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8322000000000001
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  370
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7713703019878123
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8154000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  371
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7712897265868488
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8248000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  372
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7712016100894936
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8250000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  373
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7711022713354621
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8120000000000001
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  374
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7710222896978480
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8028000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  375
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7709524088258999
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8148000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  376
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7708869860163796
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8012000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  377
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7708151050337627
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8098000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  378
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7707428254127818
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8174000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  379
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7706729053910093
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8032000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  380
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7706085766734877
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8092000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  381
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7705403188995221
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8102000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  382
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7704702013210065
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8088000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  383
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7704067163626570
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7954000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  384
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7703487948437875
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7912000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  385
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7702928028684399
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7922000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  386
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7702345059449366
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7994000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  387
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7701795931501275
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7922000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  388
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7701194879855254
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8096000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  389
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7700507885391982
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8210000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  390
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7699865155983183
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7994000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  391
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7699259470624028
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8006000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  392
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7698660042342862
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8044000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  393
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7698008916631136
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8076000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  394
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7697361987185736
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8008000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  395
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7696740232272411
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7894000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  396
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7696162779553668
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7998000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  397
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7695616952259401
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8136000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  398
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7695015293171890
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8208000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  399
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7694365297280150
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8114000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  400
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7693692030277647
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8234000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  401
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7692963261097354
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8146000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  402
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7692285070959775
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8080000000000001
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  403
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7691620351614605
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8218000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  404
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7690921250646909
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8156000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  405
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7690244740655601
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8128000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  406
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7689611057759111
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8104000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  407
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 0.7689070353312044
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7882000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  408
# 	Quantile Value:  0.5
# ValueError was raised:

# %%
fig, ax = plt.subplots()
ax.plot(SOMETHING.εs, label='systematic')
ax.plot(SOMETHING2.εs, label='multinomial')
ax.set_yscale('log')
ax.legend()
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(SOMETHING.εs[1:], SOMETHING.Wbar[1:].var(axis=1), label='MS-RWM')
# ax.plot(SOMETHING2.Wbar[1:].var(axis=1), label='RWMmultinomial')
ax.plot(SOMETHING3.εs[1:], SOMETHING3.Wbar[1:].var(axis=1), label='MS-RT')
ax.set_yscale('log')
ax.set_xscale('log')
ax.legend()
plt.show()
