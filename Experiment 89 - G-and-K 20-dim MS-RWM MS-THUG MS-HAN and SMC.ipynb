# %% [markdown]
# # Aim to test various characcteristics of the problem

# %% [markdown]
# ### Various functions and settings

# %%
import numpy as np
from numpy import zeros, eye, array, diag, exp, ones, tanh, cosh, dstack, log, hstack, vstack, sinh
from numpy.linalg import solve, norm
from numpy.random import choice, default_rng, randint, randn
from scipy.stats import multivariate_normal as MVN
from scipy.special import logsumexp, ndtr
from scipy.stats import uniform as udist
import math
import time
from copy import deepcopy

import matplotlib.pyplot as plt
from matplotlib import rc
from ipywidgets.widgets import IntSlider
from ipywidgets.widgets import interact
from warnings import resetwarnings, catch_warnings, filterwarnings
import seaborn as sns

from Manifolds.GKManifoldNew import GKManifold, data_generator, find_point_on_manifold, find_point_on_manifold_from_θ
from markov_snippets import MSAdaptive, SMCAdaptive
from tangential_hug_functions import TangentialHugSampler
from tangential_hug_functions import HugTangentialMultivariate
from RWM import RWM
from utils import ESS_univariate

# %%
seed = 1234
m = 20     # number of latent variables
d = m + 4  # dimensionality of x-component

# %%
def generate_settings(
    d=d, 
    N=2000,
    B=20,
    δ=0.01,
    δmin=1e-3,
    δmax=100.0,
    εmin=1e-16,
    min_pm=1e-4,
    maxiter=500,
    verbose=False,
    εs_fixed=None,
    adaptiveε=True,
    adaptiveδ=False,
    z0_manual=None,
    pm_target=0.23,
    pm_switch=0.1,
    prior_seed=seed,
    low_memory=True,
    integrator='rwm',
    εprop_switch=0.01,
    ε0_manual=None,
    quantile_value=0.9,
    initialization='manual',
    switch_strategy='pm',
    kernel='uniform',
    prior_scale=7,
    thinning=10,
    burnin=100,
    use_autograd=False,
    stopping_criterion={'εmin', 'pm'},
    resampling_seed=1234,
    mh_kernel_seed=1234,
    resampling_scheme='multinomial',
    prop_hug=0.5,
    projection_method='qr',
    metropolised=False):
    # here d represents m+4
    # Generate the manifold
    θ0        = array([3.0, 1.0, 2.0, 0.5])       # True parameter value on U(0, 10) scale.
    ystar     = data_generator(θ0, m, seed=seed)  # Observed data
    q         = MVN(zeros(d), eye(d))             # Proposal distribution for THUG
    resetwarnings()
    manifold  = GKManifold(ystar, kernel_type=kernel, use_autograd=use_autograd)
    # grab arguments
    arguments = locals()
    return arguments

# %%
def generate_initial_particles(ϵ0, N=5000, s=0.001):
    # Generate Manifold
    θ0        = array([3.0, 1.0, 2.0, 0.5])       # True parameter value on U(0, 10) scale.
    ystar     = data_generator(θ0, m, seed=1234)  # Observed data
    resetwarnings()
    manifold  = GKManifold(ystar, kernel_type='uniform', use_autograd=False, θtrue=θ0)

    # Generate target distribution
    ξ0 = manifold.sample()               # Initial point on manifold                            # Starting epsilon
    logηε0 = manifold.generate_logηε(ε0)  # Target filamentary distribution

    # Sample from it using RWM
    s_rwm, a_rwm = RWM(x0=ξ0, s=s, N=N, logpi=logηε0)

    # Add velocities to particles
    v0_manual = randn(*s_rwm.shape)
    z0_manual = np.hstack((s_rwm, v0_manual))
    return z0_manual

def generate_initial_particles_on_manifold(N=5000, θtrue=False):
    # Generate Manifold
    θ0        = array([3.0, 1.0, 2.0, 0.5])       # True parameter value on U(0, 10) scale.
    ystar     = data_generator(θ0, m, seed=1234)  # Observed data
    resetwarnings()
    manifold  = GKManifold(ystar, kernel_type='uniform', use_autograd=False, θtrue=θ0)
    # Sample N times
    x0_manual = np.vstack([manifold.sample(fromtheta=θtrue) for _ in range(N)])
    v0_manual = randn(*x0_manual.shape)
    return np.hstack((x0_manual, v0_manual))

def generate_particles_on_manifold_then_rwm(ϵ0, N=5000, θtrue=False, δrwm=0.001):
    """First, generate particles on the manifold. Then use RWM to actually sample from a filamentary
    distribution of sorts."""
    # Generate manifold (used only to generate filamentary distribution)
    θ0        = array([3.0, 1.0, 2.0, 0.5])       # True parameter value on U(0, 10) scale.
    ystar     = data_generator(θ0, m, seed=1234)  # Observed data
    manifold  = GKManifold(ystar, kernel_type='uniform', use_autograd=False, θtrue=θ0)
    # Sample on manifold
    on_manifold = generate_initial_particles_on_manifold(N=N, θtrue=θtrue)
    x0_on_manifold = on_manifold[:, :on_manifold.shape[1]//2]
    # Store filamentary samples
    filamentary_samples = []
    for x0 in x0_on_manifold:
        filamentary_samples.append(RWM(x0, s=δrwm, N=1, logpi=manifold.generate_logηε(ϵ0))[0].flatten())
    # Create array
    v0_manual = randn(*x0_on_manifold.shape)
    x0_manual = np.vstack(filamentary_samples)
    return np.hstack((x0_manual, v0_manual))

def sample_from_filamentary(ε0, N=2000, n_per_sample=10, s=1.0, fromtheta=False):
    samples = []
    acceptances = []
    # Generate Manifold
    θ0        = array([3.0, 1.0, 2.0, 0.5])       # True parameter value on U(0, 10) scale.
    ystar     = data_generator(θ0, m, seed=1234)  # Observed data
    resetwarnings()
    manifold  = GKManifold(ystar, kernel_type='uniform', use_autograd=False, θtrue=θ0)
    # Construct filamentary distribution
    logηε0 = manifold.generate_logηε(ε0)
    while len(acceptances) < N:
        with catch_warnings():
            filterwarnings('error')
            try:
                # Sample on the manifold
                ξ0 = manifold.sample(fromtheta=fromtheta)
                # Sample starting from ξ0 and perform 10 steps of RWM. Grab the final point
                s_rwm, a_rwm = RWM(x0=ξ0, s=s, N=n_per_sample, logpi=logηε0)
                samples.append(s_rwm[-1])
                acceptances.append(np.mean(a_rwm)) #int(sum(a_rwm == 1) > 0))
            except RuntimeWarning:
                continue
    print("Acceptance Probability: {:.3f}".format(np.mean(acceptances)*100))
    x0_manual = vstack(samples)
    v0_manual = v0_manual = randn(*x0_manual.shape)
    return hstack((x0_manual, v0_manual))

def sample_from_filamentary_with_thug(ε0, N=2000, n_per_sample=10, s=1.0, fromtheta=False):
    samples = []
    acceptances = []
    # Generate Manifold
    θ0        = array([3.0, 1.0, 2.0, 0.5])       # True parameter value on U(0, 10) scale.
    ystar     = data_generator(θ0, m, seed=1234)  # Observed data
    resetwarnings()
    manifold  = GKManifold(ystar, kernel_type='uniform', use_autograd=False, θtrue=θ0)
    # Construct filamentary distribution
    logηε0 = manifold.generate_logηε(ε0)
    while len(acceptances) < N:
        with catch_warnings():
            filterwarnings('error')
            try:
                # Sample on the manifold
                ξ0 = manifold.sample(fromtheta=fromtheta)
                # Sample starting from ξ0 and perform 10 steps of RWM. Grab the final point
                THUG = TangentialHugSampler(ξ0, T=5*s, B=5, N=N, α=0.0, logpi=logηε0, jac=manifold.fullJacobian)
                s_thug, a_thug = THUG.sample() #(x0=ξ0, s=s, N=n_per_sample, logpi=logηε0)
                samples.append(s_thug[-1])
                acceptances.append(np.mean(a_thug)) #int(sum(a_rwm == 1) > 0))
            except RuntimeWarning:
                continue
    print("Acceptance Probability: {:.3f}".format(np.mean(acceptances)*100))
    x0_manual = vstack(samples)
    v0_manual = v0_manual = randn(*x0_manual.shape)
    return hstack((x0_manual, v0_manual))

# %%
N      = 5000
B      = 20
δmin   = 1e-3
min_pm = 1e-4
pm_switch = 0.1
quantile_value = 0.9

# %% [markdown]
# # Ideas

# %% [markdown]
# ### Prior Initialization

# %% [markdown]
# I want to run MS-RWM, MS-HUG, MS-HAN starting from the prior and see what $\varepsilon$s and acceptance probabilities we obtain.
#
# - Seems that MS-RWM with adaptive step size (with small $\delta_{\text{min}}$) can reach fairly small tolerances. Therefore there doesn't necessarily seem to a be an inherent problem of the G-and-K task with reaching small epsilons. More experiments are needed.
# - Seems that MS-HUG on its own is quite slow at reaching small epsilons. This makes sense, it is designed to stay close to the current level-set, so the distances of the particles from the manifold don't change much at all.
#     - either I let it go for a very long time
#     - or I should accelerate at the beginning and only after switch to HUG or HAN.
# - Need to check if HAN on its own with `prop_hug=0.5` is enough to be able to reach small epsilon faster than HUG on its own, and hopefully achieve smaller epsilon than RMW. So far, HAN seems pretty good at keeping a very high AP as it decreases epsilon.
# - However, also HAN seems to be slowing down before reaching truly filamentary distributions. Perhaps I need a slightly larger step size. I need to be careful because starting the algorithm from the prior with $\delta=0.1$ leads to overflow error in the Jacobian computation (unsure why). For this reason, I am using $\delta=0.01$, however it might be that something like $\delta=0.05$ might be better. Alternatively, I could try and use adaptive $\delta$ just to see if it is even possible to get to filamentary distributions. One I reach those, it will be interesting to look at the histograms of the indeces.
# - MS-HAN with adaptive $\delta$ fails. More specifically, the Jacobian computation fails. Unsure why. Seems that with a large enough step size, that happens. Need to explore that.

# %% [markdown]
# ### Filamentary Initialization

# %% [markdown]
# I want to initialize the particles from $\eta_{\varepsilon_0}$ for some $\varepsilon_0$. Unsure what the correct choice would be. Either way, I need to make sure that the samples are somewhat good.
#
# - One option is to take the final particles and final $\epsilon$ from a run of MS-RWM and run MS-HUG or MS-HAN in manual mode from these particles. Hopefully, one should see that MS-HAN will be able to achieve somewhat small epsilon faster, but MS-HUG should, in theory, be able to achieve smallER epsilons, once it gets there.

# %% [markdown]
# ## Prior Initialization

# %% [markdown]
# ### MS-RWM

# %% [markdown]
# ##### Step-size=0.01

# %%
ms_rwm_001_05 = MSAdaptive(generate_settings(
        d=d, 
        N=N,
        B=B,
        δ=0.01,
        δmin=δmin,
        min_pm=min_pm,
        verbose=True,
        εs_fixed=None,
        adaptiveε=True,
        adaptiveδ=False,
        z0_manual=None,
        pm_target=0.23,
        pm_switch=pm_switch,
        prior_seed=1111,
        low_memory=True,
        integrator='rwm',
        εprop_switch=0.01,
        ε0_manual=None,
        quantile_value=0.5,
        initialization='prior',
        switch_strategy='pm',
        kernel='uniform',
        use_autograd=False,
        stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_seed=1234,
        mh_kernel_seed=1234,
        resampling_scheme='multinomial',
        maxiter=150))
ms_rwm_001_05_particles = ms_rwm_001_05.sample()
# Out:
# Integrator: RWM.
# Stopping criterion:  maxiter, εmin, pm.
# Resampling: MULTINOMIAL.
# Setting initial epsilon to εmax = 2530215592974.9248046875000000
# Iteration:  1
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 26533.7574199330774718
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7782000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  2
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 496.5262376630601580
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9528000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  3
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 90.4798063082705681
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9496000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  4
# 	Quantile Value:  0.5
# ...

# %% [markdown]
# ##### Step-size=0.1

# %%
ms_rwm_01_05 = MSAdaptive(generate_settings(
        d=d, 
        N=N,
        B=B,
        δ=0.1,
        δmin=δmin,
        min_pm=min_pm,
        verbose=True,
        εs_fixed=None,
        adaptiveε=True,
        adaptiveδ=False,
        z0_manual=None,
        pm_target=0.23,
        pm_switch=pm_switch,
        prior_seed=1111,
        low_memory=True,
        integrator='rwm',
        εprop_switch=0.01,
        ε0_manual=None,
        quantile_value=0.5,
        initialization='prior',
        switch_strategy='pm',
        kernel='uniform',
        use_autograd=False,
        stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_seed=1234,
        mh_kernel_seed=1234,
        resampling_scheme='multinomial',
        maxiter=150))
ms_rwm_01_05_particles = ms_rwm_01_05.sample()
# Out:
# Integrator: RWM.
# Stopping criterion:  maxiter, εmin, pm.
# Resampling: MULTINOMIAL.
# Setting initial epsilon to εmax = 2530215592974.9248046875000000
# Iteration:  1
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 26533.7574199330774718
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0960000000000000
# 	Step-size kept fixed at: 0.1000000000000000
# Iteration:  2
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 598.1570002365729124
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8812000000000000
# 	Step-size kept fixed at: 0.1000000000000000
# Iteration:  3
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 94.3808410515471650
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9274000000000000
# 	Step-size kept fixed at: 0.1000000000000000
# Iteration:  4
# 	Quantile Value:  0.5
# ...

# %% [markdown]
# ##### Adaptive step size

# %%
ms_rwm_aδ_05 = MSAdaptive(generate_settings(
        d=d, 
        N=N,
        B=B,
        δ=0.1,
        δmin=1e-5,
        δmax=100.0,
        min_pm=min_pm,
        verbose=True,
        εs_fixed=None,
        adaptiveε=True,
        adaptiveδ=True,
        z0_manual=None,
        pm_target=0.23,
        pm_switch=pm_switch,
        prior_seed=1111,
        low_memory=True,
        integrator='rwm',
        εprop_switch=0.01,
        ε0_manual=None,
        quantile_value=0.5,
        initialization='prior',
        switch_strategy='pm',
        kernel='uniform',
        use_autograd=False,
        stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_seed=1234,
        mh_kernel_seed=1234,
        resampling_scheme='multinomial',
        maxiter=500))
ms_rwm_aδ_05_particles = ms_rwm_aδ_05.sample()
# Out:
# Integrator: RWM.
# Stopping criterion:  maxiter, εmin, pm.
# Resampling: MULTINOMIAL.
# Setting initial epsilon to εmax = 2530215592974.9248046875000000
# Iteration:  1
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 26533.7574199330774718
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0960000000000000
# 	Step-size adapted to: 0.0935195201336777
# Iteration:  2
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 598.1570002365729124
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9220000000000000
# 	Step-size adapted to: 0.1321807343869539
# Iteration:  3
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 92.6270679994694888
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7936000000000000
# 	Step-size adapted to: 0.1752073598660959
# Iteration:  4
# 	Quantile Value:  0.5
# ...

# %% [markdown]
# ### MS-HUG

# %% [markdown]
# ##### Step-size=0.1

# %%
ms_hug_01_05 = MSAdaptive(generate_settings(
        d=d, 
        N=N,
        B=B,
        δ=0.1,
        δmin=δmin,
        min_pm=min_pm,
        verbose=True,
        εs_fixed=None,
        adaptiveε=True,
        adaptiveδ=False,
        z0_manual=None,
        pm_target=0.23,
        pm_switch=pm_switch,
        prior_seed=1111,
        low_memory=True,
        integrator='thug',
        εprop_switch=0.01,
        ε0_manual=None,
        quantile_value=0.5,
        initialization='prior',
        switch_strategy='pm',
        kernel='uniform',
        use_autograd=False,
        stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_seed=1234,
        mh_kernel_seed=1234,
        resampling_scheme='multinomial',
        maxiter=200))
ms_hug_01_05_particles = ms_hug_01_05.sample()
# Out:
# Integrator: THUG.
# Stopping criterion:  maxiter, εmin, pm.
# Resampling: MULTINOMIAL.
# Setting initial epsilon to εmax = 2530215592974.9248046875000000
# Iteration:  1
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 26533.7574199330774718
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1798000000000000
# 	Step-size kept fixed at: 0.1000000000000000
# Iteration:  2
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 675.7676929938770627
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8954000000000000
# 	Step-size kept fixed at: 0.1000000000000000
# Iteration:  3
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 108.1038500114849228
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8734000000000000
# 	Step-size kept fixed at: 0.1000000000000000
# Iteration:  4
# ...

# %% [markdown]
# ### MS-HAN

# %% [markdown]
# ##### Step-size=0.01

# %%
ms_han_001_05 = MSAdaptive(generate_settings(
        d=d, 
        N=N,
        B=B,
        δ=0.01,
        δmin=δmin,
        min_pm=min_pm,
        verbose=True,
        εs_fixed=None,
        adaptiveε=True,
        adaptiveδ=False,
        z0_manual=None,
        pm_target=0.23,
        pm_switch=pm_switch,
        prior_seed=1111,
        low_memory=True,
        integrator='hug_and_nhug',
        εprop_switch=0.01,
        ε0_manual=None,
        quantile_value=0.5,
        initialization='prior',
        switch_strategy='pm',
        kernel='uniform',
        use_autograd=False,
        stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_seed=1234,
        mh_kernel_seed=1234,
        resampling_scheme='multinomial',
        maxiter=500,
        prop_hug=0.5))
ms_han_001_05_particles = ms_han_001_05.sample()
# Out:
# Integrator: HUG + NHUG.
# Prop Hug  :  0.5
# Stopping criterion:  maxiter, εmin, pm.
# Resampling: MULTINOMIAL.
# Setting initial epsilon to εmax = 2530215592974.9248046875000000
# Iteration:  1
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 26533.7574199330774718
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8474000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  2
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 607.4206711711401567
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9532000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  3
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 100.6784783233150620
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9588000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# ...

# %%
import re
pattern = r'Epsilon: (\d+\.\d+)'
matches = re.findall(pattern, printed_text)
epsilon_values = np.array([float(match) for match in matches])
prop_moved = np.array([float(match) for match in re.findall(r'Prop Moved: (\d+\.\d+)', printed_text)])
ms_han_001_05_particles = ms_han_001_05

# %% [markdown]
# ##### Step-size=0.05

# %%
ms_han_005_05 = MSAdaptive(generate_settings(
        d=d, 
        N=N,
        B=B,
        δ=0.05,
        δmin=δmin,
        min_pm=min_pm,
        verbose=True,
        εs_fixed=None,
        adaptiveε=True,
        adaptiveδ=False,
        z0_manual=None,
        pm_target=0.23,
        pm_switch=pm_switch,
        prior_seed=1111,
        low_memory=True,
        integrator='hug_and_nhug',
        εprop_switch=0.01,
        ε0_manual=None,
        quantile_value=0.5,
        initialization='prior',
        switch_strategy='pm',
        kernel='uniform',
        use_autograd=False,
        stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_seed=1234,
        mh_kernel_seed=1234,
        resampling_scheme='multinomial',
        maxiter=500,
        prop_hug=0.5))
ms_han_005_05_particles = ms_han_005_05.sample()
# Out:
# Integrator: HUG + NHUG.
# Prop Hug  :  0.5
# Stopping criterion:  maxiter, εmin, pm.
# Resampling: MULTINOMIAL.
# Setting initial epsilon to εmax = 2530215592974.9248046875000000
# Iteration:  1
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 26533.7574199330774718
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.4080000000000000
# 	Step-size kept fixed at: 0.0500000000000000
# Iteration:  2
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 645.7182393034856887
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9532000000000000
# 	Step-size kept fixed at: 0.0500000000000000
# Iteration:  3
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 105.4885124951479014
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9484000000000000
# 	Step-size kept fixed at: 0.0500000000000000
# ...

# %% [markdown]
# ##### Step-size: adaptive

# %%
ms_han_aδ_05_060 = MSAdaptive(generate_settings(
        d=d, 
        N=N,
        B=B,
        δ=0.01,
        δmin=δmin,
        δmax=1.0,
        min_pm=min_pm,
        verbose=True,
        εs_fixed=None,
        adaptiveε=True,
        adaptiveδ=True,
        z0_manual=None,
        pm_target=0.60,
        pm_switch=pm_switch,
        prior_seed=1111,
        low_memory=True,
        integrator='hug_and_nhug',
        εprop_switch=0.01,
        ε0_manual=None,
        quantile_value=0.5,
        initialization='prior',
        switch_strategy='pm',
        kernel='uniform',
        use_autograd=False,
        stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_seed=1234,
        mh_kernel_seed=1234,
        resampling_scheme='multinomial',
        maxiter=500,
        prop_hug=0.5,
        projection_method='qr'))
ms_han_aδ_05_060_particles = ms_han_aδ_05_060.sample()
# Out:
# Integrator: HUG + NHUG.
# Prop Hug  :  0.5
# Stopping criterion:  maxiter, εmin, pm.
# Resampling: MULTINOMIAL.
# Setting initial epsilon to εmax = 2530215592974.9248046875000000
# Iteration:  1
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 26533.7574199330774718
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8474000000000000
# 	Step-size adapted to: 0.0113167631717350
# Iteration:  2
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 607.4206711711401567
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9550000000000000
# 	Step-size adapted to: 0.0135147961043231
# Iteration:  3
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 98.3985119564248549
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9520000000000000
# 	Step-size adapted to: 0.0161155572296987
# Iteration:  4
# ...

# %% [markdown]
# ##### Step-size: Adaptive but target PM is 20%

# %%
ms_han_aδ_05_020 = MSAdaptive(generate_settings(
        d=d, 
        N=N,
        B=B,
        δ=0.01,
        δmin=δmin,
        δmax=1.0,
        min_pm=min_pm,
        verbose=True,
        εs_fixed=None,
        adaptiveε=True,
        adaptiveδ=True,
        z0_manual=None,
        pm_target=0.20,
        pm_switch=pm_switch,
        prior_seed=1111,
        low_memory=True,
        integrator='hug_and_nhug',
        εprop_switch=0.01,
        ε0_manual=None,
        quantile_value=0.5,
        initialization='prior',
        switch_strategy='pm',
        kernel='uniform',
        use_autograd=False,
        stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_seed=1234,
        mh_kernel_seed=1234,
        resampling_scheme='multinomial',
        maxiter=500,
        prop_hug=0.5,
        projection_method='qr'))
ms_han_aδ_05_020_particles = ms_han_aδ_05_020.sample()
# Out:
# Integrator: HUG + NHUG.
# Prop Hug  :  0.5
# Stopping criterion:  maxiter, εmin, pm.
# Resampling: MULTINOMIAL.
# Setting initial epsilon to εmax = 2530215592974.9248046875000000
# Iteration:  1
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 26533.7574199330774718
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.8474000000000000
# 	Step-size adapted to: 0.0138223257514025
# Iteration:  2
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 607.4206711711401567
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9480000000000000
# 	Step-size adapted to: 0.0200912639853800
# Iteration:  3
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 97.6869004540105408
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9540000000000000
# 	Step-size adapted to: 0.0292911403450004
# Iteration:  4
# ...

# %% [markdown]
# ### RWM THEN HAN

# %% [markdown]
# ##### Step-size=0.01

# %%
ms_rh_001_05 = MSAdaptive(generate_settings(
        d=d, 
        N=N,
        B=B,
        δ=0.01,
        δmin=δmin,
        min_pm=min_pm,
        verbose=True,
        εs_fixed=None,
        adaptiveε=True,
        adaptiveδ=False,
        z0_manual=None,
        pm_target=0.23,
        pm_switch=pm_switch,
        prior_seed=1111,
        low_memory=True,
        integrator='rwm_then_han',
        εprop_switch=0.01,
        ε0_manual=None,
        quantile_value=0.5,
        initialization='prior',
        switch_strategy='pm',
        kernel='uniform',
        use_autograd=False,
        stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_seed=1234,
        mh_kernel_seed=1234,
        resampling_scheme='multinomial',
        maxiter=500))
ms_rh_001_05_particles = ms_rh_001_05.sample()
# Out:
# Integrator: RWM.
# Stopping criterion:  maxiter, εmin, pm.
# Resampling: MULTINOMIAL.
# Setting initial epsilon to εmax = 2530215592974.9248046875000000
# Iteration:  1
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 26533.7574199330774718
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7782000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  2
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 496.5262376630601580
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9530000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  3
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 90.6185106368249365
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9536000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  4
# 	Quantile Value:  0.5
# ...

# %% [markdown]
# ##### Step-size: adaptive

# %%
ms_rh_aδ_05 = MSAdaptive(generate_settings(
        d=d, 
        N=N,
        B=B,
        δ=0.01,
        δmin=0.01,
        δmax=1.0,
        min_pm=min_pm,
        verbose=True,
        εs_fixed=None,
        adaptiveε=True,
        adaptiveδ=True,
        z0_manual=None,
        pm_target=[0.3, 0.6],
        pm_switch=pm_switch,
        prior_seed=1111,
        low_memory=True,
        integrator='rwm_then_han',
        εprop_switch=0.01,
        ε0_manual=None,
        quantile_value=0.5,
        initialization='prior',
        switch_strategy='pm',
        kernel='uniform',
        use_autograd=False,
        stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_seed=1234,
        mh_kernel_seed=1234,
        resampling_scheme='multinomial',
        maxiter=500,
        prop_hug=0.5,
        projection_method='qr'))
ms_rh_aδ_05_particles = ms_rh_aδ_05.sample()
# Out:
# Integrator: RWM.
# Stopping criterion:  maxiter, εmin, pm.
# Resampling: MULTINOMIAL.
# Setting initial epsilon to εmax = 2530215592974.9248046875000000
# Iteration:  1
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 26533.7574199330774718
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.7782000000000000
# 	Step-size adapted to: 0.0127010554078760
# Iteration:  2
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 496.5262376630601580
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9506000000000000
# 	Step-size adapted to: 0.0175839243068945
# Iteration:  3
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 95.1183454676432660
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9484000000000000
# 	Step-size adapted to: 0.0243172285509185
# Iteration:  4
# 	Quantile Value:  0.5
# ...

# %% [markdown]
# ### MS-RWM METROPOLISED

# %% [markdown]
# ##### Step-size: 0.01

# %%
ms_rwm_001_05_metrop = MSAdaptive(generate_settings(
        d=d, 
        N=N,
        B=B,
        δ=0.01,
        δmin=δmin,
        min_pm=min_pm,
        verbose=True,
        εs_fixed=None,
        adaptiveε=True,
        adaptiveδ=False,
        z0_manual=None,
        pm_target=0.23,
        pm_switch=pm_switch,
        prior_seed=1111,
        low_memory=True,
        integrator='rwm',
        εprop_switch=0.01,
        ε0_manual=None,
        quantile_value=0.5,
        initialization='prior',
        switch_strategy='pm',
        kernel='uniform',
        use_autograd=False,
        stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_seed=1234,
        mh_kernel_seed=1234,
        resampling_scheme='multinomial',
        maxiter=150,
        metropolised=True))
ms_rwm_001_05_metrop_particles = ms_rwm_001_05_metrop.sample()
# Out:
# Integrator: RWM METROPOLISED.
# Stopping criterion:  maxiter, εmin, pm.
# Resampling: MULTINOMIAL.
# Setting initial epsilon to εmax = 2530215592974.9248046875000000
# Iteration:  1
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 26533.7574199330774718
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0086000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  2
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 565.9161331358684492
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.5052000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  3
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 96.9891152421180891
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.5106000000000001
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  4
# ...

# %% [markdown]
# ### MS-HAN METROPOLISED

# %% [markdown]
# ##### Step-size=0.05

# %%
ms_han_005_05_metrop = MSAdaptive(generate_settings(
        d=d, 
        N=N,
        B=B,
        δ=0.05,
        δmin=δmin,
        min_pm=min_pm,
        verbose=True,
        εs_fixed=None,
        adaptiveε=True,
        adaptiveδ=False,
        z0_manual=None,
        pm_target=0.23,
        pm_switch=pm_switch,
        prior_seed=1111,
        low_memory=True,
        integrator='hug_and_nhug',
        εprop_switch=0.01,
        ε0_manual=None,
        quantile_value=0.5,
        initialization='prior',
        switch_strategy='pm',
        kernel='uniform',
        use_autograd=False,
        stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_seed=1234,
        mh_kernel_seed=1234,
        resampling_scheme='multinomial',
        maxiter=500,
        prop_hug=0.5,
        metropolised=True))
ms_han_005_05_metrop_particles = ms_han_005_05_metrop.sample()
# Out:
# Integrator: HUG + NHUG METROPOLISED.
# Prop Hug  :  0.5
# Stopping criterion:  maxiter, εmin, pm.
# Resampling: MULTINOMIAL.
# Setting initial epsilon to εmax = 2530215592974.9248046875000000
# Iteration:  1
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 26533.7574199330774718
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0004000000000000
# 	Step-size kept fixed at: 0.0500000000000000
# Iteration:  2
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 568.9061762620322042
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.4532000000000000
# 	Step-size kept fixed at: 0.0500000000000000
# Iteration:  3
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 93.9271588278878085
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.4778000000000000
# 	Step-size kept fixed at: 0.0500000000000000
# ...

# %% [markdown]
# ### SMC-RWM

# %% [markdown]
# ##### Step-size: 0.01

# %%
smc_rwm_001_05 = SMCAdaptive(generate_settings(
        d=d, 
        N=N,
        B=B,
        δ=0.01,
        δmin=δmin,
        min_pm=min_pm,
        verbose=True,
        εs_fixed=None,
        adaptiveε=True,
        adaptiveδ=False,
        z0_manual=None,
        pm_target=0.23,
        pm_switch=pm_switch,
        prior_seed=1111,
        low_memory=True,
        integrator='rwm',
        εprop_switch=0.01,
        ε0_manual=None,
        quantile_value=0.5,
        initialization='prior',
        switch_strategy='pm',
        kernel='uniform',
        use_autograd=False,
        stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_seed=1234,
        mh_kernel_seed=1234,
        resampling_scheme='multinomial',
        maxiter=150))
smc_rwm_001_05_particles = smc_rwm_001_05.sample()
# Out:
# Stochastic Kernel: RWM.
# Stopping criterion:  maxiter, εmin, pm.
# Resampling: MULTINOMIAL.
# Setting initial epsilon to εmax = 2530215592974.9248046875000000
# Iteration:  1
# 	Quantile Value:  0.5
# 	Particles resampled.
# 	Epsilon: 28900.9304648243014526
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2932000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  2
# 	Quantile Value:  0.5
# 	Particles resampled.
# 	Epsilon: 528.3067300083361033
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2802000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  3
# 	Quantile Value:  0.5
# 	Particles resampled.
# 	Epsilon: 86.9558264458412822
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.2578000000000000
# 	Step-size kept fixed at: 0.0100000000000000
# Iteration:  4
# 	Quantile Value:  0.5
# 	Particles resampled.
# 	Epsilon: 39.2135909877357420
# ...

# %% [markdown]
# ##### Step-size: 0.05

# %%
smc_rwm_005_05 = SMCAdaptive(generate_settings(
        d=d, 
        N=N,
        B=B,
        δ=0.05,
        δmin=δmin,
        min_pm=min_pm,
        verbose=True,
        εs_fixed=None,
        adaptiveε=True,
        adaptiveδ=False,
        z0_manual=None,
        pm_target=0.23,
        pm_switch=pm_switch,
        prior_seed=1111,
        low_memory=True,
        integrator='rwm',
        εprop_switch=0.01,
        ε0_manual=None,
        quantile_value=0.5,
        initialization='prior',
        switch_strategy='pm',
        kernel='uniform',
        use_autograd=False,
        stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_seed=1234,
        mh_kernel_seed=1234,
        resampling_scheme='multinomial',
        maxiter=150))
smc_rwm_005_05_particles = smc_rwm_005_05.sample()
# Out:
# Stochastic Kernel: RWM.
# Stopping criterion:  maxiter, εmin, pm.
# Resampling: MULTINOMIAL.
# Setting initial epsilon to εmax = 2530215592974.9248046875000000
# Iteration:  1
# 	Quantile Value:  0.5
# 	Particles resampled.
# 	Epsilon: 28900.9304648243014526
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0072000000000000
# 	Step-size kept fixed at: 0.0500000000000000
# Iteration:  2
# 	Quantile Value:  0.5
# 	Particles resampled.
# 	Epsilon: 542.7389076379306516
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0064000000000000
# 	Step-size kept fixed at: 0.0500000000000000
# Iteration:  3
# 	Quantile Value:  0.5
# 	Particles resampled.
# 	Epsilon: 89.0644135796751755
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0066000000000001
# 	Step-size kept fixed at: 0.0500000000000000
# Iteration:  4
# 	Quantile Value:  0.5
# 	Particles resampled.
# 	Epsilon: 43.1923226685313963
# ...

# %% [markdown]
# # Robustness in $\delta$

# %% [markdown]
# I want to check robustness of MS-RWM to changing stepsize $\delta$. For this purpose, I will run the algorithm for
# various values of $\delta$. Could try with
# $$
# 1.0, 0.5, 0.1, 0.01
# $$
# If we start with a large $\delta$ from the prior, something goes wrong. Therefore, we first perform one step from the prior with a small step size, then we proceed with the correct step size.

# %% [markdown]
# ### Grab Particles

# %%
# ms_rwm_to_grab_particles = MSAdaptive(generate_settings(
#         d=d, 
#         N=N,
#         B=B,
#         δ=0.05,
#         δmin=δmin,
#         min_pm=min_pm,
#         verbose=True,
#         εs_fixed=None,
#         adaptiveε=True,
#         adaptiveδ=False,
#         z0_manual=None,
#         pm_target=0.23,
#         pm_switch=pm_switch,
#         prior_seed=1111,
#         low_memory=True,
#         integrator='rwm',
#         εprop_switch=0.01,
#         ε0_manual=None,
#         quantile_value=0.5,
#         initialization='prior',
#         switch_strategy='pm',
#         kernel='uniform',
#         use_autograd=False,
#         stopping_criterion={'εmin', 'pm', 'maxiter'},
#         resampling_seed=1234,
#         mh_kernel_seed=1234,
#         resampling_scheme='multinomial',
#         maxiter=1)) #### notice maxiter=1
# grabbed_particles = ms_rwm_to_grab_particles.sample()
# Out:
# Integrator: RWM.
# Stopping criterion:  maxiter, εmin, pm.
# Resampling: MULTINOMIAL.
# Setting initial epsilon to εmax = 2530215592974.9248046875000000
# Iteration:  1
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 26533.7574199330774718
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.3216000000000000
# 	Step-size kept fixed at: 0.0500000000000000

# %% [markdown]
# ### Assess Robustness starting from grabbed particles

# %%
# ms_rwm_1_05_manual = MSAdaptive(generate_settings(
#         d=d, 
#         N=N,
#         B=B,
#         δ=1.0,
#         δmin=δmin,
#         min_pm=min_pm,
#         verbose=True,
#         εs_fixed=None,
#         adaptiveε=True,
#         adaptiveδ=False,
#         z0_manual=grabbed_particles,
#         pm_target=0.23,
#         pm_switch=pm_switch,
#         prior_seed=1111,
#         low_memory=True,
#         integrator='rwm',
#         εprop_switch=0.01,
#         ε0_manual=ms_rwm_to_grab_particles.εs[-1],
#         quantile_value=0.5,
#         initialization='manual',
#         switch_strategy='pm',
#         kernel='uniform',
#         use_autograd=False,
#         stopping_criterion={'εmin', 'pm', 'maxiter'},
#         resampling_seed=1234,
#         mh_kernel_seed=1234,
#         resampling_scheme='multinomial',
#         maxiter=500)) 
# ms_rwm_1_05_manual_particles = ms_rwm_1_05_manual.sample()
# Out:
# Integrator: RWM.
# Stopping criterion:  maxiter, εmin, pm.
# Resampling: MULTINOMIAL.
# Iteration:  1
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 588.5724209203110604
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.0846000000000000
# 	Step-size kept fixed at: 1.0000000000000000
# Iteration:  2
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 97.0655048879120415
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.1322000000000000
# 	Step-size kept fixed at: 1.0000000000000000
# Iteration:  3
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 42.8669756916073794
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.5125999999999999
# 	Step-size kept fixed at: 1.0000000000000000
# Iteration:  4
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 27.0207787813856868
# ...

# %%
# ms_rwm_05_05_manual = MSAdaptive(generate_settings(
#         d=d, 
#         N=N,
#         B=B,
#         δ=0.5,
#         δmin=δmin,
#         min_pm=min_pm,
#         verbose=True,
#         εs_fixed=None,
#         adaptiveε=True,
#         adaptiveδ=False,
#         z0_manual=grabbed_particles,
#         pm_target=0.23,
#         pm_switch=pm_switch,
#         prior_seed=1111,
#         low_memory=True,
#         integrator='rwm',
#         εprop_switch=0.01,
#         ε0_manual=ms_rwm_to_grab_particles.εs[-1],
#         quantile_value=0.5,
#         initialization='manual',
#         switch_strategy='pm',
#         kernel='uniform',
#         use_autograd=False,
#         stopping_criterion={'εmin', 'pm', 'maxiter'},
#         resampling_seed=1234,
#         mh_kernel_seed=1234,
#         resampling_scheme='multinomial',
#         maxiter=500)) 
# ms_rwm_05_05_manual_particles = ms_rwm_05_05_manual.sample()
# Out:
# Integrator: RWM.
# Stopping criterion:  maxiter, εmin, pm.
# Resampling: MULTINOMIAL.
# Iteration:  1
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 588.5724209203110604
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.5036000000000000
# 	Step-size kept fixed at: 0.5000000000000000
# Iteration:  2
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 95.5907642778935553
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.4824000000000000
# 	Step-size kept fixed at: 0.5000000000000000
# Iteration:  3
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 42.6101705751389801
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.5236000000000000
# 	Step-size kept fixed at: 0.5000000000000000
# Iteration:  4
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 26.9665450844106296
# ...

# %%
# smc_rwm_05_05_manual = SMCAdaptive(generate_settings(
#         d=d, 
#         N=N,
#         B=B,
#         δ=0.5,
#         δmin=δmin,
#         min_pm=min_pm,
#         verbose=True,
#         εs_fixed=None,
#         adaptiveε=True,
#         adaptiveδ=False,
#         z0_manual=grabbed_particles,
#         pm_target=0.23,
#         pm_switch=pm_switch,
#         prior_seed=1111,
#         low_memory=True,
#         integrator='rwm',
#         εprop_switch=0.01,
#         ε0_manual=ms_rwm_to_grab_particles.εs[-1],
#         quantile_value=0.5,
#         initialization='manual',
#         switch_strategy='pm',
#         kernel='uniform',
#         use_autograd=False,
#         stopping_criterion={'εmin', 'pm', 'maxiter'},
#         resampling_seed=1234,
#         mh_kernel_seed=1234,
#         resampling_scheme='multinomial',
#         maxiter=500)) 
# smc_rwm_05_05_manual_particles = smc_rwm_05_05_manual.sample()
# Out:
# Stochastic Kernel: RWM.
# Stopping criterion:  maxiter, εmin, pm.
# Resampling: MULTINOMIAL.
# Iteration:  1
# 	Quantile Value:  0.5
# 	Particles resampled.
# 	Epsilon: 547.9712716443334557
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0000000000000000
# 	Step-size kept fixed at: 0.5000000000000000

# %% [markdown]
# ### Average Final Epsilon (robustness in $\delta$)

# %% [markdown]
# For SMC or also MS, when the runs are quite short, simply try and average over a number of them. We do this to obtain average min epsilon.

# %%
def avg_min_eps_smc(settings, n=5):
    avg_min_eps = 0.0
    for i in range(n):
        smc = SMCAdaptive(settings) 
        _ = smc.sample()
        avg_min_eps += (smc.εs[-1] / n)
    return avg_min_eps

def avg_min_eps_ms(settings, n=5):
    avg_min_eps = 0.0
    for i in range(n):
        ms = MSAdaptive(settings) 
        _ = ms.sample()
        avg_min_eps += (ms.εs[-1] / n)
    return avg_min_eps

def avg_final_ess_smc(settings, n=5):
    avg_ess = 0.0
    for i in range(n):
        smc = SMCAdaptive(settings) 
        _ = smc.sample()
        avg_ess += (smc.ESS[-1] / n)
    return avg_ess

# %% [markdown]
# ###### SMC

# %%
avg_min_eps_smc_rwm_5 = avg_min_eps_smc(generate_settings(d=d, N=N, B=B,
        δ=5.0, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=grabbed_particles, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=ms_rwm_to_grab_particles.εs[-1], quantile_value=0.5, initialization='manual',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500), n=10)

# %%
avg_min_eps_smc_rwm_1 = avg_min_eps_smc(generate_settings(d=d, N=N, B=B,
        δ=1.0, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=grabbed_particles, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=ms_rwm_to_grab_particles.εs[-1], quantile_value=0.5, initialization='manual',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500), n=10)

# %%
avg_min_eps_smc_rwm_05 = avg_min_eps_smc(generate_settings(d=d, N=N, B=B,
        δ=0.5, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=grabbed_particles, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=ms_rwm_to_grab_particles.εs[-1], quantile_value=0.5, initialization='manual',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500), n=10)

# %%
avg_min_eps_smc_rwm_01 = avg_min_eps_smc(generate_settings(d=d, N=N, B=B,
        δ=0.1, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=grabbed_particles, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=ms_rwm_to_grab_particles.εs[-1], quantile_value=0.5, initialization='manual',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500), n=10)

# %%
avg_min_eps_smc_rwm_005 = avg_min_eps_smc(generate_settings(d=d, N=N, B=B,
        δ=0.05, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=grabbed_particles, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=ms_rwm_to_grab_particles.εs[-1], quantile_value=0.5, initialization='manual',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500), n=10)

# %%
avg_min_eps_smc_rwm_001 = avg_min_eps_smc(generate_settings(d=d, N=N, B=B,
        δ=0.01, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=grabbed_particles, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=ms_rwm_to_grab_particles.εs[-1], quantile_value=0.5, initialization='manual',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500), n=10)

# %%
avg_min_eps_smc_rwm_0001 = avg_min_eps_smc(generate_settings(d=d, N=N, B=B,
        δ=0.001, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=grabbed_particles, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=ms_rwm_to_grab_particles.εs[-1], quantile_value=0.5, initialization='manual',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500), n=1)

# %%
avg_min_eps_smc_rwm_5, avg_min_eps_smc_rwm_1, avg_min_eps_smc_rwm_05, avg_min_eps_smc_rwm_01, avg_min_eps_smc_rwm_005, avg_min_eps_smc_rwm_001, avg_min_eps_smc_rwm_0001
# Out:
# (547.9712716443335,
#  547.9712716443335,
#  547.9712716443335,
#  547.9712716443335,
#  13.845294678196256,
#  3.6009179251825603,
#  5.26879660294467)

# %% [markdown]
# ###### MS

# %%
avg_min_eps_ms_rwm_5 = avg_min_eps_ms(generate_settings(d=d, N=N, B=B,
        δ=5.0, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=grabbed_particles, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=ms_rwm_to_grab_particles.εs[-1], quantile_value=0.5, initialization='manual',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500), n=5)

# %%
avg_min_eps_ms_rwm_1 = avg_min_eps_ms(generate_settings(d=d, N=N, B=B,
        δ=1.0, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=grabbed_particles, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=ms_rwm_to_grab_particles.εs[-1], quantile_value=0.5, initialization='manual',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500), n=1)

# %%
avg_min_eps_ms_rwm_05 = avg_min_eps_ms(generate_settings(d=d, N=N, B=B,
        δ=0.5, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=grabbed_particles, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=ms_rwm_to_grab_particles.εs[-1], quantile_value=0.5, initialization='manual',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500), n=1)

# %%
avg_min_eps_ms_rwm_01 = avg_min_eps_ms(generate_settings(d=d, N=N, B=B,
        δ=0.1, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=grabbed_particles, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=ms_rwm_to_grab_particles.εs[-1], quantile_value=0.5, initialization='manual',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500), n=1)

# %%
avg_min_eps_ms_rwm_005 = avg_min_eps_ms(generate_settings(d=d, N=N, B=B,
        δ=0.05, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=grabbed_particles, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=ms_rwm_to_grab_particles.εs[-1], quantile_value=0.5, initialization='manual',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500), n=1)

# %%
avg_min_eps_ms_rwm_001 = avg_min_eps_ms(generate_settings(d=d, N=N, B=B,
        δ=0.01, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=grabbed_particles, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=ms_rwm_to_grab_particles.εs[-1], quantile_value=0.5, initialization='manual',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500), n=1)

# %%
avg_min_eps_ms_rwm_0001 = avg_min_eps_ms(generate_settings(d=d, N=N, B=B,
        δ=0.001, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=grabbed_particles, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=ms_rwm_to_grab_particles.εs[-1], quantile_value=0.5, initialization='manual',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500), n=1)

# %%
avg_min_eps_ms_rwm_5, avg_min_eps_ms_rwm_1, avg_min_eps_ms_rwm_05, avg_min_eps_ms_rwm_01, avg_min_eps_ms_rwm_005, avg_min_eps_ms_rwm_001, avg_min_eps_ms_rwm_0001
# Out:
# (588.5724209203111,
#  16.88271390938728,
#  5.074430982242965,
#  1.4025154750104842,
#  1.007396788879631,
#  0.2807072847641516,
#  5.157228949583806)

# %% [markdown]
# ##### MS-RWM-METROPOLISED

# %%
avg_min_eps_ms_rwm_metrop_5 = avg_min_eps_ms(generate_settings(d=d, N=N, B=B,
        δ=5.0, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=grabbed_particles, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=ms_rwm_to_grab_particles.εs[-1], quantile_value=0.5, initialization='manual',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500, metropolised=True), n=5)

# %%
avg_min_eps_ms_rwm_metrop_1 = avg_min_eps_ms(generate_settings(d=d, N=N, B=B,
        δ=1.0, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=grabbed_particles, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=ms_rwm_to_grab_particles.εs[-1], quantile_value=0.5, initialization='manual',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500, metropolised=True), n=5)

# %%
avg_min_eps_ms_rwm_metrop_05 = avg_min_eps_ms(generate_settings(d=d, N=N, B=B,
        δ=0.5, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=grabbed_particles, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=ms_rwm_to_grab_particles.εs[-1], quantile_value=0.5, initialization='manual',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500, metropolised=True), n=5)

# %%
avg_min_eps_ms_rwm_metrop_01 = avg_min_eps_ms(generate_settings(d=d, N=N, B=B,
        δ=0.1, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=grabbed_particles, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=ms_rwm_to_grab_particles.εs[-1], quantile_value=0.5, initialization='manual',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500, metropolised=True), n=5)

# %%
avg_min_eps_ms_rwm_metrop_005 = avg_min_eps_ms(generate_settings(d=d, N=N, B=B,
        δ=0.05, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=grabbed_particles, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=ms_rwm_to_grab_particles.εs[-1], quantile_value=0.5, initialization='manual',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500, metropolised=True), n=5)

# %%
avg_min_eps_ms_rwm_metrop_001 = avg_min_eps_ms(generate_settings(d=d, N=N, B=B,
        δ=0.01, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=grabbed_particles, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=ms_rwm_to_grab_particles.εs[-1], quantile_value=0.5, initialization='manual',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500, metropolised=True), n=5)

# %%
avg_min_eps_ms_rwm_metrop_0001 = avg_min_eps_ms(generate_settings(d=d, N=N, B=B,
        δ=0.001, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=grabbed_particles, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=ms_rwm_to_grab_particles.εs[-1], quantile_value=0.5, initialization='manual',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500, metropolised=True), n=1)

# %% [markdown]
# ##### MS-HAN

# %%
avg_min_eps_ms_han_5 = avg_min_eps_ms(generate_settings(d=d, N=N, B=B,
        δ=5.0, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=grabbed_particles, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='hug_and_nhug',
        εprop_switch=0.01, ε0_manual=ms_rwm_to_grab_particles.εs[-1], quantile_value=0.5, initialization='manual',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500), n=1)
# Out:
# ValueError was raised:  array must not contain infs or NaNs

# %%
avg_min_eps_ms_han_1 = avg_min_eps_ms(generate_settings(d=d, N=N, B=B,
        δ=1.0, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=grabbed_particles, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='hug_and_nhug',
        εprop_switch=0.01, ε0_manual=ms_rwm_to_grab_particles.εs[-1], quantile_value=0.5, initialization='manual',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', projection_method='qr', maxiter=500), n=1)
# Out:
# ValueError was raised:  array must not contain infs or NaNs

# %%
avg_min_eps_ms_han_05 = avg_min_eps_ms(generate_settings(d=d, N=N, B=B,
        δ=0.5, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=grabbed_particles, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='hug_and_nhug',
        εprop_switch=0.01, ε0_manual=ms_rwm_to_grab_particles.εs[-1], quantile_value=0.5, initialization='manual',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500), n=1)

# %% [markdown]
# ### Other metrics

# %% [markdown]
# Above we have shown the smallest epsilon achievable for a given step size. Now we want to look at other metrics. For instance, we want to look at ESS and acceptance probability. For this reason, we simply run the algorithms for those step size and report the list of epsilons and acceptance probabilities, and show how they progress.

# %% [markdown]
# ##### SMC-RWM (ESS and AP)

# %%
FOO1 = SMCAdaptive(generate_settings(d=d, N=N, B=B,
        δ=5.0, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=grabbed_particles, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=ms_rwm_to_grab_particles.εs[-1], quantile_value=0.5, initialization='manual',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500))
_ = FOO1.sample()

# %%
FOO2 = SMCAdaptive(generate_settings(d=d, N=N, B=B,
        δ=1.0, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=grabbed_particles, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=ms_rwm_to_grab_particles.εs[-1], quantile_value=0.5, initialization='manual',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500))
_ = FOO2.sample()

# %%
FOO3 = SMCAdaptive(generate_settings(d=d, N=N, B=B,
        δ=0.5, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=grabbed_particles, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=ms_rwm_to_grab_particles.εs[-1], quantile_value=0.5, initialization='manual',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500))
_ = FOO3.sample()

# %%
FOO4 = SMCAdaptive(generate_settings(d=d, N=N, B=B,
        δ=0.1, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=grabbed_particles, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=ms_rwm_to_grab_particles.εs[-1], quantile_value=0.5, initialization='manual',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500))
_ = FOO4.sample()

# %%
FOO5 = SMCAdaptive(generate_settings(d=d, N=N, B=B,
        δ=0.05, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=grabbed_particles, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=ms_rwm_to_grab_particles.εs[-1], quantile_value=0.5, initialization='manual',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500))
_ = FOO5.sample()

# %%
FOO6 = SMCAdaptive(generate_settings(d=d, N=N, B=B,
        δ=0.01, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=grabbed_particles, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=ms_rwm_to_grab_particles.εs[-1], quantile_value=0.5, initialization='manual',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500))
_ = FOO6.sample()

# %%
FOO7 = SMCAdaptive(generate_settings(d=d, N=N, B=B,
        δ=0.001, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=grabbed_particles, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=ms_rwm_to_grab_particles.εs[-1], quantile_value=0.5, initialization='manual',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500))
_ = FOO7.sample()

# %% [markdown]
# ##### MS-RWM

# %%
FOO8 = MSAdaptive(generate_settings(d=d, N=N, B=B,
        δ=5.0, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=grabbed_particles, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=ms_rwm_to_grab_particles.εs[-1], quantile_value=0.5, initialization='manual',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500))
_ = FOO8.sample()

# %%
FOO9 = MSAdaptive(generate_settings(d=d, N=N, B=B,
        δ=1.0, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=grabbed_particles, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=ms_rwm_to_grab_particles.εs[-1], quantile_value=0.5, initialization='manual',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500))
_ = FOO9.sample()

# %%
FOO10 = MSAdaptive(generate_settings(d=d, N=N, B=B,
        δ=0.5, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=grabbed_particles, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=ms_rwm_to_grab_particles.εs[-1], quantile_value=0.5, initialization='manual',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500))
_ = FOO10.sample()

# %%
FOO11 = MSAdaptive(generate_settings(d=d, N=N, B=B,
        δ=0.1, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=grabbed_particles, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=ms_rwm_to_grab_particles.εs[-1], quantile_value=0.5, initialization='manual',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500))
_ = FOO11.sample()

# %%
FOO12 = MSAdaptive(generate_settings(d=d, N=N, B=B,
        δ=0.05, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=grabbed_particles, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=ms_rwm_to_grab_particles.εs[-1], quantile_value=0.5, initialization='manual',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500))
_ = FOO12.sample()

# %%
FOO13 = MSAdaptive(generate_settings(d=d, N=N, B=B,
        δ=0.01, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=grabbed_particles, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=ms_rwm_to_grab_particles.εs[-1], quantile_value=0.5, initialization='manual',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500))
_ = FOO13.sample()

# %%
FOO14 = MSAdaptive(generate_settings(d=d, N=N, B=B,
        δ=0.001, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=grabbed_particles, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=ms_rwm_to_grab_particles.εs[-1], quantile_value=0.5, initialization='manual',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500))
_ = FOO14.sample()

# %%
fig, ax = plt.subplots(figsize=(16, 4), ncols=2)
### ESS
ax[0].plot(FOO1.εs, FOO1.ESS, label='SMC-RWM-5.0', markevery=[-1], marker='o')
ax[0].plot(FOO2.εs, FOO2.ESS, label='SMC-RWM-1.0', markevery=[-1], marker='o')
ax[0].plot(FOO3.εs, FOO3.ESS, label='SMC-RWM-0.5', markevery=[-1], marker='o')
ax[0].plot(FOO4.εs, FOO4.ESS, label='SMC-RWM-0.1', markevery=[-1], marker='o')
ax[0].plot(FOO5.εs, FOO5.ESS, label='SMC-RWM-0.05', markevery=[-1], marker='o')
ax[0].plot(FOO6.εs, FOO6.ESS, label='SMC-RWM-0.01', markevery=[-1], marker='o')
ax[0].plot(FOO7.εs, FOO7.ESS, label='SMC-RWM-0.001', markevery=[-1], marker='o')
ax[0].set_xscale('log')
ax[0].set_yscale('log')
ax[0].legend()
ax[0].set_ylabel('ESS')
### AP
ax[1].plot(FOO1.εs, FOO1.APS, label='SMC-RWM-5.0', markevery=[-1], marker='o')
ax[1].plot(FOO2.εs, FOO2.APS, label='SMC-RWM-1.0', markevery=[-1], marker='o')
ax[1].plot(FOO3.εs, FOO3.APS, label='SMC-RWM-0.5', markevery=[-1], marker='o')
ax[1].plot(FOO4.εs, FOO4.APS, label='SMC-RWM-0.1', markevery=[-1], marker='o')
ax[1].plot(FOO5.εs, FOO5.APS, label='SMC-RWM-0.05', markevery=[-1], marker='o')
ax[1].plot(FOO6.εs, FOO6.APS, label='SMC-RWM-0.01', markevery=[-1], marker='o')
ax[1].plot(FOO7.εs, FOO7.APS, label='SMC-RWM-0.001', markevery=[-1], marker='o')
ax[1].set_xscale('log')
# ax[1].set_yscale('log')
ax[1].legend()
ax[1].set_ylabel('AP')
plt.suptitle("SMC-RWM")
plt.show()

# %%
fig, ax = plt.subplots(figsize=(16, 4), ncols=2)
### ESS
ax[0].plot(FOO8.εs, FOO8.ESS, label='MS-RWM-5.0', markevery=[-1], marker='o')
ax[0].plot(FOO9.εs, FOO9.ESS, label='MS-RWM-1.0', markevery=[-1], marker='o')
ax[0].plot(FOO10.εs, FOO10.ESS, label='MS-RWM-0.5', markevery=[-1], marker='o')
ax[0].plot(FOO11.εs, FOO11.ESS, label='MS-RWM-0.1', markevery=[-1], marker='o')
ax[0].plot(FOO12.εs, FOO12.ESS, label='MS-RWM-0.05', markevery=[-1], marker='o')
ax[0].plot(FOO13.εs, FOO13.ESS, label='MS-RWM-0.01', markevery=[-1], marker='o')
ax[0].plot(FOO14.εs, FOO14.ESS, label='MS-RWM-0.001', markevery=[-1], marker='o')

ax[0].set_xscale('log')
ax[0].set_yscale('log')
ax[0].legend()
ax[0].set_ylabel('ESS')
### AP
ax[1].plot(FOO8.εs, FOO8.PROP_MOVED, label='MS-RWM-5.0', markevery=[-1], marker='o')
ax[1].plot(FOO9.εs, FOO9.PROP_MOVED, label='MS-RWM-1.0', markevery=[-1], marker='o')
ax[1].plot(FOO10.εs, FOO10.PROP_MOVED, label='MS-RWM-0.5', markevery=[-1], marker='o')
ax[1].plot(FOO11.εs, FOO11.PROP_MOVED, label='MS-RWM-0.1', markevery=[-1], marker='o')
ax[1].plot(FOO12.εs, FOO12.PROP_MOVED, label='MS-RWM-0.05', markevery=[-1], marker='o')
ax[1].plot(FOO13.εs, FOO13.PROP_MOVED, label='MS-RWM-0.01', markevery=[-1], marker='o')
ax[1].plot(FOO14.εs, FOO14.PROP_MOVED, label='MS-RWM-0.001', markevery=[-1], marker='o')

ax[1].set_xscale('log')
# ax[1].set_yscale('log')
ax[1].legend()
ax[1].set_ylabel('PM')
plt.suptitle("MS-RWM")
plt.show()

# %% [markdown]
# ##### Together

# %%
from utils import lighten_color

# %%
fig, ax = plt.subplots(figsize=(16, 4), ncols=2)

### ESS
# SMC-RWM
ax[0].plot(FOO1.εs, FOO1.ESS, label='SMC-RWM-0.5', markevery=[-1], marker='o', color=lighten_color('red', 1.0))
ax[0].plot(FOO2.εs, FOO2.ESS, label='SMC-RWM-1.0', markevery=[-1], marker='o', color=lighten_color('red', 0.85))
ax[0].plot(FOO3.εs, FOO3.ESS, label='SMC-RWM-0.5', markevery=[-1], marker='o', color=lighten_color('red', 0.7))
ax[0].plot(FOO4.εs, FOO4.ESS, label='SMC-RWM-0.1', markevery=[-1], marker='o', color=lighten_color('red', 0.55))
ax[0].plot(FOO5.εs, FOO5.ESS, label='SMC-RWM-0.05', markevery=[-1], marker='o', color=lighten_color('red', 0.40))
ax[0].plot(FOO6.εs, FOO6.ESS, label='SMC-RWM-0.01', markevery=[-1], marker='o', color=lighten_color('red', 0.25))
ax[0].plot(FOO7.εs, FOO7.ESS, label='SMC-RWM-0.001', markevery=[-1], marker='o', color=lighten_color('red', 0.10))
# MS-RWM
ax[0].plot(FOO8.εs, FOO8.ESS, label='MS-RWM-5.0', markevery=[-1], marker='o', color=lighten_color('green', 1.0))
ax[0].plot(FOO9.εs, FOO9.ESS, label='MS-RWM-1.0', markevery=[-1], marker='o', color=lighten_color('green', 0.85))
ax[0].plot(FOO10.εs, FOO10.ESS, label='MS-RWM-0.5', markevery=[-1], marker='o', color=lighten_color('green', 0.7))
ax[0].plot(FOO11.εs, FOO11.ESS, label='MS-RWM-0.1', markevery=[-1], marker='o', color=lighten_color('green', 0.55))
ax[0].plot(FOO12.εs, FOO12.ESS, label='MS-RWM-0.05', markevery=[-1], marker='o', color=lighten_color('green', 0.4))
ax[0].plot(FOO13.εs, FOO13.ESS, label='MS-RWM-0.01', markevery=[-1], marker='o', color=lighten_color('green', 0.25))
ax[0].plot(FOO14.εs, FOO14.ESS, label='MS-RWM-0.001', markevery=[-1], marker='o', color=lighten_color('green', 0.1))
# Prettify
ax[0].set_xscale('log')
ax[0].set_yscale('log')
# ax[0].legend()
ax[0].set_ylabel('ESS')


### AP
# SMC-RWM
ax[1].plot(FOO1.εs, FOO1.APS, label='SMC-RWM-5.0', markevery=[-1], marker='o', color=lighten_color('red', 1.0))
ax[1].plot(FOO2.εs, FOO2.APS, label='SMC-RWM-1.0', markevery=[-1], marker='o', color=lighten_color('red', 0.85))
ax[1].plot(FOO3.εs, FOO3.APS, label='SMC-RWM-0.5', markevery=[-1], marker='o', color=lighten_color('red', 0.7))
ax[1].plot(FOO4.εs, FOO4.APS, label='SMC-RWM-0.1', markevery=[-1], marker='o', color=lighten_color('red', 0.55))
ax[1].plot(FOO5.εs, FOO5.APS, label='SMC-RWM-0.05', markevery=[-1], marker='o', color=lighten_color('red', 0.4))
ax[1].plot(FOO6.εs, FOO6.APS, label='SMC-RWM-0.01', markevery=[-1], marker='o', color=lighten_color('red', 0.25))
ax[1].plot(FOO7.εs, FOO7.APS, label='SMC-RWM-0.001', markevery=[-1], marker='o', color=lighten_color('red', 0.10))
# MS-RWM
ax[1].plot(FOO8.εs, FOO8.PROP_MOVED, label='MS-RWM-5.0', markevery=[-1], marker='o', color=lighten_color('green', 1.0))
ax[1].plot(FOO9.εs, FOO9.PROP_MOVED, label='MS-RWM-1.0', markevery=[-1], marker='o', color=lighten_color('green', 0.85))
ax[1].plot(FOO10.εs, FOO10.PROP_MOVED, label='MS-RWM-0.5', markevery=[-1], marker='o', color=lighten_color('green', 0.70))
ax[1].plot(FOO11.εs, FOO11.PROP_MOVED, label='MS-RWM-0.1', markevery=[-1], marker='o', color=lighten_color('green', 0.55))
ax[1].plot(FOO12.εs, FOO12.PROP_MOVED, label='MS-RWM-0.05', markevery=[-1], marker='o', color=lighten_color('green', 0.40))
ax[1].plot(FOO13.εs, FOO13.PROP_MOVED, label='MS-RWM-0.01', markevery=[-1], marker='o', color=lighten_color('green', 0.25))
ax[1].plot(FOO14.εs, FOO14.PROP_MOVED, label='MS-RWM-0.001', markevery=[-1], marker='o', color=lighten_color('green', 0.10))
# Prettify
ax[1].set_xscale('log')
# ax[1].legend()
ax[1].set_ylabel('PM')
# plt.suptitle("MS-RWM")
plt.show()

# %% [markdown]
# ### Can I do the same but starting from the prior?

# %% [markdown]
# All the plots above have been obtained starting from pre-determined particles. Can I do the same starting properly from the prior rather than manual initialization?

# %% [markdown]
# ##### SMC

# %%
BAR1 = SMCAdaptive(generate_settings(d=d, N=N, B=B,
        δ=5.0, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=None, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=None, quantile_value=0.5, initialization='prior',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500))
_ = BAR1.sample()

# %%
BAR2 = SMCAdaptive(generate_settings(d=d, N=N, B=B,
        δ=1.0, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=None, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=None, quantile_value=0.5, initialization='prior',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500))
_ = BAR2.sample()

# %%
BAR3 = SMCAdaptive(generate_settings(d=d, N=N, B=B,
        δ=0.5, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=None, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=None, quantile_value=0.5, initialization='prior',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500))
_ = BAR3.sample()

# %%
BAR4 = SMCAdaptive(generate_settings(d=d, N=N, B=B,
        δ=0.1, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=None, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=None, quantile_value=0.5, initialization='prior',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500))
_ = BAR4.sample()

# %%
BAR5 = SMCAdaptive(generate_settings(d=d, N=N, B=B,
        δ=0.05, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=None, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=None, quantile_value=0.5, initialization='prior',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500))
_ = BAR5.sample()

# %%
BAR6 = SMCAdaptive(generate_settings(d=d, N=N, B=B,
        δ=0.01, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=None, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=None, quantile_value=0.5, initialization='prior',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500))
_ = BAR6.sample()

# %%
# BAR7 = SMCAdaptive(generate_settings(d=d, N=N, B=B,
#         δ=0.001, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
#         z0_manual=None, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
#         εprop_switch=0.01, ε0_manual=None, quantile_value=0.5, initialization='prior',
#         switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
#         resampling_scheme='multinomial', maxiter=500))
# _ = BAR7.sample()

# %%
fig, ax = plt.subplots(figsize=(16, 4), ncols=2)
FROM=1
### ESS
ax[0].plot(BAR1.εs[FROM:], BAR1.ESS[FROM:], label='SMC-RWM-5.0', markevery=[-1], marker='o')
ax[0].plot(BAR2.εs[FROM:], BAR2.ESS[FROM:], label='SMC-RWM-1.0', markevery=[-1], marker='o')
ax[0].plot(BAR3.εs[FROM:], BAR3.ESS[FROM:], label='SMC-RWM-0.5', markevery=[-1], marker='o')
ax[0].plot(BAR4.εs[FROM:], BAR4.ESS[FROM:], label='SMC-RWM-0.1', markevery=[-1], marker='o')
ax[0].plot(BAR5.εs[FROM:], BAR5.ESS[FROM:], label='SMC-RWM-0.05', markevery=[-1], marker='o')
ax[0].plot(BAR6.εs[FROM:], BAR6.ESS[FROM:], label='SMC-RWM-0.01', markevery=[-1], marker='o')
# ax[0].plot(BAR7.εs[FROM:], BAR7.ESS[FROM:], label='SMC-RWM-0.001', markevery=[-1], marker='o')
ax[0].set_xscale('log')
ax[0].set_yscale('log')
ax[0].legend()
ax[0].set_ylabel('ESS')
### AP
ax[1].plot(BAR1.εs[FROM:], BAR1.APS[FROM:], label='SMC-RWM-5.0', markevery=[-1], marker='o')
ax[1].plot(BAR2.εs[FROM:], BAR2.APS[FROM:], label='SMC-RWM-1.0', markevery=[-1], marker='o')
ax[1].plot(BAR3.εs[FROM:], BAR3.APS[FROM:], label='SMC-RWM-0.5', markevery=[-1], marker='o')
ax[1].plot(BAR4.εs[FROM:], BAR4.APS[FROM:], label='SMC-RWM-0.1', markevery=[-1], marker='o')
ax[1].plot(BAR5.εs[FROM:], BAR5.APS[FROM:], label='SMC-RWM-0.05', markevery=[-1], marker='o')
ax[1].plot(BAR6.εs[FROM:], BAR6.APS[FROM:], label='SMC-RWM-0.01', markevery=[-1], marker='o')
# ax[1].plot(BAR7.εs[FROM:], BAR7.APS[FROM:], label='SMC-RWM-0.001', markevery=[-1], marker='o')
ax[1].set_xscale('log')
# ax[1].set_yscale('log')
ax[1].legend()
ax[1].set_ylabel('AP')
plt.suptitle("SMC-RWM")
plt.show()

# %% [markdown]
# ##### MS-RWM

# %%
BAR8 = MSAdaptive(generate_settings(d=d, N=N, B=B,
        δ=5.0, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=None, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=None, quantile_value=0.5, initialization='prior',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500))
_ = BAR8.sample()

# %%
BAR9 = MSAdaptive(generate_settings(d=d, N=N, B=B,
        δ=1.0, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=None, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=None, quantile_value=0.5, initialization='prior',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500,
        prior_seed=randint(low=1000,high=9999), resampling_seed=randint(low=1000,high=9999)))
_ = BAR9.sample()

# %%
BAR10 = MSAdaptive(generate_settings(d=d, N=N, B=B,
        δ=0.5, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=None, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=None, quantile_value=0.5, initialization='prior',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500,
        prior_seed=randint(low=1000,high=9999), resampling_seed=randint(low=1000,high=9999)))
_ = BAR10.sample()

# %%
BAR11 = MSAdaptive(generate_settings(d=d, N=N, B=B,
        δ=0.1, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=None, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=None, quantile_value=0.5, initialization='prior',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500))
_ = BAR11.sample()

# %%
BAR12 = MSAdaptive(generate_settings(d=d, N=N, B=B,
        δ=0.05, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=None, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=None, quantile_value=0.5, initialization='prior',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500))
_ = BAR12.sample()

# %%
BAR13 = MSAdaptive(generate_settings(d=d, N=N, B=B,
        δ=0.01, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=None, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=None, quantile_value=0.5, initialization='prior',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500))
_ = BAR13.sample()

# %% [markdown]
# ##### MMS-RWM

# %%
BAR15 = MSAdaptive(generate_settings(d=d, N=N, B=B,
        δ=5.0, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=None, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=None, quantile_value=0.5, initialization='prior',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500, metropolised=True))
_ = BAR15.sample()
# Does not move

# %%
BAR16 = MSAdaptive(generate_settings(d=d, N=N, B=B,
        δ=1.0, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=None, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=None, quantile_value=0.5, initialization='prior',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500, metropolised=True))
_ = BAR16.sample()
# Does not move

# %%
BAR17 = MSAdaptive(generate_settings(d=d, N=N, B=B,
        δ=0.5, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=None, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=None, quantile_value=0.5, initialization='prior',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500, metropolised=True))
_ = BAR17.sample()
# Does not move

# %%
BAR18 = MSAdaptive(generate_settings(d=d, N=N, B=B,
        δ=0.1, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=None, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=None, quantile_value=0.5, initialization='prior',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500, metropolised=True))
_ = BAR18.sample()
# Does not move

# %%
BAR19 = MSAdaptive(generate_settings(d=d, N=N, B=B,
        δ=0.05, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=None, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=None, quantile_value=0.5, initialization='prior',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500, metropolised=True))
_ = BAR19.sample()
# Does not move

# %%
BAR20 = MSAdaptive(generate_settings(d=d, N=N, B=B,
        δ=0.01, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=None, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=None, quantile_value=0.5, initialization='prior',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500, metropolised=True))
_ = BAR20.sample()
# Does not move

# %% [markdown]
# ##### MS-HAN

# %%
BAR22 = MSAdaptive(generate_settings(d=d, N=N, B=B,
        δ=5.0, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=None, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='hug_and_nhug',
        εprop_switch=0.01, ε0_manual=None, quantile_value=0.5, initialization='prior',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500))
_ = BAR22.sample()
# Fails
# Out:
# ValueError was raised:  array must not contain infs or NaNs

# %%
BAR23 = MSAdaptive(generate_settings(d=d, N=N, B=B,
        δ=1.0, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=None, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='hug_and_nhug',
        εprop_switch=0.01, ε0_manual=None, quantile_value=0.5, initialization='prior',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500))
_ = BAR23.sample()
# Fails
# Out:
# ValueError was raised:  array must not contain infs or NaNs

# %%
BAR24 = MSAdaptive(generate_settings(d=d, N=N, B=B,
        δ=0.5, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=None, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='hug_and_nhug',
        εprop_switch=0.01, ε0_manual=None, quantile_value=0.5, initialization='prior',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500))
_ = BAR24.sample()
# Moves

# %%
BAR25 = MSAdaptive(generate_settings(d=d, N=N, B=B,
        δ=0.1, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=None, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='hug_and_nhug',
        εprop_switch=0.01, ε0_manual=None, quantile_value=0.5, initialization='prior',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500))
_ = BAR25.sample()
# Moves

# %%
BAR26 = MSAdaptive(generate_settings(d=d, N=N, B=B,
        δ=0.05, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=None, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='hug_and_nhug',
        εprop_switch=0.01, ε0_manual=None, quantile_value=0.5, initialization='prior',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500))
_ = BAR26.sample()
# Moves

# %%
BAR27 = MSAdaptive(generate_settings(d=d, N=N, B=B,
        δ=0.01, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=None, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='hug_and_nhug',
        εprop_switch=0.01, ε0_manual=None, quantile_value=0.5, initialization='prior',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500))
_ = BAR27.sample()
# Moves

# %%
### ESS PLOTS
fig, ax = plt.subplots(figsize=(16, 7), ncols=2, nrows=2, sharex=True, sharey=True)

# SMC-RWM
# ax[0, 0].plot(BAR1.εs[FROM:], BAR1.ESS[FROM:], label='SMC-RWM-5.0', markevery=[-1], marker='o')
# ax[0, 0].plot(BAR2.εs[FROM:], BAR2.ESS[FROM:], label='SMC-RWM-1.0', markevery=[-1], marker='o')
# ax[0, 0].plot(BAR3.εs[FROM:], BAR3.ESS[FROM:], label='SMC-RWM-0.5', markevery=[-1], marker='o')
# ax[0, 0].plot(BAR4.εs[FROM:], BAR4.ESS[FROM:], label='SMC-RWM-0.1', markevery=[-1], marker='o')
ax[0, 0].plot(BAR5.εs[FROM:], BAR5.ESS[FROM:], label='SMC-RWM-0.05', markevery=[-1], marker='o')
ax[0, 0].plot(BAR6.εs[FROM:], BAR6.ESS[FROM:], label='SMC-RWM-0.01', markevery=[-1], marker='o')
# MSM-RWM
# ax[0, 1].plot(BAR15.εs[FROM:], BAR15.ESS[FROM:], label='MMS-RWM-5.0', markevery=[-1], marker='o')
# ax[0, 1].plot(BAR16.εs[FROM:], BAR16.ESS[FROM:], label='MMS-RWM-1.0', markevery=[-1], marker='o')
# ax[0, 1].plot(BAR17.εs[FROM:], BAR17.ESS[FROM:], label='MMS-RWM-0.5', markevery=[-1], marker='o')
# ax[0, 1].plot(BAR18.εs[FROM:], BAR18.ESS[FROM:], label='MMS-RWM-0.1', markevery=[-1], marker='o')
# ax[0, 1].plot(BAR19.εs[FROM:], BAR19.ESS[FROM:], label='MMS-RWM-0.05', markevery=[-1], marker='o')
ax[0, 1].plot(BAR20.εs[FROM:], BAR20.ESS[FROM:], label='MMS-RWM-0.01', markevery=[-1], marker='o')
# MS-RWM
# ax[1, 0].plot(BAR8.εs[FROM:], BAR8.ESS[FROM:], label='MS-RWM-5.0', markevery=[-1], marker='o')
# ax[1, 0].plot(BAR9.εs[FROM:], BAR9.ESS[FROM:], label='MS-RWM-1.0', markevery=[-1], marker='o')
# ax[1, 0].plot(BAR10.εs[FROM:], BAR10.ESS[FROM:], label='MS-RWM-0.5', markevery=[-1], marker='o')
ax[1, 0].plot(BAR11.εs[FROM:], BAR11.ESS[FROM:], label='MS-RWM-0.1', markevery=[-1], marker='o')
ax[1, 0].plot(BAR12.εs[FROM:], BAR12.ESS[FROM:], label='MS-RWM-0.05', markevery=[-1], marker='o')
ax[1, 0].plot(BAR13.εs[FROM:], BAR13.ESS[FROM:], label='MS-RWM-0.01', markevery=[-1], marker='o')
# MS-HAN
ax[1, 1].plot(BAR24.εs[FROM:], BAR24.ESS[FROM:], label='MS-HAN-0.5', markevery=[-1], marker='o')
ax[1, 1].plot(BAR25.εs[FROM:], BAR25.ESS[FROM:], label='MS-HAN-0.1', markevery=[-1], marker='o')
ax[1, 1].plot(BAR26.εs[FROM:], BAR26.ESS[FROM:], label='MS-HAN-0.05', markevery=[-1], marker='o')
ax[1, 1].plot(BAR27.εs[FROM:], BAR27.ESS[FROM:], label='MS-HAN-0.01', markevery=[-1], marker='o')

for i in itertools.product([0, 1], [0, 1]):
    ax[i].set_xscale('log')
    ax[i].set_yscale('log')
    ax[i].legend()
ax[0, 0].set_ylabel('ESS')
ax[1, 0].set_ylabel('ESS')
ax[1, 0].set_xlabel(r'$\mathregular{\epsilon}$', fontsize=20)
ax[1, 1].set_xlabel(r'$\mathregular{\epsilon}$', fontsize=20)
plt.tight_layout()
plt.savefig('figures/ESS_smc_mms_ms_han_gk20.png')
plt.show()

# %%
### ESS PLOTS
fig, ax = plt.subplots(figsize=(16, 7), ncols=2, nrows=2, sharex=True, sharey=True)

# SMC-RWM
ax[0, 0].plot(BAR5.εs[FROM:], BAR5.APS[FROM:], label='SMC-RWM-0.05', markevery=[-1], marker='o')
ax[0, 0].plot(BAR6.εs[FROM:], BAR6.APS[FROM:], label='SMC-RWM-0.01', markevery=[-1], marker='o')
# MSM-RWM
ax[0, 1].plot(BAR20.εs[FROM:], BAR20.PROP_MOVED[FROM:], label='MMS-RWM-0.01', markevery=[-1], marker='o')
# MS-RWM
ax[1, 0].plot(BAR11.εs[FROM:], BAR11.PROP_MOVED[FROM:], label='MS-RWM-0.1', markevery=[-1], marker='o')
ax[1, 0].plot(BAR12.εs[FROM:], BAR12.PROP_MOVED[FROM:], label='MS-RWM-0.05', markevery=[-1], marker='o')
ax[1, 0].plot(BAR13.εs[FROM:], BAR13.PROP_MOVED[FROM:], label='MS-RWM-0.01', markevery=[-1], marker='o')
# MS-HAN
ax[1, 1].plot(BAR24.εs[FROM:], BAR24.PROP_MOVED[FROM:], label='MS-HAN-0.5', markevery=[-1], marker='o')
ax[1, 1].plot(BAR25.εs[FROM:], BAR25.PROP_MOVED[FROM:], label='MS-HAN-0.1', markevery=[-1], marker='o')
ax[1, 1].plot(BAR26.εs[FROM:], BAR26.PROP_MOVED[FROM:], label='MS-HAN-0.05', markevery=[-1], marker='o')
ax[1, 1].plot(BAR27.εs[FROM:], BAR27.PROP_MOVED[FROM:], label='MS-HAN-0.01', markevery=[-1], marker='o')

for i in itertools.product([0, 1], [0, 1]):
    ax[i].set_xscale('log')
    ax[i].legend()
ax[0, 0].set_ylabel('AP')
ax[1, 0].set_ylabel('AP')
ax[1, 0].set_xlabel(r'$\mathregular{\epsilon}$', fontsize=20)
ax[1, 1].set_xlabel(r'$\mathregular{\epsilon}$', fontsize=20)
plt.tight_layout()
plt.savefig('figures/AP_smc_mms_ms_han_gk20.png')
plt.show()

# %% [markdown]
# ##### Let's quickly obtain the average epsilons

# %%
avg_min_eps_ms(generate_settings(d=d, N=N, B=B,
        δ=5.0, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=None, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=None, quantile_value=0.5, initialization='prior',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500), n=10)
# Out:
# 22778.828253722455

# %%
avg_min_eps_ms(generate_settings(d=d, N=N, B=B,
        δ=1.0, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=None, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=None, quantile_value=0.5, initialization='prior',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500), n=5)
# Out:
# 22778.828253722455

# %%
avg_min_eps_ms(generate_settings(d=d, N=N, B=B,
        δ=0.5, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=None, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=None, quantile_value=0.5, initialization='prior',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500), n=5)
# Out:
# 22778.828253722455

# %%
avg_min_eps_ms(generate_settings(d=d, N=N, B=B,
        δ=0.1, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=None, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=None, quantile_value=0.5, initialization='prior',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500), n=5)
# Out:
# 1.649603021759048

# %%
avg_min_eps_ms(generate_settings(d=d, N=N, B=B,
        δ=0.1, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=None, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=None, quantile_value=0.5, initialization='prior',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500), n=5)

# %% [markdown]
# # Try initializing from a small enough epsilon, say $\epsilon=500$

# %% [markdown]
# Similar to the first thing I tried, here I want to generated some particles that are obtained by starting the algorithm from the prior and let it run until we reach $\epsilon_{\text{min}} = 500$ these particles are then used to run the other algorithms. This is because we suspect that at the beginning there are a lot of wells.

# %% [markdown]
# ### Grab Some particles using, for instance MS-RWM with a small step size

# %%
DOES_NOT_MATTER = MSAdaptive(generate_settings(
        d=d, 
        N=N,
        B=B,
        δ=0.001,
        δmin=δmin,
        εmin=200.0,
        min_pm=min_pm,
        verbose=True,
        εs_fixed=None,
        adaptiveε=True,
        adaptiveδ=False,
        z0_manual=None,
        pm_target=0.23,
        pm_switch=pm_switch,
        prior_seed=1111,
        low_memory=True,
        integrator='rwm',
        εprop_switch=0.01,
        ε0_manual=None,
        quantile_value=0.5,
        initialization='prior',
        switch_strategy='pm',
        kernel='uniform',
        use_autograd=False,
        stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_seed=1234,
        mh_kernel_seed=1234,
        resampling_scheme='multinomial',
        maxiter=100)) #### notice maxiter=1
PARTICLES = DOES_NOT_MATTER.sample()
# Out:
# Integrator: RWM.
# Stopping criterion:  maxiter, εmin, pm.
# Resampling: MULTINOMIAL.
# Setting initial epsilon to εmax = 2530215592974.9248046875000000
# Iteration:  1
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 26533.7574199330774718
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9452000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  2
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 565.3519731500406351
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9504000000000000
# 	Step-size kept fixed at: 0.0010000000000000
# Iteration:  3
# 	Quantile Value:  0.5
# 	Trajectories constructed.
# 	Epsilon: 105.4660258601566625
# 	Weights computed and normalized.
# 	Particles Resampled.
# 	Velocities refreshed.
# 	Prop Moved: 0.9516000000000000
# 	Step-size kept fixed at: 0.0010000000000000

# %% [markdown]
# ### Run SMC-RWM from these particles

# %%
BAZ1 = SMCAdaptive(generate_settings(d=d, N=N, B=B,
        δ=5.0, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=PARTICLES, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=DOES_NOT_MATTER.εs[-1], quantile_value=0.5, initialization='manual',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500))
_ = BAZ1.sample()
### Did not move any

# %%
BAZ2 = SMCAdaptive(generate_settings(d=d, N=N, B=B,
        δ=1.0, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=PARTICLES, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=DOES_NOT_MATTER.εs[-1], quantile_value=0.5, initialization='manual',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500))
_ = BAZ2.sample()
### Did not move any

# %%
BAZ3 = SMCAdaptive(generate_settings(d=d, N=N, B=B,
        δ=0.5, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=PARTICLES, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=DOES_NOT_MATTER.εs[-1], quantile_value=0.5, initialization='manual',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500))
_ = BAZ3.sample()
### Did not move any

# %%
BAZ4 = SMCAdaptive(generate_settings(d=d, N=N, B=B,
        δ=0.1, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=PARTICLES, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=DOES_NOT_MATTER.εs[-1], quantile_value=0.5, initialization='manual',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500))
_ = BAZ4.sample()
### Did not move any

# %%
BAZ5 = SMCAdaptive(generate_settings(d=d, N=N, B=B,
        δ=0.05, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=PARTICLES, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=DOES_NOT_MATTER.εs[-1], quantile_value=0.5, initialization='manual',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500))
_ = BAZ5.sample()
# Moved some, barely

# %%
BAZ6 = SMCAdaptive(generate_settings(d=d, N=N, B=B,
        δ=0.01, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=PARTICLES, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=DOES_NOT_MATTER.εs[-1], quantile_value=0.5, initialization='manual',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500))
_ = BAZ6.sample()
# Moved a fair bit

# %%
# BAZ7 = SMCAdaptive(generate_settings(d=d, N=N, B=B,
#         δ=0.001, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
#         z0_manual=PARTICLES, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
#         εprop_switch=0.01, ε0_manual=DOES_NOT_MATTER.εs[-1], quantile_value=0.5, initialization='manual',
#         switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
#         resampling_scheme='multinomial', maxiter=500))
# _ = BAZ7.sample()
# # Moved lots

# %%
BAZ1.εs[-1], BAZ2.εs[-1], BAZ3.εs[-1], BAZ4.εs[-1], BAZ5.εs[-1], BAZ6.εs[-1]
# Out:
# (46.465522652281706,
#  46.465522652281706,
#  46.465522652281706,
#  46.465522652281706,
#  10.852442674093524,
#  3.9099113869798634)

# %% [markdown]
# ### Run MS-RWM from these particles

# %%
BAZ8 = MSAdaptive(generate_settings(d=d, N=N, B=B,
        δ=5.0, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=PARTICLES, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=DOES_NOT_MATTER.εs[-1], quantile_value=0.5, initialization='manual',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500))
_ = BAZ8.sample()
# Did not move any

# %%
BAZ9 = MSAdaptive(generate_settings(d=d, N=N, B=B,
        δ=1.0, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=PARTICLES, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=DOES_NOT_MATTER.εs[-1], quantile_value=0.5, initialization='manual',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500))
_ = BAZ9.sample()
# Barely moved any

# %%
BAZ10 = MSAdaptive(generate_settings(d=d, N=N, B=B,
        δ=0.5, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=PARTICLES, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=DOES_NOT_MATTER.εs[-1], quantile_value=0.5, initialization='manual',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500))
_ = BAZ10.sample()
# Moved

# %%
BAZ11 = MSAdaptive(generate_settings(d=d, N=N, B=B,
        δ=0.1, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=PARTICLES, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=DOES_NOT_MATTER.εs[-1], quantile_value=0.5, initialization='manual',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500))
_ = BAZ11.sample()
# Moved

# %%
BAZ12 = MSAdaptive(generate_settings(d=d, N=N, B=B,
        δ=0.05, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=PARTICLES, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=DOES_NOT_MATTER.εs[-1], quantile_value=0.5, initialization='manual',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500))
_ = BAZ12.sample()
# Moved

# %%
BAZ13 = MSAdaptive(generate_settings(d=d, N=N, B=B,
        δ=0.01, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=PARTICLES, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=DOES_NOT_MATTER.εs[-1], quantile_value=0.5, initialization='manual',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500))
_ = BAZ13.sample()
# Moved

# %%
BAZ8.εs[-1], BAZ9.εs[-1], BAZ10.εs[-1], BAZ11.εs[-1], BAZ12.εs[-1], BAZ13.εs[-1]
# Out:
# (45.57945065923498,
#  8.72423673358774,
#  5.3073998157102675,
#  1.3288344838561552,
#  1.2578585371149873,
#  0.24730650294067696)

# %% [markdown]
# ### Run MSM-RWM from these particles

# %%
BAZ15 = MSAdaptive(generate_settings(d=d, N=N, B=B,
        δ=5.0, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=PARTICLES, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=DOES_NOT_MATTER.εs[-1], quantile_value=0.5, initialization='manual',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500, metropolised=True))
_ = BAZ15.sample()
# Did not move any

# %%
BAZ16 = MSAdaptive(generate_settings(d=d, N=N, B=B,
        δ=1.0, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=PARTICLES, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=DOES_NOT_MATTER.εs[-1], quantile_value=0.5, initialization='manual',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500, metropolised=True))
_ = BAZ16.sample()
# Did not move any

# %%
BAZ17 = MSAdaptive(generate_settings(d=d, N=N, B=B,
        δ=0.5, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=PARTICLES, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=DOES_NOT_MATTER.εs[-1], quantile_value=0.5, initialization='manual',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500, metropolised=True))
_ = BAZ17.sample()
# Did not move any

# %%
BAZ18 = MSAdaptive(generate_settings(d=d, N=N, B=B,
        δ=0.1, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=PARTICLES, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=DOES_NOT_MATTER.εs[-1], quantile_value=0.5, initialization='manual',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500, metropolised=True))
_ = BAZ18.sample()

# %%
BAZ19 = MSAdaptive(generate_settings(d=d, N=N, B=B,
        δ=0.05, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=PARTICLES, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=DOES_NOT_MATTER.εs[-1], quantile_value=0.5, initialization='manual',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500, metropolised=True))
_ = BAZ19.sample()

# %%
BAZ20 = MSAdaptive(generate_settings(d=d, N=N, B=B,
        δ=0.01, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=PARTICLES, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=DOES_NOT_MATTER.εs[-1], quantile_value=0.5, initialization='manual',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500, metropolised=True))
_ = BAZ20.sample()

# %%
BAZ15.εs[-1], BAZ16.εs[-1], BAZ17.εs[-1], BAZ18.εs[-1], BAZ19.εs[-1], BAZ20.εs[-1]
# Out:
# (45.57945065923498,
#  45.57945065923498,
#  45.57945065923498,
#  45.57945065923498,
#  8.981107302001464,
#  2.295753057348892)

# %% [markdown]
# ### Run MS-HAN from these particles

# %%
BAZ22 = MSAdaptive(generate_settings(d=d, N=N, B=B,
        δ=5.0, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=PARTICLES, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='hug_and_nhug',
        εprop_switch=0.01, ε0_manual=DOES_NOT_MATTER.εs[-1], quantile_value=0.5, initialization='manual',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500, projection_method='qr'))
_ = BAZ22.sample()
# Out:
# ValueError was raised:  array must not contain infs or NaNs

# %%
BAZ23 = MSAdaptive(generate_settings(d=d, N=N, B=B,
        δ=1.0, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=PARTICLES, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='hug_and_nhug',
        εprop_switch=0.01, ε0_manual=DOES_NOT_MATTER.εs[-1], quantile_value=0.5, initialization='manual',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500, projection_method='qr'))
_ = BAZ23.sample()
# Out:
# ValueError was raised:  array must not contain infs or NaNs

# %%
BAZ24 = MSAdaptive(generate_settings(d=d, N=N, B=B,
        δ=0.5, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=PARTICLES, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='hug_and_nhug',
        εprop_switch=0.01, ε0_manual=DOES_NOT_MATTER.εs[-1], quantile_value=0.5, initialization='manual',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500, projection_method='qr'))
_ = BAZ24.sample()

# %%
BAZ25 = MSAdaptive(generate_settings(d=d, N=N, B=B,
        δ=0.1, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=PARTICLES, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='hug_and_nhug',
        εprop_switch=0.01, ε0_manual=DOES_NOT_MATTER.εs[-1], quantile_value=0.5, initialization='manual',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500, projection_method='qr'))
_ = BAZ25.sample()

# %%
BAZ26 = MSAdaptive(generate_settings(d=d, N=N, B=B,
        δ=0.05, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=PARTICLES, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='hug_and_nhug',
        εprop_switch=0.01, ε0_manual=DOES_NOT_MATTER.εs[-1], quantile_value=0.5, initialization='manual',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500, projection_method='qr'))
_ = BAZ26.sample()

# %%
BAZ27 = MSAdaptive(generate_settings(d=d, N=N, B=B,
        δ=0.01, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=PARTICLES, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='hug_and_nhug',
        εprop_switch=0.01, ε0_manual=DOES_NOT_MATTER.εs[-1], quantile_value=0.5, initialization='manual',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500, projection_method='qr'))
_ = BAZ27.sample()

# %%
BAZ24.εs[-1], BAZ25.εs[-1], BAZ26.εs[-1], BAZ27.εs[-1]
# Out:
# (0.1641222316509819,
#  0.020092187686464105,
#  0.18356523452492715,
#  2.845356146967827)

# %%
send_notification_to_iphone("Experiment 89 finished.")

# %%
### ESS PLOTS
fig, ax = plt.subplots(figsize=(16, 7), ncols=2, nrows=2, sharex=True, sharey=True)

# SMC-RWM
ax[0, 0].plot(BAZ5.εs[FROM:], BAZ5.ESS[FROM:], label='SMC-RWM-0.05', markevery=[-1], marker='o')
ax[0, 0].plot(BAZ6.εs[FROM:], BAZ6.ESS[FROM:], label='SMC-RWM-0.01', markevery=[-1], marker='o')
# MSM-RWM
ax[0, 1].plot(BAZ19.εs[FROM:], BAZ19.ESS[FROM:], label='MMS-RWM-0.05', markevery=[-1], marker='o')
ax[0, 1].plot(BAZ20.εs[FROM:], BAZ20.ESS[FROM:], label='MMS-RWM-0.01', markevery=[-1], marker='o')
# MS-RWM
ax[1, 0].plot(BAZ9.εs[FROM:], BAZ9.ESS[FROM:], label='MS-RWM-1.0', markevery=[-1], marker='o')
ax[1, 0].plot(BAZ10.εs[FROM:], BAZ10.ESS[FROM:], label='MS-RWM-0.5', markevery=[-1], marker='o')
ax[1, 0].plot(BAZ11.εs[FROM:], BAZ11.ESS[FROM:], label='MS-RWM-0.1', markevery=[-1], marker='o')
ax[1, 0].plot(BAZ12.εs[FROM:], BAZ12.ESS[FROM:], label='MS-RWM-0.05', markevery=[-1], marker='o')
ax[1, 0].plot(BAZ13.εs[FROM:], BAZ13.ESS[FROM:], label='MS-RWM-0.01', markevery=[-1], marker='o')
# MS-HAN
ax[1, 1].plot(BAZ24.εs[FROM:], BAZ24.ESS[FROM:], label='MS-HAN-0.5', markevery=[-1], marker='o')
ax[1, 1].plot(BAZ25.εs[FROM:], BAZ25.ESS[FROM:], label='MS-HAN-0.1', markevery=[-1], marker='o')
ax[1, 1].plot(BAZ26.εs[FROM:], BAZ26.ESS[FROM:], label='MS-HAN-0.05', markevery=[-1], marker='o')
ax[1, 1].plot(BAZ27.εs[FROM:], BAZ27.ESS[FROM:], label='MS-HAN-0.01', markevery=[-1], marker='o')

for i in itertools.product([0, 1], [0, 1]):
    ax[i].set_xscale('log')
    ax[i].set_yscale('log')
    ax[i].legend()
ax[0, 0].set_ylabel('ESS')
ax[1, 0].set_ylabel('ESS')
ax[1, 0].set_xlabel(r'$\mathregular{\epsilon}$', fontsize=20)
ax[1, 1].set_xlabel(r'$\mathregular{\epsilon}$', fontsize=20)
plt.tight_layout()
plt.savefig('figures/ESS_smc_mms_ms_han_gk20_particles.png')
plt.show()

# %%
### ESS PLOTS
fig, ax = plt.subplots(figsize=(16, 7), ncols=2, nrows=2, sharex=True, sharey=True)

# SMC-RWM
ax[0, 0].plot(BAZ5.εs[FROM:], BAZ5.APS[FROM:], label='SMC-RWM-0.05', markevery=[-1], marker='o')
ax[0, 0].plot(BAZ6.εs[FROM:], BAZ6.APS[FROM:], label='SMC-RWM-0.01', markevery=[-1], marker='o')
# MSM-RWM
ax[0, 1].plot(BAZ19.εs[FROM:], BAZ19.PROP_MOVED[FROM:], label='MMS-RWM-0.01', markevery=[-1], marker='o')
ax[0, 1].plot(BAZ20.εs[FROM:], BAZ20.PROP_MOVED[FROM:], label='MMS-RWM-0.01', markevery=[-1], marker='o')
# MS-RWM
ax[1, 0].plot(BAZ9.εs[FROM:], BAZ9.PROP_MOVED[FROM:], label='MS-RWM-0.1', markevery=[-1], marker='o')
ax[1, 0].plot(BAZ10.εs[FROM:], BAZ10.PROP_MOVED[FROM:], label='MS-RWM-0.1', markevery=[-1], marker='o')
ax[1, 0].plot(BAZ11.εs[FROM:], BAZ11.PROP_MOVED[FROM:], label='MS-RWM-0.1', markevery=[-1], marker='o')
ax[1, 0].plot(BAZ12.εs[FROM:], BAZ12.PROP_MOVED[FROM:], label='MS-RWM-0.05', markevery=[-1], marker='o')
ax[1, 0].plot(BAZ13.εs[FROM:], BAZ13.PROP_MOVED[FROM:], label='MS-RWM-0.01', markevery=[-1], marker='o')
# MS-HAN
ax[1, 1].plot(BAZ24.εs[FROM:], BAZ24.PROP_MOVED[FROM:], label='MS-HAN-0.5', markevery=[-1], marker='o')
ax[1, 1].plot(BAZ25.εs[FROM:], BAZ25.PROP_MOVED[FROM:], label='MS-HAN-0.1', markevery=[-1], marker='o')
ax[1, 1].plot(BAZ26.εs[FROM:], BAZ26.PROP_MOVED[FROM:], label='MS-HAN-0.05', markevery=[-1], marker='o')
ax[1, 1].plot(BAZ27.εs[FROM:], BAZ27.PROP_MOVED[FROM:], label='MS-HAN-0.01', markevery=[-1], marker='o')

for i in itertools.product([0, 1], [0, 1]):
    ax[i].set_xscale('log')
    ax[i].legend()
ax[0, 0].set_ylabel('AP')
ax[1, 0].set_ylabel('AP')
ax[1, 0].set_xlabel(r'$\mathregular{\epsilon}$', fontsize=20)
ax[1, 1].set_xlabel(r'$\mathregular{\epsilon}$', fontsize=20)
plt.tight_layout()
plt.savefig('figures/AP_smc_mms_ms_han_gk20_particles.png')
plt.show()

# %% [markdown]
# Need to figure out why MS-HAN fails when the step size is too large. Can I try applying $\psi$ on `PARTICLES` and see what error I get? The error above is a secondary error that comes from storing the particles, but I bet the true error comes from the Jacobian computation overflowing for some reason.

# %% [markdown]
# 1. Finish MSM-RWM with all step sizes. Possibly since the one with $\delta=0.5$ is working, it is likely that for smaller step sizes it will still reach $500$ iterations but due to a slower exploration of the space, it will end at a larger epsilon (the smaller $\delta$, the larger the $\epsilon$).
# 2. Fill up the final $\varepsilon$ table.
# 3. Plot ESS/$\varepsilon$ for all three algorithms (?)
# 4. Plot AP(PM)/$\varepsilon$ for all three algorithms

# %%
from numpy import save

folder = 'experiment89/'

##### SMC-RWM
### BAZ1
save(folder + 'baz1_εs.npy', BAZ1.εs)
save(folder + 'baz1_ess.npy', BAZ1.ESS)
save(folder + 'baz1_pm.npy', BAZ1.APS)
save(folder + 'baz1_k_resampled.npy', BAZ1.INDECES)
### BAZ2
save(folder + 'baz2_εs.npy', BAZ2.εs)
save(folder + 'baz2_ess.npy', BAZ2.ESS)
save(folder + 'baz2_pm.npy', BAZ2.APS)
save(folder + 'baz2_k_resampled.npy', BAZ2.INDECES)
### BAZ3
save(folder + 'baz3_εs.npy', BAZ3.εs)
save(folder + 'baz3_ess.npy', BAZ3.ESS)
save(folder + 'baz3_pm.npy', BAZ3.APS)
save(folder + 'baz3_k_resampled.npy', BAZ3.INDECES)
### BAZ4
save(folder + 'baz4_εs.npy', BAZ4.εs)
save(folder + 'baz4_ess.npy', BAZ4.ESS)
save(folder + 'baz4_pm.npy', BAZ4.APS)
save(folder + 'baz4_k_resampled.npy', BAZ4.INDECES)
### BAZ5
save(folder + 'baz5_εs.npy', BAZ5.εs)
save(folder + 'baz5_ess.npy', BAZ5.ESS)
save(folder + 'baz5_pm.npy', BAZ5.APS)
save(folder + 'baz5_k_resampled.npy', BAZ5.INDECES)
### BAZ6
save(folder + 'baz6_εs.npy', BAZ6.εs)
save(folder + 'baz6_ess.npy', BAZ6.ESS)
save(folder + 'baz6_pm.npy', BAZ6.APS)
save(folder + 'baz6_k_resampled.npy', BAZ6.INDECES)

##### MS-RWM
### BAZ8
save(folder + 'baz8_εs.npy', BAZ8.εs)
save(folder + 'baz8_ess.npy', BAZ8.ESS)
save(folder + 'baz8_pm.npy', BAZ8.PROP_MOVED)
save(folder + 'baz8_k_resampled.npy', BAZ8.K_RESAMPLED)
### BAZ9
save(folder + 'baz9_εs.npy', BAZ9.εs)
save(folder + 'baz9_ess.npy', BAZ9.ESS)
save(folder + 'baz9_pm.npy', BAZ9.PROP_MOVED)
save(folder + 'baz9_k_resampled.npy', BAZ9.K_RESAMPLED)
### BAZ10
save(folder + 'baz10_εs.npy', BAZ10.εs)
save(folder + 'baz10_ess.npy', BAZ10.ESS)
save(folder + 'baz10_pm.npy', BAZ10.PROP_MOVED)
save(folder + 'baz10_k_resampled.npy', BAZ10.K_RESAMPLED)
### BAZ11
save(folder + 'baz11_εs.npy', BAZ11.εs)
save(folder + 'baz11_ess.npy', BAZ11.ESS)
save(folder + 'baz11_pm.npy', BAZ11.PROP_MOVED)
save(folder + 'baz11_k_resampled.npy', BAZ11.K_RESAMPLED)
### BAZ12
save(folder + 'baz12_εs.npy', BAZ12.εs)
save(folder + 'baz12_ess.npy', BAZ12.ESS)
save(folder + 'baz12_pm.npy', BAZ12.PROP_MOVED)
save(folder + 'baz12_k_resampled.npy', BAZ12.K_RESAMPLED)
### BAZ13
save(folder + 'baz13_εs.npy', BAZ13.εs)
save(folder + 'baz13_ess.npy', BAZ13.ESS)
save(folder + 'baz13_pm.npy', BAZ13.PROP_MOVED)
save(folder + 'baz13_k_resampled.npy', BAZ13.K_RESAMPLED)

##### MSM-RWM
### BAZ15
save(folder + 'baz15_εs.npy', BAZ15.εs)
save(folder + 'baz15_ess.npy', BAZ15.ESS)
save(folder + 'baz15_pm.npy', BAZ15.PROP_MOVED)
save(folder + 'baz15_k_resampled.npy', BAZ15.K_RESAMPLED)
### BAZ16
save(folder + 'baz16_εs.npy', BAZ16.εs)
save(folder + 'baz16_ess.npy', BAZ16.ESS)
save(folder + 'baz16_pm.npy', BAZ16.PROP_MOVED)
save(folder + 'baz16_k_resampled.npy', BAZ16.K_RESAMPLED)
### BAZ17
save(folder + 'baz17_εs.npy', BAZ17.εs)
save(folder + 'baz17_ess.npy', BAZ17.ESS)
save(folder + 'baz17_pm.npy', BAZ17.PROP_MOVED)
save(folder + 'baz17_k_resampled.npy', BAZ17.K_RESAMPLED)
### BAZ18
save(folder + 'baz18_εs.npy', BAZ18.εs)
save(folder + 'baz18_ess.npy', BAZ18.ESS)
save(folder + 'baz18_pm.npy', BAZ18.PROP_MOVED)
save(folder + 'baz18_k_resampled.npy', BAZ18.K_RESAMPLED)
### BAZ19
save(folder + 'baz19_εs.npy', BAZ19.εs)
save(folder + 'baz19_ess.npy', BAZ19.ESS)
save(folder + 'baz19_pm.npy', BAZ19.PROP_MOVED)
save(folder + 'baz19_k_resampled.npy', BAZ19.K_RESAMPLED)
### BAZ20
save(folder + 'baz20_εs.npy', BAZ20.εs)
save(folder + 'baz20_ess.npy', BAZ20.ESS)
save(folder + 'baz20_pm.npy', BAZ20.PROP_MOVED)
save(folder + 'baz20_k_resampled.npy', BAZ20.K_RESAMPLED)

##### MS-HAN
### BAZ22
save(folder + 'baz22_εs.npy', BAZ22.εs)
save(folder + 'baz22_ess.npy', BAZ22.ESS)
save(folder + 'baz22_pm.npy', BAZ22.PROP_MOVED)
save(folder + 'baz22_k_resampled.npy', BAZ22.K_RESAMPLED)
### BAZ23
save(folder + 'baz23_εs.npy', BAZ23.εs)
save(folder + 'baz23_ess.npy', BAZ23.ESS)
save(folder + 'baz23_pm.npy', BAZ23.PROP_MOVED)
save(folder + 'baz23_k_resampled.npy', BAZ23.K_RESAMPLED)
### BAZ24
save(folder + 'baz24_εs.npy', BAZ24.εs)
save(folder + 'baz24_ess.npy', BAZ24.ESS)
save(folder + 'baz24_pm.npy', BAZ24.PROP_MOVED)
save(folder + 'baz24_k_resampled.npy', BAZ24.K_RESAMPLED)
### BAZ25
save(folder + 'baz25_εs.npy', BAZ25.εs)
save(folder + 'baz25_ess.npy', BAZ25.ESS)
save(folder + 'baz25_pm.npy', BAZ25.PROP_MOVED)
save(folder + 'baz25_k_resampled.npy', BAZ25.K_RESAMPLED)

# %%
fig, ax = plt.subplots(figsize=(16, 4), ncols=2)

### ESS
# SMC-RWM
ax[0].plot(BAZ1.εs, BAZ1.ESS, label='SMC-RWM-0.5', markevery=[-1], marker='o', color=lighten_color('red', 1.0))
ax[0].plot(BAZ2.εs, BAZ2.ESS, label='SMC-RWM-1.0', markevery=[-1], marker='o', color=lighten_color('red', 0.85))
ax[0].plot(BAZ3.εs, BAZ3.ESS, label='SMC-RWM-0.5', markevery=[-1], marker='o', color=lighten_color('red', 0.7))
ax[0].plot(BAZ4.εs, BAZ4.ESS, label='SMC-RWM-0.1', markevery=[-1], marker='o', color=lighten_color('red', 0.55))
ax[0].plot(BAZ5.εs, BAZ5.ESS, label='SMC-RWM-0.05', markevery=[-1], marker='o', color=lighten_color('red', 0.40))
ax[0].plot(BAZ6.εs, BAZ6.ESS, label='SMC-RWM-0.01', markevery=[-1], marker='o', color=lighten_color('red', 0.25))
# ax[0].plot(BAZ7.εs, BAZ7.ESS, label='SMC-RWM-0.001', markevery=[-1], marker='o', color=lighten_color('red', 0.10))
# MS-RWM
ax[0].plot(BAZ8.εs, BAZ8.ESS, label='MS-RWM-5.0', markevery=[-1], marker='o', color=lighten_color('green', 1.0))
ax[0].plot(BAZ9.εs, BAZ9.ESS, label='MS-RWM-1.0', markevery=[-1], marker='o', color=lighten_color('green', 0.85))
ax[0].plot(BAZ10.εs, BAZ10.ESS, label='MS-RWM-0.5', markevery=[-1], marker='o', color=lighten_color('green', 0.7))
ax[0].plot(BAZ11.εs, BAZ11.ESS, label='MS-RWM-0.1', markevery=[-1], marker='o', color=lighten_color('green', 0.55))
ax[0].plot(BAZ12.εs, BAZ12.ESS, label='MS-RWM-0.05', markevery=[-1], marker='o', color=lighten_color('green', 0.4))
ax[0].plot(BAZ13.εs, BAZ13.ESS, label='MS-RWM-0.01', markevery=[-1], marker='o', color=lighten_color('green', 0.25))
# ax[0].plot(BAZ14.εs, BAZ14.ESS, label='MS-RWM-0.001', markevery=[-1], marker='o', color=lighten_color('green', 0.1))
# MSM-RWM
ax[0].plot(BAZ15.εs, BAZ15.ESS, label='MSM-RWM-5.0', markevery=[-1], marker='o', color=lighten_color('blue', 1.0))
ax[0].plot(BAZ16.εs, BAZ16.ESS, label='MSM-RWM-1.0', markevery=[-1], marker='o', color=lighten_color('blue', 0.85))
ax[0].plot(BAZ17.εs, BAZ17.ESS, label='MSM-RWM-0.5', markevery=[-1], marker='o', color=lighten_color('blue', 0.7))
ax[0].plot(BAZ18.εs, BAZ18.ESS, label='MSM-RWM-0.1', markevery=[-1], marker='o', color=lighten_color('blue', 0.55))
ax[0].plot(BAZ19.εs, BAZ19.ESS, label='MSM-RWM-0.05', markevery=[-1], marker='o', color=lighten_color('blue', 0.4))
ax[0].plot(BAZ20.εs, BAZ20.ESS, label='MSM-RWM-0.01', markevery=[-1], marker='o', color=lighten_color('blue', 0.25))
# ax[0].plot(BAZ21.εs, BAZ21.ESS, label='MSM-RWM-0.001', markevery=[-1], marker='o', color=lighten_color('blue', 0.1))
# Prettify
ax[0].set_xscale('log')
ax[0].set_yscale('log')
# ax[0].legend()
ax[0].set_ylabel('ESS')


### AP
# SMC-RWM
ax[1].plot(BAZ1.εs, BAZ1.APS, label='SMC-RWM-5.0', markevery=[-1], marker='o', color=lighten_color('red', 1.0))
ax[1].plot(BAZ2.εs, BAZ2.APS, label='SMC-RWM-1.0', markevery=[-1], marker='o', color=lighten_color('red', 0.85))
ax[1].plot(BAZ3.εs, BAZ3.APS, label='SMC-RWM-0.5', markevery=[-1], marker='o', color=lighten_color('red', 0.7))
ax[1].plot(BAZ4.εs, BAZ4.APS, label='SMC-RWM-0.1', markevery=[-1], marker='o', color=lighten_color('red', 0.55))
ax[1].plot(BAZ5.εs, BAZ5.APS, label='SMC-RWM-0.05', markevery=[-1], marker='o', color=lighten_color('red', 0.4))
ax[1].plot(BAZ6.εs, BAZ6.APS, label='SMC-RWM-0.01', markevery=[-1], marker='o', color=lighten_color('red', 0.25))
# ax[1].plot(BAZ7.εs, BAZ7.APS, label='SMC-RWM-0.001', markevery=[-1], marker='o', color=lighten_color('red', 0.10))
# MS-RWM
ax[1].plot(BAZ8.εs, BAZ8.PROP_MOVED, label='MS-RWM-5.0', markevery=[-1], marker='o', color=lighten_color('green', 1.0))
ax[1].plot(BAZ9.εs, BAZ9.PROP_MOVED, label='MS-RWM-1.0', markevery=[-1], marker='o', color=lighten_color('green', 0.85))
ax[1].plot(BAZ10.εs, BAZ10.PROP_MOVED, label='MS-RWM-0.5', markevery=[-1], marker='o', color=lighten_color('green', 0.70))
ax[1].plot(BAZ11.εs, BAZ11.PROP_MOVED, label='MS-RWM-0.1', markevery=[-1], marker='o', color=lighten_color('green', 0.55))
ax[1].plot(BAZ12.εs, BAZ12.PROP_MOVED, label='MS-RWM-0.05', markevery=[-1], marker='o', color=lighten_color('green', 0.40))
ax[1].plot(BAZ13.εs, BAZ13.PROP_MOVED, label='MS-RWM-0.01', markevery=[-1], marker='o', color=lighten_color('green', 0.25))
# ax[1].plot(BAZ14.εs, BAZ14.PROP_MOVED, label='MS-RWM-0.001', markevery=[-1], marker='o', color=lighten_color('green', 0.10))
# MSM-RWM
ax[1].plot(BAZ15.εs, BAZ15.PROP_MOVED, label='MSM-RWM-5.0', markevery=[-1], marker='o', color=lighten_color('green', 1.0))
ax[1].plot(BAZ16.εs, BAZ16.PROP_MOVED, label='MSM-RWM-1.0', markevery=[-1], marker='o', color=lighten_color('green', 0.85))
ax[1].plot(BAZ17.εs, BAZ17.PROP_MOVED, label='MSM-RWM-0.5', markevery=[-1], marker='o', color=lighten_color('green', 0.70))
ax[1].plot(BAZ18.εs, BAZ18.PROP_MOVED, label='MSM-RWM-0.1', markevery=[-1], marker='o', color=lighten_color('green', 0.55))
ax[1].plot(BAZ19.εs, BAZ19.PROP_MOVED, label='MSM-RWM-0.05', markevery=[-1], marker='o', color=lighten_color('green', 0.40))
ax[1].plot(BAZ20.εs, BAZ20.PROP_MOVED, label='MSM-RWM-0.01', markevery=[-1], marker='o', color=lighten_color('green', 0.25))
# ax[1].plot(BAZ21.εs, BAZ21.PROP_MOVED, label='MSM-RWM-0.001', markevery=[-1], marker='o', color=lighten_color('green', 0.10))
# Prettify
ax[1].set_xscale('log')
# ax[1].legend()
ax[1].set_ylabel('PM')
# plt.suptitle("MS-RWM")
plt.show()

# %% [markdown]
# # Grab Particles from epsilon=500 (ish) and then run using a smaller quantile value

# %%
PARTICLES500_MS = MSAdaptive(generate_settings(
        d=d, 
        N=N,
        B=B,
        δ=0.001,
        δmin=δmin,
        εmin=500.0,
        min_pm=min_pm,
        verbose=True,
        εs_fixed=None,
        adaptiveε=True,
        adaptiveδ=False,
        z0_manual=None,
        pm_target=0.23,
        pm_switch=pm_switch,
        prior_seed=1111,
        low_memory=True,
        integrator='rwm',
        εprop_switch=0.01,
        ε0_manual=None,
        quantile_value=0.95,
        initialization='prior',
        switch_strategy='pm',
        kernel='uniform',
        use_autograd=False,
        stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_seed=1234,
        mh_kernel_seed=1234,
        resampling_scheme='multinomial',
        maxiter=100)) #### notice maxiter=1
PARTICLES500 = PARTICLES500_MS.sample()

# %% [markdown]
# ### Run SMC-RWM from grabbed particles

# %%
BEE1 = SMCAdaptive(generate_settings(d=d, N=N, B=B,
        δ=5.0, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=PARTICLES, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=DOES_NOT_MATTER.εs[-1], quantile_value=0.8, initialization='manual',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500))
_ = BEE1.sample()
### Did not move any

# %%
BEE2 = SMCAdaptive(generate_settings(d=d, N=N, B=B,
        δ=1.0, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=PARTICLES, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=DOES_NOT_MATTER.εs[-1], quantile_value=0.8, initialization='manual',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500))
_ = BEE2.sample()
### Did not move any

# %%
BEE3 = SMCAdaptive(generate_settings(d=d, N=N, B=B,
        δ=0.5, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=PARTICLES, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=DOES_NOT_MATTER.εs[-1], quantile_value=0.8, initialization='manual',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500))
_ = BEE3.sample()
### Did not move any

# %%
BEE4 = SMCAdaptive(generate_settings(d=d, N=N, B=B,
        δ=0.1, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=PARTICLES, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=DOES_NOT_MATTER.εs[-1], quantile_value=0.8, initialization='manual',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500))
_ = BEE4.sample()
### Did not move any

# %%
BEE5 = SMCAdaptive(generate_settings(d=d, N=N, B=B,
        δ=0.05, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=PARTICLES, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=DOES_NOT_MATTER.εs[-1], quantile_value=0.8, initialization='manual',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500))
_ = BEE5.sample()
### Moved some

# %%
BEE6 = SMCAdaptive(generate_settings(d=d, N=N, B=B,
        δ=0.01, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=PARTICLES, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=DOES_NOT_MATTER.εs[-1], quantile_value=0.8, initialization='manual',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500))
_ = BEE6.sample()
### Moved Some

# %%
BEE5.εs[-1], BEE6.εs[-1]
# Out:
# (9.681443594785081, 3.3098684171381074)

# %% [markdown]
# ### Run MS-RWM from grabbed particles

# %%
BEE8 =  MSAdaptive(generate_settings(d=d, N=N, B=B,
        δ=5.0, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=PARTICLES, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=DOES_NOT_MATTER.εs[-1], quantile_value=0.8, initialization='manual',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500))
_ = BEE8.sample()
### Did not move any

# %%
BEE9 =  MSAdaptive(generate_settings(d=d, N=N, B=B,
        δ=1.0, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=PARTICLES, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=DOES_NOT_MATTER.εs[-1], quantile_value=0.8, initialization='manual',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500))
_ = BEE9.sample()
### Did not move any

# %%
BEE10 =  MSAdaptive(generate_settings(d=d, N=N, B=B,
        δ=0.5, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=PARTICLES, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=DOES_NOT_MATTER.εs[-1], quantile_value=0.8, initialization='manual',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500))
_ = BEE10.sample()
### Did not move any

# %%
BEE11 =  MSAdaptive(generate_settings(d=d, N=N, B=B,
        δ=0.1, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=PARTICLES, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=DOES_NOT_MATTER.εs[-1], quantile_value=0.8, initialization='manual',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500))
_ = BEE11.sample()
### Did not move any

# %%
BEE12 =  MSAdaptive(generate_settings(d=d, N=N, B=B,
        δ=0.05, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=PARTICLES, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=DOES_NOT_MATTER.εs[-1], quantile_value=0.8, initialization='manual',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500))
_ = BEE12.sample()
### Did not move any

# %%
BEE13 =  MSAdaptive(generate_settings(d=d, N=N, B=B,
        δ=0.01, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=PARTICLES, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=DOES_NOT_MATTER.εs[-1], quantile_value=0.8, initialization='manual',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500))
_ = BEE13.sample()
### Did not move any

# %%
BEE8.εs[-1], BEE9.εs[-1], BEE10.εs[-1], BEE11.εs[-1], BEE12.εs[-1], BEE13.εs[-1]
# Out:
# (77.69159559417997,
#  12.588720125713202,
#  7.07801777029329,
#  1.241225746670634,
#  0.5707048540643018,
#  0.21907557040210507)

# %% [markdown]
# ### Run MSM-RWM from grabbed particles

# %%
BEE15 =  MSAdaptive(generate_settings(d=d, N=N, B=B,
        δ=5.0, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=PARTICLES, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=DOES_NOT_MATTER.εs[-1], quantile_value=0.8, initialization='manual',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500, metropolised=True))
_ = BEE15.sample()
### Did not move any

# %%
BEE16 =  MSAdaptive(generate_settings(d=d, N=N, B=B,
        δ=1.0, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=PARTICLES, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=DOES_NOT_MATTER.εs[-1], quantile_value=0.8, initialization='manual',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500, metropolised=True))
_ = BEE16.sample()
### Did not move any

# %%
BEE17 =  MSAdaptive(generate_settings(d=d, N=N, B=B,
        δ=0.5, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=PARTICLES, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=DOES_NOT_MATTER.εs[-1], quantile_value=0.8, initialization='manual',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500, metropolised=True))
_ = BEE17.sample()
### Did not move any

# %%
BEE18 =  MSAdaptive(generate_settings(d=d, N=N, B=B,
        δ=0.1, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=PARTICLES, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=DOES_NOT_MATTER.εs[-1], quantile_value=0.8, initialization='manual',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500, metropolised=True))
_ = BEE18.sample()
### Did not move any

# %%
BEE19 =  MSAdaptive(generate_settings(d=d, N=N, B=B,
        δ=0.05, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=PARTICLES, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=DOES_NOT_MATTER.εs[-1], quantile_value=0.8, initialization='manual',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500, metropolised=True))
_ = BEE19.sample()
### Did not move any

# %%
BEE20 =  MSAdaptive(generate_settings(d=d, N=N, B=B,
        δ=0.01, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=PARTICLES, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=DOES_NOT_MATTER.εs[-1], quantile_value=0.8, initialization='manual',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500, metropolised=True))
_ = BEE20.sample()
### Did not move any

# %% [markdown]
# ### Run MS-HAN from grabbed particles

# %%
BEE22 =  MSAdaptive(generate_settings(d=d, N=N, B=B,
        δ=5.0, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=PARTICLES, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm_then_han',
        εprop_switch=0.01, ε0_manual=DOES_NOT_MATTER.εs[-1], quantile_value=0.8, initialization='manual',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500, metropolised=True))
_ = BEE22.sample()
### Did not move any

# %%
BEE23 =  MSAdaptive(generate_settings(d=d, N=N, B=B,
        δ=1.0, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=PARTICLES, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm_then_han',
        εprop_switch=0.01, ε0_manual=DOES_NOT_MATTER.εs[-1], quantile_value=0.8, initialization='manual',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500, metropolised=True))
_ = BEE23.sample()
### Did not move any

# %%
BEE24 =  MSAdaptive(generate_settings(d=d, N=N, B=B,
        δ=0.5, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=PARTICLES, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm_then_han',
        εprop_switch=0.01, ε0_manual=DOES_NOT_MATTER.εs[-1], quantile_value=0.8, initialization='manual',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500, metropolised=True))
_ = BEE24.sample()
### Did not move any

# %%
BEE25 =  MSAdaptive(generate_settings(d=d, N=N, B=B,
        δ=0.1, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=PARTICLES, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm_then_han',
        εprop_switch=0.01, ε0_manual=DOES_NOT_MATTER.εs[-1], quantile_value=0.8, initialization='manual',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500, metropolised=True))
_ = BEE25.sample()
### Did not move any

# %%
BEE26 =  MSAdaptive(generate_settings(d=d, N=N, B=B,
        δ=0.05, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=PARTICLES, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm_then_han',
        εprop_switch=0.01, ε0_manual=DOES_NOT_MATTER.εs[-1], quantile_value=0.8, initialization='manual',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500, metropolised=True))
_ = BEE26.sample()
### Did not move any

# %%
BEE27 =  MSAdaptive(generate_settings(d=d, N=N, B=B,
        δ=0.01, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=PARTICLES, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm_then_han',
        εprop_switch=0.01, ε0_manual=DOES_NOT_MATTER.εs[-1], quantile_value=0.8, initialization='manual',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500, metropolised=True))
_ = BEE27.sample()
### Did not move any

# %% [markdown]
# # Run from Prior but with smaller quantile value

# %% [markdown]
# ### SMC from prior with small quantile value

# %%
LOO1 = SMCAdaptive(generate_settings(d=d, N=N, B=B,
        δ=5.0, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=None, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=None, quantile_value=0.8, initialization='prior',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500))
_ = LOO1.sample()
# Does not move

# %%
LOO2 = SMCAdaptive(generate_settings(d=d, N=N, B=B,
        δ=1.0, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=None, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=None, quantile_value=0.8, initialization='prior',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500))
_ = LOO2.sample()
# Does not move

# %%
LOO3 = SMCAdaptive(generate_settings(d=d, N=N, B=B,
        δ=0.5, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=None, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=None, quantile_value=0.8, initialization='prior',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500))
_ = LOO3.sample()
# Does not move

# %%
LOO4 = SMCAdaptive(generate_settings(d=d, N=N, B=B,
        δ=0.1, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=None, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=None, quantile_value=0.8, initialization='prior',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500))
_ = LOO4.sample()
# Does not move

# %%
LOO5 = SMCAdaptive(generate_settings(d=d, N=N, B=B,
        δ=0.05, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=None, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=None, quantile_value=0.8, initialization='prior',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500))
_ = LOO5.sample()
# Moves

# %%
LOO6 = SMCAdaptive(generate_settings(d=d, N=N, B=B,
        δ=0.01, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=None, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=None, quantile_value=0.8, initialization='prior',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500))
_ = LOO6.sample()
# Moves

# %% [markdown]
# ### MS-RWM from prior with smaller quantile

# %%
LOO8 = MSAdaptive(generate_settings(d=d, N=N, B=B,
        δ=5.0, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=None, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=None, quantile_value=0.8, initialization='prior',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500))
_ = LOO8.sample()
# Does not move

# %%
LOO9 = MSAdaptive(generate_settings(d=d, N=N, B=B,
        δ=1.0, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=None, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=None, quantile_value=0.8, initialization='prior',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500))
_ = LOO9.sample()
# Does not move

# %%
LOO10 = MSAdaptive(generate_settings(d=d, N=N, B=B,
        δ=0.5, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=None, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=None, quantile_value=0.8, initialization='prior',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500))
_ = LOO10.sample()
# Does not move

# %%
LOO11 = MSAdaptive(generate_settings(d=d, N=N, B=B,
        δ=0.1, δmin=δmin, min_pm=min_pm, verbose=False, εs_fixed=None, adaptiveε=True, adaptiveδ=False,
        z0_manual=None, pm_target=0.23, pm_switch=pm_switch, low_memory=True, integrator='rwm',
        εprop_switch=0.01, ε0_manual=None, quantile_value=0.8, initialization='prior',
        switch_strategy='pm', kernel='uniform',use_autograd=False, stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_scheme='multinomial', maxiter=500))
_ = LOO11.sample()
# Does not move

# %%
smc_rwm_01_05_manual = SMCAdaptive(generate_settings(
        d=d, 
        N=N,
        B=B,
        δ=0.1,
        δmin=δmin,
        min_pm=min_pm,
        verbose=True,
        εs_fixed=None,
        adaptiveε=True,
        adaptiveδ=False,
        z0_manual=grabbed_particles,
        pm_target=0.23,
        pm_switch=pm_switch,
        prior_seed=1111,
        low_memory=True,
        integrator='rwm',
        εprop_switch=0.01,
        ε0_manual=ms_rwm_to_grab_particles.εs[-1],
        quantile_value=0.5,
        initialization='manual',
        switch_strategy='pm',
        kernel='uniform',
        use_autograd=False,
        stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_seed=1234,
        mh_kernel_seed=1234,
        resampling_scheme='multinomial',
        maxiter=500)) 
smc_rwm_01_05_manual_particles = smc_rwm_01_05_manual.sample()
# Out:
# Stochastic Kernel: RWM.
# Stopping criterion:  maxiter, εmin, pm.
# Resampling: MULTINOMIAL.
# Iteration:  1
# 	Quantile Value:  0.5
# 	Particles resampled.
# 	Epsilon: 547.9712716443334557
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0000000000000000
# 	Step-size kept fixed at: 0.1000000000000000

# %%
smc_rwm_005_05_manual = SMCAdaptive(generate_settings(
        d=d, 
        N=N,
        B=B,
        δ=0.05,
        δmin=δmin,
        min_pm=min_pm,
        verbose=True,
        εs_fixed=None,
        adaptiveε=True,
        adaptiveδ=False,
        z0_manual=grabbed_particles,
        pm_target=0.23,
        pm_switch=pm_switch,
        prior_seed=1111,
        low_memory=True,
        integrator='rwm',
        εprop_switch=0.01,
        ε0_manual=ms_rwm_to_grab_particles.εs[-1],
        quantile_value=0.5,
        initialization='manual',
        switch_strategy='pm',
        kernel='uniform',
        use_autograd=False,
        stopping_criterion={'εmin', 'pm', 'maxiter'},
        resampling_seed=1234,
        mh_kernel_seed=1234,
        resampling_scheme='multinomial',
        maxiter=500)) 
smc_rwm_005_05_manual_particles = smc_rwm_005_05_manual.sample()
# Out:
# Stochastic Kernel: RWM.
# Stopping criterion:  maxiter, εmin, pm.
# Resampling: MULTINOMIAL.
# Iteration:  1
# 	Quantile Value:  0.5
# 	Particles resampled.
# 	Epsilon: 547.9712716443334557
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0044000000000000
# 	Step-size kept fixed at: 0.0500000000000000
# Iteration:  2
# 	Quantile Value:  0.5
# 	Particles resampled.
# 	Epsilon: 90.8227316444701103
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0046000000000000
# 	Step-size kept fixed at: 0.0500000000000000
# Iteration:  3
# 	Quantile Value:  0.5
# 	Particles resampled.
# 	Epsilon: 41.5214134864167050
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0024000000000000
# 	Step-size kept fixed at: 0.0500000000000000
# Iteration:  4
# 	Quantile Value:  0.5
# 	Particles resampled.
# 	Epsilon: 26.6625390014674473
# 	Weights computed and normalised.
# 	Mutation step done.
# 	Approx AP: 0.0030000000000000
# ...

# %% [markdown]
# # Plotting

# %%
# Don't show from the smallest epsilons, or it will be too much
starting_index = 2

fig, ax = plt.subplots(ncols=2, figsize=(16, 4))

# Epsilon / Iteration
# ax[0].plot(ms_rwm_01_05.εs[starting_index:], label='MS-RWM-0.1', marker='o', markevery=[-1])
ax[0].plot(ms_rwm_001_05.εs[starting_index:], label='MS-RWM-0.01', marker='o', markevery=[-1])
# ax[0].plot(ms_rwm_aδ_05.εs[starting_index:], label='MS-RWM-aδ', marker='o', markevery=[-1])
ax[0].plot(ms_hug_01_05.εs[starting_index:], label='MS-HUG-0.1', marker='o', markevery=[-1])
# ax[0].plot(epsilon_values[starting_index:], label='MS-HAN-001', marker='o', markevery=[-1])
ax[0].plot(ms_han_005_05.εs[starting_index:], label='MS-HAN-0.05', marker='o', markevery=[-1])
# ax[0].plot(ms_rh_001_05.εs[starting_index:], label='MS-RH-0.01', marker='o', markevery=[-1])
# ax[0].plot(ms_han_aδ_05_060.εs[starting_index:], label='MS-HAN-aδ06', marker='o', markevery=[-1])
# ax[0].plot(ms_han_aδ_05_020.εs[starting_index:], label='MS-HAN-aδ02', marker='o', markevery=[-1])
ax[0].plot(ms_rwm_001_05_metrop.εs[starting_index:], label='MS-RWM-M-0.01', marker='o', markevery=[-1])
ax[0].plot(ms_han_005_05_metrop.εs[starting_index:], label='MS-HAN-M-0.05', marker='o', markevery=[-1])
# ax[0].axvline(ms_rh_001_05.n_switch, color='black', ls='--')
ax[0].legend()
ax[0].set_yscale('log')
ax[0].set_ylabel(r'$\mathregular{\varepsilon}$', fontsize=20)
ax[0].set_xlabel("Iterations", fontsize=20)

# Acceptance Probability / Epsilon
# ax[1].plot(ms_rwm_01_05.εs[starting_index:], ms_rwm_01_05.PROP_MOVED[starting_index:], label='MS-RWM-0.1', marker='o', markevery=[-1])
ax[1].plot(ms_rwm_001_05.εs[starting_index:], ms_rwm_001_05.PROP_MOVED[starting_index:], label='MS-RWM-0.01', marker='o', markevery=[-1])
# ax[1].plot(ms_rwm_aδ_05.εs[starting_index:], ms_rwm_aδ_05.PROP_MOVED[starting_index:], label='MS-RWM-aδ', marker='o', markevery=[-1])
ax[1].plot(ms_hug_01_05.εs[starting_index:], ms_hug_01_05.PROP_MOVED[starting_index:], label='MS-HUG-0.1', marker='o', markevery=[-1])
# ax[1].plot(epsilon_values[starting_index:], prop_moved[starting_index:], label='MS-HAN-001', marker='o', markevery=[-1])
ax[1].plot(ms_han_005_05.εs[starting_index:], ms_han_005_05.PROP_MOVED[starting_index:], label='MS-HAN-0.05', marker='o', markevery=[-1])
# ax[1].plot(ms_rh_001_05.εs[starting_index:], ms_rh_001_05.PROP_MOVED[starting_index:], label='MS-RH-0.01', marker='o', markevery=[-1])
# ax[1].plot(ms_han_aδ_05_060.εs[starting_index:], ms_han_aδ_05_060.PROP_MOVED[starting_index:], label='MS-HAN-aδ06', marker='o', markevery=[-1])
# ax[1].plot(ms_han_aδ_05_020.εs[starting_index:], ms_han_aδ_05_020.PROP_MOVED[starting_index:], label='MS-HAN-aδ02', marker='o', markevery=[-1])
ax[1].plot(ms_rwm_001_05_metrop.εs[starting_index:], ms_rwm_001_05_metrop.PROP_MOVED[starting_index:], label='MS-RWM-M-0.01', marker='o', markevery=[-1])
ax[1].plot(ms_han_005_05_metrop.εs[starting_index:], ms_han_005_05_metrop.PROP_MOVED[starting_index:], label='MS-HAN-M-0.05', marker='o', markevery=[-1])
ax[1].legend()
ax[1].set_xscale('log')
ax[1].set_xlabel(r'$\mathregular{\varepsilon}$', fontsize=20)
ax[1].set_ylabel("Proportion of Particles Moved", fontsize=15)

plt.show()

# %%
# Don't show from the smallest epsilons, or it will be too much
starting_index = 2

fig, ax = plt.subplots(figsize=(8, 4))

# Epsilon / Iteration
ax.plot(ms_rwm_001_05.εs[starting_index:], ms_rwm_001_05.ESS[starting_index:], label='MS-RWM-0.01', marker='o', markevery=[-1])
ax.plot(ms_hug_01_05.εs[starting_index:], ms_hug_01_05.ESS[starting_index:], label='MS-HUG-0.1', marker='o', markevery=[-1])
ax.plot(ms_han_005_05.εs[starting_index:], ms_han_005_05.ESS[starting_index:], label='MS-HAN-0.05', marker='o', markevery=[-1])
ax.plot(ms_rwm_001_05_metrop.εs[starting_index:], ms_rwm_001_05_metrop.ESS[starting_index:], label='MS-RWM-M-0.01', marker='o', markevery=[-1])
ax.plot(ms_han_005_05_metrop.εs[starting_index:], ms_han_005_05_metrop.ESS[starting_index:], label='MS-HAN-M-0.05', marker='o', markevery=[-1])
# ax[0].axvline(ms_rh_001_05.n_switch, color='black', ls='--')
ax.legend()
ax.set_yscale('log')
ax.set_xscale('log')
# ax[0].set_ylabel(r'$\mathregular{\varepsilon}$', fontsize=20)
ax.set_xlabel(r"$\mathregular{\varepsilon}$", fontsize=20)
plt.show()

# %% [markdown]
# ### Visualizations for Robustness in $\delta$

# %% [markdown]
# # Indeces

# %%
def plot_histogram(n):
    fig, ax = plt.subplots(figsize=(20, 4))
    B = 20
    bins = np.arange(start=-0.5, stop=(B+1), step=1)
    _ = ax.hist(ms_han_005_05.K_RESAMPLED[n, :], bins=bins, density=True, edgecolor='k', color='lightsalmon')
    ax.set_xticks(np.arange(B+1))
    return plt.show()

resetwarnings()
interact(plot_histogram, n=(0, len(ms_han_005_05.ϵs) - 2))
# Out:
# interactive(children=(IntSlider(value=233, description='n', max=467), Output()), _dom_classes=('widget-interac…
# <function __main__.plot_histogram(n)>

# %%
def plot_histogram(n):
    fig, ax = plt.subplots(figsize=(20, 4))
    B = 20
    bins = np.arange(start=-0.5, stop=(B+1), step=1)
    _ = ax.hist(ms_rh_001_05.K_RESAMPLED[n, :], bins=bins, density=True, edgecolor='k', color='lightsalmon')
    ax.set_xticks(np.arange(B+1))
    return plt.show()

resetwarnings()
interact(plot_histogram, n=(0, len(ms_rh_001_05.ϵs) - 2))
# Out:
# interactive(children=(IntSlider(value=188, description='n', max=377), Output()), _dom_classes=('widget-interac…
# <function __main__.plot_histogram(n)>

# %% [markdown]
# # Save Data

# %%
from numpy import save

folder = 'experiment89/'

##### MS-RWM
### MS-RWM-001-05
save(folder + 'ms_rwm_001_05_εs.npy', ms_rwm_001_05.εs)
save(folder + 'ms_rwm_001_05_ess.npy', ms_rwm_001_05.ESS)
save(folder + 'ms_rwm_001_05_pm.npy', ms_rwm_001_05.PROP_MOVED)
save(folder + 'ms_rwm_001_05_k_resampled.npy', ms_rwm_001_05.K_RESAMPLED)
### MS-RWM-001-05 METROPOLISED
save(folder + 'ms_rwm_001_05_metrop_εs.npy', ms_rwm_001_05_metrop.εs)
save(folder + 'ms_rwm_001_05_metrop_ess.npy', ms_rwm_001_05_metrop.ESS)
save(folder + 'ms_rwm_001_05_metrop_pm.npy', ms_rwm_001_05_metrop.PROP_MOVED)
save(folder + 'ms_rwm_001_05_metrop_k_resampled.npy', ms_rwm_001_05_metrop.K_RESAMPLED)
### MS-RWM-01-05
save(folder + 'ms_rwm_01_05_εs.npy', ms_rwm_01_05.εs)
save(folder + 'ms_rwm_01_05_ess.npy', ms_rwm_01_05.ESS)
save(folder + 'ms_rwm_01_05_pm.npy', ms_rwm_01_05.PROP_MOVED)
save(folder + 'ms_rwm_01_05_k_resampled.npy', ms_rwm_01_05.K_RESAMPLED)
### MS-RWM-aδ-05
save(folder + 'ms_rwm_aδ_05_εs.npy', ms_rwm_aδ_05.εs)
save(folder + 'ms_rwm_aδ_05_ess.npy', ms_rwm_aδ_05.ESS)
save(folder + 'ms_rwm_aδ_05_pm.npy', ms_rwm_aδ_05.PROP_MOVED)
save(folder + 'ms_rwm_aδ_05_k_resampled.npy', ms_rwm_aδ_05.K_RESAMPLED)
save(folder + 'ms_rwm_aδ_05_δs.npy', ms_rwm_aδ_05.δs)

##### MS-HUG
### MS-HUG-01-05
save(folder + 'ms_hug_01_05_εs.npy', ms_hug_01_05.εs)
save(folder + 'ms_hug_01_05_ess.npy', ms_hug_01_05.ESS)
save(folder + 'ms_hug_01_05_pm.npy', ms_hug_01_05.PROP_MOVED)
save(folder + 'ms_hug_01_05_k_resampled.npy', ms_hug_01_05.K_RESAMPLED)

##### MS-HAN
### MS-HAN-001-05
save(folder + 'ms_han_001_05_εs.npy', epsilon_values)
# save(folder + 'ms_han_001_05_ess.npy', ms_han_001_05.ESS)
save(folder + 'ms_han_001_05_pm.npy', prop_moved)
# save(folder + 'ms_han_001_05_k_resampled.npy', ms_han_001_05.K_RESAMPLED)
### MS-HAN-005-05
save(folder + 'ms_han_005_05_εs.npy', ms_han_005_05.εs)
save(folder + 'ms_han_005_05_ess.npy', ms_han_005_05.ESS)
save(folder + 'ms_han_005_05_pm.npy', ms_han_005_05.PROP_MOVED)
save(folder + 'ms_han_005_05_k_resampled.npy', ms_han_005_05.K_RESAMPLED)
### MS-HAN-005-05 METROPOLISED
save(folder + 'ms_han_005_05_metrop_εs.npy', ms_han_005_05_metrop.εs)
save(folder + 'ms_han_005_05_metrop_ess.npy', ms_han_005_05_metrop.ESS)
save(folder + 'ms_han_005_05_metrop_pm.npy', ms_han_005_05_metrop.PROP_MOVED)
save(folder + 'ms_han_005_05_metrop_k_resampled.npy', ms_han_005_05_metrop.K_RESAMPLED)
### MS-HAN-01-05
save(folder + 'ms_han_01_05_εs.npy', ms_han_01_05.εs)
save(folder + 'ms_han_01_05_ess.npy', ms_han_01_05.ESS)
save(folder + 'ms_han_01_05_pm.npy', ms_han_01_05.PROP_MOVED)
save(folder + 'ms_han_01_05_k_resampled.npy', ms_han_01_05.K_RESAMPLED)
save(folder + 'ms_han_01_05_δs.npy', ms_han_01_05.δs)
### MS-HAN-aδ-05-020
save(folder + 'ms_han_aδ_05_020_εs.npy', ms_han_aδ_05_020.εs)
save(folder + 'ms_han_aδ_05_020_ess.npy', ms_han_aδ_05_020.ESS)
save(folder + 'ms_han_aδ_05_020_pm.npy', ms_han_aδ_05_020.PROP_MOVED)
save(folder + 'ms_han_aδ_05_020_k_resampled.npy', ms_han_aδ_05_020.K_RESAMPLED)
save(folder + 'ms_han_aδ_05_020_δs.npy', ms_han_aδ_05_020.δs)
### MS-HAN-aδ-05-060
save(folder + 'ms_han_aδ_05_060_εs.npy', ms_han_aδ_05_060.εs)
save(folder + 'ms_han_aδ_05_060_ess.npy', ms_han_aδ_05_060.ESS)
save(folder + 'ms_han_aδ_05_060_pm.npy', ms_han_aδ_05_060.PROP_MOVED)
save(folder + 'ms_han_aδ_05_060_k_resampled.npy', ms_han_aδ_05_060.K_RESAMPLED)
save(folder + 'ms_han_aδ_05_060_δs.npy', ms_han_aδ_05_060.δs)
### MS-HAN-aδ-05-023
save(folder + 'ms_han_aδ_05_023_εs.npy', ms_han_aδ_05_023.εs)
save(folder + 'ms_han_aδ_05_023_ess.npy', ms_han_aδ_05_023.ESS)
save(folder + 'ms_han_aδ_05_023_pm.npy', ms_han_aδ_05_023.PROP_MOVED)
save(folder + 'ms_han_aδ_05_023_k_resampled.npy', ms_han_aδ_05_023.K_RESAMPLED)
save(folder + 'ms_han_aδ_05_023_δs.npy', ms_han_aδ_05_023.δs)

##### MS-RH
### MS-RH-001-05
save(folder + 'ms_rh_001_05_εs.npy', ms_rh_001_05.εs)
save(folder + 'ms_rh_001_05_ess.npy', ms_rh_001_05.ESS)
save(folder + 'ms_rh_001_05_pm.npy', ms_rh_001_05.PROP_MOVED)
save(folder + 'ms_rh_001_05_k_resampled.npy', ms_rh_001_05.K_RESAMPLED)
save(folder + 'ms_rh_001_05_n_switch.npy', ms_rh_001_05.n_switch)
### MS-RH-aδ-05
save(folder + 'ms_rh_aδ_05_εs.npy', ms_rh_aδ_05.εs)
save(folder + 'ms_rh_aδ_05_ess.npy', ms_rh_aδ_05.ESS)
save(folder + 'ms_rh_aδ_05_pm.npy', ms_rh_aδ_05.PROP_MOVED)
save(folder + 'ms_rh_aδ_05_k_resampled.npy', ms_rh_aδ_05.K_RESAMPLED)
save(folder + 'ms_rh_aδ_05_n_switch.npy', ms_rh_aδ_05.n_switch)
save(folder + 'ms_rh_aδ_05_δs.npy', ms_rh_aδ_05.δs)
